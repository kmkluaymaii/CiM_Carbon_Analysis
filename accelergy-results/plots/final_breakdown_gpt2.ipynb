# %%
import os
import re
import json

# Set the base directory
base_dir = './gpt2_128/outputs'

# Dictionary to store all layer percentages
all_layers_percent = {}

# List all folders that are layer directories (named with two digits)
layer_folders = sorted([d for d in os.listdir(base_dir) if d.isdigit() and len(d) == 3])

for folder_name in layer_folders:
    folder = os.path.join(base_dir, folder_name)
    stat_path = os.path.join(folder, 'timeloop-mapper.stats.txt')

    if not os.path.isfile(stat_path):
        print(f"Warning: {stat_path} not found. Skipping.")
        continue

    with open(stat_path, 'r') as file:
        lines = file.readlines()

    # Locate the 'fJ/Compute' section
    start_index = -1
    for i, line in enumerate(lines):
        if 'fJ/Compute' in line:
            start_index = i + 1
            break

    if start_index == -1:
        print(f"Warning: 'fJ/Compute' section not found in {stat_path}. Skipping.")
        continue

    component_energy = {}
    total_energy = 0.0
    for line in lines[start_index:]:
        line = line.strip()
        if not line or line.startswith("#"):
            continue
        match = re.match(r'^([\w/]+)\s+=\s+([\d.]+)', line)
        if match:
            name = match.group(1)
            if name.lower() == 'total':
                continue  # Skip 'Total' line from component list
            energy = float(match.group(2))
            component_energy[name] = energy
            total_energy += energy
        elif "Total" in line:
            break  # Stop if a general "Total" line is reached after components

    # Calculate and print percentages
    component_energy_percent = {}
    print(f"\nLayer {folder_name} - Total Energy (excluding 'Total' line): {total_energy:.2f} fJ/Compute\n")
    for name, energy in component_energy.items():
        percent = (energy / total_energy) * 100 if total_energy > 0 else 0
        component_energy_percent[name] = percent
        print(f"{name:<35} : {energy:.2f} fJ ({percent:.2f}%)")

    # Store percentages for this layer
    all_layers_percent[folder_name] = component_energy_percent

# Optional: Output all percentages as JSON (nicely formatted)
print("\n=== All Layers Percentage Breakdown ===")
print(json.dumps(all_layers_percent, indent=2))
# Out:
# Layer 000 - Total Energy (excluding 'Total' line): 3666.39 fJ/Compute
#
# mac                                 : 665.77 fJ (18.16%)
# output_activation_reg               : 105.99 fJ (2.89%)
# input_activation_reg                : 106.82 fJ (2.91%)
# weight_reg                          : 106.82 fJ (2.91%)
# pe_spad                             : 4.86 fJ (0.13%)
# shared_glb                          : 551.13 fJ (15.03%)
# DRAM                                : 2125.00 fJ (57.96%)
#
# Layer 001 - Total Energy (excluding 'Total' line): 4088.49 fJ/Compute
#
# mac                                 : 665.77 fJ (16.28%)
# output_activation_reg               : 105.15 fJ (2.57%)
# input_activation_reg                : 106.82 fJ (2.61%)
# weight_reg                          : 106.82 fJ (2.61%)
# pe_spad                             : 12.22 fJ (0.30%)
# shared_glb                          : 466.71 fJ (11.42%)
# DRAM                                : 2625.00 fJ (64.20%)
#
# Layer 002 - Total Energy (excluding 'Total' line): 11838.73 fJ/Compute
#
# mac                                 : 665.77 fJ (5.62%)
# output_activation_reg               : 80.11 fJ (0.68%)
# input_activation_reg                : 106.82 fJ (0.90%)
# weight_reg                          : 106.82 fJ (0.90%)
# pe_spad                             : 193.19 fJ (1.63%)
# shared_glb                          : 186.02 fJ (1.57%)
# DRAM                                : 10500.00 fJ (88.69%)
#
# Layer 003 - Total Energy (excluding 'Total' line): 12096.26 fJ/Compute
#
# mac                                 : 665.77 fJ (5.50%)
# output_activation_reg               : 105.99 fJ (0.88%)
# input_activation_reg                : 106.82 fJ (0.88%)
# weight_reg                          : 106.82 fJ (0.88%)
# pe_spad                             : 193.19 fJ (1.60%)
# shared_glb                          : 417.67 fJ (3.45%)
# DRAM                                : 10500.00 fJ (86.80%)
#
# Layer 004 - Total Energy (excluding 'Total' line): 5850.62 fJ/Compute
#
# mac                                 : 665.77 fJ (11.38%)
# output_activation_reg               : 106.40 fJ (1.82%)
# input_activation_reg                : 106.82 fJ (1.83%)
# weight_reg                          : 106.82 fJ (1.83%)
# pe_spad                             : 178.69 fJ (3.05%)
# shared_glb                          : 61.12 fJ (1.04%)
# DRAM                                : 4625.00 fJ (79.05%)
#
# Layer 005 - Total Energy (excluding 'Total' line): 3218.54 fJ/Compute
#
# mac                                 : 665.77 fJ (20.69%)
# output_activation_reg               : 106.61 fJ (3.31%)
# input_activation_reg                : 106.82 fJ (3.32%)
# weight_reg                          : 106.82 fJ (3.32%)
# pe_spad                             : 26.77 fJ (0.83%)
# shared_glb                          : 674.50 fJ (20.96%)
# DRAM                                : 1531.25 fJ (47.58%)
#
# Layer 006 - Total Energy (excluding 'Total' line): 3666.39 fJ/Compute
#
# mac                                 : 665.77 fJ (18.16%)
# output_activation_reg               : 105.99 fJ (2.89%)
# input_activation_reg                : 106.82 fJ (2.91%)
# weight_reg                          : 106.82 fJ (2.91%)
# pe_spad                             : 4.86 fJ (0.13%)
# shared_glb                          : 551.13 fJ (15.03%)
# DRAM                                : 2125.00 fJ (57.96%)
#
# Layer 007 - Total Energy (excluding 'Total' line): 4088.49 fJ/Compute
#
# mac                                 : 665.77 fJ (16.28%)
# output_activation_reg               : 105.15 fJ (2.57%)
# input_activation_reg                : 106.82 fJ (2.61%)
# weight_reg                          : 106.82 fJ (2.61%)
# pe_spad                             : 12.22 fJ (0.30%)
# shared_glb                          : 466.71 fJ (11.42%)
# DRAM                                : 2625.00 fJ (64.20%)
#
# Layer 008 - Total Energy (excluding 'Total' line): 11838.73 fJ/Compute
#
# mac                                 : 665.77 fJ (5.62%)
# output_activation_reg               : 80.11 fJ (0.68%)
# input_activation_reg                : 106.82 fJ (0.90%)
# weight_reg                          : 106.82 fJ (0.90%)
# pe_spad                             : 193.19 fJ (1.63%)
# shared_glb                          : 186.02 fJ (1.57%)
# DRAM                                : 10500.00 fJ (88.69%)
#
# Layer 009 - Total Energy (excluding 'Total' line): 12096.26 fJ/Compute
#
# mac                                 : 665.77 fJ (5.50%)
# output_activation_reg               : 105.99 fJ (0.88%)
# input_activation_reg                : 106.82 fJ (0.88%)
# weight_reg                          : 106.82 fJ (0.88%)
# pe_spad                             : 193.19 fJ (1.60%)
# shared_glb                          : 417.67 fJ (3.45%)
# DRAM                                : 10500.00 fJ (86.80%)
#
# Layer 010 - Total Energy (excluding 'Total' line): 5850.62 fJ/Compute
#
# mac                                 : 665.77 fJ (11.38%)
# output_activation_reg               : 106.40 fJ (1.82%)
# input_activation_reg                : 106.82 fJ (1.83%)
# weight_reg                          : 106.82 fJ (1.83%)
# pe_spad                             : 178.69 fJ (3.05%)
# shared_glb                          : 61.12 fJ (1.04%)
# DRAM                                : 4625.00 fJ (79.05%)
#
# Layer 011 - Total Energy (excluding 'Total' line): 3218.54 fJ/Compute
#
# mac                                 : 665.77 fJ (20.69%)
# output_activation_reg               : 106.61 fJ (3.31%)
# input_activation_reg                : 106.82 fJ (3.32%)
# weight_reg                          : 106.82 fJ (3.32%)
# pe_spad                             : 26.77 fJ (0.83%)
# shared_glb                          : 674.50 fJ (20.96%)
# DRAM                                : 1531.25 fJ (47.58%)
#
# Layer 012 - Total Energy (excluding 'Total' line): 3666.39 fJ/Compute
#
# mac                                 : 665.77 fJ (18.16%)
# output_activation_reg               : 105.99 fJ (2.89%)
# input_activation_reg                : 106.82 fJ (2.91%)
# weight_reg                          : 106.82 fJ (2.91%)
# pe_spad                             : 4.86 fJ (0.13%)
# shared_glb                          : 551.13 fJ (15.03%)
# DRAM                                : 2125.00 fJ (57.96%)
#
# Layer 013 - Total Energy (excluding 'Total' line): 4088.49 fJ/Compute
#
# mac                                 : 665.77 fJ (16.28%)
# output_activation_reg               : 105.15 fJ (2.57%)
# input_activation_reg                : 106.82 fJ (2.61%)
# weight_reg                          : 106.82 fJ (2.61%)
# pe_spad                             : 12.22 fJ (0.30%)
# shared_glb                          : 466.71 fJ (11.42%)
# DRAM                                : 2625.00 fJ (64.20%)
#
# Layer 014 - Total Energy (excluding 'Total' line): 11838.73 fJ/Compute
#
# mac                                 : 665.77 fJ (5.62%)
# output_activation_reg               : 80.11 fJ (0.68%)
# input_activation_reg                : 106.82 fJ (0.90%)
# weight_reg                          : 106.82 fJ (0.90%)
# pe_spad                             : 193.19 fJ (1.63%)
# shared_glb                          : 186.02 fJ (1.57%)
# DRAM                                : 10500.00 fJ (88.69%)
#
# Layer 015 - Total Energy (excluding 'Total' line): 12096.26 fJ/Compute
#
# mac                                 : 665.77 fJ (5.50%)
# output_activation_reg               : 105.99 fJ (0.88%)
# input_activation_reg                : 106.82 fJ (0.88%)
# weight_reg                          : 106.82 fJ (0.88%)
# pe_spad                             : 193.19 fJ (1.60%)
# shared_glb                          : 417.67 fJ (3.45%)
# DRAM                                : 10500.00 fJ (86.80%)
#
# Layer 016 - Total Energy (excluding 'Total' line): 5850.62 fJ/Compute
#
# mac                                 : 665.77 fJ (11.38%)
# output_activation_reg               : 106.40 fJ (1.82%)
# input_activation_reg                : 106.82 fJ (1.83%)
# weight_reg                          : 106.82 fJ (1.83%)
# pe_spad                             : 178.69 fJ (3.05%)
# shared_glb                          : 61.12 fJ (1.04%)
# DRAM                                : 4625.00 fJ (79.05%)
#
# Layer 017 - Total Energy (excluding 'Total' line): 3218.54 fJ/Compute
#
# mac                                 : 665.77 fJ (20.69%)
# output_activation_reg               : 106.61 fJ (3.31%)
# input_activation_reg                : 106.82 fJ (3.32%)
# weight_reg                          : 106.82 fJ (3.32%)
# pe_spad                             : 26.77 fJ (0.83%)
# shared_glb                          : 674.50 fJ (20.96%)
# DRAM                                : 1531.25 fJ (47.58%)
#
# Layer 018 - Total Energy (excluding 'Total' line): 3666.39 fJ/Compute
#
# mac                                 : 665.77 fJ (18.16%)
# output_activation_reg               : 105.99 fJ (2.89%)
# input_activation_reg                : 106.82 fJ (2.91%)
# weight_reg                          : 106.82 fJ (2.91%)
# pe_spad                             : 4.86 fJ (0.13%)
# shared_glb                          : 551.13 fJ (15.03%)
# DRAM                                : 2125.00 fJ (57.96%)
#
# Layer 019 - Total Energy (excluding 'Total' line): 4088.49 fJ/Compute
#
# mac                                 : 665.77 fJ (16.28%)
# output_activation_reg               : 105.15 fJ (2.57%)
# input_activation_reg                : 106.82 fJ (2.61%)
# weight_reg                          : 106.82 fJ (2.61%)
# pe_spad                             : 12.22 fJ (0.30%)
# shared_glb                          : 466.71 fJ (11.42%)
# DRAM                                : 2625.00 fJ (64.20%)
#
# Layer 020 - Total Energy (excluding 'Total' line): 11838.73 fJ/Compute
#
# mac                                 : 665.77 fJ (5.62%)
# output_activation_reg               : 80.11 fJ (0.68%)
# input_activation_reg                : 106.82 fJ (0.90%)
# weight_reg                          : 106.82 fJ (0.90%)
# pe_spad                             : 193.19 fJ (1.63%)
# shared_glb                          : 186.02 fJ (1.57%)
# DRAM                                : 10500.00 fJ (88.69%)
#
# Layer 021 - Total Energy (excluding 'Total' line): 12096.26 fJ/Compute
#
# mac                                 : 665.77 fJ (5.50%)
# output_activation_reg               : 105.99 fJ (0.88%)
# input_activation_reg                : 106.82 fJ (0.88%)
# weight_reg                          : 106.82 fJ (0.88%)
# pe_spad                             : 193.19 fJ (1.60%)
# shared_glb                          : 417.67 fJ (3.45%)
# DRAM                                : 10500.00 fJ (86.80%)
#
# Layer 022 - Total Energy (excluding 'Total' line): 5850.62 fJ/Compute
#
# mac                                 : 665.77 fJ (11.38%)
# output_activation_reg               : 106.40 fJ (1.82%)
# input_activation_reg                : 106.82 fJ (1.83%)
# weight_reg                          : 106.82 fJ (1.83%)
# pe_spad                             : 178.69 fJ (3.05%)
# shared_glb                          : 61.12 fJ (1.04%)
# DRAM                                : 4625.00 fJ (79.05%)
#
# Layer 023 - Total Energy (excluding 'Total' line): 3218.54 fJ/Compute
#
# mac                                 : 665.77 fJ (20.69%)
# output_activation_reg               : 106.61 fJ (3.31%)
# input_activation_reg                : 106.82 fJ (3.32%)
# weight_reg                          : 106.82 fJ (3.32%)
# pe_spad                             : 26.77 fJ (0.83%)
# shared_glb                          : 674.50 fJ (20.96%)
# DRAM                                : 1531.25 fJ (47.58%)
#
# Layer 024 - Total Energy (excluding 'Total' line): 3666.39 fJ/Compute
#
# mac                                 : 665.77 fJ (18.16%)
# output_activation_reg               : 105.99 fJ (2.89%)
# input_activation_reg                : 106.82 fJ (2.91%)
# weight_reg                          : 106.82 fJ (2.91%)
# pe_spad                             : 4.86 fJ (0.13%)
# shared_glb                          : 551.13 fJ (15.03%)
# DRAM                                : 2125.00 fJ (57.96%)
#
# Layer 025 - Total Energy (excluding 'Total' line): 4088.49 fJ/Compute
#
# mac                                 : 665.77 fJ (16.28%)
# output_activation_reg               : 105.15 fJ (2.57%)
# input_activation_reg                : 106.82 fJ (2.61%)
# weight_reg                          : 106.82 fJ (2.61%)
# pe_spad                             : 12.22 fJ (0.30%)
# shared_glb                          : 466.71 fJ (11.42%)
# DRAM                                : 2625.00 fJ (64.20%)
#
# Layer 026 - Total Energy (excluding 'Total' line): 11838.73 fJ/Compute
#
# mac                                 : 665.77 fJ (5.62%)
# output_activation_reg               : 80.11 fJ (0.68%)
# input_activation_reg                : 106.82 fJ (0.90%)
# weight_reg                          : 106.82 fJ (0.90%)
# pe_spad                             : 193.19 fJ (1.63%)
# shared_glb                          : 186.02 fJ (1.57%)
# DRAM                                : 10500.00 fJ (88.69%)
#
# Layer 027 - Total Energy (excluding 'Total' line): 12096.26 fJ/Compute
#
# mac                                 : 665.77 fJ (5.50%)
# output_activation_reg               : 105.99 fJ (0.88%)
# input_activation_reg                : 106.82 fJ (0.88%)
# weight_reg                          : 106.82 fJ (0.88%)
# pe_spad                             : 193.19 fJ (1.60%)
# shared_glb                          : 417.67 fJ (3.45%)
# DRAM                                : 10500.00 fJ (86.80%)
#
# Layer 028 - Total Energy (excluding 'Total' line): 5850.62 fJ/Compute
#
# mac                                 : 665.77 fJ (11.38%)
# output_activation_reg               : 106.40 fJ (1.82%)
# input_activation_reg                : 106.82 fJ (1.83%)
# weight_reg                          : 106.82 fJ (1.83%)
# pe_spad                             : 178.69 fJ (3.05%)
# shared_glb                          : 61.12 fJ (1.04%)
# DRAM                                : 4625.00 fJ (79.05%)
#
# Layer 029 - Total Energy (excluding 'Total' line): 3218.54 fJ/Compute
#
# mac                                 : 665.77 fJ (20.69%)
# output_activation_reg               : 106.61 fJ (3.31%)
# input_activation_reg                : 106.82 fJ (3.32%)
# weight_reg                          : 106.82 fJ (3.32%)
# pe_spad                             : 26.77 fJ (0.83%)
# shared_glb                          : 674.50 fJ (20.96%)
# DRAM                                : 1531.25 fJ (47.58%)
#
# Layer 030 - Total Energy (excluding 'Total' line): 3666.39 fJ/Compute
#
# mac                                 : 665.77 fJ (18.16%)
# output_activation_reg               : 105.99 fJ (2.89%)
# input_activation_reg                : 106.82 fJ (2.91%)
# weight_reg                          : 106.82 fJ (2.91%)
# pe_spad                             : 4.86 fJ (0.13%)
# shared_glb                          : 551.13 fJ (15.03%)
# DRAM                                : 2125.00 fJ (57.96%)
#
# Layer 031 - Total Energy (excluding 'Total' line): 4088.49 fJ/Compute
#
# mac                                 : 665.77 fJ (16.28%)
# output_activation_reg               : 105.15 fJ (2.57%)
# input_activation_reg                : 106.82 fJ (2.61%)
# weight_reg                          : 106.82 fJ (2.61%)
# pe_spad                             : 12.22 fJ (0.30%)
# shared_glb                          : 466.71 fJ (11.42%)
# DRAM                                : 2625.00 fJ (64.20%)
#
# Layer 032 - Total Energy (excluding 'Total' line): 11838.73 fJ/Compute
#
# mac                                 : 665.77 fJ (5.62%)
# output_activation_reg               : 80.11 fJ (0.68%)
# input_activation_reg                : 106.82 fJ (0.90%)
# weight_reg                          : 106.82 fJ (0.90%)
# pe_spad                             : 193.19 fJ (1.63%)
# shared_glb                          : 186.02 fJ (1.57%)
# DRAM                                : 10500.00 fJ (88.69%)
#
# Layer 033 - Total Energy (excluding 'Total' line): 12096.26 fJ/Compute
#
# mac                                 : 665.77 fJ (5.50%)
# output_activation_reg               : 105.99 fJ (0.88%)
# input_activation_reg                : 106.82 fJ (0.88%)
# weight_reg                          : 106.82 fJ (0.88%)
# pe_spad                             : 193.19 fJ (1.60%)
# shared_glb                          : 417.67 fJ (3.45%)
# DRAM                                : 10500.00 fJ (86.80%)
#
# Layer 034 - Total Energy (excluding 'Total' line): 5850.62 fJ/Compute
#
# mac                                 : 665.77 fJ (11.38%)
# output_activation_reg               : 106.40 fJ (1.82%)
# input_activation_reg                : 106.82 fJ (1.83%)
# weight_reg                          : 106.82 fJ (1.83%)
# pe_spad                             : 178.69 fJ (3.05%)
# shared_glb                          : 61.12 fJ (1.04%)
# DRAM                                : 4625.00 fJ (79.05%)
#
# Layer 035 - Total Energy (excluding 'Total' line): 3218.54 fJ/Compute
#
# mac                                 : 665.77 fJ (20.69%)
# output_activation_reg               : 106.61 fJ (3.31%)
# input_activation_reg                : 106.82 fJ (3.32%)
# weight_reg                          : 106.82 fJ (3.32%)
# pe_spad                             : 26.77 fJ (0.83%)
# shared_glb                          : 674.50 fJ (20.96%)
# DRAM                                : 1531.25 fJ (47.58%)
#
# Layer 036 - Total Energy (excluding 'Total' line): 3666.39 fJ/Compute
#
# mac                                 : 665.77 fJ (18.16%)
# output_activation_reg               : 105.99 fJ (2.89%)
# input_activation_reg                : 106.82 fJ (2.91%)
# weight_reg                          : 106.82 fJ (2.91%)
# pe_spad                             : 4.86 fJ (0.13%)
# shared_glb                          : 551.13 fJ (15.03%)
# DRAM                                : 2125.00 fJ (57.96%)
#
# Layer 037 - Total Energy (excluding 'Total' line): 4088.49 fJ/Compute
#
# mac                                 : 665.77 fJ (16.28%)
# output_activation_reg               : 105.15 fJ (2.57%)
# input_activation_reg                : 106.82 fJ (2.61%)
# weight_reg                          : 106.82 fJ (2.61%)
# pe_spad                             : 12.22 fJ (0.30%)
# shared_glb                          : 466.71 fJ (11.42%)
# DRAM                                : 2625.00 fJ (64.20%)
#
# Layer 038 - Total Energy (excluding 'Total' line): 11838.73 fJ/Compute
#
# mac                                 : 665.77 fJ (5.62%)
# output_activation_reg               : 80.11 fJ (0.68%)
# input_activation_reg                : 106.82 fJ (0.90%)
# weight_reg                          : 106.82 fJ (0.90%)
# pe_spad                             : 193.19 fJ (1.63%)
# shared_glb                          : 186.02 fJ (1.57%)
# DRAM                                : 10500.00 fJ (88.69%)
#
# Layer 039 - Total Energy (excluding 'Total' line): 12096.26 fJ/Compute
#
# mac                                 : 665.77 fJ (5.50%)
# output_activation_reg               : 105.99 fJ (0.88%)
# input_activation_reg                : 106.82 fJ (0.88%)
# weight_reg                          : 106.82 fJ (0.88%)
# pe_spad                             : 193.19 fJ (1.60%)
# shared_glb                          : 417.67 fJ (3.45%)
# DRAM                                : 10500.00 fJ (86.80%)
#
# Layer 040 - Total Energy (excluding 'Total' line): 5850.62 fJ/Compute
#
# mac                                 : 665.77 fJ (11.38%)
# output_activation_reg               : 106.40 fJ (1.82%)
# input_activation_reg                : 106.82 fJ (1.83%)
# weight_reg                          : 106.82 fJ (1.83%)
# pe_spad                             : 178.69 fJ (3.05%)
# shared_glb                          : 61.12 fJ (1.04%)
# DRAM                                : 4625.00 fJ (79.05%)
#
# Layer 041 - Total Energy (excluding 'Total' line): 3218.54 fJ/Compute
#
# mac                                 : 665.77 fJ (20.69%)
# output_activation_reg               : 106.61 fJ (3.31%)
# input_activation_reg                : 106.82 fJ (3.32%)
# weight_reg                          : 106.82 fJ (3.32%)
# pe_spad                             : 26.77 fJ (0.83%)
# shared_glb                          : 674.50 fJ (20.96%)
# DRAM                                : 1531.25 fJ (47.58%)
#
# Layer 042 - Total Energy (excluding 'Total' line): 3666.39 fJ/Compute
#
# mac                                 : 665.77 fJ (18.16%)
# output_activation_reg               : 105.99 fJ (2.89%)
# input_activation_reg                : 106.82 fJ (2.91%)
# weight_reg                          : 106.82 fJ (2.91%)
# pe_spad                             : 4.86 fJ (0.13%)
# shared_glb                          : 551.13 fJ (15.03%)
# DRAM                                : 2125.00 fJ (57.96%)
#
# Layer 043 - Total Energy (excluding 'Total' line): 4088.49 fJ/Compute
#
# mac                                 : 665.77 fJ (16.28%)
# output_activation_reg               : 105.15 fJ (2.57%)
# input_activation_reg                : 106.82 fJ (2.61%)
# weight_reg                          : 106.82 fJ (2.61%)
# pe_spad                             : 12.22 fJ (0.30%)
# shared_glb                          : 466.71 fJ (11.42%)
# DRAM                                : 2625.00 fJ (64.20%)
#
# Layer 044 - Total Energy (excluding 'Total' line): 11838.73 fJ/Compute
#
# mac                                 : 665.77 fJ (5.62%)
# output_activation_reg               : 80.11 fJ (0.68%)
# input_activation_reg                : 106.82 fJ (0.90%)
# weight_reg                          : 106.82 fJ (0.90%)
# pe_spad                             : 193.19 fJ (1.63%)
# shared_glb                          : 186.02 fJ (1.57%)
# DRAM                                : 10500.00 fJ (88.69%)
#
# Layer 045 - Total Energy (excluding 'Total' line): 12096.26 fJ/Compute
#
# mac                                 : 665.77 fJ (5.50%)
# output_activation_reg               : 105.99 fJ (0.88%)
# input_activation_reg                : 106.82 fJ (0.88%)
# weight_reg                          : 106.82 fJ (0.88%)
# pe_spad                             : 193.19 fJ (1.60%)
# shared_glb                          : 417.67 fJ (3.45%)
# DRAM                                : 10500.00 fJ (86.80%)
#
# Layer 046 - Total Energy (excluding 'Total' line): 5850.62 fJ/Compute
#
# mac                                 : 665.77 fJ (11.38%)
# output_activation_reg               : 106.40 fJ (1.82%)
# input_activation_reg                : 106.82 fJ (1.83%)
# weight_reg                          : 106.82 fJ (1.83%)
# pe_spad                             : 178.69 fJ (3.05%)
# shared_glb                          : 61.12 fJ (1.04%)
# DRAM                                : 4625.00 fJ (79.05%)
#
# Layer 047 - Total Energy (excluding 'Total' line): 3218.54 fJ/Compute
#
# mac                                 : 665.77 fJ (20.69%)
# output_activation_reg               : 106.61 fJ (3.31%)
# input_activation_reg                : 106.82 fJ (3.32%)
# weight_reg                          : 106.82 fJ (3.32%)
# pe_spad                             : 26.77 fJ (0.83%)
# shared_glb                          : 674.50 fJ (20.96%)
# DRAM                                : 1531.25 fJ (47.58%)
#
# Layer 048 - Total Energy (excluding 'Total' line): 3666.39 fJ/Compute
#
# mac                                 : 665.77 fJ (18.16%)
# output_activation_reg               : 105.99 fJ (2.89%)
# input_activation_reg                : 106.82 fJ (2.91%)
# weight_reg                          : 106.82 fJ (2.91%)
# pe_spad                             : 4.86 fJ (0.13%)
# shared_glb                          : 551.13 fJ (15.03%)
# DRAM                                : 2125.00 fJ (57.96%)
#
# Layer 049 - Total Energy (excluding 'Total' line): 4088.49 fJ/Compute
#
# mac                                 : 665.77 fJ (16.28%)
# output_activation_reg               : 105.15 fJ (2.57%)
# input_activation_reg                : 106.82 fJ (2.61%)
# weight_reg                          : 106.82 fJ (2.61%)
# pe_spad                             : 12.22 fJ (0.30%)
# shared_glb                          : 466.71 fJ (11.42%)
# DRAM                                : 2625.00 fJ (64.20%)
#
# Layer 050 - Total Energy (excluding 'Total' line): 11838.73 fJ/Compute
#
# mac                                 : 665.77 fJ (5.62%)
# output_activation_reg               : 80.11 fJ (0.68%)
# input_activation_reg                : 106.82 fJ (0.90%)
# weight_reg                          : 106.82 fJ (0.90%)
# pe_spad                             : 193.19 fJ (1.63%)
# shared_glb                          : 186.02 fJ (1.57%)
# DRAM                                : 10500.00 fJ (88.69%)
#
# Layer 051 - Total Energy (excluding 'Total' line): 12096.26 fJ/Compute
#
# mac                                 : 665.77 fJ (5.50%)
# output_activation_reg               : 105.99 fJ (0.88%)
# input_activation_reg                : 106.82 fJ (0.88%)
# weight_reg                          : 106.82 fJ (0.88%)
# pe_spad                             : 193.19 fJ (1.60%)
# shared_glb                          : 417.67 fJ (3.45%)
# DRAM                                : 10500.00 fJ (86.80%)
#
# Layer 052 - Total Energy (excluding 'Total' line): 5850.62 fJ/Compute
#
# mac                                 : 665.77 fJ (11.38%)
# output_activation_reg               : 106.40 fJ (1.82%)
# input_activation_reg                : 106.82 fJ (1.83%)
# weight_reg                          : 106.82 fJ (1.83%)
# pe_spad                             : 178.69 fJ (3.05%)
# shared_glb                          : 61.12 fJ (1.04%)
# DRAM                                : 4625.00 fJ (79.05%)
#
# Layer 053 - Total Energy (excluding 'Total' line): 3218.54 fJ/Compute
#
# mac                                 : 665.77 fJ (20.69%)
# output_activation_reg               : 106.61 fJ (3.31%)
# input_activation_reg                : 106.82 fJ (3.32%)
# weight_reg                          : 106.82 fJ (3.32%)
# pe_spad                             : 26.77 fJ (0.83%)
# shared_glb                          : 674.50 fJ (20.96%)
# DRAM                                : 1531.25 fJ (47.58%)
#
# Layer 054 - Total Energy (excluding 'Total' line): 3666.39 fJ/Compute
#
# mac                                 : 665.77 fJ (18.16%)
# output_activation_reg               : 105.99 fJ (2.89%)
# input_activation_reg                : 106.82 fJ (2.91%)
# weight_reg                          : 106.82 fJ (2.91%)
# pe_spad                             : 4.86 fJ (0.13%)
# shared_glb                          : 551.13 fJ (15.03%)
# DRAM                                : 2125.00 fJ (57.96%)
#
# Layer 055 - Total Energy (excluding 'Total' line): 4088.49 fJ/Compute
#
# mac                                 : 665.77 fJ (16.28%)
# output_activation_reg               : 105.15 fJ (2.57%)
# input_activation_reg                : 106.82 fJ (2.61%)
# weight_reg                          : 106.82 fJ (2.61%)
# pe_spad                             : 12.22 fJ (0.30%)
# shared_glb                          : 466.71 fJ (11.42%)
# DRAM                                : 2625.00 fJ (64.20%)
#
# Layer 056 - Total Energy (excluding 'Total' line): 11838.73 fJ/Compute
#
# mac                                 : 665.77 fJ (5.62%)
# output_activation_reg               : 80.11 fJ (0.68%)
# input_activation_reg                : 106.82 fJ (0.90%)
# weight_reg                          : 106.82 fJ (0.90%)
# pe_spad                             : 193.19 fJ (1.63%)
# shared_glb                          : 186.02 fJ (1.57%)
# DRAM                                : 10500.00 fJ (88.69%)
#
# Layer 057 - Total Energy (excluding 'Total' line): 12096.26 fJ/Compute
#
# mac                                 : 665.77 fJ (5.50%)
# output_activation_reg               : 105.99 fJ (0.88%)
# input_activation_reg                : 106.82 fJ (0.88%)
# weight_reg                          : 106.82 fJ (0.88%)
# pe_spad                             : 193.19 fJ (1.60%)
# shared_glb                          : 417.67 fJ (3.45%)
# DRAM                                : 10500.00 fJ (86.80%)
#
# Layer 058 - Total Energy (excluding 'Total' line): 5850.62 fJ/Compute
#
# mac                                 : 665.77 fJ (11.38%)
# output_activation_reg               : 106.40 fJ (1.82%)
# input_activation_reg                : 106.82 fJ (1.83%)
# weight_reg                          : 106.82 fJ (1.83%)
# pe_spad                             : 178.69 fJ (3.05%)
# shared_glb                          : 61.12 fJ (1.04%)
# DRAM                                : 4625.00 fJ (79.05%)
#
# Layer 059 - Total Energy (excluding 'Total' line): 3218.54 fJ/Compute
#
# mac                                 : 665.77 fJ (20.69%)
# output_activation_reg               : 106.61 fJ (3.31%)
# input_activation_reg                : 106.82 fJ (3.32%)
# weight_reg                          : 106.82 fJ (3.32%)
# pe_spad                             : 26.77 fJ (0.83%)
# shared_glb                          : 674.50 fJ (20.96%)
# DRAM                                : 1531.25 fJ (47.58%)
#
# Layer 060 - Total Energy (excluding 'Total' line): 3666.39 fJ/Compute
#
# mac                                 : 665.77 fJ (18.16%)
# output_activation_reg               : 105.99 fJ (2.89%)
# input_activation_reg                : 106.82 fJ (2.91%)
# weight_reg                          : 106.82 fJ (2.91%)
# pe_spad                             : 4.86 fJ (0.13%)
# shared_glb                          : 551.13 fJ (15.03%)
# DRAM                                : 2125.00 fJ (57.96%)
#
# Layer 061 - Total Energy (excluding 'Total' line): 4088.49 fJ/Compute
#
# mac                                 : 665.77 fJ (16.28%)
# output_activation_reg               : 105.15 fJ (2.57%)
# input_activation_reg                : 106.82 fJ (2.61%)
# weight_reg                          : 106.82 fJ (2.61%)
# pe_spad                             : 12.22 fJ (0.30%)
# shared_glb                          : 466.71 fJ (11.42%)
# DRAM                                : 2625.00 fJ (64.20%)
#
# Layer 062 - Total Energy (excluding 'Total' line): 11838.73 fJ/Compute
#
# mac                                 : 665.77 fJ (5.62%)
# output_activation_reg               : 80.11 fJ (0.68%)
# input_activation_reg                : 106.82 fJ (0.90%)
# weight_reg                          : 106.82 fJ (0.90%)
# pe_spad                             : 193.19 fJ (1.63%)
# shared_glb                          : 186.02 fJ (1.57%)
# DRAM                                : 10500.00 fJ (88.69%)
#
# Layer 063 - Total Energy (excluding 'Total' line): 12096.26 fJ/Compute
#
# mac                                 : 665.77 fJ (5.50%)
# output_activation_reg               : 105.99 fJ (0.88%)
# input_activation_reg                : 106.82 fJ (0.88%)
# weight_reg                          : 106.82 fJ (0.88%)
# pe_spad                             : 193.19 fJ (1.60%)
# shared_glb                          : 417.67 fJ (3.45%)
# DRAM                                : 10500.00 fJ (86.80%)
#
# Layer 064 - Total Energy (excluding 'Total' line): 5850.62 fJ/Compute
#
# mac                                 : 665.77 fJ (11.38%)
# output_activation_reg               : 106.40 fJ (1.82%)
# input_activation_reg                : 106.82 fJ (1.83%)
# weight_reg                          : 106.82 fJ (1.83%)
# pe_spad                             : 178.69 fJ (3.05%)
# shared_glb                          : 61.12 fJ (1.04%)
# DRAM                                : 4625.00 fJ (79.05%)
#
# Layer 065 - Total Energy (excluding 'Total' line): 3218.54 fJ/Compute
#
# mac                                 : 665.77 fJ (20.69%)
# output_activation_reg               : 106.61 fJ (3.31%)
# input_activation_reg                : 106.82 fJ (3.32%)
# weight_reg                          : 106.82 fJ (3.32%)
# pe_spad                             : 26.77 fJ (0.83%)
# shared_glb                          : 674.50 fJ (20.96%)
# DRAM                                : 1531.25 fJ (47.58%)
#
# Layer 066 - Total Energy (excluding 'Total' line): 3666.39 fJ/Compute
#
# mac                                 : 665.77 fJ (18.16%)
# output_activation_reg               : 105.99 fJ (2.89%)
# input_activation_reg                : 106.82 fJ (2.91%)
# weight_reg                          : 106.82 fJ (2.91%)
# pe_spad                             : 4.86 fJ (0.13%)
# shared_glb                          : 551.13 fJ (15.03%)
# DRAM                                : 2125.00 fJ (57.96%)
#
# Layer 067 - Total Energy (excluding 'Total' line): 4088.49 fJ/Compute
#
# mac                                 : 665.77 fJ (16.28%)
# output_activation_reg               : 105.15 fJ (2.57%)
# input_activation_reg                : 106.82 fJ (2.61%)
# weight_reg                          : 106.82 fJ (2.61%)
# pe_spad                             : 12.22 fJ (0.30%)
# shared_glb                          : 466.71 fJ (11.42%)
# DRAM                                : 2625.00 fJ (64.20%)
#
# Layer 068 - Total Energy (excluding 'Total' line): 11838.73 fJ/Compute
#
# mac                                 : 665.77 fJ (5.62%)
# output_activation_reg               : 80.11 fJ (0.68%)
# input_activation_reg                : 106.82 fJ (0.90%)
# weight_reg                          : 106.82 fJ (0.90%)
# pe_spad                             : 193.19 fJ (1.63%)
# shared_glb                          : 186.02 fJ (1.57%)
# DRAM                                : 10500.00 fJ (88.69%)
#
# Layer 069 - Total Energy (excluding 'Total' line): 12096.26 fJ/Compute
#
# mac                                 : 665.77 fJ (5.50%)
# output_activation_reg               : 105.99 fJ (0.88%)
# input_activation_reg                : 106.82 fJ (0.88%)
# weight_reg                          : 106.82 fJ (0.88%)
# pe_spad                             : 193.19 fJ (1.60%)
# shared_glb                          : 417.67 fJ (3.45%)
# DRAM                                : 10500.00 fJ (86.80%)
#
# Layer 070 - Total Energy (excluding 'Total' line): 5850.62 fJ/Compute
#
# mac                                 : 665.77 fJ (11.38%)
# output_activation_reg               : 106.40 fJ (1.82%)
# input_activation_reg                : 106.82 fJ (1.83%)
# weight_reg                          : 106.82 fJ (1.83%)
# pe_spad                             : 178.69 fJ (3.05%)
# shared_glb                          : 61.12 fJ (1.04%)
# DRAM                                : 4625.00 fJ (79.05%)
#
# Layer 071 - Total Energy (excluding 'Total' line): 3218.54 fJ/Compute
#
# mac                                 : 665.77 fJ (20.69%)
# output_activation_reg               : 106.61 fJ (3.31%)
# input_activation_reg                : 106.82 fJ (3.32%)
# weight_reg                          : 106.82 fJ (3.32%)
# pe_spad                             : 26.77 fJ (0.83%)
# shared_glb                          : 674.50 fJ (20.96%)
# DRAM                                : 1531.25 fJ (47.58%)
#
# Layer 072 - Total Energy (excluding 'Total' line): 3666.39 fJ/Compute
#
# mac                                 : 665.77 fJ (18.16%)
# output_activation_reg               : 105.99 fJ (2.89%)
# input_activation_reg                : 106.82 fJ (2.91%)
# weight_reg                          : 106.82 fJ (2.91%)
# pe_spad                             : 4.86 fJ (0.13%)
# shared_glb                          : 551.13 fJ (15.03%)
# DRAM                                : 2125.00 fJ (57.96%)
#
# Layer 073 - Total Energy (excluding 'Total' line): 4088.49 fJ/Compute
#
# mac                                 : 665.77 fJ (16.28%)
# output_activation_reg               : 105.15 fJ (2.57%)
# input_activation_reg                : 106.82 fJ (2.61%)
# weight_reg                          : 106.82 fJ (2.61%)
# pe_spad                             : 12.22 fJ (0.30%)
# shared_glb                          : 466.71 fJ (11.42%)
# DRAM                                : 2625.00 fJ (64.20%)
#
# Layer 074 - Total Energy (excluding 'Total' line): 11838.73 fJ/Compute
#
# mac                                 : 665.77 fJ (5.62%)
# output_activation_reg               : 80.11 fJ (0.68%)
# input_activation_reg                : 106.82 fJ (0.90%)
# weight_reg                          : 106.82 fJ (0.90%)
# pe_spad                             : 193.19 fJ (1.63%)
# shared_glb                          : 186.02 fJ (1.57%)
# DRAM                                : 10500.00 fJ (88.69%)
#
# Layer 075 - Total Energy (excluding 'Total' line): 12096.26 fJ/Compute
#
# mac                                 : 665.77 fJ (5.50%)
# output_activation_reg               : 105.99 fJ (0.88%)
# input_activation_reg                : 106.82 fJ (0.88%)
# weight_reg                          : 106.82 fJ (0.88%)
# pe_spad                             : 193.19 fJ (1.60%)
# shared_glb                          : 417.67 fJ (3.45%)
# DRAM                                : 10500.00 fJ (86.80%)
#
# Layer 076 - Total Energy (excluding 'Total' line): 5850.62 fJ/Compute
#
# mac                                 : 665.77 fJ (11.38%)
# output_activation_reg               : 106.40 fJ (1.82%)
# input_activation_reg                : 106.82 fJ (1.83%)
# weight_reg                          : 106.82 fJ (1.83%)
# pe_spad                             : 178.69 fJ (3.05%)
# shared_glb                          : 61.12 fJ (1.04%)
# DRAM                                : 4625.00 fJ (79.05%)
#
# Layer 077 - Total Energy (excluding 'Total' line): 3218.54 fJ/Compute
#
# mac                                 : 665.77 fJ (20.69%)
# output_activation_reg               : 106.61 fJ (3.31%)
# input_activation_reg                : 106.82 fJ (3.32%)
# weight_reg                          : 106.82 fJ (3.32%)
# pe_spad                             : 26.77 fJ (0.83%)
# shared_glb                          : 674.50 fJ (20.96%)
# DRAM                                : 1531.25 fJ (47.58%)
#
# Layer 078 - Total Energy (excluding 'Total' line): 3666.39 fJ/Compute
#
# mac                                 : 665.77 fJ (18.16%)
# output_activation_reg               : 105.99 fJ (2.89%)
# input_activation_reg                : 106.82 fJ (2.91%)
# weight_reg                          : 106.82 fJ (2.91%)
# pe_spad                             : 4.86 fJ (0.13%)
# shared_glb                          : 551.13 fJ (15.03%)
# DRAM                                : 2125.00 fJ (57.96%)
#
# Layer 079 - Total Energy (excluding 'Total' line): 4088.49 fJ/Compute
#
# mac                                 : 665.77 fJ (16.28%)
# output_activation_reg               : 105.15 fJ (2.57%)
# input_activation_reg                : 106.82 fJ (2.61%)
# weight_reg                          : 106.82 fJ (2.61%)
# pe_spad                             : 12.22 fJ (0.30%)
# shared_glb                          : 466.71 fJ (11.42%)
# DRAM                                : 2625.00 fJ (64.20%)
#
# Layer 080 - Total Energy (excluding 'Total' line): 11838.73 fJ/Compute
#
# mac                                 : 665.77 fJ (5.62%)
# output_activation_reg               : 80.11 fJ (0.68%)
# input_activation_reg                : 106.82 fJ (0.90%)
# weight_reg                          : 106.82 fJ (0.90%)
# pe_spad                             : 193.19 fJ (1.63%)
# shared_glb                          : 186.02 fJ (1.57%)
# DRAM                                : 10500.00 fJ (88.69%)
#
# Layer 081 - Total Energy (excluding 'Total' line): 12096.26 fJ/Compute
#
# mac                                 : 665.77 fJ (5.50%)
# output_activation_reg               : 105.99 fJ (0.88%)
# input_activation_reg                : 106.82 fJ (0.88%)
# weight_reg                          : 106.82 fJ (0.88%)
# pe_spad                             : 193.19 fJ (1.60%)
# shared_glb                          : 417.67 fJ (3.45%)
# DRAM                                : 10500.00 fJ (86.80%)
#
# Layer 082 - Total Energy (excluding 'Total' line): 5850.62 fJ/Compute
#
# mac                                 : 665.77 fJ (11.38%)
# output_activation_reg               : 106.40 fJ (1.82%)
# input_activation_reg                : 106.82 fJ (1.83%)
# weight_reg                          : 106.82 fJ (1.83%)
# pe_spad                             : 178.69 fJ (3.05%)
# shared_glb                          : 61.12 fJ (1.04%)
# DRAM                                : 4625.00 fJ (79.05%)
#
# Layer 083 - Total Energy (excluding 'Total' line): 3218.54 fJ/Compute
#
# mac                                 : 665.77 fJ (20.69%)
# output_activation_reg               : 106.61 fJ (3.31%)
# input_activation_reg                : 106.82 fJ (3.32%)
# weight_reg                          : 106.82 fJ (3.32%)
# pe_spad                             : 26.77 fJ (0.83%)
# shared_glb                          : 674.50 fJ (20.96%)
# DRAM                                : 1531.25 fJ (47.58%)
#
# Layer 084 - Total Energy (excluding 'Total' line): 3666.39 fJ/Compute
#
# mac                                 : 665.77 fJ (18.16%)
# output_activation_reg               : 105.99 fJ (2.89%)
# input_activation_reg                : 106.82 fJ (2.91%)
# weight_reg                          : 106.82 fJ (2.91%)
# pe_spad                             : 4.86 fJ (0.13%)
# shared_glb                          : 551.13 fJ (15.03%)
# DRAM                                : 2125.00 fJ (57.96%)
#
# Layer 085 - Total Energy (excluding 'Total' line): 4088.49 fJ/Compute
#
# mac                                 : 665.77 fJ (16.28%)
# output_activation_reg               : 105.15 fJ (2.57%)
# input_activation_reg                : 106.82 fJ (2.61%)
# weight_reg                          : 106.82 fJ (2.61%)
# pe_spad                             : 12.22 fJ (0.30%)
# shared_glb                          : 466.71 fJ (11.42%)
# DRAM                                : 2625.00 fJ (64.20%)
#
# Layer 086 - Total Energy (excluding 'Total' line): 11838.73 fJ/Compute
#
# mac                                 : 665.77 fJ (5.62%)
# output_activation_reg               : 80.11 fJ (0.68%)
# input_activation_reg                : 106.82 fJ (0.90%)
# weight_reg                          : 106.82 fJ (0.90%)
# pe_spad                             : 193.19 fJ (1.63%)
# shared_glb                          : 186.02 fJ (1.57%)
# DRAM                                : 10500.00 fJ (88.69%)
#
# Layer 087 - Total Energy (excluding 'Total' line): 12096.26 fJ/Compute
#
# mac                                 : 665.77 fJ (5.50%)
# output_activation_reg               : 105.99 fJ (0.88%)
# input_activation_reg                : 106.82 fJ (0.88%)
# weight_reg                          : 106.82 fJ (0.88%)
# pe_spad                             : 193.19 fJ (1.60%)
# shared_glb                          : 417.67 fJ (3.45%)
# DRAM                                : 10500.00 fJ (86.80%)
#
# Layer 088 - Total Energy (excluding 'Total' line): 5850.62 fJ/Compute
#
# mac                                 : 665.77 fJ (11.38%)
# output_activation_reg               : 106.40 fJ (1.82%)
# input_activation_reg                : 106.82 fJ (1.83%)
# weight_reg                          : 106.82 fJ (1.83%)
# pe_spad                             : 178.69 fJ (3.05%)
# shared_glb                          : 61.12 fJ (1.04%)
# DRAM                                : 4625.00 fJ (79.05%)
#
# Layer 089 - Total Energy (excluding 'Total' line): 3218.54 fJ/Compute
#
# mac                                 : 665.77 fJ (20.69%)
# output_activation_reg               : 106.61 fJ (3.31%)
# input_activation_reg                : 106.82 fJ (3.32%)
# weight_reg                          : 106.82 fJ (3.32%)
# pe_spad                             : 26.77 fJ (0.83%)
# shared_glb                          : 674.50 fJ (20.96%)
# DRAM                                : 1531.25 fJ (47.58%)
#
# Layer 090 - Total Energy (excluding 'Total' line): 3666.39 fJ/Compute
#
# mac                                 : 665.77 fJ (18.16%)
# output_activation_reg               : 105.99 fJ (2.89%)
# input_activation_reg                : 106.82 fJ (2.91%)
# weight_reg                          : 106.82 fJ (2.91%)
# pe_spad                             : 4.86 fJ (0.13%)
# shared_glb                          : 551.13 fJ (15.03%)
# DRAM                                : 2125.00 fJ (57.96%)
#
# Layer 091 - Total Energy (excluding 'Total' line): 4088.49 fJ/Compute
#
# mac                                 : 665.77 fJ (16.28%)
# output_activation_reg               : 105.15 fJ (2.57%)
# input_activation_reg                : 106.82 fJ (2.61%)
# weight_reg                          : 106.82 fJ (2.61%)
# pe_spad                             : 12.22 fJ (0.30%)
# shared_glb                          : 466.71 fJ (11.42%)
# DRAM                                : 2625.00 fJ (64.20%)
#
# Layer 092 - Total Energy (excluding 'Total' line): 11838.73 fJ/Compute
#
# mac                                 : 665.77 fJ (5.62%)
# output_activation_reg               : 80.11 fJ (0.68%)
# input_activation_reg                : 106.82 fJ (0.90%)
# weight_reg                          : 106.82 fJ (0.90%)
# pe_spad                             : 193.19 fJ (1.63%)
# shared_glb                          : 186.02 fJ (1.57%)
# DRAM                                : 10500.00 fJ (88.69%)
#
# Layer 093 - Total Energy (excluding 'Total' line): 12096.26 fJ/Compute
#
# mac                                 : 665.77 fJ (5.50%)
# output_activation_reg               : 105.99 fJ (0.88%)
# input_activation_reg                : 106.82 fJ (0.88%)
# weight_reg                          : 106.82 fJ (0.88%)
# pe_spad                             : 193.19 fJ (1.60%)
# shared_glb                          : 417.67 fJ (3.45%)
# DRAM                                : 10500.00 fJ (86.80%)
#
# Layer 094 - Total Energy (excluding 'Total' line): 5850.62 fJ/Compute
#
# mac                                 : 665.77 fJ (11.38%)
# output_activation_reg               : 106.40 fJ (1.82%)
# input_activation_reg                : 106.82 fJ (1.83%)
# weight_reg                          : 106.82 fJ (1.83%)
# pe_spad                             : 178.69 fJ (3.05%)
# shared_glb                          : 61.12 fJ (1.04%)
# DRAM                                : 4625.00 fJ (79.05%)
#
# Layer 095 - Total Energy (excluding 'Total' line): 3218.54 fJ/Compute
#
# mac                                 : 665.77 fJ (20.69%)
# output_activation_reg               : 106.61 fJ (3.31%)
# input_activation_reg                : 106.82 fJ (3.32%)
# weight_reg                          : 106.82 fJ (3.32%)
# pe_spad                             : 26.77 fJ (0.83%)
# shared_glb                          : 674.50 fJ (20.96%)
# DRAM                                : 1531.25 fJ (47.58%)
#
# Layer 096 - Total Energy (excluding 'Total' line): 3666.39 fJ/Compute
#
# mac                                 : 665.77 fJ (18.16%)
# output_activation_reg               : 105.99 fJ (2.89%)
# input_activation_reg                : 106.82 fJ (2.91%)
# weight_reg                          : 106.82 fJ (2.91%)
# pe_spad                             : 4.86 fJ (0.13%)
# shared_glb                          : 551.13 fJ (15.03%)
# DRAM                                : 2125.00 fJ (57.96%)
#
# Layer 097 - Total Energy (excluding 'Total' line): 4088.49 fJ/Compute
#
# mac                                 : 665.77 fJ (16.28%)
# output_activation_reg               : 105.15 fJ (2.57%)
# input_activation_reg                : 106.82 fJ (2.61%)
# weight_reg                          : 106.82 fJ (2.61%)
# pe_spad                             : 12.22 fJ (0.30%)
# shared_glb                          : 466.71 fJ (11.42%)
# DRAM                                : 2625.00 fJ (64.20%)
#
# Layer 098 - Total Energy (excluding 'Total' line): 11838.73 fJ/Compute
#
# mac                                 : 665.77 fJ (5.62%)
# output_activation_reg               : 80.11 fJ (0.68%)
# input_activation_reg                : 106.82 fJ (0.90%)
# weight_reg                          : 106.82 fJ (0.90%)
# pe_spad                             : 193.19 fJ (1.63%)
# shared_glb                          : 186.02 fJ (1.57%)
# DRAM                                : 10500.00 fJ (88.69%)
#
# Layer 099 - Total Energy (excluding 'Total' line): 12096.26 fJ/Compute
#
# mac                                 : 665.77 fJ (5.50%)
# output_activation_reg               : 105.99 fJ (0.88%)
# input_activation_reg                : 106.82 fJ (0.88%)
# weight_reg                          : 106.82 fJ (0.88%)
# pe_spad                             : 193.19 fJ (1.60%)
# shared_glb                          : 417.67 fJ (3.45%)
# DRAM                                : 10500.00 fJ (86.80%)
#
# Layer 100 - Total Energy (excluding 'Total' line): 5850.62 fJ/Compute
#
# mac                                 : 665.77 fJ (11.38%)
# output_activation_reg               : 106.40 fJ (1.82%)
# input_activation_reg                : 106.82 fJ (1.83%)
# weight_reg                          : 106.82 fJ (1.83%)
# pe_spad                             : 178.69 fJ (3.05%)
# shared_glb                          : 61.12 fJ (1.04%)
# DRAM                                : 4625.00 fJ (79.05%)
#
# Layer 101 - Total Energy (excluding 'Total' line): 3218.54 fJ/Compute
#
# mac                                 : 665.77 fJ (20.69%)
# output_activation_reg               : 106.61 fJ (3.31%)
# input_activation_reg                : 106.82 fJ (3.32%)
# weight_reg                          : 106.82 fJ (3.32%)
# pe_spad                             : 26.77 fJ (0.83%)
# shared_glb                          : 674.50 fJ (20.96%)
# DRAM                                : 1531.25 fJ (47.58%)
#
# Layer 102 - Total Energy (excluding 'Total' line): 3666.39 fJ/Compute
#
# mac                                 : 665.77 fJ (18.16%)
# output_activation_reg               : 105.99 fJ (2.89%)
# input_activation_reg                : 106.82 fJ (2.91%)
# weight_reg                          : 106.82 fJ (2.91%)
# pe_spad                             : 4.86 fJ (0.13%)
# ...
#     "weight_reg": 1.8257894035162086,
#     "pe_spad": 3.0542062208791547,
#     "shared_glb": 1.0446756070296823,
#     "DRAM": 79.05145095733444
#   },
#   "089": {
#     "mac": 20.68546608089382,
#     "output_activation_reg": 3.3123714479235926,
#     "input_activation_reg": 3.318896145457257,
#     "weight_reg": 3.318896145457257,
#     "pe_spad": 0.8317435856009245,
#     "shared_glb": 20.956707078364726,
#     "DRAM": 47.57591951630242
#   },
#   "090": {
#     "mac": 18.158733795368196,
#     "output_activation_reg": 2.890854491748014,
#     "input_activation_reg": 2.9134925635297937,
#     "weight_reg": 2.9134925635297937,
#     "pe_spad": 0.13255545645716904,
#     "shared_glb": 15.031952410954647,
#     "DRAM": 57.95891871841239
#   },
#   "091": {
#     "mac": 16.28400705394901,
#     "output_activation_reg": 2.571854156424499,
#     "input_activation_reg": 2.612700532470423,
#     "weight_reg": 2.612700532470423,
#     "pe_spad": 0.29888785346179153,
#     "shared_glb": 11.415216864906116,
#     "DRAM": 64.20463300631774
#   },
#   "092": {
#     "mac": 5.623660646032134,
#     "output_activation_reg": 0.676677312515785,
#     "input_activation_reg": 0.9022927290342798,
#     "weight_reg": 0.9022927290342798,
#     "pe_spad": 1.6318473349759646,
#     "shared_glb": 1.5712834062437442,
#     "DRAM": 88.69194584216382
#   },
#   "093": {
#     "mac": 5.503932620495922,
#     "output_activation_reg": 0.8762212452443978,
#     "input_activation_reg": 0.8830828702425377,
#     "weight_reg": 0.8830828702425377,
#     "pe_spad": 1.597105220952592,
#     "shared_glb": 3.452885437316989,
#     "DRAM": 86.80368973550502
#   },
#   "094": {
#     "mac": 11.379477730565307,
#     "output_activation_reg": 1.8186106771590023,
#     "input_activation_reg": 1.8257894035162086,
#     "weight_reg": 1.8257894035162086,
#     "pe_spad": 3.0542062208791547,
#     "shared_glb": 1.0446756070296823,
#     "DRAM": 79.05145095733444
#   },
#   "095": {
#     "mac": 20.68546608089382,
#     "output_activation_reg": 3.3123714479235926,
#     "input_activation_reg": 3.318896145457257,
#     "weight_reg": 3.318896145457257,
#     "pe_spad": 0.8317435856009245,
#     "shared_glb": 20.956707078364726,
#     "DRAM": 47.57591951630242
#   },
#   "096": {
#     "mac": 18.158733795368196,
#     "output_activation_reg": 2.890854491748014,
#     "input_activation_reg": 2.9134925635297937,
#     "weight_reg": 2.9134925635297937,
#     "pe_spad": 0.13255545645716904,
#     "shared_glb": 15.031952410954647,
#     "DRAM": 57.95891871841239
#   },
#   "097": {
#     "mac": 16.28400705394901,
#     "output_activation_reg": 2.571854156424499,
#     "input_activation_reg": 2.612700532470423,
#     "weight_reg": 2.612700532470423,
#     "pe_spad": 0.29888785346179153,
#     "shared_glb": 11.415216864906116,
#     "DRAM": 64.20463300631774
#   },
#   "098": {
#     "mac": 5.623660646032134,
#     "output_activation_reg": 0.676677312515785,
#     "input_activation_reg": 0.9022927290342798,
#     "weight_reg": 0.9022927290342798,
#     "pe_spad": 1.6318473349759646,
#     "shared_glb": 1.5712834062437442,
#     "DRAM": 88.69194584216382
#   },
#   "099": {
#     "mac": 5.503932620495922,
#     "output_activation_reg": 0.8762212452443978,
#     "input_activation_reg": 0.8830828702425377,
#     "weight_reg": 0.8830828702425377,
#     "pe_spad": 1.597105220952592,
#     "shared_glb": 3.452885437316989,
#     "DRAM": 86.80368973550502
#   },
#   "100": {
#     "mac": 11.379477730565307,
#     "output_activation_reg": 1.8186106771590023,
#     "input_activation_reg": 1.8257894035162086,
#     "weight_reg": 1.8257894035162086,
#     "pe_spad": 3.0542062208791547,
#     "shared_glb": 1.0446756070296823,
#     "DRAM": 79.05145095733444
#   },
#   "101": {
#     "mac": 20.68546608089382,
#     "output_activation_reg": 3.3123714479235926,
#     "input_activation_reg": 3.318896145457257,
#     "weight_reg": 3.318896145457257,
#     "pe_spad": 0.8317435856009245,
#     "shared_glb": 20.956707078364726,
#     "DRAM": 47.57591951630242
#   },
#   "102": {
#     "mac": 18.158733795368196,
#     "output_activation_reg": 2.890854491748014,
#     "input_activation_reg": 2.9134925635297937,
#     "weight_reg": 2.9134925635297937,
#     "pe_spad": 0.13255545645716904,
#     "shared_glb": 15.031952410954647,
#     "DRAM": 57.95891871841239
#   },
#   "103": {
#     "mac": 16.28400705394901,
#     "output_activation_reg": 2.571854156424499,
#     "input_activation_reg": 2.612700532470423,
#     "weight_reg": 2.612700532470423,
#     "pe_spad": 0.29888785346179153,
#     "shared_glb": 11.415216864906116,
#     "DRAM": 64.20463300631774
#   },
#   "104": {
#     "mac": 5.623660646032134,
#     "output_activation_reg": 0.676677312515785,
#     "input_activation_reg": 0.9022927290342798,
#     "weight_reg": 0.9022927290342798,
#     "pe_spad": 1.6318473349759646,
#     "shared_glb": 1.5712834062437442,
#     "DRAM": 88.69194584216382
#   },
#   "105": {
#     "mac": 5.503932620495922,
#     "output_activation_reg": 0.8762212452443978,
#     "input_activation_reg": 0.8830828702425377,
#     "weight_reg": 0.8830828702425377,
#     "pe_spad": 1.597105220952592,
#     "shared_glb": 3.452885437316989,
#     "DRAM": 86.80368973550502
#   },
#   "106": {
#     "mac": 11.379477730565307,
#     "output_activation_reg": 1.8186106771590023,
#     "input_activation_reg": 1.8257894035162086,
#     "weight_reg": 1.8257894035162086,
#     "pe_spad": 3.0542062208791547,
#     "shared_glb": 1.0446756070296823,
#     "DRAM": 79.05145095733444
#   },
#   "107": {
#     "mac": 20.68546608089382,
#     "output_activation_reg": 3.3123714479235926,
#     "input_activation_reg": 3.318896145457257,
#     "weight_reg": 3.318896145457257,
#     "pe_spad": 0.8317435856009245,
#     "shared_glb": 20.956707078364726,
#     "DRAM": 47.57591951630242
#   },
#   "108": {
#     "mac": 18.158733795368196,
#     "output_activation_reg": 2.890854491748014,
#     "input_activation_reg": 2.9134925635297937,
#     "weight_reg": 2.9134925635297937,
#     "pe_spad": 0.13255545645716904,
#     "shared_glb": 15.031952410954647,
#     "DRAM": 57.95891871841239
#   },
#   "109": {
#     "mac": 16.28400705394901,
#     "output_activation_reg": 2.571854156424499,
#     "input_activation_reg": 2.612700532470423,
#     "weight_reg": 2.612700532470423,
#     "pe_spad": 0.29888785346179153,
#     "shared_glb": 11.415216864906116,
#     "DRAM": 64.20463300631774
#   },
#   "110": {
#     "mac": 5.623660646032134,
#     "output_activation_reg": 0.676677312515785,
#     "input_activation_reg": 0.9022927290342798,
#     "weight_reg": 0.9022927290342798,
#     "pe_spad": 1.6318473349759646,
#     "shared_glb": 1.5712834062437442,
#     "DRAM": 88.69194584216382
#   },
#   "111": {
#     "mac": 5.503932620495922,
#     "output_activation_reg": 0.8762212452443978,
#     "input_activation_reg": 0.8830828702425377,
#     "weight_reg": 0.8830828702425377,
#     "pe_spad": 1.597105220952592,
#     "shared_glb": 3.452885437316989,
#     "DRAM": 86.80368973550502
#   },
#   "112": {
#     "mac": 11.379477730565307,
#     "output_activation_reg": 1.8186106771590023,
#     "input_activation_reg": 1.8257894035162086,
#     "weight_reg": 1.8257894035162086,
#     "pe_spad": 3.0542062208791547,
#     "shared_glb": 1.0446756070296823,
#     "DRAM": 79.05145095733444
#   },
#   "113": {
#     "mac": 20.68546608089382,
#     "output_activation_reg": 3.3123714479235926,
#     "input_activation_reg": 3.318896145457257,
#     "weight_reg": 3.318896145457257,
#     "pe_spad": 0.8317435856009245,
#     "shared_glb": 20.956707078364726,
#     "DRAM": 47.57591951630242
#   },
#   "114": {
#     "mac": 18.158733795368196,
#     "output_activation_reg": 2.890854491748014,
#     "input_activation_reg": 2.9134925635297937,
#     "weight_reg": 2.9134925635297937,
#     "pe_spad": 0.13255545645716904,
#     "shared_glb": 15.031952410954647,
#     "DRAM": 57.95891871841239
#   },
#   "115": {
#     "mac": 16.28400705394901,
#     "output_activation_reg": 2.571854156424499,
#     "input_activation_reg": 2.612700532470423,
#     "weight_reg": 2.612700532470423,
#     "pe_spad": 0.29888785346179153,
#     "shared_glb": 11.415216864906116,
#     "DRAM": 64.20463300631774
#   },
#   "116": {
#     "mac": 5.623660646032134,
#     "output_activation_reg": 0.676677312515785,
#     "input_activation_reg": 0.9022927290342798,
#     "weight_reg": 0.9022927290342798,
#     "pe_spad": 1.6318473349759646,
#     "shared_glb": 1.5712834062437442,
#     "DRAM": 88.69194584216382
#   },
#   "117": {
#     "mac": 5.503932620495922,
#     "output_activation_reg": 0.8762212452443978,
#     "input_activation_reg": 0.8830828702425377,
#     "weight_reg": 0.8830828702425377,
#     "pe_spad": 1.597105220952592,
#     "shared_glb": 3.452885437316989,
#     "DRAM": 86.80368973550502
#   },
#   "118": {
#     "mac": 11.379477730565307,
#     "output_activation_reg": 1.8186106771590023,
#     "input_activation_reg": 1.8257894035162086,
#     "weight_reg": 1.8257894035162086,
#     "pe_spad": 3.0542062208791547,
#     "shared_glb": 1.0446756070296823,
#     "DRAM": 79.05145095733444
#   },
#   "119": {
#     "mac": 20.68546608089382,
#     "output_activation_reg": 3.3123714479235926,
#     "input_activation_reg": 3.318896145457257,
#     "weight_reg": 3.318896145457257,
#     "pe_spad": 0.8317435856009245,
#     "shared_glb": 20.956707078364726,
#     "DRAM": 47.57591951630242
#   },
#   "120": {
#     "mac": 18.158733795368196,
#     "output_activation_reg": 2.890854491748014,
#     "input_activation_reg": 2.9134925635297937,
#     "weight_reg": 2.9134925635297937,
#     "pe_spad": 0.13255545645716904,
#     "shared_glb": 15.031952410954647,
#     "DRAM": 57.95891871841239
#   },
#   "121": {
#     "mac": 16.28400705394901,
#     "output_activation_reg": 2.571854156424499,
#     "input_activation_reg": 2.612700532470423,
#     "weight_reg": 2.612700532470423,
#     "pe_spad": 0.29888785346179153,
#     "shared_glb": 11.415216864906116,
#     "DRAM": 64.20463300631774
#   },
#   "122": {
#     "mac": 5.623660646032134,
#     "output_activation_reg": 0.676677312515785,
#     "input_activation_reg": 0.9022927290342798,
#     "weight_reg": 0.9022927290342798,
#     "pe_spad": 1.6318473349759646,
#     "shared_glb": 1.5712834062437442,
#     "DRAM": 88.69194584216382
#   },
#   "123": {
#     "mac": 5.503932620495922,
#     "output_activation_reg": 0.8762212452443978,
#     "input_activation_reg": 0.8830828702425377,
#     "weight_reg": 0.8830828702425377,
#     "pe_spad": 1.597105220952592,
#     "shared_glb": 3.452885437316989,
#     "DRAM": 86.80368973550502
#   },
#   "124": {
#     "mac": 11.379477730565307,
#     "output_activation_reg": 1.8186106771590023,
#     "input_activation_reg": 1.8257894035162086,
#     "weight_reg": 1.8257894035162086,
#     "pe_spad": 3.0542062208791547,
#     "shared_glb": 1.0446756070296823,
#     "DRAM": 79.05145095733444
#   },
#   "125": {
#     "mac": 20.68546608089382,
#     "output_activation_reg": 3.3123714479235926,
#     "input_activation_reg": 3.318896145457257,
#     "weight_reg": 3.318896145457257,
#     "pe_spad": 0.8317435856009245,
#     "shared_glb": 20.956707078364726,
#     "DRAM": 47.57591951630242
#   },
#   "126": {
#     "mac": 18.158733795368196,
#     "output_activation_reg": 2.890854491748014,
#     "input_activation_reg": 2.9134925635297937,
#     "weight_reg": 2.9134925635297937,
#     "pe_spad": 0.13255545645716904,
#     "shared_glb": 15.031952410954647,
#     "DRAM": 57.95891871841239
#   },
#   "127": {
#     "mac": 16.28400705394901,
#     "output_activation_reg": 2.571854156424499,
#     "input_activation_reg": 2.612700532470423,
#     "weight_reg": 2.612700532470423,
#     "pe_spad": 0.29888785346179153,
#     "shared_glb": 11.415216864906116,
#     "DRAM": 64.20463300631774
#   },
#   "128": {
#     "mac": 5.623660646032134,
#     "output_activation_reg": 0.676677312515785,
#     "input_activation_reg": 0.9022927290342798,
#     "weight_reg": 0.9022927290342798,
#     "pe_spad": 1.6318473349759646,
#     "shared_glb": 1.5712834062437442,
#     "DRAM": 88.69194584216382
#   },
#   "129": {
#     "mac": 5.503932620495922,
#     "output_activation_reg": 0.8762212452443978,
#     "input_activation_reg": 0.8830828702425377,
#     "weight_reg": 0.8830828702425377,
#     "pe_spad": 1.597105220952592,
#     "shared_glb": 3.452885437316989,
#     "DRAM": 86.80368973550502
#   },
#   "130": {
#     "mac": 11.379477730565307,
#     "output_activation_reg": 1.8186106771590023,
#     "input_activation_reg": 1.8257894035162086,
#     "weight_reg": 1.8257894035162086,
#     "pe_spad": 3.0542062208791547,
#     "shared_glb": 1.0446756070296823,
#     "DRAM": 79.05145095733444
#   },
#   "131": {
#     "mac": 20.68546608089382,
#     "output_activation_reg": 3.3123714479235926,
#     "input_activation_reg": 3.318896145457257,
#     "weight_reg": 3.318896145457257,
#     "pe_spad": 0.8317435856009245,
#     "shared_glb": 20.956707078364726,
#     "DRAM": 47.57591951630242
#   },
#   "132": {
#     "mac": 18.158733795368196,
#     "output_activation_reg": 2.890854491748014,
#     "input_activation_reg": 2.9134925635297937,
#     "weight_reg": 2.9134925635297937,
#     "pe_spad": 0.13255545645716904,
#     "shared_glb": 15.031952410954647,
#     "DRAM": 57.95891871841239
#   },
#   "133": {
#     "mac": 16.28400705394901,
#     "output_activation_reg": 2.571854156424499,
#     "input_activation_reg": 2.612700532470423,
#     "weight_reg": 2.612700532470423,
#     "pe_spad": 0.29888785346179153,
#     "shared_glb": 11.415216864906116,
#     "DRAM": 64.20463300631774
#   },
#   "134": {
#     "mac": 5.623660646032134,
#     "output_activation_reg": 0.676677312515785,
#     "input_activation_reg": 0.9022927290342798,
#     "weight_reg": 0.9022927290342798,
#     "pe_spad": 1.6318473349759646,
#     "shared_glb": 1.5712834062437442,
#     "DRAM": 88.69194584216382
#   },
#   "135": {
#     "mac": 5.503932620495922,
#     "output_activation_reg": 0.8762212452443978,
#     "input_activation_reg": 0.8830828702425377,
#     "weight_reg": 0.8830828702425377,
#     "pe_spad": 1.597105220952592,
#     "shared_glb": 3.452885437316989,
#     "DRAM": 86.80368973550502
#   },
#   "136": {
#     "mac": 11.379477730565307,
#     "output_activation_reg": 1.8186106771590023,
#     "input_activation_reg": 1.8257894035162086,
#     "weight_reg": 1.8257894035162086,
#     "pe_spad": 3.0542062208791547,
#     "shared_glb": 1.0446756070296823,
#     "DRAM": 79.05145095733444
#   },
#   "137": {
#     "mac": 20.68546608089382,
#     "output_activation_reg": 3.3123714479235926,
#     "input_activation_reg": 3.318896145457257,
#     "weight_reg": 3.318896145457257,
#     "pe_spad": 0.8317435856009245,
#     "shared_glb": 20.956707078364726,
#     "DRAM": 47.57591951630242
#   },
#   "138": {
#     "mac": 18.158733795368196,
#     "output_activation_reg": 2.890854491748014,
#     "input_activation_reg": 2.9134925635297937,
#     "weight_reg": 2.9134925635297937,
#     "pe_spad": 0.13255545645716904,
#     "shared_glb": 15.031952410954647,
#     "DRAM": 57.95891871841239
#   },
#   "139": {
#     "mac": 16.28400705394901,
#     "output_activation_reg": 2.571854156424499,
#     "input_activation_reg": 2.612700532470423,
#     "weight_reg": 2.612700532470423,
#     "pe_spad": 0.29888785346179153,
#     "shared_glb": 11.415216864906116,
#     "DRAM": 64.20463300631774
#   },
#   "140": {
#     "mac": 5.623660646032134,
#     "output_activation_reg": 0.676677312515785,
#     "input_activation_reg": 0.9022927290342798,
#     "weight_reg": 0.9022927290342798,
#     "pe_spad": 1.6318473349759646,
#     "shared_glb": 1.5712834062437442,
#     "DRAM": 88.69194584216382
#   },
#   "141": {
#     "mac": 5.503932620495922,
#     "output_activation_reg": 0.8762212452443978,
#     "input_activation_reg": 0.8830828702425377,
#     "weight_reg": 0.8830828702425377,
#     "pe_spad": 1.597105220952592,
#     "shared_glb": 3.452885437316989,
#     "DRAM": 86.80368973550502
#   },
#   "142": {
#     "mac": 11.379477730565307,
#     "output_activation_reg": 1.8186106771590023,
#     "input_activation_reg": 1.8257894035162086,
#     "weight_reg": 1.8257894035162086,
#     "pe_spad": 3.0542062208791547,
#     "shared_glb": 1.0446756070296823,
#     "DRAM": 79.05145095733444
#   },
#   "143": {
#     "mac": 20.68546608089382,
#     "output_activation_reg": 3.3123714479235926,
#     "input_activation_reg": 3.318896145457257,
#     "weight_reg": 3.318896145457257,
#     "pe_spad": 0.8317435856009245,
#     "shared_glb": 20.956707078364726,
#     "DRAM": 47.57591951630242
#   },
#   "144": {
#     "mac": 25.545719997390826,
#     "output_activation_reg": 4.0825879924334,
#     "input_activation_reg": 4.098703471350898,
#     "weight_reg": 4.098703471350898,
#     "pe_spad": 6.856368875638384,
#     "shared_glb": 2.461063851829682,
#     "DRAM": 52.85685234000591
#   }
# }

# %%
import os

def extract_outputs(model, arch):
    output_dir = os.path.join(".", arch, "outputs")
    print(f"Scanning in: {output_dir}")
    print("Model \t Folder \tEnergy (J) \tCycles")

    total_energy = 0.0
    total_cycles = 0.0
    total_area = 0.0

    layer_data = []  # For plotting

    for subfolder in sorted(os.listdir(output_dir)):
        sub_path = os.path.join(output_dir, subfolder)
        if not os.path.isdir(sub_path):
            continue

        stat_file = os.path.join(sub_path, "timeloop-mapper.stats.txt")
        art_file = os.path.join(sub_path, "timeloop-mapper.ART.yaml")

        folder_energy = 0.0
        folder_cycles = 0.0

        try:
            with open(stat_file, 'r') as f:
                for line in f:
                    if line.startswith("Energy:"):
                        folder_energy = float(line.split()[1])  # uJ
                    elif line.startswith("Cycles:"):
                        folder_cycles = float(line.split()[1])
        except FileNotFoundError:
            print(f"Warning: Missing {stat_file}")
            continue

        total_energy += folder_energy
        total_cycles += folder_cycles

        # Area only once
        if total_area == 0:
            try:
                with open(art_file, 'r') as f:
                    lines = f.readlines()
                    names = [l for l in lines if 'name' in l]
                    areas = [l for l in lines if 'area' in l]
                    for name_line, area_line in zip(names, areas):
                        count = float(name_line.split('..')[1].replace(']', '').strip())
                        area_per_unit = float(area_line.split(': ')[1].strip())
                        total_area += count * area_per_unit
            except FileNotFoundError:
                print(f"Warning: Missing {art_file}")

        print(f"{model} \t {subfolder} \t{folder_energy * 1e-6:.2e} \t{int(folder_cycles)}")

        # Save for plotting
        layer_data.append({
            "Layer": int(subfolder),
            "Energy (uJ)": folder_energy,
            "Cycles": folder_cycles
        })

    # Summary
    total_energy *= 1e-6
    total_area *= 1e-6
    throughput = 1 / (total_cycles * 1e-9) if total_cycles > 0 else 0

    print("\n=== Total Summary ===")
    print("Model \t\tEnergy/inference (J) \tArea (mm²) \tThroughput (inf/s)")
    print("{:s} \t{:.2e} \t\t{:.2f} \t\t{:.2e}".format(model, total_energy, total_area, throughput))

    return layer_data

# %%
import matplotlib.pyplot as plt
import pandas as pd

def plot_energy_and_cycles_per_layer(layer_data):
    df = pd.DataFrame(layer_data).sort_values("Layer")

    # Plot Energy
    plt.figure(figsize=(10, 5))
    plt.bar(df["Layer"], df["Energy (uJ)"], color='mediumseagreen')
    plt.title("Energy per Layer for gpt2")
    plt.xlabel("Layer")
    plt.ylabel("Energy (uJ)")
    plt.xticks(df["Layer"])
    plt.tight_layout()
    plt.show()

    # Plot Cycles
    plt.figure(figsize=(10, 5))
    plt.bar(df["Layer"], df["Cycles"], color='steelblue')
    plt.title("Cycles per Layer for gpt2")
    plt.xlabel("Layer")
    plt.ylabel("Cycles")
    plt.xticks(df["Layer"])
    plt.tight_layout()
    plt.show()

# %%
layer_data = extract_outputs("gpt2", "gpt2_128")
plot_energy_and_cycles_per_layer(layer_data)
# Out:
# Scanning in: ./gpt2_128/outputs
# Model 	 Folder 	Energy (J) 	Cycles
# gpt2 	 000 	2.95e-03 	9388032
# gpt2 	 001 	1.10e-03 	3129344
# gpt2 	 002 	3.10e-06 	2048
# gpt2 	 003 	1.27e-05 	8192
# gpt2 	 004 	6.28e-03 	8388608
# gpt2 	 005 	3.46e-03 	16760832
# gpt2 	 006 	2.95e-03 	9388032
# gpt2 	 007 	1.10e-03 	3129344
# gpt2 	 008 	3.10e-06 	2048
# gpt2 	 009 	1.27e-05 	8192
# gpt2 	 010 	6.28e-03 	8388608
# gpt2 	 011 	3.46e-03 	16760832
# gpt2 	 012 	2.95e-03 	9388032
# gpt2 	 013 	1.10e-03 	3129344
# gpt2 	 014 	3.10e-06 	2048
# gpt2 	 015 	1.27e-05 	8192
# gpt2 	 016 	6.28e-03 	8388608
# gpt2 	 017 	3.46e-03 	16760832
# gpt2 	 018 	2.95e-03 	9388032
# gpt2 	 019 	1.10e-03 	3129344
# gpt2 	 020 	3.10e-06 	2048
# gpt2 	 021 	1.27e-05 	8192
# gpt2 	 022 	6.28e-03 	8388608
# gpt2 	 023 	3.46e-03 	16760832
# gpt2 	 024 	2.95e-03 	9388032
# gpt2 	 025 	1.10e-03 	3129344
# gpt2 	 026 	3.10e-06 	2048
# gpt2 	 027 	1.27e-05 	8192
# gpt2 	 028 	6.28e-03 	8388608
# gpt2 	 029 	3.46e-03 	16760832
# gpt2 	 030 	2.95e-03 	9388032
# gpt2 	 031 	1.10e-03 	3129344
# gpt2 	 032 	3.10e-06 	2048
# gpt2 	 033 	1.27e-05 	8192
# gpt2 	 034 	6.28e-03 	8388608
# gpt2 	 035 	3.46e-03 	16760832
# gpt2 	 036 	2.95e-03 	9388032
# gpt2 	 037 	1.10e-03 	3129344
# gpt2 	 038 	3.10e-06 	2048
# gpt2 	 039 	1.27e-05 	8192
# gpt2 	 040 	6.28e-03 	8388608
# gpt2 	 041 	3.46e-03 	16760832
# gpt2 	 042 	2.95e-03 	9388032
# gpt2 	 043 	1.10e-03 	3129344
# gpt2 	 044 	3.10e-06 	2048
# gpt2 	 045 	1.27e-05 	8192
# gpt2 	 046 	6.28e-03 	8388608
# gpt2 	 047 	3.46e-03 	16760832
# gpt2 	 048 	2.95e-03 	9388032
# gpt2 	 049 	1.10e-03 	3129344
# gpt2 	 050 	3.10e-06 	2048
# gpt2 	 051 	1.27e-05 	8192
# gpt2 	 052 	6.28e-03 	8388608
# gpt2 	 053 	3.46e-03 	16760832
# gpt2 	 054 	2.95e-03 	9388032
# gpt2 	 055 	1.10e-03 	3129344
# gpt2 	 056 	3.10e-06 	2048
# gpt2 	 057 	1.27e-05 	8192
# gpt2 	 058 	6.28e-03 	8388608
# gpt2 	 059 	3.46e-03 	16760832
# gpt2 	 060 	2.95e-03 	9388032
# gpt2 	 061 	1.10e-03 	3129344
# gpt2 	 062 	3.10e-06 	2048
# gpt2 	 063 	1.27e-05 	8192
# gpt2 	 064 	6.28e-03 	8388608
# gpt2 	 065 	3.46e-03 	16760832
# gpt2 	 066 	2.95e-03 	9388032
# gpt2 	 067 	1.10e-03 	3129344
# gpt2 	 068 	3.10e-06 	2048
# gpt2 	 069 	1.27e-05 	8192
# gpt2 	 070 	6.28e-03 	8388608
# gpt2 	 071 	3.46e-03 	16760832
# gpt2 	 072 	2.95e-03 	9388032
# gpt2 	 073 	1.10e-03 	3129344
# gpt2 	 074 	3.10e-06 	2048
# gpt2 	 075 	1.27e-05 	8192
# gpt2 	 076 	6.28e-03 	8388608
# gpt2 	 077 	3.46e-03 	16760832
# gpt2 	 078 	2.95e-03 	9388032
# gpt2 	 079 	1.10e-03 	3129344
# gpt2 	 080 	3.10e-06 	2048
# gpt2 	 081 	1.27e-05 	8192
# gpt2 	 082 	6.28e-03 	8388608
# gpt2 	 083 	3.46e-03 	16760832
# gpt2 	 084 	2.95e-03 	9388032
# gpt2 	 085 	1.10e-03 	3129344
# gpt2 	 086 	3.10e-06 	2048
# gpt2 	 087 	1.27e-05 	8192
# gpt2 	 088 	6.28e-03 	8388608
# gpt2 	 089 	3.46e-03 	16760832
# gpt2 	 090 	2.95e-03 	9388032
# gpt2 	 091 	1.10e-03 	3129344
# gpt2 	 092 	3.10e-06 	2048
# gpt2 	 093 	1.27e-05 	8192
# gpt2 	 094 	6.28e-03 	8388608
# gpt2 	 095 	3.46e-03 	16760832
# gpt2 	 096 	2.95e-03 	9388032
# gpt2 	 097 	1.10e-03 	3129344
# gpt2 	 098 	3.10e-06 	2048
# gpt2 	 099 	1.27e-05 	8192
# gpt2 	 100 	6.28e-03 	8388608
# gpt2 	 101 	3.46e-03 	16760832
# gpt2 	 102 	2.95e-03 	9388032
# gpt2 	 103 	1.10e-03 	3129344
# gpt2 	 104 	3.10e-06 	2048
# gpt2 	 105 	1.27e-05 	8192
# gpt2 	 106 	6.28e-03 	8388608
# gpt2 	 107 	3.46e-03 	16760832
# gpt2 	 108 	2.95e-03 	9388032
# gpt2 	 109 	1.10e-03 	3129344
# gpt2 	 110 	3.10e-06 	2048
# gpt2 	 111 	1.27e-05 	8192
# gpt2 	 112 	6.28e-03 	8388608
# gpt2 	 113 	3.46e-03 	16760832
# gpt2 	 114 	2.95e-03 	9388032
# gpt2 	 115 	1.10e-03 	3129344
# gpt2 	 116 	3.10e-06 	2048
# gpt2 	 117 	1.27e-05 	8192
# gpt2 	 118 	6.28e-03 	8388608
# gpt2 	 119 	3.46e-03 	16760832
# gpt2 	 120 	2.95e-03 	9388032
# gpt2 	 121 	1.10e-03 	3129344
# gpt2 	 122 	3.10e-06 	2048
# gpt2 	 123 	1.27e-05 	8192
# gpt2 	 124 	6.28e-03 	8388608
# gpt2 	 125 	3.46e-03 	16760832
# gpt2 	 126 	2.95e-03 	9388032
# gpt2 	 127 	1.10e-03 	3129344
# gpt2 	 128 	3.10e-06 	2048
# gpt2 	 129 	1.27e-05 	8192
# gpt2 	 130 	6.28e-03 	8388608
# gpt2 	 131 	3.46e-03 	16760832
# gpt2 	 132 	2.95e-03 	9388032
# gpt2 	 133 	1.10e-03 	3129344
# gpt2 	 134 	3.10e-06 	2048
# gpt2 	 135 	1.27e-05 	8192
# gpt2 	 136 	6.28e-03 	8388608
# gpt2 	 137 	3.46e-03 	16760832
# gpt2 	 138 	2.95e-03 	9388032
# gpt2 	 139 	1.10e-03 	3129344
# gpt2 	 140 	3.10e-06 	2048
# gpt2 	 141 	1.27e-05 	8192
# gpt2 	 142 	6.28e-03 	8388608
# gpt2 	 143 	3.46e-03 	16760832
# gpt2 	 144 	3.43e-02 	113573888
#
# === Total Summary ===
# Model 		Energy/inference (J) 	Area (mm²) 	Throughput (inf/s)
# gpt2 	3.66e-01 		15.43 		9.82e-01

# %%
all_layers_percent
# Out:
# {'000': {'mac': 18.158733795368196,
#   'output_activation_reg': 2.890854491748014,
#   'input_activation_reg': 2.9134925635297937,
#   'weight_reg': 2.9134925635297937,
#   'pe_spad': 0.13255545645716904,
#   'shared_glb': 15.031952410954647,
#   'DRAM': 57.95891871841239},
#  '001': {'mac': 16.28400705394901,
#   'output_activation_reg': 2.571854156424499,
#   'input_activation_reg': 2.612700532470423,
#   'weight_reg': 2.612700532470423,
#   'pe_spad': 0.29888785346179153,
#   'shared_glb': 11.415216864906116,
#   'DRAM': 64.20463300631774},
#  '002': {'mac': 5.623660646032134,
#   'output_activation_reg': 0.676677312515785,
#   'input_activation_reg': 0.9022927290342798,
#   'weight_reg': 0.9022927290342798,
#   'pe_spad': 1.6318473349759646,
#   'shared_glb': 1.5712834062437442,
#   'DRAM': 88.69194584216382},
#  '003': {'mac': 5.503932620495922,
#   'output_activation_reg': 0.8762212452443978,
#   'input_activation_reg': 0.8830828702425377,
#   'weight_reg': 0.8830828702425377,
#   'pe_spad': 1.597105220952592,
#   'shared_glb': 3.452885437316989,
#   'DRAM': 86.80368973550502},
#  '004': {'mac': 11.379477730565307,
#   'output_activation_reg': 1.8186106771590023,
#   'input_activation_reg': 1.8257894035162086,
#   'weight_reg': 1.8257894035162086,
#   'pe_spad': 3.0542062208791547,
#   'shared_glb': 1.0446756070296823,
#   'DRAM': 79.05145095733444},
#  '005': {'mac': 20.68546608089382,
#   'output_activation_reg': 3.3123714479235926,
#   'input_activation_reg': 3.318896145457257,
#   'weight_reg': 3.318896145457257,
#   'pe_spad': 0.8317435856009245,
#   'shared_glb': 20.956707078364726,
#   'DRAM': 47.57591951630242},
#  '006': {'mac': 18.158733795368196,
#   'output_activation_reg': 2.890854491748014,
#   'input_activation_reg': 2.9134925635297937,
#   'weight_reg': 2.9134925635297937,
#   'pe_spad': 0.13255545645716904,
#   'shared_glb': 15.031952410954647,
#   'DRAM': 57.95891871841239},
#  '007': {'mac': 16.28400705394901,
#   'output_activation_reg': 2.571854156424499,
#   'input_activation_reg': 2.612700532470423,
#   'weight_reg': 2.612700532470423,
#   'pe_spad': 0.29888785346179153,
#   'shared_glb': 11.415216864906116,
#   'DRAM': 64.20463300631774},
#  '008': {'mac': 5.623660646032134,
#   'output_activation_reg': 0.676677312515785,
#   'input_activation_reg': 0.9022927290342798,
#   'weight_reg': 0.9022927290342798,
#   'pe_spad': 1.6318473349759646,
#   'shared_glb': 1.5712834062437442,
#   'DRAM': 88.69194584216382},
#  '009': {'mac': 5.503932620495922,
#   'output_activation_reg': 0.8762212452443978,
#   'input_activation_reg': 0.8830828702425377,
#   'weight_reg': 0.8830828702425377,
#   'pe_spad': 1.597105220952592,
#   'shared_glb': 3.452885437316989,
#   'DRAM': 86.80368973550502},
#  '010': {'mac': 11.379477730565307,
#   'output_activation_reg': 1.8186106771590023,
#   'input_activation_reg': 1.8257894035162086,
#   'weight_reg': 1.8257894035162086,
#   'pe_spad': 3.0542062208791547,
#   'shared_glb': 1.0446756070296823,
#   'DRAM': 79.05145095733444},
#  '011': {'mac': 20.68546608089382,
#   'output_activation_reg': 3.3123714479235926,
#   'input_activation_reg': 3.318896145457257,
#   'weight_reg': 3.318896145457257,
#   'pe_spad': 0.8317435856009245,
#   'shared_glb': 20.956707078364726,
#   'DRAM': 47.57591951630242},
#  '012': {'mac': 18.158733795368196,
#   'output_activation_reg': 2.890854491748014,
#   'input_activation_reg': 2.9134925635297937,
#   'weight_reg': 2.9134925635297937,
#   'pe_spad': 0.13255545645716904,
#   'shared_glb': 15.031952410954647,
#   'DRAM': 57.95891871841239},
#  '013': {'mac': 16.28400705394901,
#   'output_activation_reg': 2.571854156424499,
#   'input_activation_reg': 2.612700532470423,
#   'weight_reg': 2.612700532470423,
#   'pe_spad': 0.29888785346179153,
#   'shared_glb': 11.415216864906116,
#   'DRAM': 64.20463300631774},
#  '014': {'mac': 5.623660646032134,
#   'output_activation_reg': 0.676677312515785,
#   'input_activation_reg': 0.9022927290342798,
#   'weight_reg': 0.9022927290342798,
#   'pe_spad': 1.6318473349759646,
#   'shared_glb': 1.5712834062437442,
#   'DRAM': 88.69194584216382},
#  '015': {'mac': 5.503932620495922,
#   'output_activation_reg': 0.8762212452443978,
#   'input_activation_reg': 0.8830828702425377,
#   'weight_reg': 0.8830828702425377,
#   'pe_spad': 1.597105220952592,
#   'shared_glb': 3.452885437316989,
#   'DRAM': 86.80368973550502},
#  '016': {'mac': 11.379477730565307,
#   'output_activation_reg': 1.8186106771590023,
#   'input_activation_reg': 1.8257894035162086,
#   'weight_reg': 1.8257894035162086,
#   'pe_spad': 3.0542062208791547,
#   'shared_glb': 1.0446756070296823,
#   'DRAM': 79.05145095733444},
#  '017': {'mac': 20.68546608089382,
#   'output_activation_reg': 3.3123714479235926,
#   'input_activation_reg': 3.318896145457257,
#   'weight_reg': 3.318896145457257,
#   'pe_spad': 0.8317435856009245,
#   'shared_glb': 20.956707078364726,
#   'DRAM': 47.57591951630242},
#  '018': {'mac': 18.158733795368196,
#   'output_activation_reg': 2.890854491748014,
#   'input_activation_reg': 2.9134925635297937,
#   'weight_reg': 2.9134925635297937,
#   'pe_spad': 0.13255545645716904,
#   'shared_glb': 15.031952410954647,
#   'DRAM': 57.95891871841239},
#  '019': {'mac': 16.28400705394901,
#   'output_activation_reg': 2.571854156424499,
#   'input_activation_reg': 2.612700532470423,
#   'weight_reg': 2.612700532470423,
#   'pe_spad': 0.29888785346179153,
#   'shared_glb': 11.415216864906116,
#   'DRAM': 64.20463300631774},
#  '020': {'mac': 5.623660646032134,
#   'output_activation_reg': 0.676677312515785,
#   'input_activation_reg': 0.9022927290342798,
#   'weight_reg': 0.9022927290342798,
#   'pe_spad': 1.6318473349759646,
#   'shared_glb': 1.5712834062437442,
#   'DRAM': 88.69194584216382},
#  '021': {'mac': 5.503932620495922,
#   'output_activation_reg': 0.8762212452443978,
#   'input_activation_reg': 0.8830828702425377,
#   'weight_reg': 0.8830828702425377,
#   'pe_spad': 1.597105220952592,
#   'shared_glb': 3.452885437316989,
#   'DRAM': 86.80368973550502},
#  '022': {'mac': 11.379477730565307,
#   'output_activation_reg': 1.8186106771590023,
#   'input_activation_reg': 1.8257894035162086,
#   'weight_reg': 1.8257894035162086,
#   'pe_spad': 3.0542062208791547,
#   'shared_glb': 1.0446756070296823,
#   'DRAM': 79.05145095733444},
#  '023': {'mac': 20.68546608089382,
#   'output_activation_reg': 3.3123714479235926,
#   'input_activation_reg': 3.318896145457257,
#   'weight_reg': 3.318896145457257,
#   'pe_spad': 0.8317435856009245,
#   'shared_glb': 20.956707078364726,
#   'DRAM': 47.57591951630242},
#  '024': {'mac': 18.158733795368196,
#   'output_activation_reg': 2.890854491748014,
#   'input_activation_reg': 2.9134925635297937,
#   'weight_reg': 2.9134925635297937,
#   'pe_spad': 0.13255545645716904,
#   'shared_glb': 15.031952410954647,
#   'DRAM': 57.95891871841239},
#  '025': {'mac': 16.28400705394901,
#   'output_activation_reg': 2.571854156424499,
#   'input_activation_reg': 2.612700532470423,
#   'weight_reg': 2.612700532470423,
#   'pe_spad': 0.29888785346179153,
#   'shared_glb': 11.415216864906116,
#   'DRAM': 64.20463300631774},
#  '026': {'mac': 5.623660646032134,
#   'output_activation_reg': 0.676677312515785,
#   'input_activation_reg': 0.9022927290342798,
#   'weight_reg': 0.9022927290342798,
#   'pe_spad': 1.6318473349759646,
#   'shared_glb': 1.5712834062437442,
#   'DRAM': 88.69194584216382},
#  '027': {'mac': 5.503932620495922,
#   'output_activation_reg': 0.8762212452443978,
#   'input_activation_reg': 0.8830828702425377,
#   'weight_reg': 0.8830828702425377,
#   'pe_spad': 1.597105220952592,
#   'shared_glb': 3.452885437316989,
#   'DRAM': 86.80368973550502},
#  '028': {'mac': 11.379477730565307,
#   'output_activation_reg': 1.8186106771590023,
#   'input_activation_reg': 1.8257894035162086,
#   'weight_reg': 1.8257894035162086,
#   'pe_spad': 3.0542062208791547,
#   'shared_glb': 1.0446756070296823,
#   'DRAM': 79.05145095733444},
#  '029': {'mac': 20.68546608089382,
#   'output_activation_reg': 3.3123714479235926,
#   'input_activation_reg': 3.318896145457257,
#   'weight_reg': 3.318896145457257,
#   'pe_spad': 0.8317435856009245,
#   'shared_glb': 20.956707078364726,
#   'DRAM': 47.57591951630242},
#  '030': {'mac': 18.158733795368196,
#   'output_activation_reg': 2.890854491748014,
#   'input_activation_reg': 2.9134925635297937,
#   'weight_reg': 2.9134925635297937,
#   'pe_spad': 0.13255545645716904,
#   'shared_glb': 15.031952410954647,
#   'DRAM': 57.95891871841239},
#  '031': {'mac': 16.28400705394901,
#   'output_activation_reg': 2.571854156424499,
#   'input_activation_reg': 2.612700532470423,
#   'weight_reg': 2.612700532470423,
#   'pe_spad': 0.29888785346179153,
#   'shared_glb': 11.415216864906116,
#   'DRAM': 64.20463300631774},
#  '032': {'mac': 5.623660646032134,
#   'output_activation_reg': 0.676677312515785,
#   'input_activation_reg': 0.9022927290342798,
#   'weight_reg': 0.9022927290342798,
#   'pe_spad': 1.6318473349759646,
#   'shared_glb': 1.5712834062437442,
#   'DRAM': 88.69194584216382},
#  '033': {'mac': 5.503932620495922,
#   'output_activation_reg': 0.8762212452443978,
#   'input_activation_reg': 0.8830828702425377,
#   'weight_reg': 0.8830828702425377,
#   'pe_spad': 1.597105220952592,
#   'shared_glb': 3.452885437316989,
#   'DRAM': 86.80368973550502},
#  '034': {'mac': 11.379477730565307,
#   'output_activation_reg': 1.8186106771590023,
#   'input_activation_reg': 1.8257894035162086,
#   'weight_reg': 1.8257894035162086,
#   'pe_spad': 3.0542062208791547,
#   'shared_glb': 1.0446756070296823,
#   'DRAM': 79.05145095733444},
#  '035': {'mac': 20.68546608089382,
#   'output_activation_reg': 3.3123714479235926,
#   'input_activation_reg': 3.318896145457257,
#   'weight_reg': 3.318896145457257,
#   'pe_spad': 0.8317435856009245,
#   'shared_glb': 20.956707078364726,
#   'DRAM': 47.57591951630242},
#  '036': {'mac': 18.158733795368196,
#   'output_activation_reg': 2.890854491748014,
#   'input_activation_reg': 2.9134925635297937,
#   'weight_reg': 2.9134925635297937,
#   'pe_spad': 0.13255545645716904,
#   'shared_glb': 15.031952410954647,
#   'DRAM': 57.95891871841239},
#  '037': {'mac': 16.28400705394901,
#   'output_activation_reg': 2.571854156424499,
#   'input_activation_reg': 2.612700532470423,
#   'weight_reg': 2.612700532470423,
#   'pe_spad': 0.29888785346179153,
#   'shared_glb': 11.415216864906116,
#   'DRAM': 64.20463300631774},
#  '038': {'mac': 5.623660646032134,
#   'output_activation_reg': 0.676677312515785,
#   'input_activation_reg': 0.9022927290342798,
#   'weight_reg': 0.9022927290342798,
#   'pe_spad': 1.6318473349759646,
#   'shared_glb': 1.5712834062437442,
#   'DRAM': 88.69194584216382},
#  '039': {'mac': 5.503932620495922,
#   'output_activation_reg': 0.8762212452443978,
#   'input_activation_reg': 0.8830828702425377,
#   'weight_reg': 0.8830828702425377,
#   'pe_spad': 1.597105220952592,
#   'shared_glb': 3.452885437316989,
#   'DRAM': 86.80368973550502},
#  '040': {'mac': 11.379477730565307,
#   'output_activation_reg': 1.8186106771590023,
#   'input_activation_reg': 1.8257894035162086,
#   'weight_reg': 1.8257894035162086,
#   'pe_spad': 3.0542062208791547,
#   'shared_glb': 1.0446756070296823,
#   'DRAM': 79.05145095733444},
#  '041': {'mac': 20.68546608089382,
#   'output_activation_reg': 3.3123714479235926,
#   'input_activation_reg': 3.318896145457257,
#   'weight_reg': 3.318896145457257,
#   'pe_spad': 0.8317435856009245,
#   'shared_glb': 20.956707078364726,
#   'DRAM': 47.57591951630242},
#  '042': {'mac': 18.158733795368196,
#   'output_activation_reg': 2.890854491748014,
#   'input_activation_reg': 2.9134925635297937,
#   'weight_reg': 2.9134925635297937,
#   'pe_spad': 0.13255545645716904,
#   'shared_glb': 15.031952410954647,
#   'DRAM': 57.95891871841239},
#  '043': {'mac': 16.28400705394901,
#   'output_activation_reg': 2.571854156424499,
#   'input_activation_reg': 2.612700532470423,
#   'weight_reg': 2.612700532470423,
#   'pe_spad': 0.29888785346179153,
#   'shared_glb': 11.415216864906116,
#   'DRAM': 64.20463300631774},
#  '044': {'mac': 5.623660646032134,
#   'output_activation_reg': 0.676677312515785,
#   'input_activation_reg': 0.9022927290342798,
#   'weight_reg': 0.9022927290342798,
#   'pe_spad': 1.6318473349759646,
#   'shared_glb': 1.5712834062437442,
#   'DRAM': 88.69194584216382},
#  '045': {'mac': 5.503932620495922,
#   'output_activation_reg': 0.8762212452443978,
#   'input_activation_reg': 0.8830828702425377,
#   'weight_reg': 0.8830828702425377,
#   'pe_spad': 1.597105220952592,
#   'shared_glb': 3.452885437316989,
#   'DRAM': 86.80368973550502},
#  '046': {'mac': 11.379477730565307,
#   'output_activation_reg': 1.8186106771590023,
#   'input_activation_reg': 1.8257894035162086,
#   'weight_reg': 1.8257894035162086,
#   'pe_spad': 3.0542062208791547,
#   'shared_glb': 1.0446756070296823,
#   'DRAM': 79.05145095733444},
#  '047': {'mac': 20.68546608089382,
#   'output_activation_reg': 3.3123714479235926,
#   'input_activation_reg': 3.318896145457257,
#   'weight_reg': 3.318896145457257,
#   'pe_spad': 0.8317435856009245,
#   'shared_glb': 20.956707078364726,
#   'DRAM': 47.57591951630242},
#  '048': {'mac': 18.158733795368196,
#   'output_activation_reg': 2.890854491748014,
#   'input_activation_reg': 2.9134925635297937,
#   'weight_reg': 2.9134925635297937,
#   'pe_spad': 0.13255545645716904,
#   'shared_glb': 15.031952410954647,
#   'DRAM': 57.95891871841239},
#  '049': {'mac': 16.28400705394901,
#   'output_activation_reg': 2.571854156424499,
#   'input_activation_reg': 2.612700532470423,
#   'weight_reg': 2.612700532470423,
#   'pe_spad': 0.29888785346179153,
#   'shared_glb': 11.415216864906116,
#   'DRAM': 64.20463300631774},
#  '050': {'mac': 5.623660646032134,
#   'output_activation_reg': 0.676677312515785,
#   'input_activation_reg': 0.9022927290342798,
#   'weight_reg': 0.9022927290342798,
#   'pe_spad': 1.6318473349759646,
#   'shared_glb': 1.5712834062437442,
#   'DRAM': 88.69194584216382},
#  '051': {'mac': 5.503932620495922,
#   'output_activation_reg': 0.8762212452443978,
#   'input_activation_reg': 0.8830828702425377,
#   'weight_reg': 0.8830828702425377,
#   'pe_spad': 1.597105220952592,
#   'shared_glb': 3.452885437316989,
#   'DRAM': 86.80368973550502},
#  '052': {'mac': 11.379477730565307,
#   'output_activation_reg': 1.8186106771590023,
#   'input_activation_reg': 1.8257894035162086,
#   'weight_reg': 1.8257894035162086,
#   'pe_spad': 3.0542062208791547,
#   'shared_glb': 1.0446756070296823,
#   'DRAM': 79.05145095733444},
#  '053': {'mac': 20.68546608089382,
#   'output_activation_reg': 3.3123714479235926,
#   'input_activation_reg': 3.318896145457257,
#   'weight_reg': 3.318896145457257,
#   'pe_spad': 0.8317435856009245,
#   'shared_glb': 20.956707078364726,
#   'DRAM': 47.57591951630242},
#  '054': {'mac': 18.158733795368196,
#   'output_activation_reg': 2.890854491748014,
#   'input_activation_reg': 2.9134925635297937,
#   'weight_reg': 2.9134925635297937,
#   'pe_spad': 0.13255545645716904,
#   'shared_glb': 15.031952410954647,
#   'DRAM': 57.95891871841239},
#  '055': {'mac': 16.28400705394901,
#   'output_activation_reg': 2.571854156424499,
#   'input_activation_reg': 2.612700532470423,
#   'weight_reg': 2.612700532470423,
#   'pe_spad': 0.29888785346179153,
#   'shared_glb': 11.415216864906116,
#   'DRAM': 64.20463300631774},
#  '056': {'mac': 5.623660646032134,
#   'output_activation_reg': 0.676677312515785,
#   'input_activation_reg': 0.9022927290342798,
#   'weight_reg': 0.9022927290342798,
#   'pe_spad': 1.6318473349759646,
#   'shared_glb': 1.5712834062437442,
#   'DRAM': 88.69194584216382},
#  '057': {'mac': 5.503932620495922,
#   'output_activation_reg': 0.8762212452443978,
#   'input_activation_reg': 0.8830828702425377,
#   'weight_reg': 0.8830828702425377,
#   'pe_spad': 1.597105220952592,
#   'shared_glb': 3.452885437316989,
#   'DRAM': 86.80368973550502},
#  '058': {'mac': 11.379477730565307,
#   'output_activation_reg': 1.8186106771590023,
#   'input_activation_reg': 1.8257894035162086,
#   'weight_reg': 1.8257894035162086,
#   'pe_spad': 3.0542062208791547,
#   'shared_glb': 1.0446756070296823,
#   'DRAM': 79.05145095733444},
#  '059': {'mac': 20.68546608089382,
#   'output_activation_reg': 3.3123714479235926,
#   'input_activation_reg': 3.318896145457257,
#   'weight_reg': 3.318896145457257,
#   'pe_spad': 0.8317435856009245,
#   'shared_glb': 20.956707078364726,
#   'DRAM': 47.57591951630242},
#  '060': {'mac': 18.158733795368196,
#   'output_activation_reg': 2.890854491748014,
#   'input_activation_reg': 2.9134925635297937,
#   'weight_reg': 2.9134925635297937,
#   'pe_spad': 0.13255545645716904,
#   'shared_glb': 15.031952410954647,
#   'DRAM': 57.95891871841239},
#  '061': {'mac': 16.28400705394901,
#   'output_activation_reg': 2.571854156424499,
#   'input_activation_reg': 2.612700532470423,
#   'weight_reg': 2.612700532470423,
#   'pe_spad': 0.29888785346179153,
#   'shared_glb': 11.415216864906116,
#   'DRAM': 64.20463300631774},
#  '062': {'mac': 5.623660646032134,
#   'output_activation_reg': 0.676677312515785,
#   'input_activation_reg': 0.9022927290342798,
#   'weight_reg': 0.9022927290342798,
#   'pe_spad': 1.6318473349759646,
#   'shared_glb': 1.5712834062437442,
#   'DRAM': 88.69194584216382},
#  '063': {'mac': 5.503932620495922,
#   'output_activation_reg': 0.8762212452443978,
#   'input_activation_reg': 0.8830828702425377,
#   'weight_reg': 0.8830828702425377,
#   'pe_spad': 1.597105220952592,
#   'shared_glb': 3.452885437316989,
#   'DRAM': 86.80368973550502},
#  '064': {'mac': 11.379477730565307,
#   'output_activation_reg': 1.8186106771590023,
#   'input_activation_reg': 1.8257894035162086,
#   'weight_reg': 1.8257894035162086,
#   'pe_spad': 3.0542062208791547,
#   'shared_glb': 1.0446756070296823,
#   'DRAM': 79.05145095733444},
#  '065': {'mac': 20.68546608089382,
#   'output_activation_reg': 3.3123714479235926,
#   'input_activation_reg': 3.318896145457257,
#   'weight_reg': 3.318896145457257,
#   'pe_spad': 0.8317435856009245,
#   'shared_glb': 20.956707078364726,
#   'DRAM': 47.57591951630242},
#  '066': {'mac': 18.158733795368196,
#   'output_activation_reg': 2.890854491748014,
#   'input_activation_reg': 2.9134925635297937,
#   'weight_reg': 2.9134925635297937,
#   'pe_spad': 0.13255545645716904,
#   'shared_glb': 15.031952410954647,
#   'DRAM': 57.95891871841239},
#  '067': {'mac': 16.28400705394901,
#   'output_activation_reg': 2.571854156424499,
#   'input_activation_reg': 2.612700532470423,
#   'weight_reg': 2.612700532470423,
#   'pe_spad': 0.29888785346179153,
#   'shared_glb': 11.415216864906116,
#   'DRAM': 64.20463300631774},
#  '068': {'mac': 5.623660646032134,
#   'output_activation_reg': 0.676677312515785,
#   'input_activation_reg': 0.9022927290342798,
#   'weight_reg': 0.9022927290342798,
#   'pe_spad': 1.6318473349759646,
#   'shared_glb': 1.5712834062437442,
#   'DRAM': 88.69194584216382},
#  '069': {'mac': 5.503932620495922,
#   'output_activation_reg': 0.8762212452443978,
#   'input_activation_reg': 0.8830828702425377,
#   'weight_reg': 0.8830828702425377,
#   'pe_spad': 1.597105220952592,
#   'shared_glb': 3.452885437316989,
#   'DRAM': 86.80368973550502},
#  '070': {'mac': 11.379477730565307,
#   'output_activation_reg': 1.8186106771590023,
#   'input_activation_reg': 1.8257894035162086,
#   'weight_reg': 1.8257894035162086,
#   'pe_spad': 3.0542062208791547,
#   'shared_glb': 1.0446756070296823,
#   'DRAM': 79.05145095733444},
#  '071': {'mac': 20.68546608089382,
#   'output_activation_reg': 3.3123714479235926,
#   'input_activation_reg': 3.318896145457257,
#   'weight_reg': 3.318896145457257,
#   'pe_spad': 0.8317435856009245,
#   'shared_glb': 20.956707078364726,
#   'DRAM': 47.57591951630242},
#  '072': {'mac': 18.158733795368196,
#   'output_activation_reg': 2.890854491748014,
#   'input_activation_reg': 2.9134925635297937,
#   'weight_reg': 2.9134925635297937,
#   'pe_spad': 0.13255545645716904,
#   'shared_glb': 15.031952410954647,
#   'DRAM': 57.95891871841239},
#  '073': {'mac': 16.28400705394901,
#   'output_activation_reg': 2.571854156424499,
#   'input_activation_reg': 2.612700532470423,
#   'weight_reg': 2.612700532470423,
#   'pe_spad': 0.29888785346179153,
#   'shared_glb': 11.415216864906116,
#   'DRAM': 64.20463300631774},
#  '074': {'mac': 5.623660646032134,
#   'output_activation_reg': 0.676677312515785,
#   'input_activation_reg': 0.9022927290342798,
#   'weight_reg': 0.9022927290342798,
#   'pe_spad': 1.6318473349759646,
#   'shared_glb': 1.5712834062437442,
#   'DRAM': 88.69194584216382},
#  '075': {'mac': 5.503932620495922,
#   'output_activation_reg': 0.8762212452443978,
#   'input_activation_reg': 0.8830828702425377,
#   'weight_reg': 0.8830828702425377,
#   'pe_spad': 1.597105220952592,
#   'shared_glb': 3.452885437316989,
#   'DRAM': 86.80368973550502},
#  '076': {'mac': 11.379477730565307,
#   'output_activation_reg': 1.8186106771590023,
#   'input_activation_reg': 1.8257894035162086,
#   'weight_reg': 1.8257894035162086,
#   'pe_spad': 3.0542062208791547,
#   'shared_glb': 1.0446756070296823,
#   'DRAM': 79.05145095733444},
#  '077': {'mac': 20.68546608089382,
#   'output_activation_reg': 3.3123714479235926,
#   'input_activation_reg': 3.318896145457257,
#   'weight_reg': 3.318896145457257,
#   'pe_spad': 0.8317435856009245,
#   'shared_glb': 20.956707078364726,
#   'DRAM': 47.57591951630242},
#  '078': {'mac': 18.158733795368196,
#   'output_activation_reg': 2.890854491748014,
#   'input_activation_reg': 2.9134925635297937,
#   'weight_reg': 2.9134925635297937,
#   'pe_spad': 0.13255545645716904,
#   'shared_glb': 15.031952410954647,
#   'DRAM': 57.95891871841239},
#  '079': {'mac': 16.28400705394901,
#   'output_activation_reg': 2.571854156424499,
#   'input_activation_reg': 2.612700532470423,
#   'weight_reg': 2.612700532470423,
#   'pe_spad': 0.29888785346179153,
#   'shared_glb': 11.415216864906116,
#   'DRAM': 64.20463300631774},
#  '080': {'mac': 5.623660646032134,
#   'output_activation_reg': 0.676677312515785,
#   'input_activation_reg': 0.9022927290342798,
#   'weight_reg': 0.9022927290342798,
#   'pe_spad': 1.6318473349759646,
#   'shared_glb': 1.5712834062437442,
#   'DRAM': 88.69194584216382},
#  '081': {'mac': 5.503932620495922,
#   'output_activation_reg': 0.8762212452443978,
#   'input_activation_reg': 0.8830828702425377,
#   'weight_reg': 0.8830828702425377,
#   'pe_spad': 1.597105220952592,
#   'shared_glb': 3.452885437316989,
#   'DRAM': 86.80368973550502},
#  '082': {'mac': 11.379477730565307,
#   'output_activation_reg': 1.8186106771590023,
#   'input_activation_reg': 1.8257894035162086,
#   'weight_reg': 1.8257894035162086,
#   'pe_spad': 3.0542062208791547,
#   'shared_glb': 1.0446756070296823,
#   'DRAM': 79.05145095733444},
#  '083': {'mac': 20.68546608089382,
#   'output_activation_reg': 3.3123714479235926,
#   'input_activation_reg': 3.318896145457257,
#   'weight_reg': 3.318896145457257,
#   'pe_spad': 0.8317435856009245,
#   'shared_glb': 20.956707078364726,
#   'DRAM': 47.57591951630242},
#  '084': {'mac': 18.158733795368196,
#   'output_activation_reg': 2.890854491748014,
#   'input_activation_reg': 2.9134925635297937,
#   'weight_reg': 2.9134925635297937,
#   'pe_spad': 0.13255545645716904,
#   'shared_glb': 15.031952410954647,
#   'DRAM': 57.95891871841239},
#  '085': {'mac': 16.28400705394901,
#   'output_activation_reg': 2.571854156424499,
#   'input_activation_reg': 2.612700532470423,
#   'weight_reg': 2.612700532470423,
#   'pe_spad': 0.29888785346179153,
#   'shared_glb': 11.415216864906116,
#   'DRAM': 64.20463300631774},
#  '086': {'mac': 5.623660646032134,
#   'output_activation_reg': 0.676677312515785,
#   'input_activation_reg': 0.9022927290342798,
#   'weight_reg': 0.9022927290342798,
#   'pe_spad': 1.6318473349759646,
#   'shared_glb': 1.5712834062437442,
#   'DRAM': 88.69194584216382},
#  '087': {'mac': 5.503932620495922,
#   'output_activation_reg': 0.8762212452443978,
#   'input_activation_reg': 0.8830828702425377,
#   'weight_reg': 0.8830828702425377,
#   'pe_spad': 1.597105220952592,
#   'shared_glb': 3.452885437316989,
#   'DRAM': 86.80368973550502},
#  '088': {'mac': 11.379477730565307,
#   'output_activation_reg': 1.8186106771590023,
#   'input_activation_reg': 1.8257894035162086,
#   'weight_reg': 1.8257894035162086,
#   'pe_spad': 3.0542062208791547,
#   'shared_glb': 1.0446756070296823,
#   'DRAM': 79.05145095733444},
#  '089': {'mac': 20.68546608089382,
#   'output_activation_reg': 3.3123714479235926,
#   'input_activation_reg': 3.318896145457257,
#   'weight_reg': 3.318896145457257,
#   'pe_spad': 0.8317435856009245,
#   'shared_glb': 20.956707078364726,
#   'DRAM': 47.57591951630242},
#  '090': {'mac': 18.158733795368196,
#   'output_activation_reg': 2.890854491748014,
#   'input_activation_reg': 2.9134925635297937,
#   'weight_reg': 2.9134925635297937,
#   'pe_spad': 0.13255545645716904,
#   'shared_glb': 15.031952410954647,
#   'DRAM': 57.95891871841239},
#  '091': {'mac': 16.28400705394901,
#   'output_activation_reg': 2.571854156424499,
#   'input_activation_reg': 2.612700532470423,
#   'weight_reg': 2.612700532470423,
#   'pe_spad': 0.29888785346179153,
#   'shared_glb': 11.415216864906116,
#   'DRAM': 64.20463300631774},
#  '092': {'mac': 5.623660646032134,
#   'output_activation_reg': 0.676677312515785,
#   'input_activation_reg': 0.9022927290342798,
#   'weight_reg': 0.9022927290342798,
#   'pe_spad': 1.6318473349759646,
#   'shared_glb': 1.5712834062437442,
#   'DRAM': 88.69194584216382},
#  '093': {'mac': 5.503932620495922,
#   'output_activation_reg': 0.8762212452443978,
#   'input_activation_reg': 0.8830828702425377,
#   'weight_reg': 0.8830828702425377,
#   'pe_spad': 1.597105220952592,
#   'shared_glb': 3.452885437316989,
#   'DRAM': 86.80368973550502},
#  '094': {'mac': 11.379477730565307,
#   'output_activation_reg': 1.8186106771590023,
#   'input_activation_reg': 1.8257894035162086,
#   'weight_reg': 1.8257894035162086,
#   'pe_spad': 3.0542062208791547,
#   'shared_glb': 1.0446756070296823,
#   'DRAM': 79.05145095733444},
#  '095': {'mac': 20.68546608089382,
#   'output_activation_reg': 3.3123714479235926,
#   'input_activation_reg': 3.318896145457257,
#   'weight_reg': 3.318896145457257,
#   'pe_spad': 0.8317435856009245,
#   'shared_glb': 20.956707078364726,
#   'DRAM': 47.57591951630242},
#  '096': {'mac': 18.158733795368196,
#   'output_activation_reg': 2.890854491748014,
#   'input_activation_reg': 2.9134925635297937,
#   'weight_reg': 2.9134925635297937,
#   'pe_spad': 0.13255545645716904,
#   'shared_glb': 15.031952410954647,
#   'DRAM': 57.95891871841239},
#  '097': {'mac': 16.28400705394901,
#   'output_activation_reg': 2.571854156424499,
#   'input_activation_reg': 2.612700532470423,
#   'weight_reg': 2.612700532470423,
#   'pe_spad': 0.29888785346179153,
#   'shared_glb': 11.415216864906116,
#   'DRAM': 64.20463300631774},
#  '098': {'mac': 5.623660646032134,
#   'output_activation_reg': 0.676677312515785,
#   'input_activation_reg': 0.9022927290342798,
#   'weight_reg': 0.9022927290342798,
#   'pe_spad': 1.6318473349759646,
#   'shared_glb': 1.5712834062437442,
#   'DRAM': 88.69194584216382},
#  '099': {'mac': 5.503932620495922,
#   'output_activation_reg': 0.8762212452443978,
#   'input_activation_reg': 0.8830828702425377,
#   'weight_reg': 0.8830828702425377,
#   'pe_spad': 1.597105220952592,
#   'shared_glb': 3.452885437316989,
#   'DRAM': 86.80368973550502},
#  '100': {'mac': 11.379477730565307,
#   'output_activation_reg': 1.8186106771590023,
#   'input_activation_reg': 1.8257894035162086,
#   'weight_reg': 1.8257894035162086,
#   'pe_spad': 3.0542062208791547,
#   'shared_glb': 1.0446756070296823,
#   'DRAM': 79.05145095733444},
#  '101': {'mac': 20.68546608089382,
#   'output_activation_reg': 3.3123714479235926,
#   'input_activation_reg': 3.318896145457257,
#   'weight_reg': 3.318896145457257,
#   'pe_spad': 0.8317435856009245,
#   'shared_glb': 20.956707078364726,
#   'DRAM': 47.57591951630242},
#  '102': {'mac': 18.158733795368196,
#   'output_activation_reg': 2.890854491748014,
#   'input_activation_reg': 2.9134925635297937,
#   'weight_reg': 2.9134925635297937,
#   'pe_spad': 0.13255545645716904,
#   'shared_glb': 15.031952410954647,
#   'DRAM': 57.95891871841239},
#  '103': {'mac': 16.28400705394901,
#   'output_activation_reg': 2.571854156424499,
#   'input_activation_reg': 2.612700532470423,
#   'weight_reg': 2.612700532470423,
#   'pe_spad': 0.29888785346179153,
#   'shared_glb': 11.415216864906116,
#   'DRAM': 64.20463300631774},
#  '104': {'mac': 5.623660646032134,
#   'output_activation_reg': 0.676677312515785,
#   'input_activation_reg': 0.9022927290342798,
#   'weight_reg': 0.9022927290342798,
#   'pe_spad': 1.6318473349759646,
#   'shared_glb': 1.5712834062437442,
#   'DRAM': 88.69194584216382},
#  '105': {'mac': 5.503932620495922,
#   'output_activation_reg': 0.8762212452443978,
#   'input_activation_reg': 0.8830828702425377,
#   'weight_reg': 0.8830828702425377,
#   'pe_spad': 1.597105220952592,
#   'shared_glb': 3.452885437316989,
#   'DRAM': 86.80368973550502},
#  '106': {'mac': 11.379477730565307,
#   'output_activation_reg': 1.8186106771590023,
#   'input_activation_reg': 1.8257894035162086,
#   'weight_reg': 1.8257894035162086,
#   'pe_spad': 3.0542062208791547,
#   'shared_glb': 1.0446756070296823,
#   'DRAM': 79.05145095733444},
#  '107': {'mac': 20.68546608089382,
#   'output_activation_reg': 3.3123714479235926,
#   'input_activation_reg': 3.318896145457257,
#   'weight_reg': 3.318896145457257,
#   'pe_spad': 0.8317435856009245,
#   'shared_glb': 20.956707078364726,
#   'DRAM': 47.57591951630242},
#  '108': {'mac': 18.158733795368196,
#   'output_activation_reg': 2.890854491748014,
#   'input_activation_reg': 2.9134925635297937,
#   'weight_reg': 2.9134925635297937,
#   'pe_spad': 0.13255545645716904,
#   'shared_glb': 15.031952410954647,
#   'DRAM': 57.95891871841239},
#  '109': {'mac': 16.28400705394901,
#   'output_activation_reg': 2.571854156424499,
#   'input_activation_reg': 2.612700532470423,
#   'weight_reg': 2.612700532470423,
#   'pe_spad': 0.29888785346179153,
#   'shared_glb': 11.415216864906116,
#   'DRAM': 64.20463300631774},
#  '110': {'mac': 5.623660646032134,
#   'output_activation_reg': 0.676677312515785,
#   'input_activation_reg': 0.9022927290342798,
#   'weight_reg': 0.9022927290342798,
#   'pe_spad': 1.6318473349759646,
#   'shared_glb': 1.5712834062437442,
#   'DRAM': 88.69194584216382},
#  '111': {'mac': 5.503932620495922,
#   'output_activation_reg': 0.8762212452443978,
#   'input_activation_reg': 0.8830828702425377,
#   'weight_reg': 0.8830828702425377,
#   'pe_spad': 1.597105220952592,
#   'shared_glb': 3.452885437316989,
#   'DRAM': 86.80368973550502},
#  '112': {'mac': 11.379477730565307,
#   'output_activation_reg': 1.8186106771590023,
#   'input_activation_reg': 1.8257894035162086,
#   'weight_reg': 1.8257894035162086,
#   'pe_spad': 3.0542062208791547,
#   'shared_glb': 1.0446756070296823,
#   'DRAM': 79.05145095733444},
#  '113': {'mac': 20.68546608089382,
#   'output_activation_reg': 3.3123714479235926,
#   'input_activation_reg': 3.318896145457257,
#   'weight_reg': 3.318896145457257,
#   'pe_spad': 0.8317435856009245,
#   'shared_glb': 20.956707078364726,
#   'DRAM': 47.57591951630242},
#  '114': {'mac': 18.158733795368196,
#   'output_activation_reg': 2.890854491748014,
#   'input_activation_reg': 2.9134925635297937,
#   'weight_reg': 2.9134925635297937,
#   'pe_spad': 0.13255545645716904,
#   'shared_glb': 15.031952410954647,
#   'DRAM': 57.95891871841239},
#  '115': {'mac': 16.28400705394901,
#   'output_activation_reg': 2.571854156424499,
#   'input_activation_reg': 2.612700532470423,
#   'weight_reg': 2.612700532470423,
#   'pe_spad': 0.29888785346179153,
#   'shared_glb': 11.415216864906116,
#   'DRAM': 64.20463300631774},
#  '116': {'mac': 5.623660646032134,
#   'output_activation_reg': 0.676677312515785,
#   'input_activation_reg': 0.9022927290342798,
#   'weight_reg': 0.9022927290342798,
#   'pe_spad': 1.6318473349759646,
#   'shared_glb': 1.5712834062437442,
#   'DRAM': 88.69194584216382},
#  '117': {'mac': 5.503932620495922,
#   'output_activation_reg': 0.8762212452443978,
#   'input_activation_reg': 0.8830828702425377,
#   'weight_reg': 0.8830828702425377,
#   'pe_spad': 1.597105220952592,
#   'shared_glb': 3.452885437316989,
#   'DRAM': 86.80368973550502},
#  '118': {'mac': 11.379477730565307,
#   'output_activation_reg': 1.8186106771590023,
#   'input_activation_reg': 1.8257894035162086,
#   'weight_reg': 1.8257894035162086,
#   'pe_spad': 3.0542062208791547,
#   'shared_glb': 1.0446756070296823,
#   'DRAM': 79.05145095733444},
#  '119': {'mac': 20.68546608089382,
#   'output_activation_reg': 3.3123714479235926,
#   'input_activation_reg': 3.318896145457257,
#   'weight_reg': 3.318896145457257,
#   'pe_spad': 0.8317435856009245,
#   'shared_glb': 20.956707078364726,
#   'DRAM': 47.57591951630242},
#  '120': {'mac': 18.158733795368196,
#   'output_activation_reg': 2.890854491748014,
#   'input_activation_reg': 2.9134925635297937,
#   'weight_reg': 2.9134925635297937,
#   'pe_spad': 0.13255545645716904,
#   'shared_glb': 15.031952410954647,
#   'DRAM': 57.95891871841239},
#  '121': {'mac': 16.28400705394901,
#   'output_activation_reg': 2.571854156424499,
#   'input_activation_reg': 2.612700532470423,
#   'weight_reg': 2.612700532470423,
#   'pe_spad': 0.29888785346179153,
#   'shared_glb': 11.415216864906116,
#   'DRAM': 64.20463300631774},
#  '122': {'mac': 5.623660646032134,
#   'output_activation_reg': 0.676677312515785,
#   'input_activation_reg': 0.9022927290342798,
#   'weight_reg': 0.9022927290342798,
#   'pe_spad': 1.6318473349759646,
#   'shared_glb': 1.5712834062437442,
#   'DRAM': 88.69194584216382},
#  '123': {'mac': 5.503932620495922,
#   'output_activation_reg': 0.8762212452443978,
#   'input_activation_reg': 0.8830828702425377,
#   'weight_reg': 0.8830828702425377,
#   'pe_spad': 1.597105220952592,
#   'shared_glb': 3.452885437316989,
#   'DRAM': 86.80368973550502},
#  '124': {'mac': 11.379477730565307,
#   'output_activation_reg': 1.8186106771590023,
#   'input_activation_reg': 1.8257894035162086,
#   'weight_reg': 1.8257894035162086,
#   'pe_spad': 3.0542062208791547,
#   'shared_glb': 1.0446756070296823,
#   'DRAM': 79.05145095733444},
#  '125': {'mac': 20.68546608089382,
#   'output_activation_reg': 3.3123714479235926,
#   'input_activation_reg': 3.318896145457257,
#   'weight_reg': 3.318896145457257,
#   'pe_spad': 0.8317435856009245,
#   'shared_glb': 20.956707078364726,
#   'DRAM': 47.57591951630242},
#  '126': {'mac': 18.158733795368196,
#   'output_activation_reg': 2.890854491748014,
#   'input_activation_reg': 2.9134925635297937,
#   'weight_reg': 2.9134925635297937,
#   'pe_spad': 0.13255545645716904,
#   'shared_glb': 15.031952410954647,
#   'DRAM': 57.95891871841239},
#  '127': {'mac': 16.28400705394901,
#   'output_activation_reg': 2.571854156424499,
#   'input_activation_reg': 2.612700532470423,
#   'weight_reg': 2.612700532470423,
#   'pe_spad': 0.29888785346179153,
#   'shared_glb': 11.415216864906116,
#   'DRAM': 64.20463300631774},
#  '128': {'mac': 5.623660646032134,
#   'output_activation_reg': 0.676677312515785,
#   'input_activation_reg': 0.9022927290342798,
#   'weight_reg': 0.9022927290342798,
#   'pe_spad': 1.6318473349759646,
#   'shared_glb': 1.5712834062437442,
#   'DRAM': 88.69194584216382},
#  '129': {'mac': 5.503932620495922,
#   'output_activation_reg': 0.8762212452443978,
#   'input_activation_reg': 0.8830828702425377,
#   'weight_reg': 0.8830828702425377,
#   'pe_spad': 1.597105220952592,
#   'shared_glb': 3.452885437316989,
#   'DRAM': 86.80368973550502},
#  '130': {'mac': 11.379477730565307,
#   'output_activation_reg': 1.8186106771590023,
#   'input_activation_reg': 1.8257894035162086,
#   'weight_reg': 1.8257894035162086,
#   'pe_spad': 3.0542062208791547,
#   'shared_glb': 1.0446756070296823,
#   'DRAM': 79.05145095733444},
#  '131': {'mac': 20.68546608089382,
#   'output_activation_reg': 3.3123714479235926,
#   'input_activation_reg': 3.318896145457257,
#   'weight_reg': 3.318896145457257,
#   'pe_spad': 0.8317435856009245,
#   'shared_glb': 20.956707078364726,
#   'DRAM': 47.57591951630242},
#  '132': {'mac': 18.158733795368196,
#   'output_activation_reg': 2.890854491748014,
#   'input_activation_reg': 2.9134925635297937,
#   'weight_reg': 2.9134925635297937,
#   'pe_spad': 0.13255545645716904,
#   'shared_glb': 15.031952410954647,
#   'DRAM': 57.95891871841239},
#  '133': {'mac': 16.28400705394901,
#   'output_activation_reg': 2.571854156424499,
#   'input_activation_reg': 2.612700532470423,
#   'weight_reg': 2.612700532470423,
#   'pe_spad': 0.29888785346179153,
#   'shared_glb': 11.415216864906116,
#   'DRAM': 64.20463300631774},
#  '134': {'mac': 5.623660646032134,
#   'output_activation_reg': 0.676677312515785,
#   'input_activation_reg': 0.9022927290342798,
#   'weight_reg': 0.9022927290342798,
#   'pe_spad': 1.6318473349759646,
#   'shared_glb': 1.5712834062437442,
#   'DRAM': 88.69194584216382},
#  '135': {'mac': 5.503932620495922,
#   'output_activation_reg': 0.8762212452443978,
#   'input_activation_reg': 0.8830828702425377,
#   'weight_reg': 0.8830828702425377,
#   'pe_spad': 1.597105220952592,
#   'shared_glb': 3.452885437316989,
#   'DRAM': 86.80368973550502},
#  '136': {'mac': 11.379477730565307,
#   'output_activation_reg': 1.8186106771590023,
#   'input_activation_reg': 1.8257894035162086,
#   'weight_reg': 1.8257894035162086,
#   'pe_spad': 3.0542062208791547,
#   'shared_glb': 1.0446756070296823,
#   'DRAM': 79.05145095733444},
#  '137': {'mac': 20.68546608089382,
#   'output_activation_reg': 3.3123714479235926,
#   'input_activation_reg': 3.318896145457257,
#   'weight_reg': 3.318896145457257,
#   'pe_spad': 0.8317435856009245,
#   'shared_glb': 20.956707078364726,
#   'DRAM': 47.57591951630242},
#  '138': {'mac': 18.158733795368196,
#   'output_activation_reg': 2.890854491748014,
#   'input_activation_reg': 2.9134925635297937,
#   'weight_reg': 2.9134925635297937,
#   'pe_spad': 0.13255545645716904,
#   'shared_glb': 15.031952410954647,
#   'DRAM': 57.95891871841239},
#  '139': {'mac': 16.28400705394901,
#   'output_activation_reg': 2.571854156424499,
#   'input_activation_reg': 2.612700532470423,
#   'weight_reg': 2.612700532470423,
#   'pe_spad': 0.29888785346179153,
#   'shared_glb': 11.415216864906116,
#   'DRAM': 64.20463300631774},
#  '140': {'mac': 5.623660646032134,
#   'output_activation_reg': 0.676677312515785,
#   'input_activation_reg': 0.9022927290342798,
#   'weight_reg': 0.9022927290342798,
#   'pe_spad': 1.6318473349759646,
#   'shared_glb': 1.5712834062437442,
#   'DRAM': 88.69194584216382},
#  '141': {'mac': 5.503932620495922,
#   'output_activation_reg': 0.8762212452443978,
#   'input_activation_reg': 0.8830828702425377,
#   'weight_reg': 0.8830828702425377,
#   'pe_spad': 1.597105220952592,
#   'shared_glb': 3.452885437316989,
#   'DRAM': 86.80368973550502},
#  '142': {'mac': 11.379477730565307,
#   'output_activation_reg': 1.8186106771590023,
#   'input_activation_reg': 1.8257894035162086,
#   'weight_reg': 1.8257894035162086,
#   'pe_spad': 3.0542062208791547,
#   'shared_glb': 1.0446756070296823,
#   'DRAM': 79.05145095733444},
#  '143': {'mac': 20.68546608089382,
#   'output_activation_reg': 3.3123714479235926,
#   'input_activation_reg': 3.318896145457257,
#   'weight_reg': 3.318896145457257,
#   'pe_spad': 0.8317435856009245,
#   'shared_glb': 20.956707078364726,
#   'DRAM': 47.57591951630242},
#  '144': {'mac': 25.545719997390826,
#   'output_activation_reg': 4.0825879924334,
#   'input_activation_reg': 4.098703471350898,
#   'weight_reg': 4.098703471350898,
#   'pe_spad': 6.856368875638384,
#   'shared_glb': 2.461063851829682,
#   'DRAM': 52.85685234000591}}

# %%
layer_data
# Out:
# [{'Layer': 0, 'Energy (uJ)': 2952.56, 'Cycles': 9388032.0},
#  {'Layer': 1, 'Energy (uJ)': 1097.49, 'Cycles': 3129344.0},
#  {'Layer': 2, 'Energy (uJ)': 3.1, 'Cycles': 2048.0},
#  {'Layer': 3, 'Energy (uJ)': 12.68, 'Cycles': 8192.0},
#  {'Layer': 4, 'Energy (uJ)': 6282.05, 'Cycles': 8388608.0},
#  {'Layer': 5, 'Energy (uJ)': 3455.87, 'Cycles': 16760832.0},
#  {'Layer': 6, 'Energy (uJ)': 2952.56, 'Cycles': 9388032.0},
#  {'Layer': 7, 'Energy (uJ)': 1097.49, 'Cycles': 3129344.0},
#  {'Layer': 8, 'Energy (uJ)': 3.1, 'Cycles': 2048.0},
#  {'Layer': 9, 'Energy (uJ)': 12.68, 'Cycles': 8192.0},
#  {'Layer': 10, 'Energy (uJ)': 6282.05, 'Cycles': 8388608.0},
#  {'Layer': 11, 'Energy (uJ)': 3455.87, 'Cycles': 16760832.0},
#  {'Layer': 12, 'Energy (uJ)': 2952.56, 'Cycles': 9388032.0},
#  {'Layer': 13, 'Energy (uJ)': 1097.49, 'Cycles': 3129344.0},
#  {'Layer': 14, 'Energy (uJ)': 3.1, 'Cycles': 2048.0},
#  {'Layer': 15, 'Energy (uJ)': 12.68, 'Cycles': 8192.0},
#  {'Layer': 16, 'Energy (uJ)': 6282.05, 'Cycles': 8388608.0},
#  {'Layer': 17, 'Energy (uJ)': 3455.87, 'Cycles': 16760832.0},
#  {'Layer': 18, 'Energy (uJ)': 2952.56, 'Cycles': 9388032.0},
#  {'Layer': 19, 'Energy (uJ)': 1097.49, 'Cycles': 3129344.0},
#  {'Layer': 20, 'Energy (uJ)': 3.1, 'Cycles': 2048.0},
#  {'Layer': 21, 'Energy (uJ)': 12.68, 'Cycles': 8192.0},
#  {'Layer': 22, 'Energy (uJ)': 6282.05, 'Cycles': 8388608.0},
#  {'Layer': 23, 'Energy (uJ)': 3455.87, 'Cycles': 16760832.0},
#  {'Layer': 24, 'Energy (uJ)': 2952.56, 'Cycles': 9388032.0},
#  {'Layer': 25, 'Energy (uJ)': 1097.49, 'Cycles': 3129344.0},
#  {'Layer': 26, 'Energy (uJ)': 3.1, 'Cycles': 2048.0},
#  {'Layer': 27, 'Energy (uJ)': 12.68, 'Cycles': 8192.0},
#  {'Layer': 28, 'Energy (uJ)': 6282.05, 'Cycles': 8388608.0},
#  {'Layer': 29, 'Energy (uJ)': 3455.87, 'Cycles': 16760832.0},
#  {'Layer': 30, 'Energy (uJ)': 2952.56, 'Cycles': 9388032.0},
#  {'Layer': 31, 'Energy (uJ)': 1097.49, 'Cycles': 3129344.0},
#  {'Layer': 32, 'Energy (uJ)': 3.1, 'Cycles': 2048.0},
#  {'Layer': 33, 'Energy (uJ)': 12.68, 'Cycles': 8192.0},
#  {'Layer': 34, 'Energy (uJ)': 6282.05, 'Cycles': 8388608.0},
#  {'Layer': 35, 'Energy (uJ)': 3455.87, 'Cycles': 16760832.0},
#  {'Layer': 36, 'Energy (uJ)': 2952.56, 'Cycles': 9388032.0},
#  {'Layer': 37, 'Energy (uJ)': 1097.49, 'Cycles': 3129344.0},
#  {'Layer': 38, 'Energy (uJ)': 3.1, 'Cycles': 2048.0},
#  {'Layer': 39, 'Energy (uJ)': 12.68, 'Cycles': 8192.0},
#  {'Layer': 40, 'Energy (uJ)': 6282.05, 'Cycles': 8388608.0},
#  {'Layer': 41, 'Energy (uJ)': 3455.87, 'Cycles': 16760832.0},
#  {'Layer': 42, 'Energy (uJ)': 2952.56, 'Cycles': 9388032.0},
#  {'Layer': 43, 'Energy (uJ)': 1097.49, 'Cycles': 3129344.0},
#  {'Layer': 44, 'Energy (uJ)': 3.1, 'Cycles': 2048.0},
#  {'Layer': 45, 'Energy (uJ)': 12.68, 'Cycles': 8192.0},
#  {'Layer': 46, 'Energy (uJ)': 6282.05, 'Cycles': 8388608.0},
#  {'Layer': 47, 'Energy (uJ)': 3455.87, 'Cycles': 16760832.0},
#  {'Layer': 48, 'Energy (uJ)': 2952.56, 'Cycles': 9388032.0},
#  {'Layer': 49, 'Energy (uJ)': 1097.49, 'Cycles': 3129344.0},
#  {'Layer': 50, 'Energy (uJ)': 3.1, 'Cycles': 2048.0},
#  {'Layer': 51, 'Energy (uJ)': 12.68, 'Cycles': 8192.0},
#  {'Layer': 52, 'Energy (uJ)': 6282.05, 'Cycles': 8388608.0},
#  {'Layer': 53, 'Energy (uJ)': 3455.87, 'Cycles': 16760832.0},
#  {'Layer': 54, 'Energy (uJ)': 2952.56, 'Cycles': 9388032.0},
#  {'Layer': 55, 'Energy (uJ)': 1097.49, 'Cycles': 3129344.0},
#  {'Layer': 56, 'Energy (uJ)': 3.1, 'Cycles': 2048.0},
#  {'Layer': 57, 'Energy (uJ)': 12.68, 'Cycles': 8192.0},
#  {'Layer': 58, 'Energy (uJ)': 6282.05, 'Cycles': 8388608.0},
#  {'Layer': 59, 'Energy (uJ)': 3455.87, 'Cycles': 16760832.0},
#  {'Layer': 60, 'Energy (uJ)': 2952.56, 'Cycles': 9388032.0},
#  {'Layer': 61, 'Energy (uJ)': 1097.49, 'Cycles': 3129344.0},
#  {'Layer': 62, 'Energy (uJ)': 3.1, 'Cycles': 2048.0},
#  {'Layer': 63, 'Energy (uJ)': 12.68, 'Cycles': 8192.0},
#  {'Layer': 64, 'Energy (uJ)': 6282.05, 'Cycles': 8388608.0},
#  {'Layer': 65, 'Energy (uJ)': 3455.87, 'Cycles': 16760832.0},
#  {'Layer': 66, 'Energy (uJ)': 2952.56, 'Cycles': 9388032.0},
#  {'Layer': 67, 'Energy (uJ)': 1097.49, 'Cycles': 3129344.0},
#  {'Layer': 68, 'Energy (uJ)': 3.1, 'Cycles': 2048.0},
#  {'Layer': 69, 'Energy (uJ)': 12.68, 'Cycles': 8192.0},
#  {'Layer': 70, 'Energy (uJ)': 6282.05, 'Cycles': 8388608.0},
#  {'Layer': 71, 'Energy (uJ)': 3455.87, 'Cycles': 16760832.0},
#  {'Layer': 72, 'Energy (uJ)': 2952.56, 'Cycles': 9388032.0},
#  {'Layer': 73, 'Energy (uJ)': 1097.49, 'Cycles': 3129344.0},
#  {'Layer': 74, 'Energy (uJ)': 3.1, 'Cycles': 2048.0},
#  {'Layer': 75, 'Energy (uJ)': 12.68, 'Cycles': 8192.0},
#  {'Layer': 76, 'Energy (uJ)': 6282.05, 'Cycles': 8388608.0},
#  {'Layer': 77, 'Energy (uJ)': 3455.87, 'Cycles': 16760832.0},
#  {'Layer': 78, 'Energy (uJ)': 2952.56, 'Cycles': 9388032.0},
#  {'Layer': 79, 'Energy (uJ)': 1097.49, 'Cycles': 3129344.0},
#  {'Layer': 80, 'Energy (uJ)': 3.1, 'Cycles': 2048.0},
#  {'Layer': 81, 'Energy (uJ)': 12.68, 'Cycles': 8192.0},
#  {'Layer': 82, 'Energy (uJ)': 6282.05, 'Cycles': 8388608.0},
#  {'Layer': 83, 'Energy (uJ)': 3455.87, 'Cycles': 16760832.0},
#  {'Layer': 84, 'Energy (uJ)': 2952.56, 'Cycles': 9388032.0},
#  {'Layer': 85, 'Energy (uJ)': 1097.49, 'Cycles': 3129344.0},
#  {'Layer': 86, 'Energy (uJ)': 3.1, 'Cycles': 2048.0},
#  {'Layer': 87, 'Energy (uJ)': 12.68, 'Cycles': 8192.0},
#  {'Layer': 88, 'Energy (uJ)': 6282.05, 'Cycles': 8388608.0},
#  {'Layer': 89, 'Energy (uJ)': 3455.87, 'Cycles': 16760832.0},
#  {'Layer': 90, 'Energy (uJ)': 2952.56, 'Cycles': 9388032.0},
#  {'Layer': 91, 'Energy (uJ)': 1097.49, 'Cycles': 3129344.0},
#  {'Layer': 92, 'Energy (uJ)': 3.1, 'Cycles': 2048.0},
#  {'Layer': 93, 'Energy (uJ)': 12.68, 'Cycles': 8192.0},
#  {'Layer': 94, 'Energy (uJ)': 6282.05, 'Cycles': 8388608.0},
#  {'Layer': 95, 'Energy (uJ)': 3455.87, 'Cycles': 16760832.0},
#  {'Layer': 96, 'Energy (uJ)': 2952.56, 'Cycles': 9388032.0},
#  {'Layer': 97, 'Energy (uJ)': 1097.49, 'Cycles': 3129344.0},
#  {'Layer': 98, 'Energy (uJ)': 3.1, 'Cycles': 2048.0},
#  {'Layer': 99, 'Energy (uJ)': 12.68, 'Cycles': 8192.0},
#  {'Layer': 100, 'Energy (uJ)': 6282.05, 'Cycles': 8388608.0},
#  {'Layer': 101, 'Energy (uJ)': 3455.87, 'Cycles': 16760832.0},
#  {'Layer': 102, 'Energy (uJ)': 2952.56, 'Cycles': 9388032.0},
#  {'Layer': 103, 'Energy (uJ)': 1097.49, 'Cycles': 3129344.0},
#  {'Layer': 104, 'Energy (uJ)': 3.1, 'Cycles': 2048.0},
#  {'Layer': 105, 'Energy (uJ)': 12.68, 'Cycles': 8192.0},
#  {'Layer': 106, 'Energy (uJ)': 6282.05, 'Cycles': 8388608.0},
#  {'Layer': 107, 'Energy (uJ)': 3455.87, 'Cycles': 16760832.0},
#  {'Layer': 108, 'Energy (uJ)': 2952.56, 'Cycles': 9388032.0},
#  {'Layer': 109, 'Energy (uJ)': 1097.49, 'Cycles': 3129344.0},
#  {'Layer': 110, 'Energy (uJ)': 3.1, 'Cycles': 2048.0},
#  {'Layer': 111, 'Energy (uJ)': 12.68, 'Cycles': 8192.0},
#  {'Layer': 112, 'Energy (uJ)': 6282.05, 'Cycles': 8388608.0},
#  {'Layer': 113, 'Energy (uJ)': 3455.87, 'Cycles': 16760832.0},
#  {'Layer': 114, 'Energy (uJ)': 2952.56, 'Cycles': 9388032.0},
#  {'Layer': 115, 'Energy (uJ)': 1097.49, 'Cycles': 3129344.0},
#  {'Layer': 116, 'Energy (uJ)': 3.1, 'Cycles': 2048.0},
#  {'Layer': 117, 'Energy (uJ)': 12.68, 'Cycles': 8192.0},
#  {'Layer': 118, 'Energy (uJ)': 6282.05, 'Cycles': 8388608.0},
#  {'Layer': 119, 'Energy (uJ)': 3455.87, 'Cycles': 16760832.0},
#  {'Layer': 120, 'Energy (uJ)': 2952.56, 'Cycles': 9388032.0},
#  {'Layer': 121, 'Energy (uJ)': 1097.49, 'Cycles': 3129344.0},
#  {'Layer': 122, 'Energy (uJ)': 3.1, 'Cycles': 2048.0},
#  {'Layer': 123, 'Energy (uJ)': 12.68, 'Cycles': 8192.0},
#  {'Layer': 124, 'Energy (uJ)': 6282.05, 'Cycles': 8388608.0},
#  {'Layer': 125, 'Energy (uJ)': 3455.87, 'Cycles': 16760832.0},
#  {'Layer': 126, 'Energy (uJ)': 2952.56, 'Cycles': 9388032.0},
#  {'Layer': 127, 'Energy (uJ)': 1097.49, 'Cycles': 3129344.0},
#  {'Layer': 128, 'Energy (uJ)': 3.1, 'Cycles': 2048.0},
#  {'Layer': 129, 'Energy (uJ)': 12.68, 'Cycles': 8192.0},
#  {'Layer': 130, 'Energy (uJ)': 6282.05, 'Cycles': 8388608.0},
#  {'Layer': 131, 'Energy (uJ)': 3455.87, 'Cycles': 16760832.0},
#  {'Layer': 132, 'Energy (uJ)': 2952.56, 'Cycles': 9388032.0},
#  {'Layer': 133, 'Energy (uJ)': 1097.49, 'Cycles': 3129344.0},
#  {'Layer': 134, 'Energy (uJ)': 3.1, 'Cycles': 2048.0},
#  {'Layer': 135, 'Energy (uJ)': 12.68, 'Cycles': 8192.0},
#  {'Layer': 136, 'Energy (uJ)': 6282.05, 'Cycles': 8388608.0},
#  {'Layer': 137, 'Energy (uJ)': 3455.87, 'Cycles': 16760832.0},
#  {'Layer': 138, 'Energy (uJ)': 2952.56, 'Cycles': 9388032.0},
#  {'Layer': 139, 'Energy (uJ)': 1097.49, 'Cycles': 3129344.0},
#  {'Layer': 140, 'Energy (uJ)': 3.1, 'Cycles': 2048.0},
#  {'Layer': 141, 'Energy (uJ)': 12.68, 'Cycles': 8192.0},
#  {'Layer': 142, 'Energy (uJ)': 6282.05, 'Cycles': 8388608.0},
#  {'Layer': 143, 'Energy (uJ)': 3455.87, 'Cycles': 16760832.0},
#  {'Layer': 144, 'Energy (uJ)': 34335.42, 'Cycles': 113573888.0}]

# %%
component_energy_by_layer = []
for entry in layer_data:
    layer_index = entry['Layer']
    layer_key = f"{layer_index:02d}"
    total_energy = entry['Energy (uJ)']
    percent_dict = all_layers_percent.get(layer_key, {})
    
    component_energies = {'Layer': layer_index}
    for component, percent in percent_dict.items():
        component_energies[component] = (percent / 100.0) * total_energy
    
    component_energy_by_layer.append(component_energies)

# Convert to DataFrame
df = pd.DataFrame(component_energy_by_layer)
df.set_index('Layer', inplace=True)
df.fillna(0, inplace=True)

# Plot stacked bar chart
from matplotlib import colormaps
import numpy as np
colors = plt.get_cmap('rainbow')(np.linspace(0, 1, df.shape[1]))# You can also use 'Set3', 'nipy_spectral', 'rainbow'
ax = df.plot(kind='bar', stacked=True, figsize=(16, 8), color=colors)

plt.ylabel('Energy (uJ)')
plt.title('Energy Breakdown by Component Across Layers for gpt2')
plt.legend(title='Component', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.grid(axis='y')
plt.show()
