# %%
from _import_scripts import scripts
from scripts.notebook_utils import *
from scripts.tl_output_parsing import MacroOutputStats
from scripts.utils import *
import yaml

MACRO_PATH = "../models/arch/1_macro/basic_analog/" 
macro = {}
total_per_energy = {}
SRAM_PATH = f'"{os.path.abspath("../models/memory_cells/sram_example.cell.yaml")}"'
RRAM_PATH = f'"{os.path.abspath("../models/memory_cells/rram_example.cell.yaml")}"'

dnn_layers = {
    "alexnet": 8,
    "vgg16": 16,
    "dpt_large": 227,
    "gpt2_medium": 145,
    "mobilebert": 409,
    "vision_transformer": 98,
    "resnet18": 21,
    "mobilenet_v3": 64
}

# Define the architecture
array_sizes = 128
path_list = [SRAM_PATH, RRAM_PATH]
tech_node = 22
time = "fast"

dnn_list = ["gpt2_medium"]
for DNN in dnn_list:
    dnn_layer = dnn_layers.get(DNN, None)
    def create_layer_directory(base_output_dir: str, architecture: str, layer: int) -> str:
        layer_dir = os.path.join(base_output_dir, f"{architecture}_layer_{layer}")
        if not os.path.exists(layer_dir):
            os.makedirs(layer_dir)
        return layer_dir

    num_layers = 1

    def run_map(
        spec: tl.Specification,
        arch: str,
        accelergy_verbose: bool = False,
    ) -> dict:
        output_dir = get_run_dir()
        # Just use the directory name if it causes error
        base_output_dir = os.path.dirname(output_dir)
        base_output_dir = os.path.join(base_output_dir, arch)
        global num_layers

        mapper_result = None

        if num_layers < dnn_layer+1:
            # Create a directory for the current layer
            layer_dir = create_layer_directory(base_output_dir, arch, num_layers)
            # print(f"Layer directory: {layer_dir}")
            num_layers += 1

            run_prefix = f"{layer_dir}/timeloop-mapper"
            mapper_result = tl.call_mapper(
                specification=spec,
                output_dir=layer_dir,
                log_to=os.path.join(output_dir, f"{run_prefix}.log"),
            )
            if accelergy_verbose:
                tl.call_accelergy_verbose(
                    specification=spec,
                    output_dir=layer_dir,
                    log_to=os.path.join(output_dir, "accelergy.log"),
                )

        if mapper_result is None:
            # Handle case when mapper_result is not assigned (num_layers >= 17)
            # Raise an error, return a default value
            print("Warning: mapper_result is not assigned. num_layers >= 17")
            return {}

        return MacroOutputStats.from_output_stats(mapper_result)

    import re

    def extract_range(line):
        match = re.search(r'\[(\d+):(\d+)(,\d+)?\)', line)
        if match:
            start = int(match.group(1))
            end = int(match.group(2))
            return end - start
        return None

    def read_and_compute_multiplication(filename, i):
        filename = f"../outputs/{filename}/{filename}_layer_{i+1}/timeloop-mapper.map.txt"
        with open(filename, 'r') as file:
            lines = file.readlines()

        start_searching = False
        ranges = []

        for line in lines:
            # Start searching when 'inter_macro_in_system_spatial' is found
            if "inter_macro_in_system_spatial" in line:
                start_searching = True
            
            # Stop searching if we leave the 'inter_macro_in_system_spatial' section
            elif start_searching and "inter_" in line and "inter_macro_in_system_spatial" not in line:
                break

            # If we are in the 'inter_macro_in_system_spatial' section, look for the ranges
            if start_searching:
                if "for" in line:
                    range_size = extract_range(line)
                    if range_size is not None:
                        ranges.append(range_size)
                elif line.strip() == "":  # Exit the section on an empty line
                    break

        # Compute the multiplication of all ranges, or return 1 if no ranges were found
        if not ranges:
            print(f"All macro: 1")
            return 1

        result = 1
        for size in ranges:
            result *= size
            print(f"Size: {size}")
        print(f"All macro: {result}")
        return result


    def extract_layer_number(folder_name):
        match = re.search(r'layer_(\d+)', folder_name)
        return int(match.group(1)) if match else float('inf')

    def extract_outputs(model):
        
        output_dir = "../outputs/" + model + "/" 
        print(output_dir)

        print ("Model \t Energy/inference (J) \t Area (mm2) \t Throughput (inf/s)")
        #for model in models:    
        throughput = 0   
        energy = 0
        area = 0
        cycles = 0
        folders = sorted([folder for folder in os.listdir(output_dir) if model in folder], key=extract_layer_number)
        area_per_many_macro = 0
        area_layer = 0
        j = 0
        total_sum = 0
        total_adc_area = 0  # Total area for ADC across all layers
        total_other_areas = {}  # Dictionary to store total areas for other components
        total_col_area = 0
        total_row_area = 0
        total_cim_unit_area = 0
        total_area = 0
        total_macro = 0
        
        for folder in folders:
            total = 0
            if model in folder:
                print(f"Processing layer: {folder}")
                # print(folder)
                if os.path.isdir(output_dir + folder):
                    stat_file = output_dir + folder + "/timeloop-mapper.stats.txt"
                    art_file = output_dir + folder + "/timeloop-mapper.ART.yaml"
            
                    with open(stat_file, 'r') as f:
                        energy_stat = [line for line in f if line.startswith("Energy:")][0]
                        energy_uj = energy_stat.split(' ')[1] # uJ
                        energy += float(energy_uj)
                        # print(f"Energy for this layer: {float(energy_uj)} uj")
                    
                    with open(stat_file, 'r') as f:
                        cycle_stat = [line for line in f if line.startswith("Cycles:")][0]                  
                        cycle = cycle_stat.split(' ')[1] 
                        cycles += float(cycle)
                        print(f"Cycle: {cycle}")
                    print(f"Total Cycle: {cycles}")
                        
                if j < dnn_layer:
                    with open(art_file, 'r') as file:
                        data = yaml.safe_load(file)
                    
                        # Extract and print the name, area, number of entries, and ratio for non-zero areas
                    for table in data['ART']['tables']:
                        name = table.get('name')
                        area = table.get('area')
                        if area != 0:
                            # Simplify the name for the output
                            if 'system_top_level.' in name:
                                name = name.split('system_top_level.')[-1]
                            
                            # Extract the number of entries from the name
                            if '[' in name:
                                name_part, entries_part = name.split('[')
                                number_of_entries = entries_part.split('..')[1].replace(']', '')
                                name = name_part.strip()
                            else:
                                number_of_entries = 'Unknown'
                            
                            macro = read_and_compute_multiplication(model, j)
                            # Calculate total ratio
                            if number_of_entries != 'Unknown' and number_of_entries.isdigit():
                                total_ratio = (area / 4096) * macro * int(number_of_entries)
                            else:
                                total_ratio = 0
                            
                            total += total_ratio
                            
                            # Accumulate area for ADC or other components
                            if 'adc' in name.lower():
                                total_adc_area += total_ratio
                            else:
                                if name not in total_other_areas:
                                    total_other_areas[name] = 0
                                total_other_areas[name] += total_ratio
                
                            print(f"{name.replace('_', ' ')} area: {area}, number of {name}: {number_of_entries}, \ntotal {name.replace('_', ' ')} area: ({area}*{number_of_entries}/4096) * macro = {total_ratio}\n")
                    j += 1 
                    total_sum += total
                    total_macro += macro
                    print(f"Total Area for layer {j}: {total}\n")
                    print(f"Total Macro for layer {j}: {total_macro}\n")
                print(f"Total Area for all layers: {total_sum}")
                print(f"Total Area for ADC across all layers: {total_adc_area}")
        
        # Print total area for other components
        for component, area in total_other_areas.items():
            print(f"Total Area for {component.replace('_', ' ')} across all layers: {area}")
            # print(component.replace('_', ' '))
            if component.replace('_', ' ') ==  "column drivers":
                total_col_area = area
            elif component.replace('_', ' ') ==  "row drivers":
                total_row_area = area
            else:
                total_cim_unit_area = area
                                    
        energy *= 1e-6 # conver to J
        total_area = total_sum * 1e-6 # mm2
        throughput = 1 / (cycles * 1e-9) # s
       
        total_adc_area = total_adc_area * 1e-6 # mm2
        total_col_area = total_col_area * 1e-6 # mm2
        total_row_area = total_row_area * 1e-6 # mm2
        total_cim_unit_area = total_cim_unit_area * 1e-6 # mm2
        print("\n")
        print(f"Total Area for ADC across all layers: {total_adc_area}")
        print(f"Total Area for column driver across all layers: {total_col_area}")
        print(f"Total Area for row driver across all layers: {total_row_area}")
        print(f"Total Area for cim unit across all layers: {total_cim_unit_area}")
        print(f"Total Macro across all layers: {total_macro}")
        print ("{} \t {:.2e} \t {:.2f} \t {:.2e}".format(model, energy, total_area, throughput))
        
        return total_area, total_adc_area, total_col_area, total_row_area, total_cim_unit_area, total_macro, energy, throughput

    
##----------------------------------------- Running DNN -------------------------------------------

    for path in path_list:
        arch = f"{path.split('/')[-1].split('_')[0].upper()}_{DNN}_{array_sizes}_cycle9"
        print(f"\nRunning {DNN} with {array_sizes} x {array_sizes} {path.split('/')[-1].split('_')[0].upper()} with {tech_node} nm in {time} scenario")

        num_layers = 1

        def run_dnn(dnn: str, layer: str, array_sizes: int, variables):
            print(f"{layer} ", end="", flush=True)
            spec = get_spec(
                "basic_analog",
                # Weight-stationary, dummy buffer on top to hold inputs & outputs, many
                # macros to ensure we can fit all weights.
                system="ws_dummy_buffer_many_macro",
                # Set the DNN and layer
                dnn=dnn,
                layer=layer,
            )
        
            # Do NOT generate a maximum-utilization workload; we're running a DNN
            # workload.
            spec.variables["MAX_UTILIZATION"] = False
        
            # Use a larger array to ensure we can fit all weights
            spec.architecture.find("column").spatial.meshX = array_sizes
            spec.architecture.find("row").spatial.meshY = array_sizes
        
            spec.variables.update(variables)
            output_stats = run_map(spec, arch)
            
            # Print computes for the layer
            macro_output_stats = MacroOutputStats.from_output_stats(output_stats)
            print(f"Computes for layer {int(layer) + 1}: {macro_output_stats.computes}")
            global macro
            macro[layer] = macro_output_stats.computes
            return output_stats
        
        layers = [f for f in os.listdir(f"../models/workloads/{DNN}") if f != "index.yaml" and f.endswith(".yaml")]
        layers = sorted(layers)
        print(f"Running: ", end="")
        
        # Parallel/Delayed is used to multiprocess. Equivalent to running the following
        # code in serial:
        results = joblib.Parallel(n_jobs=None)(
            joblib.delayed(run_dnn)(DNN, layer.split(".")[0], array_sizes, 
                                    {
                                        "CELL_CONFIG": path,
                                        "BITS_PER_CELL": 1 if path == SRAM_PATH else 4,
                                        "CIM_UNIT_WIDTH_CELLS": 4 if path == SRAM_PATH else 1,
                                        "IS_SRAM": path == SRAM_PATH,
                                        "TECHNOLOGY": tech_node,
                                        "ADC_RESOLUTION": 5,
                                        "GLOBAL_CYCLE_SECONDS": 1e-9 if time == "fast" else 1e-4,
                                    }
                                    ) for layer in layers
        )
        print("")
        for r in results:
            r.clear_zero_energies()
        
        #Initialize overall_energy
        energy_layer = [0] * 16
        result = 0
        
        total_adc_energy = 0.0
        total_col_energy = 0.0
        total_row_energy = 0.0
        total_cim_unit_energy = 0.0
        # Calculate overall energy
        for r in results:
        
            per_component_energy = r.per_compute("per_component_energy")
            total_energy_per_layer = sum(per_component_energy.values()) * 1e15  # Convert to fJ
            total_adc_energy += per_component_energy.get('adc', 0.0)
            total_col_energy += per_component_energy.get('column_drivers', 0.0)
            total_row_energy += per_component_energy.get('row_drivers', 0.0)
            total_cim_unit_energy += per_component_energy.get('cim_unit', 0.0)
        
            total_adc_energy = total_adc_energy * 1e15
            total_col_energy = total_col_energy * 1e15
            total_row_energy = total_row_energy * 1e15
            total_cim_unit_energy = total_cim_unit_energy * 1e15
            total_energy = total_adc_energy + total_col_energy + total_row_energy + total_cim_unit_energy
        
            total_adc_energy = total_adc_energy/total_energy
            total_col_energy = total_col_energy/total_energy
            total_row_energy = total_row_energy/total_energy
            total_cim_unit_energy = total_cim_unit_energy/total_energy

            total_per_energy[(DNN, path)] = [total_adc_energy, total_col_energy, total_row_energy, total_cim_unit_energy]
            
        # Display overall energy
        print(f"Overall energy for DNN {DNN}: {total_energy} fJ")

        for i in range(4):
            print(f"total_per_energy[{DNN}][{path.split('/')[-1].split('_')[0].upper()}][{i}]: {total_per_energy[(DNN,path)][i]}")
        print() 
        
        # Display an energy breakdown for each layer as a bar chart. Display normalized per-MAC and per-layer energy.
        fig, ax = plt.subplots(figsize=(20, 5))
        
        bar_stacked(
            {i: r.per_compute("per_component_energy") * 1e15 for i, r in enumerate(results)},
            title= f"Using {path.split('/')[-1].split('_')[0].upper()} on {array_sizes} x {array_sizes} array sizes, {tech_node} nm running {DNN}",
            xlabel="Layer",
            ylabel="Energy (fJ/MAC)",
            ax=ax,
        )
# Out:
# Running gpt2_medium with 128 x 128 SRAM with 22 nm in fast scenario
# Running: 000 Computes for layer 1: 1572864.0
# 001 Computes for layer 2: 524288.0
# 002 Computes for layer 3: 512.0
# 003 Computes for layer 4: 2048.0
# 004 Computes for layer 5: 2097152.0
# 005 Computes for layer 6: 2097152.0
# 006 Computes for layer 7: 1572864.0
# 007 Computes for layer 8: 524288.0
# 008 Computes for layer 9: 512.0
# 009 Computes for layer 10: 2048.0
# 010 Computes for layer 11: 2097152.0
# 011 Computes for layer 12: 2097152.0
# 012 Computes for layer 13: 1572864.0
# 013 Computes for layer 14: 524288.0
# 014 Computes for layer 15: 512.0
# 015 Computes for layer 16: 2048.0
# 016 Computes for layer 17: 2097152.0
# 017 Computes for layer 18: 2097152.0
# 018 Computes for layer 19: 1572864.0
# 019 Computes for layer 20: 524288.0
# 020 Computes for layer 21: 512.0
# 021 Computes for layer 22: 2048.0
# 022 Computes for layer 23: 2097152.0
# 023 Computes for layer 24: 2097152.0
# 024 Computes for layer 25: 1572864.0
# 025 Computes for layer 26: 524288.0
# 026 Computes for layer 27: 512.0
# 027 Computes for layer 28: 2048.0
# 028 Computes for layer 29: 2097152.0
# 029 Computes for layer 30: 2097152.0
# 030 Computes for layer 31: 1572864.0
# 031 Computes for layer 32: 524288.0
# 032 Computes for layer 33: 512.0
# 033 Computes for layer 34: 2048.0
# 034 Computes for layer 35: 2097152.0
# 035 Computes for layer 36: 2097152.0
# 036 Computes for layer 37: 1572864.0
# 037 Computes for layer 38: 524288.0
# 038 Computes for layer 39: 512.0
# 039 Computes for layer 40: 2048.0
# 040 Computes for layer 41: 2097152.0
# 041 Computes for layer 42: 2097152.0
# 042 Computes for layer 43: 1572864.0
# 043 Computes for layer 44: 524288.0
# 044 Computes for layer 45: 512.0
# 045 Computes for layer 46: 2048.0
# 046 Computes for layer 47: 2097152.0
# 047 Computes for layer 48: 2097152.0
# 048 Computes for layer 49: 1572864.0
# 049 Computes for layer 50: 524288.0
# 050 Computes for layer 51: 512.0
# 051 Computes for layer 52: 2048.0
# 052 Computes for layer 53: 2097152.0
# 053 Computes for layer 54: 2097152.0
# 054 Computes for layer 55: 1572864.0
# 055 Computes for layer 56: 524288.0
# 056 Computes for layer 57: 512.0
# 057 Computes for layer 58: 2048.0
# 058 Computes for layer 59: 2097152.0
# 059 Computes for layer 60: 2097152.0
# 060 Computes for layer 61: 1572864.0
# 061 Computes for layer 62: 524288.0
# 062 Computes for layer 63: 512.0
# 063 Computes for layer 64: 2048.0
# 064 Computes for layer 65: 2097152.0
# 065 Computes for layer 66: 2097152.0
# 066 Computes for layer 67: 1572864.0
# 067 Computes for layer 68: 524288.0
# 068 Computes for layer 69: 512.0
# 069 Computes for layer 70: 2048.0
# 070 Computes for layer 71: 2097152.0
# 071 Computes for layer 72: 2097152.0
# 072 Computes for layer 73: 1572864.0
# 073 Computes for layer 74: 524288.0
# 074 Computes for layer 75: 512.0
# 075 Computes for layer 76: 2048.0
# 076 Computes for layer 77: 2097152.0
# 077 Computes for layer 78: 2097152.0
# 078 Computes for layer 79: 1572864.0
# 079 Computes for layer 80: 524288.0
# 080 Computes for layer 81: 512.0
# 081 Computes for layer 82: 2048.0
# 082 Computes for layer 83: 2097152.0
# 083 Computes for layer 84: 2097152.0
# 084 Computes for layer 85: 1572864.0
# 085 Computes for layer 86: 524288.0
# 086 Computes for layer 87: 512.0
# 087 Computes for layer 88: 2048.0
# 088 Computes for layer 89: 2097152.0
# 089 Computes for layer 90: 2097152.0
# 090 Computes for layer 91: 1572864.0
# 091 Computes for layer 92: 524288.0
# 092 Computes for layer 93: 512.0
# 093 Computes for layer 94: 2048.0
# 094 Computes for layer 95: 2097152.0
# 095 Computes for layer 96: 2097152.0
# 096 Computes for layer 97: 1572864.0
# 097 Computes for layer 98: 524288.0
# 098 Computes for layer 99: 512.0
# 099 Computes for layer 100: 2048.0
# 100 Computes for layer 101: 2097152.0
# 101 Computes for layer 102: 2097152.0
# 102 Computes for layer 103: 1572864.0
# 103 Computes for layer 104: 524288.0
# 104 Computes for layer 105: 512.0
# 105 Computes for layer 106: 2048.0
# 106 Computes for layer 107: 2097152.0
# 107 Computes for layer 108: 2097152.0
# 108 Computes for layer 109: 1572864.0
# 109 Computes for layer 110: 524288.0
# 110 Computes for layer 111: 512.0
# 111 Computes for layer 112: 2048.0
# 112 Computes for layer 113: 2097152.0
# 113 Computes for layer 114: 2097152.0
# 114 Computes for layer 115: 1572864.0
# 115 Computes for layer 116: 524288.0
# 116 Computes for layer 117: 512.0
# 117 Computes for layer 118: 2048.0
# 118 Computes for layer 119: 2097152.0
# 119 Computes for layer 120: 2097152.0
# 120 Computes for layer 121: 1572864.0
# 121 Computes for layer 122: 524288.0
# 122 Computes for layer 123: 512.0
# 123 Computes for layer 124: 2048.0
# 124 Computes for layer 125: 2097152.0
# 125 Computes for layer 126: 2097152.0
# 126 Computes for layer 127: 1572864.0
# 127 Computes for layer 128: 524288.0
# 128 Computes for layer 129: 512.0
# 129 Computes for layer 130: 2048.0
# 130 Computes for layer 131: 2097152.0
# 131 Computes for layer 132: 2097152.0
# 132 Computes for layer 133: 1572864.0
# 133 Computes for layer 134: 524288.0
# 134 Computes for layer 135: 512.0
# 135 Computes for layer 136: 2048.0
# 136 Computes for layer 137: 2097152.0
# 137 Computes for layer 138: 2097152.0
# 138 Computes for layer 139: 1572864.0
# 139 Computes for layer 140: 524288.0
# 140 Computes for layer 141: 512.0
# 141 Computes for layer 142: 2048.0
# 142 Computes for layer 143: 2097152.0
# 143 Computes for layer 144: 2097152.0
# 144 Computes for layer 145: 25731584.0
#
# Overall energy for DNN gpt2_medium: 1000000000000016.6 fJ
# total_per_energy[gpt2_medium][SRAM][0]: 0.42987690855820665
# total_per_energy[gpt2_medium][SRAM][1]: 0.0030304797667152815
# total_per_energy[gpt2_medium][SRAM][2]: 0.5670716666086824
# total_per_energy[gpt2_medium][SRAM][3]: 2.094506639570847e-05
#
#
# Running gpt2_medium with 128 x 128 RRAM with 22 nm in fast scenario
# Running: 000 Computes for layer 1: 1572864.0
# 001 Computes for layer 2: 524288.0
# 002 Computes for layer 3: 512.0
# 003 Computes for layer 4: 2048.0
# 004 Computes for layer 5: 2097152.0
# 005 Computes for layer 6: 2097152.0
# 006 Computes for layer 7: 1572864.0
# 007 Computes for layer 8: 524288.0
# 008 Computes for layer 9: 512.0
# 009 Computes for layer 10: 2048.0
# 010 Computes for layer 11: 2097152.0
# 011 Computes for layer 12: 2097152.0
# 012 Computes for layer 13: 1572864.0
# 013 Computes for layer 14: 524288.0
# 014 Computes for layer 15: 512.0
# 015 Computes for layer 16: 2048.0
# 016 Computes for layer 17: 2097152.0
# 017 Computes for layer 18: 2097152.0
# 018 Computes for layer 19: 1572864.0
# 019 Computes for layer 20: 524288.0
# 020 Computes for layer 21: 512.0
# 021 Computes for layer 22: 2048.0
# 022 Computes for layer 23: 2097152.0
# 023 Computes for layer 24: 2097152.0
# 024 Computes for layer 25: 1572864.0
# 025 Computes for layer 26: 524288.0
# 026 Computes for layer 27: 512.0
# 027 Computes for layer 28: 2048.0
# 028 Computes for layer 29: 2097152.0
# 029 Computes for layer 30: 2097152.0
# 030 Computes for layer 31: 1572864.0
# 031 Computes for layer 32: 524288.0
# 032 Computes for layer 33: 512.0
# 033 Computes for layer 34: 2048.0
# 034 Computes for layer 35: 2097152.0
# 035 Computes for layer 36: 2097152.0
# 036 Computes for layer 37: 1572864.0
# 037 Computes for layer 38: 524288.0
# 038 Computes for layer 39: 512.0
# 039 Computes for layer 40: 2048.0
# 040 Computes for layer 41: 2097152.0
# 041 Computes for layer 42: 2097152.0
# 042 Computes for layer 43: 1572864.0
# 043 Computes for layer 44: 524288.0
# 044 Computes for layer 45: 512.0
# 045 Computes for layer 46: 2048.0
# 046 Computes for layer 47: 2097152.0
# 047 Computes for layer 48: 2097152.0
# 048 Computes for layer 49: 1572864.0
# 049 Computes for layer 50: 524288.0
# 050 Computes for layer 51: 512.0
# 051 Computes for layer 52: 2048.0
# 052 Computes for layer 53: 2097152.0
# 053 Computes for layer 54: 2097152.0
# 054 Computes for layer 55: 1572864.0
# 055 Computes for layer 56: 524288.0
# 056 Computes for layer 57: 512.0
# 057 Computes for layer 58: 2048.0
# 058 Computes for layer 59: 2097152.0
# 059 Computes for layer 60: 2097152.0
# 060 Computes for layer 61: 1572864.0
# 061 Computes for layer 62: 524288.0
# 062 Computes for layer 63: 512.0
# 063 Computes for layer 64: 2048.0
# 064 Computes for layer 65: 2097152.0
# 065 Computes for layer 66: 2097152.0
# 066 Computes for layer 67: 1572864.0
# 067 Computes for layer 68: 524288.0
# 068 Computes for layer 69: 512.0
# 069 Computes for layer 70: 2048.0
# 070 Computes for layer 71: 2097152.0
# 071 Computes for layer 72: 2097152.0
# 072 Computes for layer 73: 1572864.0
# 073 Computes for layer 74: 524288.0
# 074 Computes for layer 75: 512.0
# 075 Computes for layer 76: 2048.0
# 076 Computes for layer 77: 2097152.0
# 077 Computes for layer 78: 2097152.0
# 078 Computes for layer 79: 1572864.0
# 079 Computes for layer 80: 524288.0
# 080 Computes for layer 81: 512.0
# 081 Computes for layer 82: 2048.0
# 082 Computes for layer 83: 2097152.0
# 083 Computes for layer 84: 2097152.0
# 084 Computes for layer 85: 1572864.0
# 085 Computes for layer 86: 524288.0
# 086 Computes for layer 87: 512.0
# 087 Computes for layer 88: 2048.0
# 088 Computes for layer 89: 2097152.0
# 089 Computes for layer 90: 2097152.0
# 090 Computes for layer 91: 1572864.0
# 091 Computes for layer 92: 524288.0
# 092 Computes for layer 93: 512.0
# 093 Computes for layer 94: 2048.0
# 094 Computes for layer 95: 2097152.0
# 095 Computes for layer 96: 2097152.0
# 096 Computes for layer 97: 1572864.0
# 097 Computes for layer 98: 524288.0
# 098 Computes for layer 99: 512.0
# 099 Computes for layer 100: 2048.0
# 100 Computes for layer 101: 2097152.0
# 101 Computes for layer 102: 2097152.0
# 102 Computes for layer 103: 1572864.0
# 103 Computes for layer 104: 524288.0
# 104 Computes for layer 105: 512.0
# 105 Computes for layer 106: 2048.0
# 106 Computes for layer 107: 2097152.0
# 107 Computes for layer 108: 2097152.0
# 108 Computes for layer 109: 1572864.0
# 109 Computes for layer 110: 524288.0
# 110 Computes for layer 111: 512.0
# 111 Computes for layer 112: 2048.0
# 112 Computes for layer 113: 2097152.0
# 113 Computes for layer 114: 2097152.0
# 114 Computes for layer 115: 1572864.0
# 115 Computes for layer 116: 524288.0
# 116 Computes for layer 117: 512.0
# 117 Computes for layer 118: 2048.0
# 118 Computes for layer 119: 2097152.0
# 119 Computes for layer 120: 2097152.0
# 120 Computes for layer 121: 1572864.0
# 121 Computes for layer 122: 524288.0
# 122 Computes for layer 123: 512.0
# 123 Computes for layer 124: 2048.0
# 124 Computes for layer 125: 2097152.0
# 125 Computes for layer 126: 2097152.0
# 126 Computes for layer 127: 1572864.0
# 127 Computes for layer 128: 524288.0
# 128 Computes for layer 129: 512.0
# 129 Computes for layer 130: 2048.0
# 130 Computes for layer 131: 2097152.0
# 131 Computes for layer 132: 2097152.0
# 132 Computes for layer 133: 1572864.0
# 133 Computes for layer 134: 524288.0
# 134 Computes for layer 135: 512.0
# 135 Computes for layer 136: 2048.0
# 136 Computes for layer 137: 2097152.0
# 137 Computes for layer 138: 2097152.0
# 138 Computes for layer 139: 1572864.0
# 139 Computes for layer 140: 524288.0
# 140 Computes for layer 141: 512.0
# 141 Computes for layer 142: 2048.0
# 142 Computes for layer 143: 2097152.0
# 143 Computes for layer 144: 2097152.0
# 144 Computes for layer 145: 25731584.0
#
# Overall energy for DNN gpt2_medium: 1000000000000021.0 fJ
# total_per_energy[gpt2_medium][RRAM][0]: 0.34474327628362594
# total_per_energy[gpt2_medium][RRAM][1]: 1.3716381418093363e-16
# total_per_energy[gpt2_medium][RRAM][2]: 0.36430317848410404
# total_per_energy[gpt2_medium][RRAM][3]: 0.2909535452322699

# %%
display_markdown(
    """
### Calculating Area in fast scenario

"""
)

# Initialize lists for each DNN
num_dnns = len(dnn_list)
total_area = [0] * (2 * num_dnns)
total_adc_area = [0] * (2 * num_dnns)
total_col_area = [0] * (2 * num_dnns)
total_row_area = [0] * (2 * num_dnns)
total_cim_unit_area = [0] * (2 * num_dnns)
total_macro = [0] * (2 * num_dnns)
energy = [0] * (2 * num_dnns)
throughput = [0] * (2 * num_dnns)

# Loop through both DNNs and extract their outputs for SRAM and RRAM
for i, dnn in enumerate(dnn_list):
    total_area[2 * i], total_adc_area[2 * i], total_col_area[2 * i], total_row_area[2 * i], total_cim_unit_area[2 * i], total_macro[2 * i], energy[2 * i], throughput[2 * i] = extract_outputs(f"SRAM_{dnn}_{array_sizes}_cycle9")
    
    total_area[2 * i + 1], total_adc_area[2 * i + 1], total_col_area[2 * i + 1], total_row_area[2 * i + 1], total_cim_unit_area[2 * i + 1], total_macro[2 * i + 1], energy[2 * i + 1], throughput[2 * i + 1] = extract_outputs(f"RRAM_{dnn}_{array_sizes}_cycle9")
# Out:
# ### Calculating Area in fast scenario
# ../outputs/SRAM_gpt2_medium_128_cycle9/
# Model 	 Energy/inference (J) 	 Area (mm2) 	 Throughput (inf/s)
# Processing layer: SRAM_gpt2_medium_128_cycle9_layer_1
# Cycle: 256
#
# Total Cycle: 256.0
# Size: 48
# Size: 8
# All macro: 384
# adc area: 36737.2, number of adc: 4096,
# total adc area: (36737.2*4096/4096) * macro = 14107084.799999999
#
# Size: 48
# Size: 8
# All macro: 384
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 178007.04
#
# Size: 48
# Size: 8
# All macro: 384
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 168522.24
#
# Size: 48
# Size: 8
# All macro: 384
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 974420.7052799999
#
# Total Area for layer 1: 15428034.785279999
#
# Total Macro for layer 1: 384
#
# Total Area for all layers: 15428034.785279999
# Total Area for ADC across all layers: 14107084.799999999
# Processing layer: SRAM_gpt2_medium_128_cycle9_layer_2
# Cycle: 256
#
# Total Cycle: 512.0
# Size: 16
# Size: 8
# All macro: 128
# adc area: 36737.2, number of adc: 4096,
# total adc area: (36737.2*4096/4096) * macro = 4702361.6
#
# Size: 16
# Size: 8
# All macro: 128
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 59335.68
#
# Size: 16
# Size: 8
# All macro: 128
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 56174.08
#
# Size: 16
# Size: 8
# All macro: 128
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 324806.90176
#
# Total Area for layer 2: 5142678.261759999
#
# Total Macro for layer 2: 512
#
# Total Area for all layers: 20570713.047039997
# Total Area for ADC across all layers: 18809446.4
# Processing layer: SRAM_gpt2_medium_128_cycle9_layer_3
# Cycle: 16
#
# Total Cycle: 528.0
# Size: 2
# All macro: 2
# adc area: 36737.2, number of adc: 4096,
# total adc area: (36737.2*4096/4096) * macro = 73474.4
#
# Size: 2
# All macro: 2
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 927.12
#
# Size: 2
# All macro: 2
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 877.72
#
# Size: 2
# All macro: 2
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 5075.10784
#
# Total Area for layer 3: 80354.34783999999
#
# Total Macro for layer 3: 514
#
# Total Area for all layers: 20651067.394879997
# Total Area for ADC across all layers: 18882920.799999997
# Processing layer: SRAM_gpt2_medium_128_cycle9_layer_4
# Cycle: 16
#
# Total Cycle: 544.0
# Size: 4
# Size: 2
# All macro: 8
# adc area: 36737.2, number of adc: 4096,
# total adc area: (36737.2*4096/4096) * macro = 293897.6
#
# Size: 4
# Size: 2
# All macro: 8
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 3708.48
#
# Size: 4
# Size: 2
# All macro: 8
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 3510.88
#
# Size: 4
# Size: 2
# All macro: 8
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 20300.43136
#
# Total Area for layer 4: 321417.39135999995
#
# Total Macro for layer 4: 522
#
# Total Area for all layers: 20972484.786239997
# Total Area for ADC across all layers: 19176818.4
# Processing layer: SRAM_gpt2_medium_128_cycle9_layer_5
# Cycle: 256
#
# Total Cycle: 800.0
# Size: 64
# Size: 8
# All macro: 512
# adc area: 36737.2, number of adc: 4096,
# total adc area: (36737.2*4096/4096) * macro = 18809446.4
#
# Size: 64
# Size: 8
# All macro: 512
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 237342.72
#
# Size: 64
# Size: 8
# All macro: 512
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 224696.32
#
# Size: 64
# Size: 8
# All macro: 512
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 1299227.60704
#
# Total Area for layer 5: 20570713.047039997
#
# Total Macro for layer 5: 1034
#
# Total Area for all layers: 41543197.83328
# Total Area for ADC across all layers: 37986264.8
# Processing layer: SRAM_gpt2_medium_128_cycle9_layer_6
# Cycle: 256
#
# Total Cycle: 1056.0
# Size: 16
# Size: 32
# All macro: 512
# adc area: 36737.2, number of adc: 4096,
# total adc area: (36737.2*4096/4096) * macro = 18809446.4
#
# Size: 16
# Size: 32
# All macro: 512
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 237342.72
#
# Size: 16
# Size: 32
# All macro: 512
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 224696.32
#
# Size: 16
# Size: 32
# All macro: 512
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 1299227.60704
#
# Total Area for layer 6: 20570713.047039997
#
# Total Macro for layer 6: 1546
#
# Total Area for all layers: 62113910.88032
# Total Area for ADC across all layers: 56795711.199999996
# Processing layer: SRAM_gpt2_medium_128_cycle9_layer_7
# Cycle: 256
#
# Total Cycle: 1312.0
# Size: 48
# Size: 8
# All macro: 384
# adc area: 36737.2, number of adc: 4096,
# total adc area: (36737.2*4096/4096) * macro = 14107084.799999999
#
# Size: 48
# Size: 8
# All macro: 384
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 178007.04
#
# Size: 48
# Size: 8
# All macro: 384
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 168522.24
#
# Size: 48
# Size: 8
# All macro: 384
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 974420.7052799999
#
# Total Area for layer 7: 15428034.785279999
#
# Total Macro for layer 7: 1930
#
# Total Area for all layers: 77541945.6656
# Total Area for ADC across all layers: 70902796.0
# Processing layer: SRAM_gpt2_medium_128_cycle9_layer_8
# Cycle: 256
#
# Total Cycle: 1568.0
# Size: 16
# Size: 8
# All macro: 128
# adc area: 36737.2, number of adc: 4096,
# total adc area: (36737.2*4096/4096) * macro = 4702361.6
#
# Size: 16
# Size: 8
# All macro: 128
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 59335.68
#
# Size: 16
# Size: 8
# All macro: 128
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 56174.08
#
# Size: 16
# Size: 8
# All macro: 128
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 324806.90176
#
# Total Area for layer 8: 5142678.261759999
#
# Total Macro for layer 8: 2058
#
# Total Area for all layers: 82684623.92736
# Total Area for ADC across all layers: 75605157.6
# Processing layer: SRAM_gpt2_medium_128_cycle9_layer_9
# Cycle: 16
#
# Total Cycle: 1584.0
# Size: 2
# All macro: 2
# adc area: 36737.2, number of adc: 4096,
# total adc area: (36737.2*4096/4096) * macro = 73474.4
#
# Size: 2
# All macro: 2
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 927.12
#
# Size: 2
# All macro: 2
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 877.72
#
# Size: 2
# All macro: 2
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 5075.10784
#
# Total Area for layer 9: 80354.34783999999
#
# Total Macro for layer 9: 2060
#
# Total Area for all layers: 82764978.2752
# Total Area for ADC across all layers: 75678632.0
# Processing layer: SRAM_gpt2_medium_128_cycle9_layer_10
# Cycle: 16
#
# Total Cycle: 1600.0
# Size: 4
# Size: 2
# All macro: 8
# adc area: 36737.2, number of adc: 4096,
# total adc area: (36737.2*4096/4096) * macro = 293897.6
#
# Size: 4
# Size: 2
# All macro: 8
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 3708.48
#
# Size: 4
# Size: 2
# All macro: 8
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 3510.88
#
# Size: 4
# Size: 2
# All macro: 8
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 20300.43136
#
# Total Area for layer 10: 321417.39135999995
#
# Total Macro for layer 10: 2068
#
# Total Area for all layers: 83086395.66656
# Total Area for ADC across all layers: 75972529.6
# Processing layer: SRAM_gpt2_medium_128_cycle9_layer_11
# Cycle: 256
#
# Total Cycle: 1856.0
# Size: 64
# Size: 8
# All macro: 512
# adc area: 36737.2, number of adc: 4096,
# total adc area: (36737.2*4096/4096) * macro = 18809446.4
#
# Size: 64
# Size: 8
# All macro: 512
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 237342.72
#
# Size: 64
# Size: 8
# All macro: 512
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 224696.32
#
# Size: 64
# Size: 8
# All macro: 512
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 1299227.60704
#
# Total Area for layer 11: 20570713.047039997
#
# Total Macro for layer 11: 2580
#
# Total Area for all layers: 103657108.7136
# Total Area for ADC across all layers: 94781976.0
# Processing layer: SRAM_gpt2_medium_128_cycle9_layer_12
# Cycle: 256
#
# Total Cycle: 2112.0
# Size: 16
# Size: 32
# All macro: 512
# adc area: 36737.2, number of adc: 4096,
# total adc area: (36737.2*4096/4096) * macro = 18809446.4
#
# Size: 16
# Size: 32
# All macro: 512
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 237342.72
#
# Size: 16
# Size: 32
# All macro: 512
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 224696.32
#
# Size: 16
# Size: 32
# All macro: 512
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 1299227.60704
#
# Total Area for layer 12: 20570713.047039997
#
# Total Macro for layer 12: 3092
#
# Total Area for all layers: 124227821.76064
# Total Area for ADC across all layers: 113591422.4
# Processing layer: SRAM_gpt2_medium_128_cycle9_layer_13
# Cycle: 256
#
# Total Cycle: 2368.0
# Size: 48
# Size: 8
# All macro: 384
# adc area: 36737.2, number of adc: 4096,
# total adc area: (36737.2*4096/4096) * macro = 14107084.799999999
#
# Size: 48
# Size: 8
# All macro: 384
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 178007.04
#
# Size: 48
# Size: 8
# All macro: 384
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 168522.24
#
# Size: 48
# Size: 8
# All macro: 384
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 974420.7052799999
#
# Total Area for layer 13: 15428034.785279999
#
# Total Macro for layer 13: 3476
#
# Total Area for all layers: 139655856.54591998
# Total Area for ADC across all layers: 127698507.2
# Processing layer: SRAM_gpt2_medium_128_cycle9_layer_14
# Cycle: 256
#
# Total Cycle: 2624.0
# Size: 16
# Size: 8
# All macro: 128
# adc area: 36737.2, number of adc: 4096,
# total adc area: (36737.2*4096/4096) * macro = 4702361.6
#
# Size: 16
# Size: 8
# All macro: 128
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 59335.68
#
# Size: 16
# Size: 8
# All macro: 128
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 56174.08
#
# Size: 16
# Size: 8
# All macro: 128
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 324806.90176
#
# Total Area for layer 14: 5142678.261759999
#
# Total Macro for layer 14: 3604
#
# Total Area for all layers: 144798534.80767998
# Total Area for ADC across all layers: 132400868.8
# Processing layer: SRAM_gpt2_medium_128_cycle9_layer_15
# Cycle: 16
#
# Total Cycle: 2640.0
# Size: 2
# All macro: 2
# adc area: 36737.2, number of adc: 4096,
# total adc area: (36737.2*4096/4096) * macro = 73474.4
#
# Size: 2
# All macro: 2
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 927.12
#
# Size: 2
# All macro: 2
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 877.72
#
# Size: 2
# All macro: 2
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 5075.10784
#
# Total Area for layer 15: 80354.34783999999
#
# Total Macro for layer 15: 3606
#
# Total Area for all layers: 144878889.15552
# Total Area for ADC across all layers: 132474343.2
# Processing layer: SRAM_gpt2_medium_128_cycle9_layer_16
# Cycle: 16
#
# Total Cycle: 2656.0
# Size: 4
# Size: 2
# All macro: 8
# adc area: 36737.2, number of adc: 4096,
# total adc area: (36737.2*4096/4096) * macro = 293897.6
#
# Size: 4
# Size: 2
# All macro: 8
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 3708.48
#
# Size: 4
# Size: 2
# All macro: 8
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 3510.88
#
# Size: 4
# Size: 2
# All macro: 8
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 20300.43136
#
# Total Area for layer 16: 321417.39135999995
#
# Total Macro for layer 16: 3614
#
# Total Area for all layers: 145200306.54688
# Total Area for ADC across all layers: 132768240.8
# Processing layer: SRAM_gpt2_medium_128_cycle9_layer_17
# Cycle: 256
#
# Total Cycle: 2912.0
# Size: 64
# Size: 8
# All macro: 512
# adc area: 36737.2, number of adc: 4096,
# total adc area: (36737.2*4096/4096) * macro = 18809446.4
#
# Size: 64
# Size: 8
# All macro: 512
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 237342.72
#
# Size: 64
# Size: 8
# All macro: 512
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 224696.32
#
# Size: 64
# Size: 8
# All macro: 512
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 1299227.60704
#
# Total Area for layer 17: 20570713.047039997
#
# Total Macro for layer 17: 4126
#
# Total Area for all layers: 165771019.59392
# Total Area for ADC across all layers: 151577687.2
# Processing layer: SRAM_gpt2_medium_128_cycle9_layer_18
# Cycle: 256
#
# Total Cycle: 3168.0
# Size: 16
# Size: 32
# All macro: 512
# adc area: 36737.2, number of adc: 4096,
# total adc area: (36737.2*4096/4096) * macro = 18809446.4
#
# Size: 16
# Size: 32
# All macro: 512
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 237342.72
#
# Size: 16
# Size: 32
# All macro: 512
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 224696.32
#
# Size: 16
# Size: 32
# All macro: 512
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 1299227.60704
#
# Total Area for layer 18: 20570713.047039997
#
# Total Macro for layer 18: 4638
#
# Total Area for all layers: 186341732.64095998
# Total Area for ADC across all layers: 170387133.6
# Processing layer: SRAM_gpt2_medium_128_cycle9_layer_19
# Cycle: 256
#
# Total Cycle: 3424.0
# Size: 48
# Size: 8
# All macro: 384
# adc area: 36737.2, number of adc: 4096,
# total adc area: (36737.2*4096/4096) * macro = 14107084.799999999
#
# Size: 48
# Size: 8
# All macro: 384
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 178007.04
#
# Size: 48
# Size: 8
# All macro: 384
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 168522.24
#
# Size: 48
# Size: 8
# All macro: 384
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 974420.7052799999
#
# Total Area for layer 19: 15428034.785279999
#
# Total Macro for layer 19: 5022
#
# Total Area for all layers: 201769767.42623997
# Total Area for ADC across all layers: 184494218.4
# Processing layer: SRAM_gpt2_medium_128_cycle9_layer_20
# Cycle: 256
#
# Total Cycle: 3680.0
# Size: 16
# Size: 8
# All macro: 128
# adc area: 36737.2, number of adc: 4096,
# total adc area: (36737.2*4096/4096) * macro = 4702361.6
#
# Size: 16
# Size: 8
# All macro: 128
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 59335.68
#
# Size: 16
# Size: 8
# All macro: 128
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 56174.08
#
# Size: 16
# Size: 8
# All macro: 128
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 324806.90176
#
# Total Area for layer 20: 5142678.261759999
#
# Total Macro for layer 20: 5150
#
# Total Area for all layers: 206912445.68799996
# Total Area for ADC across all layers: 189196580.0
# Processing layer: SRAM_gpt2_medium_128_cycle9_layer_21
# Cycle: 16
#
# Total Cycle: 3696.0
# Size: 2
# All macro: 2
# adc area: 36737.2, number of adc: 4096,
# total adc area: (36737.2*4096/4096) * macro = 73474.4
#
# Size: 2
# All macro: 2
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 927.12
#
# Size: 2
# All macro: 2
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 877.72
#
# Size: 2
# All macro: 2
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 5075.10784
#
# Total Area for layer 21: 80354.34783999999
#
# Total Macro for layer 21: 5152
#
# Total Area for all layers: 206992800.03583997
# Total Area for ADC across all layers: 189270054.4
# Processing layer: SRAM_gpt2_medium_128_cycle9_layer_22
# Cycle: 16
#
# Total Cycle: 3712.0
# Size: 4
# Size: 2
# All macro: 8
# adc area: 36737.2, number of adc: 4096,
# total adc area: (36737.2*4096/4096) * macro = 293897.6
#
# Size: 4
# Size: 2
# All macro: 8
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 3708.48
#
# Size: 4
# Size: 2
# All macro: 8
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 3510.88
#
# Size: 4
# Size: 2
# All macro: 8
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 20300.43136
#
# Total Area for layer 22: 321417.39135999995
#
# Total Macro for layer 22: 5160
#
# Total Area for all layers: 207314217.4272
# Total Area for ADC across all layers: 189563952.0
# Processing layer: SRAM_gpt2_medium_128_cycle9_layer_23
# Cycle: 256
#
# Total Cycle: 3968.0
# Size: 64
# Size: 8
# All macro: 512
# adc area: 36737.2, number of adc: 4096,
# total adc area: (36737.2*4096/4096) * macro = 18809446.4
#
# Size: 64
# Size: 8
# All macro: 512
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 237342.72
#
# Size: 64
# Size: 8
# All macro: 512
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 224696.32
#
# Size: 64
# Size: 8
# All macro: 512
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 1299227.60704
#
# Total Area for layer 23: 20570713.047039997
#
# Total Macro for layer 23: 5672
#
# Total Area for all layers: 227884930.47423998
# Total Area for ADC across all layers: 208373398.4
# Processing layer: SRAM_gpt2_medium_128_cycle9_layer_24
# Cycle: 256
#
# Total Cycle: 4224.0
# Size: 16
# Size: 32
# All macro: 512
# adc area: 36737.2, number of adc: 4096,
# total adc area: (36737.2*4096/4096) * macro = 18809446.4
#
# Size: 16
# Size: 32
# All macro: 512
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 237342.72
#
# Size: 16
# Size: 32
# All macro: 512
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 224696.32
#
# Size: 16
# Size: 32
# All macro: 512
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 1299227.60704
#
# Total Area for layer 24: 20570713.047039997
#
# Total Macro for layer 24: 6184
#
# Total Area for all layers: 248455643.52127996
# Total Area for ADC across all layers: 227182844.8
# Processing layer: SRAM_gpt2_medium_128_cycle9_layer_25
# Cycle: 256
#
# Total Cycle: 4480.0
# Size: 48
# Size: 8
# All macro: 384
# adc area: 36737.2, number of adc: 4096,
# total adc area: (36737.2*4096/4096) * macro = 14107084.799999999
#
# Size: 48
# Size: 8
# All macro: 384
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 178007.04
#
# Size: 48
# Size: 8
# All macro: 384
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 168522.24
#
# Size: 48
# Size: 8
# All macro: 384
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 974420.7052799999
#
# Total Area for layer 25: 15428034.785279999
#
# Total Macro for layer 25: 6568
#
# Total Area for all layers: 263883678.30655995
# Total Area for ADC across all layers: 241289929.60000002
# Processing layer: SRAM_gpt2_medium_128_cycle9_layer_26
# Cycle: 256
#
# Total Cycle: 4736.0
# Size: 16
# Size: 8
# All macro: 128
# adc area: 36737.2, number of adc: 4096,
# total adc area: (36737.2*4096/4096) * macro = 4702361.6
#
# Size: 16
# Size: 8
# All macro: 128
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 59335.68
#
# Size: 16
# Size: 8
# All macro: 128
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 56174.08
#
# Size: 16
# Size: 8
# All macro: 128
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 324806.90176
#
# Total Area for layer 26: 5142678.261759999
#
# Total Macro for layer 26: 6696
#
# Total Area for all layers: 269026356.56832
# Total Area for ADC across all layers: 245992291.20000002
# Processing layer: SRAM_gpt2_medium_128_cycle9_layer_27
# Cycle: 16
#
# Total Cycle: 4752.0
# Size: 2
# All macro: 2
# adc area: 36737.2, number of adc: 4096,
# total adc area: (36737.2*4096/4096) * macro = 73474.4
#
# Size: 2
# All macro: 2
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 927.12
#
# Size: 2
# All macro: 2
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 877.72
#
# Size: 2
# All macro: 2
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 5075.10784
#
# Total Area for layer 27: 80354.34783999999
#
# Total Macro for layer 27: 6698
#
# Total Area for all layers: 269106710.91616
# Total Area for ADC across all layers: 246065765.60000002
# Processing layer: SRAM_gpt2_medium_128_cycle9_layer_28
# Cycle: 16
#
# Total Cycle: 4768.0
# Size: 4
# Size: 2
# All macro: 8
# adc area: 36737.2, number of adc: 4096,
# total adc area: (36737.2*4096/4096) * macro = 293897.6
#
# Size: 4
# Size: 2
# All macro: 8
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 3708.48
#
# Size: 4
# Size: 2
# All macro: 8
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 3510.88
#
# Size: 4
# Size: 2
# All macro: 8
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 20300.43136
#
# Total Area for layer 28: 321417.39135999995
#
# Total Macro for layer 28: 6706
#
# Total Area for all layers: 269428128.30752
# Total Area for ADC across all layers: 246359663.20000002
# Processing layer: SRAM_gpt2_medium_128_cycle9_layer_29
# Cycle: 256
#
# Total Cycle: 5024.0
# Size: 64
# Size: 8
# All macro: 512
# adc area: 36737.2, number of adc: 4096,
# total adc area: (36737.2*4096/4096) * macro = 18809446.4
#
# Size: 64
# Size: 8
# All macro: 512
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 237342.72
#
# Size: 64
# Size: 8
# All macro: 512
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 224696.32
#
# Size: 64
# Size: 8
# All macro: 512
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 1299227.60704
#
# Total Area for layer 29: 20570713.047039997
#
# Total Macro for layer 29: 7218
#
# Total Area for all layers: 289998841.35455996
# Total Area for ADC across all layers: 265169109.60000002
# Processing layer: SRAM_gpt2_medium_128_cycle9_layer_30
# Cycle: 256
#
# Total Cycle: 5280.0
# Size: 16
# Size: 32
# All macro: 512
# adc area: 36737.2, number of adc: 4096,
# total adc area: (36737.2*4096/4096) * macro = 18809446.4
#
# Size: 16
# Size: 32
# All macro: 512
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 237342.72
#
# Size: 16
# Size: 32
# All macro: 512
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 224696.32
#
# Size: 16
# Size: 32
# All macro: 512
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 1299227.60704
#
# Total Area for layer 30: 20570713.047039997
#
# Total Macro for layer 30: 7730
#
# Total Area for all layers: 310569554.40159994
# Total Area for ADC across all layers: 283978556.0
# Processing layer: SRAM_gpt2_medium_128_cycle9_layer_31
# Cycle: 256
#
# Total Cycle: 5536.0
# Size: 48
# Size: 8
# All macro: 384
# adc area: 36737.2, number of adc: 4096,
# total adc area: (36737.2*4096/4096) * macro = 14107084.799999999
#
# Size: 48
# Size: 8
# All macro: 384
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 178007.04
#
# Size: 48
# Size: 8
# All macro: 384
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 168522.24
#
# Size: 48
# Size: 8
# All macro: 384
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 974420.7052799999
#
# Total Area for layer 31: 15428034.785279999
#
# Total Macro for layer 31: 8114
#
# Total Area for all layers: 325997589.18687993
# Total Area for ADC across all layers: 298085640.8
# Processing layer: SRAM_gpt2_medium_128_cycle9_layer_32
# Cycle: 256
#
# Total Cycle: 5792.0
# Size: 16
# Size: 8
# All macro: 128
# adc area: 36737.2, number of adc: 4096,
# total adc area: (36737.2*4096/4096) * macro = 4702361.6
#
# Size: 16
# Size: 8
# All macro: 128
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 59335.68
#
# Size: 16
# Size: 8
# All macro: 128
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 56174.08
#
# Size: 16
# Size: 8
# All macro: 128
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 324806.90176
#
# Total Area for layer 32: 5142678.261759999
#
# Total Macro for layer 32: 8242
#
# Total Area for all layers: 331140267.4486399
# Total Area for ADC across all layers: 302788002.40000004
# Processing layer: SRAM_gpt2_medium_128_cycle9_layer_33
# Cycle: 16
#
# Total Cycle: 5808.0
# Size: 2
# All macro: 2
# adc area: 36737.2, number of adc: 4096,
# total adc area: (36737.2*4096/4096) * macro = 73474.4
#
# Size: 2
# All macro: 2
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 927.12
#
# Size: 2
# All macro: 2
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 877.72
#
# Size: 2
# All macro: 2
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 5075.10784
#
# Total Area for layer 33: 80354.34783999999
#
# Total Macro for layer 33: 8244
#
# Total Area for all layers: 331220621.79647994
# Total Area for ADC across all layers: 302861476.8
# Processing layer: SRAM_gpt2_medium_128_cycle9_layer_34
# Cycle: 16
#
# Total Cycle: 5824.0
# Size: 4
# Size: 2
# All macro: 8
# adc area: 36737.2, number of adc: 4096,
# total adc area: (36737.2*4096/4096) * macro = 293897.6
#
# Size: 4
# Size: 2
# All macro: 8
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 3708.48
#
# Size: 4
# Size: 2
# All macro: 8
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 3510.88
#
# Size: 4
# Size: 2
# All macro: 8
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 20300.43136
#
# Total Area for layer 34: 321417.39135999995
#
# Total Macro for layer 34: 8252
#
# Total Area for all layers: 331542039.1878399
# Total Area for ADC across all layers: 303155374.40000004
# Processing layer: SRAM_gpt2_medium_128_cycle9_layer_35
# Cycle: 256
#
# Total Cycle: 6080.0
# Size: 64
# Size: 8
# All macro: 512
# adc area: 36737.2, number of adc: 4096,
# total adc area: (36737.2*4096/4096) * macro = 18809446.4
#
# Size: 64
# Size: 8
# All macro: 512
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 237342.72
#
# Size: 64
# Size: 8
# All macro: 512
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 224696.32
#
# Size: 64
# Size: 8
# All macro: 512
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 1299227.60704
#
# Total Area for layer 35: 20570713.047039997
#
# Total Macro for layer 35: 8764
#
# Total Area for all layers: 352112752.2348799
# Total Area for ADC across all layers: 321964820.8
# Processing layer: SRAM_gpt2_medium_128_cycle9_layer_36
# Cycle: 256
#
# Total Cycle: 6336.0
# Size: 16
# Size: 32
# All macro: 512
# adc area: 36737.2, number of adc: 4096,
# total adc area: (36737.2*4096/4096) * macro = 18809446.4
#
# Size: 16
# Size: 32
# All macro: 512
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 237342.72
#
# Size: 16
# Size: 32
# All macro: 512
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 224696.32
#
# Size: 16
# Size: 32
# All macro: 512
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 1299227.60704
#
# Total Area for layer 36: 20570713.047039997
#
# Total Macro for layer 36: 9276
#
# Total Area for all layers: 372683465.2819199
# Total Area for ADC across all layers: 340774267.2
# Processing layer: SRAM_gpt2_medium_128_cycle9_layer_37
# Cycle: 256
#
# Total Cycle: 6592.0
# Size: 48
# Size: 8
# All macro: 384
# adc area: 36737.2, number of adc: 4096,
# total adc area: (36737.2*4096/4096) * macro = 14107084.799999999
#
# Size: 48
# Size: 8
# All macro: 384
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 178007.04
#
# Size: 48
# Size: 8
# All macro: 384
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 168522.24
#
# Size: 48
# Size: 8
# All macro: 384
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 974420.7052799999
#
# Total Area for layer 37: 15428034.785279999
#
# Total Macro for layer 37: 9660
#
# Total Area for all layers: 388111500.0671999
# Total Area for ADC across all layers: 354881352.0
# Processing layer: SRAM_gpt2_medium_128_cycle9_layer_38
# Cycle: 256
#
# Total Cycle: 6848.0
# Size: 16
# Size: 8
# All macro: 128
# adc area: 36737.2, number of adc: 4096,
# total adc area: (36737.2*4096/4096) * macro = 4702361.6
#
# Size: 16
# Size: 8
# All macro: 128
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 59335.68
#
# Size: 16
# Size: 8
# All macro: 128
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 56174.08
#
# Size: 16
# Size: 8
# All macro: 128
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 324806.90176
#
# Total Area for layer 38: 5142678.261759999
#
# Total Macro for layer 38: 9788
#
# Total Area for all layers: 393254178.3289599
# Total Area for ADC across all layers: 359583713.6
# Processing layer: SRAM_gpt2_medium_128_cycle9_layer_39
# Cycle: 16
#
# Total Cycle: 6864.0
# Size: 2
# All macro: 2
# adc area: 36737.2, number of adc: 4096,
# total adc area: (36737.2*4096/4096) * macro = 73474.4
#
# Size: 2
# All macro: 2
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 927.12
#
# Size: 2
# All macro: 2
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 877.72
#
# Size: 2
# All macro: 2
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 5075.10784
#
# Total Area for layer 39: 80354.34783999999
#
# Total Macro for layer 39: 9790
#
# Total Area for all layers: 393334532.6767999
# Total Area for ADC across all layers: 359657188.0
# Processing layer: SRAM_gpt2_medium_128_cycle9_layer_40
# Cycle: 16
#
# Total Cycle: 6880.0
# Size: 4
# Size: 2
# All macro: 8
# adc area: 36737.2, number of adc: 4096,
# total adc area: (36737.2*4096/4096) * macro = 293897.6
#
# Size: 4
# Size: 2
# All macro: 8
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 3708.48
#
# Size: 4
# Size: 2
# All macro: 8
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 3510.88
#
# Size: 4
# Size: 2
# All macro: 8
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 20300.43136
#
# Total Area for layer 40: 321417.39135999995
#
# Total Macro for layer 40: 9798
#
# Total Area for all layers: 393655950.0681599
# Total Area for ADC across all layers: 359951085.6
# Processing layer: SRAM_gpt2_medium_128_cycle9_layer_41
# Cycle: 256
#
# Total Cycle: 7136.0
# Size: 64
# Size: 8
# All macro: 512
# adc area: 36737.2, number of adc: 4096,
# total adc area: (36737.2*4096/4096) * macro = 18809446.4
#
# Size: 64
# Size: 8
# All macro: 512
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 237342.72
#
# Size: 64
# Size: 8
# All macro: 512
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 224696.32
#
# Size: 64
# Size: 8
# All macro: 512
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 1299227.60704
#
# Total Area for layer 41: 20570713.047039997
#
# Total Macro for layer 41: 10310
#
# Total Area for all layers: 414226663.11519986
# Total Area for ADC across all layers: 378760532.0
# Processing layer: SRAM_gpt2_medium_128_cycle9_layer_42
# Cycle: 256
#
# Total Cycle: 7392.0
# Size: 16
# Size: 32
# All macro: 512
# adc area: 36737.2, number of adc: 4096,
# total adc area: (36737.2*4096/4096) * macro = 18809446.4
#
# Size: 16
# Size: 32
# All macro: 512
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 237342.72
#
# Size: 16
# Size: 32
# All macro: 512
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 224696.32
#
# Size: 16
# Size: 32
# All macro: 512
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 1299227.60704
#
# Total Area for layer 42: 20570713.047039997
#
# Total Macro for layer 42: 10822
#
# Total Area for all layers: 434797376.16223985
# Total Area for ADC across all layers: 397569978.4
# Processing layer: SRAM_gpt2_medium_128_cycle9_layer_43
# Cycle: 256
#
# Total Cycle: 7648.0
# Size: 48
# Size: 8
# All macro: 384
# adc area: 36737.2, number of adc: 4096,
# total adc area: (36737.2*4096/4096) * macro = 14107084.799999999
#
# Size: 48
# Size: 8
# All macro: 384
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 178007.04
#
# Size: 48
# Size: 8
# All macro: 384
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 168522.24
#
# Size: 48
# Size: 8
# All macro: 384
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 974420.7052799999
#
# Total Area for layer 43: 15428034.785279999
#
# Total Macro for layer 43: 11206
#
# Total Area for all layers: 450225410.94751984
# Total Area for ADC across all layers: 411677063.2
# Processing layer: SRAM_gpt2_medium_128_cycle9_layer_44
# Cycle: 256
#
# Total Cycle: 7904.0
# Size: 16
# Size: 8
# All macro: 128
# adc area: 36737.2, number of adc: 4096,
# total adc area: (36737.2*4096/4096) * macro = 4702361.6
#
# Size: 16
# Size: 8
# All macro: 128
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 59335.68
#
# Size: 16
# Size: 8
# All macro: 128
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 56174.08
#
# Size: 16
# Size: 8
# All macro: 128
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 324806.90176
#
# Total Area for layer 44: 5142678.261759999
#
# Total Macro for layer 44: 11334
#
# Total Area for all layers: 455368089.20927984
# Total Area for ADC across all layers: 416379424.8
# Processing layer: SRAM_gpt2_medium_128_cycle9_layer_45
# Cycle: 16
#
# Total Cycle: 7920.0
# Size: 2
# All macro: 2
# adc area: 36737.2, number of adc: 4096,
# total adc area: (36737.2*4096/4096) * macro = 73474.4
#
# Size: 2
# All macro: 2
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 927.12
#
# Size: 2
# All macro: 2
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 877.72
#
# Size: 2
# All macro: 2
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 5075.10784
#
# Total Area for layer 45: 80354.34783999999
#
# Total Macro for layer 45: 11336
#
# Total Area for all layers: 455448443.55711985
# Total Area for ADC across all layers: 416452899.2
# Processing layer: SRAM_gpt2_medium_128_cycle9_layer_46
# Cycle: 16
#
# Total Cycle: 7936.0
# Size: 4
# Size: 2
# All macro: 8
# adc area: 36737.2, number of adc: 4096,
# total adc area: (36737.2*4096/4096) * macro = 293897.6
#
# Size: 4
# Size: 2
# All macro: 8
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 3708.48
#
# Size: 4
# Size: 2
# All macro: 8
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 3510.88
#
# Size: 4
# Size: 2
# All macro: 8
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 20300.43136
#
# Total Area for layer 46: 321417.39135999995
#
# Total Macro for layer 46: 11344
#
# Total Area for all layers: 455769860.94847983
# Total Area for ADC across all layers: 416746796.8
# Processing layer: SRAM_gpt2_medium_128_cycle9_layer_47
# Cycle: 256
#
# Total Cycle: 8192.0
# Size: 64
# Size: 8
# All macro: 512
# adc area: 36737.2, number of adc: 4096,
# total adc area: (36737.2*4096/4096) * macro = 18809446.4
#
# Size: 64
# Size: 8
# All macro: 512
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 237342.72
#
# Size: 64
# Size: 8
# All macro: 512
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 224696.32
#
# Size: 64
# Size: 8
# All macro: 512
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 1299227.60704
#
# Total Area for layer 47: 20570713.047039997
#
# Total Macro for layer 47: 11856
#
# Total Area for all layers: 476340573.9955198
# Total Area for ADC across all layers: 435556243.2
# Processing layer: SRAM_gpt2_medium_128_cycle9_layer_48
# Cycle: 256
#
# Total Cycle: 8448.0
# Size: 16
# Size: 32
# All macro: 512
# adc area: 36737.2, number of adc: 4096,
# total adc area: (36737.2*4096/4096) * macro = 18809446.4
#
# Size: 16
# Size: 32
# All macro: 512
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 237342.72
#
# Size: 16
# Size: 32
# All macro: 512
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 224696.32
#
# Size: 16
# Size: 32
# All macro: 512
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 1299227.60704
#
# Total Area for layer 48: 20570713.047039997
#
# Total Macro for layer 48: 12368
#
# Total Area for all layers: 496911287.0425598
# Total Area for ADC across all layers: 454365689.59999996
# Processing layer: SRAM_gpt2_medium_128_cycle9_layer_49
# Cycle: 256
#
# Total Cycle: 8704.0
# Size: 48
# Size: 8
# All macro: 384
# adc area: 36737.2, number of adc: 4096,
# total adc area: (36737.2*4096/4096) * macro = 14107084.799999999
#
# Size: 48
# Size: 8
# All macro: 384
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 178007.04
#
# Size: 48
# Size: 8
# All macro: 384
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 168522.24
#
# Size: 48
# Size: 8
# All macro: 384
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 974420.7052799999
#
# Total Area for layer 49: 15428034.785279999
#
# Total Macro for layer 49: 12752
#
# Total Area for all layers: 512339321.8278398
# Total Area for ADC across all layers: 468472774.4
# Processing layer: SRAM_gpt2_medium_128_cycle9_layer_50
# Cycle: 256
#
# Total Cycle: 8960.0
# Size: 16
# Size: 8
# All macro: 128
# adc area: 36737.2, number of adc: 4096,
# total adc area: (36737.2*4096/4096) * macro = 4702361.6
#
# Size: 16
# Size: 8
# All macro: 128
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 59335.68
#
# Size: 16
# Size: 8
# All macro: 128
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 56174.08
#
# Size: 16
# Size: 8
# All macro: 128
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 324806.90176
#
# Total Area for layer 50: 5142678.261759999
#
# Total Macro for layer 50: 12880
#
# Total Area for all layers: 517482000.0895998
# Total Area for ADC across all layers: 473175136.0
# Processing layer: SRAM_gpt2_medium_128_cycle9_layer_51
# Cycle: 16
#
# Total Cycle: 8976.0
# Size: 2
# All macro: 2
# adc area: 36737.2, number of adc: 4096,
# total adc area: (36737.2*4096/4096) * macro = 73474.4
#
# Size: 2
# All macro: 2
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 927.12
#
# Size: 2
# All macro: 2
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 877.72
#
# Size: 2
# All macro: 2
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 5075.10784
#
# Total Area for layer 51: 80354.34783999999
#
# Total Macro for layer 51: 12882
#
# Total Area for all layers: 517562354.4374398
# Total Area for ADC across all layers: 473248610.4
# Processing layer: SRAM_gpt2_medium_128_cycle9_layer_52
# Cycle: 16
#
# Total Cycle: 8992.0
# Size: 4
# Size: 2
# All macro: 8
# adc area: 36737.2, number of adc: 4096,
# total adc area: (36737.2*4096/4096) * macro = 293897.6
#
# Size: 4
# Size: 2
# All macro: 8
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 3708.48
#
# Size: 4
# Size: 2
# All macro: 8
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 3510.88
#
# Size: 4
# Size: 2
# All macro: 8
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 20300.43136
#
# Total Area for layer 52: 321417.39135999995
#
# Total Macro for layer 52: 12890
#
# Total Area for all layers: 517883771.8287998
# Total Area for ADC across all layers: 473542508.0
# Processing layer: SRAM_gpt2_medium_128_cycle9_layer_53
# Cycle: 256
#
# Total Cycle: 9248.0
# Size: 64
# Size: 8
# All macro: 512
# adc area: 36737.2, number of adc: 4096,
# total adc area: (36737.2*4096/4096) * macro = 18809446.4
#
# Size: 64
# Size: 8
# All macro: 512
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 237342.72
#
# Size: 64
# Size: 8
# All macro: 512
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 224696.32
#
# Size: 64
# Size: 8
# All macro: 512
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 1299227.60704
#
# Total Area for layer 53: 20570713.047039997
#
# Total Macro for layer 53: 13402
#
# Total Area for all layers: 538454484.8758398
# Total Area for ADC across all layers: 492351954.4
# Processing layer: SRAM_gpt2_medium_128_cycle9_layer_54
# Cycle: 256
#
# Total Cycle: 9504.0
# Size: 16
# Size: 32
# All macro: 512
# adc area: 36737.2, number of adc: 4096,
# total adc area: (36737.2*4096/4096) * macro = 18809446.4
#
# Size: 16
# Size: 32
# All macro: 512
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 237342.72
#
# Size: 16
# Size: 32
# All macro: 512
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 224696.32
#
# Size: 16
# Size: 32
# All macro: 512
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 1299227.60704
#
# Total Area for layer 54: 20570713.047039997
#
# Total Macro for layer 54: 13914
#
# Total Area for all layers: 559025197.9228798
# Total Area for ADC across all layers: 511161400.79999995
# Processing layer: SRAM_gpt2_medium_128_cycle9_layer_55
# Cycle: 256
#
# Total Cycle: 9760.0
# Size: 48
# Size: 8
# All macro: 384
# adc area: 36737.2, number of adc: 4096,
# total adc area: (36737.2*4096/4096) * macro = 14107084.799999999
#
# Size: 48
# Size: 8
# All macro: 384
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 178007.04
#
# Size: 48
# Size: 8
# All macro: 384
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 168522.24
#
# Size: 48
# Size: 8
# All macro: 384
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 974420.7052799999
#
# Total Area for layer 55: 15428034.785279999
#
# Total Macro for layer 55: 14298
#
# Total Area for all layers: 574453232.7081598
# Total Area for ADC across all layers: 525268485.59999996
# Processing layer: SRAM_gpt2_medium_128_cycle9_layer_56
# Cycle: 256
#
# Total Cycle: 10016.0
# Size: 16
# Size: 8
# All macro: 128
# adc area: 36737.2, number of adc: 4096,
# total adc area: (36737.2*4096/4096) * macro = 4702361.6
#
# Size: 16
# Size: 8
# All macro: 128
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 59335.68
#
# Size: 16
# Size: 8
# All macro: 128
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 56174.08
#
# Size: 16
# Size: 8
# All macro: 128
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 324806.90176
#
# Total Area for layer 56: 5142678.261759999
#
# Total Macro for layer 56: 14426
#
# Total Area for all layers: 579595910.9699198
# Total Area for ADC across all layers: 529970847.2
# Processing layer: SRAM_gpt2_medium_128_cycle9_layer_57
# Cycle: 16
#
# Total Cycle: 10032.0
# Size: 2
# All macro: 2
# adc area: 36737.2, number of adc: 4096,
# total adc area: (36737.2*4096/4096) * macro = 73474.4
#
# Size: 2
# All macro: 2
# ...
# total adc area: (36737.2*4096/4096) * macro = 4702361.6
#
# Size: 16
# Size: 8
# All macro: 128
# column drivers area: 208.448, number of column_drivers: 4096,
# total column drivers area: (208.448*4096/4096) * macro = 26681.344
#
# Size: 16
# Size: 8
# All macro: 128
# row drivers area: 238.226, number of row_drivers: 4096,
# total row drivers area: (238.226*4096/4096) * macro = 30492.928
#
# Size: 16
# Size: 8
# All macro: 128
# cim unit area: 0.01936, number of cim_unit: 67108864,
# total cim unit area: (0.01936*67108864/4096) * macro = 40600.86272
#
# Total Area for layer 128: 4800136.734719999
#
# Total Macro for layer 128: 32978
#
# Total Area for all layers: 1236710228.4187183
# Total Area for ADC across all layers: 1211519381.5999994
# Processing layer: RRAM_gpt2_medium_128_cycle9_layer_129
# Cycle: 16
#
# Total Cycle: 22704.0
# Size: 2
# All macro: 2
# adc area: 36737.2, number of adc: 4096,
# total adc area: (36737.2*4096/4096) * macro = 73474.4
#
# Size: 2
# All macro: 2
# column drivers area: 208.448, number of column_drivers: 4096,
# total column drivers area: (208.448*4096/4096) * macro = 416.896
#
# Size: 2
# All macro: 2
# row drivers area: 238.226, number of row_drivers: 4096,
# total row drivers area: (238.226*4096/4096) * macro = 476.452
#
# Size: 2
# All macro: 2
# cim unit area: 0.01936, number of cim_unit: 67108864,
# total cim unit area: (0.01936*67108864/4096) * macro = 634.38848
#
# Total Area for layer 129: 75002.13647999999
#
# Total Macro for layer 129: 32980
#
# Total Area for all layers: 1236785230.5551984
# Total Area for ADC across all layers: 1211592855.9999995
# Processing layer: RRAM_gpt2_medium_128_cycle9_layer_130
# Cycle: 16
#
# Total Cycle: 22720.0
# Size: 4
# Size: 2
# All macro: 8
# adc area: 36737.2, number of adc: 4096,
# total adc area: (36737.2*4096/4096) * macro = 293897.6
#
# Size: 4
# Size: 2
# All macro: 8
# column drivers area: 208.448, number of column_drivers: 4096,
# total column drivers area: (208.448*4096/4096) * macro = 1667.584
#
# Size: 4
# Size: 2
# All macro: 8
# row drivers area: 238.226, number of row_drivers: 4096,
# total row drivers area: (238.226*4096/4096) * macro = 1905.808
#
# Size: 4
# Size: 2
# All macro: 8
# cim unit area: 0.01936, number of cim_unit: 67108864,
# total cim unit area: (0.01936*67108864/4096) * macro = 2537.55392
#
# Total Area for layer 130: 300008.54591999995
#
# Total Macro for layer 130: 32988
#
# Total Area for all layers: 1237085239.1011183
# Total Area for ADC across all layers: 1211886753.5999994
# Processing layer: RRAM_gpt2_medium_128_cycle9_layer_131
# Cycle: 256
#
# Total Cycle: 22976.0
# Size: 64
# Size: 8
# All macro: 512
# adc area: 36737.2, number of adc: 4096,
# total adc area: (36737.2*4096/4096) * macro = 18809446.4
#
# Size: 64
# Size: 8
# All macro: 512
# column drivers area: 208.448, number of column_drivers: 4096,
# total column drivers area: (208.448*4096/4096) * macro = 106725.376
#
# Size: 64
# Size: 8
# All macro: 512
# row drivers area: 238.226, number of row_drivers: 4096,
# total row drivers area: (238.226*4096/4096) * macro = 121971.712
#
# Size: 64
# Size: 8
# All macro: 512
# cim unit area: 0.01936, number of cim_unit: 67108864,
# total cim unit area: (0.01936*67108864/4096) * macro = 162403.45088
#
# Total Area for layer 131: 19200546.938879997
#
# Total Macro for layer 131: 33500
#
# Total Area for all layers: 1256285786.0399983
# Total Area for ADC across all layers: 1230696199.9999995
# Processing layer: RRAM_gpt2_medium_128_cycle9_layer_132
# Cycle: 256
#
# Total Cycle: 23232.0
# Size: 16
# Size: 32
# All macro: 512
# adc area: 36737.2, number of adc: 4096,
# total adc area: (36737.2*4096/4096) * macro = 18809446.4
#
# Size: 16
# Size: 32
# All macro: 512
# column drivers area: 208.448, number of column_drivers: 4096,
# total column drivers area: (208.448*4096/4096) * macro = 106725.376
#
# Size: 16
# Size: 32
# All macro: 512
# row drivers area: 238.226, number of row_drivers: 4096,
# total row drivers area: (238.226*4096/4096) * macro = 121971.712
#
# Size: 16
# Size: 32
# All macro: 512
# cim unit area: 0.01936, number of cim_unit: 67108864,
# total cim unit area: (0.01936*67108864/4096) * macro = 162403.45088
#
# Total Area for layer 132: 19200546.938879997
#
# Total Macro for layer 132: 34012
#
# Total Area for all layers: 1275486332.9788783
# Total Area for ADC across all layers: 1249505646.3999996
# Processing layer: RRAM_gpt2_medium_128_cycle9_layer_133
# Cycle: 256
#
# Total Cycle: 23488.0
# Size: 48
# Size: 8
# All macro: 384
# adc area: 36737.2, number of adc: 4096,
# total adc area: (36737.2*4096/4096) * macro = 14107084.799999999
#
# Size: 48
# Size: 8
# All macro: 384
# column drivers area: 208.448, number of column_drivers: 4096,
# total column drivers area: (208.448*4096/4096) * macro = 80044.032
#
# Size: 48
# Size: 8
# All macro: 384
# row drivers area: 238.226, number of row_drivers: 4096,
# total row drivers area: (238.226*4096/4096) * macro = 91478.784
#
# Size: 48
# Size: 8
# All macro: 384
# cim unit area: 0.01936, number of cim_unit: 67108864,
# total cim unit area: (0.01936*67108864/4096) * macro = 121802.58815999998
#
# Total Area for layer 133: 14400410.20416
#
# Total Macro for layer 133: 34396
#
# Total Area for all layers: 1289886743.1830382
# Total Area for ADC across all layers: 1263612731.1999996
# Processing layer: RRAM_gpt2_medium_128_cycle9_layer_134
# Cycle: 256
#
# Total Cycle: 23744.0
# Size: 16
# Size: 8
# All macro: 128
# adc area: 36737.2, number of adc: 4096,
# total adc area: (36737.2*4096/4096) * macro = 4702361.6
#
# Size: 16
# Size: 8
# All macro: 128
# column drivers area: 208.448, number of column_drivers: 4096,
# total column drivers area: (208.448*4096/4096) * macro = 26681.344
#
# Size: 16
# Size: 8
# All macro: 128
# row drivers area: 238.226, number of row_drivers: 4096,
# total row drivers area: (238.226*4096/4096) * macro = 30492.928
#
# Size: 16
# Size: 8
# All macro: 128
# cim unit area: 0.01936, number of cim_unit: 67108864,
# total cim unit area: (0.01936*67108864/4096) * macro = 40600.86272
#
# Total Area for layer 134: 4800136.734719999
#
# Total Macro for layer 134: 34524
#
# Total Area for all layers: 1294686879.9177582
# Total Area for ADC across all layers: 1268315092.7999995
# Processing layer: RRAM_gpt2_medium_128_cycle9_layer_135
# Cycle: 16
#
# Total Cycle: 23760.0
# Size: 2
# All macro: 2
# adc area: 36737.2, number of adc: 4096,
# total adc area: (36737.2*4096/4096) * macro = 73474.4
#
# Size: 2
# All macro: 2
# column drivers area: 208.448, number of column_drivers: 4096,
# total column drivers area: (208.448*4096/4096) * macro = 416.896
#
# Size: 2
# All macro: 2
# row drivers area: 238.226, number of row_drivers: 4096,
# total row drivers area: (238.226*4096/4096) * macro = 476.452
#
# Size: 2
# All macro: 2
# cim unit area: 0.01936, number of cim_unit: 67108864,
# total cim unit area: (0.01936*67108864/4096) * macro = 634.38848
#
# Total Area for layer 135: 75002.13647999999
#
# Total Macro for layer 135: 34526
#
# Total Area for all layers: 1294761882.0542383
# Total Area for ADC across all layers: 1268388567.1999996
# Processing layer: RRAM_gpt2_medium_128_cycle9_layer_136
# Cycle: 16
#
# Total Cycle: 23776.0
# Size: 4
# Size: 2
# All macro: 8
# adc area: 36737.2, number of adc: 4096,
# total adc area: (36737.2*4096/4096) * macro = 293897.6
#
# Size: 4
# Size: 2
# All macro: 8
# column drivers area: 208.448, number of column_drivers: 4096,
# total column drivers area: (208.448*4096/4096) * macro = 1667.584
#
# Size: 4
# Size: 2
# All macro: 8
# row drivers area: 238.226, number of row_drivers: 4096,
# total row drivers area: (238.226*4096/4096) * macro = 1905.808
#
# Size: 4
# Size: 2
# All macro: 8
# cim unit area: 0.01936, number of cim_unit: 67108864,
# total cim unit area: (0.01936*67108864/4096) * macro = 2537.55392
#
# Total Area for layer 136: 300008.54591999995
#
# Total Macro for layer 136: 34534
#
# Total Area for all layers: 1295061890.6001582
# Total Area for ADC across all layers: 1268682464.7999995
# Processing layer: RRAM_gpt2_medium_128_cycle9_layer_137
# Cycle: 256
#
# Total Cycle: 24032.0
# Size: 64
# Size: 8
# All macro: 512
# adc area: 36737.2, number of adc: 4096,
# total adc area: (36737.2*4096/4096) * macro = 18809446.4
#
# Size: 64
# Size: 8
# All macro: 512
# column drivers area: 208.448, number of column_drivers: 4096,
# total column drivers area: (208.448*4096/4096) * macro = 106725.376
#
# Size: 64
# Size: 8
# All macro: 512
# row drivers area: 238.226, number of row_drivers: 4096,
# total row drivers area: (238.226*4096/4096) * macro = 121971.712
#
# Size: 64
# Size: 8
# All macro: 512
# cim unit area: 0.01936, number of cim_unit: 67108864,
# total cim unit area: (0.01936*67108864/4096) * macro = 162403.45088
#
# Total Area for layer 137: 19200546.938879997
#
# Total Macro for layer 137: 35046
#
# Total Area for all layers: 1314262437.5390382
# Total Area for ADC across all layers: 1287491911.1999996
# Processing layer: RRAM_gpt2_medium_128_cycle9_layer_138
# Cycle: 256
#
# Total Cycle: 24288.0
# Size: 16
# Size: 32
# All macro: 512
# adc area: 36737.2, number of adc: 4096,
# total adc area: (36737.2*4096/4096) * macro = 18809446.4
#
# Size: 16
# Size: 32
# All macro: 512
# column drivers area: 208.448, number of column_drivers: 4096,
# total column drivers area: (208.448*4096/4096) * macro = 106725.376
#
# Size: 16
# Size: 32
# All macro: 512
# row drivers area: 238.226, number of row_drivers: 4096,
# total row drivers area: (238.226*4096/4096) * macro = 121971.712
#
# Size: 16
# Size: 32
# All macro: 512
# cim unit area: 0.01936, number of cim_unit: 67108864,
# total cim unit area: (0.01936*67108864/4096) * macro = 162403.45088
#
# Total Area for layer 138: 19200546.938879997
#
# Total Macro for layer 138: 35558
#
# Total Area for all layers: 1333462984.4779181
# Total Area for ADC across all layers: 1306301357.5999997
# Processing layer: RRAM_gpt2_medium_128_cycle9_layer_139
# Cycle: 256
#
# Total Cycle: 24544.0
# Size: 48
# Size: 8
# All macro: 384
# adc area: 36737.2, number of adc: 4096,
# total adc area: (36737.2*4096/4096) * macro = 14107084.799999999
#
# Size: 48
# Size: 8
# All macro: 384
# column drivers area: 208.448, number of column_drivers: 4096,
# total column drivers area: (208.448*4096/4096) * macro = 80044.032
#
# Size: 48
# Size: 8
# All macro: 384
# row drivers area: 238.226, number of row_drivers: 4096,
# total row drivers area: (238.226*4096/4096) * macro = 91478.784
#
# Size: 48
# Size: 8
# All macro: 384
# cim unit area: 0.01936, number of cim_unit: 67108864,
# total cim unit area: (0.01936*67108864/4096) * macro = 121802.58815999998
#
# Total Area for layer 139: 14400410.20416
#
# Total Macro for layer 139: 35942
#
# Total Area for all layers: 1347863394.6820781
# Total Area for ADC across all layers: 1320408442.3999996
# Processing layer: RRAM_gpt2_medium_128_cycle9_layer_140
# Cycle: 256
#
# Total Cycle: 24800.0
# Size: 16
# Size: 8
# All macro: 128
# adc area: 36737.2, number of adc: 4096,
# total adc area: (36737.2*4096/4096) * macro = 4702361.6
#
# Size: 16
# Size: 8
# All macro: 128
# column drivers area: 208.448, number of column_drivers: 4096,
# total column drivers area: (208.448*4096/4096) * macro = 26681.344
#
# Size: 16
# Size: 8
# All macro: 128
# row drivers area: 238.226, number of row_drivers: 4096,
# total row drivers area: (238.226*4096/4096) * macro = 30492.928
#
# Size: 16
# Size: 8
# All macro: 128
# cim unit area: 0.01936, number of cim_unit: 67108864,
# total cim unit area: (0.01936*67108864/4096) * macro = 40600.86272
#
# Total Area for layer 140: 4800136.734719999
#
# Total Macro for layer 140: 36070
#
# Total Area for all layers: 1352663531.416798
# Total Area for ADC across all layers: 1325110803.9999995
# Processing layer: RRAM_gpt2_medium_128_cycle9_layer_141
# Cycle: 16
#
# Total Cycle: 24816.0
# Size: 2
# All macro: 2
# adc area: 36737.2, number of adc: 4096,
# total adc area: (36737.2*4096/4096) * macro = 73474.4
#
# Size: 2
# All macro: 2
# column drivers area: 208.448, number of column_drivers: 4096,
# total column drivers area: (208.448*4096/4096) * macro = 416.896
#
# Size: 2
# All macro: 2
# row drivers area: 238.226, number of row_drivers: 4096,
# total row drivers area: (238.226*4096/4096) * macro = 476.452
#
# Size: 2
# All macro: 2
# cim unit area: 0.01936, number of cim_unit: 67108864,
# total cim unit area: (0.01936*67108864/4096) * macro = 634.38848
#
# Total Area for layer 141: 75002.13647999999
#
# Total Macro for layer 141: 36072
#
# Total Area for all layers: 1352738533.5532782
# Total Area for ADC across all layers: 1325184278.3999996
# Processing layer: RRAM_gpt2_medium_128_cycle9_layer_142
# Cycle: 16
#
# Total Cycle: 24832.0
# Size: 4
# Size: 2
# All macro: 8
# adc area: 36737.2, number of adc: 4096,
# total adc area: (36737.2*4096/4096) * macro = 293897.6
#
# Size: 4
# Size: 2
# All macro: 8
# column drivers area: 208.448, number of column_drivers: 4096,
# total column drivers area: (208.448*4096/4096) * macro = 1667.584
#
# Size: 4
# Size: 2
# All macro: 8
# row drivers area: 238.226, number of row_drivers: 4096,
# total row drivers area: (238.226*4096/4096) * macro = 1905.808
#
# Size: 4
# Size: 2
# All macro: 8
# cim unit area: 0.01936, number of cim_unit: 67108864,
# total cim unit area: (0.01936*67108864/4096) * macro = 2537.55392
#
# Total Area for layer 142: 300008.54591999995
#
# Total Macro for layer 142: 36080
#
# Total Area for all layers: 1353038542.099198
# Total Area for ADC across all layers: 1325478175.9999995
# Processing layer: RRAM_gpt2_medium_128_cycle9_layer_143
# Cycle: 256
#
# Total Cycle: 25088.0
# Size: 64
# Size: 8
# All macro: 512
# adc area: 36737.2, number of adc: 4096,
# total adc area: (36737.2*4096/4096) * macro = 18809446.4
#
# Size: 64
# Size: 8
# All macro: 512
# column drivers area: 208.448, number of column_drivers: 4096,
# total column drivers area: (208.448*4096/4096) * macro = 106725.376
#
# Size: 64
# Size: 8
# All macro: 512
# row drivers area: 238.226, number of row_drivers: 4096,
# total row drivers area: (238.226*4096/4096) * macro = 121971.712
#
# Size: 64
# Size: 8
# All macro: 512
# cim unit area: 0.01936, number of cim_unit: 67108864,
# total cim unit area: (0.01936*67108864/4096) * macro = 162403.45088
#
# Total Area for layer 143: 19200546.938879997
#
# Total Macro for layer 143: 36592
#
# Total Area for all layers: 1372239089.038078
# Total Area for ADC across all layers: 1344287622.3999996
# Processing layer: RRAM_gpt2_medium_128_cycle9_layer_144
# Cycle: 256
#
# Total Cycle: 25344.0
# Size: 16
# Size: 32
# All macro: 512
# adc area: 36737.2, number of adc: 4096,
# total adc area: (36737.2*4096/4096) * macro = 18809446.4
#
# Size: 16
# Size: 32
# All macro: 512
# column drivers area: 208.448, number of column_drivers: 4096,
# total column drivers area: (208.448*4096/4096) * macro = 106725.376
#
# Size: 16
# Size: 32
# All macro: 512
# row drivers area: 238.226, number of row_drivers: 4096,
# total row drivers area: (238.226*4096/4096) * macro = 121971.712
#
# Size: 16
# Size: 32
# All macro: 512
# cim unit area: 0.01936, number of cim_unit: 67108864,
# total cim unit area: (0.01936*67108864/4096) * macro = 162403.45088
#
# Total Area for layer 144: 19200546.938879997
#
# Total Macro for layer 144: 37104
#
# Total Area for all layers: 1391439635.976958
# Total Area for ADC across all layers: 1363097068.7999997
# Processing layer: RRAM_gpt2_medium_128_cycle9_layer_145
# Cycle: 512
#
# Total Cycle: 25856.0
# Size: 786
# Size: 4
# All macro: 3144
# adc area: 36737.2, number of adc: 4096,
# total adc area: (36737.2*4096/4096) * macro = 115501756.8
#
# Size: 786
# Size: 4
# All macro: 3144
# column drivers area: 208.448, number of column_drivers: 4096,
# total column drivers area: (208.448*4096/4096) * macro = 655360.512
#
# Size: 786
# Size: 4
# All macro: 3144
# row drivers area: 238.226, number of row_drivers: 4096,
# total row drivers area: (238.226*4096/4096) * macro = 748982.544
#
# Size: 786
# Size: 4
# All macro: 3144
# cim unit area: 0.01936, number of cim_unit: 67108864,
# total cim unit area: (0.01936*67108864/4096) * macro = 997258.6905599999
#
# Total Area for layer 145: 117903358.54655999
#
# Total Macro for layer 145: 40248
#
# Total Area for all layers: 1509342994.523518
# Total Area for ADC across all layers: 1478598825.5999997
# Total Area for column drivers across all layers: 8389615.103999993
# Total Area for row drivers across all layers: 9588120.048000004
# Total Area for cim unit across all layers: 12766433.771520015
#
#
# Total Area for ADC across all layers: 1478.5988255999996
# Total Area for column driver across all layers: 8.389615103999992
# Total Area for row driver across all layers: 9.588120048000004
# Total Area for cim unit across all layers: 12.766433771520015
# Total Macro across all layers: 40248
# RRAM_gpt2_medium_128_cycle9 	 1.86e-03 	 1509.34 	 3.87e+04

# %%
print("\n### Area and Performance Results ###\n")

for i, dnn in enumerate(dnn_list):
    print(f"Results for {dnn} (SRAM):")
    print(f"  Total Area: {total_area[2 * i]}")
    print(f"  ADC Area: {total_adc_area[2 * i]}")
    print(f"  Column Driver Area: {total_col_area[2 * i]}")
    print(f"  Row Driver Area: {total_row_area[2 * i]}")
    print(f"  CIM Unit Area: {total_cim_unit_area[2 * i]}")
    print(f"  Total Macro: {total_macro[2 * i]}")
    print(f"  Energy: {energy[2 * i]}")
    print(f"  Throughput: {throughput[2 * i]}\n")

    print(f"Results for {dnn} (RRAM):")
    print(f"  Total Area: {total_area[2 * i + 1]}")
    print(f"  ADC Area: {total_adc_area[2 * i + 1]}")
    print(f"  Column Driver Area: {total_col_area[2 * i + 1]}")
    print(f"  Row Driver Area: {total_row_area[2 * i + 1]}")
    print(f"  CIM Unit Area: {total_cim_unit_area[2 * i + 1]}")
    print(f"  Total Macro: {total_macro[2 * i + 1]}")
    print(f"  Energy: {energy[2 * i + 1]}")
    print(f"  Throughput: {throughput[2 * i + 1]}\n")
# Out:
# ### Area and Performance Results ###
#
# Results for gpt2_medium (SRAM):
#   Total Area: 1617.05089593216
#   ADC Area: 1478.5988255999996
#   Column Driver Area: 18.657362879999994
#   Row Driver Area: 17.663237280000025
#   CIM Unit Area: 102.13147017216012
#   Total Macro: 40248
#   Energy: 0.0014993668000000007
#   Throughput: 38675.74257425743
#
# Results for gpt2_medium (RRAM):
#   Total Area: 1509.342994523518
#   ADC Area: 1478.5988255999996
#   Column Driver Area: 8.389615103999992
#   Row Driver Area: 9.588120048000004
#   CIM Unit Area: 12.766433771520015
#   Total Macro: 40248
#   Energy: 0.0018642507999999999
#   Throughput: 38675.74257425743

# %%
import matplotlib.pyplot as plt
import numpy as np

sram_label = "SRAM"
rram_label = "RRAM"

x = np.arange(len(dnn_list))  # Number of DNNs
width = 0.35  # Bar width

# Create figure and axes for three different plots (energy, area, throughput)
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(18, 6))

# Energy Plot
ax1.bar(x - width/2, energy[::2], width, label=sram_label, color='tab:blue')  # SRAM for DNN1, DNN2
ax1.bar(x + width/2, energy[1::2], width, label=rram_label, color='tab:red')  # RRAM for DNN1, DNN2
ax1.set_title("Energy Consumption")
ax1.set_xticks(x)
ax1.set_xticklabels(dnn_list)
ax1.set_xlabel("DNN models")
ax1.set_ylabel("Energy")
ax1.legend()

# Area Plot
ax2.bar(x - width/2, total_area[::2], width, label=sram_label, color='tab:blue')  # SRAM for DNN1, DNN2
ax2.bar(x + width/2, total_area[1::2], width, label=rram_label, color='tab:red')  # RRAM for DNN1, DNN2
ax2.set_title("Area")
ax2.set_xticks(x)
ax2.set_xticklabels(dnn_list)
ax2.set_xlabel("DNN models")
ax2.set_ylabel("Area")
ax2.legend()

# Throughput Plot
ax3.bar(x - width/2, throughput[::2], width, label=sram_label, color='tab:blue')  # SRAM for DNN1, DNN2
ax3.bar(x + width/2, throughput[1::2], width, label=rram_label, color='tab:red')  # RRAM for DNN1, DNN2
ax3.set_title("Throughput")
ax3.set_xticks(x)
ax3.set_xticklabels(dnn_list)
ax3.set_xlabel("DNN models")
ax3.set_ylabel("Throughput")
ax3.legend()

# Adjust layout for better spacing
plt.tight_layout()
plt.show()

# %%
display_markdown(
    """
### Calculating the energy

"""
)

path_list = [SRAM_PATH, RRAM_PATH]  # List of paths
num_dnns = len(dnn_list)  # Get the number of DNN models
num_paths = len(path_list)  # Get the number of paths
num_cases = num_dnns * num_paths  # Total number of cases

# Initialize energy lists dynamically based on the number of cases
total_adc_energy = [0] * (2 * num_dnns)
total_col_energy = [0] * (2 * num_dnns)
total_row_energy = [0] * (2 * num_dnns)
total_cim_unit_energy = [0] * (2 * num_dnns)

# Iterate through all cases dynamically based on `j`
for j in range(2 * num_dnns):  # Now `j` will be 2 * number of DNN models
    # For each DNN model, calculate energy based on the path
    dnn_idx = j // 2  # Determine which DNN model (0 or 1, 2, etc.)
    path_idx = j % 2  # Determine which path (0 for SRAM, 1 for RRAM)

    # Now iterate through each energy category (ADC, Column, Row, CIM Unit)
    for i in range(4):  # Since there are 4 categories (ADC, Column, Row, CIM Unit)
        energy_value = total_per_energy[(dnn_list[dnn_idx], path_list[path_idx])][i] * energy[j]

        if i == 0:
            total_adc_energy[j] = energy_value
        elif i == 1:
            total_col_energy[j] = energy_value
        elif i == 2:
            total_row_energy[j] = energy_value
        else:
            total_cim_unit_energy[j] = energy_value

# Print the results for total energies
print("Total ADC Energy:", total_adc_energy)
print("Total Column Energy:", total_col_energy)
print("Total Row Energy:", total_row_energy)
print("Total CIM Unit Energy:", total_cim_unit_energy)
# Out:
# ### Calculating the energy
# Total ADC Energy: [0.0006445431647788113, 0.0006426879286063707]
# Total Column Energy: [4.54380075028464e-06, 2.5570775031785686e-19]
# Total Row Energy: [0.0008502484301337273, 0.0006791524919315337]
# Total CIM Unit Energy: [3.140433717752096e-08, 0.0005424103794620953]

# %%
import matplotlib.pyplot as plt
import numpy as np
fig, ax = plt.subplots(figsize=(10, 6)) 
path = ['SRAM', 'RRAM']
num_bars = len(dnn_list) * len(path)

x = np.arange(num_bars)

# Stack bars
ax.bar(x, total_cim_unit_energy, label='cim_unit')
ax.bar(x, total_row_energy, bottom=total_cim_unit_energy, label='row_drivers')
ax.bar(x, total_col_energy, bottom=np.array(total_cim_unit_energy) + np.array(total_row_energy), label='column_drivers')
ax.bar(x, total_adc_energy, bottom=np.array(total_cim_unit_energy) + np.array(total_row_energy) + np.array(total_col_energy), label='adc')

# Labels and title
ax.set_title(f"Energy vs Memory Type for {DNN} in fast scenario")
ax.set_xlabel("Memory type")
ax.set_ylabel("Energy (J)")
# Set x-ticks
xtick_labels = [f"{mem}-{dnn}" for dnn in dnn_list for mem in path]
ax.set_xticks(x)
ax.set_xticklabels(xtick_labels)

ax.legend()

# Show plot
plt.show()
