# %%
from _import_scripts import scripts
from scripts.notebook_utils import *
from scripts.tl_output_parsing import MacroOutputStats
from scripts.utils import *
import yaml

MACRO_PATH = "../models/arch/1_macro/basic_analog/" 
macro = {}
total_per_energy = {}
SRAM_PATH = f'"{os.path.abspath("../models/memory_cells/sram_example.cell.yaml")}"'
RRAM_PATH = f'"{os.path.abspath("../models/memory_cells/rram_example.cell.yaml")}"'

dnn_layers = {
    "alexnet": 8,
    "vgg16": 16,
    "dpt_large": 227,
    "gpt2_medium": 145,
    "mobilebert": 409,
    "vision_transformer": 98,
    "resnet18": 21,
    "mobilenet_v3": 64
}

# Define the architecture
array_sizes = 128
path_list = [SRAM_PATH, RRAM_PATH]
tech_node = 22
time = "fast"

dnn_list = ["alexnet", "vgg16", "resnet18", "mobilenet_v3"]
for DNN in dnn_list:
    dnn_layer = dnn_layers.get(DNN, None)
    def create_layer_directory(base_output_dir: str, architecture: str, layer: int) -> str:
        layer_dir = os.path.join(base_output_dir, f"{architecture}_layer_{layer}")
        if not os.path.exists(layer_dir):
            os.makedirs(layer_dir)
        return layer_dir

    num_layers = 1

    def run_map(
        spec: tl.Specification,
        arch: str,
        accelergy_verbose: bool = False,
    ) -> dict:
        output_dir = get_run_dir()
        # Just use the directory name if it causes error
        base_output_dir = os.path.dirname(output_dir)
        base_output_dir = os.path.join(base_output_dir, arch)
        global num_layers

        mapper_result = None

        if num_layers < dnn_layer+1:
            # Create a directory for the current layer
            layer_dir = create_layer_directory(base_output_dir, arch, num_layers)
            # print(f"Layer directory: {layer_dir}")
            num_layers += 1

            run_prefix = f"{layer_dir}/timeloop-mapper"
            mapper_result = tl.call_mapper(
                specification=spec,
                output_dir=layer_dir,
                log_to=os.path.join(output_dir, f"{run_prefix}.log"),
            )
            if accelergy_verbose:
                tl.call_accelergy_verbose(
                    specification=spec,
                    output_dir=layer_dir,
                    log_to=os.path.join(output_dir, "accelergy.log"),
                )

        if mapper_result is None:
            # Handle case when mapper_result is not assigned (num_layers >= 17)
            # Raise an error, return a default value
            print("Warning: mapper_result is not assigned. num_layers >= 17")
            return {}

        return MacroOutputStats.from_output_stats(mapper_result)

    import re

    def extract_range(line):
        match = re.search(r'\[(\d+):(\d+)(,\d+)?\)', line)
        if match:
            start = int(match.group(1))
            end = int(match.group(2))
            return end - start
        return None

    def read_and_compute_multiplication(filename, i):
        filename = f"../outputs/{filename}/{filename}_layer_{i+1}/timeloop-mapper.map.txt"
        with open(filename, 'r') as file:
            lines = file.readlines()

        start_searching = False
        ranges = []

        for line in lines:
            # Start searching when 'inter_macro_in_system_spatial' is found
            if "inter_macro_in_system_spatial" in line:
                start_searching = True
            
            # Stop searching if we leave the 'inter_macro_in_system_spatial' section
            elif start_searching and "inter_" in line and "inter_macro_in_system_spatial" not in line:
                break

            # If we are in the 'inter_macro_in_system_spatial' section, look for the ranges
            if start_searching:
                if "for" in line:
                    range_size = extract_range(line)
                    if range_size is not None:
                        ranges.append(range_size)
                elif line.strip() == "":  # Exit the section on an empty line
                    break

        # Compute the multiplication of all ranges, or return 1 if no ranges were found
        if not ranges:
            print(f"All macro: 1")
            return 1

        result = 1
        for size in ranges:
            result *= size
            print(f"Size: {size}")
        print(f"All macro: {result}")
        return result


    def extract_layer_number(folder_name):
        match = re.search(r'layer_(\d+)', folder_name)
        return int(match.group(1)) if match else float('inf')

    def extract_outputs(model):
        
        output_dir = "../outputs/" + model + "/" 
        print(output_dir)

        print ("Model \t Energy/inference (J) \t Area (mm2) \t Throughput (inf/s)")
        #for model in models:    
        throughput = 0   
        energy = 0
        area = 0
        cycles = 0
        folders = sorted([folder for folder in os.listdir(output_dir) if model in folder], key=extract_layer_number)
        area_per_many_macro = 0
        area_layer = 0
        j = 0
        total_sum = 0
        total_adc_area = 0  # Total area for ADC across all layers
        total_other_areas = {}  # Dictionary to store total areas for other components
        total_col_area = 0
        total_row_area = 0
        total_cim_unit_area = 0
        total_area = 0
        total_macro = 0
        
        for folder in folders:
            total = 0
            if model in folder:
                print(f"Processing layer: {folder}")
                # print(folder)
                if os.path.isdir(output_dir + folder):
                    stat_file = output_dir + folder + "/timeloop-mapper.stats.txt"
                    art_file = output_dir + folder + "/timeloop-mapper.ART.yaml"
            
                    with open(stat_file, 'r') as f:
                        energy_stat = [line for line in f if line.startswith("Energy:")][0]
                        energy_uj = energy_stat.split(' ')[1] # uJ
                        energy += float(energy_uj)
                        # print(f"Energy for this layer: {float(energy_uj)} uj")
                    
                    with open(stat_file, 'r') as f:
                        cycle_stat = [line for line in f if line.startswith("Cycles:")][0]                  
                        cycle = cycle_stat.split(' ')[1] 
                        cycles += float(cycle)
                        print(f"Cycle: {cycle}")
                    print(f"Total Cycle: {cycles}")
                        
                if j < dnn_layer:
                    with open(art_file, 'r') as file:
                        data = yaml.safe_load(file)
                    
                        # Extract and print the name, area, number of entries, and ratio for non-zero areas
                    for table in data['ART']['tables']:
                        name = table.get('name')
                        area = table.get('area')
                        if area != 0:
                            # Simplify the name for the output
                            if 'system_top_level.' in name:
                                name = name.split('system_top_level.')[-1]
                            
                            # Extract the number of entries from the name
                            if '[' in name:
                                name_part, entries_part = name.split('[')
                                number_of_entries = entries_part.split('..')[1].replace(']', '')
                                name = name_part.strip()
                            else:
                                number_of_entries = 'Unknown'
                            
                            macro = read_and_compute_multiplication(model, j)
                            # Calculate total ratio
                            if number_of_entries != 'Unknown' and number_of_entries.isdigit():
                                total_ratio = (area / 4096) * macro * int(number_of_entries)
                            else:
                                total_ratio = 0
                            
                            total += total_ratio
                            
                            # Accumulate area for ADC or other components
                            if 'adc' in name.lower():
                                total_adc_area += total_ratio
                            else:
                                if name not in total_other_areas:
                                    total_other_areas[name] = 0
                                total_other_areas[name] += total_ratio
                
                            print(f"{name.replace('_', ' ')} area: {area}, number of {name}: {number_of_entries}, \ntotal {name.replace('_', ' ')} area: ({area}*{number_of_entries}/4096) * macro = {total_ratio}\n")
                    j += 1 
                    total_sum += total
                    total_macro += macro
                    print(f"Total Area for layer {j}: {total}\n")
                    print(f"Total Macro for layer {j}: {total_macro}\n")
                print(f"Total Area for all layers: {total_sum}")
                print(f"Total Area for ADC across all layers: {total_adc_area}")
        
        # Print total area for other components
        for component, area in total_other_areas.items():
            print(f"Total Area for {component.replace('_', ' ')} across all layers: {area}")
            # print(component.replace('_', ' '))
            if component.replace('_', ' ') ==  "column drivers":
                total_col_area = area
            elif component.replace('_', ' ') ==  "row drivers":
                total_row_area = area
            else:
                total_cim_unit_area = area
                                    
        energy *= 1e-6 # conver to J
        total_area = total_sum * 1e-6 # mm2
        throughput = 1 / (cycles * 1e-7) # s
       
        total_adc_area = total_adc_area * 1e-6 # mm2
        total_col_area = total_col_area * 1e-6 # mm2
        total_row_area = total_row_area * 1e-6 # mm2
        total_cim_unit_area = total_cim_unit_area * 1e-6 # mm2
        print("\n")
        print(f"Total Area for ADC across all layers: {total_adc_area}")
        print(f"Total Area for column driver across all layers: {total_col_area}")
        print(f"Total Area for row driver across all layers: {total_row_area}")
        print(f"Total Area for cim unit across all layers: {total_cim_unit_area}")
        print(f"Total Macro across all layers: {total_macro}")
        print ("{} \t {:.2e} \t {:.2f} \t {:.2e}".format(model, energy, total_area, throughput))
        
        return total_area, total_adc_area, total_col_area, total_row_area, total_cim_unit_area, total_macro, energy, throughput

    
##----------------------------------------- Running DNN -------------------------------------------

    for path in path_list:
        arch = f"{path.split('/')[-1].split('_')[0].upper()}_{DNN}_{array_sizes}_final"
        print(f"\nRunning {DNN} with {array_sizes} x {array_sizes} {path.split('/')[-1].split('_')[0].upper()} with {tech_node} nm in {time} scenario")

        num_layers = 1

        def run_dnn(dnn: str, layer: str, array_sizes: int, variables):
            print(f"{layer} ", end="", flush=True)
            spec = get_spec(
                "basic_analog",
                # Weight-stationary, dummy buffer on top to hold inputs & outputs, many
                # macros to ensure we can fit all weights.
                system="ws_dummy_buffer_many_macro",
                # Set the DNN and layer
                dnn=dnn,
                layer=layer,
            )
        
            # Do NOT generate a maximum-utilization workload; we're running a DNN
            # workload.
            spec.variables["MAX_UTILIZATION"] = False
        
            # Use a larger array to ensure we can fit all weights
            spec.architecture.find("column").spatial.meshX = array_sizes
            spec.architecture.find("row").spatial.meshY = array_sizes
        
            spec.variables.update(variables)
            output_stats = run_map(spec, arch)
            
            # Print computes for the layer
            macro_output_stats = MacroOutputStats.from_output_stats(output_stats)
            print(f"Computes for layer {int(layer) + 1}: {macro_output_stats.computes}")
            global macro
            macro[layer] = macro_output_stats.computes
            return output_stats
        
        layers = [f for f in os.listdir(f"../models/workloads/{DNN}") if f != "index.yaml" and f.endswith(".yaml")]
        layers = sorted(layers)
        print(f"Running: ", end="")
        
        # Parallel/Delayed is used to multiprocess. Equivalent to running the following
        # code in serial:
        results = joblib.Parallel(n_jobs=None)(
            joblib.delayed(run_dnn)(DNN, layer.split(".")[0], array_sizes, 
                                    {
                                        "CELL_CONFIG": path,
                                        "BITS_PER_CELL": 1 if path == SRAM_PATH else 4,
                                        "CIM_UNIT_WIDTH_CELLS": 4 if path == SRAM_PATH else 1,
                                        "IS_SRAM": path == SRAM_PATH,
                                        "TECHNOLOGY": tech_node,
                                        "ADC_RESOLUTION": 5,
                                        "GLOBAL_CYCLE_SECONDS": 1e-7 if time == "fast" else 1e-4,
                                    }
                                    ) for layer in layers
        )
        print("")
        for r in results:
            r.clear_zero_energies()
        
        #Initialize overall_energy
        energy_layer = [0] * 16
        result = 0
        
        total_adc_energy = 0.0
        total_col_energy = 0.0
        total_row_energy = 0.0
        total_cim_unit_energy = 0.0
        # Calculate overall energy
        for r in results:
        
            per_component_energy = r.per_compute("per_component_energy")
            total_energy_per_layer = sum(per_component_energy.values()) * 1e15  # Convert to fJ
            total_adc_energy += per_component_energy.get('adc', 0.0)
            total_col_energy += per_component_energy.get('column_drivers', 0.0)
            total_row_energy += per_component_energy.get('row_drivers', 0.0)
            total_cim_unit_energy += per_component_energy.get('cim_unit', 0.0)
        
            total_adc_energy = total_adc_energy * 1e15
            total_col_energy = total_col_energy * 1e15
            total_row_energy = total_row_energy * 1e15
            total_cim_unit_energy = total_cim_unit_energy * 1e15
            total_energy = total_adc_energy + total_col_energy + total_row_energy + total_cim_unit_energy
        
            total_adc_energy = total_adc_energy/total_energy
            total_col_energy = total_col_energy/total_energy
            total_row_energy = total_row_energy/total_energy
            total_cim_unit_energy = total_cim_unit_energy/total_energy

            total_per_energy[(DNN, path)] = [total_adc_energy, total_col_energy, total_row_energy, total_cim_unit_energy]
            
        # Display overall energy
        print(f"Overall energy for DNN {DNN}: {total_energy} fJ")

        for i in range(4):
            print(f"total_per_energy[{DNN}][{path.split('/')[-1].split('_')[0].upper()}][{i}]: {total_per_energy[(DNN,path)][i]}")
        print() 
        
        # Display an energy breakdown for each layer as a bar chart. Display normalized per-MAC and per-layer energy.
        fig, ax = plt.subplots(figsize=(20, 5))
        
        bar_stacked(
            {i: r.per_compute("per_component_energy") * 1e15 for i, r in enumerate(results)},
            title= f"Using {path.split('/')[-1].split('_')[0].upper()} on {array_sizes} x {array_sizes} array sizes, {tech_node} nm running {DNN}",
            xlabel="Layer",
            ylabel="Energy (fJ/MAC)",
            ax=ax,
        )
# Out:
# Running alexnet with 128 x 128 SRAM with 22 nm in fast scenario
# Running: 0 Computes for layer 1: 137259.375
# 1 Computes for layer 2: 437400.0
# 2 Computes for layer 3: 219024.0
# 3 Computes for layer 4: 292032.0
# 4 Computes for layer 5: 194688.0
# 5 Computes for layer 6: 73728.0
# 6 Computes for layer 7: 32768.0
# 7 Computes for layer 8: 8000.0
#
# Overall energy for DNN alexnet: 1000000000000017.6 fJ
# total_per_energy[alexnet][SRAM][0]: 0.40851353166802373
# total_per_energy[alexnet][SRAM][1]: 0.0028787866325598985
# total_per_energy[alexnet][SRAM][2]: 0.5867241327312558
# total_per_energy[alexnet][SRAM][3]: 0.0018835489681606294
#
#
# Running alexnet with 128 x 128 RRAM with 22 nm in fast scenario
# Running: 0 Computes for layer 1: 137259.375
# 1 Computes for layer 2: 437400.0
# 2 Computes for layer 3: 219024.0
# 3 Computes for layer 4: 292032.0
# 4 Computes for layer 5: 194688.0
# 5 Computes for layer 6: 73728.0
# 6 Computes for layer 7: 32768.0
# 7 Computes for layer 8: 8000.0
#
# Overall energy for DNN alexnet: 1000000000000022.0 fJ
# total_per_energy[alexnet][RRAM][0]: 0.3239130434778429
# total_per_energy[alexnet][RRAM][1]: 1.2913043478244211e-12
# total_per_energy[alexnet][RRAM][2]: 0.37391304347777854
# total_per_energy[alexnet][RRAM][3]: 0.30217391304308727
#
#
# Running vgg16 with 128 x 128 SRAM with 22 nm in fast scenario
# Running: 00 Computes for layer 1: 169344.0
# 01 Computes for layer 2: 3612672.0
# 02 Computes for layer 3: 1806336.0
# 03 Computes for layer 4: 3612672.0
# 04 Computes for layer 5: 1806336.0
# 05 Computes for layer 6: 3612672.0
# 06 Computes for layer 7: 3612672.0
# 07 Computes for layer 8: 1806336.0
# 08 Computes for layer 9: 3612672.0
# 09 Computes for layer 10: 3612672.0
# 10 Computes for layer 11: 903168.0
# 11 Computes for layer 12: 903168.0
# 12 Computes for layer 13: 903168.0
# 13 Computes for layer 14: 200704.0
# 14 Computes for layer 15: 32768.0
# 15 Computes for layer 16: 8000.0
#
# Overall energy for DNN vgg16: 1000000000000017.9 fJ
# total_per_energy[vgg16][SRAM][0]: 0.7533185368079499
# total_per_energy[vgg16][SRAM][1]: 0.0052957168781573825
# total_per_energy[vgg16][SRAM][2]: 0.24061218936863277
# total_per_energy[vgg16][SRAM][3]: 0.0007735569452599225
#
#
# Running vgg16 with 128 x 128 RRAM with 22 nm in fast scenario
# Running: 00 Computes for layer 1: 169344.0
# 01 Computes for layer 2: 3612672.0
# 02 Computes for layer 3: 1806336.0
# 03 Computes for layer 4: 3612672.0
# 04 Computes for layer 5: 1806336.0
# 05 Computes for layer 6: 3612672.0
# 06 Computes for layer 7: 3612672.0
# 07 Computes for layer 8: 1806336.0
# 08 Computes for layer 9: 3612672.0
# 09 Computes for layer 10: 3612672.0
# 10 Computes for layer 11: 903168.0
# 11 Computes for layer 12: 903168.0
# 12 Computes for layer 13: 903168.0
# 13 Computes for layer 14: 200704.0
# 14 Computes for layer 15: 32768.0
# 15 Computes for layer 16: 8000.0
#
# Overall energy for DNN vgg16: 1000000000000022.1 fJ
# total_per_energy[vgg16][RRAM][0]: 0.6836734693857792
# total_per_energy[vgg16][RRAM][1]: 2.7142857142778697e-12
# total_per_energy[vgg16][RRAM][2]: 0.17551020408122425
# total_per_energy[vgg16][RRAM][3]: 0.14081632653028225
#
#
# Running resnet18 with 128 x 128 SRAM with 22 nm in fast scenario
# Running: 00 Computes for layer 1: 230496.0
# 01 Computes for layer 2: 225792.0
# 02 Computes for layer 3: 225792.0
# 03 Computes for layer 4: 225792.0
# 04 Computes for layer 5: 225792.0
# 05 Computes for layer 6: 112896.0
# 06 Computes for layer 7: 225792.0
# 07 Computes for layer 8: 12544.0
# 08 Computes for layer 9: 225792.0
# 09 Computes for layer 10: 225792.0
# 10 Computes for layer 11: 112896.0
# 11 Computes for layer 12: 225792.0
# 12 Computes for layer 13: 12544.0
# 13 Computes for layer 14: 225792.0
# 14 Computes for layer 15: 225792.0
# 15 Computes for layer 16: 112896.0
# 16 Computes for layer 17: 225792.0
# 17 Computes for layer 18: 12544.0
# 18 Computes for layer 19: 225792.0
# 19 Computes for layer 20: 225792.0
# 20 Computes for layer 21: 1000.0
#
# Overall energy for DNN resnet18: 1000000000000019.1 fJ
# total_per_energy[resnet18][SRAM][0]: 0.5026378269699577
# total_per_energy[resnet18][SRAM][1]: 0.0035348107343822245
# total_per_energy[resnet18][SRAM][2]: 0.4924216109747032
# total_per_energy[resnet18][SRAM][3]: 0.0014057513209568973
#
#
# Running resnet18 with 128 x 128 RRAM with 22 nm in fast scenario
# Running: 00 Computes for layer 1: 230496.0
# 01 Computes for layer 2: 225792.0
# 02 Computes for layer 3: 225792.0
# 03 Computes for layer 4: 225792.0
# 04 Computes for layer 5: 225792.0
# 05 Computes for layer 6: 112896.0
# 06 Computes for layer 7: 225792.0
# 07 Computes for layer 8: 12544.0
# 08 Computes for layer 9: 225792.0
# 09 Computes for layer 10: 225792.0
# 10 Computes for layer 11: 112896.0
# 11 Computes for layer 12: 225792.0
# 12 Computes for layer 13: 12544.0
# 13 Computes for layer 14: 225792.0
# 14 Computes for layer 15: 225792.0
# 15 Computes for layer 16: 112896.0
# 16 Computes for layer 17: 225792.0
# 17 Computes for layer 18: 12544.0
# 18 Computes for layer 19: 225792.0
# 19 Computes for layer 20: 225792.0
# 20 Computes for layer 21: 1000.0
#
# Overall energy for DNN resnet18: 1000000000000024.2 fJ
# total_per_energy[resnet18][RRAM][0]: 0.42487046632048175
# total_per_energy[resnet18][RRAM][1]: 1.68739205526468e-12
# total_per_energy[resnet18][RRAM][2]: 0.3333333333327916
# total_per_energy[resnet18][RRAM][3]: 0.2417962003450392
#
#
# Running mobilenet_v3 with 128 x 128 SRAM with 22 nm in fast scenario
# Running: 00 Computes for layer 1: 10584.0
# 01 Computes for layer 2: 3528.0
# 02 Computes for layer 3: 6272.0
# 03 Computes for layer 4: 25088.0
# 04 Computes for layer 5: 3528.0
# 05 Computes for layer 6: 9408.0
# 06 Computes for layer 7: 10584.0
# 07 Computes for layer 8: 3969.0
# 08 Computes for layer 9: 10584.0
# 09 Computes for layer 10: 10584.0
# 10 Computes for layer 11: 2756.25
# 11 Computes for layer 12: 3.375
# 12 Computes for layer 13: 3.375
# 13 Computes for layer 14: 4410.0
# 14 Computes for layer 15: 7350.0
# 15 Computes for layer 16: 4593.75
# 16 Computes for layer 17: 7.5
# 17 Computes for layer 18: 7.5
# 18 Computes for layer 19: 7350.0
# 19 Computes for layer 20: 7350.0
# 20 Computes for layer 21: 4593.75
# 21 Computes for layer 22: 7.5
# 22 Computes for layer 23: 7.5
# 23 Computes for layer 24: 7350.0
# 24 Computes for layer 25: 14700.0
# 25 Computes for layer 26: 826.875
# 26 Computes for layer 27: 7350.0
# 27 Computes for layer 28: 6125.0
# 28 Computes for layer 29: 689.0625
# 29 Computes for layer 30: 6125.0
# 30 Computes for layer 31: 5635.0
# 31 Computes for layer 32: 633.9375
# 32 Computes for layer 33: 5635.0
# 33 Computes for layer 34: 5635.0
# 34 Computes for layer 35: 633.9375
# 35 Computes for layer 36: 5635.0
# 36 Computes for layer 37: 14700.0
# 37 Computes for layer 38: 1653.75
# 38 Computes for layer 39: 112.5
# 39 Computes for layer 40: 112.5
# 40 Computes for layer 41: 20580.0
# 41 Computes for layer 42: 28812.0
# 42 Computes for layer 43: 2315.25
# 43 Computes for layer 44: 220.5
# 44 Computes for layer 45: 220.5
# 45 Computes for layer 46: 28812.0
# 46 Computes for layer 47: 28812.0
# 47 Computes for layer 48: 1607.8125
# 48 Computes for layer 49: 220.5
# 49 Computes for layer 50: 220.5
# 50 Computes for layer 51: 10290.0
# 51 Computes for layer 52: 14700.0
# 52 Computes for layer 53: 2296.875
# 53 Computes for layer 54: 450.0
# 54 Computes for layer 55: 450.0
# 55 Computes for layer 56: 14700.0
# 56 Computes for layer 57: 14700.0
# 57 Computes for layer 58: 2296.875
# 58 Computes for layer 59: 450.0
# 59 Computes for layer 60: 450.0
# 60 Computes for layer 61: 14700.0
# 61 Computes for layer 62: 14700.0
# 62 Computes for layer 63: 2400.0
# 63 Computes for layer 64: 2500.0
#
# Overall energy for DNN mobilenet_v3: 1000000000000016.9 fJ
# total_per_energy[mobilenet_v3][SRAM][0]: 0.37951781977475396
# total_per_energy[mobilenet_v3][SRAM][1]: 0.002667953628565803
# total_per_energy[mobilenet_v3][SRAM][2]: 0.6174245127757769
# total_per_energy[mobilenet_v3][SRAM][3]: 0.0003897138209032989
#
#
# Running mobilenet_v3 with 128 x 128 RRAM with 22 nm in fast scenario
# Running: 00 Computes for layer 1: 10584.0
# 01 Computes for layer 2: 3528.0
# 02 Computes for layer 3: 6272.0
# 03 Computes for layer 4: 25088.0
# 04 Computes for layer 5: 3528.0
# 05 Computes for layer 6: 9408.0
# 06 Computes for layer 7: 10584.0
# 07 Computes for layer 8: 3969.0
# 08 Computes for layer 9: 10584.0
# 09 Computes for layer 10: 10584.0
# 10 Computes for layer 11: 2756.25
# 11 Computes for layer 12: 3.375
# 12 Computes for layer 13: 3.375
# 13 Computes for layer 14: 4410.0
# 14 Computes for layer 15: 7350.0
# 15 Computes for layer 16: 4593.75
# 16 Computes for layer 17: 7.5
# 17 Computes for layer 18: 7.5
# 18 Computes for layer 19: 7350.0
# 19 Computes for layer 20: 7350.0
# 20 Computes for layer 21: 4593.75
# 21 Computes for layer 22: 7.5
# 22 Computes for layer 23: 7.5
# 23 Computes for layer 24: 7350.0
# 24 Computes for layer 25: 14700.0
# 25 Computes for layer 26: 826.875
# 26 Computes for layer 27: 7350.0
# 27 Computes for layer 28: 6125.0
# 28 Computes for layer 29: 689.0625
# 29 Computes for layer 30: 6125.0
# 30 Computes for layer 31: 5635.0
# 31 Computes for layer 32: 633.9375
# 32 Computes for layer 33: 5635.0
# 33 Computes for layer 34: 5635.0
# 34 Computes for layer 35: 633.9375
# 35 Computes for layer 36: 5635.0
# 36 Computes for layer 37: 14700.0
# 37 Computes for layer 38: 1653.75
# 38 Computes for layer 39: 112.5
# 39 Computes for layer 40: 112.5
# 40 Computes for layer 41: 20580.0
# 41 Computes for layer 42: 28812.0
# 42 Computes for layer 43: 2315.25
# 43 Computes for layer 44: 220.5
# 44 Computes for layer 45: 220.5
# 45 Computes for layer 46: 28812.0
# 46 Computes for layer 47: 28812.0
# 47 Computes for layer 48: 1607.8125
# 48 Computes for layer 49: 220.5
# 49 Computes for layer 50: 220.5
# 50 Computes for layer 51: 10290.0
# 51 Computes for layer 52: 14700.0
# 52 Computes for layer 53: 2296.875
# 53 Computes for layer 54: 450.0
# 54 Computes for layer 55: 450.0
# 55 Computes for layer 56: 14700.0
# 56 Computes for layer 57: 14700.0
# 57 Computes for layer 58: 2296.875
# 58 Computes for layer 59: 450.0
# 59 Computes for layer 60: 450.0
# 60 Computes for layer 61: 14700.0
# 61 Computes for layer 62: 14700.0
# 62 Computes for layer 63: 2400.0
# 63 Computes for layer 64: 2500.0
#
# Overall energy for DNN mobilenet_v3: 1000000000000020.9 fJ
# total_per_energy[mobilenet_v3][RRAM][0]: 0.3879559930467373
# total_per_energy[mobilenet_v3][RRAM][1]: 6.1378112335431545e-12
# total_per_energy[mobilenet_v3][RRAM][2]: 0.5072379849450317
# total_per_energy[mobilenet_v3][RRAM][3]: 0.10480602200209324

# %%
display_markdown(
    """
### Calculating Area in fast scenario

"""
)

# Initialize lists for each DNN
num_dnns = len(dnn_list)
total_area = [0] * (2 * num_dnns)
total_adc_area = [0] * (2 * num_dnns)
total_col_area = [0] * (2 * num_dnns)
total_row_area = [0] * (2 * num_dnns)
total_cim_unit_area = [0] * (2 * num_dnns)
total_macro = [0] * (2 * num_dnns)
energy = [0] * (2 * num_dnns)
throughput = [0] * (2 * num_dnns)

# Loop through both DNNs and extract their outputs for SRAM and RRAM
for i, dnn in enumerate(dnn_list):
    total_area[2 * i], total_adc_area[2 * i], total_col_area[2 * i], total_row_area[2 * i], total_cim_unit_area[2 * i], total_macro[2 * i], energy[2 * i], throughput[2 * i] = extract_outputs(f"SRAM_{dnn}_{array_sizes}_final")
    
    total_area[2 * i + 1], total_adc_area[2 * i + 1], total_col_area[2 * i + 1], total_row_area[2 * i + 1], total_cim_unit_area[2 * i + 1], total_macro[2 * i + 1], energy[2 * i + 1], throughput[2 * i + 1] = extract_outputs(f"RRAM_{dnn}_{array_sizes}_final")
# Out:
# ### Calculating Area in fast scenario
# ../outputs/SRAM_alexnet_128_final/
# Model 	 Energy/inference (J) 	 Area (mm2) 	 Throughput (inf/s)
# Processing layer: SRAM_alexnet_128_final_layer_1
# Cycle: 3025
#
# Total Cycle: 3025.0
# Size: 3
# All macro: 3
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 47950.8
#
# Size: 3
# All macro: 3
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 1390.68
#
# Size: 3
# All macro: 3
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 1316.58
#
# Size: 3
# All macro: 3
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 7612.661759999999
#
# Total Area for layer 1: 58270.72176
#
# Total Macro for layer 1: 3
#
# Total Area for all layers: 58270.72176
# Total Area for ADC across all layers: 47950.8
# Processing layer: SRAM_alexnet_128_final_layer_2
# Cycle: 729
#
# Total Cycle: 3754.0
# Size: 3
# Size: 13
# All macro: 39
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 623360.4
#
# Size: 3
# Size: 13
# All macro: 39
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 18078.84
#
# Size: 3
# Size: 13
# All macro: 39
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 17115.54
#
# Size: 3
# Size: 13
# All macro: 39
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 98964.60287999999
#
# Total Area for layer 2: 757519.38288
#
# Total Macro for layer 2: 42
#
# Total Area for all layers: 815790.10464
# Total Area for ADC across all layers: 671311.2000000001
# Processing layer: SRAM_alexnet_128_final_layer_3
# Cycle: 169
#
# Total Cycle: 3923.0
# Size: 6
# Size: 14
# All macro: 84
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 1342622.4000000001
#
# Size: 6
# Size: 14
# All macro: 84
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 38939.04
#
# Size: 6
# Size: 14
# All macro: 84
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 36864.24
#
# Size: 6
# Size: 14
# All macro: 84
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 213154.52928
#
# Total Area for layer 3: 1631580.20928
#
# Total Macro for layer 3: 126
#
# Total Area for all layers: 2447370.31392
# Total Area for ADC across all layers: 2013933.6
# Processing layer: SRAM_alexnet_128_final_layer_4
# Cycle: 169
#
# Total Cycle: 4092.0
# Size: 3
# Size: 3
# Size: 4
# Size: 3
# All macro: 108
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 1726228.8
#
# Size: 3
# Size: 3
# Size: 4
# Size: 3
# All macro: 108
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 50064.48
#
# Size: 3
# Size: 3
# Size: 4
# Size: 3
# All macro: 108
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 47396.880000000005
#
# Size: 3
# Size: 3
# Size: 4
# Size: 3
# All macro: 108
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 274055.82336
#
# Total Area for layer 4: 2097745.98336
#
# Total Macro for layer 4: 234
#
# Total Area for all layers: 4545116.2972800005
# Total Area for ADC across all layers: 3740162.4000000004
# Processing layer: SRAM_alexnet_128_final_layer_5
# Cycle: 169
#
# Total Cycle: 4261.0
# Size: 3
# Size: 3
# Size: 4
# Size: 2
# All macro: 72
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 1150819.2
#
# Size: 3
# Size: 3
# Size: 4
# Size: 2
# All macro: 72
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 33376.32
#
# Size: 3
# Size: 3
# Size: 4
# Size: 2
# All macro: 72
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 31597.920000000002
#
# Size: 3
# Size: 3
# Size: 4
# Size: 2
# All macro: 72
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 182703.88223999998
#
# Total Area for layer 5: 1398497.32224
#
# Total Macro for layer 5: 306
#
# Total Area for all layers: 5943613.61952
# Total Area for ADC across all layers: 4890981.600000001
# Processing layer: SRAM_alexnet_128_final_layer_6
# Cycle: 2
#
# Total Cycle: 4263.0
# Size: 64
# Size: 36
# All macro: 2304
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 36826214.4
#
# Size: 64
# Size: 36
# All macro: 2304
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 1068042.24
#
# Size: 64
# Size: 36
# All macro: 2304
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 1011133.4400000001
#
# Size: 64
# Size: 36
# All macro: 2304
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 5846524.231679999
#
# Total Area for layer 6: 44751914.31168
#
# Total Macro for layer 6: 2610
#
# Total Area for all layers: 50695527.9312
# Total Area for ADC across all layers: 41717196.0
# Processing layer: SRAM_alexnet_128_final_layer_7
# Cycle: 1
#
# Total Cycle: 4264.0
# Size: 64
# Size: 32
# All macro: 2048
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 32734412.8
#
# Size: 64
# Size: 32
# All macro: 2048
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 949370.88
#
# Size: 64
# Size: 32
# All macro: 2048
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 898785.28
#
# Size: 64
# Size: 32
# All macro: 2048
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 5196910.42816
#
# Total Area for layer 7: 39779479.38816
#
# Total Macro for layer 7: 4658
#
# Total Area for all layers: 90475007.31935999
# Total Area for ADC across all layers: 74451608.8
# Processing layer: SRAM_alexnet_128_final_layer_8
# Cycle: 1
#
# Total Cycle: 4265.0
# Size: 16
# Size: 32
# All macro: 512
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 8183603.2
#
# Size: 16
# Size: 32
# All macro: 512
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 237342.72
#
# Size: 16
# Size: 32
# All macro: 512
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 224696.32
#
# Size: 16
# Size: 32
# All macro: 512
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 1299227.60704
#
# Total Area for layer 8: 9944869.84704
#
# Total Macro for layer 8: 5170
#
# Total Area for all layers: 100419877.16639999
# Total Area for ADC across all layers: 82635212.0
# Total Area for column drivers across all layers: 2396605.2
# Total Area for row drivers across all layers: 2268906.2
# Total Area for cim unit across all layers: 13119153.766399998
#
#
# Total Area for ADC across all layers: 82.635212
# Total Area for column driver across all layers: 2.3966052
# Total Area for row driver across all layers: 2.2689062
# Total Area for cim unit across all layers: 13.119153766399998
# Total Macro across all layers: 5170
# SRAM_alexnet_128_final 	 1.30e-05 	 100.42 	 2.34e+03
# ../outputs/RRAM_alexnet_128_final/
# Model 	 Energy/inference (J) 	 Area (mm2) 	 Throughput (inf/s)
# Processing layer: RRAM_alexnet_128_final_layer_1
# Cycle: 3025
#
# Total Cycle: 3025.0
# Size: 3
# All macro: 3
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 47950.8
#
# Size: 3
# All macro: 3
# column drivers area: 208.448, number of column_drivers: 4096,
# total column drivers area: (208.448*4096/4096) * macro = 625.344
#
# Size: 3
# All macro: 3
# row drivers area: 238.226, number of row_drivers: 4096,
# total row drivers area: (238.226*4096/4096) * macro = 714.678
#
# Size: 3
# All macro: 3
# cim unit area: 0.01936, number of cim_unit: 67108864,
# total cim unit area: (0.01936*67108864/4096) * macro = 951.5827199999999
#
# Total Area for layer 1: 50242.40472
#
# Total Macro for layer 1: 3
#
# Total Area for all layers: 50242.40472
# Total Area for ADC across all layers: 47950.8
# Processing layer: RRAM_alexnet_128_final_layer_2
# Cycle: 729
#
# Total Cycle: 3754.0
# Size: 3
# Size: 13
# All macro: 39
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 623360.4
#
# Size: 3
# Size: 13
# All macro: 39
# column drivers area: 208.448, number of column_drivers: 4096,
# total column drivers area: (208.448*4096/4096) * macro = 8129.472000000001
#
# Size: 3
# Size: 13
# All macro: 39
# row drivers area: 238.226, number of row_drivers: 4096,
# total row drivers area: (238.226*4096/4096) * macro = 9290.814
#
# Size: 3
# Size: 13
# All macro: 39
# cim unit area: 0.01936, number of cim_unit: 67108864,
# total cim unit area: (0.01936*67108864/4096) * macro = 12370.575359999999
#
# Total Area for layer 2: 653151.26136
#
# Total Macro for layer 2: 42
#
# Total Area for all layers: 703393.66608
# Total Area for ADC across all layers: 671311.2000000001
# Processing layer: RRAM_alexnet_128_final_layer_3
# Cycle: 169
#
# Total Cycle: 3923.0
# Size: 6
# Size: 14
# All macro: 84
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 1342622.4000000001
#
# Size: 6
# Size: 14
# All macro: 84
# column drivers area: 208.448, number of column_drivers: 4096,
# total column drivers area: (208.448*4096/4096) * macro = 17509.632
#
# Size: 6
# Size: 14
# All macro: 84
# row drivers area: 238.226, number of row_drivers: 4096,
# total row drivers area: (238.226*4096/4096) * macro = 20010.984
#
# Size: 6
# Size: 14
# All macro: 84
# cim unit area: 0.01936, number of cim_unit: 67108864,
# total cim unit area: (0.01936*67108864/4096) * macro = 26644.31616
#
# Total Area for layer 3: 1406787.33216
#
# Total Macro for layer 3: 126
#
# Total Area for all layers: 2110180.99824
# Total Area for ADC across all layers: 2013933.6
# Processing layer: RRAM_alexnet_128_final_layer_4
# Cycle: 169
#
# Total Cycle: 4092.0
# Size: 3
# Size: 3
# Size: 4
# Size: 3
# All macro: 108
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 1726228.8
#
# Size: 3
# Size: 3
# Size: 4
# Size: 3
# All macro: 108
# column drivers area: 208.448, number of column_drivers: 4096,
# total column drivers area: (208.448*4096/4096) * macro = 22512.384000000002
#
# Size: 3
# Size: 3
# Size: 4
# Size: 3
# All macro: 108
# row drivers area: 238.226, number of row_drivers: 4096,
# total row drivers area: (238.226*4096/4096) * macro = 25728.408
#
# Size: 3
# Size: 3
# Size: 4
# Size: 3
# All macro: 108
# cim unit area: 0.01936, number of cim_unit: 67108864,
# total cim unit area: (0.01936*67108864/4096) * macro = 34256.97792
#
# Total Area for layer 4: 1808726.5699200002
#
# Total Macro for layer 4: 234
#
# Total Area for all layers: 3918907.5681600003
# Total Area for ADC across all layers: 3740162.4000000004
# Processing layer: RRAM_alexnet_128_final_layer_5
# Cycle: 169
#
# Total Cycle: 4261.0
# Size: 3
# Size: 3
# Size: 4
# Size: 2
# All macro: 72
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 1150819.2
#
# Size: 3
# Size: 3
# Size: 4
# Size: 2
# All macro: 72
# column drivers area: 208.448, number of column_drivers: 4096,
# total column drivers area: (208.448*4096/4096) * macro = 15008.256000000001
#
# Size: 3
# Size: 3
# Size: 4
# Size: 2
# All macro: 72
# row drivers area: 238.226, number of row_drivers: 4096,
# total row drivers area: (238.226*4096/4096) * macro = 17152.272
#
# Size: 3
# Size: 3
# Size: 4
# Size: 2
# All macro: 72
# cim unit area: 0.01936, number of cim_unit: 67108864,
# total cim unit area: (0.01936*67108864/4096) * macro = 22837.985279999997
#
# Total Area for layer 5: 1205817.71328
#
# Total Macro for layer 5: 306
#
# Total Area for all layers: 5124725.28144
# Total Area for ADC across all layers: 4890981.600000001
# Processing layer: RRAM_alexnet_128_final_layer_6
# Cycle: 2
#
# Total Cycle: 4263.0
# Size: 64
# Size: 36
# All macro: 2304
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 36826214.4
#
# Size: 64
# Size: 36
# All macro: 2304
# column drivers area: 208.448, number of column_drivers: 4096,
# total column drivers area: (208.448*4096/4096) * macro = 480264.19200000004
#
# Size: 64
# Size: 36
# All macro: 2304
# row drivers area: 238.226, number of row_drivers: 4096,
# total row drivers area: (238.226*4096/4096) * macro = 548872.704
#
# Size: 64
# Size: 36
# All macro: 2304
# cim unit area: 0.01936, number of cim_unit: 67108864,
# total cim unit area: (0.01936*67108864/4096) * macro = 730815.5289599999
#
# Total Area for layer 6: 38586166.82496
#
# Total Macro for layer 6: 2610
#
# Total Area for all layers: 43710892.1064
# Total Area for ADC across all layers: 41717196.0
# Processing layer: RRAM_alexnet_128_final_layer_7
# Cycle: 1
#
# Total Cycle: 4264.0
# Size: 64
# Size: 32
# All macro: 2048
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 32734412.8
#
# Size: 64
# Size: 32
# All macro: 2048
# column drivers area: 208.448, number of column_drivers: 4096,
# total column drivers area: (208.448*4096/4096) * macro = 426901.504
#
# Size: 64
# Size: 32
# All macro: 2048
# row drivers area: 238.226, number of row_drivers: 4096,
# total row drivers area: (238.226*4096/4096) * macro = 487886.848
#
# Size: 64
# Size: 32
# All macro: 2048
# cim unit area: 0.01936, number of cim_unit: 67108864,
# total cim unit area: (0.01936*67108864/4096) * macro = 649613.80352
#
# Total Area for layer 7: 34298814.955520004
#
# Total Macro for layer 7: 4658
#
# Total Area for all layers: 78009707.06192
# Total Area for ADC across all layers: 74451608.8
# Processing layer: RRAM_alexnet_128_final_layer_8
# Cycle: 1
#
# Total Cycle: 4265.0
# Size: 16
# Size: 32
# All macro: 512
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 8183603.2
#
# Size: 16
# Size: 32
# All macro: 512
# column drivers area: 208.448, number of column_drivers: 4096,
# total column drivers area: (208.448*4096/4096) * macro = 106725.376
#
# Size: 16
# Size: 32
# All macro: 512
# row drivers area: 238.226, number of row_drivers: 4096,
# total row drivers area: (238.226*4096/4096) * macro = 121971.712
#
# Size: 16
# Size: 32
# All macro: 512
# cim unit area: 0.01936, number of cim_unit: 67108864,
# total cim unit area: (0.01936*67108864/4096) * macro = 162403.45088
#
# Total Area for layer 8: 8574703.738880001
#
# Total Macro for layer 8: 5170
#
# Total Area for all layers: 86584410.8008
# Total Area for ADC across all layers: 82635212.0
# Total Area for column drivers across all layers: 1077676.16
# Total Area for row drivers across all layers: 1231628.4200000002
# Total Area for cim unit across all layers: 1639894.2207999998
#
#
# Total Area for ADC across all layers: 82.635212
# Total Area for column driver across all layers: 1.0776761599999998
# Total Area for row driver across all layers: 1.23162842
# Total Area for cim unit across all layers: 1.6398942207999998
# Total Macro across all layers: 5170
# RRAM_alexnet_128_final 	 1.62e-05 	 86.58 	 2.34e+03
# ../outputs/SRAM_vgg16_128_final/
# Model 	 Energy/inference (J) 	 Area (mm2) 	 Throughput (inf/s)
# Processing layer: SRAM_vgg16_128_final_layer_1
# Cycle: 50176
#
# Total Cycle: 50176.0
# All macro: 1
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 15983.6
#
# All macro: 1
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 463.56
#
# All macro: 1
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 438.86
#
# All macro: 1
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 2537.55392
#
# Total Area for layer 1: 19423.57392
#
# Total Macro for layer 1: 1
#
# Total Area for all layers: 19423.57392
# Total Area for ADC across all layers: 15983.6
# Processing layer: SRAM_vgg16_128_final_layer_2
# Cycle: 50176
#
# Total Cycle: 100352.0
# Size: 5
# All macro: 5
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 79918.0
#
# Size: 5
# All macro: 5
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 2317.8
#
# Size: 5
# All macro: 5
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 2194.3
#
# Size: 5
# All macro: 5
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 12687.7696
#
# Total Area for layer 2: 97117.8696
#
# Total Macro for layer 2: 6
#
# Total Area for all layers: 116541.44352
# Total Area for ADC across all layers: 95901.6
# Processing layer: SRAM_vgg16_128_final_layer_3
# Cycle: 12544
#
# Total Cycle: 112896.0
# Size: 2
# Size: 5
# All macro: 10
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 159836.0
#
# Size: 2
# Size: 5
# All macro: 10
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 4635.6
#
# Size: 2
# Size: 5
# All macro: 10
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 4388.6
#
# Size: 2
# Size: 5
# All macro: 10
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 25375.5392
#
# Total Area for layer 3: 194235.7392
#
# Total Macro for layer 3: 16
#
# Total Area for all layers: 310777.18272000004
# Total Area for ADC across all layers: 255737.6
# Processing layer: SRAM_vgg16_128_final_layer_4
# Cycle: 12544
#
# Total Cycle: 125440.0
# Size: 3
# Size: 3
# Size: 2
# All macro: 18
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 287704.8
#
# Size: 3
# Size: 3
# Size: 2
# All macro: 18
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 8344.08
#
# Size: 3
# Size: 3
# Size: 2
# All macro: 18
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 7899.4800000000005
#
# Size: 3
# Size: 3
# Size: 2
# All macro: 18
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 45675.970559999994
#
# Total Area for layer 4: 349624.33056
#
# Total Macro for layer 4: 34
#
# Total Area for all layers: 660401.5132800001
# Total Area for ADC across all layers: 543442.4
# Processing layer: SRAM_vgg16_128_final_layer_5
# Cycle: 3136
#
# Total Cycle: 128576.0
# Size: 3
# Size: 3
# Size: 4
# All macro: 36
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 575409.6
#
# Size: 3
# Size: 3
# Size: 4
# All macro: 36
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 16688.16
#
# Size: 3
# Size: 3
# Size: 4
# All macro: 36
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 15798.960000000001
#
# Size: 3
# Size: 3
# Size: 4
# All macro: 36
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 91351.94111999999
#
# Total Area for layer 5: 699248.66112
#
# Total Macro for layer 5: 70
#
# Total Area for all layers: 1359650.1744
# Total Area for ADC across all layers: 1118852.0
# Processing layer: SRAM_vgg16_128_final_layer_6
# Cycle: 3136
#
# Total Cycle: 131712.0
# Size: 3
# Size: 3
# Size: 4
# Size: 2
# All macro: 72
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 1150819.2
#
# Size: 3
# Size: 3
# Size: 4
# Size: 2
# All macro: 72
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 33376.32
#
# Size: 3
# Size: 3
# Size: 4
# Size: 2
# All macro: 72
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 31597.920000000002
#
# Size: 3
# Size: 3
# Size: 4
# Size: 2
# All macro: 72
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 182703.88223999998
#
# Total Area for layer 6: 1398497.32224
#
# Total Macro for layer 6: 142
#
# Total Area for all layers: 2758147.4966399996
# Total Area for ADC across all layers: 2269671.2
# Processing layer: SRAM_vgg16_128_final_layer_7
# Cycle: 3136
#
# Total Cycle: 134848.0
# Size: 3
# Size: 3
# Size: 4
# Size: 2
# All macro: 72
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 1150819.2
#
# Size: 3
# Size: 3
# Size: 4
# Size: 2
# All macro: 72
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 33376.32
#
# Size: 3
# Size: 3
# Size: 4
# Size: 2
# All macro: 72
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 31597.920000000002
#
# Size: 3
# Size: 3
# Size: 4
# Size: 2
# All macro: 72
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 182703.88223999998
#
# Total Area for layer 7: 1398497.32224
#
# Total Macro for layer 7: 214
#
# Total Area for all layers: 4156644.818879999
# Total Area for ADC across all layers: 3420490.4000000004
# Processing layer: SRAM_vgg16_128_final_layer_8
# Cycle: 784
#
# Total Cycle: 135632.0
# Size: 3
# Size: 3
# Size: 8
# Size: 2
# All macro: 144
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 2301638.4
#
# Size: 3
# Size: 3
# Size: 8
# Size: 2
# All macro: 144
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 66752.64
#
# Size: 3
# Size: 3
# Size: 8
# Size: 2
# All macro: 144
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 63195.840000000004
#
# Size: 3
# Size: 3
# Size: 8
# Size: 2
# All macro: 144
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 365407.76447999995
#
# Total Area for layer 8: 2796994.64448
#
# Total Macro for layer 8: 358
#
# Total Area for all layers: 6953639.463359999
# Total Area for ADC across all layers: 5722128.800000001
# Processing layer: SRAM_vgg16_128_final_layer_9
# Cycle: 784
#
# Total Cycle: 136416.0
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 4603276.8
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 133505.28
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 126391.68000000001
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 730815.5289599999
#
# Total Area for layer 9: 5593989.28896
#
# Total Macro for layer 9: 646
#
# Total Area for all layers: 12547628.752319999
# Total Area for ADC across all layers: 10325405.600000001
# Processing layer: SRAM_vgg16_128_final_layer_10
# Cycle: 784
#
# Total Cycle: 137200.0
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 4603276.8
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 133505.28
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 126391.68000000001
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 730815.5289599999
#
# Total Area for layer 10: 5593989.28896
#
# Total Macro for layer 10: 934
#
# Total Area for all layers: 18141618.041279998
# Total Area for ADC across all layers: 14928682.400000002
# Processing layer: SRAM_vgg16_128_final_layer_11
# Cycle: 196
#
# Total Cycle: 137396.0
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 4603276.8
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 133505.28
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 126391.68000000001
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 730815.5289599999
#
# Total Area for layer 11: 5593989.28896
#
# Total Macro for layer 11: 1222
#
# Total Area for all layers: 23735607.330239996
# Total Area for ADC across all layers: 19531959.200000003
# Processing layer: SRAM_vgg16_128_final_layer_12
# Cycle: 196
#
# Total Cycle: 137592.0
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 4603276.8
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 133505.28
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 126391.68000000001
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 730815.5289599999
#
# Total Area for layer 12: 5593989.28896
#
# Total Macro for layer 12: 1510
#
# Total Area for all layers: 29329596.619199995
# Total Area for ADC across all layers: 24135236.000000004
# Processing layer: SRAM_vgg16_128_final_layer_13
# Cycle: 196
#
# Total Cycle: 137788.0
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 4603276.8
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 133505.28
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 126391.68000000001
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 730815.5289599999
#
# Total Area for layer 13: 5593989.28896
#
# Total Macro for layer 13: 1798
#
# Total Area for all layers: 34923585.90815999
# Total Area for ADC across all layers: 28738512.800000004
# Processing layer: SRAM_vgg16_128_final_layer_14
# Cycle: 4
#
# Total Cycle: 137792.0
# Size: 64
# Size: 49
# All macro: 3136
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 50124569.6
#
# Size: 64
# Size: 49
# All macro: 3136
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 1453724.16
#
# Size: 64
# Size: 49
# All macro: 3136
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 1376264.96
#
# Size: 64
# Size: 49
# All macro: 3136
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 7957769.093119999
#
# Total Area for layer 14: 60912327.81312
#
# Total Macro for layer 14: 4934
#
# Total Area for all layers: 95835913.72128
# Total Area for ADC across all layers: 78863082.4
# Processing layer: SRAM_vgg16_128_final_layer_15
# Cycle: 1
#
# Total Cycle: 137793.0
# Size: 64
# Size: 32
# All macro: 2048
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 32734412.8
#
# Size: 64
# Size: 32
# All macro: 2048
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 949370.88
#
# Size: 64
# Size: 32
# All macro: 2048
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 898785.28
#
# Size: 64
# Size: 32
# All macro: 2048
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 5196910.42816
#
# Total Area for layer 15: 39779479.38816
#
# Total Macro for layer 15: 6982
#
# Total Area for all layers: 135615393.10944
# Total Area for ADC across all layers: 111597495.2
# Processing layer: SRAM_vgg16_128_final_layer_16
# Cycle: 1
#
# Total Cycle: 137794.0
# Size: 16
# Size: 32
# All macro: 512
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 8183603.2
#
# Size: 16
# Size: 32
# All macro: 512
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 237342.72
#
# Size: 16
# Size: 32
# All macro: 512
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 224696.32
#
# Size: 16
# Size: 32
# All macro: 512
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 1299227.60704
#
# Total Area for layer 16: 9944869.84704
#
# Total Macro for layer 16: 7494
#
# Total Area for all layers: 145560262.95648
# Total Area for ADC across all layers: 119781098.4
# Total Area for column drivers across all layers: 3473918.64
# Total Area for row drivers across all layers: 3288816.8400000003
# Total Area for cim unit across all layers: 19016429.076479997
#
#
# Total Area for ADC across all layers: 119.7810984
# Total Area for column driver across all layers: 3.47391864
# Total Area for row driver across all layers: 3.28881684
# Total Area for cim unit across all layers: 19.016429076479998
# Total Macro across all layers: 7494
# SRAM_vgg16_128_final 	 2.83e-04 	 145.56 	 7.26e+01
# ../outputs/RRAM_vgg16_128_final/
# Model 	 Energy/inference (J) 	 Area (mm2) 	 Throughput (inf/s)
# Processing layer: RRAM_vgg16_128_final_layer_1
# Cycle: 50176
#
# Total Cycle: 50176.0
# All macro: 1
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 15983.6
#
# All macro: 1
# column drivers area: 208.448, number of column_drivers: 4096,
# total column drivers area: (208.448*4096/4096) * macro = 208.448
#
# All macro: 1
# row drivers area: 238.226, number of row_drivers: 4096,
# total row drivers area: (238.226*4096/4096) * macro = 238.226
#
# All macro: 1
# cim unit area: 0.01936, number of cim_unit: 67108864,
# total cim unit area: (0.01936*67108864/4096) * macro = 317.19424
#
# Total Area for layer 1: 16747.468240000002
#
# Total Macro for layer 1: 1
#
# Total Area for all layers: 16747.468240000002
# Total Area for ADC across all layers: 15983.6
# Processing layer: RRAM_vgg16_128_final_layer_2
# Cycle: 50176
#
# Total Cycle: 100352.0
# Size: 5
# All macro: 5
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 79918.0
#
# Size: 5
# All macro: 5
# column drivers area: 208.448, number of column_drivers: 4096,
# total column drivers area: (208.448*4096/4096) * macro = 1042.24
#
# Size: 5
# All macro: 5
# row drivers area: 238.226, number of row_drivers: 4096,
# total row drivers area: (238.226*4096/4096) * macro = 1191.13
#
# Size: 5
# All macro: 5
# cim unit area: 0.01936, number of cim_unit: 67108864,
# total cim unit area: (0.01936*67108864/4096) * macro = 1585.9712
#
# Total Area for layer 2: 83737.34120000001
#
# Total Macro for layer 2: 6
#
# Total Area for all layers: 100484.80944000001
# Total Area for ADC across all layers: 95901.6
# Processing layer: RRAM_vgg16_128_final_layer_3
# Cycle: 12544
#
# Total Cycle: 112896.0
# Size: 2
# Size: 5
# All macro: 10
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 159836.0
#
# Size: 2
# Size: 5
# All macro: 10
# column drivers area: 208.448, number of column_drivers: 4096,
# total column drivers area: (208.448*4096/4096) * macro = 2084.48
#
# Size: 2
# Size: 5
# All macro: 10
# row drivers area: 238.226, number of row_drivers: 4096,
# total row drivers area: (238.226*4096/4096) * macro = 2382.26
#
# Size: 2
# Size: 5
# All macro: 10
# cim unit area: 0.01936, number of cim_unit: 67108864,
# total cim unit area: (0.01936*67108864/4096) * macro = 3171.9424
#
# Total Area for layer 3: 167474.68240000002
#
# Total Macro for layer 3: 16
#
# Total Area for all layers: 267959.49184000003
# Total Area for ADC across all layers: 255737.6
# Processing layer: RRAM_vgg16_128_final_layer_4
# Cycle: 12544
#
# Total Cycle: 125440.0
# Size: 3
# Size: 3
# Size: 2
# All macro: 18
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 287704.8
#
# Size: 3
# Size: 3
# Size: 2
# All macro: 18
# column drivers area: 208.448, number of column_drivers: 4096,
# total column drivers area: (208.448*4096/4096) * macro = 3752.0640000000003
#
# Size: 3
# Size: 3
# Size: 2
# All macro: 18
# row drivers area: 238.226, number of row_drivers: 4096,
# total row drivers area: (238.226*4096/4096) * macro = 4288.068
#
# Size: 3
# Size: 3
# Size: 2
# All macro: 18
# cim unit area: 0.01936, number of cim_unit: 67108864,
# total cim unit area: (0.01936*67108864/4096) * macro = 5709.496319999999
#
# Total Area for layer 4: 301454.42832
#
# Total Macro for layer 4: 34
#
# Total Area for all layers: 569413.92016
# Total Area for ADC across all layers: 543442.4
# Processing layer: RRAM_vgg16_128_final_layer_5
# Cycle: 3136
#
# Total Cycle: 128576.0
# Size: 3
# Size: 3
# Size: 4
# All macro: 36
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 575409.6
#
# Size: 3
# Size: 3
# Size: 4
# All macro: 36
# column drivers area: 208.448, number of column_drivers: 4096,
# total column drivers area: (208.448*4096/4096) * macro = 7504.128000000001
#
# Size: 3
# Size: 3
# Size: 4
# All macro: 36
# row drivers area: 238.226, number of row_drivers: 4096,
# total row drivers area: (238.226*4096/4096) * macro = 8576.136
#
# Size: 3
# Size: 3
# Size: 4
# All macro: 36
# cim unit area: 0.01936, number of cim_unit: 67108864,
# total cim unit area: (0.01936*67108864/4096) * macro = 11418.992639999999
#
# Total Area for layer 5: 602908.85664
#
# Total Macro for layer 5: 70
#
# Total Area for all layers: 1172322.7768
# Total Area for ADC across all layers: 1118852.0
# Processing layer: RRAM_vgg16_128_final_layer_6
# Cycle: 3136
#
# Total Cycle: 131712.0
# Size: 3
# Size: 3
# Size: 4
# Size: 2
# All macro: 72
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 1150819.2
#
# Size: 3
# Size: 3
# Size: 4
# Size: 2
# All macro: 72
# column drivers area: 208.448, number of column_drivers: 4096,
# total column drivers area: (208.448*4096/4096) * macro = 15008.256000000001
#
# Size: 3
# Size: 3
# Size: 4
# Size: 2
# All macro: 72
# row drivers area: 238.226, number of row_drivers: 4096,
# total row drivers area: (238.226*4096/4096) * macro = 17152.272
#
# Size: 3
# Size: 3
# Size: 4
# Size: 2
# All macro: 72
# cim unit area: 0.01936, number of cim_unit: 67108864,
# total cim unit area: (0.01936*67108864/4096) * macro = 22837.985279999997
#
# Total Area for layer 6: 1205817.71328
#
# Total Macro for layer 6: 142
#
# Total Area for all layers: 2378140.49008
# Total Area for ADC across all layers: 2269671.2
# Processing layer: RRAM_vgg16_128_final_layer_7
# Cycle: 3136
#
# Total Cycle: 134848.0
# Size: 3
# Size: 3
# Size: 4
# Size: 2
# All macro: 72
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 1150819.2
#
# Size: 3
# Size: 3
# Size: 4
# Size: 2
# All macro: 72
# column drivers area: 208.448, number of column_drivers: 4096,
# total column drivers area: (208.448*4096/4096) * macro = 15008.256000000001
#
# Size: 3
# Size: 3
# Size: 4
# Size: 2
# All macro: 72
# row drivers area: 238.226, number of row_drivers: 4096,
# total row drivers area: (238.226*4096/4096) * macro = 17152.272
#
# Size: 3
# Size: 3
# Size: 4
# Size: 2
# All macro: 72
# cim unit area: 0.01936, number of cim_unit: 67108864,
# total cim unit area: (0.01936*67108864/4096) * macro = 22837.985279999997
#
# Total Area for layer 7: 1205817.71328
#
# Total Macro for layer 7: 214
#
# Total Area for all layers: 3583958.2033599997
# Total Area for ADC across all layers: 3420490.4000000004
# Processing layer: RRAM_vgg16_128_final_layer_8
# Cycle: 784
#
# Total Cycle: 135632.0
# Size: 3
# Size: 3
# Size: 8
# Size: 2
# All macro: 144
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 2301638.4
#
# Size: 3
# Size: 3
# Size: 8
# Size: 2
# All macro: 144
# column drivers area: 208.448, number of column_drivers: 4096,
# total column drivers area: (208.448*4096/4096) * macro = 30016.512000000002
#
# Size: 3
# Size: 3
# Size: 8
# Size: 2
# All macro: 144
# row drivers area: 238.226, number of row_drivers: 4096,
# total row drivers area: (238.226*4096/4096) * macro = 34304.544
#
# Size: 3
# Size: 3
# Size: 8
# Size: 2
# All macro: 144
# cim unit area: 0.01936, number of cim_unit: 67108864,
# total cim unit area: (0.01936*67108864/4096) * macro = 45675.970559999994
#
# Total Area for layer 8: 2411635.42656
#
# Total Macro for layer 8: 358
#
# Total Area for all layers: 5995593.62992
# Total Area for ADC across all layers: 5722128.800000001
# Processing layer: RRAM_vgg16_128_final_layer_9
# Cycle: 784
#
# Total Cycle: 136416.0
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 4603276.8
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# column drivers area: 208.448, number of column_drivers: 4096,
# total column drivers area: (208.448*4096/4096) * macro = 60033.024000000005
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# row drivers area: 238.226, number of row_drivers: 4096,
# total row drivers area: (238.226*4096/4096) * macro = 68609.088
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# cim unit area: 0.01936, number of cim_unit: 67108864,
# total cim unit area: (0.01936*67108864/4096) * macro = 91351.94111999999
#
# Total Area for layer 9: 4823270.85312
#
# Total Macro for layer 9: 646
#
# Total Area for all layers: 10818864.483040001
# Total Area for ADC across all layers: 10325405.600000001
# Processing layer: RRAM_vgg16_128_final_layer_10
# Cycle: 784
#
# Total Cycle: 137200.0
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 4603276.8
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# column drivers area: 208.448, number of column_drivers: 4096,
# total column drivers area: (208.448*4096/4096) * macro = 60033.024000000005
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# row drivers area: 238.226, number of row_drivers: 4096,
# total row drivers area: (238.226*4096/4096) * macro = 68609.088
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# cim unit area: 0.01936, number of cim_unit: 67108864,
# total cim unit area: (0.01936*67108864/4096) * macro = 91351.94111999999
#
# Total Area for layer 10: 4823270.85312
#
# Total Macro for layer 10: 934
#
# Total Area for all layers: 15642135.33616
# Total Area for ADC across all layers: 14928682.400000002
# Processing layer: RRAM_vgg16_128_final_layer_11
# Cycle: 196
#
# Total Cycle: 137396.0
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 4603276.8
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# column drivers area: 208.448, number of column_drivers: 4096,
# total column drivers area: (208.448*4096/4096) * macro = 60033.024000000005
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# row drivers area: 238.226, number of row_drivers: 4096,
# total row drivers area: (238.226*4096/4096) * macro = 68609.088
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# cim unit area: 0.01936, number of cim_unit: 67108864,
# total cim unit area: (0.01936*67108864/4096) * macro = 91351.94111999999
#
# Total Area for layer 11: 4823270.85312
#
# Total Macro for layer 11: 1222
#
# Total Area for all layers: 20465406.18928
# Total Area for ADC across all layers: 19531959.200000003
# Processing layer: RRAM_vgg16_128_final_layer_12
# Cycle: 196
#
# Total Cycle: 137592.0
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 4603276.8
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# column drivers area: 208.448, number of column_drivers: 4096,
# total column drivers area: (208.448*4096/4096) * macro = 60033.024000000005
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# row drivers area: 238.226, number of row_drivers: 4096,
# total row drivers area: (238.226*4096/4096) * macro = 68609.088
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# cim unit area: 0.01936, number of cim_unit: 67108864,
# total cim unit area: (0.01936*67108864/4096) * macro = 91351.94111999999
#
# Total Area for layer 12: 4823270.85312
#
# Total Macro for layer 12: 1510
#
# Total Area for all layers: 25288677.0424
# Total Area for ADC across all layers: 24135236.000000004
# Processing layer: RRAM_vgg16_128_final_layer_13
# Cycle: 196
#
# Total Cycle: 137788.0
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 4603276.8
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# column drivers area: 208.448, number of column_drivers: 4096,
# total column drivers area: (208.448*4096/4096) * macro = 60033.024000000005
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# row drivers area: 238.226, number of row_drivers: 4096,
# total row drivers area: (238.226*4096/4096) * macro = 68609.088
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# cim unit area: 0.01936, number of cim_unit: 67108864,
# total cim unit area: (0.01936*67108864/4096) * macro = 91351.94111999999
#
# Total Area for layer 13: 4823270.85312
#
# Total Macro for layer 13: 1798
#
# Total Area for all layers: 30111947.895519998
# Total Area for ADC across all layers: 28738512.800000004
# Processing layer: RRAM_vgg16_128_final_layer_14
# Cycle: 4
#
# Total Cycle: 137792.0
# Size: 64
# Size: 49
# All macro: 3136
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 50124569.6
#
# Size: 64
# Size: 49
# All macro: 3136
# column drivers area: 208.448, number of column_drivers: 4096,
# total column drivers area: (208.448*4096/4096) * macro = 653692.9280000001
#
# Size: 64
# Size: 49
# All macro: 3136
# row drivers area: 238.226, number of row_drivers: 4096,
# total row drivers area: (238.226*4096/4096) * macro = 747076.736
#
# Size: 64
# Size: 49
# All macro: 3136
# cim unit area: 0.01936, number of cim_unit: 67108864,
# total cim unit area: (0.01936*67108864/4096) * macro = 994721.1366399999
#
# Total Area for layer 14: 52520060.40064
#
# Total Macro for layer 14: 4934
#
# Total Area for all layers: 82632008.29616
# Total Area for ADC across all layers: 78863082.4
# Processing layer: RRAM_vgg16_128_final_layer_15
# Cycle: 1
#
# Total Cycle: 137793.0
# Size: 64
# Size: 32
# All macro: 2048
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 32734412.8
#
# Size: 64
# Size: 32
# All macro: 2048
# column drivers area: 208.448, number of column_drivers: 4096,
# total column drivers area: (208.448*4096/4096) * macro = 426901.504
#
# Size: 64
# Size: 32
# All macro: 2048
# row drivers area: 238.226, number of row_drivers: 4096,
# total row drivers area: (238.226*4096/4096) * macro = 487886.848
#
# Size: 64
# Size: 32
# All macro: 2048
# cim unit area: 0.01936, number of cim_unit: 67108864,
# total cim unit area: (0.01936*67108864/4096) * macro = 649613.80352
#
# Total Area for layer 15: 34298814.955520004
#
# Total Macro for layer 15: 6982
#
# Total Area for all layers: 116930823.25168
# Total Area for ADC across all layers: 111597495.2
# Processing layer: RRAM_vgg16_128_final_layer_16
# Cycle: 1
#
# Total Cycle: 137794.0
# Size: 16
# Size: 32
# All macro: 512
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 8183603.2
#
# Size: 16
# Size: 32
# All macro: 512
# column drivers area: 208.448, number of column_drivers: 4096,
# total column drivers area: (208.448*4096/4096) * macro = 106725.376
#
# Size: 16
# Size: 32
# All macro: 512
# row drivers area: 238.226, number of row_drivers: 4096,
# total row drivers area: (238.226*4096/4096) * macro = 121971.712
#
# Size: 16
# Size: 32
# All macro: 512
# cim unit area: 0.01936, number of cim_unit: 67108864,
# total cim unit area: (0.01936*67108864/4096) * macro = 162403.45088
#
# Total Area for layer 16: 8574703.738880001
#
# Total Macro for layer 16: 7494
#
# Total Area for all layers: 125505526.99056
# Total Area for ADC across all layers: 119781098.4
# Total Area for column drivers across all layers: 1562109.312
# Total Area for row drivers across all layers: 1785265.644
# Total Area for cim unit across all layers: 2377053.6345599997
#
#
# Total Area for ADC across all layers: 119.7810984
# Total Area for column driver across all layers: 1.5621093119999998
# Total Area for row driver across all layers: 1.785265644
# Total Area for cim unit across all layers: 2.3770536345599997
# Total Macro across all layers: 7494
# RRAM_vgg16_128_final 	 3.52e-04 	 125.51 	 7.26e+01
# ../outputs/SRAM_resnet18_128_final/
# Model 	 Energy/inference (J) 	 Area (mm2) 	 Throughput (inf/s)
# Processing layer: SRAM_resnet18_128_final_layer_1
# Cycle: 12544
#
# Total Cycle: 12544.0
# Size: 2
# All macro: 2
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 31967.2
#
# Size: 2
# All macro: 2
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 927.12
#
# Size: 2
# All macro: 2
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 877.72
#
# Size: 2
# All macro: 2
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 5075.10784
#
# Total Area for layer 1: 38847.14784
#
# Total Macro for layer 1: 2
#
# Total Area for all layers: 38847.14784
# Total Area for ADC across all layers: 31967.2
# Processing layer: SRAM_resnet18_128_final_layer_2
# Cycle: 3136
#
# Total Cycle: 15680.0
# Size: 5
# All macro: 5
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 79918.0
#
# Size: 5
# All macro: 5
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 2317.8
#
# Size: 5
# All macro: 5
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 2194.3
#
# Size: 5
# All macro: 5
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 12687.7696
#
# Total Area for layer 2: 97117.8696
#
# Total Macro for layer 2: 7
#
# Total Area for all layers: 135965.01744
# Total Area for ADC across all layers: 111885.2
# Processing layer: SRAM_resnet18_128_final_layer_3
# Cycle: 3136
#
# Total Cycle: 18816.0
# Size: 5
# All macro: 5
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 79918.0
#
# Size: 5
# All macro: 5
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 2317.8
#
# Size: 5
# All macro: 5
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 2194.3
#
# Size: 5
# All macro: 5
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 12687.7696
#
# Total Area for layer 3: 97117.8696
#
# Total Macro for layer 3: 12
#
# Total Area for all layers: 233082.88704
# Total Area for ADC across all layers: 191803.2
# Processing layer: SRAM_resnet18_128_final_layer_4
# Cycle: 3136
#
# Total Cycle: 21952.0
# Size: 5
# All macro: 5
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 79918.0
#
# Size: 5
# All macro: 5
# column drivers area: 463.56, number of column_drivers: 4096,
# total column drivers area: (463.56*4096/4096) * macro = 2317.8
#
# Size: 5
# All macro: 5
# row drivers area: 438.86, number of row_drivers: 4096,
# total row drivers area: (438.86*4096/4096) * macro = 2194.3
#
# Size: 5
# All macro: 5
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 12687.7696
#
# Total Area for layer 4: 97117.8696
#
# Total Macro for layer 4: 17
#
# Total Area for all layers: 330200.75664000004
# Total Area for ADC across all layers: 271721.2
# Processing layer: SRAM_resnet18_128_final_layer_5
# Cycle: 3136
#
# Total Cycle: 25088.0
# Size: 5
# All macro: 5
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 79918.0
#
# Size: 5
# All macro: 5
# column drivers area: 463.56, number of column_drivers: 4096,
# ...
# Total Area for ADC across all layers: 41141786.400000006
# Processing layer: RRAM_mobilenet_v3_128_final_layer_47
# Cycle: 196
#
# Total Cycle: 79586.0
# Size: 11
# All macro: 11
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 175819.6
#
# Size: 11
# All macro: 11
# column drivers area: 208.448, number of column_drivers: 4096,
# total column drivers area: (208.448*4096/4096) * macro = 2292.928
#
# Size: 11
# All macro: 11
# row drivers area: 238.226, number of row_drivers: 4096,
# total row drivers area: (238.226*4096/4096) * macro = 2620.486
#
# Size: 11
# All macro: 11
# cim unit area: 0.01936, number of cim_unit: 67108864,
# total cim unit area: (0.01936*67108864/4096) * macro = 3489.1366399999997
#
# Total Area for layer 47: 184222.15064
#
# Total Macro for layer 47: 2585
#
# Total Area for all layers: 43292205.400400005
# Total Area for ADC across all layers: 41317606.00000001
# Processing layer: RRAM_mobilenet_v3_128_final_layer_48
# Cycle: 49
#
# Total Cycle: 79635.0
# Size: 672
# All macro: 672
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 10740979.200000001
#
# Size: 672
# All macro: 672
# column drivers area: 208.448, number of column_drivers: 4096,
# total column drivers area: (208.448*4096/4096) * macro = 140077.056
#
# Size: 672
# All macro: 672
# row drivers area: 238.226, number of row_drivers: 4096,
# total row drivers area: (238.226*4096/4096) * macro = 160087.872
#
# Size: 672
# All macro: 672
# cim unit area: 0.01936, number of cim_unit: 67108864,
# total cim unit area: (0.01936*67108864/4096) * macro = 213154.52928
#
# Total Area for layer 48: 11254298.65728
#
# Total Macro for layer 48: 3257
#
# Total Area for all layers: 54546504.05768
# Total Area for ADC across all layers: 52058585.20000001
# Processing layer: RRAM_mobilenet_v3_128_final_layer_49
# Cycle: 1
#
# Total Cycle: 79636.0
# Size: 3
# Size: 6
# All macro: 18
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 287704.8
#
# Size: 3
# Size: 6
# All macro: 18
# column drivers area: 208.448, number of column_drivers: 4096,
# total column drivers area: (208.448*4096/4096) * macro = 3752.0640000000003
#
# Size: 3
# Size: 6
# All macro: 18
# row drivers area: 238.226, number of row_drivers: 4096,
# total row drivers area: (238.226*4096/4096) * macro = 4288.068
#
# Size: 3
# Size: 6
# All macro: 18
# cim unit area: 0.01936, number of cim_unit: 67108864,
# total cim unit area: (0.01936*67108864/4096) * macro = 5709.496319999999
#
# Total Area for layer 49: 301454.42832
#
# Total Macro for layer 49: 3275
#
# Total Area for all layers: 54847958.486
# Total Area for ADC across all layers: 52346290.00000001
# Processing layer: RRAM_mobilenet_v3_128_final_layer_50
# Cycle: 1
#
# Total Cycle: 79637.0
# Size: 11
# Size: 2
# All macro: 22
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 351639.2
#
# Size: 11
# Size: 2
# All macro: 22
# column drivers area: 208.448, number of column_drivers: 4096,
# total column drivers area: (208.448*4096/4096) * macro = 4585.856
#
# Size: 11
# Size: 2
# All macro: 22
# row drivers area: 238.226, number of row_drivers: 4096,
# total row drivers area: (238.226*4096/4096) * macro = 5240.972
#
# Size: 11
# Size: 2
# All macro: 22
# cim unit area: 0.01936, number of cim_unit: 67108864,
# total cim unit area: (0.01936*67108864/4096) * macro = 6978.273279999999
#
# Total Area for layer 50: 368444.30128
#
# Total Macro for layer 50: 3297
#
# Total Area for all layers: 55216402.78728
# Total Area for ADC across all layers: 52697929.20000001
# Processing layer: RRAM_mobilenet_v3_128_final_layer_51
# Cycle: 49
#
# Total Cycle: 79686.0
# Size: 3
# Size: 6
# All macro: 18
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 287704.8
#
# Size: 3
# Size: 6
# All macro: 18
# column drivers area: 208.448, number of column_drivers: 4096,
# total column drivers area: (208.448*4096/4096) * macro = 3752.0640000000003
#
# Size: 3
# Size: 6
# All macro: 18
# row drivers area: 238.226, number of row_drivers: 4096,
# total row drivers area: (238.226*4096/4096) * macro = 4288.068
#
# Size: 3
# Size: 6
# All macro: 18
# cim unit area: 0.01936, number of cim_unit: 67108864,
# total cim unit area: (0.01936*67108864/4096) * macro = 5709.496319999999
#
# Total Area for layer 51: 301454.42832
#
# Total Macro for layer 51: 3315
#
# Total Area for all layers: 55517857.2156
# Total Area for ADC across all layers: 52985634.00000001
# Processing layer: RRAM_mobilenet_v3_128_final_layer_52
# Cycle: 49
#
# Total Cycle: 79735.0
# Size: 15
# Size: 2
# All macro: 30
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 479508.0
#
# Size: 15
# Size: 2
# All macro: 30
# column drivers area: 208.448, number of column_drivers: 4096,
# total column drivers area: (208.448*4096/4096) * macro = 6253.4400000000005
#
# Size: 15
# Size: 2
# All macro: 30
# row drivers area: 238.226, number of row_drivers: 4096,
# total row drivers area: (238.226*4096/4096) * macro = 7146.78
#
# Size: 15
# Size: 2
# All macro: 30
# cim unit area: 0.01936, number of cim_unit: 67108864,
# total cim unit area: (0.01936*67108864/4096) * macro = 9515.8272
#
# Total Area for layer 52: 502424.04720000003
#
# Total Macro for layer 52: 3345
#
# Total Area for all layers: 56020281.2628
# Total Area for ADC across all layers: 53465142.00000001
# Processing layer: RRAM_mobilenet_v3_128_final_layer_53
# Cycle: 49
#
# Total Cycle: 79784.0
# Size: 960
# All macro: 960
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 15344256.0
#
# Size: 960
# All macro: 960
# column drivers area: 208.448, number of column_drivers: 4096,
# total column drivers area: (208.448*4096/4096) * macro = 200110.08000000002
#
# Size: 960
# All macro: 960
# row drivers area: 238.226, number of row_drivers: 4096,
# total row drivers area: (238.226*4096/4096) * macro = 228696.96
#
# Size: 960
# All macro: 960
# cim unit area: 0.01936, number of cim_unit: 67108864,
# total cim unit area: (0.01936*67108864/4096) * macro = 304506.4704
#
# Total Area for layer 53: 16077569.510400001
#
# Total Macro for layer 53: 4305
#
# Total Area for all layers: 72097850.7732
# Total Area for ADC across all layers: 68809398.0
# Processing layer: RRAM_mobilenet_v3_128_final_layer_54
# Cycle: 1
#
# Total Cycle: 79785.0
# Size: 4
# Size: 8
# All macro: 32
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 511475.2
#
# Size: 4
# Size: 8
# All macro: 32
# column drivers area: 208.448, number of column_drivers: 4096,
# total column drivers area: (208.448*4096/4096) * macro = 6670.336
#
# Size: 4
# Size: 8
# All macro: 32
# row drivers area: 238.226, number of row_drivers: 4096,
# total row drivers area: (238.226*4096/4096) * macro = 7623.232
#
# Size: 4
# Size: 8
# All macro: 32
# cim unit area: 0.01936, number of cim_unit: 67108864,
# total cim unit area: (0.01936*67108864/4096) * macro = 10150.21568
#
# Total Area for layer 54: 535918.9836800001
#
# Total Macro for layer 54: 4337
#
# Total Area for all layers: 72633769.75688
# Total Area for ADC across all layers: 69320873.2
# Processing layer: RRAM_mobilenet_v3_128_final_layer_55
# Cycle: 1
#
# Total Cycle: 79786.0
# Size: 15
# Size: 2
# All macro: 30
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 479508.0
#
# Size: 15
# Size: 2
# All macro: 30
# column drivers area: 208.448, number of column_drivers: 4096,
# total column drivers area: (208.448*4096/4096) * macro = 6253.4400000000005
#
# Size: 15
# Size: 2
# All macro: 30
# row drivers area: 238.226, number of row_drivers: 4096,
# total row drivers area: (238.226*4096/4096) * macro = 7146.78
#
# Size: 15
# Size: 2
# All macro: 30
# cim unit area: 0.01936, number of cim_unit: 67108864,
# total cim unit area: (0.01936*67108864/4096) * macro = 9515.8272
#
# Total Area for layer 55: 502424.04720000003
#
# Total Macro for layer 55: 4367
#
# Total Area for all layers: 73136193.80408
# Total Area for ADC across all layers: 69800381.2
# Processing layer: RRAM_mobilenet_v3_128_final_layer_56
# Cycle: 49
#
# Total Cycle: 79835.0
# Size: 3
# Size: 8
# All macro: 24
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 383606.4
#
# Size: 3
# Size: 8
# All macro: 24
# column drivers area: 208.448, number of column_drivers: 4096,
# total column drivers area: (208.448*4096/4096) * macro = 5002.752
#
# Size: 3
# Size: 8
# All macro: 24
# row drivers area: 238.226, number of row_drivers: 4096,
# total row drivers area: (238.226*4096/4096) * macro = 5717.424
#
# Size: 3
# Size: 8
# All macro: 24
# cim unit area: 0.01936, number of cim_unit: 67108864,
# total cim unit area: (0.01936*67108864/4096) * macro = 7612.661759999999
#
# Total Area for layer 56: 401939.23776
#
# Total Macro for layer 56: 4391
#
# Total Area for all layers: 73538133.04184
# Total Area for ADC across all layers: 70183987.60000001
# Processing layer: RRAM_mobilenet_v3_128_final_layer_57
# Cycle: 49
#
# Total Cycle: 79884.0
# Size: 15
# Size: 2
# All macro: 30
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 479508.0
#
# Size: 15
# Size: 2
# All macro: 30
# column drivers area: 208.448, number of column_drivers: 4096,
# total column drivers area: (208.448*4096/4096) * macro = 6253.4400000000005
#
# Size: 15
# Size: 2
# All macro: 30
# row drivers area: 238.226, number of row_drivers: 4096,
# total row drivers area: (238.226*4096/4096) * macro = 7146.78
#
# Size: 15
# Size: 2
# All macro: 30
# cim unit area: 0.01936, number of cim_unit: 67108864,
# total cim unit area: (0.01936*67108864/4096) * macro = 9515.8272
#
# Total Area for layer 57: 502424.04720000003
#
# Total Macro for layer 57: 4421
#
# Total Area for all layers: 74040557.08904
# Total Area for ADC across all layers: 70663495.60000001
# Processing layer: RRAM_mobilenet_v3_128_final_layer_58
# Cycle: 49
#
# Total Cycle: 79933.0
# Size: 960
# All macro: 960
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 15344256.0
#
# Size: 960
# All macro: 960
# column drivers area: 208.448, number of column_drivers: 4096,
# total column drivers area: (208.448*4096/4096) * macro = 200110.08000000002
#
# Size: 960
# All macro: 960
# row drivers area: 238.226, number of row_drivers: 4096,
# total row drivers area: (238.226*4096/4096) * macro = 228696.96
#
# Size: 960
# All macro: 960
# cim unit area: 0.01936, number of cim_unit: 67108864,
# total cim unit area: (0.01936*67108864/4096) * macro = 304506.4704
#
# Total Area for layer 58: 16077569.510400001
#
# Total Macro for layer 58: 5381
#
# Total Area for all layers: 90118126.59944
# Total Area for ADC across all layers: 86007751.60000001
# Processing layer: RRAM_mobilenet_v3_128_final_layer_59
# Cycle: 1
#
# Total Cycle: 79934.0
# Size: 4
# Size: 8
# All macro: 32
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 511475.2
#
# Size: 4
# Size: 8
# All macro: 32
# column drivers area: 208.448, number of column_drivers: 4096,
# total column drivers area: (208.448*4096/4096) * macro = 6670.336
#
# Size: 4
# Size: 8
# All macro: 32
# row drivers area: 238.226, number of row_drivers: 4096,
# total row drivers area: (238.226*4096/4096) * macro = 7623.232
#
# Size: 4
# Size: 8
# All macro: 32
# cim unit area: 0.01936, number of cim_unit: 67108864,
# total cim unit area: (0.01936*67108864/4096) * macro = 10150.21568
#
# Total Area for layer 59: 535918.9836800001
#
# Total Macro for layer 59: 5413
#
# Total Area for all layers: 90654045.58311999
# Total Area for ADC across all layers: 86519226.80000001
# Processing layer: RRAM_mobilenet_v3_128_final_layer_60
# Cycle: 1
#
# Total Cycle: 79935.0
# Size: 15
# Size: 2
# All macro: 30
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 479508.0
#
# Size: 15
# Size: 2
# All macro: 30
# column drivers area: 208.448, number of column_drivers: 4096,
# total column drivers area: (208.448*4096/4096) * macro = 6253.4400000000005
#
# Size: 15
# Size: 2
# All macro: 30
# row drivers area: 238.226, number of row_drivers: 4096,
# total row drivers area: (238.226*4096/4096) * macro = 7146.78
#
# Size: 15
# Size: 2
# All macro: 30
# cim unit area: 0.01936, number of cim_unit: 67108864,
# total cim unit area: (0.01936*67108864/4096) * macro = 9515.8272
#
# Total Area for layer 60: 502424.04720000003
#
# Total Macro for layer 60: 5443
#
# Total Area for all layers: 91156469.63031998
# Total Area for ADC across all layers: 86998734.80000001
# Processing layer: RRAM_mobilenet_v3_128_final_layer_61
# Cycle: 49
#
# Total Cycle: 79984.0
# Size: 3
# Size: 8
# All macro: 24
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 383606.4
#
# Size: 3
# Size: 8
# All macro: 24
# column drivers area: 208.448, number of column_drivers: 4096,
# total column drivers area: (208.448*4096/4096) * macro = 5002.752
#
# Size: 3
# Size: 8
# All macro: 24
# row drivers area: 238.226, number of row_drivers: 4096,
# total row drivers area: (238.226*4096/4096) * macro = 5717.424
#
# Size: 3
# Size: 8
# All macro: 24
# cim unit area: 0.01936, number of cim_unit: 67108864,
# total cim unit area: (0.01936*67108864/4096) * macro = 7612.661759999999
#
# Total Area for layer 61: 401939.23776
#
# Total Macro for layer 61: 5467
#
# Total Area for all layers: 91558408.86807999
# Total Area for ADC across all layers: 87382341.20000002
# Processing layer: RRAM_mobilenet_v3_128_final_layer_62
# Cycle: 49
#
# Total Cycle: 80033.0
# Size: 15
# Size: 2
# All macro: 30
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 479508.0
#
# Size: 15
# Size: 2
# All macro: 30
# column drivers area: 208.448, number of column_drivers: 4096,
# total column drivers area: (208.448*4096/4096) * macro = 6253.4400000000005
#
# Size: 15
# Size: 2
# All macro: 30
# row drivers area: 238.226, number of row_drivers: 4096,
# total row drivers area: (238.226*4096/4096) * macro = 7146.78
#
# Size: 15
# Size: 2
# All macro: 30
# cim unit area: 0.01936, number of cim_unit: 67108864,
# total cim unit area: (0.01936*67108864/4096) * macro = 9515.8272
#
# Total Area for layer 62: 502424.04720000003
#
# Total Macro for layer 62: 5497
#
# Total Area for all layers: 92060832.91527998
# Total Area for ADC across all layers: 87861849.20000002
# Processing layer: RRAM_mobilenet_v3_128_final_layer_63
# Cycle: 1
#
# Total Cycle: 80034.0
# Size: 20
# Size: 8
# All macro: 160
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 2557376.0
#
# Size: 20
# Size: 8
# All macro: 160
# column drivers area: 208.448, number of column_drivers: 4096,
# total column drivers area: (208.448*4096/4096) * macro = 33351.68
#
# Size: 20
# Size: 8
# All macro: 160
# row drivers area: 238.226, number of row_drivers: 4096,
# total row drivers area: (238.226*4096/4096) * macro = 38116.16
#
# Size: 20
# Size: 8
# All macro: 160
# cim unit area: 0.01936, number of cim_unit: 67108864,
# total cim unit area: (0.01936*67108864/4096) * macro = 50751.0784
#
# Total Area for layer 63: 2679594.9184000003
#
# Total Macro for layer 63: 5657
#
# Total Area for all layers: 94740427.83367999
# Total Area for ADC across all layers: 90419225.20000002
# Processing layer: RRAM_mobilenet_v3_128_final_layer_64
# Cycle: 1
#
# Total Cycle: 80035.0
# Size: 16
# Size: 10
# All macro: 160
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 2557376.0
#
# Size: 16
# Size: 10
# All macro: 160
# column drivers area: 208.448, number of column_drivers: 4096,
# total column drivers area: (208.448*4096/4096) * macro = 33351.68
#
# Size: 16
# Size: 10
# All macro: 160
# row drivers area: 238.226, number of row_drivers: 4096,
# total row drivers area: (238.226*4096/4096) * macro = 38116.16
#
# Size: 16
# Size: 10
# All macro: 160
# cim unit area: 0.01936, number of cim_unit: 67108864,
# total cim unit area: (0.01936*67108864/4096) * macro = 50751.0784
#
# Total Area for layer 64: 2679594.9184000003
#
# Total Macro for layer 64: 5817
#
# Total Area for all layers: 97420022.75208
# Total Area for ADC across all layers: 92976601.20000002
# Total Area for column drivers across all layers: 1212542.0159999996
# Total Area for row drivers across all layers: 1385760.642
# Total Area for cim unit across all layers: 1845118.8940799995
#
#
# Total Area for ADC across all layers: 92.97660120000002
# Total Area for column driver across all layers: 1.2125420159999996
# Total Area for row driver across all layers: 1.385760642
# Total Area for cim unit across all layers: 1.8451188940799994
# Total Macro across all layers: 5817
# RRAM_mobilenet_v3_128_final 	 1.89e-05 	 97.42 	 1.25e+02

# %%
print("\n### Area and Performance Results ###\n")

for i, dnn in enumerate(dnn_list):
    print(f"Results for {dnn} (SRAM):")
    print(f"  Total Area: {total_area[2 * i]}")
    print(f"  ADC Area: {total_adc_area[2 * i]}")
    print(f"  Column Driver Area: {total_col_area[2 * i]}")
    print(f"  Row Driver Area: {total_row_area[2 * i]}")
    print(f"  CIM Unit Area: {total_cim_unit_area[2 * i]}")
    print(f"  Total Macro: {total_macro[2 * i]}")
    print(f"  Energy: {energy[2 * i]}")
    print(f"  Throughput: {throughput[2 * i]}\n")

    print(f"Results for {dnn} (RRAM):")
    print(f"  Total Area: {total_area[2 * i + 1]}")
    print(f"  ADC Area: {total_adc_area[2 * i + 1]}")
    print(f"  Column Driver Area: {total_col_area[2 * i + 1]}")
    print(f"  Row Driver Area: {total_row_area[2 * i + 1]}")
    print(f"  CIM Unit Area: {total_cim_unit_area[2 * i + 1]}")
    print(f"  Total Macro: {total_macro[2 * i + 1]}")
    print(f"  Energy: {energy[2 * i + 1]}")
    print(f"  Throughput: {throughput[2 * i + 1]}\n")
# Out:
# ### Area and Performance Results ###
#
# Results for alexnet (SRAM):
#   Total Area: 100.41987716639998
#   ADC Area: 82.635212
#   Column Driver Area: 2.3966052
#   Row Driver Area: 2.2689062
#   CIM Unit Area: 13.119153766399998
#   Total Macro: 5170
#   Energy: 1.30005e-05
#   Throughput: 2344.665885111372
#
# Results for alexnet (RRAM):
#   Total Area: 86.58441080079999
#   ADC Area: 82.635212
#   Column Driver Area: 1.0776761599999998
#   Row Driver Area: 1.23162842
#   CIM Unit Area: 1.6398942207999998
#   Total Macro: 5170
#   Energy: 1.6249299999999997e-05
#   Throughput: 2344.665885111372
#
# Results for vgg16 (SRAM):
#   Total Area: 145.56026295648
#   ADC Area: 119.7810984
#   Column Driver Area: 3.47391864
#   Row Driver Area: 3.28881684
#   CIM Unit Area: 19.016429076479998
#   Total Macro: 7494
#   Energy: 0.00028297109999999995
#   Throughput: 72.57210038172926
#
# Results for vgg16 (RRAM):
#   Total Area: 125.50552699055999
#   ADC Area: 119.7810984
#   Column Driver Area: 1.5621093119999998
#   Row Driver Area: 1.785265644
#   CIM Unit Area: 2.3770536345599997
#   Total Macro: 7494
#   Energy: 0.00035196409999999995
#   Throughput: 72.57210038172926
#
# Results for resnet18 (SRAM):
#   Total Area: 27.814557853439997
#   ADC Area: 22.888515199999993
#   Column Driver Area: 0.6638179200000001
#   Row Driver Area: 0.6284475200000001
#   CIM Unit Area: 3.633777213439999
#   Total Macro: 1432
#   Energy: 3.455181000000001e-05
#   Throughput: 330.75345637361914
#
# Results for resnet18 (RRAM):
#   Total Area: 23.98237451968
#   ADC Area: 22.888515199999993
#   Column Driver Area: 0.29849753600000006
#   Row Driver Area: 0.34113963199999997
#   CIM Unit Area: 0.45422215167999985
#   Total Macro: 1432
#   Energy: 4.2794300000000005e-05
#   Throughput: 330.75345637361914
#
# Results for mobilenet_v3 (SRAM):
#   Total Area: 112.98692949263999
#   ADC Area: 92.97660120000002
#   Column Driver Area: 2.6965285199999998
#   Row Driver Area: 2.5528486199999993
#   CIM Unit Area: 14.760951152639995
#   Total Macro: 5817
#   Energy: 2.07223883e-05
#   Throughput: 124.9453364153183
#
# Results for mobilenet_v3 (RRAM):
#   Total Area: 97.42002275207999
#   ADC Area: 92.97660120000002
#   Column Driver Area: 1.2125420159999996
#   Row Driver Area: 1.385760642
#   CIM Unit Area: 1.8451188940799994
#   Total Macro: 5817
#   Energy: 1.8906694000000003e-05
#   Throughput: 124.9453364153183

# %%
import matplotlib.pyplot as plt
import numpy as np

sram_label = "SRAM"
rram_label = "RRAM"

x = np.arange(len(dnn_list))  # Number of DNNs
width = 0.35  # Bar width

# Create figure and axes for three different plots (energy, area, throughput)
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(18, 6))

# Energy Plot
ax1.bar(x - width/2, energy[::2], width, label=sram_label, color='tab:blue')  # SRAM for DNN1, DNN2
ax1.bar(x + width/2, energy[1::2], width, label=rram_label, color='tab:red')  # RRAM for DNN1, DNN2
ax1.set_title("Energy Consumption")
ax1.set_xticks(x)
ax1.set_xticklabels(dnn_list)
ax1.set_xlabel("DNN models")
ax1.set_ylabel("Energy")
ax1.legend()

# Area Plot
ax2.bar(x - width/2, total_area[::2], width, label=sram_label, color='tab:blue')  # SRAM for DNN1, DNN2
ax2.bar(x + width/2, total_area[1::2], width, label=rram_label, color='tab:red')  # RRAM for DNN1, DNN2
ax2.set_title("Area")
ax2.set_xticks(x)
ax2.set_xticklabels(dnn_list)
ax2.set_xlabel("DNN models")
ax2.set_ylabel("Area")
ax2.legend()

# Throughput Plot
ax3.bar(x - width/2, throughput[::2], width, label=sram_label, color='tab:blue')  # SRAM for DNN1, DNN2
ax3.bar(x + width/2, throughput[1::2], width, label=rram_label, color='tab:red')  # RRAM for DNN1, DNN2
ax3.set_title("Throughput")
ax3.set_xticks(x)
ax3.set_xticklabels(dnn_list)
ax3.set_xlabel("DNN models")
ax3.set_ylabel("Throughput")
ax3.legend()

# Adjust layout for better spacing
plt.tight_layout()
plt.show()

# %%
display_markdown(
    """
### Calculating the energy

"""
)

path_list = [SRAM_PATH, RRAM_PATH]  # List of paths
num_dnns = len(dnn_list)  # Get the number of DNN models
num_paths = len(path_list)  # Get the number of paths
num_cases = num_dnns * num_paths  # Total number of cases

# Initialize energy lists dynamically based on the number of cases
total_adc_energy = [0] * (2 * num_dnns)
total_col_energy = [0] * (2 * num_dnns)
total_row_energy = [0] * (2 * num_dnns)
total_cim_unit_energy = [0] * (2 * num_dnns)

# Iterate through all cases dynamically based on `j`
for j in range(2 * num_dnns):  # Now `j` will be 2 * number of DNN models
    # For each DNN model, calculate energy based on the path
    dnn_idx = j // 2  # Determine which DNN model (0 or 1, 2, etc.)
    path_idx = j % 2  # Determine which path (0 for SRAM, 1 for RRAM)

    # Now iterate through each energy category (ADC, Column, Row, CIM Unit)
    for i in range(4):  # Since there are 4 categories (ADC, Column, Row, CIM Unit)
        energy_value = total_per_energy[(dnn_list[dnn_idx], path_list[path_idx])][i] * energy[j]

        if i == 0:
            total_adc_energy[j] = energy_value
        elif i == 1:
            total_col_energy[j] = energy_value
        elif i == 2:
            total_row_energy[j] = energy_value
        else:
            total_cim_unit_energy[j] = energy_value

# Print the results for total energies
print("Total ADC Energy:", total_adc_energy)
print("Total Column Energy:", total_col_energy)
print("Total Row Energy:", total_row_energy)
print("Total CIM Unit Energy:", total_cim_unit_energy)
# Out:
# ### Calculating the energy
# Total ADC Energy: [5.3108801684501424e-06, 5.263360217384512e-06, 0.00021316737501093604, 0.0002406285173462433, 1.736704669627886e-05, 1.8182034196858595e-05, 7.86451562814187e-06, 7.334965246000791e-06]
# Total Column Energy: [3.7425665616594963e-08, 2.0982791739103364e-17, 1.4985348303007603e-06, 9.553311285686674e-16, 1.2213410888033513e-07, 7.22107618306133e-17, 5.528637105753454e-08, 1.16045718822363e-16]
# Total Row Energy: [7.627707087572691e-06, 6.075825217383466e-06, 6.808629589905031e-05, 6.177329102026441e-05, 1.7014057942291864e-05, 1.4264766666643484e-05, 1.279451049967796e-05, 9.590193366532323e-06]
# Total CIM Unit Energy: [2.4487078360572262e-08, 4.910114565211037e-06, 2.1889425971284002e-07, 4.956229163253691e-05, 4.857125254895175e-08, 1.0347499136425713e-05, 8.075801122634817e-09, 1.9815353873508446e-06]

# %%
import matplotlib.pyplot as plt
import numpy as np
fig, ax = plt.subplots(figsize=(10, 6)) 
path = ['SRAM', 'RRAM']
num_bars = len(dnn_list) * len(path)

x = np.arange(num_bars)

# Stack bars
ax.bar(x, total_cim_unit_energy, label='cim_unit')
ax.bar(x, total_row_energy, bottom=total_cim_unit_energy, label='row_drivers')
ax.bar(x, total_col_energy, bottom=np.array(total_cim_unit_energy) + np.array(total_row_energy), label='column_drivers')
ax.bar(x, total_adc_energy, bottom=np.array(total_cim_unit_energy) + np.array(total_row_energy) + np.array(total_col_energy), label='adc')

# Labels and title
ax.set_title(f"Energy vs Memory Type for {DNN} in fast scenario")
ax.set_xlabel("Memory type")
ax.set_ylabel("Energy (J)")
# Set x-ticks
xtick_labels = [f"{mem}-{dnn}" for dnn in dnn_list for mem in path]
ax.set_xticks(x)
ax.set_xticklabels(xtick_labels)

ax.legend()

# Show plot
plt.show()
