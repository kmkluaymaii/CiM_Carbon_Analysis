# %%
# !python3 run_example_designs.py --architecture eyeriss_like --problem alexnet
# Out:
# Running mapper for target eyeriss_like in /home/workspace/example_designs/example_designs/eyeriss_like/outputs/0...
# input file: /home/workspace/example_designs/example_designs/eyeriss_like/outputs/0/parsed-processed-input.yaml
#   _______                __
#  /_  __(_)___ ___  ___  / /___  ____  ____
#   / / / / __ `__ \/ _ \/ / __ \/ __ \/ __ \
#  / / / / / / / / /  __/ / /_/ / /_/ / /_/ /
# /_/ /_/_/ /_/ /_/\___/_/\____/\____/ .___/
#                                   /_/
#
# Problem configuration complete.
# execute:/usr/local/bin/accelergy /home/workspace/example_designs/example_designs/eyeriss_like/outputs/0/parsed-processed-input.yaml --oprefix timeloop-mapper. -o ./ > timeloop-mapper.accelergy.log 2>&1
# Generate Accelergy ERT (energy reference table) to replace internal energy model.
# Generate Accelergy ART (area reference table) to replace internal area model.
# Architecture configuration complete.
# Sparse optimization configuration complete.
# Using threads = 4
# Mapper configuration complete.
# Initializing Index Factorization subspace.
#   Factorization options along problem dimension C = 4
#   Factorization options along problem dimension M = 210
#   Factorization options along problem dimension R = 3
#   Factorization options along problem dimension S = 3
#   Factorization options along problem dimension N = 1
#   Factorization options along problem dimension P = 4
#   Factorization options along problem dimension Q = 9
#   Factorization options along problem dimension G = 1
# Mapspace Dimension [IndexFactorization] Size: 272160
# Mapspace Dimension [LoopPermutation] Size: 518400
# Mapspace Dimension [Spatial] Size: 1
# Mapspace Dimension [DatatypeBypass] Size: 1
# Mapspace split! Per-split Mapping Dimension [IndexFactorization] Size: 68040 Residue: 0
# Mapspace construction complete.
# Search configuration complete.
# [  1] Utilization = 0.07 | pJ/Compute =    7.131 | L6[WIO] M2 S11 - L5[IO] Q55 M4 P55 - L4[] G1 M4X - L3[] G1 C3Y - L2[I] G1 - L1[W] R11 - L0[O] M2
# [  3] Utilization = 0.02 | pJ/Compute =    8.179 | L6[WIO] M2 S11 C3 - L5[IO] Q55 M4 P55 - L4[] G1 M4X - L3[] G1 - L2[I] G1 - L1[W] R11 - L0[O] M2
# [  2] Utilization = 0.02 | pJ/Compute =    7.968 | L6[WIO] M2 S11 - L5[IO] Q55 C3 M4 P55 - L4[] G1 M4X - L3[] G1 - L2[I] G1 - L1[W] R11 - L0[O] M2
# [  0] Utilization = 0.01 | pJ/Compute =   76.597 | L6[WIO] M2 Q55 - L5[IO] R11 S11 P55 M4 - L4[] G1 M2X - L3[] G1 - L2[I] G1 - L1[W] C3 - L0[O] M4
# [  0] Utilization = 0.26 | pJ/Compute =   20.058 | L6[WIO] M2 P11 Q55 - L5[IO] M4 R11 P5 - L4[] G1 M4X - L3[] G1 S11Y - L2[I] G1 - L1[W] C3 - L0[O] M2
# [  3] Utilization = 0.26 | pJ/Compute =   21.777 | L6[WIO] M2 P11 Q55 C3 - L5[IO] M4 R11 P5 - L4[] G1 M4X - L3[] G1 S11Y - L2[I] G1 - L1[W] G1 - L0[O] M2
# [  2] Utilization = 0.26 | pJ/Compute =   73.250 | L6[WIO] M2 P11 Q55 - L5[IO] M4 R11 P5 C3 - L4[] G1 M4X - L3[] G1 S11Y - L2[I] G1 - L1[W] G1 - L0[O] M2
# [  0] Utilization = 0.26 | pJ/Compute =   16.275 | L6[WIO] P11 M16 Q5 - L5[IO] S11 P5 R11 - L4[] G1 Q11X - L3[] G1 M4Y - L2[I] G1 - L1[W] C3 - L0[O] G1
# [  1] Utilization = 0.37 | pJ/Compute =   16.306 | L6[WIO] P11 M16 Q5 - L5[IO] S11 P5 R11 - L4[] G1 Q11X - L3[] G1 M4Y C3Y - L2[I] G1 - L1[W] G1 - L0[O] G1
# [  0] Utilization = 0.26 | pJ/Compute =   10.020 | L6[WIO] Q5 R11 P11 - L5[IO] Q11 P5 - L4[] G1 M4X - L3[] G1 S11Y - L2[I] G1 - L1[W] C3 - L0[O] M16
# [  3] Utilization = 0.26 | pJ/Compute =   17.874 | L6[WIO] P11 C3 M16 Q5 - L5[IO] S11 P5 R11 - L4[] G1 Q11X - L3[] G1 M4Y - L2[I] G1 - L1[W] G1 - L0[O] G1
# [  2] Utilization = 0.26 | pJ/Compute =   17.134 | L6[WIO] P11 M16 Q5 - L5[IO] S11 C3 P5 R11 - L4[] G1 Q11X - L3[] G1 M4Y - L2[I] G1 - L1[W] G1 - L0[O] G1
# [  1] Utilization = 0.39 | pJ/Compute =   13.970 | L6[WIO] M2 Q5 P5 S11 - L5[IO] P11 M8 - L4[] G1 Q11X - L3[] G1 M2Y C3Y - L2[I] G1 - L1[W] R11 - L0[O] M2
# [  1] Utilization = 0.39 | pJ/Compute =   11.710 | L6[WIO] S11 P55 - L5[IO] M4 Q5 - L4[] G1 Q11X - L3[] G1 M2Y C3Y - L2[I] G1 - L1[W] R11 - L0[O] M8
# [  2] Utilization = 0.19 | pJ/Compute =   11.804 | L6[WIO] M2 S11 Q55 - L5[IO] C3 P55 - L4[] G1 M4X - L3[] G1 M8Y - L2[I] G1 - L1[W] R11 - L0[O] G1
# [  1] Utilization = 0.36 | pJ/Compute =    6.213 | L6[WIO] P5 M2 S11 - L5[IO] P11 Q11 - L4[] G1 M2X Q5X - L3[] G1 M2Y C3Y - L2[I] G1 - L1[W] R11 - L0[O] M8
# [  0] Utilization = 0.72 | pJ/Compute =   13.925 | L6[WIO] Q5 M2 P55 - L5[IO] M2 R11 - L4[] G1 Q11X - L3[] G1 S11Y - L2[I] G1 - L1[W] C3 - L0[O] M16
# [  3] Utilization = 0.12 | pJ/Compute =    7.787 | L6[WIO] P5 C3 M2 S11 - L5[IO] P11 Q11 - L4[] G1 M2X Q5X - L3[] G1 M2Y - L2[I] G1 - L1[W] R11 - L0[O] M8
# [  3] Utilization = 0.52 | pJ/Compute =    7.785 | L6[WIO] P55 M8 C3 - L5[IO] Q55 - L4[] G1 M8X - L3[] G1 S11Y - L2[I] G1 - L1[W] R11 - L0[O] G1
# [  2] Utilization = 0.65 | pJ/Compute =   26.312 | L6[WIO] P11 R11 M2 Q11 - L5[IO] C3 P5 M16 - L4[] G1 M2X Q5X - L3[] G1 S11Y - L2[I] G1 - L1[W] G1 - L0[O] G1
# [  1] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
# [  3] Utilization = 0.65 | pJ/Compute =    7.025 | L6[WIO] C3 P11 - L5[IO] M16 Q11 P5 - L4[] G1 M2X Q5X - L3[] G1 S11Y - L2[I] G1 - L1[W] R11 - L0[O] M2
# [  2] Utilization = 0.65 | pJ/Compute =    6.285 | L6[WIO] P11 - L5[IO] C3 M16 Q11 P5 - L4[] G1 M2X Q5X - L3[] G1 S11Y - L2[I] G1 - L1[W] R11 - L0[O] M2
# [  0] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
# [  2] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
# [  3] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
#
#
# Summary stats for best mapping found by mapper:
#   Utilization = 0.65 | pJ/Compute =    6.285
#
#
# Running mapper for target eyeriss_like in /home/workspace/example_designs/example_designs/eyeriss_like/outputs/1...
# input file: /home/workspace/example_designs/example_designs/eyeriss_like/outputs/1/parsed-processed-input.yaml
#   _______                __
#  /_  __(_)___ ___  ___  / /___  ____  ____
#   / / / / __ `__ \/ _ \/ / __ \/ __ \/ __ \
#  / / / / / / / / /  __/ / /_/ / /_/ / /_/ /
# /_/ /_/_/ /_/ /_/\___/_/\____/\____/ .___/
#                                   /_/
#
# Problem configuration complete.
# execute:/usr/local/bin/accelergy /home/workspace/example_designs/example_designs/eyeriss_like/outputs/1/parsed-processed-input.yaml --oprefix timeloop-mapper. -o ./ > timeloop-mapper.accelergy.log 2>&1
# Generate Accelergy ERT (energy reference table) to replace internal energy model.
# Generate Accelergy ART (area reference table) to replace internal area model.
# Architecture configuration complete.
# Sparse optimization configuration complete.
# Using threads = 4
# Mapper configuration complete.
# Initializing Index Factorization subspace.
#   Factorization options along problem dimension C = 84
#   Factorization options along problem dimension M = 1050
#   Factorization options along problem dimension R = 3
#   Factorization options along problem dimension S = 3
#   Factorization options along problem dimension N = 1
#   Factorization options along problem dimension P = 4
#   Factorization options along problem dimension Q = 10
#   Factorization options along problem dimension G = 1
# Mapspace Dimension [IndexFactorization] Size: 31752000
# Mapspace Dimension [LoopPermutation] Size: 518400
# Mapspace Dimension [Spatial] Size: 1
# Mapspace Dimension [DatatypeBypass] Size: 1
# Mapspace split! Per-split Mapping Dimension [IndexFactorization] Size: 7938000 Residue: 0
# Mapspace construction complete.
# Search configuration complete.
# [  0] Utilization = 0.29 | pJ/Compute =   33.813 | L6[WIO] P27 S5 R5 C2 Q9 - L5[IO] M48 - L4[] G1 M2X Q3X - L3[] G1 M2Y C4Y - L2[I] G1 - L1[W] C8 - L0[O] G1
# [  2] Utilization = 0.05 | pJ/Compute =   71.743 | L6[WIO] P27 Q9 - L5[IO] M3 S5 Q3 R5 C32 - L4[] G1 M2X - L3[] G1 M4Y - L2[I] G1 - L1[W] C2 - L0[O] M8
# [  3] Utilization = 0.21 | pJ/Compute =    7.908 | L6[WIO] S5 C4 M16 - L5[IO] Q3 M2 C2 P27 - L4[] G1 Q9X - L3[] G1 M2Y C2Y - L2[I] G1 - L1[W] R5 C4 - L0[O] M3
# [  2] Utilization = 0.18 | pJ/Compute =   33.326 | L6[WIO] M4 C8 R5 Q9 P27 - L5[IO] M8 - L4[] G1 Q3X - L3[] G1 M2Y S5Y - L2[I] G1 - L1[W] C8 - L0[O] M3
# [  1] Utilization = 0.52 | pJ/Compute =   15.714 | L6[WIO] Q3 M8 C2 P9 - L5[IO] P3 M2 R5 C16 Q3 - L4[] G1 M3X Q3X - L3[] G1 M2Y S5Y - L2[I] G1 - L1[W] C2 - L0[O] M2
# [  0] Utilization = 0.34 | pJ/Compute =   17.311 | L6[WIO] P3 C2 M8 Q3 - L5[IO] C32 P9 R5 M2 Q3 - L4[] G1 M4X Q3X - L3[] G1 S5Y - L2[I] G1 - L1[W] G1 - L0[O] M3
# [  3] Utilization = 0.54 | pJ/Compute =   14.897 | L6[WIO] Q3 M8 C2 P9 - L5[IO] P3 M2 R5 C8 Q3 - L4[] G1 M3X Q3X - L3[] G1 M2Y S5Y - L2[I] G1 - L1[W] C4 - L0[O] M2
# [  2] Utilization = 0.32 | pJ/Compute =   17.403 | L6[WIO] M2 C8 Q3 P9 R5 - L5[IO] M4 S5 P3 C2 - L4[] G1 Q9X - L3[] G1 M6Y - L2[I] G1 - L1[W] C4 - L0[O] M4
# [  2] Utilization = 0.71 | pJ/Compute =   14.516 | L6[WIO] P3 C2 M8 Q3 - L5[IO] C4 P9 R5 M2 Q3 - L4[] G1 M4X Q3X - L3[] G1 C2Y S5Y - L2[I] G1 - L1[W] C4 - L0[O] M3
# [  0] Utilization = 0.57 | pJ/Compute =    8.568 | L6[WIO] S5 P3 C4 - L5[IO] P9 C2 Q27 - L4[] G1 M8X - L3[] G1 M3Y C4Y - L2[I] G1 - L1[W] R5 C2 - L0[O] M8
# [  2] Utilization = 0.54 | pJ/Compute =    9.483 | L6[WIO] C32 P3 M12 - L5[IO] Q3 M2 P9 - L4[] G1 Q9X - L3[] G1 M2Y S5Y - L2[I] G1 - L1[W] R5 C2 - L0[O] M4
# [  3] Utilization = 0.29 | pJ/Compute =    6.638 | L6[WIO] M6 Q9 C4 - L5[IO] M2 S5 P27 - L4[] G1 M4X Q3X - L3[] G1 C4Y - L2[I] G1 - L1[W] R5 C4 - L0[O] M4
# [  1] Utilization = 0.51 | pJ/Compute =   14.871 | L6[WIO] M12 Q3 C8 S5 P9 - L5[IO] R5 Q3 P3 - L4[] G1 M4X Q3X - L3[] G1 C8Y - L2[I] G1 - L1[W] G1 - L0[O] M4
# [  3] Utilization = 0.43 | pJ/Compute =    7.124 | L6[WIO] M16 C2 S5 - L5[IO] Q9 M2 C4 P27 - L4[] G1 M3X Q3X - L3[] G1 M2Y C4Y - L2[I] G1 - L1[W] R5 C2 - L0[O] G1
# [  0] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
# [  2] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
# [  1] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
# [  3] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
#
#
# Summary stats for best mapping found by mapper:
#   Utilization = 0.57 | pJ/Compute =    8.568
#
#
# Running mapper for target eyeriss_like in /home/workspace/example_designs/example_designs/eyeriss_like/outputs/2...
# input file: /home/workspace/example_designs/example_designs/eyeriss_like/outputs/2/parsed-processed-input.yaml
#   _______                __
#  /_  __(_)___ ___  ___  / /___  ____  ____
#   / / / / __ `__ \/ _ \/ / __ \/ __ \/ __ \
#  / / / / / / / / /  __/ / /_/ / /_/ / /_/ /
# /_/ /_/_/ /_/ /_/\___/_/\____/\____/ .___/
#                                   /_/
#
# Problem configuration complete.
# execute:/usr/local/bin/accelergy /home/workspace/example_designs/example_designs/eyeriss_like/outputs/2/parsed-processed-input.yaml --oprefix timeloop-mapper. -o ./ > timeloop-mapper.accelergy.log 2>&1
# Generate Accelergy ERT (energy reference table) to replace internal energy model.
# Generate Accelergy ART (area reference table) to replace internal area model.
# Architecture configuration complete.
# Sparse optimization configuration complete.
# Using threads = 4
# Mapper configuration complete.
# Initializing Index Factorization subspace.
#   Factorization options along problem dimension C = 336
#   Factorization options along problem dimension M = 1650
#   Factorization options along problem dimension R = 3
#   Factorization options along problem dimension S = 3
#   Factorization options along problem dimension N = 1
#   Factorization options along problem dimension P = 2
#   Factorization options along problem dimension Q = 3
#   Factorization options along problem dimension G = 1
# Mapspace Dimension [IndexFactorization] Size: 29937600
# Mapspace Dimension [LoopPermutation] Size: 518400
# Mapspace Dimension [Spatial] Size: 1
# Mapspace Dimension [DatatypeBypass] Size: 1
# Mapspace split! Per-split Mapping Dimension [IndexFactorization] Size: 7484400 Residue: 0
# Mapspace construction complete.
# Search configuration complete.
# [  0] Utilization = 0.04 | pJ/Compute =   14.312 | L6[WIO] M48 P13 C4 - L5[IO] R3 C2 Q13 - L4[] G1 M2X - L3[] G1 S3Y - L2[I] G1 - L1[W] C24 - L0[O] M4
# [  3] Utilization = 0.01 | pJ/Compute =   76.986 | L6[WIO] S3 M8 C2 - L5[IO] Q13 C96 P13 M8 - L4[] G1 - L3[] G1 M2Y - L2[I] G1 - L1[W] R3 - L0[O] M3
# [  1] Utilization = 0.07 | pJ/Compute =   14.331 | L6[WIO] M48 P13 C4 - L5[IO] R3 C2 Q13 - L4[] G1 M2X - L3[] G1 C2Y S3Y - L2[I] G1 - L1[W] C12 - L0[O] M4
# [  2] Utilization = 0.11 | pJ/Compute =   14.350 | L6[WIO] M48 P13 C4 - L5[IO] R3 C2 Q13 - L4[] G1 M2X - L3[] G1 C3Y S3Y - L2[I] G1 - L1[W] C8 - L0[O] M4
# [  0] Utilization = 0.46 | pJ/Compute =    6.638 | L6[WIO] M12 C2 - L5[IO] C6 R3 P13 - L4[] G1 Q13X - L3[] G1 M2Y S3Y - L2[I] G1 - L1[W] C16 - L0[O] M16
# [  1] Utilization = 0.93 | pJ/Compute =    6.670 | L6[WIO] M12 C2 - L5[IO] C6 R3 P13 - L4[] G1 Q13X - L3[] G1 M2Y C2Y S3Y - L2[I] G1 - L1[W] C8 - L0[O] M16
# [  3] Utilization = 0.14 | pJ/Compute =   14.371 | L6[WIO] M48 P13 C4 - L5[IO] R3 C2 Q13 - L4[] G1 M2X - L3[] G1 C4Y S3Y - L2[I] G1 - L1[W] C6 - L0[O] M4
# [  3] Utilization = 0.86 | pJ/Compute =   73.198 | L6[WIO] C2 R3 S3 P13 Q13 - L5[IO] M8 - L4[] G1 M12X - L3[] G1 C12Y - L2[I] G1 - L1[W] C8 - L0[O] M4
# [  3] Utilization = 0.38 | pJ/Compute =   15.168 | L6[WIO] M24 C2 - L5[IO] S3 M4 P13 C48 - L4[] G1 Q13X - L3[] G1 M4Y C2Y - L2[I] G1 - L1[W] R3 - L0[O] G1
# [  2] Utilization = 0.29 | pJ/Compute =   12.850 | L6[WIO] M2 C2 - L5[IO] Q13 R3 C6 M48 P13 - L4[] G1 M4X - L3[] G1 C4Y S3Y - L2[I] G1 - L1[W] C4 - L0[O] G1
# [  3] Utilization = 0.93 | pJ/Compute =   13.250 | L6[WIO] P13 R3 S3 C4 - L5[IO] C2 M64 - L4[] G1 Q13X - L3[] G1 M3Y C4Y - L2[I] G1 - L1[W] C6 - L0[O] M2
# [  2] Utilization = 0.57 | pJ/Compute =   11.996 | L6[WIO] C6 P13 - L5[IO] S3 C8 Q13 - L4[] G1 M8X - L3[] G1 M6Y C2Y - L2[I] G1 - L1[W] R3 C2 - L0[O] M8
# [  2] Utilization = 0.70 | pJ/Compute =   13.228 | L6[WIO] P13 R3 S3 C4 - L5[IO] C2 M64 - L4[] G1 Q13X - L3[] G1 M3Y C3Y - L2[I] G1 - L1[W] C8 - L0[O] M2
# [  0] Utilization = 0.93 | pJ/Compute =   12.860 | L6[WIO] R3 C4 S3 - L5[IO] M4 P13 C2 - L4[] G1 Q13X - L3[] G1 M12Y - L2[I] G1 - L1[W] C24 - L0[O] M8
# [  1] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
# [  2] Utilization = 0.57 | pJ/Compute =    6.295 | L6[WIO] R3 S3 C3 - L5[IO] M8 P13 Q13 - L4[] G1 M12X - L3[] G1 M2Y C4Y - L2[I] G1 - L1[W] C16 - L0[O] M2
# [  3] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
# [  0] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
# [  2] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
#
#
# Summary stats for best mapping found by mapper:
#   Utilization = 0.93 | pJ/Compute =    6.670
#
#
# Running mapper for target eyeriss_like in /home/workspace/example_designs/example_designs/eyeriss_like/outputs/3...
# input file: /home/workspace/example_designs/example_designs/eyeriss_like/outputs/3/parsed-processed-input.yaml
#   _______                __
#  /_  __(_)___ ___  ___  / /___  ____  ____
#   / / / / __ `__ \/ _ \/ / __ \/ __ \/ __ \
#  / / / / / / / / /  __/ / /_/ / /_/ / /_/ /
# /_/ /_/_/ /_/ /_/\___/_/\____/\____/ .___/
#                                   /_/
#
# Problem configuration complete.
# execute:/usr/local/bin/accelergy /home/workspace/example_designs/example_designs/eyeriss_like/outputs/3/parsed-processed-input.yaml --oprefix timeloop-mapper. -o ./ > timeloop-mapper.accelergy.log 2>&1
# Generate Accelergy ERT (energy reference table) to replace internal energy model.
# Generate Accelergy ART (area reference table) to replace internal area model.
# Architecture configuration complete.
# Sparse optimization configuration complete.
# Using threads = 4
# Mapper configuration complete.
# Initializing Index Factorization subspace.
#   Factorization options along problem dimension C = 480
#   Factorization options along problem dimension M = 495
#   Factorization options along problem dimension R = 3
#   Factorization options along problem dimension S = 3
#   Factorization options along problem dimension N = 1
#   Factorization options along problem dimension P = 2
#   Factorization options along problem dimension Q = 3
#   Factorization options along problem dimension G = 1
# Mapspace Dimension [IndexFactorization] Size: 12830400
# Mapspace Dimension [LoopPermutation] Size: 518400
# Mapspace Dimension [Spatial] Size: 1
# Mapspace Dimension [DatatypeBypass] Size: 1
# Mapspace split! Per-split Mapping Dimension [IndexFactorization] Size: 3207600 Residue: 0
# Mapspace construction complete.
# Search configuration complete.
# [  2] Utilization = 0.04 | pJ/Compute =   72.372 | L6[WIO] Q13 M4 C4 - L5[IO] P13 M4 C8 - L4[] G1 - L3[] G1 C2Y S3Y - L2[I] G1 - L1[W] R3 C6 - L0[O] M16
# [  3] Utilization = 0.05 | pJ/Compute =   72.464 | L6[WIO] M8 C2 Q13 - L5[IO] R3 S3 M2 P13 C16 - L4[] G1 M2X - L3[] G1 M4Y - L2[I] G1 - L1[W] C12 - L0[O] M2
# [  2] Utilization = 0.74 | pJ/Compute =    8.070 | L6[WIO] M32 R3 - L5[IO] C4 P13 - L4[] G1 Q13X - L3[] G1 C4Y S3Y - L2[I] G1 - L1[W] C24 - L0[O] M8
# [  0] Utilization = 0.10 | pJ/Compute =   72.465 | L6[WIO] M8 C2 Q13 - L5[IO] R3 S3 M2 P13 C32 - L4[] G1 M2X - L3[] G1 M4Y C2Y - L2[I] G1 - L1[W] C3 - L0[O] M2
# [  3] Utilization = 0.05 | pJ/Compute =   72.372 | L6[WIO] Q13 M4 C4 - L5[IO] P13 M4 C8 - L4[] G1 - L3[] G1 C3Y S3Y - L2[I] G1 - L1[W] R3 C4 - L0[O] M16
# [  1] Utilization = 0.14 | pJ/Compute =   72.467 | L6[WIO] M8 C2 Q13 - L5[IO] R3 S3 M2 P13 C32 - L4[] G1 M2X - L3[] G1 M4Y C3Y - L2[I] G1 - L1[W] C2 - L0[O] M2
# [  0] Utilization = 0.07 | pJ/Compute =   11.891 | L6[WIO] M8 P13 C3 - L5[IO] R3 C16 Q13 - L4[] G1 M2X - L3[] G1 M2Y S3Y - L2[I] G1 - L1[W] C8 - L0[O] M8
# [  1] Utilization = 0.14 | pJ/Compute =   11.956 | L6[WIO] M8 P13 C3 - L5[IO] R3 C16 Q13 - L4[] G1 M2X - L3[] G1 M2Y C2Y S3Y - L2[I] G1 - L1[W] C4 - L0[O] M8
# [  3] Utilization = 0.14 | pJ/Compute =   73.711 | L6[WIO] M4 P13 C3 - L5[IO] C128 Q13 R3 - L4[] G1 M8X - L3[] G1 S3Y - L2[I] G1 - L1[W] G1 - L0[O] M8
# [  3] Utilization = 0.14 | pJ/Compute =   72.798 | L6[WIO] Q13 - L5[IO] R3 P13 C96 M2 - L4[] G1 M2X - L3[] G1 M4Y S3Y - L2[I] G1 - L1[W] C4 - L0[O] M16
# [  3] Utilization = 0.14 | pJ/Compute =   72.074 | L6[WIO] C8 Q13 R3 - L5[IO] P13 M4 S3 C2 - L4[] G1 M2X - L3[] G1 M2Y C6Y - L2[I] G1 - L1[W] C4 - L0[O] M16
# [  0] Utilization = 0.10 | pJ/Compute =   13.913 | L6[WIO] M8 C16 Q13 - L5[IO] R3 M8 S3 P13 - L4[] G1 M2X - L3[] G1 C8Y - L2[I] G1 - L1[W] C3 - L0[O] M2
# [  3] Utilization = 0.29 | pJ/Compute =   74.153 | L6[WIO] R3 P13 C12 M8 Q13 - L5[IO] C4 - L4[] G1 M8X - L3[] G1 M2Y S3Y - L2[I] G1 - L1[W] C8 - L0[O] M2
# [  3] Utilization = 0.62 | pJ/Compute =   12.980 | L6[WIO] P13 C3 M8 - L5[IO] S3 C4 M4 - L4[] G1 Q13X - L3[] G1 C8Y - L2[I] G1 - L1[W] R3 C4 - L0[O] M8
# [  0] Utilization = 0.29 | pJ/Compute =   12.152 | L6[WIO] C8 M2 - L5[IO] C4 M2 S3 P13 R3 Q13 - L4[] G1 M8X - L3[] G1 C6Y - L2[I] G1 - L1[W] C2 - L0[O] M8
# [  1] Utilization = 0.57 | pJ/Compute =   12.418 | L6[WIO] C8 M2 - L5[IO] C4 M2 S3 P13 R3 Q13 - L4[] G1 M8X - L3[] G1 C12Y - L2[I] G1 - L1[W] G1 - L0[O] M8
# [  0] Utilization = 0.42 | pJ/Compute =   17.036 | L6[WIO] M16 P13 C4 - L5[IO] S3 C48 M2 - L4[] G1 Q13X - L3[] G1 M4Y C2Y - L2[I] G1 - L1[W] R3 - L0[O] M2
# [  0] Utilization = 0.37 | pJ/Compute =   15.047 | L6[WIO] C16 P13 M16 - L5[IO] M4 C2 R3 - L4[] G1 Q13X - L3[] G1 M2Y C2Y S3Y - L2[I] G1 - L1[W] C6 - L0[O] M2
# [  0] Utilization = 0.93 | pJ/Compute =   13.383 | L6[WIO] M4 C3 R3 P13 - L5[IO] M2 C8 - L4[] G1 Q13X - L3[] G1 M4Y S3Y - L2[I] G1 - L1[W] C16 - L0[O] M8
# [  1] Utilization = 0.62 | pJ/Compute =   12.635 | L6[WIO] M2 C3 - L5[IO] R3 M2 P13 S3 C32 - L4[] G1 Q13X - L3[] G1 M8Y - L2[I] G1 - L1[W] C4 - L0[O] M8
# [  3] Utilization = 0.93 | pJ/Compute =   12.697 | L6[WIO] M2 C4 P13 - L5[IO] C3 M16 - L4[] G1 Q13X - L3[] G1 C4Y S3Y - L2[I] G1 - L1[W] R3 C8 - L0[O] M8
# [  1] Utilization = 0.93 | pJ/Compute =   12.980 | L6[WIO] C8 - L5[IO] C12 P13 M64 - L4[] G1 Q13X - L3[] G1 C4Y S3Y - L2[I] G1 - L1[W] R3 - L0[O] M4
# [  2] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
# [  3] Utilization = 0.62 | pJ/Compute =    6.514 | L6[WIO] C4 S3 - L5[IO] M8 C3 R3 P13 - L4[] G1 Q13X - L3[] G1 M2Y C4Y - L2[I] G1 - L1[W] C8 - L0[O] M16
# [  0] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
# [  1] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
# [  3] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
#
#
# Summary stats for best mapping found by mapper:
#   Utilization = 0.62 | pJ/Compute =    6.514
#
#
# Running mapper for target eyeriss_like in /home/workspace/example_designs/example_designs/eyeriss_like/outputs/4...
# input file: /home/workspace/example_designs/example_designs/eyeriss_like/outputs/4/parsed-processed-input.yaml
#   _______                __
#  /_  __(_)___ ___  ___  / /___  ____  ____
#   / / / / __ `__ \/ _ \/ / __ \/ __ \/ __ \
#  / / / / / / / / /  __/ / /_/ / /_/ / /_/ /
# /_/ /_/_/ /_/ /_/\___/_/\____/\____/ .___/
#                                   /_/
#
# Problem configuration complete.
# execute:/usr/local/bin/accelergy /home/workspace/example_designs/example_designs/eyeriss_like/outputs/4/parsed-processed-input.yaml --oprefix timeloop-mapper. -o ./ > timeloop-mapper.accelergy.log 2>&1
# Generate Accelergy ERT (energy reference table) to replace internal energy model.
# Generate Accelergy ART (area reference table) to replace internal area model.
# Architecture configuration complete.
# Sparse optimization configuration complete.
# Using threads = 4
# Mapper configuration complete.
# Initializing Index Factorization subspace.
#   Factorization options along problem dimension C = 165
#   Factorization options along problem dimension M = 495
#   Factorization options along problem dimension R = 3
#   Factorization options along problem dimension S = 3
#   Factorization options along problem dimension N = 1
#   Factorization options along problem dimension P = 2
#   Factorization options along problem dimension Q = 3
#   Factorization options along problem dimension G = 1
# Mapspace Dimension [IndexFactorization] Size: 4410450
# Mapspace Dimension [LoopPermutation] Size: 518400
# Mapspace Dimension [Spatial] Size: 1
# Mapspace Dimension [DatatypeBypass] Size: 1
# Mapspace split! Per-split Mapping Dimension [IndexFactorization] Size: 1102613 Residue: 2
# Mapspace construction complete.
# Search configuration complete.
#   80.265 | L6[WIO] S3 M64 C64 - L5[IO] Q13 P13 M4 - L4[] G1 - L3[] G1 - L2[I] G1 - L1[W] R3 C4 - L0[O] G1
# [  2] Utilization = 0.02 | pJ/Compute =   80.382 | L6[WIO] S3 M64 C64 - L5[IO] Q13 P13 M4 - L4[] G1 - L3[] G1 C4Y - L2[I] G1 - L1[W] R3 - L0[O] G1
# [  1] Utilization = 0.01 | pJ/Compute =   80.299 | L6[WIO] S3 M64 C64 - L5[IO] Q13 P13 M4 - L4[] G1 - L3[] G1 C2Y - L2[I] G1 - L1[W] R3 C2 - L0[O] G1
# [  3] Utilization = 0.01 | pJ/Compute =   81.447 | L6[WIO] S3 M64 C64 - L5[IO] Q13 C2 P13 M4 - L4[] G1 - L3[] G1 - L2[I] G1 - L1[W] R3 C2 - L0[O] G1
# [  0] Utilization = 0.07 | pJ/Compute =   11.959 | L6[WIO] M8 P13 C2 - L5[IO] R3 C16 Q13 - L4[] G1 - L3[] G1 M2Y C2Y S3Y - L2[I] G1 - L1[W] C4 - L0[O] M16
# [  3] Utilization = 0.04 | pJ/Compute =   13.802 | L6[WIO] M8 P13 C128 - L5[IO] R3 Q13 - L4[] G1 - L3[] G1 M2Y S3Y - L2[I] G1 - L1[W] C2 - L0[O] M16
# [  2] Utilization = 0.29 | pJ/Compute =   72.327 | L6[WIO] Q13 M4 C16 - L5[IO] P13 M2 C2 - L4[] G1 M4X - L3[] G1 M4Y S3Y - L2[I] G1 - L1[W] R3 C8 - L0[O] M2
# [  1] Utilization = 0.19 | pJ/Compute =   72.264 | L6[WIO] R3 P13 M2 C2 Q13 - L5[IO] M4 S3 C8 - L4[] G1 M4X - L3[] G1 C8Y - L2[I] G1 - L1[W] C2 - L0[O] M8
# [  3] Utilization = 0.29 | pJ/Compute =   72.284 | L6[WIO] M4 P13 C2 - L5[IO] C16 Q13 R3 - L4[] G1 M4X - L3[] G1 C4Y S3Y - L2[I] G1 - L1[W] C2 - L0[O] M16
# [  0] Utilization = 0.10 | pJ/Compute =   11.910 | L6[WIO] P13 C16 R3 S3 - L5[IO] M16 Q13 - L4[] G1 M4X - L3[] G1 C4Y - L2[I] G1 - L1[W] C4 - L0[O] M4
# [  1] Utilization = 0.19 | pJ/Compute =   12.041 | L6[WIO] P13 C16 R3 S3 - L5[IO] M16 Q13 - L4[] G1 M4X - L3[] G1 C8Y - L2[I] G1 - L1[W] C2 - L0[O] M4
# [  1] Utilization = 0.31 | pJ/Compute =   12.691 | L6[WIO] P13 C4 R3 - L5[IO] M4 C8 S3 - L4[] G1 Q13X - L3[] G1 M4Y - L2[I] G1 - L1[W] C8 - L0[O] M16
# [  2] Utilization = 0.62 | pJ/Compute =   12.693 | L6[WIO] P13 C4 R3 - L5[IO] M4 C8 S3 - L4[] G1 Q13X - L3[] G1 M4Y C2Y - L2[I] G1 - L1[W] C4 - L0[O] M16
# [  0] Utilization = 0.31 | pJ/Compute =   12.691 | L6[WIO] P13 C4 R3 - L5[IO] M4 C64 S3 - L4[] G1 Q13X - L3[] G1 M4Y - L2[I] G1 - L1[W] G1 - L0[O] M16
# [  3] Utilization = 0.15 | pJ/Compute =   16.538 | L6[WIO] R3 C4 P13 M8 - L5[IO] C32 M4 S3 - L4[] G1 Q13X - L3[] G1 C2Y - L2[I] G1 - L1[W] G1 - L0[O] M8
# [  3] Utilization = 0.19 | pJ/Compute =   18.064 | L6[WIO] M16 R3 S3 - L5[IO] P13 M8 C8 - L4[] G1 Q13X - L3[] G1 M2Y C2Y - L2[I] G1 - L1[W] C16 - L0[O] G1
# [  1] Utilization = 0.57 | pJ/Compute =   14.829 | L6[WIO] R3 C4 P13 M8 - L5[IO] C8 M4 S3 - L4[] G1 Q13X - L3[] G1 C8Y - L2[I] G1 - L1[W] G1 - L0[O] M8
# [  3] Utilization = 0.31 | pJ/Compute =   15.304 | L6[WIO] M16 C16 - L5[IO] S3 M4 P13 C4 - L4[] G1 Q13X - L3[] G1 M2Y C2Y - L2[I] G1 - L1[W] R3 C2 - L0[O] M2
# [  0] Utilization = 0.31 | pJ/Compute =    7.325 | L6[WIO] R3 S3 - L5[IO] M16 C16 P13 - L4[] G1 Q13X - L3[] G1 C4Y - L2[I] G1 - L1[W] C4 - L0[O] M16
# [  1] Utilization = 0.62 | pJ/Compute =    7.457 | L6[WIO] R3 S3 - L5[IO] M16 C16 P13 - L4[] G1 Q13X - L3[] G1 C8Y - L2[I] G1 - L1[W] C2 - L0[O] M16
# [  3] Utilization = 0.93 | pJ/Compute =   13.506 | L6[WIO] P13 C16 M64 - L5[IO] M2 - L4[] G1 Q13X - L3[] G1 M2Y C2Y S3Y - L2[I] G1 - L1[W] R3 C8 - L0[O] G1
# [  0] Utilization = 0.57 | pJ/Compute =   10.638 | L6[WIO] Q13 C32 - L5[IO] P13 - L4[] G1 M8X - L3[] G1 M4Y S3Y - L2[I] G1 - L1[W] R3 C8 - L0[O] M8
# [  2] Utilization = 0.93 | pJ/Compute =   13.197 | L6[WIO] P13 C8 M8 - L5[IO] R3 C16 - L4[] G1 Q13X - L3[] G1 M2Y C2Y S3Y - L2[I] G1 - L1[W] G1 - L0[O] M16
# [  2] Utilization = 0.93 | pJ/Compute =    6.596 | L6[WIO] C8 - L5[IO] M64 P13 - L4[] G1 Q13X - L3[] G1 C4Y S3Y - L2[I] G1 - L1[W] R3 C8 - L0[O] M4
# [  3] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
# [  1] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
# [  0] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
# [  2] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
#
#
# Summary stats for best mapping found by mapper:
#   Utilization = 0.93 | pJ/Compute =    6.596
#
#
# Running mapper for target eyeriss_like in /home/workspace/example_designs/example_designs/eyeriss_like/outputs/5...
# input file: /home/workspace/example_designs/example_designs/eyeriss_like/outputs/5/parsed-processed-input.yaml
#   _______                __
#  /_  __(_)___ ___  ___  / /___  ____  ____
#   / / / / __ `__ \/ _ \/ / __ \/ __ \/ __ \
#  / / / / / / / / /  __/ / /_/ / /_/ / /_/ /
# /_/ /_/_/ /_/ /_/\___/_/\____/\____/ .___/
#                                   /_/
#
# Problem configuration complete.
# execute:/usr/local/bin/accelergy /home/workspace/example_designs/example_designs/eyeriss_like/outputs/5/parsed-processed-input.yaml --oprefix timeloop-mapper. -o ./ > timeloop-mapper.accelergy.log 2>&1
# Generate Accelergy ERT (energy reference table) to replace internal energy model.
# Generate Accelergy ART (area reference table) to replace internal area model.
# Architecture configuration complete.
# Sparse optimization configuration complete.
# Using threads = 4
# Mapper configuration complete.
# Initializing Index Factorization subspace.
#   Factorization options along problem dimension C = 2860
#   Factorization options along problem dimension M = 1820
#   Factorization options along problem dimension R = 1
#   Factorization options along problem dimension S = 1
#   Factorization options along problem dimension N = 1
#   Factorization options along problem dimension P = 1
#   Factorization options along problem dimension Q = 1
#   Factorization options along problem dimension G = 1
# Mapspace Dimension [IndexFactorization] Size: 5205200
# Mapspace Dimension [LoopPermutation] Size: 4
# Mapspace Dimension [Spatial] Size: 1
# Mapspace Dimension [DatatypeBypass] Size: 1
# Mapspace split! Per-split Mapping Dimension [IndexFactorization] Size: 1301300 Residue: 0
# Mapspace construction complete.
# Search configuration complete.
# [  3] Utilization = 0.04 | pJ/Compute =   72.212 | L6[WIO] C4 M128 - L5[IO] C64 M2 - L4[] G1 - L3[] G1 C6Y - L2[I] G1 - L1[W] C6 - L0[O] M16
# [  1] Utilization = 0.02 | pJ/Compute =   72.171 | L6[WIO] C4 M128 - L5[IO] C64 M2 - L4[] G1 - L3[] G1 C3Y - L2[I] G1 - L1[W] C12 - L0[O] M16
# [  2] Utilization = 0.02 | pJ/Compute =   72.184 | L6[WIO] C4 M128 - L5[IO] C64 M2 - L4[] G1 - L3[] G1 C4Y - L2[I] G1 - L1[W] C9 - L0[O] M16
# [  0] Utilization = 0.01 | pJ/Compute =   72.160 | L6[WIO] C4 M128 - L5[IO] C64 M2 - L4[] G1 - L3[] G1 C2Y - L2[I] G1 - L1[W] C18 - L0[O] M16
# [  3] Utilization = 0.19 | pJ/Compute =   73.371 | L6[WIO] C48 M8 - L5[IO] M64 C16 - L4[] G1 M8X - L3[] G1 C4Y - L2[I] G1 - L1[W] C3 - L0[O] G1
# [  1] Utilization = 0.10 | pJ/Compute =   73.367 | L6[WIO] C48 M8 - L5[IO] M64 C16 - L4[] G1 M8X - L3[] G1 C2Y - L2[I] G1 - L1[W] C6 - L0[O] G1
# [  0] Utilization = 0.05 | pJ/Compute =   85.665 | L6[WIO] M2 C144 - L5[IO] C64 M32 - L4[] G1 - L3[] G1 M8Y - L2[I] G1 - L1[W] G1 - L0[O] M8
# [  3] Utilization = 0.57 | pJ/Compute =   71.860 | L6[WIO] C24 M8 - L5[IO] C16 - L4[] G1 M8X - L3[] G1 M4Y C3Y - L2[I] G1 - L1[W] C8 - L0[O] M16
# [  0] Utilization = 0.05 | pJ/Compute =   73.365 | L6[WIO] C48 M8 - L5[IO] M64 C16 - L4[] G1 M8X - L3[] G1 - L2[I] G1 - L1[W] C12 - L0[O] G1
# [  2] Utilization = 0.14 | pJ/Compute =   73.369 | L6[WIO] C48 M8 - L5[IO] M64 C16 - L4[] G1 M8X - L3[] G1 C3Y - L2[I] G1 - L1[W] C4 - L0[O] G1
# [  1] Utilization = 0.19 | pJ/Compute =   71.858 | L6[WIO] C24 M8 - L5[IO] C16 - L4[] G1 M8X - L3[] G1 M4Y - L2[I] G1 - L1[W] C24 - L0[O] M16
# [  0] Utilization = 0.29 | pJ/Compute =   74.290 | L6[WIO] M2 C4 - L5[IO] C384 M128 - L4[] G1 M4X - L3[] G1 M2Y C6Y - L2[I] G1 - L1[W] G1 - L0[O] M2
# [  2] Utilization = 0.38 | pJ/Compute =   71.859 | L6[WIO] C24 M8 - L5[IO] C16 - L4[] G1 M8X - L3[] G1 M4Y C2Y - L2[I] G1 - L1[W] C12 - L0[O] M16
# [  1] Utilization = 0.38 | pJ/Compute =   71.925 | L6[WIO] C9 M32 - L5[IO] C16 M2 - L4[] G1 M8X - L3[] G1 C8Y - L2[I] G1 - L1[W] C8 - L0[O] M8
# [  2] Utilization = 0.57 | pJ/Compute =   71.827 | L6[WIO] C2 M128 - L5[IO] C16 M4 - L4[] G1 M8X - L3[] G1 C12Y - L2[I] G1 - L1[W] C24 - L0[O] G1
# [  0] Utilization = 0.29 | pJ/Compute =   71.696 | L6[WIO] M2 - L5[IO] C128 M256 - L4[] G1 M4X - L3[] G1 M2Y C6Y - L2[I] G1 - L1[W] C12 - L0[O] G1
# [  1] Utilization = 0.38 | pJ/Compute =   71.591 | L6[WIO] C32 - L5[IO] M32 C18 - L4[] G1 M8X - L3[] G1 C8Y - L2[I] G1 - L1[W] C2 - L0[O] M16
# [  0] Utilization = 0.57 | pJ/Compute =   72.800 | L6[WIO] C64 M128 - L5[IO] C3 - L4[] G1 M8X - L3[] G1 C12Y - L2[I] G1 - L1[W] C4 - L0[O] M4
# [  1] Utilization = 0.57 | pJ/Compute =   72.121 | L6[WIO] C32 M4 - L5[IO] M16 C6 - L4[] G1 M8X - L3[] G1 C12Y - L2[I] G1 - L1[W] C4 - L0[O] M8
# [  0] Utilization = 0.57 | pJ/Compute =   71.630 | L6[WIO] C48 - L5[IO] M32 C2 - L4[] G1 M8X - L3[] G1 M2Y C6Y - L2[I] G1 - L1[W] C16 - L0[O] M8
# [  3] Utilization = 0.57 | pJ/Compute =   71.719 | L6[WIO] C2 M64 - L5[IO] C24 M4 - L4[] G1 M8X - L3[] G1 C12Y - L2[I] G1 - L1[W] C16 - L0[O] M2
# [  1] Utilization = 0.57 | pJ/Compute =   72.023 | L6[WIO] C8 M4 - L5[IO] M32 C32 - L4[] G1 M8X - L3[] G1 M4Y C3Y - L2[I] G1 - L1[W] C12 - L0[O] G1
# [  2] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
# [  1] Utilization = 0.57 | pJ/Compute =   71.800 | L6[WIO] M2 C32 - L5[IO] C6 M64 - L4[] G1 M8X - L3[] G1 M4Y C3Y - L2[I] G1 - L1[W] C16 - L0[O] G1
# [  0] Utilization = 0.57 | pJ/Compute =   71.588 | L6[WIO] C2 M2 - L5[IO] M16 C1536 - L4[] G1 M8X - L3[] G1 M4Y C3Y - L2[I] G1 - L1[W] G1 - L0[O] M4
# [  3] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
# [  1] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
# [  0] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
#
#
# Summary stats for best mapping found by mapper:
#   Utilization = 0.57 | pJ/Compute =   71.588
#
#
# Running mapper for target eyeriss_like in /home/workspace/example_designs/example_designs/eyeriss_like/outputs/6...
# input file: /home/workspace/example_designs/example_designs/eyeriss_like/outputs/6/parsed-processed-input.yaml
#   _______                __
#  /_  __(_)___ ___  ___  / /___  ____  ____
#   / / / / __ `__ \/ _ \/ / __ \/ __ \/ __ \
#  / / / / / / / / /  __/ / /_/ / /_/ / /_/ /
# /_/ /_/_/ /_/ /_/\___/_/\____/\____/ .___/
#                                   /_/
#
# Problem configuration complete.
# execute:/usr/local/bin/accelergy /home/workspace/example_designs/example_designs/eyeriss_like/outputs/6/parsed-processed-input.yaml --oprefix timeloop-mapper. -o ./ > timeloop-mapper.accelergy.log 2>&1
# Generate Accelergy ERT (energy reference table) to replace internal energy model.
# Generate Accelergy ART (area reference table) to replace internal area model.
# Architecture configuration complete.
# Sparse optimization configuration complete.
# Using threads = 4
# Mapper configuration complete.
# Initializing Index Factorization subspace.
#   Factorization options along problem dimension C = 455
#   Factorization options along problem dimension M = 1820
#   Factorization options along problem dimension R = 1
#   Factorization options along problem dimension S = 1
#   Factorization options along problem dimension N = 1
#   Factorization options along problem dimension P = 1
#   Factorization options along problem dimension Q = 1
#   Factorization options along problem dimension G = 1
# Mapspace Dimension [IndexFactorization] Size: 828100
# Mapspace Dimension [LoopPermutation] Size: 4
# Mapspace Dimension [Spatial] Size: 1
# Mapspace Dimension [DatatypeBypass] Size: 1
# Mapspace split! Per-split Mapping Dimension [IndexFactorization] Size: 207025 Residue: 0
# Mapspace construction complete.
# Search configuration complete.
# [  3] Utilization = 0.05 | pJ/Compute =   72.826 | L6[WIO] M128 - L5[IO] C256 M2 - L4[] G1 - L3[] G1 C8Y - L2[I] G1 - L1[W] C2 - L0[O] M16
# [  0] Utilization = 0.05 | pJ/Compute =   71.579 | L6[WIO] C2 M8 - L5[IO] M4 C256 - L4[] G1 M4X - L3[] G1 M2Y - L2[I] G1 - L1[W] C8 - L0[O] M16
# [  1] Utilization = 0.10 | pJ/Compute =   71.578 | L6[WIO] C2 M8 - L5[IO] M4 C256 - L4[] G1 M4X - L3[] G1 M2Y C2Y - L2[I] G1 - L1[W] C4 - L0[O] M16
# [  2] Utilization = 0.19 | pJ/Compute =   71.577 | L6[WIO] C2 M8 - L5[IO] M4 C256 - L4[] G1 M4X - L3[] G1 M2Y C4Y - L2[I] G1 - L1[W] C2 - L0[O] M16
# [  3] Utilization = 0.19 | pJ/Compute =   71.512 | L6[WIO] M4 - L5[IO] M4 C2048 - L4[] G1 M4X - L3[] G1 M4Y C2Y - L2[I] G1 - L1[W] G1 - L0[O] M16
# [  3] Utilization = 0.38 | pJ/Compute =   71.694 | L6[WIO] M8 - L5[IO] M8 C128 - L4[] G1 M8X - L3[] G1 M4Y C2Y - L2[I] G1 - L1[W] C16 - L0[O] M2
# [  0] Utilization = 0.10 | pJ/Compute =   81.680 | L6[WIO] C256 M32 - L5[IO] C2 M8 - L4[] G1 M4X - L3[] G1 M4Y - L2[I] G1 - L1[W] C8 - L0[O] G1
# [  1] Utilization = 0.19 | pJ/Compute =   81.746 | L6[WIO] C256 M32 - L5[IO] C2 M8 - L4[] G1 M4X - L3[] G1 M4Y C2Y - L2[I] G1 - L1[W] C4 - L0[O] G1
# [  0] Utilization = 0.19 | pJ/Compute =   77.267 | L6[WIO] C128 M8 - L5[IO] M64 C8 - L4[] G1 M8X - L3[] G1 C4Y - L2[I] G1 - L1[W] G1 - L0[O] G1
# [  1] Utilization = 0.19 | pJ/Compute =   73.778 | L6[WIO] C64 M128 - L5[IO] M4 - L4[] G1 M4X - L3[] G1 M2Y C4Y - L2[I] G1 - L1[W] C16 - L0[O] G1
# [  2] Utilization = 0.19 | pJ/Compute =   71.512 | L6[WIO] M4 - L5[IO] M4 C256 - L4[] G1 M4X - L3[] G1 M4Y C2Y - L2[I] G1 - L1[W] C8 - L0[O] M16
# [  0] Utilization = 0.19 | pJ/Compute =   73.543 | L6[WIO] C2 M32 - L5[IO] C256 M2 - L4[] G1 M8X - L3[] G1 C4Y - L2[I] G1 - L1[W] C2 - L0[O] M8
# [  3] Utilization = 0.38 | pJ/Compute =   71.539 | L6[WIO] M4 - L5[IO] M8 C64 - L4[] G1 M8X - L3[] G1 C8Y - L2[I] G1 - L1[W] C8 - L0[O] M16
# [  2] Utilization = 0.38 | pJ/Compute =   74.458 | L6[WIO] C64 M256 - L5[IO] C2 - L4[] G1 M8X - L3[] G1 M2Y C4Y - L2[I] G1 - L1[W] C8 - L0[O] G1
# [  1] Utilization = 0.38 | pJ/Compute =   73.810 | L6[WIO] C2 M32 - L5[IO] C256 M2 - L4[] G1 M8X - L3[] G1 C8Y - L2[I] G1 - L1[W] G1 - L0[O] M8
# [  0] Utilization = 0.38 | pJ/Compute =   72.015 | L6[WIO] C8 M128 - L5[IO] C64 - L4[] G1 M8X - L3[] G1 C8Y - L2[I] G1 - L1[W] G1 - L0[O] M4
# [  0] Utilization = 0.38 | pJ/Compute =   71.605 | L6[WIO] C16 - L5[IO] M32 C16 - L4[] G1 M8X - L3[] G1 C8Y - L2[I] G1 - L1[W] C2 - L0[O] M16
# [  2] Utilization = 0.38 | pJ/Compute =   71.577 | L6[WIO] C2 M8 - L5[IO] M4 C32 - L4[] G1 M8X - L3[] G1 C8Y - L2[I] G1 - L1[W] C8 - L0[O] M16
# [  1] Utilization = 0.38 | pJ/Compute =   71.554 | L6[WIO] M8 - L5[IO] M4 C256 - L4[] G1 M8X - L3[] G1 M2Y C4Y - L2[I] G1 - L1[W] C4 - L0[O] M8
# [  3] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
# [  0] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
# [  2] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
# [  1] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
#
#
# Summary stats for best mapping found by mapper:
#   Utilization = 0.38 | pJ/Compute =   71.539
#
#
# Running mapper for target eyeriss_like in /home/workspace/example_designs/example_designs/eyeriss_like/outputs/7...
# input file: /home/workspace/example_designs/example_designs/eyeriss_like/outputs/7/parsed-processed-input.yaml
#   _______                __
#  /_  __(_)___ ___  ___  / /___  ____  ____
#   / / / / __ `__ \/ _ \/ / __ \/ __ \/ __ \
#  / / / / / / / / /  __/ / /_/ / /_/ / /_/ /
# /_/ /_/_/ /_/ /_/\___/_/\____/\____/ .___/
#                                   /_/
#
# Problem configuration complete.
# execute:/usr/local/bin/accelergy /home/workspace/example_designs/example_designs/eyeriss_like/outputs/7/parsed-processed-input.yaml --oprefix timeloop-mapper. -o ./ > timeloop-mapper.accelergy.log 2>&1
# Generate Accelergy ERT (energy reference table) to replace internal energy model.
# Generate Accelergy ART (area reference table) to replace internal area model.
# Architecture configuration complete.
# Sparse optimization configuration complete.
# Using threads = 4
# Mapper configuration complete.
# Initializing Index Factorization subspace.
#   Factorization options along problem dimension C = 455
#   Factorization options along problem dimension M = 1225
#   Factorization options along problem dimension R = 1
#   Factorization options along problem dimension S = 1
#   Factorization options along problem dimension N = 1
#   Factorization options along problem dimension P = 1
#   Factorization options along problem dimension Q = 1
#   Factorization options along problem dimension G = 1
# Mapspace Dimension [IndexFactorization] Size: 557375
# Mapspace Dimension [LoopPermutation] Size: 4
# Mapspace Dimension [Spatial] Size: 1
# Mapspace Dimension [DatatypeBypass] Size: 1
# Mapspace split! Per-split Mapping Dimension [IndexFactorization] Size: 139344 Residue: 1
# Mapspace construction complete.
# Search configuration complete.
# [  0] Utilization = 0.10 | pJ/Compute =   72.924 | L6[WIO] C8 M125 - L5[IO] C32 - L4[] G1 M2X - L3[] G1 M4Y C2Y - L2[I] G1 - L1[W] C8 - L0[O] G1
# [  1] Utilization = 0.05 | pJ/Compute =   72.007 | L6[WIO] C8 M5 - L5[IO] M5 C32 - L4[] G1 M8X - L3[] G1 - L2[I] G1 - L1[W] C16 - L0[O] M5
# [  2] Utilization = 0.30 | pJ/Compute =   72.512 | L6[WIO] M2 C32 - L5[IO] C8 M10 - L4[] G1 M10X - L3[] G1 M5Y - L2[I] G1 - L1[W] C16 - L0[O] G1
# [  3] Utilization = 0.60 | pJ/Compute =   72.545 | L6[WIO] M2 C32 - L5[IO] C8 M10 - L4[] G1 M10X - L3[] G1 M5Y C2Y - L2[I] G1 - L1[W] C8 - L0[O] G1
# [  0] Utilization = 0.10 | pJ/Compute =   72.007 | L6[WIO] C8 M5 - L5[IO] M5 C256 - L4[] G1 M8X - L3[] G1 C2Y - L2[I] G1 - L1[W] G1 - L0[O] M5
# [  1] Utilization = 0.12 | pJ/Compute =   74.256 | L6[WIO] C64 M5 - L5[IO] M10 C8 - L4[] G1 M5X - L3[] G1 C4Y - L2[I] G1 - L1[W] C2 - L0[O] M4
# [  1] Utilization = 0.19 | pJ/Compute =   72.819 | L6[WIO] C8 M125 - L5[IO] C16 - L4[] G1 M4X - L3[] G1 C8Y - L2[I] G1 - L1[W] C4 - L0[O] M2
# [  0] Utilization = 0.12 | pJ/Compute =   75.554 | L6[WIO] M2 C64 - L5[IO] C16 M25 - L4[] G1 M5X - L3[] G1 C4Y - L2[I] G1 - L1[W] G1 - L0[O] M4
# [  0] Utilization = 0.24 | pJ/Compute =   72.181 | L6[WIO] C4 M50 - L5[IO] C8 M2 - L4[] G1 M5X - L3[] G1 C8Y - L2[I] G1 - L1[W] C16 - L0[O] M2
# [  0] Utilization = 0.38 | pJ/Compute =   90.249 | L6[WIO] C512 M5 - L5[IO] M5 - L4[] G1 M10X - L3[] G1 M2Y C4Y - L2[I] G1 - L1[W] C2 - L0[O] M2
# [  1] Utilization = 0.48 | pJ/Compute =   72.516 | L6[WIO] C32 - L5[IO] C8 M10 - L4[] G1 M10X - L3[] G1 M2Y C4Y - L2[I] G1 - L1[W] C4 - L0[O] M5
# [  0] Utilization = 0.48 | pJ/Compute =   72.365 | L6[WIO] C16 M25 - L5[IO] C32 - L4[] G1 M10X - L3[] G1 M2Y C4Y - L2[I] G1 - L1[W] C2 - L0[O] M2
# [  1] Utilization = 0.48 | pJ/Compute =   72.318 | L6[WIO] C16 M5 - L5[IO] M5 C2 - L4[] G1 M10X - L3[] G1 C8Y - L2[I] G1 - L1[W] C16 - L0[O] M4
# [  0] Utilization = 0.60 | pJ/Compute =   71.688 | L6[WIO] C32 - L5[IO] M2 C8 - L4[] G1 M10X - L3[] G1 M10Y - L2[I] G1 - L1[W] C16 - L0[O] M5
# [  2] Utilization = 0.48 | pJ/Compute =   73.374 | L6[WIO] G1 - L5[IO] C512 M25 - L4[] G1 M8X - L3[] G1 M5Y C2Y - L2[I] G1 - L1[W] C4 - L0[O] G1
# [  1] Utilization = 0.48 | pJ/Compute =   71.858 | L6[WIO] M2 C32 - L5[IO] C2 M25 - L4[] G1 M10X - L3[] G1 M2Y C4Y - L2[I] G1 - L1[W] C16 - L0[O] G1
# [  3] Utilization = 0.60 | pJ/Compute =   72.475 | L6[WIO] C256 - L5[IO] M2 C4 - L4[] G1 M10X - L3[] G1 M5Y C2Y - L2[I] G1 - L1[W] C2 - L0[O] M10
# [  1] Utilization = 0.60 | pJ/Compute =   76.506 | L6[WIO] C128 M4 - L5[IO] M5 C2 - L4[] G1 M10X - L3[] G1 M5Y C2Y - L2[I] G1 - L1[W] C8 - L0[O] G1
# [  0] Utilization = 0.60 | pJ/Compute =   71.551 | L6[WIO] G1 - L5[IO] C512 - L4[] G1 M10X - L3[] G1 M10Y - L2[I] G1 - L1[W] C8 - L0[O] M10
# [  3] Utilization = 0.60 | pJ/Compute =   71.638 | L6[WIO] C8 - L5[IO] M5 C64 - L4[] G1 M10X - L3[] G1 M5Y C2Y - L2[I] G1 - L1[W] C4 - L0[O] M4
# [  2] Utilization = 0.60 | pJ/Compute =   72.937 | L6[WIO] C32 M5 - L5[IO] M2 C16 - L4[] G1 M10X - L3[] G1 M10Y - L2[I] G1 - L1[W] C8 - L0[O] G1
# [  2] Utilization = 0.60 | pJ/Compute =   72.159 | L6[WIO] C16 M5 - L5[IO] C128 - L4[] G1 M10X - L3[] G1 M5Y C2Y - L2[I] G1 - L1[W] G1 - L0[O] M4
# [  2] Utilization = 0.60 | pJ/Compute =   71.551 | L6[WIO] C16 - L5[IO] C128 - L4[] G1 M10X - L3[] G1 M10Y - L2[I] G1 - L1[W] C2 - L0[O] M10
# [  1] Utilization = 0.60 | pJ/Compute =   71.996 | L6[WIO] C128 - L5[IO] M4 - L4[] G1 M10X - L3[] G1 M5Y C2Y - L2[I] G1 - L1[W] C16 - L0[O] M5
# [  0] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
# [  3] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
# [  2] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
# [  1] STATEMENT: 100 suboptimal mappings found since the last upgrade, terminating search.
#
#
# Summary stats for best mapping found by mapper:
#   Utilization = 0.60 | pJ/Compute =   71.551

# %%
import yaml
import re
import os

macro = {}
total_per_energy = {}

dnn_layers = {
    "alexnet": 8,
    "vgg16": 16,
    "dpt_large": 227,
    "gpt2": 145,
    "mobilebert": 409,
    "vision_transformer": 98,
    "resnet18": 21,
    "mobilenet_v3": 64,
    "alexnet-1layer": 1
}

# Define the architecture
array_sizes = 128
tech_node = 32
time = "fast"

dnn_list = ["alexnet"]
for DNN in dnn_list:
    
    dnn_layer = dnn_layers.get(DNN, None)

    def extract_range(line):
        match = re.search(r'\[(\d+):(\d+)(,\d+)?\)', line)
        if match:
            start = int(match.group(1))
            end = int(match.group(2))
            return end - start
        return None
    
    def read_and_compute_multiplication(filename, i, format_layer):
        filename = f"/home/workspace/example_designs/example_designs/eyeriss_like/{filename}/{filename}_{array_sizes}/outputs/{i:0{format_layer}d}/timeloop-mapper.map.txt"
        with open(filename, 'r') as file:
            lines = file.readlines()
    
        start_searching = False
        ranges = []
    
        for line in lines:
            # Start searching when 'inter_macro_in_system_spatial' is found
            if "inter_PE_spatial" in line:
                start_searching = True
            
            # Stop searching if we leave the 'inter_macro_in_system_spatial' section
            elif start_searching and "inter_" in line and "inter_PE_spatial" not in line:
                break
    
            # If we are in the 'inter_macro_in_system_spatial' section, look for the ranges
            if start_searching:
                if "for" in line:
                    range_size = extract_range(line)
                    if range_size is not None:
                        ranges.append(range_size)
                elif line.strip() == "":  # Exit the section on an empty line
                    break
    
        # Compute the multiplication of all ranges, or return 1 if no ranges were found
        if not ranges:
            # print(f"All macro: 1")
            return 1
    
        result = 1
        for size in ranges:
            result *= size
        #     print(f"Size: {size}")
        # print(f"All macro: {result}")
        return result
    
    
    def extract_layer_number(folder_name):
        m = re.match(r'^(\d+)$', folder_name)
        return int(m.group(1)) if m else float('inf')
    
    
    def extract_outputs(model, format_layer):
        
        output_dir = "/home/workspace/example_designs/example_designs/eyeriss_like/" + model +  "/" + model + "_" + str(array_sizes) +"/outputs/" 
        # print(output_dir)
        #for model in models:    
        throughput = 0   
        energy = 0
        area = 0
        cycles = 0
        folders = sorted(
        (f for f in os.listdir(output_dir)
           if os.path.isdir(os.path.join(output_dir, f)) and f.isdigit()),
        key=extract_layer_number)
    
        # print(folders)
        area_per_many_macro = 0
        area_layer = 0
        j = 0
        total_sum = 0
        total_adc_area = 0  # Total area for ADC across all layers
        total_other_areas = {}  # Dictionary to store total areas for other components
        total_col_area = 0
        total_row_area = 0
        total_cim_unit_area = 0
        total_area = 0
        total_macro = 0
        total_inter_PE           = 0.0
        total_weight_reg         = 0.0
        total_input_activation   = 0.0
        total_output_activation  = 0.0
        total_shared_glb         = 0.0
        total_pe_spad            = 0.0
        total_mac                = 0.0
        
        for folder in folders:
            total = 0
            print(f"Processing layer: {folder}")
            # print(folder)
            if os.path.isdir(output_dir + folder):
                stat_file = output_dir + folder + "/timeloop-mapper.stats.txt"
                art_file = output_dir + folder + "/timeloop-mapper.ART.yaml"
        
                with open(stat_file, 'r') as f:
                    energy_stat = [line for line in f if line.startswith("Energy:")][0]
                    energy_uj = energy_stat.split(' ')[1] # uJ
                    energy += float(energy_uj)
                    print(f"Energy for this layer: {float(energy_uj)} uj")
                
                with open(stat_file, 'r') as f:
                    cycle_stat = [line for line in f if line.startswith("Cycles:")][0]                  
                    cycle = cycle_stat.split(' ')[1] 
                    cycles += float(cycle)
                    # print(f"Cycle: {cycle}")
                print(f"Latency: {float(cycle)* 1e-9 * 1e+3} ms \n")
                # print(f"Power: {float(energy_uj)*1e3/(float(cycle)* 1e-9)} mW \n")
                # print(f"Total Throughput: {1/(float(cycle)* 1e-7)} inf/s \n")
                    
            if j < dnn_layer:
                with open(art_file, 'r') as file:
                    data = yaml.safe_load(file)
                
                    # Extract and print the name, area, number of entries, and ratio for non-zero areas
                for table in data['ART']['tables']:
                    name = table.get('name')
                    area = table.get('area')
                    if area != 0:
                        # Simplify the name for the output
                        if 'system_top_level.' in name:
                            name = name.split('system_top_level.')[-1]
                        
                        # Extract the number of entries from the name
                        if '[' in name:
                            name_part, entries_part = name.split('[')
                            number_of_entries = entries_part.split('..')[1].replace(']', '')
                            name = name_part.strip()
                        else:
                            number_of_entries = 'Unknown'
                        
                        macro = read_and_compute_multiplication(model, j, format_layer)
                        # Calculate total ratio
                        if number_of_entries != 'Unknown' and number_of_entries.isdigit():
                            total_ratio = (area / 4096) * macro * int(number_of_entries)
                        else:
                            total_ratio = 0
                        
                        total += total_ratio
                        
                        # Accumulate area for ADC or other components
                        if 'adc' in name.lower():
                            total_adc_area += total_ratio
                        else:
                            if name not in total_other_areas:
                                total_other_areas[name] = 0
                            total_other_areas[name] += total_ratio
            
                        # print(f"{name.replace('_', ' ')} area: {area}, number of {name}: {number_of_entries}, \ntotal {name.replace('_', ' ')} area: ({area}*{number_of_entries}/4096) * macro = {total_ratio}\n")
                j += 1 
                total_sum += total
                total_macro += macro
            #     print(f"Total Area for layer {j}: {total}\n")
            #     print(f"Total Macro for layer {j}: {total_macro}\n")
            # print(f"Total Area for all layers: {total_sum}")
            # print(f"Total Area for ADC across all layers: {total_adc_area}")
        
        # Print total area for other components
        for component, area in total_other_areas.items():
            # print(f"Total Area for {component.replace('_', ' ')} across all layers: {area}")
            # print(component.replace('_', ' '))
            if component.replace('_', ' ') ==  "column drivers":
                total_col_area = area
            elif component.replace('_', ' ') ==  "row drivers":
                total_row_area = area
    
            elif component.replace('_', ' ') == "inter PE spatial":
                total_inter_PE = area
        
            elif component.replace('_', ' ') == "weight reg":
                total_weight_reg = area
        
            elif component.replace('_', ' ') == "input activation reg":
                total_input_activation = area
        
            elif component.replace('_', ' ') == "output activation reg":
                total_output_activation = area
        
            elif component.replace('_', ' ') == "shared glb":
                total_shared_glb = area
        
            elif component.replace('_', ' ') == "pe spad":
                total_pe_spad = area
        
            elif component.replace('_', ' ') == "mac":
                total_mac = area
        
            else:
                # anything else you didn’t explicitly match
                total_cim_unit_area += area
                                    
        energy *= 1e-6 # conver to J
        total_area = total_sum * 1e-6 # mm2
        throughput = 1 / (cycles * 1e-9) # s
       # convert all areas from µm² to mm²
    
        total_adc_area = total_adc_area * 1e-6 # mm2
        total_col_area = total_col_area * 1e-6 # mm2
        total_row_area = total_row_area * 1e-6 # mm2
        total_cim_unit_area = total_cim_unit_area * 1e-6 # mm2
        total_inter_PE           = total_inter_PE          * 1e-6
        total_weight_reg         = total_weight_reg        * 1e-6
        total_input_activation   = total_input_activation  * 1e-6
        total_output_activation  = total_output_activation * 1e-6
        total_shared_glb         = total_shared_glb        * 1e-6
        total_pe_spad            = total_pe_spad           * 1e-6
        total_mac                = total_mac               * 1e-6
    
        # print(f"Total Area for ADC across all layers: {total_adc_area}")
        # print(f"Total Area for column driver across all layers: {total_col_area}")
        # print(f"Total Area for row driver across all layers: {total_row_area}")
        # print(f"Total Area for cim unit across all layers: {total_cim_unit_area}")
        # print(f"Total Area for inter PE spatial across all layers: {total_inter_PE}")
        # print(f"Total Area for weight register across all layers: {total_weight_reg}")
        # print(f"Total Area for input activation register across all layers: {total_input_activation}")
        # print(f"Total Area for output activation register across all layers: {total_output_activation}")
        # print(f"Total Area for shared global buffer across all layers: {total_shared_glb}")
        # print(f"Total Area for PE scratchpad across all layers: {total_pe_spad}")
        # print(f"Total Area for MAC units across all layers: {total_mac}")
        # print(f"Total Macro across all layers: {total_macro}")
        print(f"Total Latency: {cycles* 1e-9 * 1e+3} ms\n")
        print ("Model \t Energy/inference (J) \t Area (mm2) \t Throughput (inf/s) \t Latency (s)")
        print ("{} \t {:.2e} \t {:.2f} \t {:.2e} \t {:.2e}".format(model, energy, total_area, throughput, (cycles * 1e-9)))
        
        return total_area, total_adc_area, total_col_area, total_row_area, total_cim_unit_area, total_macro, energy, throughput

# %%
# Initialize lists for each DNN
num_dnns = len(dnn_list)
total_area = [0] * (2 * num_dnns)
total_adc_area = [0] * (2 * num_dnns)
total_col_area = [0] * (2 * num_dnns)
total_row_area = [0] * (2 * num_dnns)
total_cim_unit_area = [0] * (2 * num_dnns)
total_macro = [0] * (2 * num_dnns)
energy = [0] * (2 * num_dnns)
throughput = [0] * (2 * num_dnns)

# Loop through both DNNs and extract their outputs for SRAM and RRAM
for i, dnn in enumerate(dnn_list):
    dnn_layer = dnn_layers.get(dnn, None)
    if dnn_layer < 10:
        format_layer = 1
    elif dnn_layer >= 10 and dnn_layer < 100:
        format_layer = 2
    else:
        format_layer = 3
    total_area[2 * i], total_adc_area[2 * i], total_col_area[2 * i], total_row_area[2 * i], total_cim_unit_area[2 * i], total_macro[2 * i], energy[2 * i], throughput[2 * i] = extract_outputs(f"{dnn}", format_layer)
# Out:
# Processing layer: 0
# Energy for this layer: 441.7 uj
# Latency: 0.6388800000000001 ms
#
# Processing layer: 1
# Energy for this layer: 1918.81 uj
# Latency: 2.3328 ms
#
# Processing layer: 2
# Energy for this layer: 747.95 uj
# Latency: 0.718848 ms
#
# Processing layer: 3
# Energy for this layer: 974.02 uj
# Latency: 1.437696 ms
#
# Processing layer: 4
# Energy for this layer: 657.52 uj
# Latency: 0.6389760000000001 ms
#
# Processing layer: 5
# Energy for this layer: 2702.35 uj
# Latency: 0.39321600000000007 ms
#
# Processing layer: 6
# Energy for this layer: 1200.23 uj
# Latency: 0.26214400000000004 ms
#
# Processing layer: 7
# Energy for this layer: 293.07 uj
# Latency: 0.04096 ms
#
# Total Latency: 6.463520000000001 ms
#
# Model 	 Energy/inference (J) 	 Area (mm2) 	 Throughput (inf/s) 	 Latency (s)
# alexnet 	 8.94e-03 	 0.29 	 1.55e+02 	 6.46e-03

# %%
print("\n### Area and Performance Results ###\n")

for i, dnn in enumerate(dnn_list):
    print(f"Results for {dnn}:")
    # print(f"  Total Area: {total_area[2 * i]} mm2")
    # print(f"  Total Macro: {total_macro[2 * i]}")
    print(f"  Energy: {energy[2 * i]} J")
    print(f"  Throughput: {throughput[2 * i]} inf/s \n")
# Out:
# ### Area and Performance Results ###
#
# Results for alexnet:
#   Energy: 0.00893565 J
#   Throughput: 154.71445899447977 inf/s
