# %%
from _import_scripts import scripts
from scripts.notebook_utils import *
from scripts.tl_output_parsing import MacroOutputStats
from scripts.utils import *
import yaml

def create_layer_directory(base_output_dir: str, architecture: str, layer: int) -> str:
    layer_dir = os.path.join(base_output_dir, f"{architecture}_layer_{layer}")
    if not os.path.exists(layer_dir):
        os.makedirs(layer_dir)
    return layer_dir

num_layers = 1

def run_map(
    spec: tl.Specification,
    arch: str,
    accelergy_verbose: bool = False,
) -> dict:
    output_dir = get_run_dir()
    # Just use the directory name if it causes error
    base_output_dir = os.path.dirname(output_dir)
    base_output_dir = os.path.join(base_output_dir, arch)
    global num_layers

    mapper_result = None

    if num_layers < 17:
        # Create a directory for the current layer
        layer_dir = create_layer_directory(base_output_dir, arch, num_layers)
        # print(f"Layer directory: {layer_dir}")
        num_layers += 1

        run_prefix = f"{layer_dir}/timeloop-mapper"
        mapper_result = tl.call_mapper(
            specification=spec,
            output_dir=layer_dir,
            log_to=os.path.join(output_dir, f"{run_prefix}.log"),
        )
        if accelergy_verbose:
            tl.call_accelergy_verbose(
                specification=spec,
                output_dir=layer_dir,
                log_to=os.path.join(output_dir, "accelergy.log"),
            )

    if mapper_result is None:
        # Handle case when mapper_result is not assigned (num_layers >= 17)
        # Raise an error, return a default value
        print("Warning: mapper_result is not assigned. num_layers >= 17")
        return {}

    return MacroOutputStats.from_output_stats(mapper_result)

import re

def extract_range(line):
    match = re.search(r'\[(\d+):(\d+)(,\d+)?\)', line)
    if match:
        start = int(match.group(1))
        end = int(match.group(2))
        return end - start
    return None

def read_and_compute_multiplication(filename, i):
    filename = f"../outputs/{filename}/{filename}_layer_{i+1}/timeloop-mapper.map.txt"
    with open(filename, 'r') as file:
        lines = file.readlines()

    start_searching = False
    ranges = []

    for line in lines:
        # Start searching when 'inter_macro_in_system_spatial' is found
        if "inter_macro_in_system_spatial" in line:
            start_searching = True
        
        # Stop searching if we leave the 'inter_macro_in_system_spatial' section
        elif start_searching and "inter_" in line and "inter_macro_in_system_spatial" not in line:
            break

        # If we are in the 'inter_macro_in_system_spatial' section, look for the ranges
        if start_searching:
            if "for" in line:
                range_size = extract_range(line)
                if range_size is not None:
                    ranges.append(range_size)
            elif line.strip() == "":  # Exit the section on an empty line
                break

    # Compute the multiplication of all ranges, or return 1 if no ranges were found
    if not ranges:
        print(f"All macro: 1")
        return 1

    result = 1
    for size in ranges:
        result *= size
        print(f"Size: {size}")
    print(f"All macro: {result}")
    return result


def extract_layer_number(folder_name):
    match = re.search(r'layer_(\d+)', folder_name)
    return int(match.group(1)) if match else float('inf')

def extract_outputs(model):
    
    output_dir = "../outputs/" + model + "/" 
    print(output_dir)

    print ("Model \t Energy/inference (J) \t Area (mm2) \t Throughput (inf/s)")
    #for model in models:    
    throughput = 0   
    energy = 0
    area = 0
    cycles = 0
    folders = sorted([folder for folder in os.listdir(output_dir) if model in folder], key=extract_layer_number)
    area_per_many_macro = 0
    area_layer = 0
    j = 0
    total_sum = 0
    total_adc_area = 0  # Total area for ADC across all layers
    total_other_areas = {}  # Dictionary to store total areas for other components
    total_col_area = 0
    total_row_area = 0
    total_cim_unit_area = 0
    total_area = 0
    total_macro = 0
    
    for folder in folders:
        total = 0
        if model in folder:
            print(f"Processing layer: {folder}")
            # print(folder)
            if os.path.isdir(output_dir + folder):
                stat_file = output_dir + folder + "/timeloop-mapper.stats.txt"
                art_file = output_dir + folder + "/timeloop-mapper.ART.yaml"
        
                with open(stat_file, 'r') as f:
                    energy_stat = [line for line in f if line.startswith("Energy:")][0]
                    energy_uj = energy_stat.split(' ')[1] # uJ
                    energy += float(energy_uj)
                    # print(f"Energy for this layer: {float(energy_uj)} uj")
                
                with open(stat_file, 'r') as f:
                    cycle_stat = [line for line in f if line.startswith("Cycles:")][0]                  
                    cycle = cycle_stat.split(' ')[1] 
                    cycles += float(cycle)
                    
            if j < 16:
                with open(art_file, 'r') as file:
                    data = yaml.safe_load(file)
                
                    # Extract and print the name, area, number of entries, and ratio for non-zero areas
                for table in data['ART']['tables']:
                    name = table.get('name')
                    area = table.get('area')
                    if area != 0:
                        # Simplify the name for the output
                        if 'system_top_level.' in name:
                            name = name.split('system_top_level.')[-1]
                        
                        # Extract the number of entries from the name
                        if '[' in name:
                            name_part, entries_part = name.split('[')
                            number_of_entries = entries_part.split('..')[1].replace(']', '')
                            name = name_part.strip()
                        else:
                            number_of_entries = 'Unknown'
                        
                        macro = read_and_compute_multiplication(model, j)
                        # Calculate total ratio
                        if number_of_entries != 'Unknown' and number_of_entries.isdigit():
                            total_ratio = (area / 4096) * macro * int(number_of_entries)
                        else:
                            total_ratio = 0
                        
                        total += total_ratio
                           
                        # Accumulate area for ADC or other components
                        if 'adc' in name.lower():
                            total_adc_area += total_ratio
                        else:
                            if name not in total_other_areas:
                                total_other_areas[name] = 0
                            total_other_areas[name] += total_ratio
            
                        print(f"{name.replace('_', ' ')} area: {area}, number of {name}: {number_of_entries}, \ntotal {name.replace('_', ' ')} area: ({area}*{number_of_entries}/4096) * macro = {total_ratio}\n")
                j += 1 
                total_sum += total
                total_macro += macro
                print(f"Total Area for layer {j}: {total}\n")
                print(f"Total Macro for layer {j}: {total_macro}\n")
            print(f"Total Area for all layers: {total_sum}")
            print(f"Total Area for ADC across all layers: {total_adc_area}")
    
    # Print total area for other components
    for component, area in total_other_areas.items():
        print(f"Total Area for {component.replace('_', ' ')} across all layers: {area}")
        # print(component.replace('_', ' '))
        if component.replace('_', ' ') ==  "column drivers":
            total_col_area = area
        elif component.replace('_', ' ') ==  "row drivers":
            total_row_area = area
        else:
            total_cim_unit_area = area
                                
    energy *= 1e-6 # conver to J
    total_area = total_sum * 1e-6 # mm2
    throughput = 1 / (cycles * 1e-7) # s

    total_adc_area = total_adc_area * 1e-6 # mm2
    total_col_area = total_col_area * 1e-6 # mm2
    total_row_area = total_row_area * 1e-6 # mm2
    total_cim_unit_area = total_cim_unit_area * 1e-6 # mm2
    print("\n")
    print(f"Total Area for ADC across all layers: {total_adc_area}")
    print(f"Total Area for column driver across all layers: {total_col_area}")
    print(f"Total Area for row driver across all layers: {total_row_area}")
    print(f"Total Area for cim unit across all layers: {total_cim_unit_area}")
    print(f"Total Macro across all layers: {total_macro}")
    print ("{} \t {:.2e} \t {:.2f} \t {:.2e}".format(model, energy, total_area, throughput))
    
    return total_area, total_adc_area, total_col_area, total_row_area, total_cim_unit_area, total_macro, energy, throughput

# %%
MACRO_PATH = "../models/arch/1_macro/basic_analog/" 
macro = {}
SRAM_PATH = f'"{os.path.abspath("../models/memory_cells/sram_example.cell.yaml")}"'
RRAM_PATH = f'"{os.path.abspath("../models/memory_cells/rram_example.cell.yaml")}"'

# Define the architecture
array_sizes_list = [32, 64, 128, 256]
path = RRAM_PATH
tech_node = 22
adc_resolution = 5
DNN = "vgg16"

total_per_energy = {}

for array_sizes in array_sizes_list:
    arch = f"{path.split('/')[-1].split('_')[0].upper()}_{DNN}_{array_sizes}"
    print(f"\nRunning {DNN} with {array_sizes} x {array_sizes} {path.split('/')[-1].split('_')[0].upper()} with {tech_node} nm ")

    num_layers = 1

    def run_dnn(dnn: str, layer: str, array_sizes: int, variables):
        print(f"{layer} ", end="", flush=True)
        spec = get_spec(
            "basic_analog",
            # Weight-stationary, dummy buffer on top to hold inputs & outputs, many
            # macros to ensure we can fit all weights.
            system="ws_dummy_buffer_many_macro",
            # Set the DNN and layer
            dnn=dnn,
            layer=layer,
        )
    
        # Do NOT generate a maximum-utilization workload; we're running a DNN
        # workload.
        spec.variables["MAX_UTILIZATION"] = False
    
        # Use a larger array to ensure we can fit all weights
        spec.architecture.find("column").spatial.meshX = array_sizes
        spec.architecture.find("row").spatial.meshY = array_sizes
    
        spec.variables.update(variables)
        output_stats = run_map(spec, arch)
        
        # Print computes for the layer
        macro_output_stats = MacroOutputStats.from_output_stats(output_stats)
        print(f"Computes for layer {int(layer) + 1}: {macro_output_stats.computes}")
        global macro
        macro[layer] = macro_output_stats.computes
        return output_stats
    
    layers = [f for f in os.listdir(f"../models/workloads/{DNN}") if f != "index.yaml" and f.endswith(".yaml")]
    layers = sorted(layers)
    print(f"Running: ", end="")
    
    # Parallel/Delayed is used to multiprocess. Equivalent to running the following
    # code in serial:
    results = joblib.Parallel(n_jobs=None)(
        joblib.delayed(run_dnn)(DNN, layer.split(".")[0], array_sizes, 
                                  {
                                      "CELL_CONFIG": path,
                                      "BITS_PER_CELL": 1 if path == SRAM_PATH else 4,
                                      "CIM_UNIT_WIDTH_CELLS": 4 if path == SRAM_PATH else 1,
                                      "IS_SRAM": path == SRAM_PATH,
                                      "TECHNOLOGY": tech_node,
                                      "ADC_RESOLUTION": adc_resolution
                                  }
                                 ) for layer in layers
    )
    print("")
    for r in results:
        r.clear_zero_energies()
    
    #Initialize overall_energy
    energy_layer = [0] * 16
    result = 0
    
    # total_per_energy_32 = [0] * 4
    
    total_adc_energy = 0.0
    total_col_energy = 0.0
    total_row_energy = 0.0
    total_cim_unit_energy = 0.0
    # Calculate overall energy
    for r in results:
    
        per_component_energy = r.per_compute("per_component_energy")
        total_energy_per_layer = sum(per_component_energy.values()) * 1e15  # Convert to fJ
        total_adc_energy += per_component_energy.get('adc', 0.0)
        total_col_energy += per_component_energy.get('column_drivers', 0.0)
        total_row_energy += per_component_energy.get('row_drivers', 0.0)
        total_cim_unit_energy += per_component_energy.get('cim_unit', 0.0)
    
        total_adc_energy = total_adc_energy * 1e15
        total_col_energy = total_col_energy * 1e15
        total_row_energy = total_row_energy * 1e15
        total_cim_unit_energy = total_cim_unit_energy * 1e15
        total_energy = total_adc_energy + total_col_energy + total_row_energy + total_cim_unit_energy
    
        total_adc_energy = total_adc_energy/total_energy
        total_col_energy = total_col_energy/total_energy
        total_row_energy = total_row_energy/total_energy
        total_cim_unit_energy = total_cim_unit_energy/total_energy
      
        # total_per_energy_32[0] = total_adc_energy
        # total_per_energy_32[1] = total_col_energy
        # total_per_energy_32[2] = total_row_energy
        # total_per_energy_32[3] = total_cim_unit_energy

        total_per_energy[array_sizes] = [total_adc_energy, total_col_energy, total_row_energy, total_cim_unit_energy]
        
    # Display overall energy
    print(f"Overall energy for DNN {DNN}: {total_energy} fJ")
    
    # Display an energy breakdown for each layer as a bar chart. Display normalized per-MAC and per-layer energy.
    fig, ax = plt.subplots(figsize=(20, 5))
    
    bar_stacked(
        {i: r.per_compute("per_component_energy") * 1e15 for i, r in enumerate(results)},
        title= f"Using {path.split('/')[-1].split('_')[0].upper()} on {array_sizes} x {array_sizes} array sizes, {tech_node} nm",
        xlabel="Layer",
        ylabel="Energy (fJ/MAC)",
        ax=ax,
    )
# Out:
# Running vgg16 with 32 x 32 RRAM with 22 nm
# Computes for layer 1: 169344.0
# Computes for layer 2: 3612672.0
# Computes for layer 3: 1806336.0
# Computes for layer 4: 3612672.0
# Computes for layer 5: 1806336.0
# Computes for layer 6: 3612672.0
# Computes for layer 7: 3612672.0
# Computes for layer 8: 1806336.0
# Computes for layer 9: 3612672.0
# Computes for layer 10: 3612672.0
# Computes for layer 11: 903168.0
# Computes for layer 12: 903168.0
# Computes for layer 13: 903168.0
# Computes for layer 14: 200704.0
# Computes for layer 15: 32768.0
# Computes for layer 16: 8000.0
#
# Overall energy for DNN vgg16: 1000000000000057.0 fJ
#
# Running vgg16 with 64 x 64 RRAM with 22 nm
# Computes for layer 1: 169344.0
# Computes for layer 2: 3612672.0
# Computes for layer 3: 1806336.0
# Computes for layer 4: 3612672.0
# Computes for layer 5: 1806336.0
# Computes for layer 6: 3612672.0
# Computes for layer 7: 3612672.0
# Computes for layer 8: 1806336.0
# Computes for layer 9: 3612672.0
# Computes for layer 10: 3612672.0
# Computes for layer 11: 903168.0
# Computes for layer 12: 903168.0
# Computes for layer 13: 903168.0
# Computes for layer 14: 200704.0
# Computes for layer 15: 32768.0
# Computes for layer 16: 8000.0
#
# Overall energy for DNN vgg16: 1000000000000034.1 fJ
#
# Running vgg16 with 128 x 128 RRAM with 22 nm
# Computes for layer 1: 169344.0
# Computes for layer 2: 3612672.0
# Computes for layer 3: 1806336.0
# Computes for layer 4: 3612672.0
# Computes for layer 5: 1806336.0
# Computes for layer 6: 3612672.0
# Computes for layer 7: 3612672.0
# Computes for layer 8: 1806336.0
# Computes for layer 9: 3612672.0
# Computes for layer 10: 3612672.0
# Computes for layer 11: 903168.0
# Computes for layer 12: 903168.0
# Computes for layer 13: 903168.0
# Computes for layer 14: 200704.0
# Computes for layer 15: 32768.0
# Computes for layer 16: 8000.0
#
# Overall energy for DNN vgg16: 1000000000000022.1 fJ
#
# Running vgg16 with 256 x 256 RRAM with 22 nm
# Computes for layer 1: 169344.0
# Computes for layer 2: 3612672.0
# Computes for layer 3: 1806336.0
# Computes for layer 4: 3612672.0
# Computes for layer 5: 1806336.0
# Computes for layer 6: 3612672.0
# Computes for layer 7: 3612672.0
# Computes for layer 8: 1806336.0
# Computes for layer 9: 3612672.0
# Computes for layer 10: 3612672.0
# Computes for layer 11: 903168.0
# Computes for layer 12: 903168.0
# Computes for layer 13: 903168.0
# Computes for layer 14: 200704.0
# Computes for layer 15: 32768.0
# Computes for layer 16: 8000.0
#
# Overall energy for DNN vgg16: 1000000000000016.4 fJ

# %%
display_markdown(
    """
### Calculating Area

"""
)
total_area = [0] * 4
total_adc_area = [0] * 4
total_col_area = [0] * 4
total_row_area = [0] * 4
total_cim_unit_area = [0] * 4
total_macro = [0] * 4
energy = [0] * 4
throughput = [0] * 4
total_area[0], total_adc_area[0], total_col_area[0], total_row_area[0], total_cim_unit_area[0], total_macro[0], energy[0], throughput[0] = extract_outputs("RRAM_vgg16_32")
total_area[1], total_adc_area[1], total_col_area[1], total_row_area[1], total_cim_unit_area[1], total_macro[1], energy[1], throughput[1] = extract_outputs("RRAM_vgg16_64")
total_area[2], total_adc_area[2], total_col_area[2], total_row_area[2], total_cim_unit_area[2], total_macro[2], energy[2], throughput[2] = extract_outputs("RRAM_vgg16_128")
total_area[3], total_adc_area[3], total_col_area[3], total_row_area[3], total_cim_unit_area[3], total_macro[3], energy[3], throughput[3] = extract_outputs("RRAM_vgg16_256")
# Out:
# ### Calculating Area
# ../outputs/RRAM_vgg16_32/
# Model 	 Energy/inference (J) 	 Area (mm2) 	 Throughput (inf/s)
# Processing layer: RRAM_vgg16_32_layer_1
# Size: 4
# All macro: 4
# adc area: 12441.5, number of adc: 4096,
# total adc area: (12441.5*4096/4096) * macro = 49766.0
#
# Size: 4
# All macro: 4
# column drivers area: 52.1119, number of column_drivers: 4096,
# total column drivers area: (52.1119*4096/4096) * macro = 208.4476
#
# Size: 4
# All macro: 4
# row drivers area: 59.5565, number of row_drivers: 4096,
# total row drivers area: (59.5565*4096/4096) * macro = 238.226
#
# Size: 4
# All macro: 4
# cim unit area: 0.01936, number of cim_unit: 4194304,
# total cim unit area: (0.01936*4194304/4096) * macro = 79.29856
#
# Total Area for layer 1: 50291.972160000005
#
# Total Macro for layer 1: 4
#
# Total Area for all layers: 50291.972160000005
# Total Area for ADC across all layers: 49766.0
# Processing layer: RRAM_vgg16_32_layer_2
# Size: 3
# Size: 3
# Size: 4
# Size: 2
# All macro: 72
# adc area: 12441.5, number of adc: 4096,
# total adc area: (12441.5*4096/4096) * macro = 895788.0
#
# Size: 3
# Size: 3
# Size: 4
# Size: 2
# All macro: 72
# column drivers area: 52.1119, number of column_drivers: 4096,
# total column drivers area: (52.1119*4096/4096) * macro = 3752.0568
#
# Size: 3
# Size: 3
# Size: 4
# Size: 2
# All macro: 72
# row drivers area: 59.5565, number of row_drivers: 4096,
# total row drivers area: (59.5565*4096/4096) * macro = 4288.068
#
# Size: 3
# Size: 3
# Size: 4
# Size: 2
# All macro: 72
# cim unit area: 0.01936, number of cim_unit: 4194304,
# total cim unit area: (0.01936*4194304/4096) * macro = 1427.3740799999998
#
# Total Area for layer 2: 905255.49888
#
# Total Macro for layer 2: 76
#
# Total Area for all layers: 955547.47104
# Total Area for ADC across all layers: 945554.0
# Processing layer: RRAM_vgg16_32_layer_3
# Size: 3
# Size: 3
# Size: 8
# Size: 2
# All macro: 144
# adc area: 12441.5, number of adc: 4096,
# total adc area: (12441.5*4096/4096) * macro = 1791576.0
#
# Size: 3
# Size: 3
# Size: 8
# Size: 2
# All macro: 144
# column drivers area: 52.1119, number of column_drivers: 4096,
# total column drivers area: (52.1119*4096/4096) * macro = 7504.1136
#
# Size: 3
# Size: 3
# Size: 8
# Size: 2
# All macro: 144
# row drivers area: 59.5565, number of row_drivers: 4096,
# total row drivers area: (59.5565*4096/4096) * macro = 8576.136
#
# Size: 3
# Size: 3
# Size: 8
# Size: 2
# All macro: 144
# cim unit area: 0.01936, number of cim_unit: 4194304,
# total cim unit area: (0.01936*4194304/4096) * macro = 2854.7481599999996
#
# Total Area for layer 3: 1810510.99776
#
# Total Macro for layer 3: 220
#
# Total Area for all layers: 2766058.4688
# Total Area for ADC across all layers: 2737130.0
# Processing layer: RRAM_vgg16_32_layer_4
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# adc area: 12441.5, number of adc: 4096,
# total adc area: (12441.5*4096/4096) * macro = 3583152.0
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# column drivers area: 52.1119, number of column_drivers: 4096,
# total column drivers area: (52.1119*4096/4096) * macro = 15008.2272
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# row drivers area: 59.5565, number of row_drivers: 4096,
# total row drivers area: (59.5565*4096/4096) * macro = 17152.272
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# cim unit area: 0.01936, number of cim_unit: 4194304,
# total cim unit area: (0.01936*4194304/4096) * macro = 5709.496319999999
#
# Total Area for layer 4: 3621021.99552
#
# Total Macro for layer 4: 508
#
# Total Area for all layers: 6387080.46432
# Total Area for ADC across all layers: 6320282.0
# Processing layer: RRAM_vgg16_32_layer_5
# Size: 3
# Size: 3
# Size: 16
# Size: 4
# All macro: 576
# adc area: 12441.5, number of adc: 4096,
# total adc area: (12441.5*4096/4096) * macro = 7166304.0
#
# Size: 3
# Size: 3
# Size: 16
# Size: 4
# All macro: 576
# column drivers area: 52.1119, number of column_drivers: 4096,
# total column drivers area: (52.1119*4096/4096) * macro = 30016.4544
#
# Size: 3
# Size: 3
# Size: 16
# Size: 4
# All macro: 576
# row drivers area: 59.5565, number of row_drivers: 4096,
# total row drivers area: (59.5565*4096/4096) * macro = 34304.544
#
# Size: 3
# Size: 3
# Size: 16
# Size: 4
# All macro: 576
# cim unit area: 0.01936, number of cim_unit: 4194304,
# total cim unit area: (0.01936*4194304/4096) * macro = 11418.992639999999
#
# Total Area for layer 5: 7242043.99104
#
# Total Macro for layer 5: 1084
#
# Total Area for all layers: 13629124.45536
# Total Area for ADC across all layers: 13486586.0
# Processing layer: RRAM_vgg16_32_layer_6
# Size: 3
# Size: 3
# Size: 16
# Size: 8
# All macro: 1152
# adc area: 12441.5, number of adc: 4096,
# total adc area: (12441.5*4096/4096) * macro = 14332608.0
#
# Size: 3
# Size: 3
# Size: 16
# Size: 8
# All macro: 1152
# column drivers area: 52.1119, number of column_drivers: 4096,
# total column drivers area: (52.1119*4096/4096) * macro = 60032.9088
#
# Size: 3
# Size: 3
# Size: 16
# Size: 8
# All macro: 1152
# row drivers area: 59.5565, number of row_drivers: 4096,
# total row drivers area: (59.5565*4096/4096) * macro = 68609.088
#
# Size: 3
# Size: 3
# Size: 16
# Size: 8
# All macro: 1152
# cim unit area: 0.01936, number of cim_unit: 4194304,
# total cim unit area: (0.01936*4194304/4096) * macro = 22837.985279999997
#
# Total Area for layer 6: 14484087.98208
#
# Total Macro for layer 6: 2236
#
# Total Area for all layers: 28113212.43744
# Total Area for ADC across all layers: 27819194.0
# Processing layer: RRAM_vgg16_32_layer_7
# Size: 3
# Size: 3
# Size: 16
# Size: 8
# All macro: 1152
# adc area: 12441.5, number of adc: 4096,
# total adc area: (12441.5*4096/4096) * macro = 14332608.0
#
# Size: 3
# Size: 3
# Size: 16
# Size: 8
# All macro: 1152
# column drivers area: 52.1119, number of column_drivers: 4096,
# total column drivers area: (52.1119*4096/4096) * macro = 60032.9088
#
# Size: 3
# Size: 3
# Size: 16
# Size: 8
# All macro: 1152
# row drivers area: 59.5565, number of row_drivers: 4096,
# total row drivers area: (59.5565*4096/4096) * macro = 68609.088
#
# Size: 3
# Size: 3
# Size: 16
# Size: 8
# All macro: 1152
# cim unit area: 0.01936, number of cim_unit: 4194304,
# total cim unit area: (0.01936*4194304/4096) * macro = 22837.985279999997
#
# Total Area for layer 7: 14484087.98208
#
# Total Macro for layer 7: 3388
#
# Total Area for all layers: 42597300.41952
# Total Area for ADC across all layers: 42151802.0
# Processing layer: RRAM_vgg16_32_layer_8
# Size: 3
# Size: 3
# Size: 32
# Size: 8
# All macro: 2304
# adc area: 12441.5, number of adc: 4096,
# total adc area: (12441.5*4096/4096) * macro = 28665216.0
#
# Size: 3
# Size: 3
# Size: 32
# Size: 8
# All macro: 2304
# column drivers area: 52.1119, number of column_drivers: 4096,
# total column drivers area: (52.1119*4096/4096) * macro = 120065.8176
#
# Size: 3
# Size: 3
# Size: 32
# Size: 8
# All macro: 2304
# row drivers area: 59.5565, number of row_drivers: 4096,
# total row drivers area: (59.5565*4096/4096) * macro = 137218.176
#
# Size: 3
# Size: 3
# Size: 32
# Size: 8
# All macro: 2304
# cim unit area: 0.01936, number of cim_unit: 4194304,
# total cim unit area: (0.01936*4194304/4096) * macro = 45675.970559999994
#
# Total Area for layer 8: 28968175.96416
#
# Total Macro for layer 8: 5692
#
# Total Area for all layers: 71565476.38368
# Total Area for ADC across all layers: 70817018.0
# Processing layer: RRAM_vgg16_32_layer_9
# Size: 3
# Size: 3
# Size: 16
# Size: 16
# All macro: 2304
# adc area: 12441.5, number of adc: 4096,
# total adc area: (12441.5*4096/4096) * macro = 28665216.0
#
# Size: 3
# Size: 3
# Size: 16
# Size: 16
# All macro: 2304
# column drivers area: 52.1119, number of column_drivers: 4096,
# total column drivers area: (52.1119*4096/4096) * macro = 120065.8176
#
# Size: 3
# Size: 3
# Size: 16
# Size: 16
# All macro: 2304
# row drivers area: 59.5565, number of row_drivers: 4096,
# total row drivers area: (59.5565*4096/4096) * macro = 137218.176
#
# Size: 3
# Size: 3
# Size: 16
# Size: 16
# All macro: 2304
# cim unit area: 0.01936, number of cim_unit: 4194304,
# total cim unit area: (0.01936*4194304/4096) * macro = 45675.970559999994
#
# Total Area for layer 9: 28968175.96416
#
# Total Macro for layer 9: 7996
#
# Total Area for all layers: 100533652.34784
# Total Area for ADC across all layers: 99482234.0
# Processing layer: RRAM_vgg16_32_layer_10
# Size: 3
# Size: 3
# Size: 16
# Size: 16
# All macro: 2304
# adc area: 12441.5, number of adc: 4096,
# total adc area: (12441.5*4096/4096) * macro = 28665216.0
#
# Size: 3
# Size: 3
# Size: 16
# Size: 16
# All macro: 2304
# column drivers area: 52.1119, number of column_drivers: 4096,
# total column drivers area: (52.1119*4096/4096) * macro = 120065.8176
#
# Size: 3
# Size: 3
# Size: 16
# Size: 16
# All macro: 2304
# row drivers area: 59.5565, number of row_drivers: 4096,
# total row drivers area: (59.5565*4096/4096) * macro = 137218.176
#
# Size: 3
# Size: 3
# Size: 16
# Size: 16
# All macro: 2304
# cim unit area: 0.01936, number of cim_unit: 4194304,
# total cim unit area: (0.01936*4194304/4096) * macro = 45675.970559999994
#
# Total Area for layer 10: 28968175.96416
#
# Total Macro for layer 10: 10300
#
# Total Area for all layers: 129501828.31199999
# Total Area for ADC across all layers: 128147450.0
# Processing layer: RRAM_vgg16_32_layer_11
# Size: 3
# Size: 3
# Size: 16
# Size: 16
# All macro: 2304
# adc area: 12441.5, number of adc: 4096,
# total adc area: (12441.5*4096/4096) * macro = 28665216.0
#
# Size: 3
# Size: 3
# Size: 16
# Size: 16
# All macro: 2304
# column drivers area: 52.1119, number of column_drivers: 4096,
# total column drivers area: (52.1119*4096/4096) * macro = 120065.8176
#
# Size: 3
# Size: 3
# Size: 16
# Size: 16
# All macro: 2304
# row drivers area: 59.5565, number of row_drivers: 4096,
# total row drivers area: (59.5565*4096/4096) * macro = 137218.176
#
# Size: 3
# Size: 3
# Size: 16
# Size: 16
# All macro: 2304
# cim unit area: 0.01936, number of cim_unit: 4194304,
# total cim unit area: (0.01936*4194304/4096) * macro = 45675.970559999994
#
# Total Area for layer 11: 28968175.96416
#
# Total Macro for layer 11: 12604
#
# Total Area for all layers: 158470004.27616
# Total Area for ADC across all layers: 156812666.0
# Processing layer: RRAM_vgg16_32_layer_12
# Size: 3
# Size: 3
# Size: 16
# Size: 16
# All macro: 2304
# adc area: 12441.5, number of adc: 4096,
# total adc area: (12441.5*4096/4096) * macro = 28665216.0
#
# Size: 3
# Size: 3
# Size: 16
# Size: 16
# All macro: 2304
# column drivers area: 52.1119, number of column_drivers: 4096,
# total column drivers area: (52.1119*4096/4096) * macro = 120065.8176
#
# Size: 3
# Size: 3
# Size: 16
# Size: 16
# All macro: 2304
# row drivers area: 59.5565, number of row_drivers: 4096,
# total row drivers area: (59.5565*4096/4096) * macro = 137218.176
#
# Size: 3
# Size: 3
# Size: 16
# Size: 16
# All macro: 2304
# cim unit area: 0.01936, number of cim_unit: 4194304,
# total cim unit area: (0.01936*4194304/4096) * macro = 45675.970559999994
#
# Total Area for layer 12: 28968175.96416
#
# Total Macro for layer 12: 14908
#
# Total Area for all layers: 187438180.24032
# Total Area for ADC across all layers: 185477882.0
# Processing layer: RRAM_vgg16_32_layer_13
# Size: 3
# Size: 3
# Size: 16
# Size: 16
# All macro: 2304
# adc area: 12441.5, number of adc: 4096,
# total adc area: (12441.5*4096/4096) * macro = 28665216.0
#
# Size: 3
# Size: 3
# Size: 16
# Size: 16
# All macro: 2304
# column drivers area: 52.1119, number of column_drivers: 4096,
# total column drivers area: (52.1119*4096/4096) * macro = 120065.8176
#
# Size: 3
# Size: 3
# Size: 16
# Size: 16
# All macro: 2304
# row drivers area: 59.5565, number of row_drivers: 4096,
# total row drivers area: (59.5565*4096/4096) * macro = 137218.176
#
# Size: 3
# Size: 3
# Size: 16
# Size: 16
# All macro: 2304
# cim unit area: 0.01936, number of cim_unit: 4194304,
# total cim unit area: (0.01936*4194304/4096) * macro = 45675.970559999994
#
# Total Area for layer 13: 28968175.96416
#
# Total Macro for layer 13: 17212
#
# Total Area for all layers: 216406356.20448
# Total Area for ADC across all layers: 214143098.0
# Processing layer: RRAM_vgg16_32_layer_14
# Size: 64
# Size: 56
# All macro: 3584
# adc area: 12441.5, number of adc: 4096,
# total adc area: (12441.5*4096/4096) * macro = 44590336.0
#
# Size: 64
# Size: 56
# All macro: 3584
# column drivers area: 52.1119, number of column_drivers: 4096,
# total column drivers area: (52.1119*4096/4096) * macro = 186769.0496
#
# Size: 64
# Size: 56
# All macro: 3584
# row drivers area: 59.5565, number of row_drivers: 4096,
# total row drivers area: (59.5565*4096/4096) * macro = 213450.49599999998
#
# Size: 64
# Size: 56
# All macro: 3584
# cim unit area: 0.01936, number of cim_unit: 4194304,
# total cim unit area: (0.01936*4194304/4096) * macro = 71051.50976
#
# Total Area for layer 14: 45061607.05536
#
# Total Macro for layer 14: 20796
#
# Total Area for all layers: 261467963.25983998
# Total Area for ADC across all layers: 258733434.0
# Processing layer: RRAM_vgg16_32_layer_15
# Size: 32
# Size: 128
# All macro: 4096
# adc area: 12441.5, number of adc: 4096,
# total adc area: (12441.5*4096/4096) * macro = 50960384.0
#
# Size: 32
# Size: 128
# All macro: 4096
# column drivers area: 52.1119, number of column_drivers: 4096,
# total column drivers area: (52.1119*4096/4096) * macro = 213450.3424
#
# Size: 32
# Size: 128
# All macro: 4096
# row drivers area: 59.5565, number of row_drivers: 4096,
# total row drivers area: (59.5565*4096/4096) * macro = 243943.424
#
# Size: 32
# Size: 128
# All macro: 4096
# cim unit area: 0.01936, number of cim_unit: 4194304,
# total cim unit area: (0.01936*4194304/4096) * macro = 81201.72544
#
# Total Area for layer 15: 51498979.491840005
#
# Total Macro for layer 15: 24892
#
# Total Area for all layers: 312966942.75168
# Total Area for ADC across all layers: 309693818.0
# Processing layer: RRAM_vgg16_32_layer_16
# Size: 63
# Size: 64
# All macro: 4032
# adc area: 12441.5, number of adc: 4096,
# total adc area: (12441.5*4096/4096) * macro = 50164128.0
#
# Size: 63
# Size: 64
# All macro: 4032
# column drivers area: 52.1119, number of column_drivers: 4096,
# total column drivers area: (52.1119*4096/4096) * macro = 210115.1808
#
# Size: 63
# Size: 64
# All macro: 4032
# row drivers area: 59.5565, number of row_drivers: 4096,
# total row drivers area: (59.5565*4096/4096) * macro = 240131.808
#
# Size: 63
# Size: 64
# All macro: 4032
# cim unit area: 0.01936, number of cim_unit: 4194304,
# total cim unit area: (0.01936*4194304/4096) * macro = 79932.94847999999
#
# Total Area for layer 16: 50694307.93728
#
# Total Macro for layer 16: 28924
#
# Total Area for all layers: 363661250.68896
# Total Area for ADC across all layers: 359857946.0
# Total Area for column drivers across all layers: 1507284.5955999997
# Total Area for row drivers across all layers: 1722612.206
# Total Area for cim unit across all layers: 573407.8873599999
#
#
# Total Area for ADC across all layers: 359.85794599999997
# Total Area for column driver across all layers: 1.5072845955999996
# Total Area for row driver across all layers: 1.722612206
# Total Area for cim unit across all layers: 0.5734078873599999
# Total Macro across all layers: 28924
# RRAM_vgg16_32 	 8.84e-04 	 363.66 	 7.14e+01
# ../outputs/RRAM_vgg16_64/
# Model 	 Energy/inference (J) 	 Area (mm2) 	 Throughput (inf/s)
# Processing layer: RRAM_vgg16_64_layer_1
# Size: 2
# All macro: 2
# adc area: 14101.8, number of adc: 4096,
# total adc area: (14101.8*4096/4096) * macro = 28203.6
#
# Size: 2
# All macro: 2
# column drivers area: 104.224, number of column_drivers: 4096,
# total column drivers area: (104.224*4096/4096) * macro = 208.448
#
# Size: 2
# All macro: 2
# row drivers area: 119.113, number of row_drivers: 4096,
# total row drivers area: (119.113*4096/4096) * macro = 238.226
#
# Size: 2
# All macro: 2
# cim unit area: 0.01936, number of cim_unit: 16777216,
# total cim unit area: (0.01936*16777216/4096) * macro = 158.59712
#
# Total Area for layer 1: 28808.871119999996
#
# Total Macro for layer 1: 2
#
# Total Area for all layers: 28808.871119999996
# Total Area for ADC across all layers: 28203.6
# Processing layer: RRAM_vgg16_64_layer_2
# Size: 3
# Size: 3
# Size: 2
# All macro: 18
# adc area: 14101.8, number of adc: 4096,
# total adc area: (14101.8*4096/4096) * macro = 253832.4
#
# Size: 3
# Size: 3
# Size: 2
# All macro: 18
# column drivers area: 104.224, number of column_drivers: 4096,
# total column drivers area: (104.224*4096/4096) * macro = 1876.0320000000002
#
# Size: 3
# Size: 3
# Size: 2
# All macro: 18
# row drivers area: 119.113, number of row_drivers: 4096,
# total row drivers area: (119.113*4096/4096) * macro = 2144.034
#
# Size: 3
# Size: 3
# Size: 2
# All macro: 18
# cim unit area: 0.01936, number of cim_unit: 16777216,
# total cim unit area: (0.01936*16777216/4096) * macro = 1427.3740799999998
#
# Total Area for layer 2: 259279.84008000002
#
# Total Macro for layer 2: 20
#
# Total Area for all layers: 288088.7112
# Total Area for ADC across all layers: 282036.0
# Processing layer: RRAM_vgg16_64_layer_3
# Size: 3
# Size: 3
# Size: 4
# All macro: 36
# adc area: 14101.8, number of adc: 4096,
# total adc area: (14101.8*4096/4096) * macro = 507664.8
#
# Size: 3
# Size: 3
# Size: 4
# All macro: 36
# column drivers area: 104.224, number of column_drivers: 4096,
# total column drivers area: (104.224*4096/4096) * macro = 3752.0640000000003
#
# Size: 3
# Size: 3
# Size: 4
# All macro: 36
# row drivers area: 119.113, number of row_drivers: 4096,
# total row drivers area: (119.113*4096/4096) * macro = 4288.068
#
# Size: 3
# Size: 3
# Size: 4
# All macro: 36
# cim unit area: 0.01936, number of cim_unit: 16777216,
# total cim unit area: (0.01936*16777216/4096) * macro = 2854.7481599999996
#
# Total Area for layer 3: 518559.68016000005
#
# Total Macro for layer 3: 56
#
# Total Area for all layers: 806648.39136
# Total Area for ADC across all layers: 789700.8
# Processing layer: RRAM_vgg16_64_layer_4
# Size: 3
# Size: 3
# Size: 4
# Size: 2
# All macro: 72
# adc area: 14101.8, number of adc: 4096,
# total adc area: (14101.8*4096/4096) * macro = 1015329.6
#
# Size: 3
# Size: 3
# Size: 4
# Size: 2
# All macro: 72
# column drivers area: 104.224, number of column_drivers: 4096,
# total column drivers area: (104.224*4096/4096) * macro = 7504.128000000001
#
# Size: 3
# Size: 3
# Size: 4
# Size: 2
# All macro: 72
# row drivers area: 119.113, number of row_drivers: 4096,
# total row drivers area: (119.113*4096/4096) * macro = 8576.136
#
# Size: 3
# Size: 3
# Size: 4
# Size: 2
# All macro: 72
# cim unit area: 0.01936, number of cim_unit: 16777216,
# total cim unit area: (0.01936*16777216/4096) * macro = 5709.496319999999
#
# Total Area for layer 4: 1037119.3603200001
#
# Total Macro for layer 4: 128
#
# Total Area for all layers: 1843767.7516800002
# Total Area for ADC across all layers: 1805030.4
# Processing layer: RRAM_vgg16_64_layer_5
# Size: 3
# Size: 3
# Size: 8
# Size: 2
# All macro: 144
# adc area: 14101.8, number of adc: 4096,
# total adc area: (14101.8*4096/4096) * macro = 2030659.2
#
# Size: 3
# Size: 3
# Size: 8
# Size: 2
# All macro: 144
# column drivers area: 104.224, number of column_drivers: 4096,
# total column drivers area: (104.224*4096/4096) * macro = 15008.256000000001
#
# Size: 3
# Size: 3
# Size: 8
# Size: 2
# All macro: 144
# row drivers area: 119.113, number of row_drivers: 4096,
# total row drivers area: (119.113*4096/4096) * macro = 17152.272
#
# Size: 3
# Size: 3
# Size: 8
# Size: 2
# All macro: 144
# cim unit area: 0.01936, number of cim_unit: 16777216,
# total cim unit area: (0.01936*16777216/4096) * macro = 11418.992639999999
#
# Total Area for layer 5: 2074238.7206400002
#
# Total Macro for layer 5: 272
#
# Total Area for all layers: 3918006.4723200006
# Total Area for ADC across all layers: 3835689.5999999996
# Processing layer: RRAM_vgg16_64_layer_6
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# adc area: 14101.8, number of adc: 4096,
# total adc area: (14101.8*4096/4096) * macro = 4061318.4
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# column drivers area: 104.224, number of column_drivers: 4096,
# total column drivers area: (104.224*4096/4096) * macro = 30016.512000000002
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# row drivers area: 119.113, number of row_drivers: 4096,
# total row drivers area: (119.113*4096/4096) * macro = 34304.544
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# cim unit area: 0.01936, number of cim_unit: 16777216,
# total cim unit area: (0.01936*16777216/4096) * macro = 22837.985279999997
#
# Total Area for layer 6: 4148477.4412800004
#
# Total Macro for layer 6: 560
#
# Total Area for all layers: 8066483.9136000015
# Total Area for ADC across all layers: 7897008.0
# Processing layer: RRAM_vgg16_64_layer_7
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# adc area: 14101.8, number of adc: 4096,
# total adc area: (14101.8*4096/4096) * macro = 4061318.4
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# column drivers area: 104.224, number of column_drivers: 4096,
# total column drivers area: (104.224*4096/4096) * macro = 30016.512000000002
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# row drivers area: 119.113, number of row_drivers: 4096,
# total row drivers area: (119.113*4096/4096) * macro = 34304.544
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# cim unit area: 0.01936, number of cim_unit: 16777216,
# total cim unit area: (0.01936*16777216/4096) * macro = 22837.985279999997
#
# Total Area for layer 7: 4148477.4412800004
#
# Total Macro for layer 7: 848
#
# Total Area for all layers: 12214961.354880001
# Total Area for ADC across all layers: 11958326.4
# Processing layer: RRAM_vgg16_64_layer_8
# Size: 3
# Size: 3
# Size: 16
# Size: 4
# All macro: 576
# adc area: 14101.8, number of adc: 4096,
# total adc area: (14101.8*4096/4096) * macro = 8122636.8
#
# Size: 3
# Size: 3
# Size: 16
# Size: 4
# All macro: 576
# column drivers area: 104.224, number of column_drivers: 4096,
# total column drivers area: (104.224*4096/4096) * macro = 60033.024000000005
#
# Size: 3
# Size: 3
# Size: 16
# Size: 4
# All macro: 576
# row drivers area: 119.113, number of row_drivers: 4096,
# total row drivers area: (119.113*4096/4096) * macro = 68609.088
#
# Size: 3
# Size: 3
# Size: 16
# Size: 4
# All macro: 576
# cim unit area: 0.01936, number of cim_unit: 16777216,
# total cim unit area: (0.01936*16777216/4096) * macro = 45675.970559999994
#
# Total Area for layer 8: 8296954.882560001
#
# Total Macro for layer 8: 1424
#
# Total Area for all layers: 20511916.23744
# Total Area for ADC across all layers: 20080963.2
# Processing layer: RRAM_vgg16_64_layer_9
# Size: 3
# Size: 3
# Size: 16
# Size: 8
# All macro: 1152
# adc area: 14101.8, number of adc: 4096,
# total adc area: (14101.8*4096/4096) * macro = 16245273.6
#
# Size: 3
# Size: 3
# Size: 16
# Size: 8
# All macro: 1152
# column drivers area: 104.224, number of column_drivers: 4096,
# total column drivers area: (104.224*4096/4096) * macro = 120066.04800000001
#
# Size: 3
# Size: 3
# Size: 16
# Size: 8
# All macro: 1152
# row drivers area: 119.113, number of row_drivers: 4096,
# total row drivers area: (119.113*4096/4096) * macro = 137218.176
#
# Size: 3
# Size: 3
# Size: 16
# Size: 8
# All macro: 1152
# cim unit area: 0.01936, number of cim_unit: 16777216,
# total cim unit area: (0.01936*16777216/4096) * macro = 91351.94111999999
#
# Total Area for layer 9: 16593909.765120002
#
# Total Macro for layer 9: 2576
#
# Total Area for all layers: 37105826.002560005
# Total Area for ADC across all layers: 36326236.8
# Processing layer: RRAM_vgg16_64_layer_10
# Size: 3
# Size: 3
# Size: 16
# Size: 8
# All macro: 1152
# adc area: 14101.8, number of adc: 4096,
# total adc area: (14101.8*4096/4096) * macro = 16245273.6
#
# Size: 3
# Size: 3
# Size: 16
# Size: 8
# All macro: 1152
# column drivers area: 104.224, number of column_drivers: 4096,
# total column drivers area: (104.224*4096/4096) * macro = 120066.04800000001
#
# Size: 3
# Size: 3
# Size: 16
# Size: 8
# All macro: 1152
# row drivers area: 119.113, number of row_drivers: 4096,
# total row drivers area: (119.113*4096/4096) * macro = 137218.176
#
# Size: 3
# Size: 3
# Size: 16
# Size: 8
# All macro: 1152
# cim unit area: 0.01936, number of cim_unit: 16777216,
# total cim unit area: (0.01936*16777216/4096) * macro = 91351.94111999999
#
# Total Area for layer 10: 16593909.765120002
#
# Total Macro for layer 10: 3728
#
# Total Area for all layers: 53699735.767680004
# Total Area for ADC across all layers: 52571510.4
# Processing layer: RRAM_vgg16_64_layer_11
# Size: 3
# Size: 3
# Size: 16
# Size: 8
# All macro: 1152
# adc area: 14101.8, number of adc: 4096,
# total adc area: (14101.8*4096/4096) * macro = 16245273.6
#
# Size: 3
# Size: 3
# Size: 16
# Size: 8
# All macro: 1152
# column drivers area: 104.224, number of column_drivers: 4096,
# total column drivers area: (104.224*4096/4096) * macro = 120066.04800000001
#
# Size: 3
# Size: 3
# Size: 16
# Size: 8
# All macro: 1152
# row drivers area: 119.113, number of row_drivers: 4096,
# total row drivers area: (119.113*4096/4096) * macro = 137218.176
#
# Size: 3
# Size: 3
# Size: 16
# Size: 8
# All macro: 1152
# cim unit area: 0.01936, number of cim_unit: 16777216,
# total cim unit area: (0.01936*16777216/4096) * macro = 91351.94111999999
#
# Total Area for layer 11: 16593909.765120002
#
# Total Macro for layer 11: 4880
#
# Total Area for all layers: 70293645.5328
# Total Area for ADC across all layers: 68816784.0
# Processing layer: RRAM_vgg16_64_layer_12
# Size: 3
# Size: 3
# Size: 16
# Size: 8
# All macro: 1152
# adc area: 14101.8, number of adc: 4096,
# total adc area: (14101.8*4096/4096) * macro = 16245273.6
#
# Size: 3
# Size: 3
# Size: 16
# Size: 8
# All macro: 1152
# column drivers area: 104.224, number of column_drivers: 4096,
# total column drivers area: (104.224*4096/4096) * macro = 120066.04800000001
#
# Size: 3
# Size: 3
# Size: 16
# Size: 8
# All macro: 1152
# row drivers area: 119.113, number of row_drivers: 4096,
# total row drivers area: (119.113*4096/4096) * macro = 137218.176
#
# Size: 3
# Size: 3
# Size: 16
# Size: 8
# All macro: 1152
# cim unit area: 0.01936, number of cim_unit: 16777216,
# total cim unit area: (0.01936*16777216/4096) * macro = 91351.94111999999
#
# Total Area for layer 12: 16593909.765120002
#
# Total Macro for layer 12: 6032
#
# Total Area for all layers: 86887555.29792
# Total Area for ADC across all layers: 85062057.6
# Processing layer: RRAM_vgg16_64_layer_13
# Size: 3
# Size: 3
# Size: 16
# Size: 8
# All macro: 1152
# adc area: 14101.8, number of adc: 4096,
# total adc area: (14101.8*4096/4096) * macro = 16245273.6
#
# Size: 3
# Size: 3
# Size: 16
# Size: 8
# All macro: 1152
# column drivers area: 104.224, number of column_drivers: 4096,
# total column drivers area: (104.224*4096/4096) * macro = 120066.04800000001
#
# Size: 3
# Size: 3
# Size: 16
# Size: 8
# All macro: 1152
# row drivers area: 119.113, number of row_drivers: 4096,
# total row drivers area: (119.113*4096/4096) * macro = 137218.176
#
# Size: 3
# Size: 3
# Size: 16
# Size: 8
# All macro: 1152
# cim unit area: 0.01936, number of cim_unit: 16777216,
# total cim unit area: (0.01936*16777216/4096) * macro = 91351.94111999999
#
# Total Area for layer 13: 16593909.765120002
#
# Total Macro for layer 13: 7184
#
# Total Area for all layers: 103481465.06304
# Total Area for ADC across all layers: 101307331.19999999
# Processing layer: RRAM_vgg16_64_layer_14
# Size: 64
# Size: 56
# All macro: 3584
# adc area: 14101.8, number of adc: 4096,
# total adc area: (14101.8*4096/4096) * macro = 50540851.199999996
#
# Size: 64
# Size: 56
# All macro: 3584
# column drivers area: 104.224, number of column_drivers: 4096,
# total column drivers area: (104.224*4096/4096) * macro = 373538.816
#
# Size: 64
# Size: 56
# All macro: 3584
# row drivers area: 119.113, number of row_drivers: 4096,
# total row drivers area: (119.113*4096/4096) * macro = 426900.99199999997
#
# Size: 64
# Size: 56
# All macro: 3584
# cim unit area: 0.01936, number of cim_unit: 16777216,
# total cim unit area: (0.01936*16777216/4096) * macro = 284206.03904
#
# Total Area for layer 14: 51625497.04703999
#
# Total Macro for layer 14: 10768
#
# Total Area for all layers: 155106962.11008
# Total Area for ADC across all layers: 151848182.39999998
# Processing layer: RRAM_vgg16_64_layer_15
# Size: 128
# Size: 32
# All macro: 4096
# adc area: 14101.8, number of adc: 4096,
# total adc area: (14101.8*4096/4096) * macro = 57760972.8
#
# Size: 128
# Size: 32
# All macro: 4096
# column drivers area: 104.224, number of column_drivers: 4096,
# total column drivers area: (104.224*4096/4096) * macro = 426901.504
#
# Size: 128
# Size: 32
# All macro: 4096
# row drivers area: 119.113, number of row_drivers: 4096,
# total row drivers area: (119.113*4096/4096) * macro = 487886.848
#
# Size: 128
# Size: 32
# All macro: 4096
# cim unit area: 0.01936, number of cim_unit: 16777216,
# total cim unit area: (0.01936*16777216/4096) * macro = 324806.90176
#
# Total Area for layer 15: 59000568.05375999
#
# Total Macro for layer 15: 14864
#
# Total Area for all layers: 214107530.16384
# Total Area for ADC across all layers: 209609155.2
# Processing layer: RRAM_vgg16_64_layer_16
# Size: 32
# Size: 64
# All macro: 2048
# adc area: 14101.8, number of adc: 4096,
# total adc area: (14101.8*4096/4096) * macro = 28880486.4
#
# Size: 32
# Size: 64
# All macro: 2048
# column drivers area: 104.224, number of column_drivers: 4096,
# total column drivers area: (104.224*4096/4096) * macro = 213450.752
#
# Size: 32
# Size: 64
# All macro: 2048
# row drivers area: 119.113, number of row_drivers: 4096,
# total row drivers area: (119.113*4096/4096) * macro = 243943.424
#
# Size: 32
# Size: 64
# All macro: 2048
# cim unit area: 0.01936, number of cim_unit: 16777216,
# total cim unit area: (0.01936*16777216/4096) * macro = 162403.45088
#
# Total Area for layer 16: 29500284.026879996
#
# Total Macro for layer 16: 16912
#
# Total Area for all layers: 243607814.19072
# Total Area for ADC across all layers: 238489641.6
# Total Area for column drivers across all layers: 1762636.2880000002
# Total Area for row drivers across all layers: 2014439.0559999999
# Total Area for cim unit across all layers: 1341097.24672
#
#
# Total Area for ADC across all layers: 238.48964159999997
# Total Area for column driver across all layers: 1.7626362880000002
# Total Area for row driver across all layers: 2.0144390559999996
# Total Area for cim unit across all layers: 1.34109724672
# Total Macro across all layers: 16912
# RRAM_vgg16_64 	 5.26e-04 	 243.61 	 7.26e+01
# ../outputs/RRAM_vgg16_128/
# Model 	 Energy/inference (J) 	 Area (mm2) 	 Throughput (inf/s)
# Processing layer: RRAM_vgg16_128_layer_1
# All macro: 1
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 15983.6
#
# All macro: 1
# column drivers area: 208.448, number of column_drivers: 4096,
# total column drivers area: (208.448*4096/4096) * macro = 208.448
#
# All macro: 1
# row drivers area: 238.226, number of row_drivers: 4096,
# total row drivers area: (238.226*4096/4096) * macro = 238.226
#
# All macro: 1
# cim unit area: 0.01936, number of cim_unit: 67108864,
# total cim unit area: (0.01936*67108864/4096) * macro = 317.19424
#
# Total Area for layer 1: 16747.468240000002
#
# Total Macro for layer 1: 1
#
# Total Area for all layers: 16747.468240000002
# Total Area for ADC across all layers: 15983.6
# Processing layer: RRAM_vgg16_128_layer_2
# Size: 5
# All macro: 5
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 79918.0
#
# Size: 5
# All macro: 5
# column drivers area: 208.448, number of column_drivers: 4096,
# total column drivers area: (208.448*4096/4096) * macro = 1042.24
#
# Size: 5
# All macro: 5
# row drivers area: 238.226, number of row_drivers: 4096,
# total row drivers area: (238.226*4096/4096) * macro = 1191.13
#
# Size: 5
# All macro: 5
# cim unit area: 0.01936, number of cim_unit: 67108864,
# total cim unit area: (0.01936*67108864/4096) * macro = 1585.9712
#
# Total Area for layer 2: 83737.34120000001
#
# Total Macro for layer 2: 6
#
# Total Area for all layers: 100484.80944000001
# Total Area for ADC across all layers: 95901.6
# Processing layer: RRAM_vgg16_128_layer_3
# Size: 2
# Size: 5
# All macro: 10
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 159836.0
#
# Size: 2
# Size: 5
# All macro: 10
# column drivers area: 208.448, number of column_drivers: 4096,
# total column drivers area: (208.448*4096/4096) * macro = 2084.48
#
# Size: 2
# Size: 5
# All macro: 10
# row drivers area: 238.226, number of row_drivers: 4096,
# total row drivers area: (238.226*4096/4096) * macro = 2382.26
#
# Size: 2
# Size: 5
# All macro: 10
# cim unit area: 0.01936, number of cim_unit: 67108864,
# total cim unit area: (0.01936*67108864/4096) * macro = 3171.9424
#
# Total Area for layer 3: 167474.68240000002
#
# Total Macro for layer 3: 16
#
# Total Area for all layers: 267959.49184000003
# Total Area for ADC across all layers: 255737.6
# Processing layer: RRAM_vgg16_128_layer_4
# Size: 3
# Size: 3
# Size: 2
# All macro: 18
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 287704.8
#
# Size: 3
# Size: 3
# Size: 2
# All macro: 18
# column drivers area: 208.448, number of column_drivers: 4096,
# total column drivers area: (208.448*4096/4096) * macro = 3752.0640000000003
#
# Size: 3
# Size: 3
# Size: 2
# All macro: 18
# row drivers area: 238.226, number of row_drivers: 4096,
# total row drivers area: (238.226*4096/4096) * macro = 4288.068
#
# Size: 3
# Size: 3
# Size: 2
# All macro: 18
# cim unit area: 0.01936, number of cim_unit: 67108864,
# total cim unit area: (0.01936*67108864/4096) * macro = 5709.496319999999
#
# Total Area for layer 4: 301454.42832
#
# Total Macro for layer 4: 34
#
# Total Area for all layers: 569413.92016
# Total Area for ADC across all layers: 543442.4
# Processing layer: RRAM_vgg16_128_layer_5
# Size: 3
# Size: 3
# Size: 4
# All macro: 36
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 575409.6
#
# Size: 3
# Size: 3
# Size: 4
# All macro: 36
# column drivers area: 208.448, number of column_drivers: 4096,
# total column drivers area: (208.448*4096/4096) * macro = 7504.128000000001
#
# Size: 3
# Size: 3
# Size: 4
# All macro: 36
# row drivers area: 238.226, number of row_drivers: 4096,
# total row drivers area: (238.226*4096/4096) * macro = 8576.136
#
# Size: 3
# Size: 3
# Size: 4
# All macro: 36
# cim unit area: 0.01936, number of cim_unit: 67108864,
# total cim unit area: (0.01936*67108864/4096) * macro = 11418.992639999999
#
# Total Area for layer 5: 602908.85664
#
# Total Macro for layer 5: 70
#
# Total Area for all layers: 1172322.7768
# Total Area for ADC across all layers: 1118852.0
# Processing layer: RRAM_vgg16_128_layer_6
# Size: 3
# Size: 3
# Size: 4
# Size: 2
# All macro: 72
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 1150819.2
#
# Size: 3
# Size: 3
# Size: 4
# Size: 2
# All macro: 72
# column drivers area: 208.448, number of column_drivers: 4096,
# total column drivers area: (208.448*4096/4096) * macro = 15008.256000000001
#
# Size: 3
# Size: 3
# Size: 4
# Size: 2
# All macro: 72
# row drivers area: 238.226, number of row_drivers: 4096,
# total row drivers area: (238.226*4096/4096) * macro = 17152.272
#
# Size: 3
# Size: 3
# Size: 4
# Size: 2
# All macro: 72
# cim unit area: 0.01936, number of cim_unit: 67108864,
# total cim unit area: (0.01936*67108864/4096) * macro = 22837.985279999997
#
# Total Area for layer 6: 1205817.71328
#
# Total Macro for layer 6: 142
#
# Total Area for all layers: 2378140.49008
# Total Area for ADC across all layers: 2269671.2
# Processing layer: RRAM_vgg16_128_layer_7
# Size: 3
# Size: 3
# Size: 4
# Size: 2
# All macro: 72
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 1150819.2
#
# Size: 3
# Size: 3
# Size: 4
# Size: 2
# All macro: 72
# column drivers area: 208.448, number of column_drivers: 4096,
# total column drivers area: (208.448*4096/4096) * macro = 15008.256000000001
#
# Size: 3
# Size: 3
# Size: 4
# Size: 2
# All macro: 72
# row drivers area: 238.226, number of row_drivers: 4096,
# total row drivers area: (238.226*4096/4096) * macro = 17152.272
#
# Size: 3
# Size: 3
# Size: 4
# Size: 2
# All macro: 72
# cim unit area: 0.01936, number of cim_unit: 67108864,
# total cim unit area: (0.01936*67108864/4096) * macro = 22837.985279999997
#
# Total Area for layer 7: 1205817.71328
#
# Total Macro for layer 7: 214
#
# Total Area for all layers: 3583958.2033599997
# Total Area for ADC across all layers: 3420490.4000000004
# Processing layer: RRAM_vgg16_128_layer_8
# Size: 3
# Size: 3
# Size: 8
# Size: 2
# All macro: 144
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 2301638.4
#
# Size: 3
# Size: 3
# Size: 8
# Size: 2
# All macro: 144
# column drivers area: 208.448, number of column_drivers: 4096,
# total column drivers area: (208.448*4096/4096) * macro = 30016.512000000002
#
# Size: 3
# Size: 3
# Size: 8
# Size: 2
# All macro: 144
# row drivers area: 238.226, number of row_drivers: 4096,
# total row drivers area: (238.226*4096/4096) * macro = 34304.544
#
# Size: 3
# Size: 3
# Size: 8
# Size: 2
# All macro: 144
# cim unit area: 0.01936, number of cim_unit: 67108864,
# total cim unit area: (0.01936*67108864/4096) * macro = 45675.970559999994
#
# Total Area for layer 8: 2411635.42656
#
# Total Macro for layer 8: 358
#
# Total Area for all layers: 5995593.62992
# Total Area for ADC across all layers: 5722128.800000001
# Processing layer: RRAM_vgg16_128_layer_9
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 4603276.8
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# column drivers area: 208.448, number of column_drivers: 4096,
# total column drivers area: (208.448*4096/4096) * macro = 60033.024000000005
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# row drivers area: 238.226, number of row_drivers: 4096,
# total row drivers area: (238.226*4096/4096) * macro = 68609.088
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# cim unit area: 0.01936, number of cim_unit: 67108864,
# total cim unit area: (0.01936*67108864/4096) * macro = 91351.94111999999
#
# Total Area for layer 9: 4823270.85312
#
# Total Macro for layer 9: 646
#
# Total Area for all layers: 10818864.483040001
# Total Area for ADC across all layers: 10325405.600000001
# Processing layer: RRAM_vgg16_128_layer_10
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 4603276.8
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# column drivers area: 208.448, number of column_drivers: 4096,
# total column drivers area: (208.448*4096/4096) * macro = 60033.024000000005
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# row drivers area: 238.226, number of row_drivers: 4096,
# total row drivers area: (238.226*4096/4096) * macro = 68609.088
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# cim unit area: 0.01936, number of cim_unit: 67108864,
# total cim unit area: (0.01936*67108864/4096) * macro = 91351.94111999999
#
# Total Area for layer 10: 4823270.85312
#
# Total Macro for layer 10: 934
#
# Total Area for all layers: 15642135.33616
# Total Area for ADC across all layers: 14928682.400000002
# Processing layer: RRAM_vgg16_128_layer_11
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 4603276.8
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# column drivers area: 208.448, number of column_drivers: 4096,
# total column drivers area: (208.448*4096/4096) * macro = 60033.024000000005
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# row drivers area: 238.226, number of row_drivers: 4096,
# total row drivers area: (238.226*4096/4096) * macro = 68609.088
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# cim unit area: 0.01936, number of cim_unit: 67108864,
# total cim unit area: (0.01936*67108864/4096) * macro = 91351.94111999999
#
# Total Area for layer 11: 4823270.85312
#
# Total Macro for layer 11: 1222
#
# Total Area for all layers: 20465406.18928
# Total Area for ADC across all layers: 19531959.200000003
# Processing layer: RRAM_vgg16_128_layer_12
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 4603276.8
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# column drivers area: 208.448, number of column_drivers: 4096,
# total column drivers area: (208.448*4096/4096) * macro = 60033.024000000005
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# row drivers area: 238.226, number of row_drivers: 4096,
# total row drivers area: (238.226*4096/4096) * macro = 68609.088
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# cim unit area: 0.01936, number of cim_unit: 67108864,
# total cim unit area: (0.01936*67108864/4096) * macro = 91351.94111999999
#
# Total Area for layer 12: 4823270.85312
#
# Total Macro for layer 12: 1510
#
# Total Area for all layers: 25288677.0424
# Total Area for ADC across all layers: 24135236.000000004
# Processing layer: RRAM_vgg16_128_layer_13
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 4603276.8
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# column drivers area: 208.448, number of column_drivers: 4096,
# total column drivers area: (208.448*4096/4096) * macro = 60033.024000000005
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# row drivers area: 238.226, number of row_drivers: 4096,
# total row drivers area: (238.226*4096/4096) * macro = 68609.088
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# cim unit area: 0.01936, number of cim_unit: 67108864,
# total cim unit area: (0.01936*67108864/4096) * macro = 91351.94111999999
#
# Total Area for layer 13: 4823270.85312
#
# Total Macro for layer 13: 1798
#
# Total Area for all layers: 30111947.895519998
# Total Area for ADC across all layers: 28738512.800000004
# Processing layer: RRAM_vgg16_128_layer_14
# Size: 64
# Size: 49
# All macro: 3136
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 50124569.6
#
# Size: 64
# Size: 49
# All macro: 3136
# column drivers area: 208.448, number of column_drivers: 4096,
# total column drivers area: (208.448*4096/4096) * macro = 653692.9280000001
#
# Size: 64
# Size: 49
# All macro: 3136
# row drivers area: 238.226, number of row_drivers: 4096,
# total row drivers area: (238.226*4096/4096) * macro = 747076.736
#
# Size: 64
# Size: 49
# All macro: 3136
# cim unit area: 0.01936, number of cim_unit: 67108864,
# total cim unit area: (0.01936*67108864/4096) * macro = 994721.1366399999
#
# Total Area for layer 14: 52520060.40064
#
# Total Macro for layer 14: 4934
#
# Total Area for all layers: 82632008.29616
# Total Area for ADC across all layers: 78863082.4
# Processing layer: RRAM_vgg16_128_layer_15
# Size: 64
# Size: 32
# All macro: 2048
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 32734412.8
#
# Size: 64
# Size: 32
# All macro: 2048
# column drivers area: 208.448, number of column_drivers: 4096,
# total column drivers area: (208.448*4096/4096) * macro = 426901.504
#
# Size: 64
# Size: 32
# All macro: 2048
# row drivers area: 238.226, number of row_drivers: 4096,
# total row drivers area: (238.226*4096/4096) * macro = 487886.848
#
# Size: 64
# Size: 32
# All macro: 2048
# cim unit area: 0.01936, number of cim_unit: 67108864,
# total cim unit area: (0.01936*67108864/4096) * macro = 649613.80352
#
# Total Area for layer 15: 34298814.955520004
#
# Total Macro for layer 15: 6982
#
# Total Area for all layers: 116930823.25168
# Total Area for ADC across all layers: 111597495.2
# Processing layer: RRAM_vgg16_128_layer_16
# Size: 16
# Size: 32
# All macro: 512
# adc area: 15983.6, number of adc: 4096,
# total adc area: (15983.6*4096/4096) * macro = 8183603.2
#
# Size: 16
# Size: 32
# All macro: 512
# column drivers area: 208.448, number of column_drivers: 4096,
# total column drivers area: (208.448*4096/4096) * macro = 106725.376
#
# Size: 16
# Size: 32
# All macro: 512
# row drivers area: 238.226, number of row_drivers: 4096,
# total row drivers area: (238.226*4096/4096) * macro = 121971.712
#
# Size: 16
# Size: 32
# All macro: 512
# cim unit area: 0.01936, number of cim_unit: 67108864,
# total cim unit area: (0.01936*67108864/4096) * macro = 162403.45088
#
# Total Area for layer 16: 8574703.738880001
#
# Total Macro for layer 16: 7494
#
# Total Area for all layers: 125505526.99056
# Total Area for ADC across all layers: 119781098.4
# Total Area for column drivers across all layers: 1562109.312
# Total Area for row drivers across all layers: 1785265.644
# Total Area for cim unit across all layers: 2377053.6345599997
#
#
# Total Area for ADC across all layers: 119.7810984
# Total Area for column driver across all layers: 1.5621093119999998
# Total Area for row driver across all layers: 1.785265644
# Total Area for cim unit across all layers: 2.3770536345599997
# Total Macro across all layers: 7494
# RRAM_vgg16_128 	 3.52e-04 	 125.51 	 7.26e+01
# ../outputs/RRAM_vgg16_256/
# Model 	 Energy/inference (J) 	 Area (mm2) 	 Throughput (inf/s)
# Processing layer: RRAM_vgg16_256_layer_1
# All macro: 1
# adc area: 18116.6, number of adc: 4096,
# total adc area: (18116.6*4096/4096) * macro = 18116.6
#
# All macro: 1
# column drivers area: 416.895, number of column_drivers: 4096,
# total column drivers area: (416.895*4096/4096) * macro = 416.895
#
# All macro: 1
# row drivers area: 476.452, number of row_drivers: 4096,
# total row drivers area: (476.452*4096/4096) * macro = 476.452
#
# All macro: 1
# cim unit area: 0.01936, number of cim_unit: 268435456,
# total cim unit area: (0.01936*268435456/4096) * macro = 1268.77696
#
# Total Area for layer 1: 20278.72396
#
# Total Macro for layer 1: 1
#
# Total Area for all layers: 20278.72396
# Total Area for ADC across all layers: 18116.6
# Processing layer: RRAM_vgg16_256_layer_2
# Size: 3
# All macro: 3
# adc area: 18116.6, number of adc: 4096,
# total adc area: (18116.6*4096/4096) * macro = 54349.799999999996
#
# Size: 3
# All macro: 3
# column drivers area: 416.895, number of column_drivers: 4096,
# total column drivers area: (416.895*4096/4096) * macro = 1250.685
#
# Size: 3
# All macro: 3
# row drivers area: 476.452, number of row_drivers: 4096,
# total row drivers area: (476.452*4096/4096) * macro = 1429.356
#
# Size: 3
# All macro: 3
# cim unit area: 0.01936, number of cim_unit: 268435456,
# total cim unit area: (0.01936*268435456/4096) * macro = 3806.3308799999995
#
# Total Area for layer 2: 60836.171879999994
#
# Total Macro for layer 2: 4
#
# Total Area for all layers: 81114.89584
# Total Area for ADC across all layers: 72466.4
# Processing layer: RRAM_vgg16_256_layer_3
# Size: 3
# All macro: 3
# adc area: 18116.6, number of adc: 4096,
# total adc area: (18116.6*4096/4096) * macro = 54349.799999999996
#
# Size: 3
# All macro: 3
# column drivers area: 416.895, number of column_drivers: 4096,
# total column drivers area: (416.895*4096/4096) * macro = 1250.685
#
# Size: 3
# All macro: 3
# row drivers area: 476.452, number of row_drivers: 4096,
# total row drivers area: (476.452*4096/4096) * macro = 1429.356
#
# Size: 3
# All macro: 3
# cim unit area: 0.01936, number of cim_unit: 268435456,
# total cim unit area: (0.01936*268435456/4096) * macro = 3806.3308799999995
#
# Total Area for layer 3: 60836.171879999994
#
# Total Macro for layer 3: 7
#
# Total Area for all layers: 141951.06772
# Total Area for ADC across all layers: 126816.19999999998
# Processing layer: RRAM_vgg16_256_layer_4
# Size: 5
# All macro: 5
# adc area: 18116.6, number of adc: 4096,
# total adc area: (18116.6*4096/4096) * macro = 90583.0
#
# Size: 5
# All macro: 5
# column drivers area: 416.895, number of column_drivers: 4096,
# total column drivers area: (416.895*4096/4096) * macro = 2084.475
#
# Size: 5
# All macro: 5
# row drivers area: 476.452, number of row_drivers: 4096,
# total row drivers area: (476.452*4096/4096) * macro = 2382.26
#
# Size: 5
# All macro: 5
# cim unit area: 0.01936, number of cim_unit: 268435456,
# total cim unit area: (0.01936*268435456/4096) * macro = 6343.8848
#
# Total Area for layer 4: 101393.6198
#
# Total Macro for layer 4: 12
#
# Total Area for all layers: 243344.68751999998
# Total Area for ADC across all layers: 217399.19999999998
# Processing layer: RRAM_vgg16_256_layer_5
# Size: 2
# Size: 5
# All macro: 10
# adc area: 18116.6, number of adc: 4096,
# total adc area: (18116.6*4096/4096) * macro = 181166.0
#
# Size: 2
# Size: 5
# All macro: 10
# column drivers area: 416.895, number of column_drivers: 4096,
# total column drivers area: (416.895*4096/4096) * macro = 4168.95
#
# Size: 2
# Size: 5
# All macro: 10
# row drivers area: 476.452, number of row_drivers: 4096,
# total row drivers area: (476.452*4096/4096) * macro = 4764.52
#
# Size: 2
# Size: 5
# All macro: 10
# cim unit area: 0.01936, number of cim_unit: 268435456,
# total cim unit area: (0.01936*268435456/4096) * macro = 12687.7696
#
# Total Area for layer 5: 202787.2396
#
# Total Macro for layer 5: 22
#
# Total Area for all layers: 446131.92712
# Total Area for ADC across all layers: 398565.19999999995
# Processing layer: RRAM_vgg16_256_layer_6
# Size: 3
# Size: 3
# Size: 2
# All macro: 18
# adc area: 18116.6, number of adc: 4096,
# total adc area: (18116.6*4096/4096) * macro = 326098.8
#
# Size: 3
# Size: 3
# Size: 2
# All macro: 18
# column drivers area: 416.895, number of column_drivers: 4096,
# total column drivers area: (416.895*4096/4096) * macro = 7504.11
#
# Size: 3
# Size: 3
# Size: 2
# All macro: 18
# row drivers area: 476.452, number of row_drivers: 4096,
# total row drivers area: (476.452*4096/4096) * macro = 8576.136
#
# Size: 3
# Size: 3
# Size: 2
# All macro: 18
# cim unit area: 0.01936, number of cim_unit: 268435456,
# total cim unit area: (0.01936*268435456/4096) * macro = 22837.985279999997
#
# Total Area for layer 6: 365017.03128
#
# Total Macro for layer 6: 40
#
# Total Area for all layers: 811148.9584
# Total Area for ADC across all layers: 724664.0
# Processing layer: RRAM_vgg16_256_layer_7
# Size: 3
# Size: 3
# Size: 2
# All macro: 18
# adc area: 18116.6, number of adc: 4096,
# total adc area: (18116.6*4096/4096) * macro = 326098.8
#
# Size: 3
# Size: 3
# Size: 2
# All macro: 18
# column drivers area: 416.895, number of column_drivers: 4096,
# total column drivers area: (416.895*4096/4096) * macro = 7504.11
#
# Size: 3
# Size: 3
# Size: 2
# All macro: 18
# row drivers area: 476.452, number of row_drivers: 4096,
# total row drivers area: (476.452*4096/4096) * macro = 8576.136
#
# Size: 3
# Size: 3
# Size: 2
# All macro: 18
# cim unit area: 0.01936, number of cim_unit: 268435456,
# total cim unit area: (0.01936*268435456/4096) * macro = 22837.985279999997
#
# Total Area for layer 7: 365017.03128
#
# Total Macro for layer 7: 58
#
# Total Area for all layers: 1176165.98968
# Total Area for ADC across all layers: 1050762.8
# Processing layer: RRAM_vgg16_256_layer_8
# Size: 3
# Size: 3
# Size: 4
# All macro: 36
# adc area: 18116.6, number of adc: 4096,
# total adc area: (18116.6*4096/4096) * macro = 652197.6
#
# Size: 3
# Size: 3
# Size: 4
# All macro: 36
# column drivers area: 416.895, number of column_drivers: 4096,
# total column drivers area: (416.895*4096/4096) * macro = 15008.22
#
# Size: 3
# Size: 3
# Size: 4
# All macro: 36
# row drivers area: 476.452, number of row_drivers: 4096,
# total row drivers area: (476.452*4096/4096) * macro = 17152.272
#
# Size: 3
# Size: 3
# Size: 4
# All macro: 36
# cim unit area: 0.01936, number of cim_unit: 268435456,
# total cim unit area: (0.01936*268435456/4096) * macro = 45675.970559999994
#
# Total Area for layer 8: 730034.06256
#
# Total Macro for layer 8: 94
#
# Total Area for all layers: 1906200.05224
# Total Area for ADC across all layers: 1702960.4
# Processing layer: RRAM_vgg16_256_layer_9
# Size: 3
# Size: 3
# Size: 4
# Size: 2
# All macro: 72
# adc area: 18116.6, number of adc: 4096,
# total adc area: (18116.6*4096/4096) * macro = 1304395.2
#
# Size: 3
# Size: 3
# Size: 4
# Size: 2
# All macro: 72
# column drivers area: 416.895, number of column_drivers: 4096,
# total column drivers area: (416.895*4096/4096) * macro = 30016.44
#
# Size: 3
# Size: 3
# Size: 4
# Size: 2
# All macro: 72
# row drivers area: 476.452, number of row_drivers: 4096,
# total row drivers area: (476.452*4096/4096) * macro = 34304.544
#
# Size: 3
# Size: 3
# Size: 4
# Size: 2
# All macro: 72
# cim unit area: 0.01936, number of cim_unit: 268435456,
# total cim unit area: (0.01936*268435456/4096) * macro = 91351.94111999999
#
# Total Area for layer 9: 1460068.12512
#
# Total Macro for layer 9: 166
#
# Total Area for all layers: 3366268.17736
# Total Area for ADC across all layers: 3007355.5999999996
# Processing layer: RRAM_vgg16_256_layer_10
# Size: 3
# Size: 3
# Size: 4
# Size: 2
# All macro: 72
# adc area: 18116.6, number of adc: 4096,
# total adc area: (18116.6*4096/4096) * macro = 1304395.2
#
# Size: 3
# Size: 3
# Size: 4
# Size: 2
# All macro: 72
# column drivers area: 416.895, number of column_drivers: 4096,
# total column drivers area: (416.895*4096/4096) * macro = 30016.44
#
# Size: 3
# Size: 3
# Size: 4
# Size: 2
# All macro: 72
# row drivers area: 476.452, number of row_drivers: 4096,
# total row drivers area: (476.452*4096/4096) * macro = 34304.544
#
# Size: 3
# Size: 3
# Size: 4
# Size: 2
# All macro: 72
# cim unit area: 0.01936, number of cim_unit: 268435456,
# total cim unit area: (0.01936*268435456/4096) * macro = 91351.94111999999
#
# Total Area for layer 10: 1460068.12512
#
# Total Macro for layer 10: 238
#
# Total Area for all layers: 4826336.30248
# Total Area for ADC across all layers: 4311750.8
# Processing layer: RRAM_vgg16_256_layer_11
# Size: 3
# Size: 3
# Size: 4
# Size: 2
# All macro: 72
# adc area: 18116.6, number of adc: 4096,
# total adc area: (18116.6*4096/4096) * macro = 1304395.2
#
# Size: 3
# Size: 3
# Size: 4
# Size: 2
# All macro: 72
# column drivers area: 416.895, number of column_drivers: 4096,
# total column drivers area: (416.895*4096/4096) * macro = 30016.44
#
# Size: 3
# Size: 3
# Size: 4
# Size: 2
# All macro: 72
# row drivers area: 476.452, number of row_drivers: 4096,
# total row drivers area: (476.452*4096/4096) * macro = 34304.544
#
# Size: 3
# Size: 3
# Size: 4
# Size: 2
# All macro: 72
# cim unit area: 0.01936, number of cim_unit: 268435456,
# total cim unit area: (0.01936*268435456/4096) * macro = 91351.94111999999
#
# Total Area for layer 11: 1460068.12512
#
# Total Macro for layer 11: 310
#
# Total Area for all layers: 6286404.4276
# Total Area for ADC across all layers: 5616146.0
# Processing layer: RRAM_vgg16_256_layer_12
# Size: 3
# Size: 3
# Size: 4
# Size: 2
# All macro: 72
# adc area: 18116.6, number of adc: 4096,
# total adc area: (18116.6*4096/4096) * macro = 1304395.2
#
# Size: 3
# Size: 3
# Size: 4
# Size: 2
# All macro: 72
# column drivers area: 416.895, number of column_drivers: 4096,
# total column drivers area: (416.895*4096/4096) * macro = 30016.44
#
# Size: 3
# Size: 3
# Size: 4
# Size: 2
# All macro: 72
# row drivers area: 476.452, number of row_drivers: 4096,
# total row drivers area: (476.452*4096/4096) * macro = 34304.544
#
# Size: 3
# Size: 3
# Size: 4
# Size: 2
# All macro: 72
# cim unit area: 0.01936, number of cim_unit: 268435456,
# total cim unit area: (0.01936*268435456/4096) * macro = 91351.94111999999
#
# Total Area for layer 12: 1460068.12512
#
# Total Macro for layer 12: 382
#
# Total Area for all layers: 7746472.55272
# Total Area for ADC across all layers: 6920541.2
# Processing layer: RRAM_vgg16_256_layer_13
# Size: 3
# Size: 3
# Size: 4
# Size: 2
# All macro: 72
# adc area: 18116.6, number of adc: 4096,
# total adc area: (18116.6*4096/4096) * macro = 1304395.2
#
# Size: 3
# Size: 3
# Size: 4
# Size: 2
# All macro: 72
# column drivers area: 416.895, number of column_drivers: 4096,
# total column drivers area: (416.895*4096/4096) * macro = 30016.44
#
# Size: 3
# Size: 3
# Size: 4
# Size: 2
# All macro: 72
# row drivers area: 476.452, number of row_drivers: 4096,
# total row drivers area: (476.452*4096/4096) * macro = 34304.544
#
# Size: 3
# Size: 3
# Size: 4
# Size: 2
# All macro: 72
# cim unit area: 0.01936, number of cim_unit: 268435456,
# total cim unit area: (0.01936*268435456/4096) * macro = 91351.94111999999
#
# Total Area for layer 13: 1460068.12512
#
# Total Macro for layer 13: 454
#
# Total Area for all layers: 9206540.67784
# Total Area for ADC across all layers: 8224936.4
# Processing layer: RRAM_vgg16_256_layer_14
# Size: 32
# Size: 98
# All macro: 3136
# adc area: 18116.6, number of adc: 4096,
# total adc area: (18116.6*4096/4096) * macro = 56813657.599999994
#
# Size: 32
# Size: 98
# All macro: 3136
# column drivers area: 416.895, number of column_drivers: 4096,
# total column drivers area: (416.895*4096/4096) * macro = 1307382.72
#
# Size: 32
# Size: 98
# All macro: 3136
# row drivers area: 476.452, number of row_drivers: 4096,
# total row drivers area: (476.452*4096/4096) * macro = 1494153.472
#
# Size: 32
# Size: 98
# All macro: 3136
# cim unit area: 0.01936, number of cim_unit: 268435456,
# total cim unit area: (0.01936*268435456/4096) * macro = 3978884.5465599997
#
# Total Area for layer 14: 63594078.33855999
#
# Total Macro for layer 14: 3590
#
# Total Area for all layers: 72800619.0164
# Total Area for ADC across all layers: 65038593.99999999
# Processing layer: RRAM_vgg16_256_layer_15
# Size: 32
# Size: 16
# All macro: 512
# adc area: 18116.6, number of adc: 4096,
# total adc area: (18116.6*4096/4096) * macro = 9275699.2
#
# Size: 32
# Size: 16
# All macro: 512
# column drivers area: 416.895, number of column_drivers: 4096,
# total column drivers area: (416.895*4096/4096) * macro = 213450.24
#
# Size: 32
# Size: 16
# All macro: 512
# row drivers area: 476.452, number of row_drivers: 4096,
# total row drivers area: (476.452*4096/4096) * macro = 243943.424
#
# Size: 32
# Size: 16
# All macro: 512
# cim unit area: 0.01936, number of cim_unit: 268435456,
# total cim unit area: (0.01936*268435456/4096) * macro = 649613.80352
#
# Total Area for layer 15: 10382706.66752
#
# Total Macro for layer 15: 4102
#
# Total Area for all layers: 83183325.68392
# Total Area for ADC across all layers: 74314293.19999999
# Processing layer: RRAM_vgg16_256_layer_16
# Size: 8
# Size: 16
# All macro: 128
# adc area: 18116.6, number of adc: 4096,
# total adc area: (18116.6*4096/4096) * macro = 2318924.8
#
# Size: 8
# Size: 16
# All macro: 128
# column drivers area: 416.895, number of column_drivers: 4096,
# total column drivers area: (416.895*4096/4096) * macro = 53362.56
#
# Size: 8
# Size: 16
# All macro: 128
# row drivers area: 476.452, number of row_drivers: 4096,
# total row drivers area: (476.452*4096/4096) * macro = 60985.856
#
# Size: 8
# Size: 16
# All macro: 128
# cim unit area: 0.01936, number of cim_unit: 268435456,
# total cim unit area: (0.01936*268435456/4096) * macro = 162403.45088
#
# Total Area for layer 16: 2595676.66688
#
# Total Macro for layer 16: 4230
#
# Total Area for all layers: 85779002.3508
# Total Area for ADC across all layers: 76633217.99999999
# Total Area for column drivers across all layers: 1763465.85
# Total Area for row drivers across all layers: 2015391.9600000002
# Total Area for cim unit across all layers: 5366926.5408
#
#
# Total Area for ADC across all layers: 76.63321799999999
# Total Area for column driver across all layers: 1.76346585
# Total Area for row driver across all layers: 2.01539196
# Total Area for cim unit across all layers: 5.3669265408
# Total Macro across all layers: 4230
# RRAM_vgg16_256 	 2.77e-04 	 85.78 	 7.26e+01

# %%
print(total_area)
print(total_adc_area)
print(total_col_area)
print(total_row_area)
print(total_cim_unit_area)
print(total_macro)
print(energy)
print(throughput)
# Out:
# [363.66125068896, 243.60781419071998, 125.50552699055999, 85.77900235079998]
# [359.85794599999997, 238.48964159999997, 119.7810984, 76.63321799999999]
# [1.5072845955999996, 1.7626362880000002, 1.5621093119999998, 1.76346585]
# [1.722612206, 2.0144390559999996, 1.785265644, 2.01539196]
# [0.5734078873599999, 1.34109724672, 2.3770536345599997, 5.3669265408]
# [28924, 16912, 7494, 4230]
# [0.0008842079999999999, 0.0005264769999999998, 0.00035196409999999995, 0.0002766422]
# [71.42346975216056, 72.56630746344473, 72.57210038172926, 72.5736804290556]

# %%
import matplotlib.pyplot as plt
import numpy as np
fig, ax = plt.subplots(figsize=(10, 5)) 
array_sizes = ['32', '64', '128', '256']

x = np.arange(len(array_sizes))

# Stack bars
ax.bar(array_sizes, total_cim_unit_area, label='cim_unit')
ax.bar(array_sizes, total_row_area, bottom=total_cim_unit_area, label='row_drivers')
ax.bar(array_sizes, total_col_area, bottom=np.array(total_cim_unit_area) + np.array(total_row_area), label='column_drivers')
ax.bar(array_sizes, total_adc_area, bottom=np.array(total_cim_unit_area) + np.array(total_row_area) + np.array(total_col_area), label='adc')

# Labels and title
ax.set_title("Area vs Array Size for vgg16")
ax.set_xlabel("Array Size")
ax.set_ylabel("Area (mm2)")
# Set x-ticks
ax.set_xticks(x)
ax.set_xticklabels(array_sizes)

ax.legend()

# Show plot
plt.show()

# %%
for array_size in array_sizes_list:
    print(f"Array size: {array_size}")
    # For each component index (0 to 3)
    for i in range(4):
        print(f"total_per_energy[{array_size}][{i}]: {total_per_energy[array_size][i]}")
    print()
# Out:
# Array size: 32
# total_per_energy[32][0]: 0.5372894947863196
# total_per_energy[32][1]: 2.133119486763598e-12
# total_per_energy[32][2]: 0.3512429831588533
# total_per_energy[32][3]: 0.11146752205269395
#
# Array size: 64
# total_per_energy[64][0]: 0.6261682242974085
# total_per_energy[64][1]: 2.4859813084046343e-12
# total_per_energy[64][2]: 0.2439252336443198
# total_per_energy[64][3]: 0.1299065420557857
#
# Array size: 128
# total_per_energy[128][0]: 0.6836734693857792
# total_per_energy[128][1]: 2.7142857142778697e-12
# total_per_energy[128][2]: 0.17551020408122425
# total_per_energy[128][3]: 0.14081632653028225
#
# Array size: 256
# total_per_energy[256][0]: 0.630291627466167
# total_per_energy[256][1]: 5.004703668835625e-12
# total_per_energy[256][2]: 0.23988711194615717
# total_per_energy[256][3]: 0.12982126058267118

# %%
display_markdown(
    """
### Calculating the energy

"""
)

total_adc_energy = [0] * 4
total_col_energy = [0] * 4
total_row_energy = [0] * 4
total_cim_unit_energy = [0] * 4
for j in range(len(energy)):
    if j == 0:
        for i in range(4):
            if i == 0:
                total_adc_energy[j] = total_per_energy[32][i] * energy[j]
            elif i == 1:
                total_col_energy[j] = total_per_energy[32][i] * energy[j]
            elif i == 2:
                total_row_energy[j] = total_per_energy[32][i] * energy[j]
            else:
                total_cim_unit_energy[j] = total_per_energy[32][i] * energy[j]
    elif j == 1:
        for i in range(4):
            if i == 0:
                total_adc_energy[j] = total_per_energy[64][i] * energy[j]
            elif i == 1:
                total_col_energy[j] = total_per_energy[64][i] * energy[j]
            elif i == 2:
                total_row_energy[j] = total_per_energy[64][i] * energy[j]
            else:
                total_cim_unit_energy[j] = total_per_energy[64][i] * energy[j]

    elif j == 2:
        for i in range(4):
            if i == 0:
                total_adc_energy[j] = total_per_energy[128][i] * energy[j]
            elif i == 1:
                total_col_energy[j] = total_per_energy[128][i] * energy[j]
            elif i == 2:
                total_row_energy[j] = total_per_energy[128][i] * energy[j]
            else:
                total_cim_unit_energy[j] = total_per_energy[128][i] * energy[j]

    else:
        for i in range(4):
            if i == 0:
                total_adc_energy[j] = total_per_energy[256][i] * energy[j]
            elif i == 1:
                total_col_energy[j] = total_per_energy[256][i] * energy[j]
            elif i == 2:
                total_row_energy[j] = total_per_energy[256][i] * energy[j]
            else:
                total_cim_unit_energy[j] = total_per_energy[256][i] * energy[j]
                
print("Total ADC Energy:", total_adc_energy)
print("Total Column Energy:", total_col_energy)
print("Total Row Energy:", total_row_energy)
print("Total CIM Unit Energy:", total_cim_unit_energy)
# Out:
# ### Calculating the energy
# Total ADC Energy: [0.00047507566960602204, 0.0003296631682234266, 0.0002406285173462433, 0.00017436526246382086]
# Total Column Energy: [1.8861213151522672e-15, 1.3088119813049462e-15, 9.553311285686674e-16, 1.3845122332947587e-15]
# Total Row Energy: [0.0003105718556529233, 0.00012842102523336052, 6.177329102026441e-05, 6.636289840043121e-05]
# Total CIM Unit Energy: [9.85604747391684e-05, 6.839280654190387e-05, 4.956229163253691e-05, 3.591403913436344e-05]

# %%
import matplotlib.pyplot as plt
import numpy as np
fig, ax = plt.subplots(figsize=(10, 5)) 
array_sizes = ['32', '64', '128', '256']

x = np.arange(len(array_sizes))

# Stack bars
ax.bar(array_sizes, total_cim_unit_energy, label='cim_unit')
ax.bar(array_sizes, total_row_energy, bottom=total_cim_unit_energy, label='row_drivers')
ax.bar(array_sizes, total_col_energy, bottom=np.array(total_cim_unit_energy) + np.array(total_row_energy), label='column_drivers')
ax.bar(array_sizes, total_adc_energy, bottom=np.array(total_cim_unit_energy) + np.array(total_row_energy) + np.array(total_col_energy), label='adc')

# Labels and title
ax.set_title("Energy vs Array Size for vgg16")
ax.set_xlabel("Array Size")
ax.set_ylabel("Energy (J)")
# Set x-ticks
ax.set_xticks(x)
ax.set_xticklabels(array_sizes)

ax.legend()

# Show plot
plt.show()

# %%
display_markdown(
    """
### Plot the Throughput

"""
)
import matplotlib.pyplot as plt

# Data
array_sizes = ['32', '64', '128', '256']
x = np.arange(len(array_sizes))
# Plotting the line graph
plt.figure(figsize=(10, 6))
plt.plot(array_sizes, throughput, marker='o', linestyle='-', color='b')

# Adding labels and title
plt.xlabel('Array Size')
plt.ylabel('Throughput')
plt.title('Throughput vs Array Size for vgg 16')
plt.grid(False)
plt.xticks(x, array_sizes) 
# Show plot
plt.show()
# Out:
# ### Plot the Throughput

# %%
display_markdown(
    """
### Plot the Number of Macros

"""
)
import matplotlib.pyplot as plt

# Data
array_sizes = ['32', '64', '128', '256']
x = np.arange(len(array_sizes))
# Plotting the line graph
plt.figure(figsize=(10, 6))
plt.plot(array_sizes, total_macro, marker='o', linestyle='-', color='b')

# Adding labels and title
plt.xlabel('Array Size')
plt.ylabel('Number of Macros')
plt.title('Number of Macros vs Array Size for vgg 16')
plt.grid(False)
plt.xticks(x, array_sizes) 
# Show plot
plt.show()
# Out:
# ### Plot the Number of Macros
