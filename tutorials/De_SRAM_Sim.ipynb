# %% [markdown]
# # 32x32 Array size, 22 nm

# %%
from _import_scripts import scripts
from scripts.notebook_utils import *
from scripts.tl_output_parsing import MacroOutputStats

MACRO_PATH = "../models/arch/1_macro/basic_analog/" 

display_markdown(
    """
### 32x32 Array Sizes, 22 nm

"""
)
array_sizes = 32
SRAM_PATH = f'"{os.path.abspath("../models/memory_cells/sram_example.cell.yaml")}"'
path = SRAM_PATH
macro = {}

def run_layer(dnn: str, layer: str, array_sizes: int, variables):
    print(f"{layer} ", end="", flush=True)
    spec = get_spec(
        "basic_analog",
        # Weight-stationary, dummy buffer on top to hold inputs & outputs, many
        # macros to ensure we can fit all weights.
        system="ws_dummy_buffer_many_macro",
        # Set the DNN and layer
        dnn=dnn,
        layer=layer,
    )

    # Do NOT generate a maximum-utilization workload; we're running a DNN
    # workload.
    spec.variables["MAX_UTILIZATION"] = False

    # Use a larger array to ensure we can fit all weights
    spec.architecture.find("column").spatial.meshX = array_sizes
    spec.architecture.find("row").spatial.meshY = array_sizes

    spec.variables.update(variables)
    output_stats = run_mapper(spec)
    
    # Print computes for the layer
    macro_output_stats = MacroOutputStats.from_output_stats(output_stats)
    print(f"Computes: {macro_output_stats.computes}")
    global macro
    macro[layer] = macro_output_stats.computes
    return output_stats


DNN_OPTIONS = [
    d
    for d in os.listdir(f"../models/workloads/")
    if os.path.isdir(f"../models/workloads/{d}")
]
DNN_OPTIONS = [d for d in DNN_OPTIONS if not d.startswith("_")]
print(f"Available DNNs: {DNN_OPTIONS}")

# =============================================================================
# Change this DNN to explore different DNNs!
# =============================================================================
DNN = "vgg16"
# =============================================================================
# Change this DNN to explore different DNNs!
# =============================================================================

layers = [f for f in os.listdir(f"../models/workloads/{DNN}") if f != "index.yaml" and f.endswith(".yaml")]
layers = sorted(layers)
print(f"Running: ", end="")

# Parallel/Delayed is used to multiprocess. Equivalent to running the following
# code in serial:
# results = [run_layer(DNN, layer.split(".")[0]) for layer in layers]
results = joblib.Parallel(n_jobs=None)(
    joblib.delayed(run_layer)(DNN, layer.split(".")[0], array_sizes, 
                              {
                                  "CELL_CONFIG": path,
                                  "BITS_PER_CELL": 1 if path == SRAM_PATH else 4,
                                  "CIM_UNIT_WIDTH_CELLS": 4 if path == SRAM_PATH else 1,
                                  "IS_SRAM": path == SRAM_PATH,
                                  "TECHNOLOGY": 22,
                                  "ADC_RESOLUTION": 5
                              }
                             ) for layer in layers
)
print("")
for r in results:
    r.clear_zero_energies()

# Initialize overall_energy
energy_layer = [0] * 16
result = 0

total_per_energy_32 = [0] * 4

total_adc_energy = 0.0
total_col_energy = 0.0
total_row_energy = 0.0
total_cim_unit_energy = 0.0
# Calculate overall energy
for r in results:

    per_component_energy = r.per_compute("per_component_energy")
    total_energy_per_layer = sum(per_component_energy.values()) * 1e15  # Convert to fJ
    total_adc_energy += per_component_energy.get('adc', 0.0)
    total_col_energy += per_component_energy.get('column_drivers', 0.0)
    total_row_energy += per_component_energy.get('row_drivers', 0.0)
    total_cim_unit_energy += per_component_energy.get('cim_unit', 0.0)

    total_adc_energy = total_adc_energy * 1e15
    total_col_energy = total_col_energy * 1e15
    total_row_energy = total_row_energy * 1e15
    total_cim_unit_energy = total_cim_unit_energy * 1e15
    total_energy = total_adc_energy + total_col_energy + total_row_energy + total_cim_unit_energy

    total_adc_energy = total_adc_energy/total_energy
    total_col_energy = total_col_energy/total_energy
    total_row_energy = total_row_energy/total_energy
    total_cim_unit_energy = total_cim_unit_energy/total_energy
  
    total_per_energy_32[0] = total_adc_energy
    total_per_energy_32[1] = total_col_energy
    total_per_energy_32[2] = total_row_energy
    total_per_energy_32[3] = total_cim_unit_energy
    
# Display overall energy
print(f"Overall energy for DNN {DNN}: {total_energy} fJ")

# Display an energy breakdown for each layer as a bar chart. Display normalized per-MAC and per-layer energy.
fig, ax = plt.subplots(figsize=(20, 5))

bar_stacked(
    {i: r.per_compute("per_component_energy") * 1e15 for i, r in enumerate(results)},
    title="Using SRAM on 32 x 32 array sizes, 22 nm",
    xlabel="Layer",
    ylabel="Energy (fJ/MAC)",
    ax=ax,
)
# Out:
# ### 32x32 Array Sizes, 22 nm
# Available DNNs: ['vision_transformer', 'dpt_large', 'resnet18', 'mobilebert', 'msft_phi_1_5', 'gpt2_medium', 'vgg16', 'mobilenet_v3', 'alexnet', 'densenet201']
# Running: 00 /home/workspace/scripts/../outputs/vgg16_32_SRAM_de
# Layer directory: /home/workspace/scripts/../outputs/vgg16_32_SRAM_de/vgg16_32_SRAM_de_layer_1
# Computes: 169344.0
# 01 /home/workspace/scripts/../outputs/vgg16_32_SRAM_de
# Layer directory: /home/workspace/scripts/../outputs/vgg16_32_SRAM_de/vgg16_32_SRAM_de_layer_2
# Computes: 3612672.0
# 02 /home/workspace/scripts/../outputs/vgg16_32_SRAM_de
# Layer directory: /home/workspace/scripts/../outputs/vgg16_32_SRAM_de/vgg16_32_SRAM_de_layer_3
# Computes: 1806336.0
# 03 /home/workspace/scripts/../outputs/vgg16_32_SRAM_de
# Layer directory: /home/workspace/scripts/../outputs/vgg16_32_SRAM_de/vgg16_32_SRAM_de_layer_4
# Computes: 3612672.0
# 04 /home/workspace/scripts/../outputs/vgg16_32_SRAM_de
# Layer directory: /home/workspace/scripts/../outputs/vgg16_32_SRAM_de/vgg16_32_SRAM_de_layer_5
# Computes: 1806336.0
# 05 /home/workspace/scripts/../outputs/vgg16_32_SRAM_de
# Layer directory: /home/workspace/scripts/../outputs/vgg16_32_SRAM_de/vgg16_32_SRAM_de_layer_6
# Computes: 3612672.0
# 06 /home/workspace/scripts/../outputs/vgg16_32_SRAM_de
# Layer directory: /home/workspace/scripts/../outputs/vgg16_32_SRAM_de/vgg16_32_SRAM_de_layer_7
# Computes: 3612672.0
# 07 /home/workspace/scripts/../outputs/vgg16_32_SRAM_de
# Layer directory: /home/workspace/scripts/../outputs/vgg16_32_SRAM_de/vgg16_32_SRAM_de_layer_8
# Computes: 1806336.0
# 08 /home/workspace/scripts/../outputs/vgg16_32_SRAM_de
# Layer directory: /home/workspace/scripts/../outputs/vgg16_32_SRAM_de/vgg16_32_SRAM_de_layer_9
# Computes: 3612672.0
# 09 /home/workspace/scripts/../outputs/vgg16_32_SRAM_de
# Layer directory: /home/workspace/scripts/../outputs/vgg16_32_SRAM_de/vgg16_32_SRAM_de_layer_10
# Computes: 3612672.0
# 10 /home/workspace/scripts/../outputs/vgg16_32_SRAM_de
# Layer directory: /home/workspace/scripts/../outputs/vgg16_32_SRAM_de/vgg16_32_SRAM_de_layer_11
# Computes: 903168.0
# 11 /home/workspace/scripts/../outputs/vgg16_32_SRAM_de
# Layer directory: /home/workspace/scripts/../outputs/vgg16_32_SRAM_de/vgg16_32_SRAM_de_layer_12
# Computes: 903168.0
# 12 /home/workspace/scripts/../outputs/vgg16_32_SRAM_de
# Layer directory: /home/workspace/scripts/../outputs/vgg16_32_SRAM_de/vgg16_32_SRAM_de_layer_13
# Computes: 903168.0
# 13 /home/workspace/scripts/../outputs/vgg16_32_SRAM_de
# Layer directory: /home/workspace/scripts/../outputs/vgg16_32_SRAM_de/vgg16_32_SRAM_de_layer_14
# Computes: 200704.0
# 14 /home/workspace/scripts/../outputs/vgg16_32_SRAM_de
# Layer directory: /home/workspace/scripts/../outputs/vgg16_32_SRAM_de/vgg16_32_SRAM_de_layer_15
# Computes: 32768.0
# 15 /home/workspace/scripts/../outputs/vgg16_32_SRAM_de
# Layer directory: /home/workspace/scripts/../outputs/vgg16_32_SRAM_de/vgg16_32_SRAM_de_layer_16
# Computes: 7999.9999923706055
#
# Overall energy for DNN vgg16: 1000000000000078.5 fJ

# %% [markdown]
# # 64 x 64 Array Size, 22 nm

# %%
from _import_scripts import scripts
from scripts.notebook_utils import *
from scripts.tl_output_parsing import MacroOutputStats

MACRO_PATH = "../models/arch/1_macro/basic_analog/" 

display_markdown(
    """
### 64x64 Array Sizes, 22 nm

"""
)
array_sizes = 64
SRAM_PATH = f'"{os.path.abspath("../models/memory_cells/sram_example.cell.yaml")}"'
path = SRAM_PATH
macro = {}

def run_layer(dnn: str, layer: str, array_sizes: int, variables):
    print(f"{layer} ", end="", flush=True)
    spec = get_spec(
        "basic_analog",
        # Weight-stationary, dummy buffer on top to hold inputs & outputs, many
        # macros to ensure we can fit all weights.
        system="ws_dummy_buffer_many_macro",
        # Set the DNN and layer
        dnn=dnn,
        layer=layer,
    )

    # Do NOT generate a maximum-utilization workload; we're running a DNN
    # workload.
    spec.variables["MAX_UTILIZATION"] = False

    # Use a larger array to ensure we can fit all weights
    spec.architecture.find("column").spatial.meshX = array_sizes
    spec.architecture.find("row").spatial.meshY = array_sizes

    spec.variables.update(variables)
    output_stats = run_mapper(spec)
    
    # Print computes for the layer
    macro_output_stats = MacroOutputStats.from_output_stats(output_stats)
    print(f"Computes: {macro_output_stats.computes}")
    global macro
    macro[layer] = macro_output_stats.computes
    return output_stats


DNN_OPTIONS = [
    d
    for d in os.listdir(f"../models/workloads/")
    if os.path.isdir(f"../models/workloads/{d}")
]
DNN_OPTIONS = [d for d in DNN_OPTIONS if not d.startswith("_")]
print(f"Available DNNs: {DNN_OPTIONS}")

# =============================================================================
# Change this DNN to explore different DNNs!
# =============================================================================
DNN = "vgg16"
# =============================================================================
# Change this DNN to explore different DNNs!
# =============================================================================

layers = [f for f in os.listdir(f"../models/workloads/{DNN}") if f != "index.yaml" and f.endswith(".yaml")]
layers = sorted(layers)
print(f"Running: ", end="")

# Parallel/Delayed is used to multiprocess. Equivalent to running the following
# code in serial:
# results = [run_layer(DNN, layer.split(".")[0]) for layer in layers]
results = joblib.Parallel(n_jobs=None)(
    joblib.delayed(run_layer)(DNN, layer.split(".")[0], array_sizes, 
                              {
                                  "CELL_CONFIG": path,
                                  "BITS_PER_CELL": 1 if path == SRAM_PATH else 4,
                                  "CIM_UNIT_WIDTH_CELLS": 4 if path == SRAM_PATH else 1,
                                  "IS_SRAM": path == SRAM_PATH,
                                  "TECHNOLOGY": 22,
                                  "ADC_RESOLUTION": 5
                              }
                             ) for layer in layers
)
print("")
for r in results:
    r.clear_zero_energies()

# Initialize overall_energy
energy_layer = [0] * 16
result = 0

total_per_energy_64 = [0] * 4

total_adc_energy = 0.0
total_col_energy = 0.0
total_row_energy = 0.0
total_cim_unit_energy = 0.0
# Calculate overall energy
for r in results:

    per_component_energy = r.per_compute("per_component_energy")
    total_energy_per_layer = sum(per_component_energy.values()) * 1e15  # Convert to fJ
    total_adc_energy += per_component_energy.get('adc', 0.0)
    total_col_energy += per_component_energy.get('column_drivers', 0.0)
    total_row_energy += per_component_energy.get('row_drivers', 0.0)
    total_cim_unit_energy += per_component_energy.get('cim_unit', 0.0)

    total_adc_energy = total_adc_energy * 1e15
    total_col_energy = total_col_energy * 1e15
    total_row_energy = total_row_energy * 1e15
    total_cim_unit_energy = total_cim_unit_energy * 1e15
    total_energy = total_adc_energy + total_col_energy + total_row_energy + total_cim_unit_energy

    total_adc_energy = total_adc_energy/total_energy
    total_col_energy = total_col_energy/total_energy
    total_row_energy = total_row_energy/total_energy
    total_cim_unit_energy = total_cim_unit_energy/total_energy
  
    total_per_energy_64[0] = total_adc_energy
    total_per_energy_64[1] = total_col_energy
    total_per_energy_64[2] = total_row_energy
    total_per_energy_64[3] = total_cim_unit_energy
    
# Display overall energy
print(f"Overall energy for DNN {DNN}: {total_energy} fJ")

# Display an energy breakdown for each layer as a bar chart. Display normalized per-MAC and per-layer energy.
fig, ax = plt.subplots(figsize=(20, 5))

bar_stacked(
    {i: r.per_compute("per_component_energy") * 1e15 for i, r in enumerate(results)},
    title="Using SRAM on 64 x 64 array sizes, 22 nm",
    xlabel="Layer",
    ylabel="Energy (fJ/MAC)",
    ax=ax,
)
# Out:
# ### 64x64 Array Sizes, 22 nm
# Available DNNs: ['vision_transformer', 'dpt_large', 'resnet18', 'mobilebert', 'msft_phi_1_5', 'gpt2_medium', 'vgg16', 'mobilenet_v3', 'alexnet', 'densenet201']
# Running: 00 /home/workspace/scripts/../outputs/vgg16_64_SRAM_de
# Layer directory: /home/workspace/scripts/../outputs/vgg16_64_SRAM_de/vgg16_64_SRAM_de_layer_1
# Computes: 169344.0
# 01 /home/workspace/scripts/../outputs/vgg16_64_SRAM_de
# Layer directory: /home/workspace/scripts/../outputs/vgg16_64_SRAM_de/vgg16_64_SRAM_de_layer_2
# Computes: 3612672.0
# 02 /home/workspace/scripts/../outputs/vgg16_64_SRAM_de
# Layer directory: /home/workspace/scripts/../outputs/vgg16_64_SRAM_de/vgg16_64_SRAM_de_layer_3
# Computes: 1806336.0
# 03 /home/workspace/scripts/../outputs/vgg16_64_SRAM_de
# Layer directory: /home/workspace/scripts/../outputs/vgg16_64_SRAM_de/vgg16_64_SRAM_de_layer_4
# Computes: 3612672.0
# 04 /home/workspace/scripts/../outputs/vgg16_64_SRAM_de
# Layer directory: /home/workspace/scripts/../outputs/vgg16_64_SRAM_de/vgg16_64_SRAM_de_layer_5
# Computes: 1806336.0
# 05 /home/workspace/scripts/../outputs/vgg16_64_SRAM_de
# Layer directory: /home/workspace/scripts/../outputs/vgg16_64_SRAM_de/vgg16_64_SRAM_de_layer_6
# Computes: 3612672.0
# 06 /home/workspace/scripts/../outputs/vgg16_64_SRAM_de
# Layer directory: /home/workspace/scripts/../outputs/vgg16_64_SRAM_de/vgg16_64_SRAM_de_layer_7
# Computes: 3612672.0
# 07 /home/workspace/scripts/../outputs/vgg16_64_SRAM_de
# Layer directory: /home/workspace/scripts/../outputs/vgg16_64_SRAM_de/vgg16_64_SRAM_de_layer_8
# Computes: 1806336.0
# 08 /home/workspace/scripts/../outputs/vgg16_64_SRAM_de
# Layer directory: /home/workspace/scripts/../outputs/vgg16_64_SRAM_de/vgg16_64_SRAM_de_layer_9
# Computes: 3612672.0
# 09 /home/workspace/scripts/../outputs/vgg16_64_SRAM_de
# Layer directory: /home/workspace/scripts/../outputs/vgg16_64_SRAM_de/vgg16_64_SRAM_de_layer_10
# Computes: 3612672.0
# 10 /home/workspace/scripts/../outputs/vgg16_64_SRAM_de
# Layer directory: /home/workspace/scripts/../outputs/vgg16_64_SRAM_de/vgg16_64_SRAM_de_layer_11
# Computes: 903168.0
# 11 /home/workspace/scripts/../outputs/vgg16_64_SRAM_de
# Layer directory: /home/workspace/scripts/../outputs/vgg16_64_SRAM_de/vgg16_64_SRAM_de_layer_12
# Computes: 903168.0
# 12 /home/workspace/scripts/../outputs/vgg16_64_SRAM_de
# Layer directory: /home/workspace/scripts/../outputs/vgg16_64_SRAM_de/vgg16_64_SRAM_de_layer_13
# Computes: 903168.0
# 13 /home/workspace/scripts/../outputs/vgg16_64_SRAM_de
# Layer directory: /home/workspace/scripts/../outputs/vgg16_64_SRAM_de/vgg16_64_SRAM_de_layer_14
# Computes: 200704.0
# 14 /home/workspace/scripts/../outputs/vgg16_64_SRAM_de
# Layer directory: /home/workspace/scripts/../outputs/vgg16_64_SRAM_de/vgg16_64_SRAM_de_layer_15
# Computes: 32768.0
# 15 /home/workspace/scripts/../outputs/vgg16_64_SRAM_de
# Layer directory: /home/workspace/scripts/../outputs/vgg16_64_SRAM_de/vgg16_64_SRAM_de_layer_16
# Computes: 8000.0
#
# Overall energy for DNN vgg16: 1000000000000033.2 fJ

# %% [markdown]
# # 128x128 Array Size, 22 nm

# %%
from _import_scripts import scripts
from scripts.notebook_utils import *
from scripts.tl_output_parsing import MacroOutputStats

MACRO_PATH = "../models/arch/1_macro/basic_analog/" 

display_markdown(
    """
### 128x128 Array Sizes, 22 nm

"""
)
array_sizes = 128
SRAM_PATH = f'"{os.path.abspath("../models/memory_cells/sram_example.cell.yaml")}"'
path = SRAM_PATH
macro = {}

def run_layer(dnn: str, layer: str, array_sizes: int, variables):
    print(f"{layer} ", end="", flush=True)
    spec = get_spec(
        "basic_analog",
        # Weight-stationary, dummy buffer on top to hold inputs & outputs, many
        # macros to ensure we can fit all weights.
        system="ws_dummy_buffer_many_macro",
        # Set the DNN and layer
        dnn=dnn,
        layer=layer,
    )

    # Do NOT generate a maximum-utilization workload; we're running a DNN
    # workload.
    spec.variables["MAX_UTILIZATION"] = False

    # Use a larger array to ensure we can fit all weights
    spec.architecture.find("column").spatial.meshX = array_sizes
    spec.architecture.find("row").spatial.meshY = array_sizes

    spec.variables.update(variables)
    output_stats = run_mapper(spec)
    
    # Print computes for the layer
    macro_output_stats = MacroOutputStats.from_output_stats(output_stats)
    print(f"Computes: {macro_output_stats.computes}")
    global macro
    macro[layer] = macro_output_stats.computes
    return output_stats


DNN_OPTIONS = [
    d
    for d in os.listdir(f"../models/workloads/")
    if os.path.isdir(f"../models/workloads/{d}")
]
DNN_OPTIONS = [d for d in DNN_OPTIONS if not d.startswith("_")]
print(f"Available DNNs: {DNN_OPTIONS}")

# =============================================================================
# Change this DNN to explore different DNNs!
# =============================================================================
DNN = "vgg16"
# =============================================================================
# Change this DNN to explore different DNNs!
# =============================================================================

layers = [f for f in os.listdir(f"../models/workloads/{DNN}") if f != "index.yaml" and f.endswith(".yaml")]
layers = sorted(layers)
print(f"Running: ", end="")

# Parallel/Delayed is used to multiprocess. Equivalent to running the following
# code in serial:
# results = [run_layer(DNN, layer.split(".")[0]) for layer in layers]
results = joblib.Parallel(n_jobs=None)(
    joblib.delayed(run_layer)(DNN, layer.split(".")[0], array_sizes, 
                              {
                                  "CELL_CONFIG": path,
                                  "BITS_PER_CELL": 1 if path == SRAM_PATH else 4,
                                  "CIM_UNIT_WIDTH_CELLS": 4 if path == SRAM_PATH else 1,
                                  "IS_SRAM": path == SRAM_PATH,
                                  "TECHNOLOGY": 22,
                                  "ADC_RESOLUTION": 5
                              }
                             ) for layer in layers
)
print("")
for r in results:
    r.clear_zero_energies()

# Initialize overall_energy
energy_layer = [0] * 16
result = 0

total_per_energy_128 = [0] * 4

total_adc_energy = 0.0
total_col_energy = 0.0
total_row_energy = 0.0
total_cim_unit_energy = 0.0
# Calculate overall energy
for r in results:

    per_component_energy = r.per_compute("per_component_energy")
    total_energy_per_layer = sum(per_component_energy.values()) * 1e15  # Convert to fJ
    total_adc_energy += per_component_energy.get('adc', 0.0)
    total_col_energy += per_component_energy.get('column_drivers', 0.0)
    total_row_energy += per_component_energy.get('row_drivers', 0.0)
    total_cim_unit_energy += per_component_energy.get('cim_unit', 0.0)

    total_adc_energy = total_adc_energy * 1e15
    total_col_energy = total_col_energy * 1e15
    total_row_energy = total_row_energy * 1e15
    total_cim_unit_energy = total_cim_unit_energy * 1e15
    total_energy = total_adc_energy + total_col_energy + total_row_energy + total_cim_unit_energy

    total_adc_energy = total_adc_energy/total_energy
    total_col_energy = total_col_energy/total_energy
    total_row_energy = total_row_energy/total_energy
    total_cim_unit_energy = total_cim_unit_energy/total_energy
  
    total_per_energy_128[0] = total_adc_energy
    total_per_energy_128[1] = total_col_energy
    total_per_energy_128[2] = total_row_energy
    total_per_energy_128[3] = total_cim_unit_energy
    
# Display overall energy
print(f"Overall energy for DNN {DNN}: {total_energy} fJ")

# Display an energy breakdown for each layer as a bar chart. Display normalized per-MAC and per-layer energy.
fig, ax = plt.subplots(figsize=(20, 5))

bar_stacked(
    {i: r.per_compute("per_component_energy") * 1e15 for i, r in enumerate(results)},
    title="Using SRAM on 128 x 128 array sizes, 22 nm",
    xlabel="Layer",
    ylabel="Energy (fJ/MAC)",
    ax=ax,
)
# Out:
# ### 128x128 Array Sizes, 22 nm
# Available DNNs: ['vision_transformer', 'dpt_large', 'resnet18', 'mobilebert', 'msft_phi_1_5', 'gpt2_medium', 'vgg16', 'mobilenet_v3', 'alexnet', 'densenet201']
# Running: 00 /home/workspace/scripts/../outputs/vgg16_128_SRAM_de
# Layer directory: /home/workspace/scripts/../outputs/vgg16_128_SRAM_de/vgg16_128_SRAM_de_layer_1
# Computes: 169344.0
# 01 /home/workspace/scripts/../outputs/vgg16_128_SRAM_de
# Layer directory: /home/workspace/scripts/../outputs/vgg16_128_SRAM_de/vgg16_128_SRAM_de_layer_2
# Computes: 3612672.0
# 02 /home/workspace/scripts/../outputs/vgg16_128_SRAM_de
# Layer directory: /home/workspace/scripts/../outputs/vgg16_128_SRAM_de/vgg16_128_SRAM_de_layer_3
# Computes: 1806336.0
# 03 /home/workspace/scripts/../outputs/vgg16_128_SRAM_de
# Layer directory: /home/workspace/scripts/../outputs/vgg16_128_SRAM_de/vgg16_128_SRAM_de_layer_4
# Computes: 3612672.0
# 04 /home/workspace/scripts/../outputs/vgg16_128_SRAM_de
# Layer directory: /home/workspace/scripts/../outputs/vgg16_128_SRAM_de/vgg16_128_SRAM_de_layer_5
# Computes: 1806336.0
# 05 /home/workspace/scripts/../outputs/vgg16_128_SRAM_de
# Layer directory: /home/workspace/scripts/../outputs/vgg16_128_SRAM_de/vgg16_128_SRAM_de_layer_6
# Computes: 3612672.0
# 06 /home/workspace/scripts/../outputs/vgg16_128_SRAM_de
# Layer directory: /home/workspace/scripts/../outputs/vgg16_128_SRAM_de/vgg16_128_SRAM_de_layer_7
# Computes: 3612672.0
# 07 /home/workspace/scripts/../outputs/vgg16_128_SRAM_de
# Layer directory: /home/workspace/scripts/../outputs/vgg16_128_SRAM_de/vgg16_128_SRAM_de_layer_8
# Computes: 1806336.0
# 08 /home/workspace/scripts/../outputs/vgg16_128_SRAM_de
# Layer directory: /home/workspace/scripts/../outputs/vgg16_128_SRAM_de/vgg16_128_SRAM_de_layer_9
# Computes: 3612672.0
# 09 /home/workspace/scripts/../outputs/vgg16_128_SRAM_de
# Layer directory: /home/workspace/scripts/../outputs/vgg16_128_SRAM_de/vgg16_128_SRAM_de_layer_10
# Computes: 3612672.0
# 10 /home/workspace/scripts/../outputs/vgg16_128_SRAM_de
# Layer directory: /home/workspace/scripts/../outputs/vgg16_128_SRAM_de/vgg16_128_SRAM_de_layer_11
# Computes: 903168.0
# 11 /home/workspace/scripts/../outputs/vgg16_128_SRAM_de
# Layer directory: /home/workspace/scripts/../outputs/vgg16_128_SRAM_de/vgg16_128_SRAM_de_layer_12
# Computes: 903168.0
# 12 /home/workspace/scripts/../outputs/vgg16_128_SRAM_de
# Layer directory: /home/workspace/scripts/../outputs/vgg16_128_SRAM_de/vgg16_128_SRAM_de_layer_13
# Computes: 903168.0
# 13 /home/workspace/scripts/../outputs/vgg16_128_SRAM_de
# Layer directory: /home/workspace/scripts/../outputs/vgg16_128_SRAM_de/vgg16_128_SRAM_de_layer_14
# Computes: 200704.0
# 14 /home/workspace/scripts/../outputs/vgg16_128_SRAM_de
# Layer directory: /home/workspace/scripts/../outputs/vgg16_128_SRAM_de/vgg16_128_SRAM_de_layer_15
# Computes: 32768.0
# 15 /home/workspace/scripts/../outputs/vgg16_128_SRAM_de
# Layer directory: /home/workspace/scripts/../outputs/vgg16_128_SRAM_de/vgg16_128_SRAM_de_layer_16
# Computes: 8000.0
#
# Overall energy for DNN vgg16: 1000000000000017.9 fJ

# %% [markdown]
# # 256x256 Array Size, 22 nm

# %%
from _import_scripts import scripts
from scripts.notebook_utils import *
from scripts.tl_output_parsing import MacroOutputStats

MACRO_PATH = "../models/arch/1_macro/basic_analog/" 

display_markdown(
    """
### 256x256 Array Sizes, 22 nm

"""
)
array_sizes = 256
SRAM_PATH = f'"{os.path.abspath("../models/memory_cells/sram_example.cell.yaml")}"'
path = SRAM_PATH
macro = {}

def run_layer(dnn: str, layer: str, array_sizes: int, variables):
    print(f"{layer} ", end="", flush=True)
    spec = get_spec(
        "basic_analog",
        # Weight-stationary, dummy buffer on top to hold inputs & outputs, many
        # macros to ensure we can fit all weights.
        system="ws_dummy_buffer_many_macro",
        # Set the DNN and layer
        dnn=dnn,
        layer=layer,
    )

    # Do NOT generate a maximum-utilization workload; we're running a DNN
    # workload.
    spec.variables["MAX_UTILIZATION"] = False

    # Use a larger array to ensure we can fit all weights
    spec.architecture.find("column").spatial.meshX = array_sizes
    spec.architecture.find("row").spatial.meshY = array_sizes

    spec.variables.update(variables)
    output_stats = run_mapper(spec)
    
    # Print computes for the layer
    macro_output_stats = MacroOutputStats.from_output_stats(output_stats)
    print(f"Computes: {macro_output_stats.computes}")
    global macro
    macro[layer] = macro_output_stats.computes
    return output_stats


DNN_OPTIONS = [
    d
    for d in os.listdir(f"../models/workloads/")
    if os.path.isdir(f"../models/workloads/{d}")
]
DNN_OPTIONS = [d for d in DNN_OPTIONS if not d.startswith("_")]
print(f"Available DNNs: {DNN_OPTIONS}")

# =============================================================================
# Change this DNN to explore different DNNs!
# =============================================================================
DNN = "vgg16"
# =============================================================================
# Change this DNN to explore different DNNs!
# =============================================================================

layers = [f for f in os.listdir(f"../models/workloads/{DNN}") if f != "index.yaml" and f.endswith(".yaml")]
layers = sorted(layers)
print(f"Running: ", end="")

# Parallel/Delayed is used to multiprocess. Equivalent to running the following
# code in serial:
# results = [run_layer(DNN, layer.split(".")[0]) for layer in layers]
results = joblib.Parallel(n_jobs=None)(
    joblib.delayed(run_layer)(DNN, layer.split(".")[0], array_sizes, 
                              {
                                  "CELL_CONFIG": path,
                                  "BITS_PER_CELL": 1 if path == SRAM_PATH else 4,
                                  "CIM_UNIT_WIDTH_CELLS": 4 if path == SRAM_PATH else 1,
                                  "IS_SRAM": path == SRAM_PATH,
                                  "TECHNOLOGY": 22,
                                  "ADC_RESOLUTION": 5
                              }
                             ) for layer in layers
)
print("")
for r in results:
    r.clear_zero_energies()

# Initialize overall_energy
energy_layer = [0] * 16
result = 0

total_per_energy_256 = [0] * 4

total_adc_energy = 0.0
total_col_energy = 0.0
total_row_energy = 0.0
total_cim_unit_energy = 0.0
# Calculate overall energy
for r in results:

    per_component_energy = r.per_compute("per_component_energy")
    total_energy_per_layer = sum(per_component_energy.values()) * 1e15  # Convert to fJ
    total_adc_energy += per_component_energy.get('adc', 0.0)
    total_col_energy += per_component_energy.get('column_drivers', 0.0)
    total_row_energy += per_component_energy.get('row_drivers', 0.0)
    total_cim_unit_energy += per_component_energy.get('cim_unit', 0.0)

    total_adc_energy = total_adc_energy * 1e15
    total_col_energy = total_col_energy * 1e15
    total_row_energy = total_row_energy * 1e15
    total_cim_unit_energy = total_cim_unit_energy * 1e15
    total_energy = total_adc_energy + total_col_energy + total_row_energy + total_cim_unit_energy

    total_adc_energy = total_adc_energy/total_energy
    total_col_energy = total_col_energy/total_energy
    total_row_energy = total_row_energy/total_energy
    total_cim_unit_energy = total_cim_unit_energy/total_energy
  
    total_per_energy_256[0] = total_adc_energy
    total_per_energy_256[1] = total_col_energy
    total_per_energy_256[2] = total_row_energy
    total_per_energy_256[3] = total_cim_unit_energy
    
# Display overall energy
print(f"Overall energy for DNN {DNN}: {total_energy} fJ")

# Display an energy breakdown for each layer as a bar chart. Display normalized per-MAC and per-layer energy.
fig, ax = plt.subplots(figsize=(20, 5))

bar_stacked(
    {i: r.per_compute("per_component_energy") * 1e15 for i, r in enumerate(results)},
    title="Using SRAM on 256 x 256 array sizes, 22 nm",
    xlabel="Layer",
    ylabel="Energy (fJ/MAC)",
    ax=ax,
)
# Out:
# ### 256x256 Array Sizes, 22 nm
# Available DNNs: ['vision_transformer', 'dpt_large', 'resnet18', 'mobilebert', 'msft_phi_1_5', 'gpt2_medium', 'vgg16', 'mobilenet_v3', 'alexnet', 'densenet201']
# Running: 00 /home/workspace/scripts/../outputs/vgg16_256_SRAM_de
# Layer directory: /home/workspace/scripts/../outputs/vgg16_256_SRAM_de/vgg16_256_SRAM_de_layer_1
# Computes: 169344.0
# 01 /home/workspace/scripts/../outputs/vgg16_256_SRAM_de
# Layer directory: /home/workspace/scripts/../outputs/vgg16_256_SRAM_de/vgg16_256_SRAM_de_layer_2
# Computes: 3612672.0
# 02 /home/workspace/scripts/../outputs/vgg16_256_SRAM_de
# Layer directory: /home/workspace/scripts/../outputs/vgg16_256_SRAM_de/vgg16_256_SRAM_de_layer_3
# Computes: 1806336.0
# 03 /home/workspace/scripts/../outputs/vgg16_256_SRAM_de
# Layer directory: /home/workspace/scripts/../outputs/vgg16_256_SRAM_de/vgg16_256_SRAM_de_layer_4
# Computes: 3612672.0
# 04 /home/workspace/scripts/../outputs/vgg16_256_SRAM_de
# Layer directory: /home/workspace/scripts/../outputs/vgg16_256_SRAM_de/vgg16_256_SRAM_de_layer_5
# Computes: 1806336.0
# 05 /home/workspace/scripts/../outputs/vgg16_256_SRAM_de
# Layer directory: /home/workspace/scripts/../outputs/vgg16_256_SRAM_de/vgg16_256_SRAM_de_layer_6
# Computes: 3612672.0
# 06 /home/workspace/scripts/../outputs/vgg16_256_SRAM_de
# Layer directory: /home/workspace/scripts/../outputs/vgg16_256_SRAM_de/vgg16_256_SRAM_de_layer_7
# Computes: 3612672.0
# 07 /home/workspace/scripts/../outputs/vgg16_256_SRAM_de
# Layer directory: /home/workspace/scripts/../outputs/vgg16_256_SRAM_de/vgg16_256_SRAM_de_layer_8
# Computes: 1806336.0
# 08 /home/workspace/scripts/../outputs/vgg16_256_SRAM_de
# Layer directory: /home/workspace/scripts/../outputs/vgg16_256_SRAM_de/vgg16_256_SRAM_de_layer_9
# Computes: 3612672.0
# 09 /home/workspace/scripts/../outputs/vgg16_256_SRAM_de
# Layer directory: /home/workspace/scripts/../outputs/vgg16_256_SRAM_de/vgg16_256_SRAM_de_layer_10
# Computes: 3612672.0
# 10 /home/workspace/scripts/../outputs/vgg16_256_SRAM_de
# Layer directory: /home/workspace/scripts/../outputs/vgg16_256_SRAM_de/vgg16_256_SRAM_de_layer_11
# Computes: 903168.0
# 11 /home/workspace/scripts/../outputs/vgg16_256_SRAM_de
# Layer directory: /home/workspace/scripts/../outputs/vgg16_256_SRAM_de/vgg16_256_SRAM_de_layer_12
# Computes: 903168.0
# 12 /home/workspace/scripts/../outputs/vgg16_256_SRAM_de
# Layer directory: /home/workspace/scripts/../outputs/vgg16_256_SRAM_de/vgg16_256_SRAM_de_layer_13
# Computes: 903168.0
# 13 /home/workspace/scripts/../outputs/vgg16_256_SRAM_de
# Layer directory: /home/workspace/scripts/../outputs/vgg16_256_SRAM_de/vgg16_256_SRAM_de_layer_14
# Computes: 200704.0
# 14 /home/workspace/scripts/../outputs/vgg16_256_SRAM_de
# Layer directory: /home/workspace/scripts/../outputs/vgg16_256_SRAM_de/vgg16_256_SRAM_de_layer_15
# Computes: 32768.0
# 15 /home/workspace/scripts/../outputs/vgg16_256_SRAM_de
# Layer directory: /home/workspace/scripts/../outputs/vgg16_256_SRAM_de/vgg16_256_SRAM_de_layer_16
# Computes: 8000.0
#
# Overall energy for DNN vgg16: 1000000000000012.2 fJ

# %%
print(total_per_energy_32)
# Out:
# [0.3960061304112863, 0.0007033541719245287, 0.6028750045068203, 0.00041551090996894173]

# %%
print(total_per_energy_64)
# Out:
# [0.63805695467786, 0.0022474841985667894, 0.3590260774830676, 0.0006694836405055874]

# %%
print(total_per_energy_128)
# Out:
# [0.7533058320486852, 0.005295627565595982, 0.24060813143059875, 0.0007904089551201641]

# %%
print(total_per_energy_256)
# Out:
# [0.6516730002148846, 0.009162327853767471, 0.3384809016042562, 0.0006837703270916192]

# %%
from _import_scripts import scripts
from scripts.notebook_utils import *
from scripts.tl_output_parsing import MacroOutputStats
total_area = [0] * 4
total_adc_area = [0] * 4
total_col_area = [0] * 4
total_row_area = [0] * 4
total_cim_unit_area = [0] * 4
total_macro = [0] * 4
energy = [0] * 4
throughput = [0] * 4
total_area[0], total_adc_area[0], total_col_area[0], total_row_area[0], total_cim_unit_area[0], total_macro[0], energy[0], throughput[0] = extract_outputs("vgg16_32_SRAM_de")
total_area[1], total_adc_area[1], total_col_area[1], total_row_area[1], total_cim_unit_area[1], total_macro[1], energy[1], throughput[1] = extract_outputs("vgg16_64_SRAM_de")
total_area[2], total_adc_area[2], total_col_area[2], total_row_area[2], total_cim_unit_area[2], total_macro[2], energy[2], throughput[2] = extract_outputs("vgg16_128_SRAM_de")
total_area[3], total_adc_area[3], total_col_area[3], total_row_area[3], total_cim_unit_area[3], total_macro[3], energy[3], throughput[3] = extract_outputs("vgg16_256_SRAM_de")
# Out:
# ../outputs/vgg16_32_SRAM_de/
# Model 	 Energy/inference (J) 	 Area (mm2) 	 Throughput (inf/s)
# Processing layer: vgg16_32_SRAM_de_layer_1
# Size: 4
# All macro: 4
# adc area: 12441.546372, number of adc: 4096,
# total adc area: (12441.546372*4096/4096) * macro = 49766.185488
#
# Size: 4
# All macro: 4
# column drivers area: 34.183326, number of column_drivers: 4096,
# total column drivers area: (34.183326*4096/4096) * macro = 136.733304
#
# Size: 4
# All macro: 4
# row drivers area: 126.55998, number of row_drivers: 4096,
# total row drivers area: (126.55998*4096/4096) * macro = 506.23992
#
# Size: 4
# All macro: 4
# cim unit area: 0.15488, number of cim_unit: 4194304,
# total cim unit area: (0.15488*4194304/4096) * macro = 634.38848
#
# Total Area for layer 1: 51043.547192000005
#
# Total Macro for layer 1: 4
#
# Total Area for all layers: 51043.547192000005
# Total Area for ADC across all layers: 49766.185488
# Processing layer: vgg16_32_SRAM_de_layer_2
# Size: 3
# Size: 3
# Size: 4
# All macro: 36
# adc area: 12441.546372, number of adc: 4096,
# total adc area: (12441.546372*4096/4096) * macro = 447895.669392
#
# Size: 3
# Size: 3
# Size: 4
# All macro: 36
# column drivers area: 34.183326, number of column_drivers: 4096,
# total column drivers area: (34.183326*4096/4096) * macro = 1230.5997360000001
#
# Size: 3
# Size: 3
# Size: 4
# All macro: 36
# row drivers area: 126.55998, number of row_drivers: 4096,
# total row drivers area: (126.55998*4096/4096) * macro = 4556.15928
#
# Size: 3
# Size: 3
# Size: 4
# All macro: 36
# cim unit area: 0.15488, number of cim_unit: 4194304,
# total cim unit area: (0.15488*4194304/4096) * macro = 5709.496319999999
#
# Total Area for layer 2: 459391.924728
#
# Total Macro for layer 2: 40
#
# Total Area for all layers: 510435.47192000004
# Total Area for ADC across all layers: 497661.85488
# Processing layer: vgg16_32_SRAM_de_layer_3
# Size: 3
# Size: 3
# Size: 8
# All macro: 72
# adc area: 12441.546372, number of adc: 4096,
# total adc area: (12441.546372*4096/4096) * macro = 895791.338784
#
# Size: 3
# Size: 3
# Size: 8
# All macro: 72
# column drivers area: 34.183326, number of column_drivers: 4096,
# total column drivers area: (34.183326*4096/4096) * macro = 2461.1994720000002
#
# Size: 3
# Size: 3
# Size: 8
# All macro: 72
# row drivers area: 126.55998, number of row_drivers: 4096,
# total row drivers area: (126.55998*4096/4096) * macro = 9112.31856
#
# Size: 3
# Size: 3
# Size: 8
# All macro: 72
# cim unit area: 0.15488, number of cim_unit: 4194304,
# total cim unit area: (0.15488*4194304/4096) * macro = 11418.992639999999
#
# Total Area for layer 3: 918783.849456
#
# Total Macro for layer 3: 112
#
# Total Area for all layers: 1429219.321376
# Total Area for ADC across all layers: 1393453.193664
# Processing layer: vgg16_32_SRAM_de_layer_4
# Size: 3
# Size: 3
# Size: 4
# Size: 4
# All macro: 144
# adc area: 12441.546372, number of adc: 4096,
# total adc area: (12441.546372*4096/4096) * macro = 1791582.677568
#
# Size: 3
# Size: 3
# Size: 4
# Size: 4
# All macro: 144
# column drivers area: 34.183326, number of column_drivers: 4096,
# total column drivers area: (34.183326*4096/4096) * macro = 4922.3989440000005
#
# Size: 3
# Size: 3
# Size: 4
# Size: 4
# All macro: 144
# row drivers area: 126.55998, number of row_drivers: 4096,
# total row drivers area: (126.55998*4096/4096) * macro = 18224.63712
#
# Size: 3
# Size: 3
# Size: 4
# Size: 4
# All macro: 144
# cim unit area: 0.15488, number of cim_unit: 4194304,
# total cim unit area: (0.15488*4194304/4096) * macro = 22837.985279999997
#
# Total Area for layer 4: 1837567.698912
#
# Total Macro for layer 4: 256
#
# Total Area for all layers: 3266787.020288
# Total Area for ADC across all layers: 3185035.871232
# Processing layer: vgg16_32_SRAM_de_layer_5
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# adc area: 12441.546372, number of adc: 4096,
# total adc area: (12441.546372*4096/4096) * macro = 3583165.355136
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# column drivers area: 34.183326, number of column_drivers: 4096,
# total column drivers area: (34.183326*4096/4096) * macro = 9844.797888000001
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# row drivers area: 126.55998, number of row_drivers: 4096,
# total row drivers area: (126.55998*4096/4096) * macro = 36449.27424
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# cim unit area: 0.15488, number of cim_unit: 4194304,
# total cim unit area: (0.15488*4194304/4096) * macro = 45675.970559999994
#
# Total Area for layer 5: 3675135.397824
#
# Total Macro for layer 5: 544
#
# Total Area for all layers: 6941922.418112
# Total Area for ADC across all layers: 6768201.226368001
# Processing layer: vgg16_32_SRAM_de_layer_6
# Size: 3
# Size: 3
# Size: 8
# Size: 8
# All macro: 576
# adc area: 12441.546372, number of adc: 4096,
# total adc area: (12441.546372*4096/4096) * macro = 7166330.710272
#
# Size: 3
# Size: 3
# Size: 8
# Size: 8
# All macro: 576
# column drivers area: 34.183326, number of column_drivers: 4096,
# total column drivers area: (34.183326*4096/4096) * macro = 19689.595776000002
#
# Size: 3
# Size: 3
# Size: 8
# Size: 8
# All macro: 576
# row drivers area: 126.55998, number of row_drivers: 4096,
# total row drivers area: (126.55998*4096/4096) * macro = 72898.54848
#
# Size: 3
# Size: 3
# Size: 8
# Size: 8
# All macro: 576
# cim unit area: 0.15488, number of cim_unit: 4194304,
# total cim unit area: (0.15488*4194304/4096) * macro = 91351.94111999999
#
# Total Area for layer 6: 7350270.795648
#
# Total Macro for layer 6: 1120
#
# Total Area for all layers: 14292193.21376
# Total Area for ADC across all layers: 13934531.936640002
# Processing layer: vgg16_32_SRAM_de_layer_7
# Size: 3
# Size: 3
# Size: 8
# Size: 8
# All macro: 576
# adc area: 12441.546372, number of adc: 4096,
# total adc area: (12441.546372*4096/4096) * macro = 7166330.710272
#
# Size: 3
# Size: 3
# Size: 8
# Size: 8
# All macro: 576
# column drivers area: 34.183326, number of column_drivers: 4096,
# total column drivers area: (34.183326*4096/4096) * macro = 19689.595776000002
#
# Size: 3
# Size: 3
# Size: 8
# Size: 8
# All macro: 576
# row drivers area: 126.55998, number of row_drivers: 4096,
# total row drivers area: (126.55998*4096/4096) * macro = 72898.54848
#
# Size: 3
# Size: 3
# Size: 8
# Size: 8
# All macro: 576
# cim unit area: 0.15488, number of cim_unit: 4194304,
# total cim unit area: (0.15488*4194304/4096) * macro = 91351.94111999999
#
# Total Area for layer 7: 7350270.795648
#
# Total Macro for layer 7: 1696
#
# Total Area for all layers: 21642464.009408
# Total Area for ADC across all layers: 21100862.646912
# Processing layer: vgg16_32_SRAM_de_layer_8
# Size: 3
# Size: 3
# Size: 32
# Size: 8
# All macro: 2304
# adc area: 12441.546372, number of adc: 4096,
# total adc area: (12441.546372*4096/4096) * macro = 28665322.841088
#
# Size: 3
# Size: 3
# Size: 32
# Size: 8
# All macro: 2304
# column drivers area: 34.183326, number of column_drivers: 4096,
# total column drivers area: (34.183326*4096/4096) * macro = 78758.38310400001
#
# Size: 3
# Size: 3
# Size: 32
# Size: 8
# All macro: 2304
# row drivers area: 126.55998, number of row_drivers: 4096,
# total row drivers area: (126.55998*4096/4096) * macro = 291594.19392
#
# Size: 3
# Size: 3
# Size: 32
# Size: 8
# All macro: 2304
# cim unit area: 0.15488, number of cim_unit: 4194304,
# total cim unit area: (0.15488*4194304/4096) * macro = 365407.76447999995
#
# Total Area for layer 8: 29401083.182592
#
# Total Macro for layer 8: 4000
#
# Total Area for all layers: 51043547.192
# Total Area for ADC across all layers: 49766185.488000005
# Processing layer: vgg16_32_SRAM_de_layer_9
# Size: 3
# Size: 3
# Size: 32
# Size: 8
# All macro: 2304
# adc area: 12441.546372, number of adc: 4096,
# total adc area: (12441.546372*4096/4096) * macro = 28665322.841088
#
# Size: 3
# Size: 3
# Size: 32
# Size: 8
# All macro: 2304
# column drivers area: 34.183326, number of column_drivers: 4096,
# total column drivers area: (34.183326*4096/4096) * macro = 78758.38310400001
#
# Size: 3
# Size: 3
# Size: 32
# Size: 8
# All macro: 2304
# row drivers area: 126.55998, number of row_drivers: 4096,
# total row drivers area: (126.55998*4096/4096) * macro = 291594.19392
#
# Size: 3
# Size: 3
# Size: 32
# Size: 8
# All macro: 2304
# cim unit area: 0.15488, number of cim_unit: 4194304,
# total cim unit area: (0.15488*4194304/4096) * macro = 365407.76447999995
#
# Total Area for layer 9: 29401083.182592
#
# Total Macro for layer 9: 6304
#
# Total Area for all layers: 80444630.374592
# Total Area for ADC across all layers: 78431508.329088
# Processing layer: vgg16_32_SRAM_de_layer_10
# Size: 3
# Size: 3
# Size: 32
# Size: 8
# All macro: 2304
# adc area: 12441.546372, number of adc: 4096,
# total adc area: (12441.546372*4096/4096) * macro = 28665322.841088
#
# Size: 3
# Size: 3
# Size: 32
# Size: 8
# All macro: 2304
# column drivers area: 34.183326, number of column_drivers: 4096,
# total column drivers area: (34.183326*4096/4096) * macro = 78758.38310400001
#
# Size: 3
# Size: 3
# Size: 32
# Size: 8
# All macro: 2304
# row drivers area: 126.55998, number of row_drivers: 4096,
# total row drivers area: (126.55998*4096/4096) * macro = 291594.19392
#
# Size: 3
# Size: 3
# Size: 32
# Size: 8
# All macro: 2304
# cim unit area: 0.15488, number of cim_unit: 4194304,
# total cim unit area: (0.15488*4194304/4096) * macro = 365407.76447999995
#
# Total Area for layer 10: 29401083.182592
#
# Total Macro for layer 10: 8608
#
# Total Area for all layers: 109845713.55718401
# Total Area for ADC across all layers: 107096831.170176
# Processing layer: vgg16_32_SRAM_de_layer_11
# Size: 3
# Size: 3
# Size: 32
# Size: 8
# All macro: 2304
# adc area: 12441.546372, number of adc: 4096,
# total adc area: (12441.546372*4096/4096) * macro = 28665322.841088
#
# Size: 3
# Size: 3
# Size: 32
# Size: 8
# All macro: 2304
# column drivers area: 34.183326, number of column_drivers: 4096,
# total column drivers area: (34.183326*4096/4096) * macro = 78758.38310400001
#
# Size: 3
# Size: 3
# Size: 32
# Size: 8
# All macro: 2304
# row drivers area: 126.55998, number of row_drivers: 4096,
# total row drivers area: (126.55998*4096/4096) * macro = 291594.19392
#
# Size: 3
# Size: 3
# Size: 32
# Size: 8
# All macro: 2304
# cim unit area: 0.15488, number of cim_unit: 4194304,
# total cim unit area: (0.15488*4194304/4096) * macro = 365407.76447999995
#
# Total Area for layer 11: 29401083.182592
#
# Total Macro for layer 11: 10912
#
# Total Area for all layers: 139246796.73977602
# Total Area for ADC across all layers: 135762154.011264
# Processing layer: vgg16_32_SRAM_de_layer_12
# Size: 3
# Size: 3
# Size: 32
# Size: 8
# All macro: 2304
# adc area: 12441.546372, number of adc: 4096,
# total adc area: (12441.546372*4096/4096) * macro = 28665322.841088
#
# Size: 3
# Size: 3
# Size: 32
# Size: 8
# All macro: 2304
# column drivers area: 34.183326, number of column_drivers: 4096,
# total column drivers area: (34.183326*4096/4096) * macro = 78758.38310400001
#
# Size: 3
# Size: 3
# Size: 32
# Size: 8
# All macro: 2304
# row drivers area: 126.55998, number of row_drivers: 4096,
# total row drivers area: (126.55998*4096/4096) * macro = 291594.19392
#
# Size: 3
# Size: 3
# Size: 32
# Size: 8
# All macro: 2304
# cim unit area: 0.15488, number of cim_unit: 4194304,
# total cim unit area: (0.15488*4194304/4096) * macro = 365407.76447999995
#
# Total Area for layer 12: 29401083.182592
#
# Total Macro for layer 12: 13216
#
# Total Area for all layers: 168647879.92236802
# Total Area for ADC across all layers: 164427476.852352
# Processing layer: vgg16_32_SRAM_de_layer_13
# Size: 3
# Size: 3
# Size: 32
# Size: 8
# All macro: 2304
# adc area: 12441.546372, number of adc: 4096,
# total adc area: (12441.546372*4096/4096) * macro = 28665322.841088
#
# Size: 3
# Size: 3
# Size: 32
# Size: 8
# All macro: 2304
# column drivers area: 34.183326, number of column_drivers: 4096,
# total column drivers area: (34.183326*4096/4096) * macro = 78758.38310400001
#
# Size: 3
# Size: 3
# Size: 32
# Size: 8
# All macro: 2304
# row drivers area: 126.55998, number of row_drivers: 4096,
# total row drivers area: (126.55998*4096/4096) * macro = 291594.19392
#
# Size: 3
# Size: 3
# Size: 32
# Size: 8
# All macro: 2304
# cim unit area: 0.15488, number of cim_unit: 4194304,
# total cim unit area: (0.15488*4194304/4096) * macro = 365407.76447999995
#
# Total Area for layer 13: 29401083.182592
#
# Total Macro for layer 13: 15520
#
# Total Area for all layers: 198048963.10496002
# Total Area for ADC across all layers: 193092799.69344
# Processing layer: vgg16_32_SRAM_de_layer_14
# Size: 256
# Size: 14
# All macro: 3584
# adc area: 12441.546372, number of adc: 4096,
# total adc area: (12441.546372*4096/4096) * macro = 44590502.197248004
#
# Size: 256
# Size: 14
# All macro: 3584
# column drivers area: 34.183326, number of column_drivers: 4096,
# total column drivers area: (34.183326*4096/4096) * macro = 122513.040384
#
# Size: 256
# Size: 14
# All macro: 3584
# row drivers area: 126.55998, number of row_drivers: 4096,
# total row drivers area: (126.55998*4096/4096) * macro = 453590.96832
#
# Size: 256
# Size: 14
# All macro: 3584
# cim unit area: 0.15488, number of cim_unit: 4194304,
# total cim unit area: (0.15488*4194304/4096) * macro = 568412.07808
#
# Total Area for layer 14: 45735018.284032
#
# Total Macro for layer 14: 19104
#
# Total Area for all layers: 243783981.388992
# Total Area for ADC across all layers: 237683301.890688
# Processing layer: vgg16_32_SRAM_de_layer_15
# Size: 64
# Size: 64
# All macro: 4096
# adc area: 12441.546372, number of adc: 4096,
# total adc area: (12441.546372*4096/4096) * macro = 50960573.939712
#
# Size: 64
# Size: 64
# All macro: 4096
# column drivers area: 34.183326, number of column_drivers: 4096,
# total column drivers area: (34.183326*4096/4096) * macro = 140014.903296
#
# Size: 64
# Size: 64
# All macro: 4096
# row drivers area: 126.55998, number of row_drivers: 4096,
# total row drivers area: (126.55998*4096/4096) * macro = 518389.67808
#
# Size: 64
# Size: 64
# All macro: 4096
# cim unit area: 0.15488, number of cim_unit: 4194304,
# total cim unit area: (0.15488*4194304/4096) * macro = 649613.80352
#
# Total Area for layer 15: 52268592.324608006
#
# Total Macro for layer 15: 23200
#
# Total Area for all layers: 296052573.71360004
# Total Area for ADC across all layers: 288643875.8304
# Processing layer: vgg16_32_SRAM_de_layer_16
# Size: 21
# Size: 128
# All macro: 2688
# adc area: 12441.546372, number of adc: 4096,
# total adc area: (12441.546372*4096/4096) * macro = 33442876.647936
#
# Size: 21
# Size: 128
# All macro: 2688
# column drivers area: 34.183326, number of column_drivers: 4096,
# total column drivers area: (34.183326*4096/4096) * macro = 91884.78028800001
#
# Size: 21
# Size: 128
# All macro: 2688
# row drivers area: 126.55998, number of row_drivers: 4096,
# total row drivers area: (126.55998*4096/4096) * macro = 340193.22624
#
# Size: 21
# Size: 128
# All macro: 2688
# cim unit area: 0.15488, number of cim_unit: 4194304,
# total cim unit area: (0.15488*4194304/4096) * macro = 426309.05856
#
# Total Area for layer 16: 34301263.713024
#
# Total Macro for layer 16: 25888
#
# Total Area for all layers: 330353837.42662406
# Total Area for ADC across all layers: 322086752.478336
# Total Area for column drivers across all layers: 884937.9434880001
# Total Area for row drivers across all layers: 3276384.76224
# Total Area for cim unit across all layers: 4105762.242559999
#
#
# Total Area for ADC across all layers: 322.08675247833594
# Total Area for column driver across all layers: 0.884937943488
# Total Area for row driver across all layers: 3.2763847622399997
# Total Area for cim unit across all layers: 4.105762242559999
# Total Macro across all layers: 25888
# vgg16_32_SRAM_de 	 1.23e-03 	 330.35 	 4.45e+01
# ../outputs/vgg16_64_SRAM_de/
# Model 	 Energy/inference (J) 	 Area (mm2) 	 Throughput (inf/s)
# Processing layer: vgg16_64_SRAM_de_layer_1
# Size: 2
# All macro: 2
# adc area: 14101.81828, number of adc: 4096,
# total adc area: (14101.81828*4096/4096) * macro = 28203.63656
#
# Size: 2
# All macro: 2
# column drivers area: 121.395866, number of column_drivers: 4096,
# total column drivers area: (121.395866*4096/4096) * macro = 242.791732
#
# Size: 2
# All macro: 2
# row drivers area: 227.85231, number of row_drivers: 4096,
# total row drivers area: (227.85231*4096/4096) * macro = 455.70462
#
# Size: 2
# All macro: 2
# cim unit area: 0.15488, number of cim_unit: 16777216,
# total cim unit area: (0.15488*16777216/4096) * macro = 1268.77696
#
# Total Area for layer 1: 30170.909872
#
# Total Macro for layer 1: 2
#
# Total Area for all layers: 30170.909872
# Total Area for ADC across all layers: 28203.63656
# Processing layer: vgg16_64_SRAM_de_layer_2
# Size: 3
# Size: 3
# Size: 2
# All macro: 18
# adc area: 14101.81828, number of adc: 4096,
# total adc area: (14101.81828*4096/4096) * macro = 253832.72904
#
# Size: 3
# Size: 3
# Size: 2
# All macro: 18
# column drivers area: 121.395866, number of column_drivers: 4096,
# total column drivers area: (121.395866*4096/4096) * macro = 2185.125588
#
# Size: 3
# Size: 3
# Size: 2
# All macro: 18
# row drivers area: 227.85231, number of row_drivers: 4096,
# total row drivers area: (227.85231*4096/4096) * macro = 4101.34158
#
# Size: 3
# Size: 3
# Size: 2
# All macro: 18
# cim unit area: 0.15488, number of cim_unit: 16777216,
# total cim unit area: (0.15488*16777216/4096) * macro = 11418.992639999999
#
# Total Area for layer 2: 271538.188848
#
# Total Macro for layer 2: 20
#
# Total Area for all layers: 301709.09872
# Total Area for ADC across all layers: 282036.3656
# Processing layer: vgg16_64_SRAM_de_layer_3
# Size: 3
# Size: 3
# Size: 4
# All macro: 36
# adc area: 14101.81828, number of adc: 4096,
# total adc area: (14101.81828*4096/4096) * macro = 507665.45808
#
# Size: 3
# Size: 3
# Size: 4
# All macro: 36
# column drivers area: 121.395866, number of column_drivers: 4096,
# total column drivers area: (121.395866*4096/4096) * macro = 4370.251176
#
# Size: 3
# Size: 3
# Size: 4
# All macro: 36
# row drivers area: 227.85231, number of row_drivers: 4096,
# total row drivers area: (227.85231*4096/4096) * macro = 8202.68316
#
# Size: 3
# Size: 3
# Size: 4
# All macro: 36
# cim unit area: 0.15488, number of cim_unit: 16777216,
# total cim unit area: (0.15488*16777216/4096) * macro = 22837.985279999997
#
# Total Area for layer 3: 543076.377696
#
# Total Macro for layer 3: 56
#
# Total Area for all layers: 844785.476416
# Total Area for ADC across all layers: 789701.82368
# Processing layer: vgg16_64_SRAM_de_layer_4
# Size: 3
# Size: 3
# Size: 4
# All macro: 36
# adc area: 14101.81828, number of adc: 4096,
# total adc area: (14101.81828*4096/4096) * macro = 507665.45808
#
# Size: 3
# Size: 3
# Size: 4
# All macro: 36
# column drivers area: 121.395866, number of column_drivers: 4096,
# total column drivers area: (121.395866*4096/4096) * macro = 4370.251176
#
# Size: 3
# Size: 3
# Size: 4
# All macro: 36
# row drivers area: 227.85231, number of row_drivers: 4096,
# total row drivers area: (227.85231*4096/4096) * macro = 8202.68316
#
# Size: 3
# Size: 3
# Size: 4
# All macro: 36
# cim unit area: 0.15488, number of cim_unit: 16777216,
# total cim unit area: (0.15488*16777216/4096) * macro = 22837.985279999997
#
# Total Area for layer 4: 543076.377696
#
# Total Macro for layer 4: 92
#
# Total Area for all layers: 1387861.8541120002
# Total Area for ADC across all layers: 1297367.2817600002
# Processing layer: vgg16_64_SRAM_de_layer_5
# Size: 3
# Size: 3
# Size: 8
# All macro: 72
# adc area: 14101.81828, number of adc: 4096,
# total adc area: (14101.81828*4096/4096) * macro = 1015330.91616
#
# Size: 3
# Size: 3
# Size: 8
# All macro: 72
# column drivers area: 121.395866, number of column_drivers: 4096,
# total column drivers area: (121.395866*4096/4096) * macro = 8740.502352
#
# Size: 3
# Size: 3
# Size: 8
# All macro: 72
# row drivers area: 227.85231, number of row_drivers: 4096,
# total row drivers area: (227.85231*4096/4096) * macro = 16405.36632
#
# Size: 3
# Size: 3
# Size: 8
# All macro: 72
# cim unit area: 0.15488, number of cim_unit: 16777216,
# total cim unit area: (0.15488*16777216/4096) * macro = 45675.970559999994
#
# Total Area for layer 5: 1086152.755392
#
# Total Macro for layer 5: 164
#
# Total Area for all layers: 2474014.6095040003
# Total Area for ADC across all layers: 2312698.19792
# Processing layer: vgg16_64_SRAM_de_layer_6
# Size: 3
# Size: 3
# Size: 4
# Size: 4
# All macro: 144
# adc area: 14101.81828, number of adc: 4096,
# total adc area: (14101.81828*4096/4096) * macro = 2030661.83232
#
# Size: 3
# Size: 3
# Size: 4
# Size: 4
# All macro: 144
# column drivers area: 121.395866, number of column_drivers: 4096,
# total column drivers area: (121.395866*4096/4096) * macro = 17481.004704
#
# Size: 3
# Size: 3
# Size: 4
# Size: 4
# All macro: 144
# row drivers area: 227.85231, number of row_drivers: 4096,
# total row drivers area: (227.85231*4096/4096) * macro = 32810.73264
#
# Size: 3
# Size: 3
# Size: 4
# Size: 4
# All macro: 144
# cim unit area: 0.15488, number of cim_unit: 16777216,
# total cim unit area: (0.15488*16777216/4096) * macro = 91351.94111999999
#
# Total Area for layer 6: 2172305.510784
#
# Total Macro for layer 6: 308
#
# Total Area for all layers: 4646320.120288
# Total Area for ADC across all layers: 4343360.03024
# Processing layer: vgg16_64_SRAM_de_layer_7
# Size: 3
# Size: 3
# Size: 4
# Size: 4
# All macro: 144
# adc area: 14101.81828, number of adc: 4096,
# total adc area: (14101.81828*4096/4096) * macro = 2030661.83232
#
# Size: 3
# Size: 3
# Size: 4
# Size: 4
# All macro: 144
# column drivers area: 121.395866, number of column_drivers: 4096,
# total column drivers area: (121.395866*4096/4096) * macro = 17481.004704
#
# Size: 3
# Size: 3
# Size: 4
# Size: 4
# All macro: 144
# row drivers area: 227.85231, number of row_drivers: 4096,
# total row drivers area: (227.85231*4096/4096) * macro = 32810.73264
#
# Size: 3
# Size: 3
# Size: 4
# Size: 4
# All macro: 144
# cim unit area: 0.15488, number of cim_unit: 16777216,
# total cim unit area: (0.15488*16777216/4096) * macro = 91351.94111999999
#
# Total Area for layer 7: 2172305.510784
#
# Total Macro for layer 7: 452
#
# Total Area for all layers: 6818625.631072001
# Total Area for ADC across all layers: 6374021.86256
# Processing layer: vgg16_64_SRAM_de_layer_8
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# adc area: 14101.81828, number of adc: 4096,
# total adc area: (14101.81828*4096/4096) * macro = 4061323.66464
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# column drivers area: 121.395866, number of column_drivers: 4096,
# total column drivers area: (121.395866*4096/4096) * macro = 34962.009408
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# row drivers area: 227.85231, number of row_drivers: 4096,
# total row drivers area: (227.85231*4096/4096) * macro = 65621.46528
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# cim unit area: 0.15488, number of cim_unit: 16777216,
# total cim unit area: (0.15488*16777216/4096) * macro = 182703.88223999998
#
# Total Area for layer 8: 4344611.021568
#
# Total Macro for layer 8: 740
#
# Total Area for all layers: 11163236.65264
# Total Area for ADC across all layers: 10435345.5272
# Processing layer: vgg16_64_SRAM_de_layer_9
# Size: 3
# Size: 3
# Size: 8
# Size: 8
# All macro: 576
# adc area: 14101.81828, number of adc: 4096,
# total adc area: (14101.81828*4096/4096) * macro = 8122647.32928
#
# Size: 3
# Size: 3
# Size: 8
# Size: 8
# All macro: 576
# column drivers area: 121.395866, number of column_drivers: 4096,
# total column drivers area: (121.395866*4096/4096) * macro = 69924.018816
#
# Size: 3
# Size: 3
# Size: 8
# Size: 8
# All macro: 576
# row drivers area: 227.85231, number of row_drivers: 4096,
# total row drivers area: (227.85231*4096/4096) * macro = 131242.93056
#
# Size: 3
# Size: 3
# Size: 8
# Size: 8
# All macro: 576
# cim unit area: 0.15488, number of cim_unit: 16777216,
# total cim unit area: (0.15488*16777216/4096) * macro = 365407.76447999995
#
# Total Area for layer 9: 8689222.043136
#
# Total Macro for layer 9: 1316
#
# Total Area for all layers: 19852458.695776
# Total Area for ADC across all layers: 18557992.856480002
# Processing layer: vgg16_64_SRAM_de_layer_10
# Size: 3
# Size: 3
# Size: 8
# Size: 8
# All macro: 576
# adc area: 14101.81828, number of adc: 4096,
# total adc area: (14101.81828*4096/4096) * macro = 8122647.32928
#
# Size: 3
# Size: 3
# Size: 8
# Size: 8
# All macro: 576
# column drivers area: 121.395866, number of column_drivers: 4096,
# total column drivers area: (121.395866*4096/4096) * macro = 69924.018816
#
# Size: 3
# Size: 3
# Size: 8
# Size: 8
# All macro: 576
# row drivers area: 227.85231, number of row_drivers: 4096,
# total row drivers area: (227.85231*4096/4096) * macro = 131242.93056
#
# Size: 3
# Size: 3
# Size: 8
# Size: 8
# All macro: 576
# cim unit area: 0.15488, number of cim_unit: 16777216,
# total cim unit area: (0.15488*16777216/4096) * macro = 365407.76447999995
#
# Total Area for layer 10: 8689222.043136
#
# Total Macro for layer 10: 1892
#
# Total Area for all layers: 28541680.738912
# Total Area for ADC across all layers: 26680640.185760003
# Processing layer: vgg16_64_SRAM_de_layer_11
# Size: 3
# Size: 3
# Size: 8
# Size: 8
# All macro: 576
# adc area: 14101.81828, number of adc: 4096,
# total adc area: (14101.81828*4096/4096) * macro = 8122647.32928
#
# Size: 3
# Size: 3
# Size: 8
# Size: 8
# All macro: 576
# column drivers area: 121.395866, number of column_drivers: 4096,
# total column drivers area: (121.395866*4096/4096) * macro = 69924.018816
#
# Size: 3
# Size: 3
# Size: 8
# Size: 8
# All macro: 576
# row drivers area: 227.85231, number of row_drivers: 4096,
# total row drivers area: (227.85231*4096/4096) * macro = 131242.93056
#
# Size: 3
# Size: 3
# Size: 8
# Size: 8
# All macro: 576
# cim unit area: 0.15488, number of cim_unit: 16777216,
# total cim unit area: (0.15488*16777216/4096) * macro = 365407.76447999995
#
# Total Area for layer 11: 8689222.043136
#
# Total Macro for layer 11: 2468
#
# Total Area for all layers: 37230902.782048
# Total Area for ADC across all layers: 34803287.51504
# Processing layer: vgg16_64_SRAM_de_layer_12
# Size: 3
# Size: 3
# Size: 8
# Size: 8
# All macro: 576
# adc area: 14101.81828, number of adc: 4096,
# total adc area: (14101.81828*4096/4096) * macro = 8122647.32928
#
# Size: 3
# Size: 3
# Size: 8
# Size: 8
# All macro: 576
# column drivers area: 121.395866, number of column_drivers: 4096,
# total column drivers area: (121.395866*4096/4096) * macro = 69924.018816
#
# Size: 3
# Size: 3
# Size: 8
# Size: 8
# All macro: 576
# row drivers area: 227.85231, number of row_drivers: 4096,
# total row drivers area: (227.85231*4096/4096) * macro = 131242.93056
#
# Size: 3
# Size: 3
# Size: 8
# Size: 8
# All macro: 576
# cim unit area: 0.15488, number of cim_unit: 16777216,
# total cim unit area: (0.15488*16777216/4096) * macro = 365407.76447999995
#
# Total Area for layer 12: 8689222.043136
#
# Total Macro for layer 12: 3044
#
# Total Area for all layers: 45920124.825184
# Total Area for ADC across all layers: 42925934.84432
# Processing layer: vgg16_64_SRAM_de_layer_13
# Size: 3
# Size: 3
# Size: 8
# Size: 8
# All macro: 576
# adc area: 14101.81828, number of adc: 4096,
# total adc area: (14101.81828*4096/4096) * macro = 8122647.32928
#
# Size: 3
# Size: 3
# Size: 8
# Size: 8
# All macro: 576
# column drivers area: 121.395866, number of column_drivers: 4096,
# total column drivers area: (121.395866*4096/4096) * macro = 69924.018816
#
# Size: 3
# Size: 3
# Size: 8
# Size: 8
# All macro: 576
# row drivers area: 227.85231, number of row_drivers: 4096,
# total row drivers area: (227.85231*4096/4096) * macro = 131242.93056
#
# Size: 3
# Size: 3
# Size: 8
# Size: 8
# All macro: 576
# cim unit area: 0.15488, number of cim_unit: 16777216,
# total cim unit area: (0.15488*16777216/4096) * macro = 365407.76447999995
#
# Total Area for layer 13: 8689222.043136
#
# Total Macro for layer 13: 3620
#
# Total Area for all layers: 54609346.86832
# Total Area for ADC across all layers: 51048582.1736
# Processing layer: vgg16_64_SRAM_de_layer_14
# Size: 16
# Size: 196
# All macro: 3136
# adc area: 14101.81828, number of adc: 4096,
# total adc area: (14101.81828*4096/4096) * macro = 44223302.12608
#
# Size: 16
# Size: 196
# All macro: 3136
# column drivers area: 121.395866, number of column_drivers: 4096,
# total column drivers area: (121.395866*4096/4096) * macro = 380697.43577599997
#
# Size: 16
# Size: 196
# All macro: 3136
# row drivers area: 227.85231, number of row_drivers: 4096,
# total row drivers area: (227.85231*4096/4096) * macro = 714544.84416
#
# Size: 16
# Size: 196
# All macro: 3136
# cim unit area: 0.15488, number of cim_unit: 16777216,
# total cim unit area: (0.15488*16777216/4096) * macro = 1989442.2732799998
#
# Total Area for layer 14: 47307986.679296
#
# Total Macro for layer 14: 6756
#
# Total Area for all layers: 101917333.547616
# Total Area for ADC across all layers: 95271884.29968
# Processing layer: vgg16_64_SRAM_de_layer_15
# Size: 128
# Size: 32
# All macro: 4096
# adc area: 14101.81828, number of adc: 4096,
# total adc area: (14101.81828*4096/4096) * macro = 57761047.67488
#
# Size: 128
# Size: 32
# All macro: 4096
# column drivers area: 121.395866, number of column_drivers: 4096,
# total column drivers area: (121.395866*4096/4096) * macro = 497237.467136
#
# Size: 128
# Size: 32
# All macro: 4096
# row drivers area: 227.85231, number of row_drivers: 4096,
# total row drivers area: (227.85231*4096/4096) * macro = 933283.06176
#
# Size: 128
# Size: 32
# All macro: 4096
# cim unit area: 0.15488, number of cim_unit: 16777216,
# total cim unit area: (0.15488*16777216/4096) * macro = 2598455.21408
#
# Total Area for layer 15: 61790023.417856
#
# Total Macro for layer 15: 10852
#
# Total Area for all layers: 163707356.965472
# Total Area for ADC across all layers: 153032931.97456
# Processing layer: vgg16_64_SRAM_de_layer_16
# Size: 32
# Size: 64
# All macro: 2048
# adc area: 14101.81828, number of adc: 4096,
# total adc area: (14101.81828*4096/4096) * macro = 28880523.83744
#
# Size: 32
# Size: 64
# All macro: 2048
# column drivers area: 121.395866, number of column_drivers: 4096,
# total column drivers area: (121.395866*4096/4096) * macro = 248618.733568
#
# Size: 32
# Size: 64
# All macro: 2048
# row drivers area: 227.85231, number of row_drivers: 4096,
# total row drivers area: (227.85231*4096/4096) * macro = 466641.53088
#
# Size: 32
# Size: 64
# All macro: 2048
# cim unit area: 0.15488, number of cim_unit: 16777216,
# total cim unit area: (0.15488*16777216/4096) * macro = 1299227.60704
#
# Total Area for layer 16: 30895011.708928
#
# Total Macro for layer 16: 12900
#
# Total Area for all layers: 194602368.6744
# Total Area for ADC across all layers: 181913455.81199998
# Total Area for column drivers across all layers: 1566006.6713999999
# Total Area for row drivers across all layers: 2939294.799
# Total Area for cim unit across all layers: 8183611.392
#
#
# Total Area for ADC across all layers: 181.91345581199997
# Total Area for column driver across all layers: 1.5660066713999998
# Total Area for row driver across all layers: 2.939294799
# Total Area for cim unit across all layers: 8.183611392
# Total Macro across all layers: 12900
# vgg16_64_SRAM_de 	 5.12e-04 	 194.60 	 6.15e+01
# ../outputs/vgg16_128_SRAM_de/
# Model 	 Energy/inference (J) 	 Area (mm2) 	 Throughput (inf/s)
# Processing layer: vgg16_128_SRAM_de_layer_1
# All macro: 1
# adc area: 15983.646474, number of adc: 4096,
# total adc area: (15983.646474*4096/4096) * macro = 15983.646474
#
# All macro: 1
# column drivers area: 463.560166, number of column_drivers: 4096,
# total column drivers area: (463.560166*4096/4096) * macro = 463.560166
#
# All macro: 1
# row drivers area: 438.8595, number of row_drivers: 4096,
# total row drivers area: (438.8595*4096/4096) * macro = 438.8595
#
# All macro: 1
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 2537.55392
#
# Total Area for layer 1: 19423.620059999997
#
# Total Macro for layer 1: 1
#
# Total Area for all layers: 19423.620059999997
# Total Area for ADC across all layers: 15983.646474
# Processing layer: vgg16_128_SRAM_de_layer_2
# Size: 5
# All macro: 5
# adc area: 15983.646474, number of adc: 4096,
# total adc area: (15983.646474*4096/4096) * macro = 79918.23237
#
# Size: 5
# All macro: 5
# column drivers area: 463.560166, number of column_drivers: 4096,
# total column drivers area: (463.560166*4096/4096) * macro = 2317.80083
#
# Size: 5
# All macro: 5
# row drivers area: 438.8595, number of row_drivers: 4096,
# total row drivers area: (438.8595*4096/4096) * macro = 2194.2975
#
# Size: 5
# All macro: 5
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 12687.7696
#
# Total Area for layer 2: 97118.1003
#
# Total Macro for layer 2: 6
#
# Total Area for all layers: 116541.72036
# Total Area for ADC across all layers: 95901.87884399999
# Processing layer: vgg16_128_SRAM_de_layer_3
# Size: 2
# Size: 5
# All macro: 10
# adc area: 15983.646474, number of adc: 4096,
# total adc area: (15983.646474*4096/4096) * macro = 159836.46474
#
# Size: 2
# Size: 5
# All macro: 10
# column drivers area: 463.560166, number of column_drivers: 4096,
# total column drivers area: (463.560166*4096/4096) * macro = 4635.60166
#
# Size: 2
# Size: 5
# All macro: 10
# row drivers area: 438.8595, number of row_drivers: 4096,
# total row drivers area: (438.8595*4096/4096) * macro = 4388.595
#
# Size: 2
# Size: 5
# All macro: 10
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 25375.5392
#
# Total Area for layer 3: 194236.2006
#
# Total Macro for layer 3: 16
#
# Total Area for all layers: 310777.92096
# Total Area for ADC across all layers: 255738.343584
# Processing layer: vgg16_128_SRAM_de_layer_4
# Size: 3
# Size: 3
# Size: 2
# All macro: 18
# adc area: 15983.646474, number of adc: 4096,
# total adc area: (15983.646474*4096/4096) * macro = 287705.636532
#
# Size: 3
# Size: 3
# Size: 2
# All macro: 18
# column drivers area: 463.560166, number of column_drivers: 4096,
# total column drivers area: (463.560166*4096/4096) * macro = 8344.082988
#
# Size: 3
# Size: 3
# Size: 2
# All macro: 18
# row drivers area: 438.8595, number of row_drivers: 4096,
# total row drivers area: (438.8595*4096/4096) * macro = 7899.4710000000005
#
# Size: 3
# Size: 3
# Size: 2
# All macro: 18
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 45675.970559999994
#
# Total Area for layer 4: 349625.16108
#
# Total Macro for layer 4: 34
#
# Total Area for all layers: 660403.08204
# Total Area for ADC across all layers: 543443.9801159999
# Processing layer: vgg16_128_SRAM_de_layer_5
# Size: 3
# Size: 3
# Size: 4
# All macro: 36
# adc area: 15983.646474, number of adc: 4096,
# total adc area: (15983.646474*4096/4096) * macro = 575411.273064
#
# Size: 3
# Size: 3
# Size: 4
# All macro: 36
# column drivers area: 463.560166, number of column_drivers: 4096,
# total column drivers area: (463.560166*4096/4096) * macro = 16688.165976
#
# Size: 3
# Size: 3
# Size: 4
# All macro: 36
# row drivers area: 438.8595, number of row_drivers: 4096,
# total row drivers area: (438.8595*4096/4096) * macro = 15798.942000000001
#
# Size: 3
# Size: 3
# Size: 4
# All macro: 36
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 91351.94111999999
#
# Total Area for layer 5: 699250.32216
#
# Total Macro for layer 5: 70
#
# Total Area for all layers: 1359653.4042
# Total Area for ADC across all layers: 1118855.25318
# Processing layer: vgg16_128_SRAM_de_layer_6
# Size: 3
# Size: 3
# Size: 4
# All macro: 36
# adc area: 15983.646474, number of adc: 4096,
# total adc area: (15983.646474*4096/4096) * macro = 575411.273064
#
# Size: 3
# Size: 3
# Size: 4
# All macro: 36
# column drivers area: 463.560166, number of column_drivers: 4096,
# total column drivers area: (463.560166*4096/4096) * macro = 16688.165976
#
# Size: 3
# Size: 3
# Size: 4
# All macro: 36
# row drivers area: 438.8595, number of row_drivers: 4096,
# total row drivers area: (438.8595*4096/4096) * macro = 15798.942000000001
#
# Size: 3
# Size: 3
# Size: 4
# All macro: 36
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 91351.94111999999
#
# Total Area for layer 6: 699250.32216
#
# Total Macro for layer 6: 106
#
# Total Area for all layers: 2058903.72636
# Total Area for ADC across all layers: 1694266.526244
# Processing layer: vgg16_128_SRAM_de_layer_7
# Size: 3
# Size: 3
# Size: 4
# All macro: 36
# adc area: 15983.646474, number of adc: 4096,
# total adc area: (15983.646474*4096/4096) * macro = 575411.273064
#
# Size: 3
# Size: 3
# Size: 4
# All macro: 36
# column drivers area: 463.560166, number of column_drivers: 4096,
# total column drivers area: (463.560166*4096/4096) * macro = 16688.165976
#
# Size: 3
# Size: 3
# Size: 4
# All macro: 36
# row drivers area: 438.8595, number of row_drivers: 4096,
# total row drivers area: (438.8595*4096/4096) * macro = 15798.942000000001
#
# Size: 3
# Size: 3
# Size: 4
# All macro: 36
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 91351.94111999999
#
# Total Area for layer 7: 699250.32216
#
# Total Macro for layer 7: 142
#
# Total Area for all layers: 2758154.0485199997
# Total Area for ADC across all layers: 2269677.799308
# Processing layer: vgg16_128_SRAM_de_layer_8
# Size: 3
# Size: 3
# Size: 8
# All macro: 72
# adc area: 15983.646474, number of adc: 4096,
# total adc area: (15983.646474*4096/4096) * macro = 1150822.546128
#
# Size: 3
# Size: 3
# Size: 8
# All macro: 72
# column drivers area: 463.560166, number of column_drivers: 4096,
# total column drivers area: (463.560166*4096/4096) * macro = 33376.331952
#
# Size: 3
# Size: 3
# Size: 8
# All macro: 72
# row drivers area: 438.8595, number of row_drivers: 4096,
# total row drivers area: (438.8595*4096/4096) * macro = 31597.884000000002
#
# Size: 3
# Size: 3
# Size: 8
# All macro: 72
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 182703.88223999998
#
# Total Area for layer 8: 1398500.64432
#
# Total Macro for layer 8: 214
#
# Total Area for all layers: 4156654.6928399997
# Total Area for ADC across all layers: 3420500.3454360003
# Processing layer: vgg16_128_SRAM_de_layer_9
# Size: 3
# Size: 3
# Size: 4
# Size: 4
# All macro: 144
# adc area: 15983.646474, number of adc: 4096,
# total adc area: (15983.646474*4096/4096) * macro = 2301645.092256
#
# Size: 3
# Size: 3
# Size: 4
# Size: 4
# All macro: 144
# column drivers area: 463.560166, number of column_drivers: 4096,
# total column drivers area: (463.560166*4096/4096) * macro = 66752.663904
#
# Size: 3
# Size: 3
# Size: 4
# Size: 4
# All macro: 144
# row drivers area: 438.8595, number of row_drivers: 4096,
# total row drivers area: (438.8595*4096/4096) * macro = 63195.768000000004
#
# Size: 3
# Size: 3
# Size: 4
# Size: 4
# All macro: 144
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 365407.76447999995
#
# Total Area for layer 9: 2797001.28864
#
# Total Macro for layer 9: 358
#
# Total Area for all layers: 6953655.98148
# Total Area for ADC across all layers: 5722145.437692
# Processing layer: vgg16_128_SRAM_de_layer_10
# Size: 3
# Size: 3
# Size: 4
# Size: 4
# All macro: 144
# adc area: 15983.646474, number of adc: 4096,
# total adc area: (15983.646474*4096/4096) * macro = 2301645.092256
#
# Size: 3
# Size: 3
# Size: 4
# Size: 4
# All macro: 144
# column drivers area: 463.560166, number of column_drivers: 4096,
# total column drivers area: (463.560166*4096/4096) * macro = 66752.663904
#
# Size: 3
# Size: 3
# Size: 4
# Size: 4
# All macro: 144
# row drivers area: 438.8595, number of row_drivers: 4096,
# total row drivers area: (438.8595*4096/4096) * macro = 63195.768000000004
#
# Size: 3
# Size: 3
# Size: 4
# Size: 4
# All macro: 144
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 365407.76447999995
#
# Total Area for layer 10: 2797001.28864
#
# Total Macro for layer 10: 502
#
# Total Area for all layers: 9750657.270119999
# Total Area for ADC across all layers: 8023790.529948
# Processing layer: vgg16_128_SRAM_de_layer_11
# Size: 3
# Size: 3
# Size: 4
# Size: 4
# All macro: 144
# adc area: 15983.646474, number of adc: 4096,
# total adc area: (15983.646474*4096/4096) * macro = 2301645.092256
#
# Size: 3
# Size: 3
# Size: 4
# Size: 4
# All macro: 144
# column drivers area: 463.560166, number of column_drivers: 4096,
# total column drivers area: (463.560166*4096/4096) * macro = 66752.663904
#
# Size: 3
# Size: 3
# Size: 4
# Size: 4
# All macro: 144
# row drivers area: 438.8595, number of row_drivers: 4096,
# total row drivers area: (438.8595*4096/4096) * macro = 63195.768000000004
#
# Size: 3
# Size: 3
# Size: 4
# Size: 4
# All macro: 144
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 365407.76447999995
#
# Total Area for layer 11: 2797001.28864
#
# Total Macro for layer 11: 646
#
# Total Area for all layers: 12547658.558759999
# Total Area for ADC across all layers: 10325435.622204
# Processing layer: vgg16_128_SRAM_de_layer_12
# Size: 3
# Size: 3
# Size: 4
# Size: 4
# All macro: 144
# adc area: 15983.646474, number of adc: 4096,
# total adc area: (15983.646474*4096/4096) * macro = 2301645.092256
#
# Size: 3
# Size: 3
# Size: 4
# Size: 4
# All macro: 144
# column drivers area: 463.560166, number of column_drivers: 4096,
# total column drivers area: (463.560166*4096/4096) * macro = 66752.663904
#
# Size: 3
# Size: 3
# Size: 4
# Size: 4
# All macro: 144
# row drivers area: 438.8595, number of row_drivers: 4096,
# total row drivers area: (438.8595*4096/4096) * macro = 63195.768000000004
#
# Size: 3
# Size: 3
# Size: 4
# Size: 4
# All macro: 144
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 365407.76447999995
#
# Total Area for layer 12: 2797001.28864
#
# Total Macro for layer 12: 790
#
# Total Area for all layers: 15344659.847399998
# Total Area for ADC across all layers: 12627080.71446
# Processing layer: vgg16_128_SRAM_de_layer_13
# Size: 3
# Size: 3
# Size: 4
# Size: 4
# All macro: 144
# adc area: 15983.646474, number of adc: 4096,
# total adc area: (15983.646474*4096/4096) * macro = 2301645.092256
#
# Size: 3
# Size: 3
# Size: 4
# Size: 4
# All macro: 144
# column drivers area: 463.560166, number of column_drivers: 4096,
# total column drivers area: (463.560166*4096/4096) * macro = 66752.663904
#
# Size: 3
# Size: 3
# Size: 4
# Size: 4
# All macro: 144
# row drivers area: 438.8595, number of row_drivers: 4096,
# total row drivers area: (438.8595*4096/4096) * macro = 63195.768000000004
#
# Size: 3
# Size: 3
# Size: 4
# Size: 4
# All macro: 144
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 365407.76447999995
#
# Total Area for layer 13: 2797001.28864
#
# Total Macro for layer 13: 934
#
# Total Area for all layers: 18141661.13604
# Total Area for ADC across all layers: 14928725.806716
# Processing layer: vgg16_128_SRAM_de_layer_14
# Size: 16
# Size: 196
# All macro: 3136
# adc area: 15983.646474, number of adc: 4096,
# total adc area: (15983.646474*4096/4096) * macro = 50124715.342464
#
# Size: 16
# Size: 196
# All macro: 3136
# column drivers area: 463.560166, number of column_drivers: 4096,
# total column drivers area: (463.560166*4096/4096) * macro = 1453724.680576
#
# Size: 16
# Size: 196
# All macro: 3136
# row drivers area: 438.8595, number of row_drivers: 4096,
# total row drivers area: (438.8595*4096/4096) * macro = 1376263.392
#
# Size: 16
# Size: 196
# All macro: 3136
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 7957769.093119999
#
# Total Area for layer 14: 60912472.508159995
#
# Total Macro for layer 14: 4070
#
# Total Area for all layers: 79054133.6442
# Total Area for ADC across all layers: 65053441.14918
# Processing layer: vgg16_128_SRAM_de_layer_15
# Size: 64
# Size: 32
# All macro: 2048
# adc area: 15983.646474, number of adc: 4096,
# total adc area: (15983.646474*4096/4096) * macro = 32734507.978752
#
# Size: 64
# Size: 32
# All macro: 2048
# column drivers area: 463.560166, number of column_drivers: 4096,
# total column drivers area: (463.560166*4096/4096) * macro = 949371.219968
#
# Size: 64
# Size: 32
# All macro: 2048
# row drivers area: 438.8595, number of row_drivers: 4096,
# total row drivers area: (438.8595*4096/4096) * macro = 898784.256
#
# Size: 64
# Size: 32
# All macro: 2048
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 5196910.42816
#
# Total Area for layer 15: 39779573.882879995
#
# Total Macro for layer 15: 6118
#
# Total Area for all layers: 118833707.52708
# Total Area for ADC across all layers: 97787949.127932
# Processing layer: vgg16_128_SRAM_de_layer_16
# Size: 16
# Size: 32
# All macro: 512
# adc area: 15983.646474, number of adc: 4096,
# total adc area: (15983.646474*4096/4096) * macro = 8183626.994688
#
# Size: 16
# Size: 32
# All macro: 512
# column drivers area: 463.560166, number of column_drivers: 4096,
# total column drivers area: (463.560166*4096/4096) * macro = 237342.804992
#
# Size: 16
# Size: 32
# All macro: 512
# row drivers area: 438.8595, number of row_drivers: 4096,
# total row drivers area: (438.8595*4096/4096) * macro = 224696.064
#
# Size: 16
# Size: 32
# All macro: 512
# cim unit area: 0.15488, number of cim_unit: 67108864,
# total cim unit area: (0.15488*67108864/4096) * macro = 1299227.60704
#
# Total Area for layer 16: 9944893.470719999
#
# Total Macro for layer 16: 6630
#
# Total Area for all layers: 128778600.9978
# Total Area for ADC across all layers: 105971576.12262
# Total Area for column drivers across all layers: 3073403.90058
# Total Area for row drivers across all layers: 2909638.4850000003
# Total Area for cim unit across all layers: 16823982.4896
#
#
# Total Area for ADC across all layers: 105.97157612262
# Total Area for column driver across all layers: 3.07340390058
# Total Area for row driver across all layers: 2.9096384850000003
# Total Area for cim unit across all layers: 16.8239824896
# Total Macro across all layers: 6630
# vgg16_128_SRAM_de 	 2.83e-04 	 128.78 	 6.80e+01
# ../outputs/vgg16_256_SRAM_de/
# Model 	 Energy/inference (J) 	 Area (mm2) 	 Throughput (inf/s)
# Processing layer: vgg16_256_SRAM_de_layer_1
# All macro: 1
# adc area: 18116.596707, number of adc: 4096,
# total adc area: (18116.596707*4096/4096) * macro = 18116.596707
#
# All macro: 1
# column drivers area: 1818.845866, number of column_drivers: 4096,
# total column drivers area: (1818.845866*4096/4096) * macro = 1818.845866
#
# All macro: 1
# row drivers area: 844.0287, number of row_drivers: 4096,
# total row drivers area: (844.0287*4096/4096) * macro = 844.0287
#
# All macro: 1
# cim unit area: 0.15488, number of cim_unit: 268435456,
# total cim unit area: (0.15488*268435456/4096) * macro = 10150.21568
#
# Total Area for layer 1: 30929.686952999997
#
# Total Macro for layer 1: 1
#
# Total Area for all layers: 30929.686952999997
# Total Area for ADC across all layers: 18116.596707
# Processing layer: vgg16_256_SRAM_de_layer_2
# Size: 3
# All macro: 3
# adc area: 18116.596707, number of adc: 4096,
# total adc area: (18116.596707*4096/4096) * macro = 54349.790121
#
# Size: 3
# All macro: 3
# column drivers area: 1818.845866, number of column_drivers: 4096,
# total column drivers area: (1818.845866*4096/4096) * macro = 5456.537598
#
# Size: 3
# All macro: 3
# row drivers area: 844.0287, number of row_drivers: 4096,
# total row drivers area: (844.0287*4096/4096) * macro = 2532.0861
#
# Size: 3
# All macro: 3
# cim unit area: 0.15488, number of cim_unit: 268435456,
# total cim unit area: (0.15488*268435456/4096) * macro = 30450.647039999996
#
# Total Area for layer 2: 92789.06085899999
#
# Total Macro for layer 2: 4
#
# Total Area for all layers: 123718.74781199999
# Total Area for ADC across all layers: 72466.386828
# Processing layer: vgg16_256_SRAM_de_layer_3
# Size: 3
# All macro: 3
# adc area: 18116.596707, number of adc: 4096,
# total adc area: (18116.596707*4096/4096) * macro = 54349.790121
#
# Size: 3
# All macro: 3
# column drivers area: 1818.845866, number of column_drivers: 4096,
# total column drivers area: (1818.845866*4096/4096) * macro = 5456.537598
#
# Size: 3
# All macro: 3
# row drivers area: 844.0287, number of row_drivers: 4096,
# total row drivers area: (844.0287*4096/4096) * macro = 2532.0861
#
# Size: 3
# All macro: 3
# cim unit area: 0.15488, number of cim_unit: 268435456,
# total cim unit area: (0.15488*268435456/4096) * macro = 30450.647039999996
#
# Total Area for layer 3: 92789.06085899999
#
# Total Macro for layer 3: 7
#
# Total Area for all layers: 216507.80867099998
# Total Area for ADC across all layers: 126816.176949
# Processing layer: vgg16_256_SRAM_de_layer_4
# Size: 5
# All macro: 5
# adc area: 18116.596707, number of adc: 4096,
# total adc area: (18116.596707*4096/4096) * macro = 90582.983535
#
# Size: 5
# All macro: 5
# column drivers area: 1818.845866, number of column_drivers: 4096,
# total column drivers area: (1818.845866*4096/4096) * macro = 9094.22933
#
# Size: 5
# All macro: 5
# row drivers area: 844.0287, number of row_drivers: 4096,
# total row drivers area: (844.0287*4096/4096) * macro = 4220.1435
#
# Size: 5
# All macro: 5
# cim unit area: 0.15488, number of cim_unit: 268435456,
# total cim unit area: (0.15488*268435456/4096) * macro = 50751.0784
#
# Total Area for layer 4: 154648.434765
#
# Total Macro for layer 4: 12
#
# Total Area for all layers: 371156.24343599996
# Total Area for ADC across all layers: 217399.160484
# Processing layer: vgg16_256_SRAM_de_layer_5
# Size: 2
# Size: 5
# All macro: 10
# adc area: 18116.596707, number of adc: 4096,
# total adc area: (18116.596707*4096/4096) * macro = 181165.96707
#
# Size: 2
# Size: 5
# All macro: 10
# column drivers area: 1818.845866, number of column_drivers: 4096,
# total column drivers area: (1818.845866*4096/4096) * macro = 18188.45866
#
# Size: 2
# Size: 5
# All macro: 10
# row drivers area: 844.0287, number of row_drivers: 4096,
# total row drivers area: (844.0287*4096/4096) * macro = 8440.287
#
# Size: 2
# Size: 5
# All macro: 10
# cim unit area: 0.15488, number of cim_unit: 268435456,
# total cim unit area: (0.15488*268435456/4096) * macro = 101502.1568
#
# Total Area for layer 5: 309296.86953
#
# Total Macro for layer 5: 22
#
# Total Area for all layers: 680453.112966
# Total Area for ADC across all layers: 398565.127554
# Processing layer: vgg16_256_SRAM_de_layer_6
# Size: 3
# Size: 3
# Size: 2
# All macro: 18
# adc area: 18116.596707, number of adc: 4096,
# total adc area: (18116.596707*4096/4096) * macro = 326098.740726
#
# Size: 3
# Size: 3
# Size: 2
# All macro: 18
# column drivers area: 1818.845866, number of column_drivers: 4096,
# total column drivers area: (1818.845866*4096/4096) * macro = 32739.225587999998
#
# Size: 3
# Size: 3
# Size: 2
# All macro: 18
# row drivers area: 844.0287, number of row_drivers: 4096,
# total row drivers area: (844.0287*4096/4096) * macro = 15192.516599999999
#
# Size: 3
# Size: 3
# Size: 2
# All macro: 18
# cim unit area: 0.15488, number of cim_unit: 268435456,
# total cim unit area: (0.15488*268435456/4096) * macro = 182703.88223999998
#
# Total Area for layer 6: 556734.3651539999
#
# Total Macro for layer 6: 40
#
# Total Area for all layers: 1237187.4781199999
# Total Area for ADC across all layers: 724663.86828
# Processing layer: vgg16_256_SRAM_de_layer_7
# Size: 3
# Size: 3
# Size: 2
# All macro: 18
# adc area: 18116.596707, number of adc: 4096,
# total adc area: (18116.596707*4096/4096) * macro = 326098.740726
#
# Size: 3
# Size: 3
# Size: 2
# All macro: 18
# column drivers area: 1818.845866, number of column_drivers: 4096,
# total column drivers area: (1818.845866*4096/4096) * macro = 32739.225587999998
#
# Size: 3
# Size: 3
# Size: 2
# All macro: 18
# row drivers area: 844.0287, number of row_drivers: 4096,
# total row drivers area: (844.0287*4096/4096) * macro = 15192.516599999999
#
# Size: 3
# Size: 3
# Size: 2
# All macro: 18
# cim unit area: 0.15488, number of cim_unit: 268435456,
# total cim unit area: (0.15488*268435456/4096) * macro = 182703.88223999998
#
# Total Area for layer 7: 556734.3651539999
#
# Total Macro for layer 7: 58
#
# Total Area for all layers: 1793921.8432739996
# Total Area for ADC across all layers: 1050762.609006
# Processing layer: vgg16_256_SRAM_de_layer_8
# Size: 3
# Size: 3
# Size: 4
# All macro: 36
# adc area: 18116.596707, number of adc: 4096,
# total adc area: (18116.596707*4096/4096) * macro = 652197.481452
#
# Size: 3
# Size: 3
# Size: 4
# All macro: 36
# column drivers area: 1818.845866, number of column_drivers: 4096,
# total column drivers area: (1818.845866*4096/4096) * macro = 65478.451175999995
#
# Size: 3
# Size: 3
# Size: 4
# All macro: 36
# row drivers area: 844.0287, number of row_drivers: 4096,
# total row drivers area: (844.0287*4096/4096) * macro = 30385.033199999998
#
# Size: 3
# Size: 3
# Size: 4
# All macro: 36
# cim unit area: 0.15488, number of cim_unit: 268435456,
# total cim unit area: (0.15488*268435456/4096) * macro = 365407.76447999995
#
# Total Area for layer 8: 1113468.7303079998
#
# Total Macro for layer 8: 94
#
# Total Area for all layers: 2907390.573581999
# Total Area for ADC across all layers: 1702960.090458
# Processing layer: vgg16_256_SRAM_de_layer_9
# Size: 3
# Size: 3
# Size: 4
# All macro: 36
# adc area: 18116.596707, number of adc: 4096,
# total adc area: (18116.596707*4096/4096) * macro = 652197.481452
#
# Size: 3
# Size: 3
# Size: 4
# All macro: 36
# column drivers area: 1818.845866, number of column_drivers: 4096,
# total column drivers area: (1818.845866*4096/4096) * macro = 65478.451175999995
#
# Size: 3
# Size: 3
# Size: 4
# All macro: 36
# row drivers area: 844.0287, number of row_drivers: 4096,
# total row drivers area: (844.0287*4096/4096) * macro = 30385.033199999998
#
# Size: 3
# Size: 3
# Size: 4
# All macro: 36
# cim unit area: 0.15488, number of cim_unit: 268435456,
# total cim unit area: (0.15488*268435456/4096) * macro = 365407.76447999995
#
# Total Area for layer 9: 1113468.7303079998
#
# Total Macro for layer 9: 130
#
# Total Area for all layers: 4020859.303889999
# Total Area for ADC across all layers: 2355157.57191
# Processing layer: vgg16_256_SRAM_de_layer_10
# Size: 3
# Size: 3
# Size: 4
# All macro: 36
# adc area: 18116.596707, number of adc: 4096,
# total adc area: (18116.596707*4096/4096) * macro = 652197.481452
#
# Size: 3
# Size: 3
# Size: 4
# All macro: 36
# column drivers area: 1818.845866, number of column_drivers: 4096,
# total column drivers area: (1818.845866*4096/4096) * macro = 65478.451175999995
#
# Size: 3
# Size: 3
# Size: 4
# All macro: 36
# row drivers area: 844.0287, number of row_drivers: 4096,
# total row drivers area: (844.0287*4096/4096) * macro = 30385.033199999998
#
# Size: 3
# Size: 3
# Size: 4
# All macro: 36
# cim unit area: 0.15488, number of cim_unit: 268435456,
# total cim unit area: (0.15488*268435456/4096) * macro = 365407.76447999995
#
# Total Area for layer 10: 1113468.7303079998
#
# Total Macro for layer 10: 166
#
# Total Area for all layers: 5134328.034197999
# Total Area for ADC across all layers: 3007355.053362
# Processing layer: vgg16_256_SRAM_de_layer_11
# Size: 3
# Size: 3
# Size: 4
# All macro: 36
# adc area: 18116.596707, number of adc: 4096,
# total adc area: (18116.596707*4096/4096) * macro = 652197.481452
#
# Size: 3
# Size: 3
# Size: 4
# All macro: 36
# column drivers area: 1818.845866, number of column_drivers: 4096,
# total column drivers area: (1818.845866*4096/4096) * macro = 65478.451175999995
#
# Size: 3
# Size: 3
# Size: 4
# All macro: 36
# row drivers area: 844.0287, number of row_drivers: 4096,
# total row drivers area: (844.0287*4096/4096) * macro = 30385.033199999998
#
# Size: 3
# Size: 3
# Size: 4
# All macro: 36
# cim unit area: 0.15488, number of cim_unit: 268435456,
# total cim unit area: (0.15488*268435456/4096) * macro = 365407.76447999995
#
# Total Area for layer 11: 1113468.7303079998
#
# Total Macro for layer 11: 202
#
# Total Area for all layers: 6247796.764505999
# Total Area for ADC across all layers: 3659552.5348139997
# Processing layer: vgg16_256_SRAM_de_layer_12
# Size: 3
# Size: 3
# Size: 4
# All macro: 36
# adc area: 18116.596707, number of adc: 4096,
# total adc area: (18116.596707*4096/4096) * macro = 652197.481452
#
# Size: 3
# Size: 3
# Size: 4
# All macro: 36
# column drivers area: 1818.845866, number of column_drivers: 4096,
# total column drivers area: (1818.845866*4096/4096) * macro = 65478.451175999995
#
# Size: 3
# Size: 3
# Size: 4
# All macro: 36
# row drivers area: 844.0287, number of row_drivers: 4096,
# total row drivers area: (844.0287*4096/4096) * macro = 30385.033199999998
#
# Size: 3
# Size: 3
# Size: 4
# All macro: 36
# cim unit area: 0.15488, number of cim_unit: 268435456,
# total cim unit area: (0.15488*268435456/4096) * macro = 365407.76447999995
#
# Total Area for layer 12: 1113468.7303079998
#
# Total Macro for layer 12: 238
#
# Total Area for all layers: 7361265.494813999
# Total Area for ADC across all layers: 4311750.0162659995
# Processing layer: vgg16_256_SRAM_de_layer_13
# Size: 3
# Size: 3
# Size: 4
# All macro: 36
# adc area: 18116.596707, number of adc: 4096,
# total adc area: (18116.596707*4096/4096) * macro = 652197.481452
#
# Size: 3
# Size: 3
# Size: 4
# All macro: 36
# column drivers area: 1818.845866, number of column_drivers: 4096,
# total column drivers area: (1818.845866*4096/4096) * macro = 65478.451175999995
#
# Size: 3
# Size: 3
# Size: 4
# All macro: 36
# row drivers area: 844.0287, number of row_drivers: 4096,
# total row drivers area: (844.0287*4096/4096) * macro = 30385.033199999998
#
# Size: 3
# Size: 3
# Size: 4
# All macro: 36
# cim unit area: 0.15488, number of cim_unit: 268435456,
# total cim unit area: (0.15488*268435456/4096) * macro = 365407.76447999995
#
# Total Area for layer 13: 1113468.7303079998
#
# Total Macro for layer 13: 274
#
# Total Area for all layers: 8474734.225122
# Total Area for ADC across all layers: 4963947.497718
# Processing layer: vgg16_256_SRAM_de_layer_14
# Size: 32
# Size: 98
# All macro: 3136
# adc area: 18116.596707, number of adc: 4096,
# total adc area: (18116.596707*4096/4096) * macro = 56813647.273152
#
# Size: 32
# Size: 98
# All macro: 3136
# column drivers area: 1818.845866, number of column_drivers: 4096,
# total column drivers area: (1818.845866*4096/4096) * macro = 5703900.635776
#
# Size: 32
# Size: 98
# All macro: 3136
# row drivers area: 844.0287, number of row_drivers: 4096,
# total row drivers area: (844.0287*4096/4096) * macro = 2646874.0031999997
#
# Size: 32
# Size: 98
# All macro: 3136
# cim unit area: 0.15488, number of cim_unit: 268435456,
# total cim unit area: (0.15488*268435456/4096) * macro = 31831076.372479998
#
# Total Area for layer 14: 96995498.284608
#
# Total Macro for layer 14: 3410
#
# Total Area for all layers: 105470232.50973001
# Total Area for ADC across all layers: 61777594.77087
# Processing layer: vgg16_256_SRAM_de_layer_15
# Size: 32
# Size: 16
# All macro: 512
# adc area: 18116.596707, number of adc: 4096,
# total adc area: (18116.596707*4096/4096) * macro = 9275697.513984
#
# Size: 32
# Size: 16
# All macro: 512
# column drivers area: 1818.845866, number of column_drivers: 4096,
# total column drivers area: (1818.845866*4096/4096) * macro = 931249.083392
#
# Size: 32
# Size: 16
# All macro: 512
# row drivers area: 844.0287, number of row_drivers: 4096,
# total row drivers area: (844.0287*4096/4096) * macro = 432142.6944
#
# Size: 32
# Size: 16
# All macro: 512
# cim unit area: 0.15488, number of cim_unit: 268435456,
# total cim unit area: (0.15488*268435456/4096) * macro = 5196910.42816
#
# Total Area for layer 15: 15835999.719935998
#
# Total Macro for layer 15: 3922
#
# Total Area for all layers: 121306232.22966601
# Total Area for ADC across all layers: 71053292.284854
# Processing layer: vgg16_256_SRAM_de_layer_16
# Size: 8
# Size: 16
# All macro: 128
# adc area: 18116.596707, number of adc: 4096,
# total adc area: (18116.596707*4096/4096) * macro = 2318924.378496
#
# Size: 8
# Size: 16
# All macro: 128
# column drivers area: 1818.845866, number of column_drivers: 4096,
# total column drivers area: (1818.845866*4096/4096) * macro = 232812.270848
#
# Size: 8
# Size: 16
# All macro: 128
# row drivers area: 844.0287, number of row_drivers: 4096,
# total row drivers area: (844.0287*4096/4096) * macro = 108035.6736
#
# Size: 8
# Size: 16
# All macro: 128
# cim unit area: 0.15488, number of cim_unit: 268435456,
# total cim unit area: (0.15488*268435456/4096) * macro = 1299227.60704
#
# Total Area for layer 16: 3958999.9299839996
#
# Total Macro for layer 16: 4050
#
# Total Area for all layers: 125265232.15965001
# Total Area for ADC across all layers: 73372216.66335
# Total Area for column drivers across all layers: 7366325.757300001
# Total Area for row drivers across all layers: 3418316.2349999994
# Total Area for cim unit across all layers: 41108373.50399999
#
#
# Total Area for ADC across all layers: 73.37221666335
# Total Area for column driver across all layers: 7.3663257573
# Total Area for row driver across all layers: 3.4183162349999994
# Total Area for cim unit across all layers: 41.10837350399999
# Total Macro across all layers: 4050
# vgg16_256_SRAM_de 	 2.15e-04 	 125.27 	 7.15e+01

# %%
print(total_area)
print(total_adc_area)
print(total_col_area)
print(total_row_area)
print(total_cim_unit_area)
print(total_macro)
print(energy)
print(throughput)
# Out:
# [330.35383742662407, 194.6023686744, 128.7786009978, 125.26523215965001]
# [322.08675247833594, 181.91345581199997, 105.97157612262, 73.37221666335]
# [0.884937943488, 1.5660066713999998, 3.07340390058, 7.3663257573]
# [3.2763847622399997, 2.939294799, 2.9096384850000003, 3.4183162349999994]
# [4.105762242559999, 8.183611392, 16.8239824896, 41.10837350399999]
# [25888, 12900, 6630, 4050]
# [0.001225431, 0.000512178, 0.00028297109999999995, 0.00021539409999999997]
# [44.50715007365933, 61.46319276701147, 68.02443437682815, 71.45562248565528]

# %%
import matplotlib.pyplot as plt
import numpy as np
fig, ax = plt.subplots(figsize=(10, 5)) 
array_sizes = ['32', '64', '128', '256']

x = np.arange(len(array_sizes))

# Stack bars
ax.bar(array_sizes, total_cim_unit_area, label='cim_unit')
ax.bar(array_sizes, total_row_area, bottom=total_cim_unit_area, label='row_drivers')
ax.bar(array_sizes, total_col_area, bottom=np.array(total_cim_unit_area) + np.array(total_row_area), label='column_drivers')
ax.bar(array_sizes, total_adc_area, bottom=np.array(total_cim_unit_area) + np.array(total_row_area) + np.array(total_col_area), label='adc')

# Labels and title
ax.set_title("Area vs Array Size for vgg16")
ax.set_xlabel("Array Size")
ax.set_ylabel("Area (mm2)")
# Set x-ticks
ax.set_xticks(x)
ax.set_xticklabels(array_sizes)

ax.legend()

# Show plot
plt.show()

# %%
total_per_energy_32 = [0.3960061304112863, 0.0007033541719245287, 0.6028750045068203, 0.00041551090996894173]
total_per_energy_64 = [0.63805695467786, 0.0022474841985667894, 0.3590260774830676, 0.0006694836405055874]
total_per_energy_128 = [0.7533058320486852, 0.005295627565595982, 0.24060813143059875, 0.0007904089551201641]
total_per_energy_256 = [0.6516730002148846, 0.009162327853767471, 0.3384809016042562, 0.0006837703270916192]

# %%
total_adc_energy = [0] * 4
total_col_energy = [0] * 4
total_row_energy = [0] * 4
total_cim_unit_energy = [0] * 4
for j in range(len(energy)):
    if j == 0:
        for i in range(len(total_per_energy_32)):
            if i == 0:
                total_adc_energy[j] = total_per_energy_32[i] * energy[j]
            elif i == 1:
                total_col_energy[j] = total_per_energy_32[i] * energy[j]
            elif i == 2:
                total_row_energy[j] = total_per_energy_32[i] * energy[j]
            else:
                total_cim_unit_energy[j] = total_per_energy_32[i] * energy[j]
    elif j == 1:
        for i in range(len(total_per_energy_64)):
            if i == 0:
                total_adc_energy[j] = total_per_energy_64[i] * energy[j]
            elif i == 1:
                total_col_energy[j] = total_per_energy_64[i] * energy[j]
            elif i == 2:
                total_row_energy[j] = total_per_energy_64[i] * energy[j]
            else:
                total_cim_unit_energy[j] = total_per_energy_64[i] * energy[j]

    elif j == 2:
        for i in range(len(total_per_energy_128)):
            if i == 0:
                total_adc_energy[j] = total_per_energy_128[i] * energy[j]
            elif i == 1:
                total_col_energy[j] = total_per_energy_128[i] * energy[j]
            elif i == 2:
                total_row_energy[j] = total_per_energy_128[i] * energy[j]
            else:
                total_cim_unit_energy[j] = total_per_energy_128[i] * energy[j]

    else:
        for i in range(len(total_per_energy_256)):
            if i == 0:
                total_adc_energy[j] = total_per_energy_256[i] * energy[j]
            elif i == 1:
                total_col_energy[j] = total_per_energy_256[i] * energy[j]
            elif i == 2:
                total_row_energy[j] = total_per_energy_256[i] * energy[j]
            else:
                total_cim_unit_energy[j] = total_per_energy_256[i] * energy[j]
                
print(total_adc_energy)
print(total_col_energy)
print(total_row_energy)
print(total_cim_unit_energy)
# Out:
# [0.00048527818839603294, 0.000326798734932997, 0.00021316377993123165, 0.00014036651937558486]
# [8.61912006255647e-07, 1.151111961853541e-06, 1.498509557427017e-06, 1.973511361967176e-06]
# [0.0007387817196477973, 0.00018388525831312258, 6.808514761986109e-05, 7.29067891682373e-05]
# [5.091799499141502e-07, 3.4289479202687073e-07, 2.2366289148020342e-07, 1.4728009421060492e-07]

# %%
import matplotlib.pyplot as plt
import numpy as np
fig, ax = plt.subplots(figsize=(10, 5)) 
array_sizes = ['32', '64', '128', '256']

x = np.arange(len(array_sizes))

# Stack bars
ax.bar(array_sizes, total_cim_unit_energy, label='cim_unit')
ax.bar(array_sizes, total_row_energy, bottom=total_cim_unit_energy, label='row_drivers')
ax.bar(array_sizes, total_col_energy, bottom=np.array(total_cim_unit_energy) + np.array(total_row_energy), label='column_drivers')
ax.bar(array_sizes, total_adc_energy, bottom=np.array(total_cim_unit_energy) + np.array(total_row_energy) + np.array(total_col_energy), label='adc')

# Labels and title
ax.set_title("Energy vs Array Size for vgg16")
ax.set_xlabel("Array Size")
ax.set_ylabel("Energy (J)")
# Set x-ticks
ax.set_xticks(x)
ax.set_xticklabels(array_sizes)

ax.legend()

# Show plot
plt.show()

# %%
print(energy)
# Out:
# [0.001225431, 0.000512178, 0.00028297109999999995, 0.00021539409999999997]

# %%
import matplotlib.pyplot as plt

# Data
array_sizes = ['32', '64', '128', '256']
x = np.arange(len(array_sizes))
# Plotting the line graph
plt.figure(figsize=(10, 6))
plt.plot(array_sizes, total_macro, marker='o', linestyle='-', color='b')

# Adding labels and title
plt.xlabel('Array Size')
plt.ylabel('Number of Macros')
plt.title('Number of Macros vs Array Size for vgg 16')
plt.grid(False)
plt.xticks(x, array_sizes) 
# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
array_sizes = ['32', '64', '128', '256']
x = np.arange(len(array_sizes))
# Plotting the line graph
plt.figure(figsize=(10, 6))
plt.plot(array_sizes, throughput, marker='o', linestyle='-', color='b')

# Adding labels and title
plt.xlabel('Array Size')
plt.ylabel('Throughput')
plt.title('Throughput vs Array Size for vgg 16')
plt.grid(False)
plt.xticks(x, array_sizes) 
# Show plot
plt.show()
