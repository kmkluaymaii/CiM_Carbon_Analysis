# %%
from _import_scripts import scripts
from scripts.notebook_utils import *
from scripts.tl_output_parsing import MacroOutputStats
from scripts.utils import *
import yaml

def create_layer_directory(base_output_dir: str, architecture: str, layer: int) -> str:
    layer_dir = os.path.join(base_output_dir, f"{architecture}_layer_{layer}")
    if not os.path.exists(layer_dir):
        os.makedirs(layer_dir)
    return layer_dir

num_layers = 1

def run_map(
    spec: tl.Specification,
    arch: str,
    accelergy_verbose: bool = False,
) -> dict:
    output_dir = get_run_dir()
    # Just use the directory name if it causes error
    base_output_dir = os.path.dirname(output_dir)
    base_output_dir = os.path.join(base_output_dir, arch)
    global num_layers

    mapper_result = None

    if num_layers < 146:
        # Create a directory for the current layer
        layer_dir = create_layer_directory(base_output_dir, arch, num_layers)
        # print(f"Layer directory: {layer_dir}")
        num_layers += 1

        run_prefix = f"{layer_dir}/timeloop-mapper"
        mapper_result = tl.call_mapper(
            specification=spec,
            output_dir=layer_dir,
            log_to=os.path.join(output_dir, f"{run_prefix}.log"),
        )
        if accelergy_verbose:
            tl.call_accelergy_verbose(
                specification=spec,
                output_dir=layer_dir,
                log_to=os.path.join(output_dir, "accelergy.log"),
            )

    if mapper_result is None:
        # Handle case when mapper_result is not assigned (num_layers >= 17)
        # Raise an error, return a default value
        print("Warning: mapper_result is not assigned. num_layers >= 17")
        return {}

    return MacroOutputStats.from_output_stats(mapper_result)

import re

def extract_range(line):
    match = re.search(r'\[(\d+):(\d+)(,\d+)?\)', line)
    if match:
        start = int(match.group(1))
        end = int(match.group(2))
        return end - start
    return None

def read_and_compute_multiplication(filename, i):
    filename = f"../outputs/{filename}/{filename}_layer_{i+1}/timeloop-mapper.map.txt"
    with open(filename, 'r') as file:
        lines = file.readlines()

    start_searching = False
    ranges = []

    for line in lines:
        # Start searching when 'inter_macro_in_system_spatial' is found
        if "inter_macro_in_system_spatial" in line:
            start_searching = True
        
        # Stop searching if we leave the 'inter_macro_in_system_spatial' section
        elif start_searching and "inter_" in line and "inter_macro_in_system_spatial" not in line:
            break

        # If we are in the 'inter_macro_in_system_spatial' section, look for the ranges
        if start_searching:
            if "for" in line:
                range_size = extract_range(line)
                if range_size is not None:
                    ranges.append(range_size)
            elif line.strip() == "":  # Exit the section on an empty line
                break

    # Compute the multiplication of all ranges, or return 1 if no ranges were found
    if not ranges:
        print(f"All macro: 1")
        return 1

    result = 1
    for size in ranges:
        result *= size
        print(f"Size: {size}")
    print(f"All macro: {result}")
    return result


def extract_layer_number(folder_name):
    match = re.search(r'layer_(\d+)', folder_name)
    return int(match.group(1)) if match else float('inf')

def extract_outputs(model):
    
    output_dir = "../outputs/" + model + "/" 
    print(output_dir)

    print ("Model \t Energy/inference (J) \t Area (mm2) \t Throughput (inf/s)")
    #for model in models:    
    throughput = 0   
    energy = 0
    area = 0
    cycles = 0
    folders = sorted([folder for folder in os.listdir(output_dir) if model in folder], key=extract_layer_number)
    area_per_many_macro = 0
    area_layer = 0
    j = 0
    total_sum = 0
    total_adc_area = 0  # Total area for ADC across all layers
    total_other_areas = {}  # Dictionary to store total areas for other components
    total_col_area = 0
    total_row_area = 0
    total_cim_unit_area = 0
    total_area = 0
    total_macro = 0
    
    for folder in folders:
        total = 0
        if model in folder:
            print(f"Processing layer: {folder}")
            # print(folder)
            if os.path.isdir(output_dir + folder):
                stat_file = output_dir + folder + "/timeloop-mapper.stats.txt"
                art_file = output_dir + folder + "/timeloop-mapper.ART.yaml"
        
                with open(stat_file, 'r') as f:
                    energy_stat = [line for line in f if line.startswith("Energy:")][0]
                    energy_uj = energy_stat.split(' ')[1] # uJ
                    energy += float(energy_uj)
                    # print(f"Energy for this layer: {float(energy_uj)} uj")
                
                with open(stat_file, 'r') as f:
                    cycle_stat = [line for line in f if line.startswith("Cycles:")][0]                  
                    cycle = cycle_stat.split(' ')[1] 
                    cycles += float(cycle)
                    
            if j < 16:
                with open(art_file, 'r') as file:
                    data = yaml.safe_load(file)
                
                    # Extract and print the name, area, number of entries, and ratio for non-zero areas
                for table in data['ART']['tables']:
                    name = table.get('name')
                    area = table.get('area')
                    if area != 0:
                        # Simplify the name for the output
                        if 'system_top_level.' in name:
                            name = name.split('system_top_level.')[-1]
                        
                        # Extract the number of entries from the name
                        if '[' in name:
                            name_part, entries_part = name.split('[')
                            number_of_entries = entries_part.split('..')[1].replace(']', '')
                            name = name_part.strip()
                        else:
                            number_of_entries = 'Unknown'
                        
                        macro = read_and_compute_multiplication(model, j)
                        # Calculate total ratio
                        if number_of_entries != 'Unknown' and number_of_entries.isdigit():
                            total_ratio = (area / 4096) * macro * int(number_of_entries)
                        else:
                            total_ratio = 0
                        
                        total += total_ratio
                           
                        # Accumulate area for ADC or other components
                        if 'adc' in name.lower():
                            total_adc_area += total_ratio
                        else:
                            if name not in total_other_areas:
                                total_other_areas[name] = 0
                            total_other_areas[name] += total_ratio
            
                        print(f"{name.replace('_', ' ')} area: {area}, number of {name}: {number_of_entries}, \ntotal {name.replace('_', ' ')} area: ({area}*{number_of_entries}/4096) * macro = {total_ratio}\n")
                j += 1 
                total_sum += total
                total_macro += macro
                print(f"Total Area for layer {j}: {total}\n")
                print(f"Total Macro for layer {j}: {total_macro}\n")
            print(f"Total Area for all layers: {total_sum}")
            print(f"Total Area for ADC across all layers: {total_adc_area}")
    
    # Print total area for other components
    for component, area in total_other_areas.items():
        print(f"Total Area for {component.replace('_', ' ')} across all layers: {area}")
        # print(component.replace('_', ' '))
        if component.replace('_', ' ') ==  "column drivers":
            total_col_area = area
        elif component.replace('_', ' ') ==  "row drivers":
            total_row_area = area
        else:
            total_cim_unit_area = area
                                
    energy *= 1e-6 # conver to J
    total_area = total_sum * 1e-6 # mm2
    throughput = 1 / (cycles * 1e-7) # s

    total_adc_area = total_adc_area * 1e-6 # mm2
    total_col_area = total_col_area * 1e-6 # mm2
    total_row_area = total_row_area * 1e-6 # mm2
    total_cim_unit_area = total_cim_unit_area * 1e-6 # mm2
    print("\n")
    print(f"Total Area for ADC across all layers: {total_adc_area}")
    print(f"Total Area for column driver across all layers: {total_col_area}")
    print(f"Total Area for row driver across all layers: {total_row_area}")
    print(f"Total Area for cim unit across all layers: {total_cim_unit_area}")
    print(f"Total Macro across all layers: {total_macro}")
    print ("{} \t {:.2e} \t {:.2f} \t {:.2e}".format(model, energy, total_area, throughput))
    
    return total_area, total_adc_area, total_col_area, total_row_area, total_cim_unit_area, total_macro, energy, throughput

# %%
MACRO_PATH = "../models/arch/1_macro/basic_analog/" 
macro = {}
SRAM_PATH = f'"{os.path.abspath("../models/memory_cells/sram_example.cell.yaml")}"'
RRAM_PATH = f'"{os.path.abspath("../models/memory_cells/rram_example.cell.yaml")}"'

# Define the architecture
array_sizes = 128
path_list = [SRAM_PATH, RRAM_PATH]
tech_node = 32
# adc_resolution = 6
DNN = "gpt2_medium"
time = "fast"

total_per_energy = {}

for path in path_list:
    arch = f"{path.split('/')[-1].split('_')[0].upper()}_{DNN}_{array_sizes}_{time}"
    print(f"\nRunning {DNN} with {array_sizes} x {array_sizes} {path.split('/')[-1].split('_')[0].upper()} with {tech_node} nm in {time} scenario")

    num_layers = 1

    def run_dnn(dnn: str, layer: str, array_sizes: int, variables):
        print(f"{layer} ", end="", flush=True)
        spec = get_spec(
            "basic_analog",
            # Weight-stationary, dummy buffer on top to hold inputs & outputs, many
            # macros to ensure we can fit all weights.
            system="ws_dummy_buffer_many_macro",
            # Set the DNN and layer
            dnn=dnn,
            layer=layer,
        )
    
        # Do NOT generate a maximum-utilization workload; we're running a DNN
        # workload.
        spec.variables["MAX_UTILIZATION"] = False
    
        # Use a larger array to ensure we can fit all weights
        spec.architecture.find("column").spatial.meshX = array_sizes
        spec.architecture.find("row").spatial.meshY = array_sizes
    
        spec.variables.update(variables)
        output_stats = run_map(spec, arch)
        
        # Print computes for the layer
        macro_output_stats = MacroOutputStats.from_output_stats(output_stats)
        print(f"Computes for layer {int(layer) + 1}: {macro_output_stats.computes}")
        global macro
        macro[layer] = macro_output_stats.computes
        return output_stats
    
    layers = [f for f in os.listdir(f"../models/workloads/{DNN}") if f != "index.yaml" and f.endswith(".yaml")]
    layers = sorted(layers)
    print(f"Running: ", end="")
    
    # Parallel/Delayed is used to multiprocess. Equivalent to running the following
    # code in serial:
    results = joblib.Parallel(n_jobs=None)(
        joblib.delayed(run_dnn)(DNN, layer.split(".")[0], array_sizes, 
                                  {
                                      "CELL_CONFIG": path,
                                      "BITS_PER_CELL": 1 if path == SRAM_PATH else 4,
                                      "CIM_UNIT_WIDTH_CELLS": 4 if path == SRAM_PATH else 1,
                                      "IS_SRAM": path == SRAM_PATH,
                                      "TECHNOLOGY": tech_node,
                                      "ADC_RESOLUTION": 4 if path == SRAM_PATH else 6,
                                      "GLOBAL_CYCLE_SECONDS": 1e-7 if time == "fast" else 1e-4,
                                  }
                                 ) for layer in layers
    )
    print("")
    for r in results:
        r.clear_zero_energies()
    
    #Initialize overall_energy
    energy_layer = [0] * 16
    result = 0
    
    # total_per_energy_32 = [0] * 4
    
    total_adc_energy = 0.0
    total_col_energy = 0.0
    total_row_energy = 0.0
    total_cim_unit_energy = 0.0
    # Calculate overall energy
    for r in results:
    
        per_component_energy = r.per_compute("per_component_energy")
        total_energy_per_layer = sum(per_component_energy.values()) * 1e15  # Convert to fJ
        total_adc_energy += per_component_energy.get('adc', 0.0)
        total_col_energy += per_component_energy.get('column_drivers', 0.0)
        total_row_energy += per_component_energy.get('row_drivers', 0.0)
        total_cim_unit_energy += per_component_energy.get('cim_unit', 0.0)
    
        total_adc_energy = total_adc_energy * 1e15
        total_col_energy = total_col_energy * 1e15
        total_row_energy = total_row_energy * 1e15
        total_cim_unit_energy = total_cim_unit_energy * 1e15
        total_energy = total_adc_energy + total_col_energy + total_row_energy + total_cim_unit_energy
    
        total_adc_energy = total_adc_energy/total_energy
        total_col_energy = total_col_energy/total_energy
        total_row_energy = total_row_energy/total_energy
        total_cim_unit_energy = total_cim_unit_energy/total_energy

        total_per_energy[path] = [total_adc_energy, total_col_energy, total_row_energy, total_cim_unit_energy]
        
    # Display overall energy
    print(f"Overall energy for DNN {DNN}: {total_energy} fJ")

    for i in range(4):
        print(f"total_per_energy[{path.split('/')[-1].split('_')[0].upper()}][{i}]: {total_per_energy[path][i]}")
    print() 
    
    # Display an energy breakdown for each layer as a bar chart. Display normalized per-MAC and per-layer energy.
    fig, ax = plt.subplots(figsize=(20, 5))
    
    bar_stacked(
        {i: r.per_compute("per_component_energy") * 1e15 for i, r in enumerate(results)},
        title= f"Using {path.split('/')[-1].split('_')[0].upper()} on {array_sizes} x {array_sizes} array sizes, {tech_node} nm",
        xlabel="Layer",
        ylabel="Energy (fJ/MAC)",
        ax=ax,
    )
# Out:
# Running gpt2_medium with 128 x 128 SRAM with 32 nm in fast scenario
# Computes for layer 1: 1572864.0
# Computes for layer 2: 524288.0
# Computes for layer 3: 512.0
# Computes for layer 4: 2048.0
# Computes for layer 5: 2097152.0
# Computes for layer 6: 2097152.0
# Computes for layer 7: 1572864.0
# Computes for layer 8: 524288.0
# Computes for layer 9: 512.0
# Computes for layer 10: 2048.0
# Computes for layer 11: 2097152.0
# Computes for layer 12: 2097152.0
# Computes for layer 13: 1572864.0
# Computes for layer 14: 524288.0
# Computes for layer 15: 512.0
# Computes for layer 16: 2048.0
# Computes for layer 17: 2097152.0
# Computes for layer 18: 2097152.0
# Computes for layer 19: 1572864.0
# Computes for layer 20: 524288.0
# Computes for layer 21: 512.0
# Computes for layer 22: 2048.0
# Computes for layer 23: 2097152.0
# Computes for layer 24: 2097152.0
# Computes for layer 25: 1572864.0
# Computes for layer 26: 524288.0
# Computes for layer 27: 512.0
# Computes for layer 28: 2048.0
# Computes for layer 29: 2097152.0
# Computes for layer 30: 2097152.0
# Computes for layer 31: 1572864.0
# Computes for layer 32: 524288.0
# Computes for layer 33: 512.0
# Computes for layer 34: 2048.0
# Computes for layer 35: 2097152.0
# Computes for layer 36: 2097152.0
# Computes for layer 37: 1572864.0
# Computes for layer 38: 524288.0
# Computes for layer 39: 512.0
# Computes for layer 40: 2048.0
# Computes for layer 41: 2097152.0
# Computes for layer 42: 2097152.0
# Computes for layer 43: 1572864.0
# Computes for layer 44: 524288.0
# Computes for layer 45: 512.0
# Computes for layer 46: 2048.0
# Computes for layer 47: 2097152.0
# Computes for layer 48: 2097152.0
# Computes for layer 49: 1572864.0
# Computes for layer 50: 524288.0
# Computes for layer 51: 512.0
# Computes for layer 52: 2048.0
# Computes for layer 53: 2097152.0
# Computes for layer 54: 2097152.0
# Computes for layer 55: 1572864.0
# Computes for layer 56: 524288.0
# Computes for layer 57: 512.0
# Computes for layer 58: 2048.0
# Computes for layer 59: 2097152.0
# Computes for layer 60: 2097152.0
# Computes for layer 61: 1572864.0
# Computes for layer 62: 524288.0
# Computes for layer 63: 512.0
# Computes for layer 64: 2048.0
# Computes for layer 65: 2097152.0
# Computes for layer 66: 2097152.0
# Computes for layer 67: 1572864.0
# Computes for layer 68: 524288.0
# Computes for layer 69: 512.0
# Computes for layer 70: 2048.0
# Computes for layer 71: 2097152.0
# Computes for layer 72: 2097152.0
# Computes for layer 73: 1572864.0
# Computes for layer 74: 524288.0
# Computes for layer 75: 512.0
# Computes for layer 76: 2048.0
# Computes for layer 77: 2097152.0
# Computes for layer 78: 2097152.0
# Computes for layer 79: 1572864.0
# Computes for layer 80: 524288.0
# Computes for layer 81: 512.0
# Computes for layer 82: 2048.0
# Computes for layer 83: 2097152.0
# Computes for layer 84: 2097152.0
# Computes for layer 85: 1572864.0
# Computes for layer 86: 524288.0
# Computes for layer 87: 512.0
# Computes for layer 88: 2048.0
# Computes for layer 89: 2097152.0
# Computes for layer 90: 2097152.0
# Computes for layer 91: 1572864.0
# Computes for layer 92: 524288.0
# Computes for layer 93: 512.0
# Computes for layer 94: 2048.0
# Computes for layer 95: 2097152.0
# Computes for layer 96: 2097152.0
# Computes for layer 97: 1572864.0
# Computes for layer 98: 524288.0
# Computes for layer 99: 512.0
# Computes for layer 100: 2048.0
# Computes for layer 101: 2097152.0
# Computes for layer 102: 2097152.0
# Computes for layer 103: 1572864.0
# Computes for layer 104: 524288.0
# Computes for layer 105: 512.0
# Computes for layer 106: 2048.0
# Computes for layer 107: 2097152.0
# Computes for layer 108: 2097152.0
# Computes for layer 109: 1572864.0
# Computes for layer 110: 524288.0
# Computes for layer 111: 512.0
# Computes for layer 112: 2048.0
# Computes for layer 113: 2097152.0
# Computes for layer 114: 2097152.0
# Computes for layer 115: 1572864.0
# Computes for layer 116: 524288.0
# Computes for layer 117: 512.0
# Computes for layer 118: 2048.0
# Computes for layer 119: 2097152.0
# Computes for layer 120: 2097152.0
# Computes for layer 121: 1572864.0
# Computes for layer 122: 524288.0
# Computes for layer 123: 512.0
# Computes for layer 124: 2048.0
# Computes for layer 125: 2097152.0
# Computes for layer 126: 2097152.0
# Computes for layer 127: 1572864.0
# Computes for layer 128: 524288.0
# Computes for layer 129: 512.0
# Computes for layer 130: 2048.0
# Computes for layer 131: 2097152.0
# Computes for layer 132: 2097152.0
# Computes for layer 133: 1572864.0
# Computes for layer 134: 524288.0
# Computes for layer 135: 512.0
# Computes for layer 136: 2048.0
# Computes for layer 137: 2097152.0
# Computes for layer 138: 2097152.0
# Computes for layer 139: 1572864.0
# Computes for layer 140: 524288.0
# Computes for layer 141: 512.0
# Computes for layer 142: 2048.0
# Computes for layer 143: 2097152.0
# Computes for layer 144: 2097152.0
# Computes for layer 145: 25731584.0
#
# Overall energy for DNN gpt2_medium: 1000000000000029.1 fJ
# total_per_energy[SRAM][0]: 0.49498867845044764
# total_per_energy[SRAM][1]: 0.003001527092731456
# total_per_energy[SRAM][2]: 0.5002545154552236
# total_per_energy[SRAM][3]: 0.0017552790015973338
#
#
# Running gpt2_medium with 128 x 128 RRAM with 32 nm in fast scenario
# Computes for layer 1: 1572864.0
# Computes for layer 2: 524288.0
# Computes for layer 3: 512.0
# Computes for layer 4: 2048.0
# Computes for layer 5: 2097152.0
# Computes for layer 6: 2097152.0
# Computes for layer 7: 1572864.0
# Computes for layer 8: 524288.0
# Computes for layer 9: 512.0
# Computes for layer 10: 2048.0
# Computes for layer 11: 2097152.0
# Computes for layer 12: 2097152.0
# Computes for layer 13: 1572864.0
# Computes for layer 14: 524288.0
# Computes for layer 15: 512.0
# Computes for layer 16: 2048.0
# Computes for layer 17: 2097152.0
# Computes for layer 18: 2097152.0
# Computes for layer 19: 1572864.0
# Computes for layer 20: 524288.0
# Computes for layer 21: 512.0
# Computes for layer 22: 2048.0
# Computes for layer 23: 2097152.0
# Computes for layer 24: 2097152.0
# Computes for layer 25: 1572864.0
# Computes for layer 26: 524288.0
# Computes for layer 27: 512.0
# Computes for layer 28: 2048.0
# Computes for layer 29: 2097152.0
# Computes for layer 30: 2097152.0
# Computes for layer 31: 1572864.0
# Computes for layer 32: 524288.0
# Computes for layer 33: 512.0
# Computes for layer 34: 2048.0
# Computes for layer 35: 2097152.0
# Computes for layer 36: 2097152.0
# Computes for layer 37: 1572864.0
# Computes for layer 38: 524288.0
# Computes for layer 39: 512.0
# Computes for layer 40: 2048.0
# Computes for layer 41: 2097152.0
# Computes for layer 42: 2097152.0
# Computes for layer 43: 1572864.0
# Computes for layer 44: 524288.0
# Computes for layer 45: 512.0
# Computes for layer 46: 2048.0
# Computes for layer 47: 2097152.0
# Computes for layer 48: 2097152.0
# Computes for layer 49: 1572864.0
# Computes for layer 50: 524288.0
# Computes for layer 51: 512.0
# Computes for layer 52: 2048.0
# Computes for layer 53: 2097152.0
# Computes for layer 54: 2097152.0
# Computes for layer 55: 1572864.0
# Computes for layer 56: 524288.0
# Computes for layer 57: 512.0
# Computes for layer 58: 2048.0
# Computes for layer 59: 2097152.0
# Computes for layer 60: 2097152.0
# Computes for layer 61: 1572864.0
# Computes for layer 62: 524288.0
# Computes for layer 63: 512.0
# Computes for layer 64: 2048.0
# Computes for layer 65: 2097152.0
# Computes for layer 66: 2097152.0
# Computes for layer 67: 1572864.0
# Computes for layer 68: 524288.0
# Computes for layer 69: 512.0
# Computes for layer 70: 2048.0
# Computes for layer 71: 2097152.0
# Computes for layer 72: 2097152.0
# Computes for layer 73: 1572864.0
# Computes for layer 74: 524288.0
# Computes for layer 75: 512.0
# Computes for layer 76: 2048.0
# Computes for layer 77: 2097152.0
# Computes for layer 78: 2097152.0
# Computes for layer 79: 1572864.0
# Computes for layer 80: 524288.0
# Computes for layer 81: 512.0
# Computes for layer 82: 2048.0
# Computes for layer 83: 2097152.0
# Computes for layer 84: 2097152.0
# Computes for layer 85: 1572864.0
# Computes for layer 86: 524288.0
# Computes for layer 87: 512.0
# Computes for layer 88: 2048.0
# Computes for layer 89: 2097152.0
# Computes for layer 90: 2097152.0
# Computes for layer 91: 1572864.0
# Computes for layer 92: 524288.0
# Computes for layer 93: 512.0
# Computes for layer 94: 2048.0
# Computes for layer 95: 2097152.0
# Computes for layer 96: 2097152.0
# Computes for layer 97: 1572864.0
# Computes for layer 98: 524288.0
# Computes for layer 99: 512.0
# Computes for layer 100: 2048.0
# Computes for layer 101: 2097152.0
# Computes for layer 102: 2097152.0
# Computes for layer 103: 1572864.0
# Computes for layer 104: 524288.0
# Computes for layer 105: 512.0
# Computes for layer 106: 2048.0
# Computes for layer 107: 2097152.0
# Computes for layer 108: 2097152.0
# Computes for layer 109: 1572864.0
# Computes for layer 110: 524288.0
# Computes for layer 111: 512.0
# Computes for layer 112: 2048.0
# Computes for layer 113: 2097152.0
# Computes for layer 114: 2097152.0
# Computes for layer 115: 1572864.0
# Computes for layer 116: 524288.0
# Computes for layer 117: 512.0
# Computes for layer 118: 2048.0
# Computes for layer 119: 2097152.0
# Computes for layer 120: 2097152.0
# Computes for layer 121: 1572864.0
# Computes for layer 122: 524288.0
# Computes for layer 123: 512.0
# Computes for layer 124: 2048.0
# Computes for layer 125: 2097152.0
# Computes for layer 126: 2097152.0
# Computes for layer 127: 1572864.0
# Computes for layer 128: 524288.0
# Computes for layer 129: 512.0
# Computes for layer 130: 2048.0
# Computes for layer 131: 2097152.0
# Computes for layer 132: 2097152.0
# Computes for layer 133: 1572864.0
# Computes for layer 134: 524288.0
# Computes for layer 135: 512.0
# Computes for layer 136: 2048.0
# Computes for layer 137: 2097152.0
# Computes for layer 138: 2097152.0
# Computes for layer 139: 1572864.0
# Computes for layer 140: 524288.0
# Computes for layer 141: 512.0
# Computes for layer 142: 2048.0
# Computes for layer 143: 2097152.0
# Computes for layer 144: 2097152.0
# Computes for layer 145: 25731584.0
#
# Overall energy for DNN gpt2_medium: 1000000000000035.4 fJ
# total_per_energy[RRAM][0]: 0.4703328509401236
# total_per_energy[RRAM][1]: 1.1823444283633175e-12
# total_per_energy[RRAM][2]: 0.35745296671447435
# total_per_energy[RRAM][3]: 0.17221418234421965

# %%
display_markdown(
    """
### Calculating Area in fast scenario

"""
)
total_area = [0] * 2
total_adc_area = [0] * 2
total_col_area = [0] * 2
total_row_area = [0] * 2
total_cim_unit_area = [0] * 2
total_macro = [0] * 2
energy = [0] * 2
throughput = [0] * 2
total_area[0], total_adc_area[0], total_col_area[0], total_row_area[0], total_cim_unit_area[0], total_macro[0], energy[0], throughput[0] = extract_outputs(f"SRAM_{DNN}_128_fast")
total_area[1], total_adc_area[1], total_col_area[1], total_row_area[1], total_cim_unit_area[1], total_macro[1], energy[1], throughput[1] = extract_outputs(f"RRAM_{DNN}_128_fast")
# Out:
# ### Calculating Area in fast scenario
# ../outputs/SRAM_gpt2_medium_128_fast/
# Model 	 Energy/inference (J) 	 Area (mm2) 	 Throughput (inf/s)
# Processing layer: SRAM_gpt2_medium_128_fast_layer_1
# Size: 48
# Size: 8
# All macro: 384
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 10949798.399999999
#
# Size: 48
# Size: 8
# All macro: 384
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 404985.60000000003
#
# Size: 48
# Size: 8
# All macro: 384
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 356542.464
#
# Size: 48
# Size: 8
# All macro: 384
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 2061584.3020800003
#
# Total Area for layer 1: 13772910.766079998
#
# Total Macro for layer 1: 384
#
# Total Area for all layers: 13772910.766079998
# Total Area for ADC across all layers: 10949798.399999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_2
# Size: 16
# Size: 8
# All macro: 128
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 3649932.8
#
# Size: 16
# Size: 8
# All macro: 128
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 134995.2
#
# Size: 16
# Size: 8
# All macro: 128
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 118847.488
#
# Size: 16
# Size: 8
# All macro: 128
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 687194.76736
#
# Total Area for layer 2: 4590970.25536
#
# Total Macro for layer 2: 512
#
# Total Area for all layers: 18363881.02144
# Total Area for ADC across all layers: 14599731.2
# Processing layer: SRAM_gpt2_medium_128_fast_layer_3
# Size: 2
# All macro: 2
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 57030.2
#
# Size: 2
# All macro: 2
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 2109.3
#
# Size: 2
# All macro: 2
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 1856.992
#
# Size: 2
# All macro: 2
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 10737.41824
#
# Total Area for layer 3: 71733.91024
#
# Total Macro for layer 3: 514
#
# Total Area for all layers: 18435614.931679998
# Total Area for ADC across all layers: 14656761.399999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_4
# Size: 4
# Size: 2
# All macro: 8
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 228120.8
#
# Size: 4
# Size: 2
# All macro: 8
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 8437.2
#
# Size: 4
# Size: 2
# All macro: 8
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 7427.968
#
# Size: 4
# Size: 2
# All macro: 8
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 42949.67296
#
# Total Area for layer 4: 286935.64096
#
# Total Macro for layer 4: 522
#
# Total Area for all layers: 18722550.572639998
# Total Area for ADC across all layers: 14884882.2
# Processing layer: SRAM_gpt2_medium_128_fast_layer_5
# Size: 64
# Size: 8
# All macro: 512
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 14599731.2
#
# Size: 64
# Size: 8
# All macro: 512
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 539980.8
#
# Size: 64
# Size: 8
# All macro: 512
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 475389.952
#
# Size: 64
# Size: 8
# All macro: 512
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 2748779.06944
#
# Total Area for layer 5: 18363881.02144
#
# Total Macro for layer 5: 1034
#
# Total Area for all layers: 37086431.59408
# Total Area for ADC across all layers: 29484613.4
# Processing layer: SRAM_gpt2_medium_128_fast_layer_6
# Size: 16
# Size: 32
# All macro: 512
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 14599731.2
#
# Size: 16
# Size: 32
# All macro: 512
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 539980.8
#
# Size: 16
# Size: 32
# All macro: 512
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 475389.952
#
# Size: 16
# Size: 32
# All macro: 512
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 2748779.06944
#
# Total Area for layer 6: 18363881.02144
#
# Total Macro for layer 6: 1546
#
# Total Area for all layers: 55450312.61552
# Total Area for ADC across all layers: 44084344.599999994
# Processing layer: SRAM_gpt2_medium_128_fast_layer_7
# Size: 48
# Size: 8
# All macro: 384
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 10949798.399999999
#
# Size: 48
# Size: 8
# All macro: 384
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 404985.60000000003
#
# Size: 48
# Size: 8
# All macro: 384
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 356542.464
#
# Size: 48
# Size: 8
# All macro: 384
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 2061584.3020800003
#
# Total Area for layer 7: 13772910.766079998
#
# Total Macro for layer 7: 1930
#
# Total Area for all layers: 69223223.38159999
# Total Area for ADC across all layers: 55034142.99999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_8
# Size: 16
# Size: 8
# All macro: 128
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 3649932.8
#
# Size: 16
# Size: 8
# All macro: 128
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 134995.2
#
# Size: 16
# Size: 8
# All macro: 128
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 118847.488
#
# Size: 16
# Size: 8
# All macro: 128
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 687194.76736
#
# Total Area for layer 8: 4590970.25536
#
# Total Macro for layer 8: 2058
#
# Total Area for all layers: 73814193.63696
# Total Area for ADC across all layers: 58684075.79999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_9
# Size: 2
# All macro: 2
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 57030.2
#
# Size: 2
# All macro: 2
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 2109.3
#
# Size: 2
# All macro: 2
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 1856.992
#
# Size: 2
# All macro: 2
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 10737.41824
#
# Total Area for layer 9: 71733.91024
#
# Total Macro for layer 9: 2060
#
# Total Area for all layers: 73885927.5472
# Total Area for ADC across all layers: 58741105.99999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_10
# Size: 4
# Size: 2
# All macro: 8
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 228120.8
#
# Size: 4
# Size: 2
# All macro: 8
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 8437.2
#
# Size: 4
# Size: 2
# All macro: 8
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 7427.968
#
# Size: 4
# Size: 2
# All macro: 8
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 42949.67296
#
# Total Area for layer 10: 286935.64096
#
# Total Macro for layer 10: 2068
#
# Total Area for all layers: 74172863.18815999
# Total Area for ADC across all layers: 58969226.79999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_11
# Size: 64
# Size: 8
# All macro: 512
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 14599731.2
#
# Size: 64
# Size: 8
# All macro: 512
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 539980.8
#
# Size: 64
# Size: 8
# All macro: 512
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 475389.952
#
# Size: 64
# Size: 8
# All macro: 512
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 2748779.06944
#
# Total Area for layer 11: 18363881.02144
#
# Total Macro for layer 11: 2580
#
# Total Area for all layers: 92536744.20959999
# Total Area for ADC across all layers: 73568957.99999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_12
# Size: 16
# Size: 32
# All macro: 512
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 14599731.2
#
# Size: 16
# Size: 32
# All macro: 512
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 539980.8
#
# Size: 16
# Size: 32
# All macro: 512
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 475389.952
#
# Size: 16
# Size: 32
# All macro: 512
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 2748779.06944
#
# Total Area for layer 12: 18363881.02144
#
# Total Macro for layer 12: 3092
#
# Total Area for all layers: 110900625.23103999
# Total Area for ADC across all layers: 88168689.19999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_13
# Size: 48
# Size: 8
# All macro: 384
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 10949798.399999999
#
# Size: 48
# Size: 8
# All macro: 384
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 404985.60000000003
#
# Size: 48
# Size: 8
# All macro: 384
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 356542.464
#
# Size: 48
# Size: 8
# All macro: 384
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 2061584.3020800003
#
# Total Area for layer 13: 13772910.766079998
#
# Total Macro for layer 13: 3476
#
# Total Area for all layers: 124673535.99711998
# Total Area for ADC across all layers: 99118487.6
# Processing layer: SRAM_gpt2_medium_128_fast_layer_14
# Size: 16
# Size: 8
# All macro: 128
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 3649932.8
#
# Size: 16
# Size: 8
# All macro: 128
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 134995.2
#
# Size: 16
# Size: 8
# All macro: 128
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 118847.488
#
# Size: 16
# Size: 8
# All macro: 128
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 687194.76736
#
# Total Area for layer 14: 4590970.25536
#
# Total Macro for layer 14: 3604
#
# Total Area for all layers: 129264506.25247997
# Total Area for ADC across all layers: 102768420.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_15
# Size: 2
# All macro: 2
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 57030.2
#
# Size: 2
# All macro: 2
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 2109.3
#
# Size: 2
# All macro: 2
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 1856.992
#
# Size: 2
# All macro: 2
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 10737.41824
#
# Total Area for layer 15: 71733.91024
#
# Total Macro for layer 15: 3606
#
# Total Area for all layers: 129336240.16271996
# Total Area for ADC across all layers: 102825450.6
# Processing layer: SRAM_gpt2_medium_128_fast_layer_16
# Size: 4
# Size: 2
# All macro: 8
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 228120.8
#
# Size: 4
# Size: 2
# All macro: 8
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 8437.2
#
# Size: 4
# Size: 2
# All macro: 8
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 7427.968
#
# Size: 4
# Size: 2
# All macro: 8
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 42949.67296
#
# Total Area for layer 16: 286935.64096
#
# Total Macro for layer 16: 3614
#
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_17
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_18
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_19
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_20
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_21
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_22
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_23
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_24
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_25
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_26
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_27
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_28
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_29
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_30
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_31
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_32
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_33
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_34
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_35
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_36
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_37
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_38
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_39
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_40
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_41
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_42
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_43
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_44
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_45
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_46
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_47
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_48
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_49
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_50
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_51
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_52
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_53
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_54
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_55
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_56
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_57
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_58
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_59
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_60
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_61
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_62
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_63
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_64
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_65
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_66
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_67
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_68
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_69
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_70
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_71
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_72
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_73
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_74
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_75
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_76
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_77
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_78
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_79
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_80
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_81
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_82
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_83
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_84
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_85
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_86
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_87
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_88
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_89
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_90
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_91
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_92
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_93
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_94
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_95
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_96
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_97
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_98
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_99
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_100
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_101
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_102
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_103
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_104
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_105
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_106
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_107
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_108
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_109
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_110
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_111
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_112
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_113
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_114
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_115
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_116
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_117
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_118
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_119
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_120
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_121
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_122
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_123
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_124
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_125
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_126
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_127
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_128
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_129
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_130
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_131
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_132
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_133
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_134
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_135
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_136
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_137
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_138
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_139
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_140
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_141
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_142
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_143
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_144
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_145
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Total Area for column drivers across all layers: 3811505.1
# Total Area for row drivers across all layers: 3355584.544
# Total Area for cim unit across all layers: 19402514.75968
#
#
# Total Area for ADC across all layers: 103.05357139999998
# Total Area for column driver across all layers: 3.8115050999999998
# Total Area for row driver across all layers: 3.355584544
# Total Area for cim unit across all layers: 19.40251475968
# Total Macro across all layers: 3614
# SRAM_gpt2_medium_128_fast 	 2.61e-03 	 129.62 	 3.87e+02
# ../outputs/RRAM_gpt2_medium_128_fast/
# Model 	 Energy/inference (J) 	 Area (mm2) 	 Throughput (inf/s)
# Processing layer: RRAM_gpt2_medium_128_fast_layer_1
# Size: 48
# Size: 8
# All macro: 384
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 11426227.2
#
# Size: 48
# Size: 8
# All macro: 384
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 169348.992
#
# Size: 48
# Size: 8
# All macro: 384
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 193541.76
#
# Size: 48
# Size: 8
# All macro: 384
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 257698.03776000004
#
# Total Area for layer 1: 12046815.98976
#
# Total Macro for layer 1: 384
#
# Total Area for all layers: 12046815.98976
# Total Area for ADC across all layers: 11426227.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_2
# Size: 16
# Size: 8
# All macro: 128
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 3808742.4
#
# Size: 16
# Size: 8
# All macro: 128
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 56449.664
#
# Size: 16
# Size: 8
# All macro: 128
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 64513.92
#
# Size: 16
# Size: 8
# All macro: 128
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 85899.34592
#
# Total Area for layer 2: 4015605.32992
#
# Total Macro for layer 2: 512
#
# Total Area for all layers: 16062421.31968
# Total Area for ADC across all layers: 15234969.6
# Processing layer: RRAM_gpt2_medium_128_fast_layer_3
# Size: 2
# All macro: 2
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 59511.6
#
# Size: 2
# All macro: 2
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 882.026
#
# Size: 2
# All macro: 2
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 1008.03
#
# Size: 2
# All macro: 2
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 1342.17728
#
# Total Area for layer 3: 62743.83328
#
# Total Macro for layer 3: 514
#
# Total Area for all layers: 16125165.15296
# Total Area for ADC across all layers: 15294481.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_4
# Size: 4
# Size: 2
# All macro: 8
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 238046.4
#
# Size: 4
# Size: 2
# All macro: 8
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 3528.104
#
# Size: 4
# Size: 2
# All macro: 8
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 4032.12
#
# Size: 4
# Size: 2
# All macro: 8
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 5368.70912
#
# Total Area for layer 4: 250975.33312
#
# Total Macro for layer 4: 522
#
# Total Area for all layers: 16376140.48608
# Total Area for ADC across all layers: 15532527.6
# Processing layer: RRAM_gpt2_medium_128_fast_layer_5
# Size: 64
# Size: 8
# All macro: 512
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 15234969.6
#
# Size: 64
# Size: 8
# All macro: 512
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 225798.656
#
# Size: 64
# Size: 8
# All macro: 512
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 258055.68
#
# Size: 64
# Size: 8
# All macro: 512
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 343597.38368
#
# Total Area for layer 5: 16062421.31968
#
# Total Macro for layer 5: 1034
#
# Total Area for all layers: 32438561.80576
# Total Area for ADC across all layers: 30767497.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_6
# Size: 16
# Size: 32
# All macro: 512
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 15234969.6
#
# Size: 16
# Size: 32
# All macro: 512
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 225798.656
#
# Size: 16
# Size: 32
# All macro: 512
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 258055.68
#
# Size: 16
# Size: 32
# All macro: 512
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 343597.38368
#
# Total Area for layer 6: 16062421.31968
#
# Total Macro for layer 6: 1546
#
# Total Area for all layers: 48500983.12544
# Total Area for ADC across all layers: 46002466.8
# Processing layer: RRAM_gpt2_medium_128_fast_layer_7
# Size: 48
# Size: 8
# All macro: 384
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 11426227.2
#
# Size: 48
# Size: 8
# All macro: 384
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 169348.992
#
# Size: 48
# Size: 8
# All macro: 384
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 193541.76
#
# Size: 48
# Size: 8
# All macro: 384
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 257698.03776000004
#
# Total Area for layer 7: 12046815.98976
#
# Total Macro for layer 7: 1930
#
# Total Area for all layers: 60547799.1152
# Total Area for ADC across all layers: 57428694.0
# Processing layer: RRAM_gpt2_medium_128_fast_layer_8
# Size: 16
# Size: 8
# All macro: 128
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 3808742.4
#
# Size: 16
# Size: 8
# All macro: 128
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 56449.664
#
# Size: 16
# Size: 8
# All macro: 128
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 64513.92
#
# Size: 16
# Size: 8
# All macro: 128
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 85899.34592
#
# Total Area for layer 8: 4015605.32992
#
# Total Macro for layer 8: 2058
#
# Total Area for all layers: 64563404.44512
# Total Area for ADC across all layers: 61237436.4
# Processing layer: RRAM_gpt2_medium_128_fast_layer_9
# Size: 2
# All macro: 2
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 59511.6
#
# Size: 2
# All macro: 2
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 882.026
#
# Size: 2
# All macro: 2
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 1008.03
#
# Size: 2
# All macro: 2
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 1342.17728
#
# Total Area for layer 9: 62743.83328
#
# Total Macro for layer 9: 2060
#
# Total Area for all layers: 64626148.2784
# Total Area for ADC across all layers: 61296948.0
# Processing layer: RRAM_gpt2_medium_128_fast_layer_10
# Size: 4
# Size: 2
# All macro: 8
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 238046.4
#
# Size: 4
# Size: 2
# All macro: 8
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 3528.104
#
# Size: 4
# Size: 2
# All macro: 8
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 4032.12
#
# Size: 4
# Size: 2
# All macro: 8
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 5368.70912
#
# Total Area for layer 10: 250975.33312
#
# Total Macro for layer 10: 2068
#
# Total Area for all layers: 64877123.61152
# Total Area for ADC across all layers: 61534994.4
# Processing layer: RRAM_gpt2_medium_128_fast_layer_11
# Size: 64
# Size: 8
# All macro: 512
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 15234969.6
#
# Size: 64
# Size: 8
# All macro: 512
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 225798.656
#
# Size: 64
# Size: 8
# All macro: 512
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 258055.68
#
# Size: 64
# Size: 8
# All macro: 512
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 343597.38368
#
# Total Area for layer 11: 16062421.31968
#
# Total Macro for layer 11: 2580
#
# Total Area for all layers: 80939544.9312
# Total Area for ADC across all layers: 76769964.0
# Processing layer: RRAM_gpt2_medium_128_fast_layer_12
# Size: 16
# Size: 32
# All macro: 512
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 15234969.6
#
# Size: 16
# Size: 32
# All macro: 512
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 225798.656
#
# Size: 16
# Size: 32
# All macro: 512
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 258055.68
#
# Size: 16
# Size: 32
# All macro: 512
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 343597.38368
#
# Total Area for layer 12: 16062421.31968
#
# Total Macro for layer 12: 3092
#
# Total Area for all layers: 97001966.25088
# Total Area for ADC across all layers: 92004933.6
# Processing layer: RRAM_gpt2_medium_128_fast_layer_13
# Size: 48
# Size: 8
# All macro: 384
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 11426227.2
#
# Size: 48
# Size: 8
# All macro: 384
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 169348.992
#
# Size: 48
# Size: 8
# All macro: 384
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 193541.76
#
# Size: 48
# Size: 8
# All macro: 384
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 257698.03776000004
#
# Total Area for layer 13: 12046815.98976
#
# Total Macro for layer 13: 3476
#
# Total Area for all layers: 109048782.24064
# Total Area for ADC across all layers: 103431160.8
# Processing layer: RRAM_gpt2_medium_128_fast_layer_14
# Size: 16
# Size: 8
# All macro: 128
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 3808742.4
#
# Size: 16
# Size: 8
# All macro: 128
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 56449.664
#
# Size: 16
# Size: 8
# All macro: 128
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 64513.92
#
# Size: 16
# Size: 8
# All macro: 128
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 85899.34592
#
# Total Area for layer 14: 4015605.32992
#
# Total Macro for layer 14: 3604
#
# Total Area for all layers: 113064387.57056
# Total Area for ADC across all layers: 107239903.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_15
# Size: 2
# All macro: 2
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 59511.6
#
# Size: 2
# All macro: 2
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 882.026
#
# Size: 2
# All macro: 2
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 1008.03
#
# Size: 2
# All macro: 2
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 1342.17728
#
# Total Area for layer 15: 62743.83328
#
# Total Macro for layer 15: 3606
#
# Total Area for all layers: 113127131.40383999
# Total Area for ADC across all layers: 107299414.8
# Processing layer: RRAM_gpt2_medium_128_fast_layer_16
# Size: 4
# Size: 2
# All macro: 8
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 238046.4
#
# Size: 4
# Size: 2
# All macro: 8
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 3528.104
#
# Size: 4
# Size: 2
# All macro: 8
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 4032.12
#
# Size: 4
# Size: 2
# All macro: 8
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 5368.70912
#
# Total Area for layer 16: 250975.33312
#
# Total Macro for layer 16: 3614
#
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_17
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_18
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_19
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_20
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_21
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_22
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_23
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_24
# ...
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_41
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_42
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_43
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_44
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_45
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_46
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_47
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_48
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_49
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_50
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_51
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_52
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_53
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_54
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_55
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_56
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_57
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_58
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_59
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_60
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_61
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_62
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_63
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_64
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_65
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_66
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_67
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_68
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_69
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_70
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_71
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_72
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_73
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_74
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_75
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_76
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_77
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_78
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_79
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_80
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_81
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_82
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_83
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_84
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_85
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_86
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_87
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_88
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_89
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_90
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_91
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_92
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_93
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_94
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_95
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_96
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_97
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_98
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_99
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_100
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_101
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_102
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_103
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_104
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_105
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_106
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_107
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_108
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_109
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_110
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_111
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_112
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_113
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_114
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_115
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_116
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_117
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_118
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_119
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_120
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_121
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_122
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_123
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_124
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_125
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_126
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_127
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_128
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_129
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_130
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_131
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_132
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_133
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_134
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_135
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_136
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_137
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_138
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_139
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_140
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_141
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_142
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_143
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_144
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_145
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Total Area for column drivers across all layers: 1593820.9820000003
# Total Area for row drivers across all layers: 1821510.21
# Total Area for cim unit across all layers: 2425314.34496
#
#
# Total Area for ADC across all layers: 107.5374612
# Total Area for column driver across all layers: 1.5938209820000002
# Total Area for row driver across all layers: 1.8215102099999998
# Total Area for cim unit across all layers: 2.42531434496
# Total Macro across all layers: 3614
# RRAM_gpt2_medium_128_fast 	 3.16e-03 	 113.38 	 3.87e+02

# %%
print(total_area)
print(total_adc_area)
print(total_col_area)
print(total_row_area)
print(total_cim_unit_area)
print(total_macro)
print(energy)
print(throughput)
# Out:
# [129.62317580367994, 113.37810673695999]
# [103.05357139999998, 107.5374612]
# [3.8115050999999998, 1.5938209820000002]
# [3.355584544, 1.8215102099999998]
# [19.40251475968, 2.42531434496]
# [3614, 3614]
# [0.0026079909, 0.0031604893099999995]
# [386.75742574257424, 386.75742574257424]

# %%
import matplotlib.pyplot as plt
import numpy as np
fig, ax = plt.subplots(figsize=(10, 5)) 
# array_sizes = ['32', '64', '128', '256']
path = ['SRAM', 'RRAM']

x = np.arange(len(path))

# Stack bars
ax.bar(path, total_cim_unit_area, label='cim_unit')
ax.bar(path, total_row_area, bottom=total_cim_unit_area, label='row_drivers')
ax.bar(path, total_col_area, bottom=np.array(total_cim_unit_area) + np.array(total_row_area), label='column_drivers')
ax.bar(path, total_adc_area, bottom=np.array(total_cim_unit_area) + np.array(total_row_area) + np.array(total_col_area), label='adc')

# Labels and title
ax.set_title(f"Area vs Memory Type for {DNN} in fast scenario")
ax.set_xlabel("Memory type")
ax.set_ylabel("Area (mm2)")
# Set x-ticks
ax.set_xticks(x)
ax.set_xticklabels(path)

ax.legend()

# Show plot
plt.show()

# %%
for path in path_list:
    print(f"Memory Type: {path.split('/')[-1].split('_')[0].upper()}")
    # For each component index (0 to 3)
    for i in range(4):
        print(f"total_per_energy[{path.split('/')[-1].split('_')[0].upper()}][{i}]: {total_per_energy[path][i]}")
    print()
# Out:
# Memory Type: SRAM
# total_per_energy[SRAM][0]: 0.49498867845044764
# total_per_energy[SRAM][1]: 0.003001527092731456
# total_per_energy[SRAM][2]: 0.5002545154552236
# total_per_energy[SRAM][3]: 0.0017552790015973338
#
# Memory Type: RRAM
# total_per_energy[RRAM][0]: 0.4703328509401236
# total_per_energy[RRAM][1]: 1.1823444283633175e-12
# total_per_energy[RRAM][2]: 0.35745296671447435
# total_per_energy[RRAM][3]: 0.17221418234421965

# %%
display_markdown(
    """
### Calculating the energy

"""
)

path_list = [SRAM_PATH, RRAM_PATH]
total_adc_energy = [0] * 2
total_col_energy = [0] * 2
total_row_energy = [0] * 2
total_cim_unit_energy = [0] * 2
for j in range(len(energy)):
    if j == 0:
        for i in range(4):
            if i == 0:
                total_adc_energy[j] = total_per_energy[path_list[0]][i] * energy[j]
            elif i == 1:
                total_col_energy[j] = total_per_energy[path_list[0]][i] * energy[j]
            elif i == 2:
                total_row_energy[j] = total_per_energy[path_list[0]][i] * energy[j]
            else:
                total_cim_unit_energy[j] = total_per_energy[path_list[0]][i] * energy[j]
    else:
        for i in range(4):
            if i == 0:
                total_adc_energy[j] = total_per_energy[path_list[1]][i] * energy[j]
            elif i == 1:
                total_col_energy[j] = total_per_energy[path_list[1]][i] * energy[j]
            elif i == 2:
                total_row_energy[j] = total_per_energy[path_list[1]][i] * energy[j]
            else:
                total_cim_unit_energy[j] = total_per_energy[path_list[1]][i] * energy[j]

    
print("Total ADC Energy:", total_adc_energy)
print("Total Column Energy:", total_col_energy)
print("Total Row Energy:", total_row_energy)
print("Total CIM Unit Energy:", total_cim_unit_energy)
# Out:
# ### Calculating the energy
# Total ADC Energy: [0.0012909259690017936, 0.0014864819475380838]
# Total Column Energy: [7.827955343947094e-06, 3.736786926580325e-15]
# Total Row Energy: [0.0013046592239911324, 0.0011297262801288818]
# Total CIM Unit Energy: [4.577751663126932e-06, 0.0005442810823292969]

# %%
import matplotlib.pyplot as plt
import numpy as np
fig, ax = plt.subplots(figsize=(10, 5)) 
path = ['SRAM', 'RRAM']

# x = np.arange(len(array_sizes))

# Stack bars
ax.bar(path, total_cim_unit_energy, label='cim_unit')
ax.bar(path, total_row_energy, bottom=total_cim_unit_energy, label='row_drivers')
ax.bar(path, total_col_energy, bottom=np.array(total_cim_unit_energy) + np.array(total_row_energy), label='column_drivers')
ax.bar(path, total_adc_energy, bottom=np.array(total_cim_unit_energy) + np.array(total_row_energy) + np.array(total_col_energy), label='adc')

# Labels and title
ax.set_title(f"Energy vs Memory Type for {DNN} in fast scenario")
ax.set_xlabel("Memory type")
ax.set_ylabel("Energy (J)")
# Set x-ticks
ax.set_xticks(x)
ax.set_xticklabels(path)

ax.legend()

# Show plot
plt.show()

# %%
display_markdown(
    """
### Plot the Throughput

"""
)
import matplotlib.pyplot as plt

# Data
path = ['SRAM', 'RRAM']
x = np.arange(len(path))
# Plotting the line graph
plt.figure(figsize=(10, 6))
plt.plot(path, throughput, marker='o', linestyle='-', color='b')

# Adding labels and title
plt.xlabel('Memory type')
plt.ylabel('Throughput')
plt.title(f'Throughput vs Memory Type for {DNN}')
plt.grid(False)
plt.xticks(x, path) 
# Show plot
plt.show()
# Out:
# ### Plot the Throughput

# %%
display_markdown(
    """
### Plot the Number of Macros

"""
)
import matplotlib.pyplot as plt

# Data
path = ['SRAM', 'RRAM']
x = np.arange(len(path))
# Plotting the line graph
plt.figure(figsize=(10, 6))
plt.plot(path, total_macro, marker='o', linestyle='-', color='b')

# Adding labels and title
plt.xlabel('Memory type')
plt.ylabel('Number of Macros')
plt.title(f'Number of Macros vs Memory Type for {DNN}')
plt.grid(False)
plt.xticks(x, path) 
# Show plot
plt.show()
# Out:
# ### Plot the Number of Macros
