# %%
from _import_scripts import scripts
from scripts.notebook_utils import *
from scripts.tl_output_parsing import MacroOutputStats
from scripts.utils import *
import yaml

def create_layer_directory(base_output_dir: str, architecture: str, layer: int) -> str:
    layer_dir = os.path.join(base_output_dir, f"{architecture}_layer_{layer}")
    if not os.path.exists(layer_dir):
        os.makedirs(layer_dir)
    return layer_dir

num_layers = 1

def run_map(
    spec: tl.Specification,
    arch: str,
    accelergy_verbose: bool = False,
) -> dict:
    output_dir = get_run_dir()
    # Just use the directory name if it causes error
    base_output_dir = os.path.dirname(output_dir)
    base_output_dir = os.path.join(base_output_dir, arch)
    global num_layers

    mapper_result = None

    if num_layers < 410:
        # Create a directory for the current layer
        layer_dir = create_layer_directory(base_output_dir, arch, num_layers)
        # print(f"Layer directory: {layer_dir}")
        num_layers += 1

        run_prefix = f"{layer_dir}/timeloop-mapper"
        mapper_result = tl.call_mapper(
            specification=spec,
            output_dir=layer_dir,
            log_to=os.path.join(output_dir, f"{run_prefix}.log"),
        )
        if accelergy_verbose:
            tl.call_accelergy_verbose(
                specification=spec,
                output_dir=layer_dir,
                log_to=os.path.join(output_dir, "accelergy.log"),
            )

    if mapper_result is None:
        # Handle case when mapper_result is not assigned (num_layers >= 17)
        # Raise an error, return a default value
        print("Warning: mapper_result is not assigned. num_layers >= 17")
        return {}

    return MacroOutputStats.from_output_stats(mapper_result)

import re

def extract_range(line):
    match = re.search(r'\[(\d+):(\d+)(,\d+)?\)', line)
    if match:
        start = int(match.group(1))
        end = int(match.group(2))
        return end - start
    return None

def read_and_compute_multiplication(filename, i):
    filename = f"../outputs/{filename}/{filename}_layer_{i+1}/timeloop-mapper.map.txt"
    with open(filename, 'r') as file:
        lines = file.readlines()

    start_searching = False
    ranges = []

    for line in lines:
        # Start searching when 'inter_macro_in_system_spatial' is found
        if "inter_macro_in_system_spatial" in line:
            start_searching = True
        
        # Stop searching if we leave the 'inter_macro_in_system_spatial' section
        elif start_searching and "inter_" in line and "inter_macro_in_system_spatial" not in line:
            break

        # If we are in the 'inter_macro_in_system_spatial' section, look for the ranges
        if start_searching:
            if "for" in line:
                range_size = extract_range(line)
                if range_size is not None:
                    ranges.append(range_size)
            elif line.strip() == "":  # Exit the section on an empty line
                break

    # Compute the multiplication of all ranges, or return 1 if no ranges were found
    if not ranges:
        print(f"All macro: 1")
        return 1

    result = 1
    for size in ranges:
        result *= size
        print(f"Size: {size}")
    print(f"All macro: {result}")
    return result


def extract_layer_number(folder_name):
    match = re.search(r'layer_(\d+)', folder_name)
    return int(match.group(1)) if match else float('inf')

def extract_outputs(model):
    
    output_dir = "../outputs/" + model + "/" 
    print(output_dir)

    print ("Model \t Energy/inference (J) \t Area (mm2) \t Throughput (inf/s)")
    #for model in models:    
    throughput = 0   
    energy = 0
    area = 0
    cycles = 0
    folders = sorted([folder for folder in os.listdir(output_dir) if model in folder], key=extract_layer_number)
    area_per_many_macro = 0
    area_layer = 0
    j = 0
    total_sum = 0
    total_adc_area = 0  # Total area for ADC across all layers
    total_other_areas = {}  # Dictionary to store total areas for other components
    total_col_area = 0
    total_row_area = 0
    total_cim_unit_area = 0
    total_area = 0
    total_macro = 0
    
    for folder in folders:
        total = 0
        if model in folder:
            print(f"Processing layer: {folder}")
            # print(folder)
            if os.path.isdir(output_dir + folder):
                stat_file = output_dir + folder + "/timeloop-mapper.stats.txt"
                art_file = output_dir + folder + "/timeloop-mapper.ART.yaml"
        
                with open(stat_file, 'r') as f:
                    energy_stat = [line for line in f if line.startswith("Energy:")][0]
                    energy_uj = energy_stat.split(' ')[1] # uJ
                    energy += float(energy_uj)
                    # print(f"Energy for this layer: {float(energy_uj)} uj")
                
                with open(stat_file, 'r') as f:
                    cycle_stat = [line for line in f if line.startswith("Cycles:")][0]                  
                    cycle = cycle_stat.split(' ')[1] 
                    cycles += float(cycle)
                    
            if j < 16:
                with open(art_file, 'r') as file:
                    data = yaml.safe_load(file)
                
                    # Extract and print the name, area, number of entries, and ratio for non-zero areas
                for table in data['ART']['tables']:
                    name = table.get('name')
                    area = table.get('area')
                    if area != 0:
                        # Simplify the name for the output
                        if 'system_top_level.' in name:
                            name = name.split('system_top_level.')[-1]
                        
                        # Extract the number of entries from the name
                        if '[' in name:
                            name_part, entries_part = name.split('[')
                            number_of_entries = entries_part.split('..')[1].replace(']', '')
                            name = name_part.strip()
                        else:
                            number_of_entries = 'Unknown'
                        
                        macro = read_and_compute_multiplication(model, j)
                        # Calculate total ratio
                        if number_of_entries != 'Unknown' and number_of_entries.isdigit():
                            total_ratio = (area / 4096) * macro * int(number_of_entries)
                        else:
                            total_ratio = 0
                        
                        total += total_ratio
                           
                        # Accumulate area for ADC or other components
                        if 'adc' in name.lower():
                            total_adc_area += total_ratio
                        else:
                            if name not in total_other_areas:
                                total_other_areas[name] = 0
                            total_other_areas[name] += total_ratio
            
                        print(f"{name.replace('_', ' ')} area: {area}, number of {name}: {number_of_entries}, \ntotal {name.replace('_', ' ')} area: ({area}*{number_of_entries}/4096) * macro = {total_ratio}\n")
                j += 1 
                total_sum += total
                total_macro += macro
                print(f"Total Area for layer {j}: {total}\n")
                print(f"Total Macro for layer {j}: {total_macro}\n")
            print(f"Total Area for all layers: {total_sum}")
            print(f"Total Area for ADC across all layers: {total_adc_area}")
    
    # Print total area for other components
    for component, area in total_other_areas.items():
        print(f"Total Area for {component.replace('_', ' ')} across all layers: {area}")
        # print(component.replace('_', ' '))
        if component.replace('_', ' ') ==  "column drivers":
            total_col_area = area
        elif component.replace('_', ' ') ==  "row drivers":
            total_row_area = area
        else:
            total_cim_unit_area = area
                                
    energy *= 1e-6 # conver to J
    total_area = total_sum * 1e-6 # mm2
    throughput = 1 / (cycles * 1e-7) # s

    total_adc_area = total_adc_area * 1e-6 # mm2
    total_col_area = total_col_area * 1e-6 # mm2
    total_row_area = total_row_area * 1e-6 # mm2
    total_cim_unit_area = total_cim_unit_area * 1e-6 # mm2
    print("\n")
    print(f"Total Area for ADC across all layers: {total_adc_area}")
    print(f"Total Area for column driver across all layers: {total_col_area}")
    print(f"Total Area for row driver across all layers: {total_row_area}")
    print(f"Total Area for cim unit across all layers: {total_cim_unit_area}")
    print(f"Total Macro across all layers: {total_macro}")
    print ("{} \t {:.2e} \t {:.2f} \t {:.2e}".format(model, energy, total_area, throughput))
    
    return total_area, total_adc_area, total_col_area, total_row_area, total_cim_unit_area, total_macro, energy, throughput

# %%
MACRO_PATH = "../models/arch/1_macro/basic_analog/" 
macro = {}
SRAM_PATH = f'"{os.path.abspath("../models/memory_cells/sram_example.cell.yaml")}"'
RRAM_PATH = f'"{os.path.abspath("../models/memory_cells/rram_example.cell.yaml")}"'

# Define the architecture
array_sizes = 128
path_list = [SRAM_PATH, RRAM_PATH]
tech_node = 32
# adc_resolution = 6
DNN = "mobilebert"
time = "fast"

total_per_energy = {}

for path in path_list:
    arch = f"{path.split('/')[-1].split('_')[0].upper()}_{DNN}_{array_sizes}_{time}"
    print(f"\nRunning {DNN} with {array_sizes} x {array_sizes} {path.split('/')[-1].split('_')[0].upper()} with {tech_node} nm in {time} scenario")

    num_layers = 1

    def run_dnn(dnn: str, layer: str, array_sizes: int, variables):
        print(f"{layer} ", end="", flush=True)
        spec = get_spec(
            "basic_analog",
            # Weight-stationary, dummy buffer on top to hold inputs & outputs, many
            # macros to ensure we can fit all weights.
            system="ws_dummy_buffer_many_macro",
            # Set the DNN and layer
            dnn=dnn,
            layer=layer,
        )
    
        # Do NOT generate a maximum-utilization workload; we're running a DNN
        # workload.
        spec.variables["MAX_UTILIZATION"] = False
    
        # Use a larger array to ensure we can fit all weights
        spec.architecture.find("column").spatial.meshX = array_sizes
        spec.architecture.find("row").spatial.meshY = array_sizes
    
        spec.variables.update(variables)
        output_stats = run_map(spec, arch)
        
        # Print computes for the layer
        macro_output_stats = MacroOutputStats.from_output_stats(output_stats)
        print(f"Computes for layer {int(layer) + 1}: {macro_output_stats.computes}")
        global macro
        macro[layer] = macro_output_stats.computes
        return output_stats
    
    layers = [f for f in os.listdir(f"../models/workloads/{DNN}") if f != "index.yaml" and f.endswith(".yaml")]
    layers = sorted(layers)
    print(f"Running: ", end="")
    
    # Parallel/Delayed is used to multiprocess. Equivalent to running the following
    # code in serial:
    results = joblib.Parallel(n_jobs=None)(
        joblib.delayed(run_dnn)(DNN, layer.split(".")[0], array_sizes, 
                                  {
                                      "CELL_CONFIG": path,
                                      "BITS_PER_CELL": 1 if path == SRAM_PATH else 4,
                                      "CIM_UNIT_WIDTH_CELLS": 4 if path == SRAM_PATH else 1,
                                      "IS_SRAM": path == SRAM_PATH,
                                      "TECHNOLOGY": tech_node,
                                      "ADC_RESOLUTION": 4 if path == SRAM_PATH else 6,
                                      "GLOBAL_CYCLE_SECONDS": 1e-7 if time == "fast" else 1e-4,
                                  }
                                 ) for layer in layers
    )
    print("")
    for r in results:
        r.clear_zero_energies()
    
    #Initialize overall_energy
    energy_layer = [0] * 16
    result = 0
    
    # total_per_energy_32 = [0] * 4
    
    total_adc_energy = 0.0
    total_col_energy = 0.0
    total_row_energy = 0.0
    total_cim_unit_energy = 0.0
    # Calculate overall energy
    for r in results:
    
        per_component_energy = r.per_compute("per_component_energy")
        total_energy_per_layer = sum(per_component_energy.values()) * 1e15  # Convert to fJ
        total_adc_energy += per_component_energy.get('adc', 0.0)
        total_col_energy += per_component_energy.get('column_drivers', 0.0)
        total_row_energy += per_component_energy.get('row_drivers', 0.0)
        total_cim_unit_energy += per_component_energy.get('cim_unit', 0.0)
    
        total_adc_energy = total_adc_energy * 1e15
        total_col_energy = total_col_energy * 1e15
        total_row_energy = total_row_energy * 1e15
        total_cim_unit_energy = total_cim_unit_energy * 1e15
        total_energy = total_adc_energy + total_col_energy + total_row_energy + total_cim_unit_energy
    
        total_adc_energy = total_adc_energy/total_energy
        total_col_energy = total_col_energy/total_energy
        total_row_energy = total_row_energy/total_energy
        total_cim_unit_energy = total_cim_unit_energy/total_energy

        total_per_energy[path] = [total_adc_energy, total_col_energy, total_row_energy, total_cim_unit_energy]
        
    # Display overall energy
    print(f"Overall energy for DNN {DNN}: {total_energy} fJ")

    for i in range(4):
        print(f"total_per_energy[{path.split('/')[-1].split('_')[0].upper()}][{i}]: {total_per_energy[path][i]}")
    print() 
    
    # Display an energy breakdown for each layer as a bar chart. Display normalized per-MAC and per-layer energy.
    fig, ax = plt.subplots(figsize=(20, 5))
    
    bar_stacked(
        {i: r.per_compute("per_component_energy") * 1e15 for i, r in enumerate(results)},
        title= f"Using {path.split('/')[-1].split('_')[0].upper()} on {array_sizes} x {array_sizes} array sizes, {tech_node} nm",
        xlabel="Layer",
        ylabel="Energy (fJ/MAC)",
        ax=ax,
    )
# Out:
# Running mobilebert with 128 x 128 SRAM with 32 nm in fast scenario
# Computes for layer 1: 53376.0
# Computes for layer 2: 17792.0
# Computes for layer 3: 17792.0
# Computes for layer 4: 4448.0
# Computes for layer 5: 4448.0
# Computes for layer 6: 17792.0
# Computes for layer 7: 34.75
# Computes for layer 8: 150.9453125
# Computes for layer 9: 4448.0
# Computes for layer 10: 17792.0
# Computes for layer 11: 17792.0
# Computes for layer 12: 17792.0
# Computes for layer 13: 17792.0
# Computes for layer 14: 17792.0
# Computes for layer 15: 17792.0
# Computes for layer 16: 17792.0
# Computes for layer 17: 17792.0
# Computes for layer 18: 17792.0
# Computes for layer 19: 17792.0
# Computes for layer 20: 17792.0
# Computes for layer 21: 4448.0
# Computes for layer 22: 4448.0
# Computes for layer 23: 17792.0
# Computes for layer 24: 34.75
# Computes for layer 25: 150.9453125
# Computes for layer 26: 4448.0
# Computes for layer 27: 17792.0
# Computes for layer 28: 17792.0
# Computes for layer 29: 17792.0
# Computes for layer 30: 17792.0
# Computes for layer 31: 17792.0
# Computes for layer 32: 17792.0
# Computes for layer 33: 17792.0
# Computes for layer 34: 17792.0
# Computes for layer 35: 17792.0
# Computes for layer 36: 17792.0
# Computes for layer 37: 17792.0
# Computes for layer 38: 4448.0
# Computes for layer 39: 4448.0
# Computes for layer 40: 17792.0
# Computes for layer 41: 34.75
# Computes for layer 42: 150.9453125
# Computes for layer 43: 4448.0
# Computes for layer 44: 17792.0
# Computes for layer 45: 17792.0
# Computes for layer 46: 17792.0
# Computes for layer 47: 17792.0
# Computes for layer 48: 17792.0
# Computes for layer 49: 17792.0
# Computes for layer 50: 17792.0
# Computes for layer 51: 17792.0
# Computes for layer 52: 17792.0
# Computes for layer 53: 17792.0
# Computes for layer 54: 17792.0
# Computes for layer 55: 4448.0
# Computes for layer 56: 4448.0
# Computes for layer 57: 17792.0
# Computes for layer 58: 34.75
# Computes for layer 59: 150.9453125
# Computes for layer 60: 4448.0
# Computes for layer 61: 17792.0
# Computes for layer 62: 17792.0
# Computes for layer 63: 17792.0
# Computes for layer 64: 17792.0
# Computes for layer 65: 17792.0
# Computes for layer 66: 17792.0
# Computes for layer 67: 17792.0
# Computes for layer 68: 17792.0
# Computes for layer 69: 17792.0
# Computes for layer 70: 17792.0
# Computes for layer 71: 17792.0
# Computes for layer 72: 4448.0
# Computes for layer 73: 4448.0
# Computes for layer 74: 17792.0
# Computes for layer 75: 34.75
# Computes for layer 76: 150.9453125
# Computes for layer 77: 4448.0
# Computes for layer 78: 17792.0
# Computes for layer 79: 17792.0
# Computes for layer 80: 17792.0
# Computes for layer 81: 17792.0
# Computes for layer 82: 17792.0
# Computes for layer 83: 17792.0
# Computes for layer 84: 17792.0
# Computes for layer 85: 17792.0
# Computes for layer 86: 17792.0
# Computes for layer 87: 17792.0
# Computes for layer 88: 17792.0
# Computes for layer 89: 4448.0
# Computes for layer 90: 4448.0
# Computes for layer 91: 17792.0
# Computes for layer 92: 34.75
# Computes for layer 93: 150.9453125
# Computes for layer 94: 4448.0
# Computes for layer 95: 17792.0
# Computes for layer 96: 17792.0
# Computes for layer 97: 17792.0
# Computes for layer 98: 17792.0
# Computes for layer 99: 17792.0
# Computes for layer 100: 17792.0
# Computes for layer 101: 17792.0
# Computes for layer 102: 17792.0
# Computes for layer 103: 17792.0
# Computes for layer 104: 17792.0
# Computes for layer 105: 17792.0
# Computes for layer 106: 4448.0
# Computes for layer 107: 4448.0
# Computes for layer 108: 17792.0
# Computes for layer 109: 34.75
# Computes for layer 110: 150.9453125
# Computes for layer 111: 4448.0
# Computes for layer 112: 17792.0
# Computes for layer 113: 17792.0
# Computes for layer 114: 17792.0
# Computes for layer 115: 17792.0
# Computes for layer 116: 17792.0
# Computes for layer 117: 17792.0
# Computes for layer 118: 17792.0
# Computes for layer 119: 17792.0
# Computes for layer 120: 17792.0
# Computes for layer 121: 17792.0
# Computes for layer 122: 17792.0
# Computes for layer 123: 4448.0
# Computes for layer 124: 4448.0
# Computes for layer 125: 17792.0
# Computes for layer 126: 34.75
# Computes for layer 127: 150.9453125
# Computes for layer 128: 4448.0
# Computes for layer 129: 17792.0
# Computes for layer 130: 17792.0
# Computes for layer 131: 17792.0
# Computes for layer 132: 17792.0
# Computes for layer 133: 17792.0
# Computes for layer 134: 17792.0
# Computes for layer 135: 17792.0
# Computes for layer 136: 17792.0
# Computes for layer 137: 17792.0
# Computes for layer 138: 17792.0
# Computes for layer 139: 17792.0
# Computes for layer 140: 4448.0
# Computes for layer 141: 4448.0
# Computes for layer 142: 17792.0
# Computes for layer 143: 34.75
# Computes for layer 144: 150.9453125
# Computes for layer 145: 4448.0
# Computes for layer 146: 17792.0
# Computes for layer 147: 17792.0
# Computes for layer 148: 17792.0
# Computes for layer 149: 17792.0
# Computes for layer 150: 17792.0
# Computes for layer 151: 17792.0
# Computes for layer 152: 17792.0
# Computes for layer 153: 17792.0
# Computes for layer 154: 17792.0
# Computes for layer 155: 17792.0
# Computes for layer 156: 17792.0
# Computes for layer 157: 4448.0
# Computes for layer 158: 4448.0
# Computes for layer 159: 17792.0
# Computes for layer 160: 34.75
# Computes for layer 161: 150.9453125
# Computes for layer 162: 4448.0
# Computes for layer 163: 17792.0
# Computes for layer 164: 17792.0
# Computes for layer 165: 17792.0
# Computes for layer 166: 17792.0
# Computes for layer 167: 17792.0
# Computes for layer 168: 17792.0
# Computes for layer 169: 17792.0
# Computes for layer 170: 17792.0
# Computes for layer 171: 17792.0
# Computes for layer 172: 17792.0
# Computes for layer 173: 17792.0
# Computes for layer 174: 4448.0
# Computes for layer 175: 4448.0
# Computes for layer 176: 17792.0
# Computes for layer 177: 34.75
# Computes for layer 178: 150.9453125
# Computes for layer 179: 4448.0
# Computes for layer 180: 17792.0
# Computes for layer 181: 17792.0
# Computes for layer 182: 17792.0
# Computes for layer 183: 17792.0
# Computes for layer 184: 17792.0
# Computes for layer 185: 17792.0
# Computes for layer 186: 17792.0
# Computes for layer 187: 17792.0
# Computes for layer 188: 17792.0
# Computes for layer 189: 17792.0
# Computes for layer 190: 17792.0
# Computes for layer 191: 4448.0
# Computes for layer 192: 4448.0
# Computes for layer 193: 17792.0
# Computes for layer 194: 34.75
# Computes for layer 195: 150.9453125
# Computes for layer 196: 4448.0
# Computes for layer 197: 17792.0
# Computes for layer 198: 17792.0
# Computes for layer 199: 17792.0
# Computes for layer 200: 17792.0
# Computes for layer 201: 17792.0
# Computes for layer 202: 17792.0
# Computes for layer 203: 17792.0
# Computes for layer 204: 17792.0
# Computes for layer 205: 17792.0
# Computes for layer 206: 17792.0
# Computes for layer 207: 17792.0
# Computes for layer 208: 4448.0
# Computes for layer 209: 4448.0
# Computes for layer 210: 17792.0
# Computes for layer 211: 34.75
# Computes for layer 212: 150.9453125
# Computes for layer 213: 4448.0
# Computes for layer 214: 17792.0
# Computes for layer 215: 17792.0
# Computes for layer 216: 17792.0
# Computes for layer 217: 17792.0
# Computes for layer 218: 17792.0
# Computes for layer 219: 17792.0
# Computes for layer 220: 17792.0
# Computes for layer 221: 17792.0
# Computes for layer 222: 17792.0
# Computes for layer 223: 17792.0
# Computes for layer 224: 17792.0
# Computes for layer 225: 4448.0
# Computes for layer 226: 4448.0
# Computes for layer 227: 17792.0
# Computes for layer 228: 34.75
# Computes for layer 229: 150.9453125
# Computes for layer 230: 4448.0
# Computes for layer 231: 17792.0
# Computes for layer 232: 17792.0
# Computes for layer 233: 17792.0
# Computes for layer 234: 17792.0
# Computes for layer 235: 17792.0
# Computes for layer 236: 17792.0
# Computes for layer 237: 17792.0
# Computes for layer 238: 17792.0
# Computes for layer 239: 17792.0
# Computes for layer 240: 17792.0
# Computes for layer 241: 17792.0
# Computes for layer 242: 4448.0
# Computes for layer 243: 4448.0
# Computes for layer 244: 17792.0
# Computes for layer 245: 34.75
# Computes for layer 246: 150.9453125
# Computes for layer 247: 4448.0
# Computes for layer 248: 17792.0
# Computes for layer 249: 17792.0
# Computes for layer 250: 17792.0
# Computes for layer 251: 17792.0
# Computes for layer 252: 17792.0
# Computes for layer 253: 17792.0
# Computes for layer 254: 17792.0
# Computes for layer 255: 17792.0
# Computes for layer 256: 17792.0
# Computes for layer 257: 17792.0
# Computes for layer 258: 17792.0
# Computes for layer 259: 4448.0
# Computes for layer 260: 4448.0
# Computes for layer 261: 17792.0
# Computes for layer 262: 34.75
# Computes for layer 263: 150.9453125
# Computes for layer 264: 4448.0
# Computes for layer 265: 17792.0
# Computes for layer 266: 17792.0
# Computes for layer 267: 17792.0
# Computes for layer 268: 17792.0
# Computes for layer 269: 17792.0
# Computes for layer 270: 17792.0
# Computes for layer 271: 17792.0
# Computes for layer 272: 17792.0
# Computes for layer 273: 17792.0
# Computes for layer 274: 17792.0
# Computes for layer 275: 17792.0
# Computes for layer 276: 4448.0
# Computes for layer 277: 4448.0
# Computes for layer 278: 17792.0
# Computes for layer 279: 34.75
# Computes for layer 280: 150.9453125
# Computes for layer 281: 4448.0
# Computes for layer 282: 17792.0
# Computes for layer 283: 17792.0
# Computes for layer 284: 17792.0
# Computes for layer 285: 17792.0
# Computes for layer 286: 17792.0
# Computes for layer 287: 17792.0
# Computes for layer 288: 17792.0
# Computes for layer 289: 17792.0
# Computes for layer 290: 17792.0
# Computes for layer 291: 17792.0
# Computes for layer 292: 17792.0
# Computes for layer 293: 4448.0
# Computes for layer 294: 4448.0
# Computes for layer 295: 17792.0
# Computes for layer 296: 34.75
# Computes for layer 297: 150.9453125
# Computes for layer 298: 4448.0
# Computes for layer 299: 17792.0
# Computes for layer 300: 17792.0
# Computes for layer 301: 17792.0
# Computes for layer 302: 17792.0
# Computes for layer 303: 17792.0
# Computes for layer 304: 17792.0
# Computes for layer 305: 17792.0
# Computes for layer 306: 17792.0
# Computes for layer 307: 17792.0
# Computes for layer 308: 17792.0
# Computes for layer 309: 17792.0
# Computes for layer 310: 4448.0
# Computes for layer 311: 4448.0
# Computes for layer 312: 17792.0
# Computes for layer 313: 34.75
# Computes for layer 314: 150.9453125
# Computes for layer 315: 4448.0
# Computes for layer 316: 17792.0
# Computes for layer 317: 17792.0
# Computes for layer 318: 17792.0
# Computes for layer 319: 17792.0
# Computes for layer 320: 17792.0
# Computes for layer 321: 17792.0
# Computes for layer 322: 17792.0
# Computes for layer 323: 17792.0
# Computes for layer 324: 17792.0
# Computes for layer 325: 17792.0
# Computes for layer 326: 17792.0
# Computes for layer 327: 4448.0
# Computes for layer 328: 4448.0
# Computes for layer 329: 17792.0
# Computes for layer 330: 34.75
# Computes for layer 331: 150.9453125
# Computes for layer 332: 4448.0
# Computes for layer 333: 17792.0
# Computes for layer 334: 17792.0
# Computes for layer 335: 17792.0
# Computes for layer 336: 17792.0
# Computes for layer 337: 17792.0
# Computes for layer 338: 17792.0
# Computes for layer 339: 17792.0
# Computes for layer 340: 17792.0
# Computes for layer 341: 17792.0
# Computes for layer 342: 17792.0
# Computes for layer 343: 17792.0
# Computes for layer 344: 4448.0
# Computes for layer 345: 4448.0
# Computes for layer 346: 17792.0
# Computes for layer 347: 34.75
# Computes for layer 348: 150.9453125
# Computes for layer 349: 4448.0
# Computes for layer 350: 17792.0
# Computes for layer 351: 17792.0
# Computes for layer 352: 17792.0
# Computes for layer 353: 17792.0
# Computes for layer 354: 17792.0
# Computes for layer 355: 17792.0
# Computes for layer 356: 17792.0
# Computes for layer 357: 17792.0
# Computes for layer 358: 17792.0
# Computes for layer 359: 17792.0
# Computes for layer 360: 17792.0
# Computes for layer 361: 4448.0
# Computes for layer 362: 4448.0
# Computes for layer 363: 17792.0
# Computes for layer 364: 34.75
# Computes for layer 365: 150.9453125
# Computes for layer 366: 4448.0
# Computes for layer 367: 17792.0
# Computes for layer 368: 17792.0
# Computes for layer 369: 17792.0
# Computes for layer 370: 17792.0
# Computes for layer 371: 17792.0
# Computes for layer 372: 17792.0
# Computes for layer 373: 17792.0
# Computes for layer 374: 17792.0
# Computes for layer 375: 17792.0
# Computes for layer 376: 17792.0
# Computes for layer 377: 17792.0
# Computes for layer 378: 4448.0
# Computes for layer 379: 4448.0
# Computes for layer 380: 17792.0
# Computes for layer 381: 34.75
# Computes for layer 382: 150.9453125
# Computes for layer 383: 4448.0
# Computes for layer 384: 17792.0
# Computes for layer 385: 17792.0
# Computes for layer 386: 17792.0
# Computes for layer 387: 17792.0
# Computes for layer 388: 17792.0
# Computes for layer 389: 17792.0
# Computes for layer 390: 17792.0
# Computes for layer 391: 17792.0
# Computes for layer 392: 17792.0
# Computes for layer 393: 17792.0
# Computes for layer 394: 17792.0
# Computes for layer 395: 4448.0
# Computes for layer 396: 4448.0
# Computes for layer 397: 17792.0
# Computes for layer 398: 34.75
# Computes for layer 399: 150.9453125
# Computes for layer 400: 4448.0
# Computes for layer 401: 17792.0
# Computes for layer 402: 17792.0
# Computes for layer 403: 17792.0
# Computes for layer 404: 17792.0
# Computes for layer 405: 17792.0
# Computes for layer 406: 17792.0
# Computes for layer 407: 17792.0
# Computes for layer 408: 17792.0
# Computes for layer 409: 17792.0
#
# Overall energy for DNN mobilebert: 1000000000000029.5 fJ
# total_per_energy[SRAM][0]: 0.4915375363859875
# total_per_energy[SRAM][1]: 0.0029805999546810053
# total_per_energy[SRAM][2]: 0.5037388227501635
# total_per_energy[SRAM][3]: 0.0017430409091680585
#
#
# Running mobilebert with 128 x 128 RRAM with 32 nm in fast scenario
# Computes for layer 1: 53376.0
# Computes for layer 2: 17792.0
# Computes for layer 3: 17792.0
# Computes for layer 4: 4448.0
# Computes for layer 5: 4448.0
# Computes for layer 6: 17792.0
# Computes for layer 7: 34.75
# Computes for layer 8: 150.9453125
# Computes for layer 9: 4448.0
# Computes for layer 10: 17792.0
# Computes for layer 11: 17792.0
# Computes for layer 12: 17792.0
# Computes for layer 13: 17792.0
# Computes for layer 14: 17792.0
# Computes for layer 15: 17792.0
# Computes for layer 16: 17792.0
# Computes for layer 17: 17792.0
# Computes for layer 18: 17792.0
# Computes for layer 19: 17792.0
# Computes for layer 20: 17792.0
# Computes for layer 21: 4448.0
# Computes for layer 22: 4448.0
# Computes for layer 23: 17792.0
# Computes for layer 24: 34.75
# Computes for layer 25: 150.9453125
# Computes for layer 26: 4448.0
# Computes for layer 27: 17792.0
# Computes for layer 28: 17792.0
# Computes for layer 29: 17792.0
# Computes for layer 30: 17792.0
# Computes for layer 31: 17792.0
# Computes for layer 32: 17792.0
# Computes for layer 33: 17792.0
# Computes for layer 34: 17792.0
# Computes for layer 35: 17792.0
# Computes for layer 36: 17792.0
# Computes for layer 37: 17792.0
# Computes for layer 38: 4448.0
# Computes for layer 39: 4448.0
# Computes for layer 40: 17792.0
# Computes for layer 41: 34.75
# Computes for layer 42: 150.9453125
# Computes for layer 43: 4448.0
# Computes for layer 44: 17792.0
# Computes for layer 45: 17792.0
# Computes for layer 46: 17792.0
# Computes for layer 47: 17792.0
# Computes for layer 48: 17792.0
# Computes for layer 49: 17792.0
# Computes for layer 50: 17792.0
# Computes for layer 51: 17792.0
# Computes for layer 52: 17792.0
# Computes for layer 53: 17792.0
# Computes for layer 54: 17792.0
# Computes for layer 55: 4448.0
# Computes for layer 56: 4448.0
# Computes for layer 57: 17792.0
# Computes for layer 58: 34.75
# Computes for layer 59: 150.9453125
# Computes for layer 60: 4448.0
# Computes for layer 61: 17792.0
# Computes for layer 62: 17792.0
# Computes for layer 63: 17792.0
# Computes for layer 64: 17792.0
# Computes for layer 65: 17792.0
# Computes for layer 66: 17792.0
# Computes for layer 67: 17792.0
# Computes for layer 68: 17792.0
# Computes for layer 69: 17792.0
# Computes for layer 70: 17792.0
# Computes for layer 71: 17792.0
# Computes for layer 72: 4448.0
# Computes for layer 73: 4448.0
# Computes for layer 74: 17792.0
# Computes for layer 75: 34.75
# Computes for layer 76: 150.9453125
# Computes for layer 77: 4448.0
# Computes for layer 78: 17792.0
# Computes for layer 79: 17792.0
# Computes for layer 80: 17792.0
# Computes for layer 81: 17792.0
# Computes for layer 82: 17792.0
# Computes for layer 83: 17792.0
# Computes for layer 84: 17792.0
# Computes for layer 85: 17792.0
# Computes for layer 86: 17792.0
# Computes for layer 87: 17792.0
# Computes for layer 88: 17792.0
# Computes for layer 89: 4448.0
# Computes for layer 90: 4448.0
# Computes for layer 91: 17792.0
# Computes for layer 92: 34.75
# Computes for layer 93: 150.9453125
# Computes for layer 94: 4448.0
# Computes for layer 95: 17792.0
# Computes for layer 96: 17792.0
# Computes for layer 97: 17792.0
# Computes for layer 98: 17792.0
# Computes for layer 99: 17792.0
# Computes for layer 100: 17792.0
# Computes for layer 101: 17792.0
# Computes for layer 102: 17792.0
# Computes for layer 103: 17792.0
# Computes for layer 104: 17792.0
# Computes for layer 105: 17792.0
# Computes for layer 106: 4448.0
# Computes for layer 107: 4448.0
# Computes for layer 108: 17792.0
# Computes for layer 109: 34.75
# Computes for layer 110: 150.9453125
# Computes for layer 111: 4448.0
# Computes for layer 112: 17792.0
# Computes for layer 113: 17792.0
# Computes for layer 114: 17792.0
# Computes for layer 115: 17792.0
# Computes for layer 116: 17792.0
# Computes for layer 117: 17792.0
# Computes for layer 118: 17792.0
# Computes for layer 119: 17792.0
# Computes for layer 120: 17792.0
# Computes for layer 121: 17792.0
# Computes for layer 122: 17792.0
# Computes for layer 123: 4448.0
# Computes for layer 124: 4448.0
# Computes for layer 125: 17792.0
# Computes for layer 126: 34.75
# Computes for layer 127: 150.9453125
# Computes for layer 128: 4448.0
# Computes for layer 129: 17792.0
# Computes for layer 130: 17792.0
# Computes for layer 131: 17792.0
# Computes for layer 132: 17792.0
# Computes for layer 133: 17792.0
# Computes for layer 134: 17792.0
# Computes for layer 135: 17792.0
# Computes for layer 136: 17792.0
# Computes for layer 137: 17792.0
# Computes for layer 138: 17792.0
# Computes for layer 139: 17792.0
# Computes for layer 140: 4448.0
# Computes for layer 141: 4448.0
# Computes for layer 142: 17792.0
# Computes for layer 143: 34.75
# Computes for layer 144: 150.9453125
# Computes for layer 145: 4448.0
# Computes for layer 146: 17792.0
# Computes for layer 147: 17792.0
# Computes for layer 148: 17792.0
# Computes for layer 149: 17792.0
# Computes for layer 150: 17792.0
# Computes for layer 151: 17792.0
# Computes for layer 152: 17792.0
# Computes for layer 153: 17792.0
# Computes for layer 154: 17792.0
# Computes for layer 155: 17792.0
# Computes for layer 156: 17792.0
# Computes for layer 157: 4448.0
# Computes for layer 158: 4448.0
# Computes for layer 159: 17792.0
# Computes for layer 160: 34.75
# Computes for layer 161: 150.9453125
# Computes for layer 162: 4448.0
# Computes for layer 163: 17792.0
# Computes for layer 164: 17792.0
# Computes for layer 165: 17792.0
# Computes for layer 166: 17792.0
# Computes for layer 167: 17792.0
# Computes for layer 168: 17792.0
# Computes for layer 169: 17792.0
# Computes for layer 170: 17792.0
# Computes for layer 171: 17792.0
# Computes for layer 172: 17792.0
# Computes for layer 173: 17792.0
# Computes for layer 174: 4448.0
# Computes for layer 175: 4448.0
# Computes for layer 176: 17792.0
# Computes for layer 177: 34.75
# Computes for layer 178: 150.9453125
# Computes for layer 179: 4448.0
# Computes for layer 180: 17792.0
# Computes for layer 181: 17792.0
# Computes for layer 182: 17792.0
# Computes for layer 183: 17792.0
# Computes for layer 184: 17792.0
# Computes for layer 185: 17792.0
# Computes for layer 186: 17792.0
# Computes for layer 187: 17792.0
# Computes for layer 188: 17792.0
# Computes for layer 189: 17792.0
# Computes for layer 190: 17792.0
# Computes for layer 191: 4448.0
# Computes for layer 192: 4448.0
# Computes for layer 193: 17792.0
# Computes for layer 194: 34.75
# Computes for layer 195: 150.9453125
# Computes for layer 196: 4448.0
# Computes for layer 197: 17792.0
# Computes for layer 198: 17792.0
# Computes for layer 199: 17792.0
# Computes for layer 200: 17792.0
# Computes for layer 201: 17792.0
# Computes for layer 202: 17792.0
# Computes for layer 203: 17792.0
# Computes for layer 204: 17792.0
# Computes for layer 205: 17792.0
# Computes for layer 206: 17792.0
# Computes for layer 207: 17792.0
# Computes for layer 208: 4448.0
# Computes for layer 209: 4448.0
# Computes for layer 210: 17792.0
# Computes for layer 211: 34.75
# Computes for layer 212: 150.9453125
# Computes for layer 213: 4448.0
# Computes for layer 214: 17792.0
# Computes for layer 215: 17792.0
# Computes for layer 216: 17792.0
# Computes for layer 217: 17792.0
# Computes for layer 218: 17792.0
# Computes for layer 219: 17792.0
# Computes for layer 220: 17792.0
# Computes for layer 221: 17792.0
# Computes for layer 222: 17792.0
# Computes for layer 223: 17792.0
# Computes for layer 224: 17792.0
# Computes for layer 225: 4448.0
# Computes for layer 226: 4448.0
# Computes for layer 227: 17792.0
# Computes for layer 228: 34.75
# Computes for layer 229: 150.9453125
# Computes for layer 230: 4448.0
# Computes for layer 231: 17792.0
# Computes for layer 232: 17792.0
# Computes for layer 233: 17792.0
# Computes for layer 234: 17792.0
# Computes for layer 235: 17792.0
# Computes for layer 236: 17792.0
# Computes for layer 237: 17792.0
# Computes for layer 238: 17792.0
# Computes for layer 239: 17792.0
# Computes for layer 240: 17792.0
# Computes for layer 241: 17792.0
# Computes for layer 242: 4448.0
# Computes for layer 243: 4448.0
# Computes for layer 244: 17792.0
# Computes for layer 245: 34.75
# Computes for layer 246: 150.9453125
# Computes for layer 247: 4448.0
# Computes for layer 248: 17792.0
# Computes for layer 249: 17792.0
# Computes for layer 250: 17792.0
# Computes for layer 251: 17792.0
# Computes for layer 252: 17792.0
# Computes for layer 253: 17792.0
# Computes for layer 254: 17792.0
# Computes for layer 255: 17792.0
# Computes for layer 256: 17792.0
# Computes for layer 257: 17792.0
# Computes for layer 258: 17792.0
# Computes for layer 259: 4448.0
# Computes for layer 260: 4448.0
# Computes for layer 261: 17792.0
# Computes for layer 262: 34.75
# Computes for layer 263: 150.9453125
# Computes for layer 264: 4448.0
# Computes for layer 265: 17792.0
# Computes for layer 266: 17792.0
# Computes for layer 267: 17792.0
# Computes for layer 268: 17792.0
# Computes for layer 269: 17792.0
# Computes for layer 270: 17792.0
# Computes for layer 271: 17792.0
# Computes for layer 272: 17792.0
# Computes for layer 273: 17792.0
# Computes for layer 274: 17792.0
# Computes for layer 275: 17792.0
# Computes for layer 276: 4448.0
# Computes for layer 277: 4448.0
# Computes for layer 278: 17792.0
# Computes for layer 279: 34.75
# Computes for layer 280: 150.9453125
# Computes for layer 281: 4448.0
# Computes for layer 282: 17792.0
# Computes for layer 283: 17792.0
# Computes for layer 284: 17792.0
# Computes for layer 285: 17792.0
# Computes for layer 286: 17792.0
# Computes for layer 287: 17792.0
# Computes for layer 288: 17792.0
# Computes for layer 289: 17792.0
# Computes for layer 290: 17792.0
# Computes for layer 291: 17792.0
# Computes for layer 292: 17792.0
# Computes for layer 293: 4448.0
# Computes for layer 294: 4448.0
# Computes for layer 295: 17792.0
# Computes for layer 296: 34.75
# Computes for layer 297: 150.9453125
# Computes for layer 298: 4448.0
# Computes for layer 299: 17792.0
# Computes for layer 300: 17792.0
# Computes for layer 301: 17792.0
# Computes for layer 302: 17792.0
# Computes for layer 303: 17792.0
# Computes for layer 304: 17792.0
# Computes for layer 305: 17792.0
# Computes for layer 306: 17792.0
# Computes for layer 307: 17792.0
# Computes for layer 308: 17792.0
# Computes for layer 309: 17792.0
# Computes for layer 310: 4448.0
# Computes for layer 311: 4448.0
# Computes for layer 312: 17792.0
# Computes for layer 313: 34.75
# Computes for layer 314: 150.9453125
# Computes for layer 315: 4448.0
# Computes for layer 316: 17792.0
# Computes for layer 317: 17792.0
# Computes for layer 318: 17792.0
# Computes for layer 319: 17792.0
# Computes for layer 320: 17792.0
# Computes for layer 321: 17792.0
# Computes for layer 322: 17792.0
# Computes for layer 323: 17792.0
# Computes for layer 324: 17792.0
# Computes for layer 325: 17792.0
# Computes for layer 326: 17792.0
# Computes for layer 327: 4448.0
# Computes for layer 328: 4448.0
# Computes for layer 329: 17792.0
# Computes for layer 330: 34.75
# Computes for layer 331: 150.9453125
# Computes for layer 332: 4448.0
# Computes for layer 333: 17792.0
# Computes for layer 334: 17792.0
# Computes for layer 335: 17792.0
# Computes for layer 336: 17792.0
# Computes for layer 337: 17792.0
# Computes for layer 338: 17792.0
# Computes for layer 339: 17792.0
# Computes for layer 340: 17792.0
# Computes for layer 341: 17792.0
# Computes for layer 342: 17792.0
# Computes for layer 343: 17792.0
# Computes for layer 344: 4448.0
# Computes for layer 345: 4448.0
# Computes for layer 346: 17792.0
# Computes for layer 347: 34.75
# Computes for layer 348: 150.9453125
# Computes for layer 349: 4448.0
# Computes for layer 350: 17792.0
# Computes for layer 351: 17792.0
# Computes for layer 352: 17792.0
# Computes for layer 353: 17792.0
# Computes for layer 354: 17792.0
# Computes for layer 355: 17792.0
# Computes for layer 356: 17792.0
# Computes for layer 357: 17792.0
# Computes for layer 358: 17792.0
# Computes for layer 359: 17792.0
# Computes for layer 360: 17792.0
# Computes for layer 361: 4448.0
# Computes for layer 362: 4448.0
# Computes for layer 363: 17792.0
# Computes for layer 364: 34.75
# Computes for layer 365: 150.9453125
# Computes for layer 366: 4448.0
# Computes for layer 367: 17792.0
# Computes for layer 368: 17792.0
# Computes for layer 369: 17792.0
# Computes for layer 370: 17792.0
# Computes for layer 371: 17792.0
# Computes for layer 372: 17792.0
# Computes for layer 373: 17792.0
# Computes for layer 374: 17792.0
# Computes for layer 375: 17792.0
# Computes for layer 376: 17792.0
# Computes for layer 377: 17792.0
# Computes for layer 378: 4448.0
# Computes for layer 379: 4448.0
# Computes for layer 380: 17792.0
# Computes for layer 381: 34.75
# Computes for layer 382: 150.9453125
# Computes for layer 383: 4448.0
# Computes for layer 384: 17792.0
# Computes for layer 385: 17792.0
# Computes for layer 386: 17792.0
# Computes for layer 387: 17792.0
# Computes for layer 388: 17792.0
# Computes for layer 389: 17792.0
# Computes for layer 390: 17792.0
# Computes for layer 391: 17792.0
# Computes for layer 392: 17792.0
# Computes for layer 393: 17792.0
# Computes for layer 394: 17792.0
# Computes for layer 395: 4448.0
# Computes for layer 396: 4448.0
# Computes for layer 397: 17792.0
# Computes for layer 398: 34.75
# Computes for layer 399: 150.9453125
# Computes for layer 400: 4448.0
# Computes for layer 401: 17792.0
# Computes for layer 402: 17792.0
# Computes for layer 403: 17792.0
# Computes for layer 404: 17792.0
# Computes for layer 405: 17792.0
# Computes for layer 406: 17792.0
# Computes for layer 407: 17792.0
# Computes for layer 408: 17792.0
# Computes for layer 409: 17792.0
#
# Overall energy for DNN mobilebert: 1000000000000036.1 fJ
# total_per_energy[RRAM][0]: 0.46695402298806443
# total_per_energy[RRAM][1]: 1.1738505747140433e-12
# total_per_energy[RRAM][2]: 0.35919540229849845
# total_per_energy[RRAM][3]: 0.17385057471226323

# %%
display_markdown(
    """
### Calculating Area in fast scenario

"""
)
total_area = [0] * 2
total_adc_area = [0] * 2
total_col_area = [0] * 2
total_row_area = [0] * 2
total_cim_unit_area = [0] * 2
total_macro = [0] * 2
energy = [0] * 2
throughput = [0] * 2
total_area[0], total_adc_area[0], total_col_area[0], total_row_area[0], total_cim_unit_area[0], total_macro[0], energy[0], throughput[0] = extract_outputs(f"SRAM_{DNN}_128_fast")
total_area[1], total_adc_area[1], total_col_area[1], total_row_area[1], total_cim_unit_area[1], total_macro[1], energy[1], throughput[1] = extract_outputs(f"RRAM_{DNN}_128_fast")
# Out:
# ### Calculating Area in fast scenario
# ../outputs/SRAM_mobilebert_128_fast/
# Model 	 Energy/inference (J) 	 Area (mm2) 	 Throughput (inf/s)
# Processing layer: SRAM_mobilebert_128_fast_layer_1
# Size: 8
# Size: 3
# All macro: 24
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 684362.3999999999
#
# Size: 8
# Size: 3
# All macro: 24
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 25311.600000000002
#
# Size: 8
# Size: 3
# All macro: 24
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 22283.904
#
# Size: 8
# Size: 3
# All macro: 24
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 128849.01888000002
#
# Total Area for layer 1: 860806.9228799999
#
# Total Macro for layer 1: 24
#
# Total Area for all layers: 860806.9228799999
# Total Area for ADC across all layers: 684362.3999999999
# Processing layer: SRAM_mobilebert_128_fast_layer_2
# Size: 2
# Size: 4
# All macro: 8
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 228120.8
#
# Size: 2
# Size: 4
# All macro: 8
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 8437.2
#
# Size: 2
# Size: 4
# All macro: 8
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 7427.968
#
# Size: 2
# Size: 4
# All macro: 8
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 42949.67296
#
# Total Area for layer 2: 286935.64096
#
# Total Macro for layer 2: 32
#
# Total Area for all layers: 1147742.56384
# Total Area for ADC across all layers: 912483.2
# Processing layer: SRAM_mobilebert_128_fast_layer_3
# Size: 2
# Size: 4
# All macro: 8
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 228120.8
#
# Size: 2
# Size: 4
# All macro: 8
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 8437.2
#
# Size: 2
# Size: 4
# All macro: 8
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 7427.968
#
# Size: 2
# Size: 4
# All macro: 8
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 42949.67296
#
# Total Area for layer 3: 286935.64096
#
# Total Macro for layer 3: 40
#
# Total Area for all layers: 1434678.2048
# Total Area for ADC across all layers: 1140604.0
# Processing layer: SRAM_mobilebert_128_fast_layer_4
# Size: 2
# All macro: 2
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 57030.2
#
# Size: 2
# All macro: 2
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 2109.3
#
# Size: 2
# All macro: 2
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 1856.992
#
# Size: 2
# All macro: 2
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 10737.41824
#
# Total Area for layer 4: 71733.91024
#
# Total Macro for layer 4: 42
#
# Total Area for all layers: 1506412.11504
# Total Area for ADC across all layers: 1197634.2
# Processing layer: SRAM_mobilebert_128_fast_layer_5
# Size: 2
# All macro: 2
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 57030.2
#
# Size: 2
# All macro: 2
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 2109.3
#
# Size: 2
# All macro: 2
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 1856.992
#
# Size: 2
# All macro: 2
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 10737.41824
#
# Total Area for layer 5: 71733.91024
#
# Total Macro for layer 5: 44
#
# Total Area for all layers: 1578146.0252800002
# Total Area for ADC across all layers: 1254664.4
# Processing layer: SRAM_mobilebert_128_fast_layer_6
# Size: 2
# Size: 4
# All macro: 8
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 228120.8
#
# Size: 2
# Size: 4
# All macro: 8
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 8437.2
#
# Size: 2
# Size: 4
# All macro: 8
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 7427.968
#
# Size: 2
# Size: 4
# All macro: 8
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 42949.67296
#
# Total Area for layer 6: 286935.64096
#
# Total Macro for layer 6: 52
#
# Total Area for all layers: 1865081.6662400002
# Total Area for ADC across all layers: 1482785.2
# Processing layer: SRAM_mobilebert_128_fast_layer_7
# Size: 2
# All macro: 2
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 57030.2
#
# Size: 2
# All macro: 2
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 2109.3
#
# Size: 2
# All macro: 2
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 1856.992
#
# Size: 2
# All macro: 2
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 10737.41824
#
# Total Area for layer 7: 71733.91024
#
# Total Macro for layer 7: 54
#
# Total Area for all layers: 1936815.5764800003
# Total Area for ADC across all layers: 1539815.4
# Processing layer: SRAM_mobilebert_128_fast_layer_8
# Size: 3
# Size: 2
# All macro: 6
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 171090.59999999998
#
# Size: 3
# Size: 2
# All macro: 6
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 6327.900000000001
#
# Size: 3
# Size: 2
# All macro: 6
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 5570.976
#
# Size: 3
# Size: 2
# All macro: 6
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 32212.254720000004
#
# Total Area for layer 8: 215201.73071999996
#
# Total Macro for layer 8: 60
#
# Total Area for all layers: 2152017.3072
# Total Area for ADC across all layers: 1710906.0
# Processing layer: SRAM_mobilebert_128_fast_layer_9
# Size: 2
# All macro: 2
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 57030.2
#
# Size: 2
# All macro: 2
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 2109.3
#
# Size: 2
# All macro: 2
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 1856.992
#
# Size: 2
# All macro: 2
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 10737.41824
#
# Total Area for layer 9: 71733.91024
#
# Total Macro for layer 9: 62
#
# Total Area for all layers: 2223751.2174400003
# Total Area for ADC across all layers: 1767936.2
# Processing layer: SRAM_mobilebert_128_fast_layer_10
# Size: 8
# All macro: 8
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 228120.8
#
# Size: 8
# All macro: 8
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 8437.2
#
# Size: 8
# All macro: 8
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 7427.968
#
# Size: 8
# All macro: 8
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 42949.67296
#
# Total Area for layer 10: 286935.64096
#
# Total Macro for layer 10: 70
#
# Total Area for all layers: 2510686.8584000003
# Total Area for ADC across all layers: 1996057.0
# Processing layer: SRAM_mobilebert_128_fast_layer_11
# Size: 2
# Size: 4
# All macro: 8
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 228120.8
#
# Size: 2
# Size: 4
# All macro: 8
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 8437.2
#
# Size: 2
# Size: 4
# All macro: 8
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 7427.968
#
# Size: 2
# Size: 4
# All macro: 8
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 42949.67296
#
# Total Area for layer 11: 286935.64096
#
# Total Macro for layer 11: 78
#
# Total Area for all layers: 2797622.4993600002
# Total Area for ADC across all layers: 2224177.8
# Processing layer: SRAM_mobilebert_128_fast_layer_12
# Size: 8
# All macro: 8
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 228120.8
#
# Size: 8
# All macro: 8
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 8437.2
#
# Size: 8
# All macro: 8
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 7427.968
#
# Size: 8
# All macro: 8
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 42949.67296
#
# Total Area for layer 12: 286935.64096
#
# Total Macro for layer 12: 86
#
# Total Area for all layers: 3084558.1403200002
# Total Area for ADC across all layers: 2452298.5999999996
# Processing layer: SRAM_mobilebert_128_fast_layer_13
# Size: 2
# Size: 4
# All macro: 8
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 228120.8
#
# Size: 2
# Size: 4
# All macro: 8
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 8437.2
#
# Size: 2
# Size: 4
# All macro: 8
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 7427.968
#
# Size: 2
# Size: 4
# All macro: 8
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 42949.67296
#
# Total Area for layer 13: 286935.64096
#
# Total Macro for layer 13: 94
#
# Total Area for all layers: 3371493.78128
# Total Area for ADC across all layers: 2680419.3999999994
# Processing layer: SRAM_mobilebert_128_fast_layer_14
# Size: 8
# All macro: 8
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 228120.8
#
# Size: 8
# All macro: 8
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 8437.2
#
# Size: 8
# All macro: 8
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 7427.968
#
# Size: 8
# All macro: 8
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 42949.67296
#
# Total Area for layer 14: 286935.64096
#
# Total Macro for layer 14: 102
#
# Total Area for all layers: 3658429.42224
# Total Area for ADC across all layers: 2908540.1999999993
# Processing layer: SRAM_mobilebert_128_fast_layer_15
# Size: 2
# Size: 4
# All macro: 8
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 228120.8
#
# Size: 2
# Size: 4
# All macro: 8
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 8437.2
#
# Size: 2
# Size: 4
# All macro: 8
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 7427.968
#
# Size: 2
# Size: 4
# All macro: 8
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 42949.67296
#
# Total Area for layer 15: 286935.64096
#
# Total Macro for layer 15: 110
#
# Total Area for all layers: 3945365.0632
# Total Area for ADC across all layers: 3136660.999999999
# Processing layer: SRAM_mobilebert_128_fast_layer_16
# Size: 8
# All macro: 8
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 228120.8
#
# Size: 8
# All macro: 8
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 8437.2
#
# Size: 8
# All macro: 8
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 7427.968
#
# Size: 8
# All macro: 8
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 42949.67296
#
# Total Area for layer 16: 286935.64096
#
# Total Macro for layer 16: 118
#
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_17
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_18
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_19
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_20
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_21
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_22
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_23
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_24
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_25
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_26
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_27
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_28
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_29
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_30
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_31
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_32
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_33
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_34
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_35
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_36
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_37
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_38
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_39
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_40
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_41
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_42
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_43
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_44
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_45
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_46
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_47
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_48
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_49
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_50
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_51
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_52
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_53
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_54
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_55
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_56
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_57
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_58
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_59
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_60
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_61
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_62
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_63
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_64
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_65
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_66
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_67
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_68
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_69
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_70
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_71
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_72
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_73
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_74
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_75
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_76
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_77
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_78
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_79
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_80
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_81
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_82
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_83
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_84
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_85
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_86
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_87
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_88
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_89
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_90
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_91
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_92
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_93
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_94
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_95
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_96
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_97
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_98
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_99
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_100
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_101
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_102
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_103
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_104
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_105
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_106
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_107
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_108
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_109
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_110
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_111
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_112
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_113
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_114
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_115
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_116
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_117
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_118
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_119
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_120
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_121
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_122
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_123
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_124
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_125
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_126
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_127
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_128
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_129
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_130
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_131
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_132
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_133
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_134
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_135
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_136
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_137
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_138
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_139
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_140
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_141
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_142
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_143
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_144
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_145
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_146
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_147
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_148
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_149
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_150
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_151
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_152
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_153
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_154
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_155
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_156
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_157
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_158
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_159
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_160
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_161
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_162
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_163
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_164
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_165
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_166
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_167
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_168
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_169
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_170
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_171
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_172
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_173
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_174
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_175
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_176
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_177
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_178
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_179
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_180
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_181
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_182
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_183
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_184
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_185
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_186
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_187
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_188
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_189
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_190
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_191
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_192
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_193
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_194
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_195
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_196
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_197
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_198
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_199
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_200
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_201
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_202
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_203
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_204
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_205
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_206
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_207
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_208
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_209
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_210
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_211
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_212
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_213
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_214
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_215
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_216
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_217
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_218
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_219
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_220
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_221
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_222
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_223
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_224
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_225
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_226
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_227
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_228
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_229
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_230
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_231
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_232
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_233
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_234
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_235
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_236
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_237
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_238
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_239
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_240
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_241
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_242
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_243
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_244
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_245
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_246
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_247
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_248
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_249
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_250
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_251
# Total Area for all layers: 4232300.70416
# Total Area for ADC across all layers: 3364781.799999999
# Processing layer: SRAM_mobilebert_128_fast_layer_252
# Total Area for all layers: 4232300.70416
# ...
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_302
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_303
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_304
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_305
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_306
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_307
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_308
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_309
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_310
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_311
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_312
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_313
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_314
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_315
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_316
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_317
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_318
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_319
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_320
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_321
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_322
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_323
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_324
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_325
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_326
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_327
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_328
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_329
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_330
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_331
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_332
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_333
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_334
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_335
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_336
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_337
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_338
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_339
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_340
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_341
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_342
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_343
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_344
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_345
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_346
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_347
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_348
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_349
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_350
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_351
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_352
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_353
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_354
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_355
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_356
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_357
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_358
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_359
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_360
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_361
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_362
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_363
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_364
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_365
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_366
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_367
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_368
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_369
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_370
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_371
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_372
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_373
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_374
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_375
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_376
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_377
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_378
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_379
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_380
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_381
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_382
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_383
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_384
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_385
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_386
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_387
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_388
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_389
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_390
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_391
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_392
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_393
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_394
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_395
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_396
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_397
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_398
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_399
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_400
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_401
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_402
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_403
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_404
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_405
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_406
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_407
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_408
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Processing layer: RRAM_mobilebert_128_fast_layer_409
# Total Area for all layers: 3701886.16352
# Total Area for ADC across all layers: 3511184.4
# Total Area for column drivers across all layers: 52039.53400000001
# Total Area for row drivers across all layers: 59473.77000000001
# Total Area for cim unit across all layers: 79188.45952000002
#
#
# Total Area for ADC across all layers: 3.5111844
# Total Area for column driver across all layers: 0.052039534000000005
# Total Area for row driver across all layers: 0.05947377000000001
# Total Area for cim unit across all layers: 0.07918845952000002
# Total Macro across all layers: 118
# RRAM_mobilebert_128_fast 	 1.01e-04 	 3.70 	 1.99e+02

# %%
print(total_area)
print(total_adc_area)
print(total_col_area)
print(total_row_area)
print(total_cim_unit_area)
print(total_macro)
print(energy)
print(throughput)
# Out:
# [4.23230070416, 3.7018861635199998]
# [3.364781799999999, 3.5111844]
# [0.1244487, 0.052039534000000005]
# [0.10956252799999995, 0.05947377000000001]
# [0.6335076761600001, 0.07918845952000002]
# [118, 118]
# [8.347524200000011e-05, 0.0001013848299999999]
# [198.52693017807866, 198.52693017807866]

# %%
import matplotlib.pyplot as plt
import numpy as np
fig, ax = plt.subplots(figsize=(10, 5)) 
# array_sizes = ['32', '64', '128', '256']
path = ['SRAM', 'RRAM']

x = np.arange(len(path))

# Stack bars
ax.bar(path, total_cim_unit_area, label='cim_unit')
ax.bar(path, total_row_area, bottom=total_cim_unit_area, label='row_drivers')
ax.bar(path, total_col_area, bottom=np.array(total_cim_unit_area) + np.array(total_row_area), label='column_drivers')
ax.bar(path, total_adc_area, bottom=np.array(total_cim_unit_area) + np.array(total_row_area) + np.array(total_col_area), label='adc')

# Labels and title
ax.set_title(f"Area vs Memory Type for {DNN} in fast scenario")
ax.set_xlabel("Memory type")
ax.set_ylabel("Area (mm2)")
# Set x-ticks
ax.set_xticks(x)
ax.set_xticklabels(path)

ax.legend()

# Show plot
plt.show()

# %%
for path in path_list:
    print(f"Memory Type: {path.split('/')[-1].split('_')[0].upper()}")
    # For each component index (0 to 3)
    for i in range(4):
        print(f"total_per_energy[{path.split('/')[-1].split('_')[0].upper()}][{i}]: {total_per_energy[path][i]}")
    print()
# Out:
# Memory Type: SRAM
# total_per_energy[SRAM][0]: 0.4915375363859875
# total_per_energy[SRAM][1]: 0.0029805999546810053
# total_per_energy[SRAM][2]: 0.5037388227501635
# total_per_energy[SRAM][3]: 0.0017430409091680585
#
# Memory Type: RRAM
# total_per_energy[RRAM][0]: 0.46695402298806443
# total_per_energy[RRAM][1]: 1.1738505747140433e-12
# total_per_energy[RRAM][2]: 0.35919540229849845
# total_per_energy[RRAM][3]: 0.17385057471226323

# %%
display_markdown(
    """
### Calculating the energy

"""
)

path_list = [SRAM_PATH, RRAM_PATH]
total_adc_energy = [0] * 2
total_col_energy = [0] * 2
total_row_energy = [0] * 2
total_cim_unit_energy = [0] * 2
for j in range(len(energy)):
    if j == 0:
        for i in range(4):
            if i == 0:
                total_adc_energy[j] = total_per_energy[path_list[0]][i] * energy[j]
            elif i == 1:
                total_col_energy[j] = total_per_energy[path_list[0]][i] * energy[j]
            elif i == 2:
                total_row_energy[j] = total_per_energy[path_list[0]][i] * energy[j]
            else:
                total_cim_unit_energy[j] = total_per_energy[path_list[0]][i] * energy[j]
    else:
        for i in range(4):
            if i == 0:
                total_adc_energy[j] = total_per_energy[path_list[1]][i] * energy[j]
            elif i == 1:
                total_col_energy[j] = total_per_energy[path_list[1]][i] * energy[j]
            elif i == 2:
                total_row_energy[j] = total_per_energy[path_list[1]][i] * energy[j]
            else:
                total_cim_unit_energy[j] = total_per_energy[path_list[1]][i] * energy[j]

    
print("Total ADC Energy:", total_adc_energy)
print("Total Column Energy:", total_col_energy)
print("Total Row Energy:", total_row_energy)
print("Total CIM Unit Energy:", total_cim_unit_energy)
# Out:
# ### Calculating the energy
# Total ADC Energy: [4.103121480190417e-05, 4.734205423846096e-05]
# Total Column Energy: [2.488063025221863e-07, 1.1901064096278545e-16]
# Total Row Energy: [4.204972013386506e-05, 3.641696479881484e-05]
# Total CIM Unit Energy: [1.455007617087039e-07, 1.7625810962605088e-05]

# %%
import matplotlib.pyplot as plt
import numpy as np
fig, ax = plt.subplots(figsize=(10, 5)) 
path = ['SRAM', 'RRAM']

# x = np.arange(len(array_sizes))

# Stack bars
ax.bar(path, total_cim_unit_energy, label='cim_unit')
ax.bar(path, total_row_energy, bottom=total_cim_unit_energy, label='row_drivers')
ax.bar(path, total_col_energy, bottom=np.array(total_cim_unit_energy) + np.array(total_row_energy), label='column_drivers')
ax.bar(path, total_adc_energy, bottom=np.array(total_cim_unit_energy) + np.array(total_row_energy) + np.array(total_col_energy), label='adc')

# Labels and title
ax.set_title(f"Energy vs Memory Type for {DNN} in fast scenario")
ax.set_xlabel("Memory type")
ax.set_ylabel("Energy (J)")
# Set x-ticks
ax.set_xticks(x)
ax.set_xticklabels(path)

ax.legend()

# Show plot
plt.show()

# %%
display_markdown(
    """
### Plot the Throughput

"""
)
import matplotlib.pyplot as plt

# Data
path = ['SRAM', 'RRAM']
x = np.arange(len(path))
# Plotting the line graph
plt.figure(figsize=(10, 6))
plt.plot(path, throughput, marker='o', linestyle='-', color='b')

# Adding labels and title
plt.xlabel('Memory type')
plt.ylabel('Throughput')
plt.title(f'Throughput vs Memory Type for {DNN}')
plt.grid(False)
plt.xticks(x, path) 
# Show plot
plt.show()
# Out:
# ### Plot the Throughput

# %%
display_markdown(
    """
### Plot the Number of Macros

"""
)
import matplotlib.pyplot as plt

# Data
path = ['SRAM', 'RRAM']
x = np.arange(len(path))
# Plotting the line graph
plt.figure(figsize=(10, 6))
plt.plot(path, total_macro, marker='o', linestyle='-', color='b')

# Adding labels and title
plt.xlabel('Memory type')
plt.ylabel('Number of Macros')
plt.title(f'Number of Macros vs Memory Type for {DNN}')
plt.grid(False)
plt.xticks(x, path) 
# Show plot
plt.show()
# Out:
# ### Plot the Number of Macros
