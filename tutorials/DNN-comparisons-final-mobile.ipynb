# %%
from _import_scripts import scripts
from scripts.notebook_utils import *
from scripts.tl_output_parsing import MacroOutputStats
from scripts.utils import *
import yaml

MACRO_PATH = "../models/arch/1_macro/basic_analog/" 
macro = {}
total_per_energy = {}
SRAM_PATH = f'"{os.path.abspath("../models/memory_cells/sram_example.cell.yaml")}"'
RRAM_PATH = f'"{os.path.abspath("../models/memory_cells/rram_example.cell.yaml")}"'

dnn_layers = {
    "alexnet": 8,
    "vgg16": 16,
    "dpt_large": 227,
    "gpt2_medium": 145,
    "mobilebert": 409,
    "vision_transformer": 98,
    "resnet18": 21,
    "mobilenet_v3": 64
}

# Define the architecture
array_sizes = 128
path_list = [SRAM_PATH, RRAM_PATH]
tech_node = 32
time = "fast"

dnn_list = ["mobilenet_v3", "mobilebert"]
for DNN in dnn_list:
    dnn_layer = dnn_layers.get(DNN, None)
    def create_layer_directory(base_output_dir: str, architecture: str, layer: int) -> str:
        layer_dir = os.path.join(base_output_dir, f"{architecture}_layer_{layer}")
        if not os.path.exists(layer_dir):
            os.makedirs(layer_dir)
        return layer_dir

    num_layers = 1

    def run_map(
        spec: tl.Specification,
        arch: str,
        accelergy_verbose: bool = False,
    ) -> dict:
        output_dir = get_run_dir()
        # Just use the directory name if it causes error
        base_output_dir = os.path.dirname(output_dir)
        base_output_dir = os.path.join(base_output_dir, arch)
        global num_layers

        mapper_result = None

        if num_layers < dnn_layer+1:
            # Create a directory for the current layer
            layer_dir = create_layer_directory(base_output_dir, arch, num_layers)
            # print(f"Layer directory: {layer_dir}")
            num_layers += 1

            run_prefix = f"{layer_dir}/timeloop-mapper"
            mapper_result = tl.call_mapper(
                specification=spec,
                output_dir=layer_dir,
                log_to=os.path.join(output_dir, f"{run_prefix}.log"),
            )
            if accelergy_verbose:
                tl.call_accelergy_verbose(
                    specification=spec,
                    output_dir=layer_dir,
                    log_to=os.path.join(output_dir, "accelergy.log"),
                )

        if mapper_result is None:
            # Handle case when mapper_result is not assigned (num_layers >= 17)
            # Raise an error, return a default value
            print("Warning: mapper_result is not assigned. num_layers >= 17")
            return {}

        return MacroOutputStats.from_output_stats(mapper_result)

    import re

    def extract_range(line):
        match = re.search(r'\[(\d+):(\d+)(,\d+)?\)', line)
        if match:
            start = int(match.group(1))
            end = int(match.group(2))
            return end - start
        return None

    def read_and_compute_multiplication(filename, i):
        filename = f"../outputs/{filename}/{filename}_layer_{i+1}/timeloop-mapper.map.txt"
        with open(filename, 'r') as file:
            lines = file.readlines()

        start_searching = False
        ranges = []

        for line in lines:
            # Start searching when 'inter_macro_in_system_spatial' is found
            if "inter_macro_in_system_spatial" in line:
                start_searching = True
            
            # Stop searching if we leave the 'inter_macro_in_system_spatial' section
            elif start_searching and "inter_" in line and "inter_macro_in_system_spatial" not in line:
                break

            # If we are in the 'inter_macro_in_system_spatial' section, look for the ranges
            if start_searching:
                if "for" in line:
                    range_size = extract_range(line)
                    if range_size is not None:
                        ranges.append(range_size)
                elif line.strip() == "":  # Exit the section on an empty line
                    break

        # Compute the multiplication of all ranges, or return 1 if no ranges were found
        if not ranges:
            print(f"All macro: 1")
            return 1

        result = 1
        for size in ranges:
            result *= size
            print(f"Size: {size}")
        print(f"All macro: {result}")
        return result


    def extract_layer_number(folder_name):
        match = re.search(r'layer_(\d+)', folder_name)
        return int(match.group(1)) if match else float('inf')

    def extract_outputs(model):
        
        output_dir = "../outputs/" + model + "/" 
        print(output_dir)

        print ("Model \t Energy/inference (J) \t Area (mm2) \t Throughput (inf/s)")
        #for model in models:    
        throughput = 0   
        energy = 0
        area = 0
        cycles = 0
        folders = sorted([folder for folder in os.listdir(output_dir) if model in folder], key=extract_layer_number)
        area_per_many_macro = 0
        area_layer = 0
        j = 0
        total_sum = 0
        total_adc_area = 0  # Total area for ADC across all layers
        total_other_areas = {}  # Dictionary to store total areas for other components
        total_col_area = 0
        total_row_area = 0
        total_cim_unit_area = 0
        total_area = 0
        total_macro = 0
        
        for folder in folders:
            total = 0
            if model in folder:
                print(f"Processing layer: {folder}")
                # print(folder)
                if os.path.isdir(output_dir + folder):
                    stat_file = output_dir + folder + "/timeloop-mapper.stats.txt"
                    art_file = output_dir + folder + "/timeloop-mapper.ART.yaml"
            
                    with open(stat_file, 'r') as f:
                        energy_stat = [line for line in f if line.startswith("Energy:")][0]
                        energy_uj = energy_stat.split(' ')[1] # uJ
                        energy += float(energy_uj)
                        # print(f"Energy for this layer: {float(energy_uj)} uj")
                    
                    with open(stat_file, 'r') as f:
                        cycle_stat = [line for line in f if line.startswith("Cycles:")][0]                  
                        cycle = cycle_stat.split(' ')[1] 
                        cycles += float(cycle)
                        print(f"Cycle: {cycle}")
                    print(f"Total Cycle: {cycles}")
                        
                if j < dnn_layer:
                    with open(art_file, 'r') as file:
                        data = yaml.safe_load(file)
                    
                        # Extract and print the name, area, number of entries, and ratio for non-zero areas
                    for table in data['ART']['tables']:
                        name = table.get('name')
                        area = table.get('area')
                        if area != 0:
                            # Simplify the name for the output
                            if 'system_top_level.' in name:
                                name = name.split('system_top_level.')[-1]
                            
                            # Extract the number of entries from the name
                            if '[' in name:
                                name_part, entries_part = name.split('[')
                                number_of_entries = entries_part.split('..')[1].replace(']', '')
                                name = name_part.strip()
                            else:
                                number_of_entries = 'Unknown'
                            
                            macro = read_and_compute_multiplication(model, j)
                            # Calculate total ratio
                            if number_of_entries != 'Unknown' and number_of_entries.isdigit():
                                total_ratio = (area / 4096) * macro * int(number_of_entries)
                            else:
                                total_ratio = 0
                            
                            total += total_ratio
                            
                            # Accumulate area for ADC or other components
                            if 'adc' in name.lower():
                                total_adc_area += total_ratio
                            else:
                                if name not in total_other_areas:
                                    total_other_areas[name] = 0
                                total_other_areas[name] += total_ratio
                
                            print(f"{name.replace('_', ' ')} area: {area}, number of {name}: {number_of_entries}, \ntotal {name.replace('_', ' ')} area: ({area}*{number_of_entries}/4096) * macro = {total_ratio}\n")
                    j += 1 
                    total_sum += total
                    total_macro += macro
                    print(f"Total Area for layer {j}: {total}\n")
                    print(f"Total Macro for layer {j}: {total_macro}\n")
                print(f"Total Area for all layers: {total_sum}")
                print(f"Total Area for ADC across all layers: {total_adc_area}")
        
        # Print total area for other components
        for component, area in total_other_areas.items():
            print(f"Total Area for {component.replace('_', ' ')} across all layers: {area}")
            # print(component.replace('_', ' '))
            if component.replace('_', ' ') ==  "column drivers":
                total_col_area = area
            elif component.replace('_', ' ') ==  "row drivers":
                total_row_area = area
            else:
                total_cim_unit_area = area
                                    
        energy *= 1e-6 # conver to J
        total_area = total_sum * 1e-6 # mm2
        throughput = 1 / (cycles * 1e-7) # s
       
        total_adc_area = total_adc_area * 1e-6 # mm2
        total_col_area = total_col_area * 1e-6 # mm2
        total_row_area = total_row_area * 1e-6 # mm2
        total_cim_unit_area = total_cim_unit_area * 1e-6 # mm2
        print("\n")
        print(f"Total Area for ADC across all layers: {total_adc_area}")
        print(f"Total Area for column driver across all layers: {total_col_area}")
        print(f"Total Area for row driver across all layers: {total_row_area}")
        print(f"Total Area for cim unit across all layers: {total_cim_unit_area}")
        print(f"Total Macro across all layers: {total_macro}")
        print ("{} \t {:.2e} \t {:.2f} \t {:.2e}".format(model, energy, total_area, throughput))
        
        return total_area, total_adc_area, total_col_area, total_row_area, total_cim_unit_area, total_macro, energy, throughput

    
##----------------------------------------- Running DNN -------------------------------------------

    for path in path_list:
        arch = f"{path.split('/')[-1].split('_')[0].upper()}_{DNN}_{array_sizes}"
        print(f"\nRunning {DNN} with {array_sizes} x {array_sizes} {path.split('/')[-1].split('_')[0].upper()} with {tech_node} nm in {time} scenario")

        num_layers = 1

        def run_dnn(dnn: str, layer: str, array_sizes: int, variables):
            print(f"{layer} ", end="", flush=True)
            spec = get_spec(
                "basic_analog",
                # Weight-stationary, dummy buffer on top to hold inputs & outputs, many
                # macros to ensure we can fit all weights.
                system="ws_dummy_buffer_many_macro",
                # Set the DNN and layer
                dnn=dnn,
                layer=layer,
            )
        
            # Do NOT generate a maximum-utilization workload; we're running a DNN
            # workload.
            spec.variables["MAX_UTILIZATION"] = False
        
            # Use a larger array to ensure we can fit all weights
            spec.architecture.find("column").spatial.meshX = array_sizes
            spec.architecture.find("row").spatial.meshY = array_sizes
        
            spec.variables.update(variables)
            output_stats = run_map(spec, arch)
            
            # Print computes for the layer
            macro_output_stats = MacroOutputStats.from_output_stats(output_stats)
            print(f"Computes for layer {int(layer) + 1}: {macro_output_stats.computes}")
            global macro
            macro[layer] = macro_output_stats.computes
            return output_stats
        
        layers = [f for f in os.listdir(f"../models/workloads/{DNN}") if f != "index.yaml" and f.endswith(".yaml")]
        layers = sorted(layers)
        print(f"Running: ", end="")
        
        # Parallel/Delayed is used to multiprocess. Equivalent to running the following
        # code in serial:
        results = joblib.Parallel(n_jobs=None)(
            joblib.delayed(run_dnn)(DNN, layer.split(".")[0], array_sizes, 
                                    {
                                        "CELL_CONFIG": path,
                                        "BITS_PER_CELL": 1 if path == SRAM_PATH else 4,
                                        "CIM_UNIT_WIDTH_CELLS": 4 if path == SRAM_PATH else 1,
                                        "IS_SRAM": path == SRAM_PATH,
                                        "TECHNOLOGY": tech_node,
                                        "ADC_RESOLUTION": 4 if path == SRAM_PATH else 6,
                                        "GLOBAL_CYCLE_SECONDS": 1e-7 if time == "fast" else 1e-4,
                                    }
                                    ) for layer in layers
        )
        print("")
        for r in results:
            r.clear_zero_energies()
        
        #Initialize overall_energy
        energy_layer = [0] * 16
        result = 0
        
        total_adc_energy = 0.0
        total_col_energy = 0.0
        total_row_energy = 0.0
        total_cim_unit_energy = 0.0
        # Calculate overall energy
        for r in results:
        
            per_component_energy = r.per_compute("per_component_energy")
            total_energy_per_layer = sum(per_component_energy.values()) * 1e15  # Convert to fJ
            total_adc_energy += per_component_energy.get('adc', 0.0)
            total_col_energy += per_component_energy.get('column_drivers', 0.0)
            total_row_energy += per_component_energy.get('row_drivers', 0.0)
            total_cim_unit_energy += per_component_energy.get('cim_unit', 0.0)
        
            total_adc_energy = total_adc_energy * 1e15
            total_col_energy = total_col_energy * 1e15
            total_row_energy = total_row_energy * 1e15
            total_cim_unit_energy = total_cim_unit_energy * 1e15
            total_energy = total_adc_energy + total_col_energy + total_row_energy + total_cim_unit_energy
        
            total_adc_energy = total_adc_energy/total_energy
            total_col_energy = total_col_energy/total_energy
            total_row_energy = total_row_energy/total_energy
            total_cim_unit_energy = total_cim_unit_energy/total_energy

            total_per_energy[(DNN, path)] = [total_adc_energy, total_col_energy, total_row_energy, total_cim_unit_energy]
            
        # Display overall energy
        print(f"Overall energy for DNN {DNN}: {total_energy} fJ")

        for i in range(4):
            print(f"total_per_energy[{DNN}][{path.split('/')[-1].split('_')[0].upper()}][{i}]: {total_per_energy[(DNN,path)][i]}")
        print() 
        
        # Display an energy breakdown for each layer as a bar chart. Display normalized per-MAC and per-layer energy.
        fig, ax = plt.subplots(figsize=(20, 5))
        
        bar_stacked(
            {i: r.per_compute("per_component_energy") * 1e15 for i, r in enumerate(results)},
            title= f"Using {path.split('/')[-1].split('_')[0].upper()} on {array_sizes} x {array_sizes} array sizes, {tech_node} nm running {DNN}",
            xlabel="Layer",
            ylabel="Energy (fJ/MAC)",
            ax=ax,
        )
# Out:
# Running mobilenet_v3 with 128 x 128 SRAM with 32 nm in fast scenario
# Computes for layer 1: 10584.0
# Computes for layer 2: 3528.0
# Computes for layer 3: 6272.0
# Computes for layer 4: 25088.0
# Computes for layer 5: 3528.0
# Computes for layer 6: 9408.0
# Computes for layer 7: 10584.0
# Computes for layer 8: 3969.0
# Computes for layer 9: 10584.0
# Computes for layer 10: 10584.0
# Computes for layer 11: 2756.25
# Computes for layer 12: 3.375
# Computes for layer 13: 3.375
# Computes for layer 14: 4410.0
# Computes for layer 15: 7350.0
# Computes for layer 16: 4593.75
# Computes for layer 17: 7.5
# Computes for layer 18: 7.5
# Computes for layer 19: 7350.0
# Computes for layer 20: 7350.0
# Computes for layer 21: 4593.75
# Computes for layer 22: 7.5
# Computes for layer 23: 7.5
# Computes for layer 24: 7350.0
# Computes for layer 25: 14700.0
# Computes for layer 26: 826.875
# Computes for layer 27: 7350.0
# Computes for layer 28: 6125.0
# Computes for layer 29: 689.0625
# Computes for layer 30: 6125.0
# Computes for layer 31: 5635.0
# Computes for layer 32: 633.9375
# Computes for layer 33: 5635.0
# Computes for layer 34: 5635.0
# Computes for layer 35: 633.9375
# Computes for layer 36: 5635.0
# Computes for layer 37: 14700.0
# Computes for layer 38: 1653.75
# Computes for layer 39: 112.5
# Computes for layer 40: 112.5
# Computes for layer 41: 20580.0
# Computes for layer 42: 28812.0
# Computes for layer 43: 2315.25
# Computes for layer 44: 220.5
# Computes for layer 45: 220.5
# Computes for layer 46: 28812.0
# Computes for layer 47: 28812.0
# Computes for layer 48: 1607.8125
# Computes for layer 49: 220.5
# Computes for layer 50: 220.5
# Computes for layer 51: 10290.0
# Computes for layer 52: 14700.0
# Computes for layer 53: 2296.875
# Computes for layer 54: 450.0
# Computes for layer 55: 450.0
# Computes for layer 56: 14700.0
# Computes for layer 57: 14700.0
# Computes for layer 58: 2296.875
# Computes for layer 59: 450.0
# Computes for layer 60: 450.0
# Computes for layer 61: 14700.0
# Computes for layer 62: 14700.0
# Computes for layer 63: 2400.0
# Computes for layer 64: 2500.0
#
# Overall energy for DNN mobilenet_v3: 1000000000000029.4 fJ
# total_per_energy[mobilenet_v3][SRAM][0]: 0.4423770835411924
# total_per_energy[mobilenet_v3][SRAM][1]: 0.0026707691088420533
# total_per_energy[mobilenet_v3][SRAM][2]: 0.5546220151980688
# total_per_energy[mobilenet_v3][SRAM][3]: 0.00033013215189680667
#
#
# Running mobilenet_v3 with 128 x 128 RRAM with 32 nm in fast scenario
# Computes for layer 1: 10584.0
# Computes for layer 2: 3528.0
# Computes for layer 3: 6272.0
# Computes for layer 4: 25088.0
# Computes for layer 5: 3528.0
# Computes for layer 6: 9408.0
# Computes for layer 7: 10584.0
# Computes for layer 8: 3969.0
# Computes for layer 9: 10584.0
# Computes for layer 10: 10584.0
# Computes for layer 11: 2756.25
# Computes for layer 12: 3.375
# Computes for layer 13: 3.375
# Computes for layer 14: 4410.0
# Computes for layer 15: 7350.0
# Computes for layer 16: 4593.75
# Computes for layer 17: 7.5
# Computes for layer 18: 7.5
# Computes for layer 19: 7350.0
# Computes for layer 20: 7350.0
# Computes for layer 21: 4593.75
# Computes for layer 22: 7.5
# Computes for layer 23: 7.5
# Computes for layer 24: 7350.0
# Computes for layer 25: 14700.0
# Computes for layer 26: 826.875
# Computes for layer 27: 7350.0
# Computes for layer 28: 6125.0
# Computes for layer 29: 689.0625
# Computes for layer 30: 6125.0
# Computes for layer 31: 5635.0
# Computes for layer 32: 633.9375
# Computes for layer 33: 5635.0
# Computes for layer 34: 5635.0
# Computes for layer 35: 633.9375
# Computes for layer 36: 5635.0
# Computes for layer 37: 14700.0
# Computes for layer 38: 1653.75
# Computes for layer 39: 112.5
# Computes for layer 40: 112.5
# Computes for layer 41: 20580.0
# Computes for layer 42: 28812.0
# Computes for layer 43: 2315.25
# Computes for layer 44: 220.5
# Computes for layer 45: 220.5
# Computes for layer 46: 28812.0
# Computes for layer 47: 28812.0
# Computes for layer 48: 1607.8125
# Computes for layer 49: 220.5
# Computes for layer 50: 220.5
# Computes for layer 51: 10290.0
# Computes for layer 52: 14700.0
# Computes for layer 53: 2296.875
# Computes for layer 54: 450.0
# Computes for layer 55: 450.0
# Computes for layer 56: 14700.0
# Computes for layer 57: 14700.0
# Computes for layer 58: 2296.875
# Computes for layer 59: 450.0
# Computes for layer 60: 450.0
# Computes for layer 61: 14700.0
# Computes for layer 62: 14700.0
# Computes for layer 63: 2400.0
# Computes for layer 64: 2500.0
#
# Overall energy for DNN mobilenet_v3: 1000000000000035.4 fJ
# total_per_energy[mobilenet_v3][RRAM][0]: 0.48565121412061124
# total_per_energy[mobilenet_v3][RRAM][1]: 4.8880479347185365e-12
# total_per_energy[mobilenet_v3][RRAM][2]: 0.4572690003188519
# total_per_energy[mobilenet_v3][RRAM][3]: 0.057079785555648736
#
#
# Running mobilebert with 128 x 128 SRAM with 32 nm in fast scenario
# Computes for layer 1: 53376.0
# Computes for layer 2: 17792.0
# Computes for layer 3: 17792.0
# Computes for layer 4: 4448.0
# Computes for layer 5: 4448.0
# Computes for layer 6: 17792.0
# Computes for layer 7: 34.75
# Computes for layer 8: 150.9453125
# Computes for layer 9: 4448.0
# Computes for layer 10: 17792.0
# Computes for layer 11: 17792.0
# Computes for layer 12: 17792.0
# Computes for layer 13: 17792.0
# Computes for layer 14: 17792.0
# Computes for layer 15: 17792.0
# Computes for layer 16: 17792.0
# Computes for layer 17: 17792.0
# Computes for layer 18: 17792.0
# Computes for layer 19: 17792.0
# Computes for layer 20: 17792.0
# Computes for layer 21: 4448.0
# Computes for layer 22: 4448.0
# Computes for layer 23: 17792.0
# Computes for layer 24: 34.75
# Computes for layer 25: 150.9453125
# Computes for layer 26: 4448.0
# Computes for layer 27: 17792.0
# Computes for layer 28: 17792.0
# Computes for layer 29: 17792.0
# Computes for layer 30: 17792.0
# Computes for layer 31: 17792.0
# Computes for layer 32: 17792.0
# Computes for layer 33: 17792.0
# Computes for layer 34: 17792.0
# Computes for layer 35: 17792.0
# Computes for layer 36: 17792.0
# Computes for layer 37: 17792.0
# Computes for layer 38: 4448.0
# Computes for layer 39: 4448.0
# Computes for layer 40: 17792.0
# Computes for layer 41: 34.75
# Computes for layer 42: 150.9453125
# Computes for layer 43: 4448.0
# Computes for layer 44: 17792.0
# Computes for layer 45: 17792.0
# Computes for layer 46: 17792.0
# Computes for layer 47: 17792.0
# Computes for layer 48: 17792.0
# Computes for layer 49: 17792.0
# Computes for layer 50: 17792.0
# Computes for layer 51: 17792.0
# Computes for layer 52: 17792.0
# Computes for layer 53: 17792.0
# Computes for layer 54: 17792.0
# Computes for layer 55: 4448.0
# Computes for layer 56: 4448.0
# Computes for layer 57: 17792.0
# Computes for layer 58: 34.75
# Computes for layer 59: 150.9453125
# Computes for layer 60: 4448.0
# Computes for layer 61: 17792.0
# Computes for layer 62: 17792.0
# Computes for layer 63: 17792.0
# Computes for layer 64: 17792.0
# Computes for layer 65: 17792.0
# Computes for layer 66: 17792.0
# Computes for layer 67: 17792.0
# Computes for layer 68: 17792.0
# Computes for layer 69: 17792.0
# Computes for layer 70: 17792.0
# Computes for layer 71: 17792.0
# Computes for layer 72: 4448.0
# Computes for layer 73: 4448.0
# Computes for layer 74: 17792.0
# Computes for layer 75: 34.75
# Computes for layer 76: 150.9453125
# Computes for layer 77: 4448.0
# Computes for layer 78: 17792.0
# Computes for layer 79: 17792.0
# Computes for layer 80: 17792.0
# Computes for layer 81: 17792.0
# Computes for layer 82: 17792.0
# Computes for layer 83: 17792.0
# Computes for layer 84: 17792.0
# Computes for layer 85: 17792.0
# Computes for layer 86: 17792.0
# Computes for layer 87: 17792.0
# Computes for layer 88: 17792.0
# Computes for layer 89: 4448.0
# Computes for layer 90: 4448.0
# Computes for layer 91: 17792.0
# Computes for layer 92: 34.75
# Computes for layer 93: 150.9453125
# Computes for layer 94: 4448.0
# Computes for layer 95: 17792.0
# Computes for layer 96: 17792.0
# Computes for layer 97: 17792.0
# Computes for layer 98: 17792.0
# Computes for layer 99: 17792.0
# Computes for layer 100: 17792.0
# Computes for layer 101: 17792.0
# Computes for layer 102: 17792.0
# Computes for layer 103: 17792.0
# Computes for layer 104: 17792.0
# Computes for layer 105: 17792.0
# Computes for layer 106: 4448.0
# Computes for layer 107: 4448.0
# Computes for layer 108: 17792.0
# Computes for layer 109: 34.75
# Computes for layer 110: 150.9453125
# Computes for layer 111: 4448.0
# Computes for layer 112: 17792.0
# Computes for layer 113: 17792.0
# Computes for layer 114: 17792.0
# Computes for layer 115: 17792.0
# Computes for layer 116: 17792.0
# Computes for layer 117: 17792.0
# Computes for layer 118: 17792.0
# Computes for layer 119: 17792.0
# Computes for layer 120: 17792.0
# Computes for layer 121: 17792.0
# Computes for layer 122: 17792.0
# Computes for layer 123: 4448.0
# Computes for layer 124: 4448.0
# Computes for layer 125: 17792.0
# Computes for layer 126: 34.75
# Computes for layer 127: 150.9453125
# Computes for layer 128: 4448.0
# Computes for layer 129: 17792.0
# Computes for layer 130: 17792.0
# Computes for layer 131: 17792.0
# Computes for layer 132: 17792.0
# Computes for layer 133: 17792.0
# Computes for layer 134: 17792.0
# Computes for layer 135: 17792.0
# Computes for layer 136: 17792.0
# Computes for layer 137: 17792.0
# Computes for layer 138: 17792.0
# Computes for layer 139: 17792.0
# Computes for layer 140: 4448.0
# Computes for layer 141: 4448.0
# Computes for layer 142: 17792.0
# Computes for layer 143: 34.75
# Computes for layer 144: 150.9453125
# Computes for layer 145: 4448.0
# Computes for layer 146: 17792.0
# Computes for layer 147: 17792.0
# Computes for layer 148: 17792.0
# Computes for layer 149: 17792.0
# Computes for layer 150: 17792.0
# Computes for layer 151: 17792.0
# Computes for layer 152: 17792.0
# Computes for layer 153: 17792.0
# Computes for layer 154: 17792.0
# Computes for layer 155: 17792.0
# Computes for layer 156: 17792.0
# Computes for layer 157: 4448.0
# Computes for layer 158: 4448.0
# Computes for layer 159: 17792.0
# Computes for layer 160: 34.75
# Computes for layer 161: 150.9453125
# Computes for layer 162: 4448.0
# Computes for layer 163: 17792.0
# Computes for layer 164: 17792.0
# Computes for layer 165: 17792.0
# Computes for layer 166: 17792.0
# Computes for layer 167: 17792.0
# Computes for layer 168: 17792.0
# Computes for layer 169: 17792.0
# Computes for layer 170: 17792.0
# Computes for layer 171: 17792.0
# Computes for layer 172: 17792.0
# Computes for layer 173: 17792.0
# Computes for layer 174: 4448.0
# Computes for layer 175: 4448.0
# Computes for layer 176: 17792.0
# Computes for layer 177: 34.75
# Computes for layer 178: 150.9453125
# Computes for layer 179: 4448.0
# Computes for layer 180: 17792.0
# Computes for layer 181: 17792.0
# Computes for layer 182: 17792.0
# Computes for layer 183: 17792.0
# Computes for layer 184: 17792.0
# Computes for layer 185: 17792.0
# Computes for layer 186: 17792.0
# Computes for layer 187: 17792.0
# Computes for layer 188: 17792.0
# Computes for layer 189: 17792.0
# Computes for layer 190: 17792.0
# Computes for layer 191: 4448.0
# Computes for layer 192: 4448.0
# Computes for layer 193: 17792.0
# Computes for layer 194: 34.75
# Computes for layer 195: 150.9453125
# Computes for layer 196: 4448.0
# Computes for layer 197: 17792.0
# Computes for layer 198: 17792.0
# Computes for layer 199: 17792.0
# Computes for layer 200: 17792.0
# Computes for layer 201: 17792.0
# Computes for layer 202: 17792.0
# Computes for layer 203: 17792.0
# Computes for layer 204: 17792.0
# Computes for layer 205: 17792.0
# Computes for layer 206: 17792.0
# Computes for layer 207: 17792.0
# Computes for layer 208: 4448.0
# Computes for layer 209: 4448.0
# Computes for layer 210: 17792.0
# Computes for layer 211: 34.75
# Computes for layer 212: 150.9453125
# Computes for layer 213: 4448.0
# Computes for layer 214: 17792.0
# Computes for layer 215: 17792.0
# Computes for layer 216: 17792.0
# Computes for layer 217: 17792.0
# Computes for layer 218: 17792.0
# Computes for layer 219: 17792.0
# Computes for layer 220: 17792.0
# Computes for layer 221: 17792.0
# Computes for layer 222: 17792.0
# Computes for layer 223: 17792.0
# Computes for layer 224: 17792.0
# Computes for layer 225: 4448.0
# Computes for layer 226: 4448.0
# Computes for layer 227: 17792.0
# Computes for layer 228: 34.75
# Computes for layer 229: 150.9453125
# Computes for layer 230: 4448.0
# Computes for layer 231: 17792.0
# Computes for layer 232: 17792.0
# Computes for layer 233: 17792.0
# Computes for layer 234: 17792.0
# Computes for layer 235: 17792.0
# Computes for layer 236: 17792.0
# Computes for layer 237: 17792.0
# Computes for layer 238: 17792.0
# Computes for layer 239: 17792.0
# Computes for layer 240: 17792.0
# Computes for layer 241: 17792.0
# Computes for layer 242: 4448.0
# Computes for layer 243: 4448.0
# Computes for layer 244: 17792.0
# Computes for layer 245: 34.75
# Computes for layer 246: 150.9453125
# Computes for layer 247: 4448.0
# Computes for layer 248: 17792.0
# Computes for layer 249: 17792.0
# Computes for layer 250: 17792.0
# Computes for layer 251: 17792.0
# Computes for layer 252: 17792.0
# Computes for layer 253: 17792.0
# Computes for layer 254: 17792.0
# Computes for layer 255: 17792.0
# Computes for layer 256: 17792.0
# Computes for layer 257: 17792.0
# Computes for layer 258: 17792.0
# Computes for layer 259: 4448.0
# Computes for layer 260: 4448.0
# Computes for layer 261: 17792.0
# Computes for layer 262: 34.75
# Computes for layer 263: 150.9453125
# Computes for layer 264: 4448.0
# Computes for layer 265: 17792.0
# Computes for layer 266: 17792.0
# Computes for layer 267: 17792.0
# Computes for layer 268: 17792.0
# Computes for layer 269: 17792.0
# Computes for layer 270: 17792.0
# Computes for layer 271: 17792.0
# Computes for layer 272: 17792.0
# Computes for layer 273: 17792.0
# Computes for layer 274: 17792.0
# Computes for layer 275: 17792.0
# Computes for layer 276: 4448.0
# Computes for layer 277: 4448.0
# Computes for layer 278: 17792.0
# Computes for layer 279: 34.75
# Computes for layer 280: 150.9453125
# Computes for layer 281: 4448.0
# Computes for layer 282: 17792.0
# Computes for layer 283: 17792.0
# Computes for layer 284: 17792.0
# Computes for layer 285: 17792.0
# Computes for layer 286: 17792.0
# Computes for layer 287: 17792.0
# Computes for layer 288: 17792.0
# Computes for layer 289: 17792.0
# Computes for layer 290: 17792.0
# Computes for layer 291: 17792.0
# Computes for layer 292: 17792.0
# Computes for layer 293: 4448.0
# Computes for layer 294: 4448.0
# Computes for layer 295: 17792.0
# Computes for layer 296: 34.75
# Computes for layer 297: 150.9453125
# Computes for layer 298: 4448.0
# Computes for layer 299: 17792.0
# Computes for layer 300: 17792.0
# Computes for layer 301: 17792.0
# Computes for layer 302: 17792.0
# Computes for layer 303: 17792.0
# Computes for layer 304: 17792.0
# Computes for layer 305: 17792.0
# Computes for layer 306: 17792.0
# Computes for layer 307: 17792.0
# Computes for layer 308: 17792.0
# Computes for layer 309: 17792.0
# Computes for layer 310: 4448.0
# Computes for layer 311: 4448.0
# Computes for layer 312: 17792.0
# Computes for layer 313: 34.75
# Computes for layer 314: 150.9453125
# Computes for layer 315: 4448.0
# Computes for layer 316: 17792.0
# Computes for layer 317: 17792.0
# Computes for layer 318: 17792.0
# Computes for layer 319: 17792.0
# Computes for layer 320: 17792.0
# Computes for layer 321: 17792.0
# Computes for layer 322: 17792.0
# Computes for layer 323: 17792.0
# Computes for layer 324: 17792.0
# Computes for layer 325: 17792.0
# Computes for layer 326: 17792.0
# Computes for layer 327: 4448.0
# Computes for layer 328: 4448.0
# Computes for layer 329: 17792.0
# Computes for layer 330: 34.75
# Computes for layer 331: 150.9453125
# Computes for layer 332: 4448.0
# Computes for layer 333: 17792.0
# Computes for layer 334: 17792.0
# Computes for layer 335: 17792.0
# Computes for layer 336: 17792.0
# Computes for layer 337: 17792.0
# Computes for layer 338: 17792.0
# Computes for layer 339: 17792.0
# Computes for layer 340: 17792.0
# Computes for layer 341: 17792.0
# Computes for layer 342: 17792.0
# Computes for layer 343: 17792.0
# Computes for layer 344: 4448.0
# Computes for layer 345: 4448.0
# Computes for layer 346: 17792.0
# Computes for layer 347: 34.75
# Computes for layer 348: 150.9453125
# Computes for layer 349: 4448.0
# Computes for layer 350: 17792.0
# Computes for layer 351: 17792.0
# Computes for layer 352: 17792.0
# Computes for layer 353: 17792.0
# Computes for layer 354: 17792.0
# Computes for layer 355: 17792.0
# Computes for layer 356: 17792.0
# Computes for layer 357: 17792.0
# Computes for layer 358: 17792.0
# Computes for layer 359: 17792.0
# Computes for layer 360: 17792.0
# Computes for layer 361: 4448.0
# Computes for layer 362: 4448.0
# Computes for layer 363: 17792.0
# Computes for layer 364: 34.75
# Computes for layer 365: 150.9453125
# Computes for layer 366: 4448.0
# Computes for layer 367: 17792.0
# Computes for layer 368: 17792.0
# Computes for layer 369: 17792.0
# Computes for layer 370: 17792.0
# Computes for layer 371: 17792.0
# Computes for layer 372: 17792.0
# Computes for layer 373: 17792.0
# Computes for layer 374: 17792.0
# Computes for layer 375: 17792.0
# Computes for layer 376: 17792.0
# Computes for layer 377: 17792.0
# Computes for layer 378: 4448.0
# Computes for layer 379: 4448.0
# Computes for layer 380: 17792.0
# Computes for layer 381: 34.75
# Computes for layer 382: 150.9453125
# Computes for layer 383: 4448.0
# Computes for layer 384: 17792.0
# Computes for layer 385: 17792.0
# Computes for layer 386: 17792.0
# Computes for layer 387: 17792.0
# Computes for layer 388: 17792.0
# Computes for layer 389: 17792.0
# Computes for layer 390: 17792.0
# Computes for layer 391: 17792.0
# Computes for layer 392: 17792.0
# Computes for layer 393: 17792.0
# Computes for layer 394: 17792.0
# Computes for layer 395: 4448.0
# Computes for layer 396: 4448.0
# Computes for layer 397: 17792.0
# Computes for layer 398: 34.75
# Computes for layer 399: 150.9453125
# Computes for layer 400: 4448.0
# Computes for layer 401: 17792.0
# Computes for layer 402: 17792.0
# Computes for layer 403: 17792.0
# Computes for layer 404: 17792.0
# Computes for layer 405: 17792.0
# Computes for layer 406: 17792.0
# Computes for layer 407: 17792.0
# Computes for layer 408: 17792.0
# Computes for layer 409: 17792.0
#
# Overall energy for DNN mobilebert: 1000000000000029.5 fJ
# total_per_energy[mobilebert][SRAM][0]: 0.4915375363859875
# total_per_energy[mobilebert][SRAM][1]: 0.0029805999546810053
# total_per_energy[mobilebert][SRAM][2]: 0.5037388227501635
# total_per_energy[mobilebert][SRAM][3]: 0.0017430409091680585
#
#
# Running mobilebert with 128 x 128 RRAM with 32 nm in fast scenario
# Computes for layer 1: 53376.0
# Computes for layer 2: 17792.0
# Computes for layer 3: 17792.0
# Computes for layer 4: 4448.0
# Computes for layer 5: 4448.0
# Computes for layer 6: 17792.0
# Computes for layer 7: 34.75
# Computes for layer 8: 150.9453125
# Computes for layer 9: 4448.0
# Computes for layer 10: 17792.0
# Computes for layer 11: 17792.0
# Computes for layer 12: 17792.0
# Computes for layer 13: 17792.0
# Computes for layer 14: 17792.0
# Computes for layer 15: 17792.0
# Computes for layer 16: 17792.0
# Computes for layer 17: 17792.0
# Computes for layer 18: 17792.0
# Computes for layer 19: 17792.0
# Computes for layer 20: 17792.0
# Computes for layer 21: 4448.0
# Computes for layer 22: 4448.0
# Computes for layer 23: 17792.0
# Computes for layer 24: 34.75
# Computes for layer 25: 150.9453125
# Computes for layer 26: 4448.0
# Computes for layer 27: 17792.0
# Computes for layer 28: 17792.0
# Computes for layer 29: 17792.0
# Computes for layer 30: 17792.0
# Computes for layer 31: 17792.0
# Computes for layer 32: 17792.0
# Computes for layer 33: 17792.0
# Computes for layer 34: 17792.0
# Computes for layer 35: 17792.0
# Computes for layer 36: 17792.0
# Computes for layer 37: 17792.0
# Computes for layer 38: 4448.0
# Computes for layer 39: 4448.0
# Computes for layer 40: 17792.0
# Computes for layer 41: 34.75
# Computes for layer 42: 150.9453125
# Computes for layer 43: 4448.0
# Computes for layer 44: 17792.0
# Computes for layer 45: 17792.0
# Computes for layer 46: 17792.0
# Computes for layer 47: 17792.0
# Computes for layer 48: 17792.0
# Computes for layer 49: 17792.0
# Computes for layer 50: 17792.0
# Computes for layer 51: 17792.0
# Computes for layer 52: 17792.0
# Computes for layer 53: 17792.0
# Computes for layer 54: 17792.0
# Computes for layer 55: 4448.0
# Computes for layer 56: 4448.0
# Computes for layer 57: 17792.0
# Computes for layer 58: 34.75
# Computes for layer 59: 150.9453125
# Computes for layer 60: 4448.0
# Computes for layer 61: 17792.0
# Computes for layer 62: 17792.0
# Computes for layer 63: 17792.0
# Computes for layer 64: 17792.0
# Computes for layer 65: 17792.0
# Computes for layer 66: 17792.0
# Computes for layer 67: 17792.0
# Computes for layer 68: 17792.0
# Computes for layer 69: 17792.0
# Computes for layer 70: 17792.0
# Computes for layer 71: 17792.0
# Computes for layer 72: 4448.0
# Computes for layer 73: 4448.0
# Computes for layer 74: 17792.0
# Computes for layer 75: 34.75
# Computes for layer 76: 150.9453125
# Computes for layer 77: 4448.0
# Computes for layer 78: 17792.0
# Computes for layer 79: 17792.0
# Computes for layer 80: 17792.0
# Computes for layer 81: 17792.0
# Computes for layer 82: 17792.0
# Computes for layer 83: 17792.0
# Computes for layer 84: 17792.0
# Computes for layer 85: 17792.0
# Computes for layer 86: 17792.0
# Computes for layer 87: 17792.0
# Computes for layer 88: 17792.0
# Computes for layer 89: 4448.0
# Computes for layer 90: 4448.0
# Computes for layer 91: 17792.0
# Computes for layer 92: 34.75
# Computes for layer 93: 150.9453125
# Computes for layer 94: 4448.0
# Computes for layer 95: 17792.0
# Computes for layer 96: 17792.0
# Computes for layer 97: 17792.0
# Computes for layer 98: 17792.0
# Computes for layer 99: 17792.0
# Computes for layer 100: 17792.0
# Computes for layer 101: 17792.0
# Computes for layer 102: 17792.0
# Computes for layer 103: 17792.0
# Computes for layer 104: 17792.0
# Computes for layer 105: 17792.0
# Computes for layer 106: 4448.0
# Computes for layer 107: 4448.0
# Computes for layer 108: 17792.0
# Computes for layer 109: 34.75
# Computes for layer 110: 150.9453125
# Computes for layer 111: 4448.0
# Computes for layer 112: 17792.0
# Computes for layer 113: 17792.0
# Computes for layer 114: 17792.0
# Computes for layer 115: 17792.0
# Computes for layer 116: 17792.0
# Computes for layer 117: 17792.0
# Computes for layer 118: 17792.0
# Computes for layer 119: 17792.0
# Computes for layer 120: 17792.0
# Computes for layer 121: 17792.0
# Computes for layer 122: 17792.0
# Computes for layer 123: 4448.0
# Computes for layer 124: 4448.0
# Computes for layer 125: 17792.0
# Computes for layer 126: 34.75
# Computes for layer 127: 150.9453125
# Computes for layer 128: 4448.0
# Computes for layer 129: 17792.0
# Computes for layer 130: 17792.0
# Computes for layer 131: 17792.0
# Computes for layer 132: 17792.0
# Computes for layer 133: 17792.0
# Computes for layer 134: 17792.0
# Computes for layer 135: 17792.0
# Computes for layer 136: 17792.0
# Computes for layer 137: 17792.0
# Computes for layer 138: 17792.0
# Computes for layer 139: 17792.0
# Computes for layer 140: 4448.0
# Computes for layer 141: 4448.0
# Computes for layer 142: 17792.0
# Computes for layer 143: 34.75
# Computes for layer 144: 150.9453125
# Computes for layer 145: 4448.0
# Computes for layer 146: 17792.0
# Computes for layer 147: 17792.0
# Computes for layer 148: 17792.0
# Computes for layer 149: 17792.0
# Computes for layer 150: 17792.0
# Computes for layer 151: 17792.0
# Computes for layer 152: 17792.0
# Computes for layer 153: 17792.0
# Computes for layer 154: 17792.0
# Computes for layer 155: 17792.0
# Computes for layer 156: 17792.0
# Computes for layer 157: 4448.0
# Computes for layer 158: 4448.0
# Computes for layer 159: 17792.0
# Computes for layer 160: 34.75
# Computes for layer 161: 150.9453125
# Computes for layer 162: 4448.0
# Computes for layer 163: 17792.0
# Computes for layer 164: 17792.0
# Computes for layer 165: 17792.0
# Computes for layer 166: 17792.0
# Computes for layer 167: 17792.0
# Computes for layer 168: 17792.0
# Computes for layer 169: 17792.0
# Computes for layer 170: 17792.0
# Computes for layer 171: 17792.0
# Computes for layer 172: 17792.0
# Computes for layer 173: 17792.0
# Computes for layer 174: 4448.0
# Computes for layer 175: 4448.0
# Computes for layer 176: 17792.0
# Computes for layer 177: 34.75
# Computes for layer 178: 150.9453125
# Computes for layer 179: 4448.0
# Computes for layer 180: 17792.0
# Computes for layer 181: 17792.0
# Computes for layer 182: 17792.0
# Computes for layer 183: 17792.0
# Computes for layer 184: 17792.0
# Computes for layer 185: 17792.0
# Computes for layer 186: 17792.0
# Computes for layer 187: 17792.0
# Computes for layer 188: 17792.0
# Computes for layer 189: 17792.0
# Computes for layer 190: 17792.0
# Computes for layer 191: 4448.0
# Computes for layer 192: 4448.0
# Computes for layer 193: 17792.0
# Computes for layer 194: 34.75
# Computes for layer 195: 150.9453125
# Computes for layer 196: 4448.0
# Computes for layer 197: 17792.0
# Computes for layer 198: 17792.0
# Computes for layer 199: 17792.0
# Computes for layer 200: 17792.0
# Computes for layer 201: 17792.0
# Computes for layer 202: 17792.0
# Computes for layer 203: 17792.0
# Computes for layer 204: 17792.0
# Computes for layer 205: 17792.0
# Computes for layer 206: 17792.0
# Computes for layer 207: 17792.0
# Computes for layer 208: 4448.0
# Computes for layer 209: 4448.0
# Computes for layer 210: 17792.0
# Computes for layer 211: 34.75
# Computes for layer 212: 150.9453125
# Computes for layer 213: 4448.0
# Computes for layer 214: 17792.0
# Computes for layer 215: 17792.0
# Computes for layer 216: 17792.0
# Computes for layer 217: 17792.0
# Computes for layer 218: 17792.0
# Computes for layer 219: 17792.0
# Computes for layer 220: 17792.0
# Computes for layer 221: 17792.0
# Computes for layer 222: 17792.0
# Computes for layer 223: 17792.0
# Computes for layer 224: 17792.0
# Computes for layer 225: 4448.0
# Computes for layer 226: 4448.0
# Computes for layer 227: 17792.0
# Computes for layer 228: 34.75
# Computes for layer 229: 150.9453125
# Computes for layer 230: 4448.0
# Computes for layer 231: 17792.0
# Computes for layer 232: 17792.0
# Computes for layer 233: 17792.0
# Computes for layer 234: 17792.0
# Computes for layer 235: 17792.0
# Computes for layer 236: 17792.0
# Computes for layer 237: 17792.0
# Computes for layer 238: 17792.0
# Computes for layer 239: 17792.0
# Computes for layer 240: 17792.0
# Computes for layer 241: 17792.0
# Computes for layer 242: 4448.0
# Computes for layer 243: 4448.0
# Computes for layer 244: 17792.0
# Computes for layer 245: 34.75
# Computes for layer 246: 150.9453125
# Computes for layer 247: 4448.0
# Computes for layer 248: 17792.0
# Computes for layer 249: 17792.0
# Computes for layer 250: 17792.0
# Computes for layer 251: 17792.0
# Computes for layer 252: 17792.0
# Computes for layer 253: 17792.0
# Computes for layer 254: 17792.0
# Computes for layer 255: 17792.0
# Computes for layer 256: 17792.0
# Computes for layer 257: 17792.0
# Computes for layer 258: 17792.0
# Computes for layer 259: 4448.0
# Computes for layer 260: 4448.0
# Computes for layer 261: 17792.0
# Computes for layer 262: 34.75
# Computes for layer 263: 150.9453125
# Computes for layer 264: 4448.0
# Computes for layer 265: 17792.0
# Computes for layer 266: 17792.0
# Computes for layer 267: 17792.0
# Computes for layer 268: 17792.0
# Computes for layer 269: 17792.0
# Computes for layer 270: 17792.0
# Computes for layer 271: 17792.0
# Computes for layer 272: 17792.0
# Computes for layer 273: 17792.0
# Computes for layer 274: 17792.0
# Computes for layer 275: 17792.0
# Computes for layer 276: 4448.0
# Computes for layer 277: 4448.0
# Computes for layer 278: 17792.0
# Computes for layer 279: 34.75
# Computes for layer 280: 150.9453125
# Computes for layer 281: 4448.0
# Computes for layer 282: 17792.0
# Computes for layer 283: 17792.0
# Computes for layer 284: 17792.0
# Computes for layer 285: 17792.0
# Computes for layer 286: 17792.0
# Computes for layer 287: 17792.0
# Computes for layer 288: 17792.0
# Computes for layer 289: 17792.0
# Computes for layer 290: 17792.0
# Computes for layer 291: 17792.0
# Computes for layer 292: 17792.0
# Computes for layer 293: 4448.0
# Computes for layer 294: 4448.0
# Computes for layer 295: 17792.0
# Computes for layer 296: 34.75
# Computes for layer 297: 150.9453125
# Computes for layer 298: 4448.0
# Computes for layer 299: 17792.0
# Computes for layer 300: 17792.0
# Computes for layer 301: 17792.0
# Computes for layer 302: 17792.0
# Computes for layer 303: 17792.0
# Computes for layer 304: 17792.0
# Computes for layer 305: 17792.0
# Computes for layer 306: 17792.0
# Computes for layer 307: 17792.0
# Computes for layer 308: 17792.0
# Computes for layer 309: 17792.0
# Computes for layer 310: 4448.0
# Computes for layer 311: 4448.0
# Computes for layer 312: 17792.0
# Computes for layer 313: 34.75
# Computes for layer 314: 150.9453125
# Computes for layer 315: 4448.0
# Computes for layer 316: 17792.0
# Computes for layer 317: 17792.0
# Computes for layer 318: 17792.0
# Computes for layer 319: 17792.0
# Computes for layer 320: 17792.0
# Computes for layer 321: 17792.0
# Computes for layer 322: 17792.0
# Computes for layer 323: 17792.0
# Computes for layer 324: 17792.0
# Computes for layer 325: 17792.0
# Computes for layer 326: 17792.0
# Computes for layer 327: 4448.0
# Computes for layer 328: 4448.0
# Computes for layer 329: 17792.0
# Computes for layer 330: 34.75
# Computes for layer 331: 150.9453125
# Computes for layer 332: 4448.0
# Computes for layer 333: 17792.0
# Computes for layer 334: 17792.0
# Computes for layer 335: 17792.0
# Computes for layer 336: 17792.0
# Computes for layer 337: 17792.0
# Computes for layer 338: 17792.0
# Computes for layer 339: 17792.0
# Computes for layer 340: 17792.0
# Computes for layer 341: 17792.0
# Computes for layer 342: 17792.0
# Computes for layer 343: 17792.0
# Computes for layer 344: 4448.0
# Computes for layer 345: 4448.0
# Computes for layer 346: 17792.0
# Computes for layer 347: 34.75
# Computes for layer 348: 150.9453125
# Computes for layer 349: 4448.0
# Computes for layer 350: 17792.0
# Computes for layer 351: 17792.0
# Computes for layer 352: 17792.0
# Computes for layer 353: 17792.0
# Computes for layer 354: 17792.0
# Computes for layer 355: 17792.0
# Computes for layer 356: 17792.0
# Computes for layer 357: 17792.0
# Computes for layer 358: 17792.0
# Computes for layer 359: 17792.0
# Computes for layer 360: 17792.0
# Computes for layer 361: 4448.0
# Computes for layer 362: 4448.0
# Computes for layer 363: 17792.0
# Computes for layer 364: 34.75
# Computes for layer 365: 150.9453125
# Computes for layer 366: 4448.0
# Computes for layer 367: 17792.0
# Computes for layer 368: 17792.0
# Computes for layer 369: 17792.0
# Computes for layer 370: 17792.0
# Computes for layer 371: 17792.0
# Computes for layer 372: 17792.0
# Computes for layer 373: 17792.0
# Computes for layer 374: 17792.0
# Computes for layer 375: 17792.0
# Computes for layer 376: 17792.0
# Computes for layer 377: 17792.0
# Computes for layer 378: 4448.0
# Computes for layer 379: 4448.0
# Computes for layer 380: 17792.0
# Computes for layer 381: 34.75
# Computes for layer 382: 150.9453125
# Computes for layer 383: 4448.0
# Computes for layer 384: 17792.0
# Computes for layer 385: 17792.0
# Computes for layer 386: 17792.0
# Computes for layer 387: 17792.0
# Computes for layer 388: 17792.0
# Computes for layer 389: 17792.0
# Computes for layer 390: 17792.0
# Computes for layer 391: 17792.0
# Computes for layer 392: 17792.0
# Computes for layer 393: 17792.0
# Computes for layer 394: 17792.0
# Computes for layer 395: 4448.0
# Computes for layer 396: 4448.0
# Computes for layer 397: 17792.0
# Computes for layer 398: 34.75
# Computes for layer 399: 150.9453125
# Computes for layer 400: 4448.0
# Computes for layer 401: 17792.0
# Computes for layer 402: 17792.0
# Computes for layer 403: 17792.0
# Computes for layer 404: 17792.0
# Computes for layer 405: 17792.0
# Computes for layer 406: 17792.0
# Computes for layer 407: 17792.0
# Computes for layer 408: 17792.0
# Computes for layer 409: 17792.0
#
# Overall energy for DNN mobilebert: 1000000000000036.1 fJ
# total_per_energy[mobilebert][RRAM][0]: 0.46695402298806443
# total_per_energy[mobilebert][RRAM][1]: 1.1738505747140433e-12
# total_per_energy[mobilebert][RRAM][2]: 0.35919540229849845
# total_per_energy[mobilebert][RRAM][3]: 0.17385057471226323

# %%
display_markdown(
    """
### Calculating Area in fast scenario

"""
)

# Initialize lists for each DNN
num_dnns = len(dnn_list)
total_area = [0] * (2 * num_dnns)
total_adc_area = [0] * (2 * num_dnns)
total_col_area = [0] * (2 * num_dnns)
total_row_area = [0] * (2 * num_dnns)
total_cim_unit_area = [0] * (2 * num_dnns)
total_macro = [0] * (2 * num_dnns)
energy = [0] * (2 * num_dnns)
throughput = [0] * (2 * num_dnns)

# Loop through both DNNs and extract their outputs for SRAM and RRAM
for i, dnn in enumerate(dnn_list):
    total_area[2 * i], total_adc_area[2 * i], total_col_area[2 * i], total_row_area[2 * i], total_cim_unit_area[2 * i], total_macro[2 * i], energy[2 * i], throughput[2 * i] = extract_outputs(f"SRAM_{dnn}_{array_sizes}")
    
    total_area[2 * i + 1], total_adc_area[2 * i + 1], total_col_area[2 * i + 1], total_row_area[2 * i + 1], total_cim_unit_area[2 * i + 1], total_macro[2 * i + 1], energy[2 * i + 1], throughput[2 * i + 1] = extract_outputs(f"RRAM_{dnn}_{array_sizes}")
# Out:
# ### Calculating Area in fast scenario
# ../outputs/SRAM_mobilenet_v3_128/
# Model 	 Energy/inference (J) 	 Area (mm2) 	 Throughput (inf/s)
# Processing layer: SRAM_mobilenet_v3_128_layer_1
# Cycle: 12544
#
# Total Cycle: 12544.0
# All macro: 1
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 28515.1
#
# All macro: 1
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 1054.65
#
# All macro: 1
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 928.496
#
# All macro: 1
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 5368.70912
#
# Total Area for layer 1: 35866.95512
#
# Total Macro for layer 1: 1
#
# Total Area for all layers: 35866.95512
# Total Area for ADC across all layers: 28515.1
# Processing layer: SRAM_mobilenet_v3_128_layer_2
# Cycle: 12544
#
# Total Cycle: 25088.0
# Size: 16
# All macro: 16
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 456241.6
#
# Size: 16
# All macro: 16
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 16874.4
#
# Size: 16
# All macro: 16
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 14855.936
#
# Size: 16
# All macro: 16
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 85899.34592
#
# Total Area for layer 2: 573871.28192
#
# Total Macro for layer 2: 17
#
# Total Area for all layers: 609738.23704
# Total Area for ADC across all layers: 484756.69999999995
# Processing layer: SRAM_mobilenet_v3_128_layer_3
# Cycle: 12544
#
# Total Cycle: 37632.0
# All macro: 1
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 28515.1
#
# All macro: 1
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 1054.65
#
# All macro: 1
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 928.496
#
# All macro: 1
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 5368.70912
#
# Total Area for layer 3: 35866.95512
#
# Total Macro for layer 3: 18
#
# Total Area for all layers: 645605.1921600001
# Total Area for ADC across all layers: 513271.79999999993
# Processing layer: SRAM_mobilenet_v3_128_layer_4
# Cycle: 12544
#
# Total Cycle: 50176.0
# All macro: 1
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 28515.1
#
# All macro: 1
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 1054.65
#
# All macro: 1
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 928.496
#
# All macro: 1
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 5368.70912
#
# Total Area for layer 4: 35866.95512
#
# Total Macro for layer 4: 19
#
# Total Area for all layers: 681472.1472800002
# Total Area for ADC across all layers: 541786.8999999999
# Processing layer: SRAM_mobilenet_v3_128_layer_5
# Cycle: 3136
#
# Total Cycle: 53312.0
# Size: 64
# All macro: 64
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 1824966.4
#
# Size: 64
# All macro: 64
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 67497.6
#
# Size: 64
# All macro: 64
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 59423.744
#
# Size: 64
# All macro: 64
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 343597.38368
#
# Total Area for layer 5: 2295485.12768
#
# Total Macro for layer 5: 83
#
# Total Area for all layers: 2976957.27496
# Total Area for ADC across all layers: 2366753.3
# Processing layer: SRAM_mobilenet_v3_128_layer_6
# Cycle: 3136
#
# Total Cycle: 56448.0
# All macro: 1
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 28515.1
#
# All macro: 1
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 1054.65
#
# All macro: 1
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 928.496
#
# All macro: 1
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 5368.70912
#
# Total Area for layer 6: 35866.95512
#
# Total Macro for layer 6: 84
#
# Total Area for all layers: 3012824.23008
# Total Area for ADC across all layers: 2395268.4
# Processing layer: SRAM_mobilenet_v3_128_layer_7
# Cycle: 3136
#
# Total Cycle: 59584.0
# Size: 2
# All macro: 2
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 57030.2
#
# Size: 2
# All macro: 2
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 2109.3
#
# Size: 2
# All macro: 2
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 1856.992
#
# Size: 2
# All macro: 2
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 10737.41824
#
# Total Area for layer 7: 71733.91024
#
# Total Macro for layer 7: 86
#
# Total Area for all layers: 3084558.1403200002
# Total Area for ADC across all layers: 2452298.6
# Processing layer: SRAM_mobilenet_v3_128_layer_8
# Cycle: 3136
#
# Total Cycle: 62720.0
# Size: 72
# All macro: 72
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 2053087.2
#
# Size: 72
# All macro: 72
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 75934.8
#
# Size: 72
# All macro: 72
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 66851.712
#
# Size: 72
# All macro: 72
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 386547.05664
#
# Total Area for layer 8: 2582420.76864
#
# Total Macro for layer 8: 158
#
# Total Area for all layers: 5666978.90896
# Total Area for ADC across all layers: 4505385.8
# Processing layer: SRAM_mobilenet_v3_128_layer_9
# Cycle: 3136
#
# Total Cycle: 65856.0
# All macro: 1
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 28515.1
#
# All macro: 1
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 1054.65
#
# All macro: 1
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 928.496
#
# All macro: 1
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 5368.70912
#
# Total Area for layer 9: 35866.95512
#
# Total Macro for layer 9: 159
#
# Total Area for all layers: 5702845.86408
# Total Area for ADC across all layers: 4533900.899999999
# Processing layer: SRAM_mobilenet_v3_128_layer_10
# Cycle: 3136
#
# Total Cycle: 68992.0
# Size: 2
# All macro: 2
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 57030.2
#
# Size: 2
# All macro: 2
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 2109.3
#
# Size: 2
# All macro: 2
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 1856.992
#
# Size: 2
# All macro: 2
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 10737.41824
#
# Total Area for layer 10: 71733.91024
#
# Total Macro for layer 10: 161
#
# Total Area for all layers: 5774579.77432
# Total Area for ADC across all layers: 4590931.1
# Processing layer: SRAM_mobilenet_v3_128_layer_11
# Cycle: 784
#
# Total Cycle: 69776.0
# Size: 72
# All macro: 72
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 2053087.2
#
# Size: 72
# All macro: 72
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 75934.8
#
# Size: 72
# All macro: 72
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 66851.712
#
# Size: 72
# All macro: 72
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 386547.05664
#
# Total Area for layer 11: 2582420.76864
#
# Total Macro for layer 11: 233
#
# Total Area for all layers: 8357000.542959999
# Total Area for ADC across all layers: 6644018.3
# Processing layer: SRAM_mobilenet_v3_128_layer_12
# Cycle: 1
#
# Total Cycle: 69777.0
# All macro: 1
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 28515.1
#
# All macro: 1
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 1054.65
#
# All macro: 1
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 928.496
#
# All macro: 1
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 5368.70912
#
# Total Area for layer 12: 35866.95512
#
# Total Macro for layer 12: 234
#
# Total Area for all layers: 8392867.498079998
# Total Area for ADC across all layers: 6672533.399999999
# Processing layer: SRAM_mobilenet_v3_128_layer_13
# Cycle: 1
#
# Total Cycle: 69778.0
# Size: 2
# All macro: 2
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 57030.2
#
# Size: 2
# All macro: 2
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 2109.3
#
# Size: 2
# All macro: 2
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 1856.992
#
# Size: 2
# All macro: 2
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 10737.41824
#
# Total Area for layer 13: 71733.91024
#
# Total Macro for layer 13: 236
#
# Total Area for all layers: 8464601.408319999
# Total Area for ADC across all layers: 6729563.6
# Processing layer: SRAM_mobilenet_v3_128_layer_14
# Cycle: 784
#
# Total Cycle: 70562.0
# All macro: 1
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 28515.1
#
# All macro: 1
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 1054.65
#
# All macro: 1
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 928.496
#
# All macro: 1
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 5368.70912
#
# Total Area for layer 14: 35866.95512
#
# Total Macro for layer 14: 237
#
# Total Area for all layers: 8500468.363439998
# Total Area for ADC across all layers: 6758078.699999999
# Processing layer: SRAM_mobilenet_v3_128_layer_15
# Cycle: 784
#
# Total Cycle: 71346.0
# Size: 2
# All macro: 2
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 57030.2
#
# Size: 2
# All macro: 2
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 2109.3
#
# Size: 2
# All macro: 2
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 1856.992
#
# Size: 2
# All macro: 2
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 10737.41824
#
# Total Area for layer 15: 71733.91024
#
# Total Macro for layer 15: 239
#
# Total Area for all layers: 8572202.273679998
# Total Area for ADC across all layers: 6815108.899999999
# Processing layer: SRAM_mobilenet_v3_128_layer_16
# Cycle: 784
#
# Total Cycle: 72130.0
# Size: 120
# All macro: 120
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 3421812.0
#
# Size: 120
# All macro: 120
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 126558.00000000001
#
# Size: 120
# All macro: 120
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 111419.52
#
# Size: 120
# All macro: 120
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 644245.0944000001
#
# Total Area for layer 16: 4304034.6144
#
# Total Macro for layer 16: 359
#
# Total Area for all layers: 12876236.888079997
# Total Area for ADC across all layers: 10236920.899999999
# Processing layer: SRAM_mobilenet_v3_128_layer_17
# Cycle: 1
#
# Total Cycle: 72131.0
# All macro: 1
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 28515.1
#
# All macro: 1
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 1054.65
#
# All macro: 1
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 928.496
#
# All macro: 1
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 5368.70912
#
# Total Area for layer 17: 35866.95512
#
# Total Macro for layer 17: 360
#
# Total Area for all layers: 12912103.843199996
# Total Area for ADC across all layers: 10265435.999999998
# Processing layer: SRAM_mobilenet_v3_128_layer_18
# Cycle: 1
#
# Total Cycle: 72132.0
# Size: 2
# All macro: 2
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 57030.2
#
# Size: 2
# All macro: 2
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 2109.3
#
# Size: 2
# All macro: 2
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 1856.992
#
# Size: 2
# All macro: 2
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 10737.41824
#
# Total Area for layer 18: 71733.91024
#
# Total Macro for layer 18: 362
#
# Total Area for all layers: 12983837.753439996
# Total Area for ADC across all layers: 10322466.199999997
# Processing layer: SRAM_mobilenet_v3_128_layer_19
# Cycle: 784
#
# Total Cycle: 72916.0
# All macro: 1
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 28515.1
#
# All macro: 1
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 1054.65
#
# All macro: 1
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 928.496
#
# All macro: 1
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 5368.70912
#
# Total Area for layer 19: 35866.95512
#
# Total Macro for layer 19: 363
#
# Total Area for all layers: 13019704.708559996
# Total Area for ADC across all layers: 10350981.299999997
# Processing layer: SRAM_mobilenet_v3_128_layer_20
# Cycle: 784
#
# Total Cycle: 73700.0
# Size: 2
# All macro: 2
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 57030.2
#
# Size: 2
# All macro: 2
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 2109.3
#
# Size: 2
# All macro: 2
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 1856.992
#
# Size: 2
# All macro: 2
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 10737.41824
#
# Total Area for layer 20: 71733.91024
#
# Total Macro for layer 20: 365
#
# Total Area for all layers: 13091438.618799996
# Total Area for ADC across all layers: 10408011.499999996
# Processing layer: SRAM_mobilenet_v3_128_layer_21
# Cycle: 784
#
# Total Cycle: 74484.0
# Size: 120
# All macro: 120
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 3421812.0
#
# Size: 120
# All macro: 120
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 126558.00000000001
#
# Size: 120
# All macro: 120
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 111419.52
#
# Size: 120
# All macro: 120
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 644245.0944000001
#
# Total Area for layer 21: 4304034.6144
#
# Total Macro for layer 21: 485
#
# Total Area for all layers: 17395473.233199995
# Total Area for ADC across all layers: 13829823.499999996
# Processing layer: SRAM_mobilenet_v3_128_layer_22
# Cycle: 1
#
# Total Cycle: 74485.0
# All macro: 1
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 28515.1
#
# All macro: 1
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 1054.65
#
# All macro: 1
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 928.496
#
# All macro: 1
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 5368.70912
#
# Total Area for layer 22: 35866.95512
#
# Total Macro for layer 22: 486
#
# Total Area for all layers: 17431340.188319996
# Total Area for ADC across all layers: 13858338.599999996
# Processing layer: SRAM_mobilenet_v3_128_layer_23
# Cycle: 1
#
# Total Cycle: 74486.0
# Size: 2
# All macro: 2
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 57030.2
#
# Size: 2
# All macro: 2
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 2109.3
#
# Size: 2
# All macro: 2
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 1856.992
#
# Size: 2
# All macro: 2
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 10737.41824
#
# Total Area for layer 23: 71733.91024
#
# Total Macro for layer 23: 488
#
# Total Area for all layers: 17503074.098559994
# Total Area for ADC across all layers: 13915368.799999995
# Processing layer: SRAM_mobilenet_v3_128_layer_24
# Cycle: 784
#
# Total Cycle: 75270.0
# All macro: 1
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 28515.1
#
# All macro: 1
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 1054.65
#
# All macro: 1
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 928.496
#
# All macro: 1
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 5368.70912
#
# Total Area for layer 24: 35866.95512
#
# Total Macro for layer 24: 489
#
# Total Area for all layers: 17538941.053679995
# Total Area for ADC across all layers: 13943883.899999995
# Processing layer: SRAM_mobilenet_v3_128_layer_25
# Cycle: 784
#
# Total Cycle: 76054.0
# Size: 4
# All macro: 4
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 114060.4
#
# Size: 4
# All macro: 4
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 4218.6
#
# Size: 4
# All macro: 4
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 3713.984
#
# Size: 4
# All macro: 4
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 21474.83648
#
# Total Area for layer 25: 143467.82048
#
# Total Macro for layer 25: 493
#
# Total Area for all layers: 17682408.874159995
# Total Area for ADC across all layers: 14057944.299999995
# Processing layer: SRAM_mobilenet_v3_128_layer_26
# Cycle: 196
#
# Total Cycle: 76250.0
# Size: 240
# All macro: 240
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 6843624.0
#
# Size: 240
# All macro: 240
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 253116.00000000003
#
# Size: 240
# All macro: 240
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 222839.04
#
# Size: 240
# All macro: 240
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 1288490.1888000001
#
# Total Area for layer 26: 8608069.2288
#
# Total Macro for layer 26: 733
#
# Total Area for all layers: 26290478.102959998
# Total Area for ADC across all layers: 20901568.299999997
# Processing layer: SRAM_mobilenet_v3_128_layer_27
# Cycle: 196
#
# Total Cycle: 76446.0
# Size: 2
# Size: 2
# All macro: 4
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 114060.4
#
# Size: 2
# Size: 2
# All macro: 4
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 4218.6
#
# Size: 2
# Size: 2
# All macro: 4
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 3713.984
#
# Size: 2
# Size: 2
# All macro: 4
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 21474.83648
#
# Total Area for layer 27: 143467.82048
#
# Total Macro for layer 27: 737
#
# Total Area for all layers: 26433945.92344
# Total Area for ADC across all layers: 21015628.699999996
# Processing layer: SRAM_mobilenet_v3_128_layer_28
# Cycle: 196
#
# Total Cycle: 76642.0
# Size: 4
# All macro: 4
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 114060.4
#
# Size: 4
# All macro: 4
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 4218.6
#
# Size: 4
# All macro: 4
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 3713.984
#
# Size: 4
# All macro: 4
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 21474.83648
#
# Total Area for layer 28: 143467.82048
#
# Total Macro for layer 28: 741
#
# Total Area for all layers: 26577413.74392
# Total Area for ADC across all layers: 21129689.099999994
# Processing layer: SRAM_mobilenet_v3_128_layer_29
# Cycle: 196
#
# Total Cycle: 76838.0
# Size: 200
# All macro: 200
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 5703020.0
#
# Size: 200
# All macro: 200
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 210930.00000000003
#
# Size: 200
# All macro: 200
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 185699.19999999998
#
# Size: 200
# All macro: 200
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 1073741.824
#
# Total Area for layer 29: 7173391.024
#
# Total Macro for layer 29: 941
#
# Total Area for all layers: 33750804.76792
# Total Area for ADC across all layers: 26832709.099999994
# Processing layer: SRAM_mobilenet_v3_128_layer_30
# Cycle: 196
#
# Total Cycle: 77034.0
# Size: 2
# Size: 2
# All macro: 4
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 114060.4
#
# Size: 2
# Size: 2
# All macro: 4
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 4218.6
#
# Size: 2
# Size: 2
# All macro: 4
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 3713.984
#
# Size: 2
# Size: 2
# All macro: 4
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 21474.83648
#
# Total Area for layer 30: 143467.82048
#
# Total Macro for layer 30: 945
#
# Total Area for all layers: 33894272.5884
# Total Area for ADC across all layers: 26946769.499999993
# Processing layer: SRAM_mobilenet_v3_128_layer_31
# Cycle: 196
#
# Total Cycle: 77230.0
# Size: 3
# All macro: 3
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 85545.29999999999
#
# Size: 3
# All macro: 3
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 3163.9500000000003
#
# Size: 3
# All macro: 3
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 2785.488
#
# Size: 3
# All macro: 3
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 16106.127360000002
#
# Total Area for layer 31: 107600.86535999998
#
# Total Macro for layer 31: 948
#
# Total Area for all layers: 34001873.45376
# Total Area for ADC across all layers: 27032314.799999993
# Processing layer: SRAM_mobilenet_v3_128_layer_32
# Cycle: 196
#
# Total Cycle: 77426.0
# Size: 184
# All macro: 184
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 5246778.399999999
#
# Size: 184
# All macro: 184
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 194055.6
#
# Size: 184
# All macro: 184
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 170843.264
#
# Size: 184
# All macro: 184
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 987842.47808
#
# Total Area for layer 32: 6599519.742079999
#
# Total Macro for layer 32: 1132
#
# Total Area for all layers: 40601393.19584
# Total Area for ADC across all layers: 32279093.19999999
# Processing layer: SRAM_mobilenet_v3_128_layer_33
# Cycle: 196
#
# Total Cycle: 77622.0
# Size: 2
# Size: 2
# All macro: 4
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 114060.4
#
# Size: 2
# Size: 2
# All macro: 4
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 4218.6
#
# Size: 2
# Size: 2
# All macro: 4
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 3713.984
#
# Size: 2
# Size: 2
# All macro: 4
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 21474.83648
#
# Total Area for layer 33: 143467.82048
#
# Total Macro for layer 33: 1136
#
# Total Area for all layers: 40744861.01632
# Total Area for ADC across all layers: 32393153.59999999
# Processing layer: SRAM_mobilenet_v3_128_layer_34
# Cycle: 196
#
# Total Cycle: 77818.0
# Size: 3
# All macro: 3
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 85545.29999999999
#
# Size: 3
# All macro: 3
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 3163.9500000000003
#
# Size: 3
# All macro: 3
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 2785.488
#
# Size: 3
# All macro: 3
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 16106.127360000002
#
# Total Area for layer 34: 107600.86535999998
#
# Total Macro for layer 34: 1139
#
# Total Area for all layers: 40852461.88168
# Total Area for ADC across all layers: 32478698.89999999
# Processing layer: SRAM_mobilenet_v3_128_layer_35
# Cycle: 196
#
# Total Cycle: 78014.0
# Size: 184
# All macro: 184
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 5246778.399999999
#
# Size: 184
# All macro: 184
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 194055.6
#
# Size: 184
# All macro: 184
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 170843.264
#
# Size: 184
# All macro: 184
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 987842.47808
#
# Total Area for layer 35: 6599519.742079999
#
# Total Macro for layer 35: 1323
#
# Total Area for all layers: 47451981.62376
# Total Area for ADC across all layers: 37725477.29999999
# Processing layer: SRAM_mobilenet_v3_128_layer_36
# Cycle: 196
#
# Total Cycle: 78210.0
# Size: 2
# Size: 2
# All macro: 4
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 114060.4
#
# Size: 2
# Size: 2
# All macro: 4
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 4218.6
#
# Size: 2
# Size: 2
# All macro: 4
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 3713.984
#
# Size: 2
# Size: 2
# All macro: 4
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 21474.83648
#
# Total Area for layer 36: 143467.82048
#
# Total Macro for layer 36: 1327
#
# Total Area for all layers: 47595449.44424
# Total Area for ADC across all layers: 37839537.69999999
# Processing layer: SRAM_mobilenet_v3_128_layer_37
# Cycle: 196
#
# Total Cycle: 78406.0
# Size: 8
# All macro: 8
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 228120.8
#
# Size: 8
# All macro: 8
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 8437.2
#
# Size: 8
# All macro: 8
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 7427.968
#
# Size: 8
# All macro: 8
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 42949.67296
#
# Total Area for layer 37: 286935.64096
#
# Total Macro for layer 37: 1335
#
# Total Area for all layers: 47882385.0852
# Total Area for ADC across all layers: 38067658.499999985
# Processing layer: SRAM_mobilenet_v3_128_layer_38
# Cycle: 196
#
# Total Cycle: 78602.0
# Size: 480
# All macro: 480
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 13687248.0
#
# Size: 480
# All macro: 480
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 506232.00000000006
#
# Size: 480
# All macro: 480
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 445678.08
#
# Size: 480
# All macro: 480
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 2576980.3776000002
#
# Total Area for layer 38: 17216138.4576
#
# Total Macro for layer 38: 1815
#
# Total Area for all layers: 65098523.542799994
# Total Area for ADC across all layers: 51754906.499999985
# Processing layer: SRAM_mobilenet_v3_128_layer_39
# Cycle: 1
#
# Total Cycle: 78603.0
# Size: 2
# Size: 4
# All macro: 8
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 228120.8
#
# Size: 2
# Size: 4
# All macro: 8
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 8437.2
#
# Size: 2
# Size: 4
# All macro: 8
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 7427.968
#
# Size: 2
# Size: 4
# All macro: 8
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 42949.67296
#
# Total Area for layer 39: 286935.64096
#
# Total Macro for layer 39: 1823
#
# Total Area for all layers: 65385459.183759995
# Total Area for ADC across all layers: 51983027.29999998
# Processing layer: SRAM_mobilenet_v3_128_layer_40
# Cycle: 1
#
# Total Cycle: 78604.0
# Size: 8
# All macro: 8
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 228120.8
#
# Size: 8
# All macro: 8
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 8437.2
#
# Size: 8
# All macro: 8
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 7427.968
#
# Size: 8
# All macro: 8
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 42949.67296
#
# Total Area for layer 40: 286935.64096
#
# Total Macro for layer 40: 1831
#
# Total Area for all layers: 65672394.824719995
# Total Area for ADC across all layers: 52211148.09999998
# Processing layer: SRAM_mobilenet_v3_128_layer_41
# Cycle: 196
#
# Total Cycle: 78800.0
# Size: 2
# Size: 4
# All macro: 8
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 228120.8
#
# Size: 2
# Size: 4
# All macro: 8
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 8437.2
#
# Size: 2
# Size: 4
# All macro: 8
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 7427.968
#
# Size: 2
# Size: 4
# All macro: 8
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 42949.67296
#
# Total Area for layer 41: 286935.64096
#
# Total Macro for layer 41: 1839
#
# Total Area for all layers: 65959330.465679996
# Total Area for ADC across all layers: 52439268.899999976
# Processing layer: SRAM_mobilenet_v3_128_layer_42
# Cycle: 196
#
# Total Cycle: 78996.0
# Size: 11
# All macro: 11
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 313666.1
#
# Size: 11
# All macro: 11
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 11601.150000000001
#
# Size: 11
# All macro: 11
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 10213.456
#
# Size: 11
# All macro: 11
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 59055.80032
#
# Total Area for layer 42: 394536.50632
#
# Total Macro for layer 42: 1850
#
# Total Area for all layers: 66353866.971999995
# Total Area for ADC across all layers: 52752934.99999998
# Processing layer: SRAM_mobilenet_v3_128_layer_43
# Cycle: 196
#
# Total Cycle: 79192.0
# Size: 672
# All macro: 672
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 19162147.2
#
# Size: 672
# All macro: 672
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 708724.8
#
# Size: 672
# All macro: 672
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 623949.312
#
# Size: 672
# All macro: 672
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 3607772.52864
#
# Total Area for layer 43: 24102593.84064
#
# Total Macro for layer 43: 2522
#
# Total Area for all layers: 90456460.81264
# Total Area for ADC across all layers: 71915082.19999997
# Processing layer: SRAM_mobilenet_v3_128_layer_44
# Cycle: 1
#
# Total Cycle: 79193.0
# Size: 3
# Size: 6
# All macro: 18
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 513271.8
#
# Size: 3
# Size: 6
# All macro: 18
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 18983.7
#
# Size: 3
# Size: 6
# All macro: 18
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 16712.928
#
# Size: 3
# Size: 6
# All macro: 18
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 96636.76416
#
# Total Area for layer 44: 645605.19216
#
# Total Macro for layer 44: 2540
#
# Total Area for all layers: 91102066.00479999
# Total Area for ADC across all layers: 72428353.99999997
# Processing layer: SRAM_mobilenet_v3_128_layer_45
# Cycle: 1
#
# Total Cycle: 79194.0
# Size: 11
# Size: 2
# All macro: 22
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 627332.2
#
# Size: 11
# Size: 2
# All macro: 22
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 23202.300000000003
#
# Size: 11
# Size: 2
# All macro: 22
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 20426.912
#
# Size: 11
# Size: 2
# All macro: 22
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 118111.60064
#
# Total Area for layer 45: 789073.01264
#
# Total Macro for layer 45: 2562
#
# Total Area for all layers: 91891139.01743999
# Total Area for ADC across all layers: 73055686.19999997
# Processing layer: SRAM_mobilenet_v3_128_layer_46
# Cycle: 196
#
# Total Cycle: 79390.0
# Size: 2
# Size: 6
# All macro: 12
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 342181.19999999995
#
# Size: 2
# Size: 6
# All macro: 12
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 12655.800000000001
#
# Size: 2
# Size: 6
# All macro: 12
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 11141.952
#
# Size: 2
# Size: 6
# All macro: 12
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 64424.50944000001
#
# Total Area for layer 46: 430403.4614399999
#
# Total Macro for layer 46: 2574
#
# Total Area for all layers: 92321542.47887999
# Total Area for ADC across all layers: 73397867.39999998
# Processing layer: SRAM_mobilenet_v3_128_layer_47
# Cycle: 196
#
# Total Cycle: 79586.0
# Size: 11
# All macro: 11
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 313666.1
#
# Size: 11
# All macro: 11
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 11601.150000000001
#
# Size: 11
# All macro: 11
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 10213.456
#
# Size: 11
# All macro: 11
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 59055.80032
#
# Total Area for layer 47: 394536.50632
#
# Total Macro for layer 47: 2585
#
# Total Area for all layers: 92716078.98519999
# Total Area for ADC across all layers: 73711533.49999997
# Processing layer: SRAM_mobilenet_v3_128_layer_48
# Cycle: 49
#
# Total Cycle: 79635.0
# Size: 672
# All macro: 672
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 19162147.2
#
# Size: 672
# All macro: 672
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 708724.8
#
# Size: 672
# All macro: 672
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 623949.312
#
# Size: 672
# All macro: 672
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 3607772.52864
#
# Total Area for layer 48: 24102593.84064
#
# Total Macro for layer 48: 3257
#
# Total Area for all layers: 116818672.82584
# Total Area for ADC across all layers: 92873680.69999997
# Processing layer: SRAM_mobilenet_v3_128_layer_49
# Cycle: 1
#
# Total Cycle: 79636.0
# Size: 3
# Size: 6
# All macro: 18
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 513271.8
#
# Size: 3
# Size: 6
# All macro: 18
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 18983.7
#
# Size: 3
# Size: 6
# All macro: 18
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 16712.928
#
# Size: 3
# Size: 6
# All macro: 18
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 96636.76416
#
# Total Area for layer 49: 645605.19216
#
# Total Macro for layer 49: 3275
#
# Total Area for all layers: 117464278.01799999
# Total Area for ADC across all layers: 93386952.49999997
# Processing layer: SRAM_mobilenet_v3_128_layer_50
# Cycle: 1
#
# Total Cycle: 79637.0
# Size: 11
# Size: 2
# All macro: 22
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 627332.2
#
# Size: 11
# Size: 2
# All macro: 22
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 23202.300000000003
#
# Size: 11
# Size: 2
# All macro: 22
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 20426.912
#
# Size: 11
# Size: 2
# All macro: 22
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 118111.60064
#
# Total Area for layer 50: 789073.01264
#
# Total Macro for layer 50: 3297
#
# Total Area for all layers: 118253351.03063999
# Total Area for ADC across all layers: 94014284.69999997
# Processing layer: SRAM_mobilenet_v3_128_layer_51
# Cycle: 49
#
# Total Cycle: 79686.0
# Size: 3
# Size: 6
# All macro: 18
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 513271.8
#
# Size: 3
# Size: 6
# All macro: 18
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 18983.7
#
# Size: 3
# Size: 6
# All macro: 18
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 16712.928
#
# Size: 3
# Size: 6
# All macro: 18
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 96636.76416
#
# Total Area for layer 51: 645605.19216
#
# Total Macro for layer 51: 3315
#
# Total Area for all layers: 118898956.22279999
# Total Area for ADC across all layers: 94527556.49999997
# Processing layer: SRAM_mobilenet_v3_128_layer_52
# Cycle: 49
#
# Total Cycle: 79735.0
# Size: 15
# Size: 2
# All macro: 30
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 855453.0
#
# Size: 15
# Size: 2
# All macro: 30
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 31639.500000000004
#
# Size: 15
# Size: 2
# All macro: 30
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 27854.88
#
# Size: 15
# Size: 2
# All macro: 30
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 161061.27360000001
#
# Total Area for layer 52: 1076008.6536
#
# Total Macro for layer 52: 3345
#
# Total Area for all layers: 119974964.8764
# Total Area for ADC across all layers: 95383009.49999997
# Processing layer: SRAM_mobilenet_v3_128_layer_53
# Cycle: 49
#
# Total Cycle: 79784.0
# Size: 960
# All macro: 960
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 27374496.0
#
# Size: 960
# All macro: 960
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 1012464.0000000001
#
# Size: 960
# All macro: 960
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 891356.16
#
# Size: 960
# All macro: 960
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 5153960.7552000005
#
# Total Area for layer 53: 34432276.9152
#
# Total Macro for layer 53: 4305
#
# Total Area for all layers: 154407241.7916
# Total Area for ADC across all layers: 122757505.49999997
# Processing layer: SRAM_mobilenet_v3_128_layer_54
# Cycle: 1
#
# Total Cycle: 79785.0
# Size: 4
# Size: 8
# All macro: 32
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 912483.2
#
# Size: 4
# Size: 8
# All macro: 32
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 33748.8
#
# Size: 4
# Size: 8
# All macro: 32
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 29711.872
#
# Size: 4
# Size: 8
# All macro: 32
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 171798.69184
#
# Total Area for layer 54: 1147742.56384
#
# Total Macro for layer 54: 4337
#
# Total Area for all layers: 155554984.35544
# Total Area for ADC across all layers: 123669988.69999997
# Processing layer: SRAM_mobilenet_v3_128_layer_55
# Cycle: 1
#
# Total Cycle: 79786.0
# Size: 15
# Size: 2
# All macro: 30
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 855453.0
#
# Size: 15
# Size: 2
# All macro: 30
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 31639.500000000004
#
# Size: 15
# Size: 2
# All macro: 30
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 27854.88
#
# Size: 15
# Size: 2
# All macro: 30
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 161061.27360000001
#
# Total Area for layer 55: 1076008.6536
#
# Total Macro for layer 55: 4367
#
# Total Area for all layers: 156630993.00904
# Total Area for ADC across all layers: 124525441.69999997
# Processing layer: SRAM_mobilenet_v3_128_layer_56
# Cycle: 49
#
# Total Cycle: 79835.0
# Size: 3
# Size: 8
# All macro: 24
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 684362.3999999999
#
# Size: 3
# Size: 8
# All macro: 24
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 25311.600000000002
#
# Size: 3
# Size: 8
# All macro: 24
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 22283.904
#
# Size: 3
# Size: 8
# All macro: 24
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 128849.01888000002
#
# Total Area for layer 56: 860806.9228799999
#
# Total Macro for layer 56: 4391
#
# Total Area for all layers: 157491799.93192
# Total Area for ADC across all layers: 125209804.09999998
# Processing layer: SRAM_mobilenet_v3_128_layer_57
# Cycle: 49
#
# Total Cycle: 79884.0
# Size: 15
# Size: 2
# All macro: 30
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 855453.0
#
# Size: 15
# Size: 2
# All macro: 30
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 31639.500000000004
#
# Size: 15
# Size: 2
# All macro: 30
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 27854.88
#
# Size: 15
# Size: 2
# All macro: 30
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 161061.27360000001
#
# Total Area for layer 57: 1076008.6536
#
# Total Macro for layer 57: 4421
#
# Total Area for all layers: 158567808.58552
# Total Area for ADC across all layers: 126065257.09999998
# Processing layer: SRAM_mobilenet_v3_128_layer_58
# Cycle: 49
#
# Total Cycle: 79933.0
# Size: 960
# All macro: 960
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 27374496.0
#
# Size: 960
# All macro: 960
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 1012464.0000000001
#
# Size: 960
# All macro: 960
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 891356.16
#
# Size: 960
# All macro: 960
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 5153960.7552000005
#
# Total Area for layer 58: 34432276.9152
#
# Total Macro for layer 58: 5381
#
# Total Area for all layers: 193000085.50072
# Total Area for ADC across all layers: 153439753.09999996
# Processing layer: SRAM_mobilenet_v3_128_layer_59
# Cycle: 1
#
# Total Cycle: 79934.0
# Size: 4
# Size: 8
# All macro: 32
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 912483.2
#
# Size: 4
# Size: 8
# All macro: 32
# column drivers area: 1054.65, number of column_drivers: 4096,
# ...
# total adc area: (29755.8*4096/4096) * macro = 238046.4
#
# Size: 2
# Size: 4
# All macro: 8
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 3528.104
#
# Size: 2
# Size: 4
# All macro: 8
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 4032.12
#
# Size: 2
# Size: 4
# All macro: 8
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 5368.70912
#
# Total Area for layer 391: 250975.33312
#
# Total Macro for layer 391: 2546
#
# Total Area for all layers: 79872899.76544039
# Total Area for ADC across all layers: 75758266.79999994
# Processing layer: RRAM_mobilebert_128_layer_392
# Cycle: 139
#
# Total Cycle: 48278.0
# Size: 8
# All macro: 8
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 238046.4
#
# Size: 8
# All macro: 8
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 3528.104
#
# Size: 8
# All macro: 8
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 4032.12
#
# Size: 8
# All macro: 8
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 5368.70912
#
# Total Area for layer 392: 250975.33312
#
# Total Macro for layer 392: 2554
#
# Total Area for all layers: 80123875.0985604
# Total Area for ADC across all layers: 75996313.19999994
# Processing layer: RRAM_mobilebert_128_layer_393
# Cycle: 139
#
# Total Cycle: 48417.0
# Size: 2
# Size: 4
# All macro: 8
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 238046.4
#
# Size: 2
# Size: 4
# All macro: 8
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 3528.104
#
# Size: 2
# Size: 4
# All macro: 8
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 4032.12
#
# Size: 2
# Size: 4
# All macro: 8
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 5368.70912
#
# Total Area for layer 393: 250975.33312
#
# Total Macro for layer 393: 2562
#
# Total Area for all layers: 80374850.4316804
# Total Area for ADC across all layers: 76234359.59999995
# Processing layer: RRAM_mobilebert_128_layer_394
# Cycle: 139
#
# Total Cycle: 48556.0
# Size: 2
# Size: 4
# All macro: 8
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 238046.4
#
# Size: 2
# Size: 4
# All macro: 8
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 3528.104
#
# Size: 2
# Size: 4
# All macro: 8
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 4032.12
#
# Size: 2
# Size: 4
# All macro: 8
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 5368.70912
#
# Total Area for layer 394: 250975.33312
#
# Total Macro for layer 394: 2570
#
# Total Area for all layers: 80625825.7648004
# Total Area for ADC across all layers: 76472405.99999996
# Processing layer: RRAM_mobilebert_128_layer_395
# Cycle: 139
#
# Total Cycle: 48695.0
# Size: 2
# All macro: 2
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 59511.6
#
# Size: 2
# All macro: 2
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 882.026
#
# Size: 2
# All macro: 2
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 1008.03
#
# Size: 2
# All macro: 2
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 1342.17728
#
# Total Area for layer 395: 62743.83328
#
# Total Macro for layer 395: 2572
#
# Total Area for all layers: 80688569.5980804
# Total Area for ADC across all layers: 76531917.59999995
# Processing layer: RRAM_mobilebert_128_layer_396
# Cycle: 139
#
# Total Cycle: 48834.0
# Size: 2
# All macro: 2
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 59511.6
#
# Size: 2
# All macro: 2
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 882.026
#
# Size: 2
# All macro: 2
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 1008.03
#
# Size: 2
# All macro: 2
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 1342.17728
#
# Total Area for layer 396: 62743.83328
#
# Total Macro for layer 396: 2574
#
# Total Area for all layers: 80751313.4313604
# Total Area for ADC across all layers: 76591429.19999994
# Processing layer: RRAM_mobilebert_128_layer_397
# Cycle: 139
#
# Total Cycle: 48973.0
# Size: 2
# Size: 4
# All macro: 8
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 238046.4
#
# Size: 2
# Size: 4
# All macro: 8
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 3528.104
#
# Size: 2
# Size: 4
# All macro: 8
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 4032.12
#
# Size: 2
# Size: 4
# All macro: 8
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 5368.70912
#
# Total Area for layer 397: 250975.33312
#
# Total Macro for layer 397: 2582
#
# Total Area for all layers: 81002288.7644804
# Total Area for ADC across all layers: 76829475.59999995
# Processing layer: RRAM_mobilebert_128_layer_398
# Cycle: 4
#
# Total Cycle: 48977.0
# Size: 2
# All macro: 2
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 59511.6
#
# Size: 2
# All macro: 2
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 882.026
#
# Size: 2
# All macro: 2
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 1008.03
#
# Size: 2
# All macro: 2
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 1342.17728
#
# Total Area for layer 398: 62743.83328
#
# Total Macro for layer 398: 2584
#
# Total Area for all layers: 81065032.5977604
# Total Area for ADC across all layers: 76888987.19999994
# Processing layer: RRAM_mobilebert_128_layer_399
# Cycle: 4
#
# Total Cycle: 48981.0
# Size: 3
# Size: 2
# All macro: 6
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 178534.8
#
# Size: 3
# Size: 2
# All macro: 6
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 2646.078
#
# Size: 3
# Size: 2
# All macro: 6
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 3024.09
#
# Size: 3
# Size: 2
# All macro: 6
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 4026.5318400000006
#
# Total Area for layer 399: 188231.49984
#
# Total Macro for layer 399: 2590
#
# Total Area for all layers: 81253264.0976004
# Total Area for ADC across all layers: 77067521.99999994
# Processing layer: RRAM_mobilebert_128_layer_400
# Cycle: 139
#
# Total Cycle: 49120.0
# Size: 2
# All macro: 2
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 59511.6
#
# Size: 2
# All macro: 2
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 882.026
#
# Size: 2
# All macro: 2
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 1008.03
#
# Size: 2
# All macro: 2
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 1342.17728
#
# Total Area for layer 400: 62743.83328
#
# Total Macro for layer 400: 2592
#
# Total Area for all layers: 81316007.9308804
# Total Area for ADC across all layers: 77127033.59999993
# Processing layer: RRAM_mobilebert_128_layer_401
# Cycle: 139
#
# Total Cycle: 49259.0
# Size: 8
# All macro: 8
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 238046.4
#
# Size: 8
# All macro: 8
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 3528.104
#
# Size: 8
# All macro: 8
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 4032.12
#
# Size: 8
# All macro: 8
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 5368.70912
#
# Total Area for layer 401: 250975.33312
#
# Total Macro for layer 401: 2600
#
# Total Area for all layers: 81566983.2640004
# Total Area for ADC across all layers: 77365079.99999994
# Processing layer: RRAM_mobilebert_128_layer_402
# Cycle: 139
#
# Total Cycle: 49398.0
# Size: 2
# Size: 4
# All macro: 8
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 238046.4
#
# Size: 2
# Size: 4
# All macro: 8
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 3528.104
#
# Size: 2
# Size: 4
# All macro: 8
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 4032.12
#
# Size: 2
# Size: 4
# All macro: 8
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 5368.70912
#
# Total Area for layer 402: 250975.33312
#
# Total Macro for layer 402: 2608
#
# Total Area for all layers: 81817958.5971204
# Total Area for ADC across all layers: 77603126.39999995
# Processing layer: RRAM_mobilebert_128_layer_403
# Cycle: 139
#
# Total Cycle: 49537.0
# Size: 8
# All macro: 8
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 238046.4
#
# Size: 8
# All macro: 8
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 3528.104
#
# Size: 8
# All macro: 8
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 4032.12
#
# Size: 8
# All macro: 8
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 5368.70912
#
# Total Area for layer 403: 250975.33312
#
# Total Macro for layer 403: 2616
#
# Total Area for all layers: 82068933.93024041
# Total Area for ADC across all layers: 77841172.79999995
# Processing layer: RRAM_mobilebert_128_layer_404
# Cycle: 139
#
# Total Cycle: 49676.0
# Size: 2
# Size: 4
# All macro: 8
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 238046.4
#
# Size: 2
# Size: 4
# All macro: 8
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 3528.104
#
# Size: 2
# Size: 4
# All macro: 8
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 4032.12
#
# Size: 2
# Size: 4
# All macro: 8
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 5368.70912
#
# Total Area for layer 404: 250975.33312
#
# Total Macro for layer 404: 2624
#
# Total Area for all layers: 82319909.26336041
# Total Area for ADC across all layers: 78079219.19999996
# Processing layer: RRAM_mobilebert_128_layer_405
# Cycle: 139
#
# Total Cycle: 49815.0
# Size: 8
# All macro: 8
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 238046.4
#
# Size: 8
# All macro: 8
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 3528.104
#
# Size: 8
# All macro: 8
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 4032.12
#
# Size: 8
# All macro: 8
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 5368.70912
#
# Total Area for layer 405: 250975.33312
#
# Total Macro for layer 405: 2632
#
# Total Area for all layers: 82570884.59648041
# Total Area for ADC across all layers: 78317265.59999996
# Processing layer: RRAM_mobilebert_128_layer_406
# Cycle: 139
#
# Total Cycle: 49954.0
# Size: 2
# Size: 4
# All macro: 8
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 238046.4
#
# Size: 2
# Size: 4
# All macro: 8
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 3528.104
#
# Size: 2
# Size: 4
# All macro: 8
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 4032.12
#
# Size: 2
# Size: 4
# All macro: 8
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 5368.70912
#
# Total Area for layer 406: 250975.33312
#
# Total Macro for layer 406: 2640
#
# Total Area for all layers: 82821859.92960042
# Total Area for ADC across all layers: 78555311.99999997
# Processing layer: RRAM_mobilebert_128_layer_407
# Cycle: 139
#
# Total Cycle: 50093.0
# Size: 8
# All macro: 8
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 238046.4
#
# Size: 8
# All macro: 8
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 3528.104
#
# Size: 8
# All macro: 8
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 4032.12
#
# Size: 8
# All macro: 8
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 5368.70912
#
# Total Area for layer 407: 250975.33312
#
# Total Macro for layer 407: 2648
#
# Total Area for all layers: 83072835.26272042
# Total Area for ADC across all layers: 78793358.39999998
# Processing layer: RRAM_mobilebert_128_layer_408
# Cycle: 139
#
# Total Cycle: 50232.0
# Size: 2
# Size: 4
# All macro: 8
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 238046.4
#
# Size: 2
# Size: 4
# All macro: 8
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 3528.104
#
# Size: 2
# Size: 4
# All macro: 8
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 4032.12
#
# Size: 2
# Size: 4
# All macro: 8
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 5368.70912
#
# Total Area for layer 408: 250975.33312
#
# Total Macro for layer 408: 2656
#
# Total Area for all layers: 83323810.59584042
# Total Area for ADC across all layers: 79031404.79999998
# Processing layer: RRAM_mobilebert_128_layer_409
# Cycle: 139
#
# Total Cycle: 50371.0
# Size: 8
# All macro: 8
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 238046.4
#
# Size: 8
# All macro: 8
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 3528.104
#
# Size: 8
# All macro: 8
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 4032.12
#
# Size: 8
# All macro: 8
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 5368.70912
#
# Total Area for layer 409: 250975.33312
#
# Total Macro for layer 409: 2664
#
# Total Area for all layers: 83574785.92896043
# Total Area for ADC across all layers: 79269451.19999999
# Total Area for column drivers across all layers: 1174858.632000006
# Total Area for row drivers across all layers: 1342695.9600000086
# Total Area for cim unit across all layers: 1787780.1369600005
#
#
# Total Area for ADC across all layers: 79.26945119999998
# Total Area for column driver across all layers: 1.174858632000006
# Total Area for row driver across all layers: 1.3426959600000086
# Total Area for cim unit across all layers: 1.7877801369600004
# Total Macro across all layers: 2664
# RRAM_mobilebert_128 	 1.01e-04 	 83.57 	 1.99e+02

# %%
print("\n### Area and Performance Results ###\n")

for i, dnn in enumerate(dnn_list):
    print(f"Results for {dnn} (SRAM):")
    print(f"  Total Area: {total_area[2 * i]}")
    print(f"  ADC Area: {total_adc_area[2 * i]}")
    print(f"  Column Driver Area: {total_col_area[2 * i]}")
    print(f"  Row Driver Area: {total_row_area[2 * i]}")
    print(f"  CIM Unit Area: {total_cim_unit_area[2 * i]}")
    print(f"  Total Macro: {total_macro[2 * i]}")
    print(f"  Energy: {energy[2 * i]}")
    print(f"  Throughput: {throughput[2 * i]}\n")

    print(f"Results for {dnn} (RRAM):")
    print(f"  Total Area: {total_area[2 * i + 1]}")
    print(f"  ADC Area: {total_adc_area[2 * i + 1]}")
    print(f"  Column Driver Area: {total_col_area[2 * i + 1]}")
    print(f"  Row Driver Area: {total_row_area[2 * i + 1]}")
    print(f"  CIM Unit Area: {total_cim_unit_area[2 * i + 1]}")
    print(f"  Total Macro: {total_macro[2 * i + 1]}")
    print(f"  Energy: {energy[2 * i + 1]}")
    print(f"  Throughput: {throughput[2 * i + 1]}\n")
# Out:
# ### Area and Performance Results ###
#
# Results for mobilenet_v3 (SRAM):
#   Total Area: 208.63807793304002
#   ADC Area: 165.87233669999995
#   Column Driver Area: 6.134899049999999
#   Row Driver Area: 5.401061232000001
#   CIM Unit Area: 31.229780951040002
#   Total Macro: 5817
#   Energy: 3.399735499999999e-05
#   Throughput: 124.9453364153183
#
# Results for mobilenet_v3 (RRAM):
#   Total Area: 182.49043909488
#   ADC Area: 173.08948859999995
#   Column Driver Area: 2.5653726210000003
#   Row Driver Area: 2.9318552550000003
#   CIM Unit Area: 3.9037226188800003
#   Total Macro: 5817
#   Energy: 3.348051499999999e-05
#   Throughput: 124.9453364153183
#
# Results for mobilebert (SRAM):
#   Total Area: 95.54956843967933
#   ADC Area: 75.9642263999997
#   Column Driver Area: 2.809587600000003
#   Row Driver Area: 2.473513344000011
#   CIM Unit Area: 14.302241095680003
#   Total Macro: 2664
#   Energy: 8.347524200000011e-05
#   Throughput: 198.52693017807866
#
# Results for mobilebert (RRAM):
#   Total Area: 83.57478592896042
#   ADC Area: 79.26945119999998
#   Column Driver Area: 1.174858632000006
#   Row Driver Area: 1.3426959600000086
#   CIM Unit Area: 1.7877801369600004
#   Total Macro: 2664
#   Energy: 0.0001013848299999999
#   Throughput: 198.52693017807866

# %%
import matplotlib.pyplot as plt
import numpy as np

sram_label = "SRAM"
rram_label = "RRAM"

x = np.arange(len(dnn_list))  # Number of DNNs
width = 0.35  # Bar width

# Create figure and axes for three different plots (energy, area, throughput)
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(18, 6))

# Energy Plot
ax1.bar(x - width/2, energy[::2], width, label=sram_label, color='tab:blue')  # SRAM for DNN1, DNN2
ax1.bar(x + width/2, energy[1::2], width, label=rram_label, color='tab:red')  # RRAM for DNN1, DNN2
ax1.set_title("Energy Consumption")
ax1.set_xticks(x)
ax1.set_xticklabels(dnn_list)
ax1.set_xlabel("DNN models")
ax1.set_ylabel("Energy")
ax1.legend()

# Area Plot
ax2.bar(x - width/2, total_area[::2], width, label=sram_label, color='tab:blue')  # SRAM for DNN1, DNN2
ax2.bar(x + width/2, total_area[1::2], width, label=rram_label, color='tab:red')  # RRAM for DNN1, DNN2
ax2.set_title("Area")
ax2.set_xticks(x)
ax2.set_xticklabels(dnn_list)
ax2.set_xlabel("DNN models")
ax2.set_ylabel("Area")
ax2.legend()

# Throughput Plot
ax3.bar(x - width/2, throughput[::2], width, label=sram_label, color='tab:blue')  # SRAM for DNN1, DNN2
ax3.bar(x + width/2, throughput[1::2], width, label=rram_label, color='tab:red')  # RRAM for DNN1, DNN2
ax3.set_title("Throughput")
ax3.set_xticks(x)
ax3.set_xticklabels(dnn_list)
ax3.set_xlabel("DNN models")
ax3.set_ylabel("Throughput")
ax3.legend()

# Adjust layout for better spacing
plt.tight_layout()
plt.show()

# %%
display_markdown(
    """
### Calculating the energy

"""
)

path_list = [SRAM_PATH, RRAM_PATH]  # List of paths
num_dnns = len(dnn_list)  # Get the number of DNN models
num_paths = len(path_list)  # Get the number of paths
num_cases = num_dnns * num_paths  # Total number of cases

# Initialize energy lists dynamically based on the number of cases
total_adc_energy = [0] * (2 * num_dnns)
total_col_energy = [0] * (2 * num_dnns)
total_row_energy = [0] * (2 * num_dnns)
total_cim_unit_energy = [0] * (2 * num_dnns)

# Iterate through all cases dynamically based on `j`
for j in range(2 * num_dnns):  # Now `j` will be 2 * number of DNN models
    # For each DNN model, calculate energy based on the path
    dnn_idx = j // 2  # Determine which DNN model (0 or 1, 2, etc.)
    path_idx = j % 2  # Determine which path (0 for SRAM, 1 for RRAM)

    # Now iterate through each energy category (ADC, Column, Row, CIM Unit)
    for i in range(4):  # Since there are 4 categories (ADC, Column, Row, CIM Unit)
        energy_value = total_per_energy[(dnn_list[dnn_idx], path_list[path_idx])][i] * energy[j]

        if i == 0:
            total_adc_energy[j] = energy_value
        elif i == 1:
            total_col_energy[j] = energy_value
        elif i == 2:
            total_row_energy[j] = energy_value
        else:
            total_cim_unit_energy[j] = energy_value

# Print the results for total energies
print("Total ADC Energy:", total_adc_energy)
print("Total Column Energy:", total_col_energy)
print("Total Row Energy:", total_row_energy)
print("Total CIM Unit Energy:", total_cim_unit_energy)
# Out:
# ### Calculating the energy
# Total ADC Energy: [1.503965075301457e-05, 1.625985275913333e-05, 4.103121480190417e-05, 4.734205423846096e-05]
# Total Column Energy: [9.079908551633691e-08, 1.6365436219906296e-16, 2.488063025221863e-07, 1.1901064096278545e-16]
# Total Row Energy: [1.8855681541504132e-05, 1.5309601624210325e-05, 4.204972013386506e-05, 3.641696479881484e-05]
# Total CIM Unit Energy: [1.1223619964949657e-08, 1.9110606164926806e-06, 1.455007617087039e-07, 1.7625810962605088e-05]

# %%
import matplotlib.pyplot as plt
import numpy as np
fig, ax = plt.subplots(figsize=(10, 6)) 
path = ['SRAM', 'RRAM']
num_bars = len(dnn_list) * len(path)

x = np.arange(num_bars)

# Stack bars
ax.bar(x, total_cim_unit_energy, label='cim_unit')
ax.bar(x, total_row_energy, bottom=total_cim_unit_energy, label='row_drivers')
ax.bar(x, total_col_energy, bottom=np.array(total_cim_unit_energy) + np.array(total_row_energy), label='column_drivers')
ax.bar(x, total_adc_energy, bottom=np.array(total_cim_unit_energy) + np.array(total_row_energy) + np.array(total_col_energy), label='adc')

# Labels and title
ax.set_title(f"Energy vs Memory Type for {DNN} in fast scenario")
ax.set_xlabel("Memory type")
ax.set_ylabel("Energy (J)")
# Set x-ticks
xtick_labels = [f"{mem}-{dnn}" for dnn in dnn_list for mem in path]
ax.set_xticks(x)
ax.set_xticklabels(xtick_labels)

ax.legend()

# Show plot
plt.show()
