# %%
from _import_scripts import scripts
from scripts.notebook_utils import *
from scripts.tl_output_parsing import MacroOutputStats
from scripts.utils import *
import yaml

def create_layer_directory(base_output_dir: str, architecture: str, layer: int) -> str:
    layer_dir = os.path.join(base_output_dir, f"{architecture}_layer_{layer}")
    if not os.path.exists(layer_dir):
        os.makedirs(layer_dir)
    return layer_dir

num_layers = 1

def run_map(
    spec: tl.Specification,
    arch: str,
    accelergy_verbose: bool = False,
) -> dict:
    output_dir = get_run_dir()
    # Just use the directory name if it causes error
    base_output_dir = os.path.dirname(output_dir)
    base_output_dir = os.path.join(base_output_dir, arch)
    global num_layers

    mapper_result = None

    if num_layers < 99:
        # Create a directory for the current layer
        layer_dir = create_layer_directory(base_output_dir, arch, num_layers)
        # print(f"Layer directory: {layer_dir}")
        num_layers += 1

        run_prefix = f"{layer_dir}/timeloop-mapper"
        mapper_result = tl.call_mapper(
            specification=spec,
            output_dir=layer_dir,
            log_to=os.path.join(output_dir, f"{run_prefix}.log"),
        )
        if accelergy_verbose:
            tl.call_accelergy_verbose(
                specification=spec,
                output_dir=layer_dir,
                log_to=os.path.join(output_dir, "accelergy.log"),
            )

    if mapper_result is None:
        # Handle case when mapper_result is not assigned (num_layers >= 17)
        # Raise an error, return a default value
        print("Warning: mapper_result is not assigned. num_layers >= 17")
        return {}

    return MacroOutputStats.from_output_stats(mapper_result)

import re

def extract_range(line):
    match = re.search(r'\[(\d+):(\d+)(,\d+)?\)', line)
    if match:
        start = int(match.group(1))
        end = int(match.group(2))
        return end - start
    return None

def read_and_compute_multiplication(filename, i):
    filename = f"../outputs/{filename}/{filename}_layer_{i+1}/timeloop-mapper.map.txt"
    with open(filename, 'r') as file:
        lines = file.readlines()

    start_searching = False
    ranges = []

    for line in lines:
        # Start searching when 'inter_macro_in_system_spatial' is found
        if "inter_macro_in_system_spatial" in line:
            start_searching = True
        
        # Stop searching if we leave the 'inter_macro_in_system_spatial' section
        elif start_searching and "inter_" in line and "inter_macro_in_system_spatial" not in line:
            break

        # If we are in the 'inter_macro_in_system_spatial' section, look for the ranges
        if start_searching:
            if "for" in line:
                range_size = extract_range(line)
                if range_size is not None:
                    ranges.append(range_size)
            elif line.strip() == "":  # Exit the section on an empty line
                break

    # Compute the multiplication of all ranges, or return 1 if no ranges were found
    if not ranges:
        print(f"All macro: 1")
        return 1

    result = 1
    for size in ranges:
        result *= size
        print(f"Size: {size}")
    print(f"All macro: {result}")
    return result


def extract_layer_number(folder_name):
    match = re.search(r'layer_(\d+)', folder_name)
    return int(match.group(1)) if match else float('inf')

def extract_outputs(model):
    
    output_dir = "../outputs/" + model + "/" 
    print(output_dir)

    print ("Model \t Energy/inference (J) \t Area (mm2) \t Throughput (inf/s)")
    #for model in models:    
    throughput = 0   
    energy = 0
    area = 0
    cycles = 0
    folders = sorted([folder for folder in os.listdir(output_dir) if model in folder], key=extract_layer_number)
    area_per_many_macro = 0
    area_layer = 0
    j = 0
    total_sum = 0
    total_adc_area = 0  # Total area for ADC across all layers
    total_other_areas = {}  # Dictionary to store total areas for other components
    total_col_area = 0
    total_row_area = 0
    total_cim_unit_area = 0
    total_area = 0
    total_macro = 0
    
    for folder in folders:
        total = 0
        if model in folder:
            print(f"Processing layer: {folder}")
            # print(folder)
            if os.path.isdir(output_dir + folder):
                stat_file = output_dir + folder + "/timeloop-mapper.stats.txt"
                art_file = output_dir + folder + "/timeloop-mapper.ART.yaml"
        
                with open(stat_file, 'r') as f:
                    energy_stat = [line for line in f if line.startswith("Energy:")][0]
                    energy_uj = energy_stat.split(' ')[1] # uJ
                    energy += float(energy_uj)
                    # print(f"Energy for this layer: {float(energy_uj)} uj")
                
                with open(stat_file, 'r') as f:
                    cycle_stat = [line for line in f if line.startswith("Cycles:")][0]                  
                    cycle = cycle_stat.split(' ')[1] 
                    cycles += float(cycle)
                    
            if j < 16:
                with open(art_file, 'r') as file:
                    data = yaml.safe_load(file)
                
                    # Extract and print the name, area, number of entries, and ratio for non-zero areas
                for table in data['ART']['tables']:
                    name = table.get('name')
                    area = table.get('area')
                    if area != 0:
                        # Simplify the name for the output
                        if 'system_top_level.' in name:
                            name = name.split('system_top_level.')[-1]
                        
                        # Extract the number of entries from the name
                        if '[' in name:
                            name_part, entries_part = name.split('[')
                            number_of_entries = entries_part.split('..')[1].replace(']', '')
                            name = name_part.strip()
                        else:
                            number_of_entries = 'Unknown'
                        
                        macro = read_and_compute_multiplication(model, j)
                        # Calculate total ratio
                        if number_of_entries != 'Unknown' and number_of_entries.isdigit():
                            total_ratio = (area / 4096) * macro * int(number_of_entries)
                        else:
                            total_ratio = 0
                        
                        total += total_ratio
                           
                        # Accumulate area for ADC or other components
                        if 'adc' in name.lower():
                            total_adc_area += total_ratio
                        else:
                            if name not in total_other_areas:
                                total_other_areas[name] = 0
                            total_other_areas[name] += total_ratio
            
                        print(f"{name.replace('_', ' ')} area: {area}, number of {name}: {number_of_entries}, \ntotal {name.replace('_', ' ')} area: ({area}*{number_of_entries}/4096) * macro = {total_ratio}\n")
                j += 1 
                total_sum += total
                total_macro += macro
                print(f"Total Area for layer {j}: {total}\n")
                print(f"Total Macro for layer {j}: {total_macro}\n")
            print(f"Total Area for all layers: {total_sum}")
            print(f"Total Area for ADC across all layers: {total_adc_area}")
    
    # Print total area for other components
    for component, area in total_other_areas.items():
        print(f"Total Area for {component.replace('_', ' ')} across all layers: {area}")
        # print(component.replace('_', ' '))
        if component.replace('_', ' ') ==  "column drivers":
            total_col_area = area
        elif component.replace('_', ' ') ==  "row drivers":
            total_row_area = area
        else:
            total_cim_unit_area = area
                                
    energy *= 1e-6 # conver to J
    total_area = total_sum * 1e-6 # mm2
    throughput = 1 / (cycles * 1e-7) # s

    total_adc_area = total_adc_area * 1e-6 # mm2
    total_col_area = total_col_area * 1e-6 # mm2
    total_row_area = total_row_area * 1e-6 # mm2
    total_cim_unit_area = total_cim_unit_area * 1e-6 # mm2
    print("\n")
    print(f"Total Area for ADC across all layers: {total_adc_area}")
    print(f"Total Area for column driver across all layers: {total_col_area}")
    print(f"Total Area for row driver across all layers: {total_row_area}")
    print(f"Total Area for cim unit across all layers: {total_cim_unit_area}")
    print(f"Total Macro across all layers: {total_macro}")
    print ("{} \t {:.2e} \t {:.2f} \t {:.2e}".format(model, energy, total_area, throughput))
    
    return total_area, total_adc_area, total_col_area, total_row_area, total_cim_unit_area, total_macro, energy, throughput

# %%
MACRO_PATH = "../models/arch/1_macro/basic_analog/" 
macro = {}
SRAM_PATH = f'"{os.path.abspath("../models/memory_cells/sram_example.cell.yaml")}"'
RRAM_PATH = f'"{os.path.abspath("../models/memory_cells/rram_example.cell.yaml")}"'

# Define the architecture
array_sizes = 128
path_list = [SRAM_PATH, RRAM_PATH]
tech_node = 32
# adc_resolution = 6
DNN = "vision_transformer"
time = "fast"

total_per_energy = {}

for path in path_list:
    arch = f"{path.split('/')[-1].split('_')[0].upper()}_{DNN}_{array_sizes}_{time}"
    print(f"\nRunning {DNN} with {array_sizes} x {array_sizes} {path.split('/')[-1].split('_')[0].upper()} with {tech_node} nm in {time} scenario")

    num_layers = 1

    def run_dnn(dnn: str, layer: str, array_sizes: int, variables):
        print(f"{layer} ", end="", flush=True)
        spec = get_spec(
            "basic_analog",
            # Weight-stationary, dummy buffer on top to hold inputs & outputs, many
            # macros to ensure we can fit all weights.
            system="ws_dummy_buffer_many_macro",
            # Set the DNN and layer
            dnn=dnn,
            layer=layer,
        )
    
        # Do NOT generate a maximum-utilization workload; we're running a DNN
        # workload.
        spec.variables["MAX_UTILIZATION"] = False
    
        # Use a larger array to ensure we can fit all weights
        spec.architecture.find("column").spatial.meshX = array_sizes
        spec.architecture.find("row").spatial.meshY = array_sizes
    
        spec.variables.update(variables)
        output_stats = run_map(spec, arch)
        
        # Print computes for the layer
        macro_output_stats = MacroOutputStats.from_output_stats(output_stats)
        print(f"Computes for layer {int(layer) + 1}: {macro_output_stats.computes}")
        global macro
        macro[layer] = macro_output_stats.computes
        return output_stats
    
    layers = [f for f in os.listdir(f"../models/workloads/{DNN}") if f != "index.yaml" and f.endswith(".yaml")]
    layers = sorted(layers)
    print(f"Running: ", end="")
    
    # Parallel/Delayed is used to multiprocess. Equivalent to running the following
    # code in serial:
    results = joblib.Parallel(n_jobs=None)(
        joblib.delayed(run_dnn)(DNN, layer.split(".")[0], array_sizes, 
                                  {
                                      "CELL_CONFIG": path,
                                      "BITS_PER_CELL": 1 if path == SRAM_PATH else 4,
                                      "CIM_UNIT_WIDTH_CELLS": 4 if path == SRAM_PATH else 1,
                                      "IS_SRAM": path == SRAM_PATH,
                                      "TECHNOLOGY": tech_node,
                                      "ADC_RESOLUTION": 4 if path == SRAM_PATH else 6,
                                      "GLOBAL_CYCLE_SECONDS": 1e-7 if time == "fast" else 1e-4,
                                  }
                                 ) for layer in layers
    )
    print("")
    for r in results:
        r.clear_zero_energies()
    
    #Initialize overall_energy
    energy_layer = [0] * 16
    result = 0
    
    # total_per_energy_32 = [0] * 4
    
    total_adc_energy = 0.0
    total_col_energy = 0.0
    total_row_energy = 0.0
    total_cim_unit_energy = 0.0
    # Calculate overall energy
    for r in results:
    
        per_component_energy = r.per_compute("per_component_energy")
        total_energy_per_layer = sum(per_component_energy.values()) * 1e15  # Convert to fJ
        total_adc_energy += per_component_energy.get('adc', 0.0)
        total_col_energy += per_component_energy.get('column_drivers', 0.0)
        total_row_energy += per_component_energy.get('row_drivers', 0.0)
        total_cim_unit_energy += per_component_energy.get('cim_unit', 0.0)
    
        total_adc_energy = total_adc_energy * 1e15
        total_col_energy = total_col_energy * 1e15
        total_row_energy = total_row_energy * 1e15
        total_cim_unit_energy = total_cim_unit_energy * 1e15
        total_energy = total_adc_energy + total_col_energy + total_row_energy + total_cim_unit_energy
    
        total_adc_energy = total_adc_energy/total_energy
        total_col_energy = total_col_energy/total_energy
        total_row_energy = total_row_energy/total_energy
        total_cim_unit_energy = total_cim_unit_energy/total_energy

        total_per_energy[path] = [total_adc_energy, total_col_energy, total_row_energy, total_cim_unit_energy]
        
    # Display overall energy
    print(f"Overall energy for DNN {DNN}: {total_energy} fJ")

    for i in range(4):
        print(f"total_per_energy[{path.split('/')[-1].split('_')[0].upper()}][{i}]: {total_per_energy[path][i]}")
    print() 
    
    # Display an energy breakdown for each layer as a bar chart. Display normalized per-MAC and per-layer energy.
    fig, ax = plt.subplots(figsize=(20, 5))
    
    bar_stacked(
        {i: r.per_compute("per_component_energy") * 1e15 for i, r in enumerate(results)},
        title= f"Using {path.split('/')[-1].split('_')[0].upper()} on {array_sizes} x {array_sizes} array sizes, {tech_node} nm",
        xlabel="Layer",
        ylabel="Energy (fJ/MAC)",
        ax=ax,
    )
# Out:
# Running vision_transformer with 128 x 128 SRAM with 32 nm in fast scenario
# Computes for layer 1: 225792.0
# Computes for layer 2: 226944.0
# Computes for layer 3: 226944.0
# Computes for layer 4: 226944.0
# Computes for layer 5: 295.5
# Computes for layer 6: 909.5859375
# Computes for layer 7: 226944.0
# Computes for layer 8: 907776.0
# Computes for layer 9: 907776.0
# Computes for layer 10: 226944.0
# Computes for layer 11: 226944.0
# Computes for layer 12: 226944.0
# Computes for layer 13: 295.5
# Computes for layer 14: 909.5859375
# Computes for layer 15: 226944.0
# Computes for layer 16: 907776.0
# Computes for layer 17: 907776.0
# Computes for layer 18: 226944.0
# Computes for layer 19: 226944.0
# Computes for layer 20: 226944.0
# Computes for layer 21: 295.5
# Computes for layer 22: 909.5859375
# Computes for layer 23: 226944.0
# Computes for layer 24: 907776.0
# Computes for layer 25: 907776.0
# Computes for layer 26: 226944.0
# Computes for layer 27: 226944.0
# Computes for layer 28: 226944.0
# Computes for layer 29: 295.5
# Computes for layer 30: 909.5859375
# Computes for layer 31: 226944.0
# Computes for layer 32: 907776.0
# Computes for layer 33: 907776.0
# Computes for layer 34: 226944.0
# Computes for layer 35: 226944.0
# Computes for layer 36: 226944.0
# Computes for layer 37: 295.5
# Computes for layer 38: 909.5859375
# Computes for layer 39: 226944.0
# Computes for layer 40: 907776.0
# Computes for layer 41: 907776.0
# Computes for layer 42: 226944.0
# Computes for layer 43: 226944.0
# Computes for layer 44: 226944.0
# Computes for layer 45: 295.5
# Computes for layer 46: 909.5859375
# Computes for layer 47: 226944.0
# Computes for layer 48: 907776.0
# Computes for layer 49: 907776.0
# Computes for layer 50: 226944.0
# Computes for layer 51: 226944.0
# Computes for layer 52: 226944.0
# Computes for layer 53: 295.5
# Computes for layer 54: 909.5859375
# Computes for layer 55: 226944.0
# Computes for layer 56: 907776.0
# Computes for layer 57: 907776.0
# Computes for layer 58: 226944.0
# Computes for layer 59: 226944.0
# Computes for layer 60: 226944.0
# Computes for layer 61: 295.5
# Computes for layer 62: 909.5859375
# Computes for layer 63: 226944.0
# Computes for layer 64: 907776.0
# Computes for layer 65: 907776.0
# Computes for layer 66: 226944.0
# Computes for layer 67: 226944.0
# Computes for layer 68: 226944.0
# Computes for layer 69: 295.5
# Computes for layer 70: 909.5859375
# Computes for layer 71: 226944.0
# Computes for layer 72: 907776.0
# Computes for layer 73: 907776.0
# Computes for layer 74: 226944.0
# Computes for layer 75: 226944.0
# Computes for layer 76: 226944.0
# Computes for layer 77: 295.5
# Computes for layer 78: 909.5859375
# Computes for layer 79: 226944.0
# Computes for layer 80: 907776.0
# Computes for layer 81: 907776.0
# Computes for layer 82: 226944.0
# Computes for layer 83: 226944.0
# Computes for layer 84: 226944.0
# Computes for layer 85: 295.5
# Computes for layer 86: 909.5859375
# Computes for layer 87: 226944.0
# Computes for layer 88: 907776.0
# Computes for layer 89: 907776.0
# Computes for layer 90: 226944.0
# Computes for layer 91: 226944.0
# Computes for layer 92: 226944.0
# Computes for layer 93: 295.5
# Computes for layer 94: 909.5859375
# Computes for layer 95: 226944.0
# Computes for layer 96: 907776.0
# Computes for layer 97: 907776.0
# Computes for layer 98: 1500.0
#
# Overall energy for DNN vision_transformer: 1000000000000029.1 fJ
# total_per_energy[SRAM][0]: 0.48394570197874043
# total_per_energy[SRAM][1]: 0.0029345643630625745
# total_per_energy[SRAM][2]: 0.5114036141476345
# total_per_energy[SRAM][3]: 0.0017161195105625283
#
#
# Running vision_transformer with 128 x 128 RRAM with 32 nm in fast scenario
# Computes for layer 1: 225792.0
# Computes for layer 2: 226944.0
# Computes for layer 3: 226944.0
# Computes for layer 4: 226944.0
# Computes for layer 5: 295.5
# Computes for layer 6: 909.5859375
# Computes for layer 7: 226944.0
# Computes for layer 8: 907776.0
# Computes for layer 9: 907776.0
# Computes for layer 10: 226944.0
# Computes for layer 11: 226944.0
# Computes for layer 12: 226944.0
# Computes for layer 13: 295.5
# Computes for layer 14: 909.5859375
# Computes for layer 15: 226944.0
# Computes for layer 16: 907776.0
# Computes for layer 17: 907776.0
# Computes for layer 18: 226944.0
# Computes for layer 19: 226944.0
# Computes for layer 20: 226944.0
# Computes for layer 21: 295.5
# Computes for layer 22: 909.5859375
# Computes for layer 23: 226944.0
# Computes for layer 24: 907776.0
# Computes for layer 25: 907776.0
# Computes for layer 26: 226944.0
# Computes for layer 27: 226944.0
# Computes for layer 28: 226944.0
# Computes for layer 29: 295.5
# Computes for layer 30: 909.5859375
# Computes for layer 31: 226944.0
# Computes for layer 32: 907776.0
# Computes for layer 33: 907776.0
# Computes for layer 34: 226944.0
# Computes for layer 35: 226944.0
# Computes for layer 36: 226944.0
# Computes for layer 37: 295.5
# Computes for layer 38: 909.5859375
# Computes for layer 39: 226944.0
# Computes for layer 40: 907776.0
# Computes for layer 41: 907776.0
# Computes for layer 42: 226944.0
# Computes for layer 43: 226944.0
# Computes for layer 44: 226944.0
# Computes for layer 45: 295.5
# Computes for layer 46: 909.5859375
# Computes for layer 47: 226944.0
# Computes for layer 48: 907776.0
# Computes for layer 49: 907776.0
# Computes for layer 50: 226944.0
# Computes for layer 51: 226944.0
# Computes for layer 52: 226944.0
# Computes for layer 53: 295.5
# Computes for layer 54: 909.5859375
# Computes for layer 55: 226944.0
# Computes for layer 56: 907776.0
# Computes for layer 57: 907776.0
# Computes for layer 58: 226944.0
# Computes for layer 59: 226944.0
# Computes for layer 60: 226944.0
# Computes for layer 61: 295.5
# Computes for layer 62: 909.5859375
# Computes for layer 63: 226944.0
# Computes for layer 64: 907776.0
# Computes for layer 65: 907776.0
# Computes for layer 66: 226944.0
# Computes for layer 67: 226944.0
# Computes for layer 68: 226944.0
# Computes for layer 69: 295.5
# Computes for layer 70: 909.5859375
# Computes for layer 71: 226944.0
# Computes for layer 72: 907776.0
# Computes for layer 73: 907776.0
# Computes for layer 74: 226944.0
# Computes for layer 75: 226944.0
# Computes for layer 76: 226944.0
# Computes for layer 77: 295.5
# Computes for layer 78: 909.5859375
# Computes for layer 79: 226944.0
# Computes for layer 80: 907776.0
# Computes for layer 81: 907776.0
# Computes for layer 82: 226944.0
# Computes for layer 83: 226944.0
# Computes for layer 84: 226944.0
# Computes for layer 85: 295.5
# Computes for layer 86: 909.5859375
# Computes for layer 87: 226944.0
# Computes for layer 88: 907776.0
# Computes for layer 89: 907776.0
# Computes for layer 90: 226944.0
# Computes for layer 91: 226944.0
# Computes for layer 92: 226944.0
# Computes for layer 93: 295.5
# Computes for layer 94: 909.5859375
# Computes for layer 95: 226944.0
# Computes for layer 96: 907776.0
# Computes for layer 97: 907776.0
# Computes for layer 98: 1500.0
#
# Overall energy for DNN vision_transformer: 1000000000000035.4 fJ
# total_per_energy[RRAM][0]: 0.4596888260250064
# total_per_energy[RRAM][1]: 1.1555869872691976e-12
# total_per_energy[RRAM][2]: 0.3649222065059064
# total_per_energy[RRAM][3]: 0.17538896746793167

# %%
display_markdown(
    """
### Calculating Area in fast scenario

"""
)
total_area = [0] * 2
total_adc_area = [0] * 2
total_col_area = [0] * 2
total_row_area = [0] * 2
total_cim_unit_area = [0] * 2
total_macro = [0] * 2
energy = [0] * 2
throughput = [0] * 2
total_area[0], total_adc_area[0], total_col_area[0], total_row_area[0], total_cim_unit_area[0], total_macro[0], energy[0], throughput[0] = extract_outputs(f"SRAM_{DNN}_128_fast")
total_area[1], total_adc_area[1], total_col_area[1], total_row_area[1], total_cim_unit_area[1], total_macro[1], energy[1], throughput[1] = extract_outputs(f"RRAM_{DNN}_128_fast")
# Out:
# ### Calculating Area in fast scenario
# ../outputs/SRAM_vision_transformer_128_fast/
# Model 	 Energy/inference (J) 	 Area (mm2) 	 Throughput (inf/s)
# Processing layer: SRAM_vision_transformer_128_fast_layer_1
# Size: 2
# Size: 12
# Size: 3
# All macro: 72
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 2053087.2
#
# Size: 2
# Size: 12
# Size: 3
# All macro: 72
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 75934.8
#
# Size: 2
# Size: 12
# Size: 3
# All macro: 72
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 66851.712
#
# Size: 2
# Size: 12
# Size: 3
# All macro: 72
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 386547.05664
#
# Total Area for layer 1: 2582420.76864
#
# Total Macro for layer 1: 72
#
# Total Area for all layers: 2582420.76864
# Total Area for ADC across all layers: 2053087.2
# Processing layer: SRAM_vision_transformer_128_fast_layer_2
# Size: 12
# Size: 6
# All macro: 72
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 2053087.2
#
# Size: 12
# Size: 6
# All macro: 72
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 75934.8
#
# Size: 12
# Size: 6
# All macro: 72
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 66851.712
#
# Size: 12
# Size: 6
# All macro: 72
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 386547.05664
#
# Total Area for layer 2: 2582420.76864
#
# Total Macro for layer 2: 144
#
# Total Area for all layers: 5164841.53728
# Total Area for ADC across all layers: 4106174.4
# Processing layer: SRAM_vision_transformer_128_fast_layer_3
# Size: 12
# Size: 6
# All macro: 72
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 2053087.2
#
# Size: 12
# Size: 6
# All macro: 72
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 75934.8
#
# Size: 12
# Size: 6
# All macro: 72
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 66851.712
#
# Size: 12
# Size: 6
# All macro: 72
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 386547.05664
#
# Total Area for layer 3: 2582420.76864
#
# Total Macro for layer 3: 216
#
# Total Area for all layers: 7747262.305919999
# Total Area for ADC across all layers: 6159261.6
# Processing layer: SRAM_vision_transformer_128_fast_layer_4
# Size: 12
# Size: 6
# All macro: 72
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 2053087.2
#
# Size: 12
# Size: 6
# All macro: 72
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 75934.8
#
# Size: 12
# Size: 6
# All macro: 72
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 66851.712
#
# Size: 12
# Size: 6
# All macro: 72
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 386547.05664
#
# Total Area for layer 4: 2582420.76864
#
# Total Macro for layer 4: 288
#
# Total Area for all layers: 10329683.07456
# Total Area for ADC across all layers: 8212348.8
# Processing layer: SRAM_vision_transformer_128_fast_layer_5
# Size: 2
# All macro: 2
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 57030.2
#
# Size: 2
# All macro: 2
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 2109.3
#
# Size: 2
# All macro: 2
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 1856.992
#
# Size: 2
# All macro: 2
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 10737.41824
#
# Total Area for layer 5: 71733.91024
#
# Total Macro for layer 5: 290
#
# Total Area for all layers: 10401416.9848
# Total Area for ADC across all layers: 8269379.0
# Processing layer: SRAM_vision_transformer_128_fast_layer_6
# Size: 4
# Size: 2
# All macro: 8
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 228120.8
#
# Size: 4
# Size: 2
# All macro: 8
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 8437.2
#
# Size: 4
# Size: 2
# All macro: 8
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 7427.968
#
# Size: 4
# Size: 2
# All macro: 8
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 42949.67296
#
# Total Area for layer 6: 286935.64096
#
# Total Macro for layer 6: 298
#
# Total Area for all layers: 10688352.62576
# Total Area for ADC across all layers: 8497499.8
# Processing layer: SRAM_vision_transformer_128_fast_layer_7
# Size: 12
# Size: 6
# All macro: 72
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 2053087.2
#
# Size: 12
# Size: 6
# All macro: 72
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 75934.8
#
# Size: 12
# Size: 6
# All macro: 72
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 66851.712
#
# Size: 12
# Size: 6
# All macro: 72
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 386547.05664
#
# Total Area for layer 7: 2582420.76864
#
# Total Macro for layer 7: 370
#
# Total Area for all layers: 13270773.3944
# Total Area for ADC across all layers: 10550587.0
# Processing layer: SRAM_vision_transformer_128_fast_layer_8
# Size: 48
# Size: 6
# All macro: 288
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 8212348.8
#
# Size: 48
# Size: 6
# All macro: 288
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 303739.2
#
# Size: 48
# Size: 6
# All macro: 288
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 267406.848
#
# Size: 48
# Size: 6
# All macro: 288
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 1546188.22656
#
# Total Area for layer 8: 10329683.07456
#
# Total Macro for layer 8: 658
#
# Total Area for all layers: 23600456.468960002
# Total Area for ADC across all layers: 18762935.8
# Processing layer: SRAM_vision_transformer_128_fast_layer_9
# Size: 12
# Size: 24
# All macro: 288
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 8212348.8
#
# Size: 12
# Size: 24
# All macro: 288
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 303739.2
#
# Size: 12
# Size: 24
# All macro: 288
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 267406.848
#
# Size: 12
# Size: 24
# All macro: 288
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 1546188.22656
#
# Total Area for layer 9: 10329683.07456
#
# Total Macro for layer 9: 946
#
# Total Area for all layers: 33930139.54352
# Total Area for ADC across all layers: 26975284.6
# Processing layer: SRAM_vision_transformer_128_fast_layer_10
# Size: 12
# Size: 6
# All macro: 72
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 2053087.2
#
# Size: 12
# Size: 6
# All macro: 72
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 75934.8
#
# Size: 12
# Size: 6
# All macro: 72
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 66851.712
#
# Size: 12
# Size: 6
# All macro: 72
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 386547.05664
#
# Total Area for layer 10: 2582420.76864
#
# Total Macro for layer 10: 1018
#
# Total Area for all layers: 36512560.31216
# Total Area for ADC across all layers: 29028371.8
# Processing layer: SRAM_vision_transformer_128_fast_layer_11
# Size: 12
# Size: 6
# All macro: 72
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 2053087.2
#
# Size: 12
# Size: 6
# All macro: 72
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 75934.8
#
# Size: 12
# Size: 6
# All macro: 72
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 66851.712
#
# Size: 12
# Size: 6
# All macro: 72
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 386547.05664
#
# Total Area for layer 11: 2582420.76864
#
# Total Macro for layer 11: 1090
#
# Total Area for all layers: 39094981.0808
# Total Area for ADC across all layers: 31081459.0
# Processing layer: SRAM_vision_transformer_128_fast_layer_12
# Size: 12
# Size: 6
# All macro: 72
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 2053087.2
#
# Size: 12
# Size: 6
# All macro: 72
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 75934.8
#
# Size: 12
# Size: 6
# All macro: 72
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 66851.712
#
# Size: 12
# Size: 6
# All macro: 72
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 386547.05664
#
# Total Area for layer 12: 2582420.76864
#
# Total Macro for layer 12: 1162
#
# Total Area for all layers: 41677401.84943999
# Total Area for ADC across all layers: 33134546.2
# Processing layer: SRAM_vision_transformer_128_fast_layer_13
# Size: 2
# All macro: 2
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 57030.2
#
# Size: 2
# All macro: 2
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 2109.3
#
# Size: 2
# All macro: 2
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 1856.992
#
# Size: 2
# All macro: 2
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 10737.41824
#
# Total Area for layer 13: 71733.91024
#
# Total Macro for layer 13: 1164
#
# Total Area for all layers: 41749135.759679995
# Total Area for ADC across all layers: 33191576.4
# Processing layer: SRAM_vision_transformer_128_fast_layer_14
# Size: 4
# Size: 2
# All macro: 8
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 228120.8
#
# Size: 4
# Size: 2
# All macro: 8
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 8437.2
#
# Size: 4
# Size: 2
# All macro: 8
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 7427.968
#
# Size: 4
# Size: 2
# All macro: 8
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 42949.67296
#
# Total Area for layer 14: 286935.64096
#
# Total Macro for layer 14: 1172
#
# Total Area for all layers: 42036071.400639996
# Total Area for ADC across all layers: 33419697.2
# Processing layer: SRAM_vision_transformer_128_fast_layer_15
# Size: 12
# Size: 6
# All macro: 72
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 2053087.2
#
# Size: 12
# Size: 6
# All macro: 72
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 75934.8
#
# Size: 12
# Size: 6
# All macro: 72
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 66851.712
#
# Size: 12
# Size: 6
# All macro: 72
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 386547.05664
#
# Total Area for layer 15: 2582420.76864
#
# Total Macro for layer 15: 1244
#
# Total Area for all layers: 44618492.16927999
# Total Area for ADC across all layers: 35472784.4
# Processing layer: SRAM_vision_transformer_128_fast_layer_16
# Size: 48
# Size: 6
# All macro: 288
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 8212348.8
#
# Size: 48
# Size: 6
# All macro: 288
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 303739.2
#
# Size: 48
# Size: 6
# All macro: 288
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 267406.848
#
# Size: 48
# Size: 6
# All macro: 288
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 1546188.22656
#
# Total Area for layer 16: 10329683.07456
#
# Total Macro for layer 16: 1532
#
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_17
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_18
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_19
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_20
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_21
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_22
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_23
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_24
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_25
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_26
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_27
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_28
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_29
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_30
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_31
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_32
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_33
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_34
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_35
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_36
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_37
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_38
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_39
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_40
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_41
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_42
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_43
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_44
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_45
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_46
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_47
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_48
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_49
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_50
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_51
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_52
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_53
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_54
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_55
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_56
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_57
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_58
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_59
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_60
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_61
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_62
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_63
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_64
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_65
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_66
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_67
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_68
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_69
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_70
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_71
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_72
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_73
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_74
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_75
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_76
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_77
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_78
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_79
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_80
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_81
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_82
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_83
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_84
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_85
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_86
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_87
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_88
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_89
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_90
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_91
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_92
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_93
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_94
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_95
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_96
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_97
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Processing layer: SRAM_vision_transformer_128_fast_layer_98
# Total Area for all layers: 54948175.243839994
# Total Area for ADC across all layers: 43685133.199999996
# Total Area for column drivers across all layers: 1615723.8
# Total Area for row drivers across all layers: 1422455.8720000004
# Total Area for cim unit across all layers: 8224862.371840001
#
#
# Total Area for ADC across all layers: 43.685133199999996
# Total Area for column driver across all layers: 1.6157238
# Total Area for row driver across all layers: 1.4224558720000005
# Total Area for cim unit across all layers: 8.22486237184
# Total Macro across all layers: 1532
# SRAM_vision_transformer_128_fast 	 4.89e-04 	 54.95 	 6.82e+02
# ../outputs/RRAM_vision_transformer_128_fast/
# Model 	 Energy/inference (J) 	 Area (mm2) 	 Throughput (inf/s)
# Processing layer: RRAM_vision_transformer_128_fast_layer_1
# Size: 2
# Size: 12
# Size: 3
# All macro: 72
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 2142417.6
#
# Size: 2
# Size: 12
# Size: 3
# All macro: 72
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 31752.935999999998
#
# Size: 2
# Size: 12
# Size: 3
# All macro: 72
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 36289.08
#
# Size: 2
# Size: 12
# Size: 3
# All macro: 72
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 48318.38208
#
# Total Area for layer 1: 2258777.9980800003
#
# Total Macro for layer 1: 72
#
# Total Area for all layers: 2258777.9980800003
# Total Area for ADC across all layers: 2142417.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_2
# Size: 12
# Size: 6
# All macro: 72
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 2142417.6
#
# Size: 12
# Size: 6
# All macro: 72
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 31752.935999999998
#
# Size: 12
# Size: 6
# All macro: 72
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 36289.08
#
# Size: 12
# Size: 6
# All macro: 72
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 48318.38208
#
# Total Area for layer 2: 2258777.9980800003
#
# Total Macro for layer 2: 144
#
# Total Area for all layers: 4517555.996160001
# Total Area for ADC across all layers: 4284835.2
# Processing layer: RRAM_vision_transformer_128_fast_layer_3
# Size: 12
# Size: 6
# All macro: 72
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 2142417.6
#
# Size: 12
# Size: 6
# All macro: 72
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 31752.935999999998
#
# Size: 12
# Size: 6
# All macro: 72
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 36289.08
#
# Size: 12
# Size: 6
# All macro: 72
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 48318.38208
#
# Total Area for layer 3: 2258777.9980800003
#
# Total Macro for layer 3: 216
#
# Total Area for all layers: 6776333.994240001
# Total Area for ADC across all layers: 6427252.800000001
# Processing layer: RRAM_vision_transformer_128_fast_layer_4
# Size: 12
# Size: 6
# All macro: 72
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 2142417.6
#
# Size: 12
# Size: 6
# All macro: 72
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 31752.935999999998
#
# Size: 12
# Size: 6
# All macro: 72
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 36289.08
#
# Size: 12
# Size: 6
# All macro: 72
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 48318.38208
#
# Total Area for layer 4: 2258777.9980800003
#
# Total Macro for layer 4: 288
#
# Total Area for all layers: 9035111.992320001
# Total Area for ADC across all layers: 8569670.4
# Processing layer: RRAM_vision_transformer_128_fast_layer_5
# Size: 2
# All macro: 2
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 59511.6
#
# Size: 2
# All macro: 2
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 882.026
#
# Size: 2
# All macro: 2
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 1008.03
#
# Size: 2
# All macro: 2
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 1342.17728
#
# Total Area for layer 5: 62743.83328
#
# Total Macro for layer 5: 290
#
# Total Area for all layers: 9097855.825600002
# Total Area for ADC across all layers: 8629182.0
# Processing layer: RRAM_vision_transformer_128_fast_layer_6
# Size: 4
# Size: 2
# All macro: 8
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 238046.4
#
# Size: 4
# Size: 2
# All macro: 8
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 3528.104
#
# Size: 4
# Size: 2
# All macro: 8
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 4032.12
#
# Size: 4
# Size: 2
# All macro: 8
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 5368.70912
#
# Total Area for layer 6: 250975.33312
#
# Total Macro for layer 6: 298
#
# Total Area for all layers: 9348831.158720002
# Total Area for ADC across all layers: 8867228.4
# Processing layer: RRAM_vision_transformer_128_fast_layer_7
# Size: 12
# Size: 6
# All macro: 72
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 2142417.6
#
# Size: 12
# Size: 6
# All macro: 72
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 31752.935999999998
#
# Size: 12
# Size: 6
# All macro: 72
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 36289.08
#
# Size: 12
# Size: 6
# All macro: 72
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 48318.38208
#
# Total Area for layer 7: 2258777.9980800003
#
# Total Macro for layer 7: 370
#
# Total Area for all layers: 11607609.156800002
# Total Area for ADC across all layers: 11009646.0
# Processing layer: RRAM_vision_transformer_128_fast_layer_8
# Size: 48
# Size: 6
# All macro: 288
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 8569670.4
#
# Size: 48
# Size: 6
# All macro: 288
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 127011.74399999999
#
# Size: 48
# Size: 6
# All macro: 288
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 145156.32
#
# Size: 48
# Size: 6
# All macro: 288
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 193273.52832
#
# Total Area for layer 8: 9035111.992320001
#
# Total Macro for layer 8: 658
#
# Total Area for all layers: 20642721.149120003
# Total Area for ADC across all layers: 19579316.4
# Processing layer: RRAM_vision_transformer_128_fast_layer_9
# Size: 12
# Size: 24
# All macro: 288
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 8569670.4
#
# Size: 12
# Size: 24
# All macro: 288
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 127011.74399999999
#
# Size: 12
# Size: 24
# All macro: 288
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 145156.32
#
# Size: 12
# Size: 24
# All macro: 288
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 193273.52832
#
# Total Area for layer 9: 9035111.992320001
#
# Total Macro for layer 9: 946
#
# Total Area for all layers: 29677833.141440004
# Total Area for ADC across all layers: 28148986.799999997
# Processing layer: RRAM_vision_transformer_128_fast_layer_10
# Size: 12
# Size: 6
# All macro: 72
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 2142417.6
#
# Size: 12
# Size: 6
# All macro: 72
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 31752.935999999998
#
# Size: 12
# Size: 6
# All macro: 72
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 36289.08
#
# Size: 12
# Size: 6
# All macro: 72
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 48318.38208
#
# Total Area for layer 10: 2258777.9980800003
#
# Total Macro for layer 10: 1018
#
# Total Area for all layers: 31936611.139520004
# Total Area for ADC across all layers: 30291404.4
# Processing layer: RRAM_vision_transformer_128_fast_layer_11
# Size: 12
# Size: 6
# All macro: 72
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 2142417.6
#
# Size: 12
# Size: 6
# All macro: 72
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 31752.935999999998
#
# Size: 12
# Size: 6
# All macro: 72
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 36289.08
#
# Size: 12
# Size: 6
# All macro: 72
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 48318.38208
#
# Total Area for layer 11: 2258777.9980800003
#
# Total Macro for layer 11: 1090
#
# Total Area for all layers: 34195389.137600005
# Total Area for ADC across all layers: 32433822.0
# Processing layer: RRAM_vision_transformer_128_fast_layer_12
# Size: 12
# Size: 6
# All macro: 72
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 2142417.6
#
# Size: 12
# Size: 6
# All macro: 72
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 31752.935999999998
#
# Size: 12
# Size: 6
# All macro: 72
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 36289.08
#
# Size: 12
# Size: 6
# All macro: 72
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 48318.38208
#
# Total Area for layer 12: 2258777.9980800003
#
# Total Macro for layer 12: 1162
#
# Total Area for all layers: 36454167.135680005
# Total Area for ADC across all layers: 34576239.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_13
# Size: 2
# All macro: 2
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 59511.6
#
# Size: 2
# All macro: 2
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 882.026
#
# Size: 2
# All macro: 2
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 1008.03
#
# Size: 2
# All macro: 2
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 1342.17728
#
# Total Area for layer 13: 62743.83328
#
# Total Macro for layer 13: 1164
#
# Total Area for all layers: 36516910.96896
# Total Area for ADC across all layers: 34635751.2
# Processing layer: RRAM_vision_transformer_128_fast_layer_14
# Size: 4
# Size: 2
# All macro: 8
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 238046.4
#
# Size: 4
# Size: 2
# All macro: 8
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 3528.104
#
# Size: 4
# Size: 2
# All macro: 8
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 4032.12
#
# Size: 4
# Size: 2
# All macro: 8
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 5368.70912
#
# Total Area for layer 14: 250975.33312
#
# Total Macro for layer 14: 1172
#
# Total Area for all layers: 36767886.302080005
# Total Area for ADC across all layers: 34873797.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_15
# Size: 12
# Size: 6
# All macro: 72
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 2142417.6
#
# Size: 12
# Size: 6
# All macro: 72
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 31752.935999999998
#
# Size: 12
# Size: 6
# All macro: 72
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 36289.08
#
# Size: 12
# Size: 6
# All macro: 72
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 48318.38208
#
# Total Area for layer 15: 2258777.9980800003
#
# Total Macro for layer 15: 1244
#
# Total Area for all layers: 39026664.300160006
# Total Area for ADC across all layers: 37016215.2
# Processing layer: RRAM_vision_transformer_128_fast_layer_16
# Size: 48
# Size: 6
# All macro: 288
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 8569670.4
#
# Size: 48
# Size: 6
# All macro: 288
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 127011.74399999999
#
# Size: 48
# Size: 6
# All macro: 288
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 145156.32
#
# Size: 48
# Size: 6
# All macro: 288
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 193273.52832
#
# Total Area for layer 16: 9035111.992320001
#
# Total Macro for layer 16: 1532
#
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_17
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_18
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_19
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_20
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_21
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_22
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_23
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_24
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_25
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_26
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_27
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_28
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_29
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_30
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_31
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_32
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_33
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_34
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_35
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_36
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_37
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_38
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_39
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_40
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_41
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_42
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_43
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_44
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_45
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_46
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_47
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_48
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_49
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_50
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_51
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_52
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_53
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_54
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_55
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_56
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_57
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_58
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_59
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_60
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_61
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_62
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_63
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_64
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_65
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_66
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_67
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_68
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_69
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_70
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_71
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_72
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_73
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_74
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_75
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_76
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_77
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_78
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_79
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_80
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_81
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_82
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_83
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_84
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_85
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_86
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_87
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_88
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_89
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_90
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_91
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_92
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_93
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_94
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_95
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_96
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_97
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Processing layer: RRAM_vision_transformer_128_fast_layer_98
# Total Area for all layers: 48061776.29248001
# Total Area for ADC across all layers: 45585885.6
# Total Area for column drivers across all layers: 675631.9159999999
# Total Area for row drivers across all layers: 772150.98
# Total Area for cim unit across all layers: 1028107.7964800001
#
#
# Total Area for ADC across all layers: 45.5858856
# Total Area for column driver across all layers: 0.6756319159999998
# Total Area for row driver across all layers: 0.7721509799999999
# Total Area for cim unit across all layers: 1.02810779648
# Total Macro across all layers: 1532
# RRAM_vision_transformer_128_fast 	 5.93e-04 	 48.06 	 6.82e+02

# %%
print(total_area)
print(total_adc_area)
print(total_col_area)
print(total_row_area)
print(total_cim_unit_area)
print(total_macro)
print(energy)
print(throughput)
# Out:
# [54.94817524383999, 48.061776292480005]
# [43.685133199999996, 45.5858856]
# [1.6157238, 0.6756319159999998]
# [1.4224558720000005, 0.7721509799999999]
# [8.22486237184, 1.02810779648]
# [1532, 1532]
# [0.0004889842899999996, 0.0005927573100000002]
# [681.7097279978185, 681.7097279978185]

# %%
import matplotlib.pyplot as plt
import numpy as np
fig, ax = plt.subplots(figsize=(10, 5)) 
# array_sizes = ['32', '64', '128', '256']
path = ['SRAM', 'RRAM']

x = np.arange(len(path))

# Stack bars
ax.bar(path, total_cim_unit_area, label='cim_unit')
ax.bar(path, total_row_area, bottom=total_cim_unit_area, label='row_drivers')
ax.bar(path, total_col_area, bottom=np.array(total_cim_unit_area) + np.array(total_row_area), label='column_drivers')
ax.bar(path, total_adc_area, bottom=np.array(total_cim_unit_area) + np.array(total_row_area) + np.array(total_col_area), label='adc')

# Labels and title
ax.set_title(f"Area vs Memory Type for {DNN} in fast scenario")
ax.set_xlabel("Memory type")
ax.set_ylabel("Area (mm2)")
# Set x-ticks
ax.set_xticks(x)
ax.set_xticklabels(path)

ax.legend()

# Show plot
plt.show()

# %%
for path in path_list:
    print(f"Memory Type: {path.split('/')[-1].split('_')[0].upper()}")
    # For each component index (0 to 3)
    for i in range(4):
        print(f"total_per_energy[{path.split('/')[-1].split('_')[0].upper()}][{i}]: {total_per_energy[path][i]}")
    print()
# Out:
# Memory Type: SRAM
# total_per_energy[SRAM][0]: 0.48394570197874043
# total_per_energy[SRAM][1]: 0.0029345643630625745
# total_per_energy[SRAM][2]: 0.5114036141476345
# total_per_energy[SRAM][3]: 0.0017161195105625283
#
# Memory Type: RRAM
# total_per_energy[RRAM][0]: 0.4596888260250064
# total_per_energy[RRAM][1]: 1.1555869872691976e-12
# total_per_energy[RRAM][2]: 0.3649222065059064
# total_per_energy[RRAM][3]: 0.17538896746793167

# %%
display_markdown(
    """
### Calculating the energy

"""
)

path_list = [SRAM_PATH, RRAM_PATH]
total_adc_energy = [0] * 2
total_col_energy = [0] * 2
total_row_energy = [0] * 2
total_cim_unit_energy = [0] * 2
for j in range(len(energy)):
    if j == 0:
        for i in range(4):
            if i == 0:
                total_adc_energy[j] = total_per_energy[path_list[0]][i] * energy[j]
            elif i == 1:
                total_col_energy[j] = total_per_energy[path_list[0]][i] * energy[j]
            elif i == 2:
                total_row_energy[j] = total_per_energy[path_list[0]][i] * energy[j]
            else:
                total_cim_unit_energy[j] = total_per_energy[path_list[0]][i] * energy[j]
    else:
        for i in range(4):
            if i == 0:
                total_adc_energy[j] = total_per_energy[path_list[1]][i] * energy[j]
            elif i == 1:
                total_col_energy[j] = total_per_energy[path_list[1]][i] * energy[j]
            elif i == 2:
                total_row_energy[j] = total_per_energy[path_list[1]][i] * energy[j]
            else:
                total_cim_unit_energy[j] = total_per_energy[path_list[1]][i] * energy[j]

    
print("Total ADC Energy:", total_adc_energy)
print("Total Column Energy:", total_col_energy)
print("Total Row Energy:", total_row_energy)
print("Total CIM Unit Energy:", total_cim_unit_energy)
# Out:
# ### Calculating the energy
# Total ADC Energy: [0.0002366418454806258, 0.0002724839119516409]
# Total Column Energy: [1.4349558715314542e-06, 6.849826340446941e-16]
# Total Row Energy: [0.0002500683331674148, 0.00021631030548770566]
# Total CIM Unit Energy: [8.391554804275648e-07, 0.00010396309255996873]

# %%
import matplotlib.pyplot as plt
import numpy as np
fig, ax = plt.subplots(figsize=(10, 5)) 
path = ['SRAM', 'RRAM']

# x = np.arange(len(array_sizes))

# Stack bars
ax.bar(path, total_cim_unit_energy, label='cim_unit')
ax.bar(path, total_row_energy, bottom=total_cim_unit_energy, label='row_drivers')
ax.bar(path, total_col_energy, bottom=np.array(total_cim_unit_energy) + np.array(total_row_energy), label='column_drivers')
ax.bar(path, total_adc_energy, bottom=np.array(total_cim_unit_energy) + np.array(total_row_energy) + np.array(total_col_energy), label='adc')

# Labels and title
ax.set_title(f"Energy vs Memory Type for {DNN} in fast scenario")
ax.set_xlabel("Memory type")
ax.set_ylabel("Energy (J)")
# Set x-ticks
ax.set_xticks(x)
ax.set_xticklabels(path)

ax.legend()

# Show plot
plt.show()

# %%
display_markdown(
    """
### Plot the Throughput

"""
)
import matplotlib.pyplot as plt

# Data
path = ['SRAM', 'RRAM']
x = np.arange(len(path))
# Plotting the line graph
plt.figure(figsize=(10, 6))
plt.plot(path, throughput, marker='o', linestyle='-', color='b')

# Adding labels and title
plt.xlabel('Memory type')
plt.ylabel('Throughput')
plt.title(f'Throughput vs Memory Type for {DNN}')
plt.grid(False)
plt.xticks(x, path) 
# Show plot
plt.show()
# Out:
# ### Plot the Throughput

# %%
display_markdown(
    """
### Plot the Number of Macros

"""
)
import matplotlib.pyplot as plt

# Data
path = ['SRAM', 'RRAM']
x = np.arange(len(path))
# Plotting the line graph
plt.figure(figsize=(10, 6))
plt.plot(path, total_macro, marker='o', linestyle='-', color='b')

# Adding labels and title
plt.xlabel('Memory type')
plt.ylabel('Number of Macros')
plt.title(f'Number of Macros vs Memory Type for {DNN}')
plt.grid(False)
plt.xticks(x, path) 
# Show plot
plt.show()
# Out:
# ### Plot the Number of Macros
