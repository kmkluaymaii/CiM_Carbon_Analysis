# %%
from _import_scripts import scripts
from scripts.notebook_utils import *
from scripts.tl_output_parsing import MacroOutputStats
from scripts.utils import *
import yaml

def create_layer_directory(base_output_dir: str, architecture: str, layer: int) -> str:
    layer_dir = os.path.join(base_output_dir, f"{architecture}_layer_{layer}")
    if not os.path.exists(layer_dir):
        os.makedirs(layer_dir)
    return layer_dir

num_layers = 1

def run_map(
    spec: tl.Specification,
    arch: str,
    accelergy_verbose: bool = False,
) -> dict:
    output_dir = get_run_dir()
    # Just use the directory name if it causes error
    base_output_dir = os.path.dirname(output_dir)
    base_output_dir = os.path.join(base_output_dir, arch)
    global num_layers

    mapper_result = None

    if num_layers < 228:
        # Create a directory for the current layer
        layer_dir = create_layer_directory(base_output_dir, arch, num_layers)
        # print(f"Layer directory: {layer_dir}")
        num_layers += 1

        run_prefix = f"{layer_dir}/timeloop-mapper"
        mapper_result = tl.call_mapper(
            specification=spec,
            output_dir=layer_dir,
            log_to=os.path.join(output_dir, f"{run_prefix}.log"),
        )
        if accelergy_verbose:
            tl.call_accelergy_verbose(
                specification=spec,
                output_dir=layer_dir,
                log_to=os.path.join(output_dir, "accelergy.log"),
            )

    if mapper_result is None:
        # Handle case when mapper_result is not assigned (num_layers >= 17)
        # Raise an error, return a default value
        print("Warning: mapper_result is not assigned. num_layers >= 17")
        return {}

    return MacroOutputStats.from_output_stats(mapper_result)

import re

def extract_range(line):
    match = re.search(r'\[(\d+):(\d+)(,\d+)?\)', line)
    if match:
        start = int(match.group(1))
        end = int(match.group(2))
        return end - start
    return None

def read_and_compute_multiplication(filename, i):
    filename = f"../outputs/{filename}/{filename}_layer_{i+1}/timeloop-mapper.map.txt"
    with open(filename, 'r') as file:
        lines = file.readlines()

    start_searching = False
    ranges = []

    for line in lines:
        # Start searching when 'inter_macro_in_system_spatial' is found
        if "inter_macro_in_system_spatial" in line:
            start_searching = True
        
        # Stop searching if we leave the 'inter_macro_in_system_spatial' section
        elif start_searching and "inter_" in line and "inter_macro_in_system_spatial" not in line:
            break

        # If we are in the 'inter_macro_in_system_spatial' section, look for the ranges
        if start_searching:
            if "for" in line:
                range_size = extract_range(line)
                if range_size is not None:
                    ranges.append(range_size)
            elif line.strip() == "":  # Exit the section on an empty line
                break

    # Compute the multiplication of all ranges, or return 1 if no ranges were found
    if not ranges:
        print(f"All macro: 1")
        return 1

    result = 1
    for size in ranges:
        result *= size
        print(f"Size: {size}")
    print(f"All macro: {result}")
    return result


def extract_layer_number(folder_name):
    match = re.search(r'layer_(\d+)', folder_name)
    return int(match.group(1)) if match else float('inf')

def extract_outputs(model):
    
    output_dir = "../outputs/" + model + "/" 
    print(output_dir)

    print ("Model \t Energy/inference (J) \t Area (mm2) \t Throughput (inf/s)")
    #for model in models:    
    throughput = 0   
    energy = 0
    area = 0
    cycles = 0
    folders = sorted([folder for folder in os.listdir(output_dir) if model in folder], key=extract_layer_number)
    area_per_many_macro = 0
    area_layer = 0
    j = 0
    total_sum = 0
    total_adc_area = 0  # Total area for ADC across all layers
    total_other_areas = {}  # Dictionary to store total areas for other components
    total_col_area = 0
    total_row_area = 0
    total_cim_unit_area = 0
    total_area = 0
    total_macro = 0
    
    for folder in folders:
        total = 0
        if model in folder:
            print(f"Processing layer: {folder}")
            # print(folder)
            if os.path.isdir(output_dir + folder):
                stat_file = output_dir + folder + "/timeloop-mapper.stats.txt"
                art_file = output_dir + folder + "/timeloop-mapper.ART.yaml"
        
                with open(stat_file, 'r') as f:
                    energy_stat = [line for line in f if line.startswith("Energy:")][0]
                    energy_uj = energy_stat.split(' ')[1] # uJ
                    energy += float(energy_uj)
                    # print(f"Energy for this layer: {float(energy_uj)} uj")
                
                with open(stat_file, 'r') as f:
                    cycle_stat = [line for line in f if line.startswith("Cycles:")][0]                  
                    cycle = cycle_stat.split(' ')[1] 
                    cycles += float(cycle)
                    
            if j < 16:
                with open(art_file, 'r') as file:
                    data = yaml.safe_load(file)
                
                    # Extract and print the name, area, number of entries, and ratio for non-zero areas
                for table in data['ART']['tables']:
                    name = table.get('name')
                    area = table.get('area')
                    if area != 0:
                        # Simplify the name for the output
                        if 'system_top_level.' in name:
                            name = name.split('system_top_level.')[-1]
                        
                        # Extract the number of entries from the name
                        if '[' in name:
                            name_part, entries_part = name.split('[')
                            number_of_entries = entries_part.split('..')[1].replace(']', '')
                            name = name_part.strip()
                        else:
                            number_of_entries = 'Unknown'
                        
                        macro = read_and_compute_multiplication(model, j)
                        # Calculate total ratio
                        if number_of_entries != 'Unknown' and number_of_entries.isdigit():
                            total_ratio = (area / 4096) * macro * int(number_of_entries)
                        else:
                            total_ratio = 0
                        
                        total += total_ratio
                           
                        # Accumulate area for ADC or other components
                        if 'adc' in name.lower():
                            total_adc_area += total_ratio
                        else:
                            if name not in total_other_areas:
                                total_other_areas[name] = 0
                            total_other_areas[name] += total_ratio
            
                        print(f"{name.replace('_', ' ')} area: {area}, number of {name}: {number_of_entries}, \ntotal {name.replace('_', ' ')} area: ({area}*{number_of_entries}/4096) * macro = {total_ratio}\n")
                j += 1 
                total_sum += total
                total_macro += macro
                print(f"Total Area for layer {j}: {total}\n")
                print(f"Total Macro for layer {j}: {total_macro}\n")
            print(f"Total Area for all layers: {total_sum}")
            print(f"Total Area for ADC across all layers: {total_adc_area}")
    
    # Print total area for other components
    for component, area in total_other_areas.items():
        print(f"Total Area for {component.replace('_', ' ')} across all layers: {area}")
        # print(component.replace('_', ' '))
        if component.replace('_', ' ') ==  "column drivers":
            total_col_area = area
        elif component.replace('_', ' ') ==  "row drivers":
            total_row_area = area
        else:
            total_cim_unit_area = area
                                
    energy *= 1e-6 # conver to J
    total_area = total_sum * 1e-6 # mm2
    throughput = 1 / (cycles * 1e-7) # s

    total_adc_area = total_adc_area * 1e-6 # mm2
    total_col_area = total_col_area * 1e-6 # mm2
    total_row_area = total_row_area * 1e-6 # mm2
    total_cim_unit_area = total_cim_unit_area * 1e-6 # mm2
    print("\n")
    print(f"Total Area for ADC across all layers: {total_adc_area}")
    print(f"Total Area for column driver across all layers: {total_col_area}")
    print(f"Total Area for row driver across all layers: {total_row_area}")
    print(f"Total Area for cim unit across all layers: {total_cim_unit_area}")
    print(f"Total Macro across all layers: {total_macro}")
    print ("{} \t {:.2e} \t {:.2f} \t {:.2e}".format(model, energy, total_area, throughput))
    
    return total_area, total_adc_area, total_col_area, total_row_area, total_cim_unit_area, total_macro, energy, throughput

# %%
MACRO_PATH = "../models/arch/1_macro/basic_analog/" 
macro = {}
SRAM_PATH = f'"{os.path.abspath("../models/memory_cells/sram_example.cell.yaml")}"'
RRAM_PATH = f'"{os.path.abspath("../models/memory_cells/rram_example.cell.yaml")}"'

# Define the architecture
array_sizes = 128
path_list = [SRAM_PATH, RRAM_PATH]
tech_node = 32
# adc_resolution = 6
DNN = "dpt_large"
time = "fast"

total_per_energy = {}

for path in path_list:
    arch = f"{path.split('/')[-1].split('_')[0].upper()}_{DNN}_{array_sizes}_{time}"
    print(f"\nRunning {DNN} with {array_sizes} x {array_sizes} {path.split('/')[-1].split('_')[0].upper()} with {tech_node} nm in {time} scenario")

    num_layers = 1

    def run_dnn(dnn: str, layer: str, array_sizes: int, variables):
        print(f"{layer} ", end="", flush=True)
        spec = get_spec(
            "basic_analog",
            # Weight-stationary, dummy buffer on top to hold inputs & outputs, many
            # macros to ensure we can fit all weights.
            system="ws_dummy_buffer_many_macro",
            # Set the DNN and layer
            dnn=dnn,
            layer=layer,
        )
    
        # Do NOT generate a maximum-utilization workload; we're running a DNN
        # workload.
        spec.variables["MAX_UTILIZATION"] = False
    
        # Use a larger array to ensure we can fit all weights
        spec.architecture.find("column").spatial.meshX = array_sizes
        spec.architecture.find("row").spatial.meshY = array_sizes
    
        spec.variables.update(variables)
        output_stats = run_map(spec, arch)
        
        # Print computes for the layer
        macro_output_stats = MacroOutputStats.from_output_stats(output_stats)
        print(f"Computes for layer {int(layer) + 1}: {macro_output_stats.computes}")
        global macro
        macro[layer] = macro_output_stats.computes
        return output_stats
    
    layers = [f for f in os.listdir(f"../models/workloads/{DNN}") if f != "index.yaml" and f.endswith(".yaml")]
    layers = sorted(layers)
    print(f"Running: ", end="")
    
    # Parallel/Delayed is used to multiprocess. Equivalent to running the following
    # code in serial:
    results = joblib.Parallel(n_jobs=None)(
        joblib.delayed(run_dnn)(DNN, layer.split(".")[0], array_sizes, 
                                  {
                                      "CELL_CONFIG": path,
                                      "BITS_PER_CELL": 1 if path == SRAM_PATH else 4,
                                      "CIM_UNIT_WIDTH_CELLS": 4 if path == SRAM_PATH else 1,
                                      "IS_SRAM": path == SRAM_PATH,
                                      "TECHNOLOGY": tech_node,
                                      "ADC_RESOLUTION": 4 if path == SRAM_PATH else 6,
                                      "GLOBAL_CYCLE_SECONDS": 1e-7 if time == "fast" else 1e-4,
                                  }
                                 ) for layer in layers
    )
    print("")
    for r in results:
        r.clear_zero_energies()
    
    #Initialize overall_energy
    energy_layer = [0] * 16
    result = 0
    
    # total_per_energy_32 = [0] * 4
    
    total_adc_energy = 0.0
    total_col_energy = 0.0
    total_row_energy = 0.0
    total_cim_unit_energy = 0.0
    # Calculate overall energy
    for r in results:
    
        per_component_energy = r.per_compute("per_component_energy")
        total_energy_per_layer = sum(per_component_energy.values()) * 1e15  # Convert to fJ
        total_adc_energy += per_component_energy.get('adc', 0.0)
        total_col_energy += per_component_energy.get('column_drivers', 0.0)
        total_row_energy += per_component_energy.get('row_drivers', 0.0)
        total_cim_unit_energy += per_component_energy.get('cim_unit', 0.0)
    
        total_adc_energy = total_adc_energy * 1e15
        total_col_energy = total_col_energy * 1e15
        total_row_energy = total_row_energy * 1e15
        total_cim_unit_energy = total_cim_unit_energy * 1e15
        total_energy = total_adc_energy + total_col_energy + total_row_energy + total_cim_unit_energy
    
        total_adc_energy = total_adc_energy/total_energy
        total_col_energy = total_col_energy/total_energy
        total_row_energy = total_row_energy/total_energy
        total_cim_unit_energy = total_cim_unit_energy/total_energy

        total_per_energy[path] = [total_adc_energy, total_col_energy, total_row_energy, total_cim_unit_energy]
        
    # Display overall energy
    print(f"Overall energy for DNN {DNN}: {total_energy} fJ")
    
    # Display an energy breakdown for each layer as a bar chart. Display normalized per-MAC and per-layer energy.
    fig, ax = plt.subplots(figsize=(20, 5))
    
    bar_stacked(
        {i: r.per_compute("per_component_energy") * 1e15 for i, r in enumerate(results)},
        title= f"Using {path.split('/')[-1].split('_')[0].upper()} on {array_sizes} x {array_sizes} array sizes, {tech_node} nm",
        xlabel="Layer",
        ylabel="Energy (fJ/MAC)",
        ax=ax,
    )
# Out:
# Running dpt_large with 128 x 128 SRAM with 32 nm in fast scenario
# Computes for layer 1: 884736.0
# Computes for layer 2: 1181696.0
# Computes for layer 3: 1181696.0
# Computes for layer 4: 1181696.0
# Computes for layer 5: 1154.0
# Computes for layer 6: 10404.03125
# Computes for layer 7: 1181696.0
# Computes for layer 8: 4726784.0
# Computes for layer 9: 4726784.0
# Computes for layer 10: 1181696.0
# Computes for layer 11: 1181696.0
# Computes for layer 12: 1181696.0
# Computes for layer 13: 1154.0
# Computes for layer 14: 10404.03125
# Computes for layer 15: 1181696.0
# Computes for layer 16: 4726784.0
# Computes for layer 17: 4726784.0
# Computes for layer 18: 1181696.0
# Computes for layer 19: 1181696.0
# Computes for layer 20: 1181696.0
# Computes for layer 21: 1154.0
# Computes for layer 22: 10404.03125
# Computes for layer 23: 1181696.0
# Computes for layer 24: 4726784.0
# Computes for layer 25: 4726784.0
# Computes for layer 26: 1181696.0
# Computes for layer 27: 1181696.0
# Computes for layer 28: 1181696.0
# Computes for layer 29: 1154.0
# Computes for layer 30: 10404.03125
# Computes for layer 31: 1181696.0
# Computes for layer 32: 4726784.0
# Computes for layer 33: 4726784.0
# Computes for layer 34: 1181696.0
# Computes for layer 35: 1181696.0
# Computes for layer 36: 1181696.0
# Computes for layer 37: 1154.0
# Computes for layer 38: 10404.03125
# Computes for layer 39: 1181696.0
# Computes for layer 40: 4726784.0
# Computes for layer 41: 4726784.0
# Computes for layer 42: 1181696.0
# Computes for layer 43: 1181696.0
# Computes for layer 44: 1181696.0
# Computes for layer 45: 1154.0
# Computes for layer 46: 10404.03125
# Computes for layer 47: 1181696.0
# Computes for layer 48: 4726784.0
# Computes for layer 49: 4726784.0
# Computes for layer 50: 1181696.0
# Computes for layer 51: 1181696.0
# Computes for layer 52: 1181696.0
# Computes for layer 53: 1154.0
# Computes for layer 54: 10404.03125
# Computes for layer 55: 1181696.0
# Computes for layer 56: 4726784.0
# Computes for layer 57: 4726784.0
# Computes for layer 58: 1181696.0
# Computes for layer 59: 1181696.0
# Computes for layer 60: 1181696.0
# Computes for layer 61: 1154.0
# Computes for layer 62: 10404.03125
# Computes for layer 63: 1181696.0
# Computes for layer 64: 4726784.0
# Computes for layer 65: 4726784.0
# Computes for layer 66: 1181696.0
# Computes for layer 67: 1181696.0
# Computes for layer 68: 1181696.0
# Computes for layer 69: 1154.0
# Computes for layer 70: 10404.03125
# Computes for layer 71: 1181696.0
# Computes for layer 72: 4726784.0
# Computes for layer 73: 4726784.0
# Computes for layer 74: 1181696.0
# Computes for layer 75: 1181696.0
# Computes for layer 76: 1181696.0
# Computes for layer 77: 1154.0
# Computes for layer 78: 10404.03125
# Computes for layer 79: 1181696.0
# Computes for layer 80: 4726784.0
# Computes for layer 81: 4726784.0
# Computes for layer 82: 1181696.0
# Computes for layer 83: 1181696.0
# Computes for layer 84: 1181696.0
# Computes for layer 85: 1154.0
# Computes for layer 86: 10404.03125
# Computes for layer 87: 1181696.0
# Computes for layer 88: 4726784.0
# Computes for layer 89: 4726784.0
# Computes for layer 90: 1181696.0
# Computes for layer 91: 1181696.0
# Computes for layer 92: 1181696.0
# Computes for layer 93: 1154.0
# Computes for layer 94: 10404.03125
# Computes for layer 95: 1181696.0
# Computes for layer 96: 4726784.0
# Computes for layer 97: 4726784.0
# Computes for layer 98: 1181696.0
# Computes for layer 99: 1181696.0
# Computes for layer 100: 1181696.0
# Computes for layer 101: 1154.0
# Computes for layer 102: 10404.03125
# Computes for layer 103: 1181696.0
# Computes for layer 104: 4726784.0
# Computes for layer 105: 4726784.0
# Computes for layer 106: 1181696.0
# Computes for layer 107: 1181696.0
# Computes for layer 108: 1181696.0
# Computes for layer 109: 1154.0
# Computes for layer 110: 10404.03125
# Computes for layer 111: 1181696.0
# Computes for layer 112: 4726784.0
# Computes for layer 113: 4726784.0
# Computes for layer 114: 1181696.0
# Computes for layer 115: 1181696.0
# Computes for layer 116: 1181696.0
# Computes for layer 117: 1154.0
# Computes for layer 118: 10404.03125
# Computes for layer 119: 1181696.0
# Computes for layer 120: 4726784.0
# Computes for layer 121: 4726784.0
# Computes for layer 122: 1181696.0
# Computes for layer 123: 1181696.0
# Computes for layer 124: 1181696.0
# Computes for layer 125: 1154.0
# Computes for layer 126: 10404.03125
# Computes for layer 127: 1181696.0
# Computes for layer 128: 4726784.0
# Computes for layer 129: 4726784.0
# Computes for layer 130: 1181696.0
# Computes for layer 131: 1181696.0
# Computes for layer 132: 1181696.0
# Computes for layer 133: 1154.0
# Computes for layer 134: 10404.03125
# Computes for layer 135: 1181696.0
# Computes for layer 136: 4726784.0
# Computes for layer 137: 4726784.0
# Computes for layer 138: 1181696.0
# Computes for layer 139: 1181696.0
# Computes for layer 140: 1181696.0
# Computes for layer 141: 1154.0
# Computes for layer 142: 10404.03125
# Computes for layer 143: 1181696.0
# Computes for layer 144: 4726784.0
# Computes for layer 145: 4726784.0
# Computes for layer 146: 1181696.0
# Computes for layer 147: 1181696.0
# Computes for layer 148: 1181696.0
# Computes for layer 149: 1154.0
# Computes for layer 150: 10404.03125
# Computes for layer 151: 1181696.0
# Computes for layer 152: 4726784.0
# Computes for layer 153: 4726784.0
# Computes for layer 154: 1181696.0
# Computes for layer 155: 1181696.0
# Computes for layer 156: 1181696.0
# Computes for layer 157: 1154.0
# Computes for layer 158: 10404.03125
# Computes for layer 159: 1181696.0
# Computes for layer 160: 4726784.0
# Computes for layer 161: 4726784.0
# Computes for layer 162: 1181696.0
# Computes for layer 163: 1181696.0
# Computes for layer 164: 1181696.0
# Computes for layer 165: 1154.0
# Computes for layer 166: 10404.03125
# Computes for layer 167: 1181696.0
# Computes for layer 168: 4726784.0
# Computes for layer 169: 4726784.0
# Computes for layer 170: 1181696.0
# Computes for layer 171: 1181696.0
# Computes for layer 172: 1181696.0
# Computes for layer 173: 1154.0
# Computes for layer 174: 10404.03125
# Computes for layer 175: 1181696.0
# Computes for layer 176: 4726784.0
# Computes for layer 177: 4726784.0
# Computes for layer 178: 1181696.0
# Computes for layer 179: 1181696.0
# Computes for layer 180: 1181696.0
# Computes for layer 181: 1154.0
# Computes for layer 182: 10404.03125
# Computes for layer 183: 1181696.0
# Computes for layer 184: 4726784.0
# Computes for layer 185: 4726784.0
# Computes for layer 186: 1181696.0
# Computes for layer 187: 1181696.0
# Computes for layer 188: 1181696.0
# Computes for layer 189: 1154.0
# Computes for layer 190: 10404.03125
# Computes for layer 191: 1181696.0
# Computes for layer 192: 4726784.0
# Computes for layer 193: 4726784.0
# Computes for layer 194: 2359296.0
# Computes for layer 195: 294912.0
# Computes for layer 196: 2359296.0
# Computes for layer 197: 589824.0
# Computes for layer 198: 2359296.0
# Computes for layer 199: 1179648.0
# Computes for layer 200: 2359296.0
# Computes for layer 201: 1179648.0
# Computes for layer 202: 2654208.0
# Computes for layer 203: 10616832.0
# Computes for layer 204: 5308416.0
# Computes for layer 205: 2654208.0
# Computes for layer 206: 663552.0
# Computes for layer 207: 165888.0
# Computes for layer 208: 165888.0
# Computes for layer 209: 73728.0
# Computes for layer 210: 663552.0
# Computes for layer 211: 663552.0
# Computes for layer 212: 663552.0
# Computes for layer 213: 663552.0
# Computes for layer 214: 294912.0
# Computes for layer 215: 2654208.0
# Computes for layer 216: 2654208.0
# Computes for layer 217: 2654208.0
# Computes for layer 218: 2654208.0
# Computes for layer 219: 1179648.0
# Computes for layer 220: 10616832.0
# Computes for layer 221: 10616832.0
# Computes for layer 222: 10616832.0
# Computes for layer 223: 10616832.0
# Computes for layer 224: 4718592.0
# Computes for layer 225: 21233664.0
# Computes for layer 226: 10616832.0
# Computes for layer 227: 9216.0
#
# Overall energy for DNN dpt_large: 1000000000001102.6 fJ
#
# Running dpt_large with 128 x 128 RRAM with 32 nm in fast scenario
# Computes for layer 1: 884736.0
# Computes for layer 2: 1181696.0
# Computes for layer 3: 1181696.0
# Computes for layer 4: 1181696.0
# Computes for layer 5: 1154.0
# Computes for layer 6: 10404.03125
# Computes for layer 7: 1181696.0
# Computes for layer 8: 4726784.0
# Computes for layer 9: 4726784.0
# Computes for layer 10: 1181696.0
# Computes for layer 11: 1181696.0
# Computes for layer 12: 1181696.0
# Computes for layer 13: 1154.0
# Computes for layer 14: 10404.03125
# Computes for layer 15: 1181696.0
# Computes for layer 16: 4726784.0
# Computes for layer 17: 4726784.0
# Computes for layer 18: 1181696.0
# Computes for layer 19: 1181696.0
# Computes for layer 20: 1181696.0
# Computes for layer 21: 1154.0
# Computes for layer 22: 10404.03125
# Computes for layer 23: 1181696.0
# Computes for layer 24: 4726784.0
# Computes for layer 25: 4726784.0
# Computes for layer 26: 1181696.0
# Computes for layer 27: 1181696.0
# Computes for layer 28: 1181696.0
# Computes for layer 29: 1154.0
# Computes for layer 30: 10404.03125
# Computes for layer 31: 1181696.0
# Computes for layer 32: 4726784.0
# Computes for layer 33: 4726784.0
# Computes for layer 34: 1181696.0
# Computes for layer 35: 1181696.0
# Computes for layer 36: 1181696.0
# Computes for layer 37: 1154.0
# Computes for layer 38: 10404.03125
# Computes for layer 39: 1181696.0
# Computes for layer 40: 4726784.0
# Computes for layer 41: 4726784.0
# Computes for layer 42: 1181696.0
# Computes for layer 43: 1181696.0
# Computes for layer 44: 1181696.0
# Computes for layer 45: 1154.0
# Computes for layer 46: 10404.03125
# Computes for layer 47: 1181696.0
# Computes for layer 48: 4726784.0
# Computes for layer 49: 4726784.0
# Computes for layer 50: 1181696.0
# Computes for layer 51: 1181696.0
# Computes for layer 52: 1181696.0
# Computes for layer 53: 1154.0
# Computes for layer 54: 10404.03125
# Computes for layer 55: 1181696.0
# Computes for layer 56: 4726784.0
# Computes for layer 57: 4726784.0
# Computes for layer 58: 1181696.0
# Computes for layer 59: 1181696.0
# Computes for layer 60: 1181696.0
# Computes for layer 61: 1154.0
# Computes for layer 62: 10404.03125
# Computes for layer 63: 1181696.0
# Computes for layer 64: 4726784.0
# Computes for layer 65: 4726784.0
# Computes for layer 66: 1181696.0
# Computes for layer 67: 1181696.0
# Computes for layer 68: 1181696.0
# Computes for layer 69: 1154.0
# Computes for layer 70: 10404.03125
# Computes for layer 71: 1181696.0
# Computes for layer 72: 4726784.0
# Computes for layer 73: 4726784.0
# Computes for layer 74: 1181696.0
# Computes for layer 75: 1181696.0
# Computes for layer 76: 1181696.0
# Computes for layer 77: 1154.0
# Computes for layer 78: 10404.03125
# Computes for layer 79: 1181696.0
# Computes for layer 80: 4726784.0
# Computes for layer 81: 4726784.0
# Computes for layer 82: 1181696.0
# Computes for layer 83: 1181696.0
# Computes for layer 84: 1181696.0
# Computes for layer 85: 1154.0
# Computes for layer 86: 10404.03125
# Computes for layer 87: 1181696.0
# Computes for layer 88: 4726784.0
# Computes for layer 89: 4726784.0
# Computes for layer 90: 1181696.0
# Computes for layer 91: 1181696.0
# Computes for layer 92: 1181696.0
# Computes for layer 93: 1154.0
# Computes for layer 94: 10404.03125
# Computes for layer 95: 1181696.0
# Computes for layer 96: 4726784.0
# Computes for layer 97: 4726784.0
# Computes for layer 98: 1181696.0
# Computes for layer 99: 1181696.0
# Computes for layer 100: 1181696.0
# Computes for layer 101: 1154.0
# Computes for layer 102: 10404.03125
# Computes for layer 103: 1181696.0
# Computes for layer 104: 4726784.0
# Computes for layer 105: 4726784.0
# Computes for layer 106: 1181696.0
# Computes for layer 107: 1181696.0
# Computes for layer 108: 1181696.0
# Computes for layer 109: 1154.0
# Computes for layer 110: 10404.03125
# Computes for layer 111: 1181696.0
# Computes for layer 112: 4726784.0
# Computes for layer 113: 4726784.0
# Computes for layer 114: 1181696.0
# Computes for layer 115: 1181696.0
# Computes for layer 116: 1181696.0
# Computes for layer 117: 1154.0
# Computes for layer 118: 10404.03125
# Computes for layer 119: 1181696.0
# Computes for layer 120: 4726784.0
# Computes for layer 121: 4726784.0
# Computes for layer 122: 1181696.0
# Computes for layer 123: 1181696.0
# Computes for layer 124: 1181696.0
# Computes for layer 125: 1154.0
# Computes for layer 126: 10404.03125
# Computes for layer 127: 1181696.0
# Computes for layer 128: 4726784.0
# Computes for layer 129: 4726784.0
# Computes for layer 130: 1181696.0
# Computes for layer 131: 1181696.0
# Computes for layer 132: 1181696.0
# Computes for layer 133: 1154.0
# Computes for layer 134: 10404.03125
# Computes for layer 135: 1181696.0
# Computes for layer 136: 4726784.0
# Computes for layer 137: 4726784.0
# Computes for layer 138: 1181696.0
# Computes for layer 139: 1181696.0
# Computes for layer 140: 1181696.0
# Computes for layer 141: 1154.0
# Computes for layer 142: 10404.03125
# Computes for layer 143: 1181696.0
# Computes for layer 144: 4726784.0
# Computes for layer 145: 4726784.0
# Computes for layer 146: 1181696.0
# Computes for layer 147: 1181696.0
# Computes for layer 148: 1181696.0
# Computes for layer 149: 1154.0
# Computes for layer 150: 10404.03125
# Computes for layer 151: 1181696.0
# Computes for layer 152: 4726784.0
# Computes for layer 153: 4726784.0
# Computes for layer 154: 1181696.0
# Computes for layer 155: 1181696.0
# Computes for layer 156: 1181696.0
# Computes for layer 157: 1154.0
# Computes for layer 158: 10404.03125
# Computes for layer 159: 1181696.0
# Computes for layer 160: 4726784.0
# Computes for layer 161: 4726784.0
# Computes for layer 162: 1181696.0
# Computes for layer 163: 1181696.0
# Computes for layer 164: 1181696.0
# Computes for layer 165: 1154.0
# Computes for layer 166: 10404.03125
# Computes for layer 167: 1181696.0
# Computes for layer 168: 4726784.0
# Computes for layer 169: 4726784.0
# Computes for layer 170: 1181696.0
# Computes for layer 171: 1181696.0
# Computes for layer 172: 1181696.0
# Computes for layer 173: 1154.0
# Computes for layer 174: 10404.03125
# Computes for layer 175: 1181696.0
# Computes for layer 176: 4726784.0
# Computes for layer 177: 4726784.0
# Computes for layer 178: 1181696.0
# Computes for layer 179: 1181696.0
# Computes for layer 180: 1181696.0
# Computes for layer 181: 1154.0
# Computes for layer 182: 10404.03125
# Computes for layer 183: 1181696.0
# Computes for layer 184: 4726784.0
# Computes for layer 185: 4726784.0
# Computes for layer 186: 1181696.0
# Computes for layer 187: 1181696.0
# Computes for layer 188: 1181696.0
# Computes for layer 189: 1154.0
# Computes for layer 190: 10404.03125
# Computes for layer 191: 1181696.0
# Computes for layer 192: 4726784.0
# Computes for layer 193: 4726784.0
# Computes for layer 194: 2359296.0
# Computes for layer 195: 294912.0
# Computes for layer 196: 2359296.0
# Computes for layer 197: 589824.0
# Computes for layer 198: 2359296.0
# Computes for layer 199: 1179648.0
# Computes for layer 200: 2359296.0
# Computes for layer 201: 1179648.0
# Computes for layer 202: 2654208.0
# Computes for layer 203: 10616832.0
# Computes for layer 204: 5308416.0
# Computes for layer 205: 2654208.0
# Computes for layer 206: 663552.0
# Computes for layer 207: 165888.0
# Computes for layer 208: 165888.0
# Computes for layer 209: 73728.0
# Computes for layer 210: 663552.0
# Computes for layer 211: 663552.0
# Computes for layer 212: 663552.0
# Computes for layer 213: 663552.0
# Computes for layer 214: 294912.0
# Computes for layer 215: 2654208.0
# Computes for layer 216: 2654208.0
# Computes for layer 217: 2654208.0
# Computes for layer 218: 2654208.0
# Computes for layer 219: 1179648.0
# Computes for layer 220: 10616832.0
# Computes for layer 221: 10616832.0
# Computes for layer 222: 10616832.0
# Computes for layer 223: 10616832.0
# Computes for layer 224: 4718592.0
# Computes for layer 225: 21233664.0
# Computes for layer 226: 10616832.0
# Computes for layer 227: 9216.0
#
# Overall energy for DNN dpt_large: 1000000000000979.4 fJ

# %%
display_markdown(
    """
### Calculating Area in fast scenario

"""
)
total_area = [0] * 2
total_adc_area = [0] * 2
total_col_area = [0] * 2
total_row_area = [0] * 2
total_cim_unit_area = [0] * 2
total_macro = [0] * 2
energy = [0] * 2
throughput = [0] * 2
total_area[0], total_adc_area[0], total_col_area[0], total_row_area[0], total_cim_unit_area[0], total_macro[0], energy[0], throughput[0] = extract_outputs("SRAM_dpt_large_128_fast")
total_area[1], total_adc_area[1], total_col_area[1], total_row_area[1], total_cim_unit_area[1], total_macro[1], energy[1], throughput[1] = extract_outputs("RRAM_dpt_large_128_fast")
# Out:
# ### Calculating Area in fast scenario
# ../outputs/SRAM_dpt_large_128_fast/
# Model 	 Energy/inference (J) 	 Area (mm2) 	 Throughput (inf/s)
# Processing layer: SRAM_dpt_large_128_fast_layer_1
# Size: 2
# Size: 16
# Size: 3
# All macro: 96
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 2737449.5999999996
#
# Size: 2
# Size: 16
# Size: 3
# All macro: 96
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 101246.40000000001
#
# Size: 2
# Size: 16
# Size: 3
# All macro: 96
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 89135.616
#
# Size: 2
# Size: 16
# Size: 3
# All macro: 96
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 515396.0755200001
#
# Total Area for layer 1: 3443227.6915199994
#
# Total Macro for layer 1: 96
#
# Total Area for all layers: 3443227.6915199994
# Total Area for ADC across all layers: 2737449.5999999996
# Processing layer: SRAM_dpt_large_128_fast_layer_2
# Size: 16
# Size: 8
# All macro: 128
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 3649932.8
#
# Size: 16
# Size: 8
# All macro: 128
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 134995.2
#
# Size: 16
# Size: 8
# All macro: 128
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 118847.488
#
# Size: 16
# Size: 8
# All macro: 128
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 687194.76736
#
# Total Area for layer 2: 4590970.25536
#
# Total Macro for layer 2: 224
#
# Total Area for all layers: 8034197.94688
# Total Area for ADC across all layers: 6387382.399999999
# Processing layer: SRAM_dpt_large_128_fast_layer_3
# Size: 16
# Size: 8
# All macro: 128
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 3649932.8
#
# Size: 16
# Size: 8
# All macro: 128
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 134995.2
#
# Size: 16
# Size: 8
# All macro: 128
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 118847.488
#
# Size: 16
# Size: 8
# All macro: 128
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 687194.76736
#
# Total Area for layer 3: 4590970.25536
#
# Total Macro for layer 3: 352
#
# Total Area for all layers: 12625168.20224
# Total Area for ADC across all layers: 10037315.2
# Processing layer: SRAM_dpt_large_128_fast_layer_4
# Size: 16
# Size: 8
# All macro: 128
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 3649932.8
#
# Size: 16
# Size: 8
# All macro: 128
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 134995.2
#
# Size: 16
# Size: 8
# All macro: 128
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 118847.488
#
# Size: 16
# Size: 8
# All macro: 128
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 687194.76736
#
# Total Area for layer 4: 4590970.25536
#
# Total Macro for layer 4: 480
#
# Total Area for all layers: 17216138.457599998
# Total Area for ADC across all layers: 13687248.0
# Processing layer: SRAM_dpt_large_128_fast_layer_5
# Size: 5
# All macro: 5
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 142575.5
#
# Size: 5
# All macro: 5
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 5273.25
#
# Size: 5
# All macro: 5
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 4642.48
#
# Size: 5
# All macro: 5
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 26843.5456
#
# Total Area for layer 5: 179334.77560000002
#
# Total Macro for layer 5: 485
#
# Total Area for all layers: 17395473.2332
# Total Area for ADC across all layers: 13829823.5
# Processing layer: SRAM_dpt_large_128_fast_layer_6
# Size: 10
# Size: 5
# All macro: 50
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 1425755.0
#
# Size: 10
# Size: 5
# All macro: 50
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 52732.50000000001
#
# Size: 10
# Size: 5
# All macro: 50
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 46424.799999999996
#
# Size: 10
# Size: 5
# All macro: 50
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 268435.456
#
# Total Area for layer 6: 1793347.756
#
# Total Macro for layer 6: 535
#
# Total Area for all layers: 19188820.9892
# Total Area for ADC across all layers: 15255578.5
# Processing layer: SRAM_dpt_large_128_fast_layer_7
# Size: 16
# Size: 8
# All macro: 128
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 3649932.8
#
# Size: 16
# Size: 8
# All macro: 128
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 134995.2
#
# Size: 16
# Size: 8
# All macro: 128
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 118847.488
#
# Size: 16
# Size: 8
# All macro: 128
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 687194.76736
#
# Total Area for layer 7: 4590970.25536
#
# Total Macro for layer 7: 663
#
# Total Area for all layers: 23779791.24456
# Total Area for ADC across all layers: 18905511.3
# Processing layer: SRAM_dpt_large_128_fast_layer_8
# Size: 64
# Size: 8
# All macro: 512
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 14599731.2
#
# Size: 64
# Size: 8
# All macro: 512
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 539980.8
#
# Size: 64
# Size: 8
# All macro: 512
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 475389.952
#
# Size: 64
# Size: 8
# All macro: 512
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 2748779.06944
#
# Total Area for layer 8: 18363881.02144
#
# Total Macro for layer 8: 1175
#
# Total Area for all layers: 42143672.266
# Total Area for ADC across all layers: 33505242.5
# Processing layer: SRAM_dpt_large_128_fast_layer_9
# Size: 16
# Size: 32
# All macro: 512
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 14599731.2
#
# Size: 16
# Size: 32
# All macro: 512
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 539980.8
#
# Size: 16
# Size: 32
# All macro: 512
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 475389.952
#
# Size: 16
# Size: 32
# All macro: 512
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 2748779.06944
#
# Total Area for layer 9: 18363881.02144
#
# Total Macro for layer 9: 1687
#
# Total Area for all layers: 60507553.28744
# Total Area for ADC across all layers: 48104973.7
# Processing layer: SRAM_dpt_large_128_fast_layer_10
# Size: 16
# Size: 8
# All macro: 128
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 3649932.8
#
# Size: 16
# Size: 8
# All macro: 128
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 134995.2
#
# Size: 16
# Size: 8
# All macro: 128
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 118847.488
#
# Size: 16
# Size: 8
# All macro: 128
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 687194.76736
#
# Total Area for layer 10: 4590970.25536
#
# Total Macro for layer 10: 1815
#
# Total Area for all layers: 65098523.5428
# Total Area for ADC across all layers: 51754906.5
# Processing layer: SRAM_dpt_large_128_fast_layer_11
# Size: 16
# Size: 8
# All macro: 128
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 3649932.8
#
# Size: 16
# Size: 8
# All macro: 128
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 134995.2
#
# Size: 16
# Size: 8
# All macro: 128
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 118847.488
#
# Size: 16
# Size: 8
# All macro: 128
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 687194.76736
#
# Total Area for layer 11: 4590970.25536
#
# Total Macro for layer 11: 1943
#
# Total Area for all layers: 69689493.79816
# Total Area for ADC across all layers: 55404839.3
# Processing layer: SRAM_dpt_large_128_fast_layer_12
# Size: 16
# Size: 8
# All macro: 128
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 3649932.8
#
# Size: 16
# Size: 8
# All macro: 128
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 134995.2
#
# Size: 16
# Size: 8
# All macro: 128
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 118847.488
#
# Size: 16
# Size: 8
# All macro: 128
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 687194.76736
#
# Total Area for layer 12: 4590970.25536
#
# Total Macro for layer 12: 2071
#
# Total Area for all layers: 74280464.05352
# Total Area for ADC across all layers: 59054772.099999994
# Processing layer: SRAM_dpt_large_128_fast_layer_13
# Size: 5
# All macro: 5
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 142575.5
#
# Size: 5
# All macro: 5
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 5273.25
#
# Size: 5
# All macro: 5
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 4642.48
#
# Size: 5
# All macro: 5
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 26843.5456
#
# Total Area for layer 13: 179334.77560000002
#
# Total Macro for layer 13: 2076
#
# Total Area for all layers: 74459798.82912
# Total Area for ADC across all layers: 59197347.599999994
# Processing layer: SRAM_dpt_large_128_fast_layer_14
# Size: 10
# Size: 5
# All macro: 50
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 1425755.0
#
# Size: 10
# Size: 5
# All macro: 50
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 52732.50000000001
#
# Size: 10
# Size: 5
# All macro: 50
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 46424.799999999996
#
# Size: 10
# Size: 5
# All macro: 50
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 268435.456
#
# Total Area for layer 14: 1793347.756
#
# Total Macro for layer 14: 2126
#
# Total Area for all layers: 76253146.58511999
# Total Area for ADC across all layers: 60623102.599999994
# Processing layer: SRAM_dpt_large_128_fast_layer_15
# Size: 16
# Size: 8
# All macro: 128
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 3649932.8
#
# Size: 16
# Size: 8
# All macro: 128
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 134995.2
#
# Size: 16
# Size: 8
# All macro: 128
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 118847.488
#
# Size: 16
# Size: 8
# All macro: 128
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 687194.76736
#
# Total Area for layer 15: 4590970.25536
#
# Total Macro for layer 15: 2254
#
# Total Area for all layers: 80844116.84048
# Total Area for ADC across all layers: 64273035.39999999
# Processing layer: SRAM_dpt_large_128_fast_layer_16
# Size: 64
# Size: 8
# All macro: 512
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 14599731.2
#
# Size: 64
# Size: 8
# All macro: 512
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 539980.8
#
# Size: 64
# Size: 8
# All macro: 512
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 475389.952
#
# Size: 64
# Size: 8
# All macro: 512
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 2748779.06944
#
# Total Area for layer 16: 18363881.02144
#
# Total Macro for layer 16: 2766
#
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_17
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_18
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_19
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_20
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_21
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_22
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_23
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_24
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_25
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_26
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_27
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_28
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_29
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_30
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_31
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_32
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_33
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_34
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_35
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_36
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_37
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_38
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_39
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_40
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_41
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_42
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_43
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_44
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_45
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_46
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_47
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_48
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_49
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_50
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_51
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_52
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_53
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_54
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_55
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_56
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_57
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_58
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_59
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_60
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_61
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_62
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_63
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_64
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_65
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_66
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_67
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_68
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_69
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_70
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_71
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_72
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_73
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_74
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_75
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_76
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_77
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_78
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_79
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_80
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_81
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_82
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_83
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_84
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_85
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_86
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_87
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_88
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_89
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_90
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_91
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_92
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_93
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_94
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_95
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_96
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_97
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_98
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_99
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_100
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_101
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_102
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_103
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_104
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_105
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_106
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_107
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_108
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_109
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_110
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_111
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_112
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_113
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_114
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_115
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_116
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_117
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_118
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_119
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_120
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_121
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_122
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_123
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_124
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_125
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_126
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_127
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_128
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_129
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_130
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_131
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_132
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_133
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_134
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_135
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_136
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_137
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_138
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_139
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_140
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_141
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_142
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_143
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_144
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_145
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_146
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_147
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_148
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_149
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_150
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_151
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_152
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_153
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_154
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_155
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_156
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_157
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_158
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_159
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_160
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_161
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_162
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_163
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_164
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_165
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_166
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_167
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_168
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_169
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_170
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_171
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_172
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_173
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_174
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_175
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_176
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_177
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_178
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_179
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_180
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_181
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_182
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_183
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_184
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_185
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_186
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_187
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_188
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_189
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_190
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_191
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_192
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_193
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_194
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_195
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_196
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_197
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_198
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_199
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_200
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_201
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_202
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_203
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_204
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_205
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_206
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_207
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_208
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_209
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_210
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_211
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_212
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_213
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_214
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_215
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_216
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_217
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_218
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_219
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_220
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_221
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_222
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_223
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_224
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_225
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_226
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_fast_layer_227
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Total Area for column drivers across all layers: 2917161.9000000004
# Total Area for row drivers across all layers: 2568219.9359999998
# Total Area for cim unit across all layers: 14849849.42592
#
#
# Total Area for ADC across all layers: 78.87276659999999
# Total Area for column driver across all layers: 2.9171619000000004
# Total Area for row driver across all layers: 2.5682199359999998
# Total Area for cim unit across all layers: 14.84984942592
# Total Macro across all layers: 2766
# SRAM_dpt_large_128_fast 	 6.95e-03 	 99.21 	 1.88e+01
# ../outputs/RRAM_dpt_large_128_fast/
# Model 	 Energy/inference (J) 	 Area (mm2) 	 Throughput (inf/s)
# Processing layer: RRAM_dpt_large_128_fast_layer_1
# Size: 2
# Size: 16
# Size: 3
# All macro: 96
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 2856556.8
#
# Size: 2
# Size: 16
# Size: 3
# All macro: 96
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 42337.248
#
# Size: 2
# Size: 16
# Size: 3
# All macro: 96
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 48385.44
#
# Size: 2
# Size: 16
# Size: 3
# All macro: 96
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 64424.50944000001
#
# Total Area for layer 1: 3011703.99744
#
# Total Macro for layer 1: 96
#
# Total Area for all layers: 3011703.99744
# Total Area for ADC across all layers: 2856556.8
# Processing layer: RRAM_dpt_large_128_fast_layer_2
# Size: 16
# Size: 8
# All macro: 128
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 3808742.4
#
# Size: 16
# Size: 8
# All macro: 128
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 56449.664
#
# Size: 16
# Size: 8
# All macro: 128
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 64513.92
#
# Size: 16
# Size: 8
# All macro: 128
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 85899.34592
#
# Total Area for layer 2: 4015605.32992
#
# Total Macro for layer 2: 224
#
# Total Area for all layers: 7027309.32736
# Total Area for ADC across all layers: 6665299.199999999
# Processing layer: RRAM_dpt_large_128_fast_layer_3
# Size: 16
# Size: 8
# All macro: 128
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 3808742.4
#
# Size: 16
# Size: 8
# All macro: 128
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 56449.664
#
# Size: 16
# Size: 8
# All macro: 128
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 64513.92
#
# Size: 16
# Size: 8
# All macro: 128
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 85899.34592
#
# Total Area for layer 3: 4015605.32992
#
# Total Macro for layer 3: 352
#
# Total Area for all layers: 11042914.65728
# Total Area for ADC across all layers: 10474041.6
# Processing layer: RRAM_dpt_large_128_fast_layer_4
# Size: 16
# Size: 8
# All macro: 128
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 3808742.4
#
# Size: 16
# Size: 8
# All macro: 128
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 56449.664
#
# Size: 16
# Size: 8
# All macro: 128
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 64513.92
#
# Size: 16
# Size: 8
# All macro: 128
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 85899.34592
#
# Total Area for layer 4: 4015605.32992
#
# Total Macro for layer 4: 480
#
# Total Area for all layers: 15058519.9872
# Total Area for ADC across all layers: 14282784.0
# Processing layer: RRAM_dpt_large_128_fast_layer_5
# Size: 5
# All macro: 5
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 148779.0
#
# Size: 5
# All macro: 5
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 2205.065
#
# Size: 5
# All macro: 5
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 2520.075
#
# Size: 5
# All macro: 5
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 3355.4432
#
# Total Area for layer 5: 156859.58320000002
#
# Total Macro for layer 5: 485
#
# Total Area for all layers: 15215379.5704
# Total Area for ADC across all layers: 14431563.0
# ...
# Processing layer: RRAM_dpt_large_128_fast_layer_122
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_123
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_124
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_125
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_126
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_127
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_128
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_129
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_130
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_131
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_132
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_133
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_134
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_135
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_136
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_137
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_138
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_139
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_140
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_141
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_142
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_143
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_144
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_145
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_146
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_147
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_148
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_149
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_150
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_151
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_152
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_153
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_154
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_155
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_156
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_157
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_158
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_159
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_160
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_161
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_162
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_163
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_164
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_165
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_166
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_167
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_168
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_169
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_170
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_171
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_172
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_173
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_174
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_175
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_176
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_177
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_178
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_179
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_180
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_181
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_182
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_183
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_184
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_185
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_186
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_187
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_188
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_189
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_190
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_191
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_192
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_193
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_194
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_195
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_196
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_197
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_198
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_199
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_200
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_201
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_202
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_203
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_204
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_205
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_206
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_207
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_208
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_209
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_210
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_211
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_212
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_213
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_214
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_215
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_216
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_217
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_218
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_219
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_220
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_221
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_222
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_223
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_224
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_225
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_226
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Processing layer: RRAM_dpt_large_128_fast_layer_227
# Total Area for all layers: 86774721.42624001
# Total Area for ADC across all layers: 82304542.8
# Total Area for column drivers across all layers: 1219841.9579999999
# Total Area for row drivers across all layers: 1394105.49
# Total Area for cim unit across all layers: 1856231.17824
#
#
# Total Area for ADC across all layers: 82.3045428
# Total Area for column driver across all layers: 1.2198419579999997
# Total Area for row driver across all layers: 1.3941054899999998
# Total Area for cim unit across all layers: 1.85623117824
# Total Macro across all layers: 2766
# RRAM_dpt_large_128_fast 	 8.38e-03 	 86.77 	 1.88e+01

# %%
print(total_area)
print(total_adc_area)
print(total_col_area)
print(total_row_area)
print(total_cim_unit_area)
print(total_macro)
print(energy)
print(throughput)
# Out:
# [99.20799786191999, 86.77472142624]
# [78.87276659999999, 82.3045428]
# [2.9171619000000004, 1.2198419579999997]
# [2.5682199359999998, 1.3941054899999998]
# [14.84984942592, 1.85623117824]
# [2766, 2766]
# [0.006946794100000004, 0.008378306799999994]
# [18.838351870271573, 18.838351870271573]

# %%
import matplotlib.pyplot as plt
import numpy as np
fig, ax = plt.subplots(figsize=(10, 5)) 
# array_sizes = ['32', '64', '128', '256']
path = ['SRAM', 'RRAM']

x = np.arange(len(path))

# Stack bars
ax.bar(path, total_cim_unit_area, label='cim_unit')
ax.bar(path, total_row_area, bottom=total_cim_unit_area, label='row_drivers')
ax.bar(path, total_col_area, bottom=np.array(total_cim_unit_area) + np.array(total_row_area), label='column_drivers')
ax.bar(path, total_adc_area, bottom=np.array(total_cim_unit_area) + np.array(total_row_area) + np.array(total_col_area), label='adc')

# Labels and title
ax.set_title("Area vs Memory Type for alexnet in fast scenario")
ax.set_xlabel("Memory type")
ax.set_ylabel("Area (mm2)")
# Set x-ticks
ax.set_xticks(x)
ax.set_xticklabels(path)

ax.legend()

# Show plot
plt.show()

# %%
for path in path_list:
    print(f"Memory Type: {path.split('/')[-1].split('_')[0].upper()}")
    # For each component index (0 to 3)
    for i in range(4):
        print(f"total_per_energy[{path.split('/')[-1].split('_')[0].upper()}][{i}]: {total_per_energy[path][i]}")
    print()
# Out:
# Memory Type: SRAM
# total_per_energy[SRAM][0]: 0.4847776383417458
# total_per_energy[SRAM][1]: 0.00293960908356164
# total_per_energy[SRAM][2]: 0.5105636829351832
# total_per_energy[SRAM][3]: 0.0017190696395093037
#
# Memory Type: RRAM
# total_per_energy[RRAM][0]: 0.45968882602467864
# total_per_energy[RRAM][1]: 1.1555869872788764e-12
# total_per_energy[RRAM][2]: 0.3635077793494324
# total_per_energy[RRAM][3]: 0.17680339462473338

# %%
display_markdown(
    """
### Calculating the energy

"""
)

path_list = [SRAM_PATH, RRAM_PATH]
total_adc_energy = [0] * 2
total_col_energy = [0] * 2
total_row_energy = [0] * 2
total_cim_unit_energy = [0] * 2
for j in range(len(energy)):
    if j == 0:
        for i in range(4):
            if i == 0:
                total_adc_energy[j] = total_per_energy[path_list[0]][i] * energy[j]
            elif i == 1:
                total_col_energy[j] = total_per_energy[path_list[0]][i] * energy[j]
            elif i == 2:
                total_row_energy[j] = total_per_energy[path_list[0]][i] * energy[j]
            else:
                total_cim_unit_energy[j] = total_per_energy[path_list[0]][i] * energy[j]
    else:
        for i in range(4):
            if i == 0:
                total_adc_energy[j] = total_per_energy[path_list[1]][i] * energy[j]
            elif i == 1:
                total_col_energy[j] = total_per_energy[path_list[1]][i] * energy[j]
            elif i == 2:
                total_row_energy[j] = total_per_energy[path_list[1]][i] * energy[j]
            else:
                total_cim_unit_energy[j] = total_per_energy[path_list[1]][i] * energy[j]

    
print("Total ADC Energy:", total_adc_energy)
print("Total Column Energy:", total_col_energy)
print("Total Row Energy:", total_row_energy)
print("Total CIM Unit Energy:", total_cim_unit_energy)
# Out:
# ### Calculating the energy
# Total ADC Energy: [0.0033676504378443756, 0.0038514140169665792]
# Total Column Energy: [2.042085903799242e-05, 9.681862313510116e-15]
# Total Row Energy: [0.003546780780288403, 0.003045579699576247]
# Total CIM Unit Energy: [1.1942022829232366e-05, 0.001481313083447486]

# %%
import matplotlib.pyplot as plt
import numpy as np
fig, ax = plt.subplots(figsize=(10, 5)) 
path = ['SRAM', 'RRAM']

# x = np.arange(len(array_sizes))

# Stack bars
ax.bar(path, total_cim_unit_energy, label='cim_unit')
ax.bar(path, total_row_energy, bottom=total_cim_unit_energy, label='row_drivers')
ax.bar(path, total_col_energy, bottom=np.array(total_cim_unit_energy) + np.array(total_row_energy), label='column_drivers')
ax.bar(path, total_adc_energy, bottom=np.array(total_cim_unit_energy) + np.array(total_row_energy) + np.array(total_col_energy), label='adc')

# Labels and title
ax.set_title("Energy vs Memory Type for alexnet in fast scenario")
ax.set_xlabel("Memory type")
ax.set_ylabel("Energy (J)")
# Set x-ticks
ax.set_xticks(x)
ax.set_xticklabels(path)

ax.legend()

# Show plot
plt.show()

# %%
display_markdown(
    """
### Plot the Throughput

"""
)
import matplotlib.pyplot as plt

# Data
path = ['SRAM', 'RRAM']
x = np.arange(len(path))
# Plotting the line graph
plt.figure(figsize=(10, 6))
plt.plot(path, throughput, marker='o', linestyle='-', color='b')

# Adding labels and title
plt.xlabel('Memory type')
plt.ylabel('Throughput')
plt.title('Throughput vs Memory Type for alexnet')
plt.grid(False)
plt.xticks(x, path) 
# Show plot
plt.show()
# Out:
# ### Plot the Throughput

# %%
display_markdown(
    """
### Plot the Number of Macros

"""
)
import matplotlib.pyplot as plt

# Data
path = ['SRAM', 'RRAM']
x = np.arange(len(path))
# Plotting the line graph
plt.figure(figsize=(10, 6))
plt.plot(path, total_macro, marker='o', linestyle='-', color='b')

# Adding labels and title
plt.xlabel('Memory type')
plt.ylabel('Number of Macros')
plt.title('Number of Macros vs Memory Type for alexnet')
plt.grid(False)
plt.xticks(x, path) 
# Show plot
plt.show()
# Out:
# ### Plot the Number of Macros
