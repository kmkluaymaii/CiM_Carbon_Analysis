# %%
from _import_scripts import scripts
from scripts.notebook_utils import *
from scripts.tl_output_parsing import MacroOutputStats
from scripts.utils import *
import yaml

MACRO_PATH = "../models/arch/1_macro/basic_analog/" 
macro = {}
total_per_energy = {}
SRAM_PATH = f'"{os.path.abspath("../models/memory_cells/sram_example.cell.yaml")}"'
RRAM_PATH = f'"{os.path.abspath("../models/memory_cells/rram_example.cell.yaml")}"'

dnn_layers = {
    "alexnet": 8,
    "vgg16": 16,
    "dpt_large": 227,
    "gpt2_medium": 145,
    "mobilebert": 409,
    "vision_transformer": 98,
    "resnet18": 21,
    "mobilenet_v3": 64
}

# Define the architecture
array_sizes = 128
path_list = [SRAM_PATH, RRAM_PATH]
tech_node = 32
time = "fast"

dnn_list = ["dpt_large", "gpt2_medium"]
for DNN in dnn_list:
    dnn_layer = dnn_layers.get(DNN, None)
    def create_layer_directory(base_output_dir: str, architecture: str, layer: int) -> str:
        layer_dir = os.path.join(base_output_dir, f"{architecture}_layer_{layer}")
        if not os.path.exists(layer_dir):
            os.makedirs(layer_dir)
        return layer_dir

    num_layers = 1

    def run_map(
        spec: tl.Specification,
        arch: str,
        accelergy_verbose: bool = False,
    ) -> dict:
        output_dir = get_run_dir()
        # Just use the directory name if it causes error
        base_output_dir = os.path.dirname(output_dir)
        base_output_dir = os.path.join(base_output_dir, arch)
        global num_layers

        mapper_result = None

        if num_layers < dnn_layer+1:
            # Create a directory for the current layer
            layer_dir = create_layer_directory(base_output_dir, arch, num_layers)
            # print(f"Layer directory: {layer_dir}")
            num_layers += 1

            run_prefix = f"{layer_dir}/timeloop-mapper"
            mapper_result = tl.call_mapper(
                specification=spec,
                output_dir=layer_dir,
                log_to=os.path.join(output_dir, f"{run_prefix}.log"),
            )
            if accelergy_verbose:
                tl.call_accelergy_verbose(
                    specification=spec,
                    output_dir=layer_dir,
                    log_to=os.path.join(output_dir, "accelergy.log"),
                )

        if mapper_result is None:
            # Handle case when mapper_result is not assigned (num_layers >= 17)
            # Raise an error, return a default value
            print("Warning: mapper_result is not assigned. num_layers >= 17")
            return {}

        return MacroOutputStats.from_output_stats(mapper_result)

    import re

    def extract_range(line):
        match = re.search(r'\[(\d+):(\d+)(,\d+)?\)', line)
        if match:
            start = int(match.group(1))
            end = int(match.group(2))
            return end - start
        return None

    def read_and_compute_multiplication(filename, i):
        filename = f"../outputs/{filename}/{filename}_layer_{i+1}/timeloop-mapper.map.txt"
        with open(filename, 'r') as file:
            lines = file.readlines()

        start_searching = False
        ranges = []

        for line in lines:
            # Start searching when 'inter_macro_in_system_spatial' is found
            if "inter_macro_in_system_spatial" in line:
                start_searching = True
            
            # Stop searching if we leave the 'inter_macro_in_system_spatial' section
            elif start_searching and "inter_" in line and "inter_macro_in_system_spatial" not in line:
                break

            # If we are in the 'inter_macro_in_system_spatial' section, look for the ranges
            if start_searching:
                if "for" in line:
                    range_size = extract_range(line)
                    if range_size is not None:
                        ranges.append(range_size)
                elif line.strip() == "":  # Exit the section on an empty line
                    break

        # Compute the multiplication of all ranges, or return 1 if no ranges were found
        if not ranges:
            print(f"All macro: 1")
            return 1

        result = 1
        for size in ranges:
            result *= size
            print(f"Size: {size}")
        print(f"All macro: {result}")
        return result


    def extract_layer_number(folder_name):
        match = re.search(r'layer_(\d+)', folder_name)
        return int(match.group(1)) if match else float('inf')

    def extract_outputs(model):
        
        output_dir = "../outputs/" + model + "/" 
        print(output_dir)

        print ("Model \t Energy/inference (J) \t Area (mm2) \t Throughput (inf/s)")
        #for model in models:    
        throughput = 0   
        energy = 0
        area = 0
        cycles = 0
        folders = sorted([folder for folder in os.listdir(output_dir) if model in folder], key=extract_layer_number)
        area_per_many_macro = 0
        area_layer = 0
        j = 0
        total_sum = 0
        total_adc_area = 0  # Total area for ADC across all layers
        total_other_areas = {}  # Dictionary to store total areas for other components
        total_col_area = 0
        total_row_area = 0
        total_cim_unit_area = 0
        total_area = 0
        total_macro = 0
        
        for folder in folders:
            total = 0
            if model in folder:
                print(f"Processing layer: {folder}")
                # print(folder)
                if os.path.isdir(output_dir + folder):
                    stat_file = output_dir + folder + "/timeloop-mapper.stats.txt"
                    art_file = output_dir + folder + "/timeloop-mapper.ART.yaml"
            
                    with open(stat_file, 'r') as f:
                        energy_stat = [line for line in f if line.startswith("Energy:")][0]
                        energy_uj = energy_stat.split(' ')[1] # uJ
                        energy += float(energy_uj)
                        # print(f"Energy for this layer: {float(energy_uj)} uj")
                    
                    with open(stat_file, 'r') as f:
                        cycle_stat = [line for line in f if line.startswith("Cycles:")][0]                  
                        cycle = cycle_stat.split(' ')[1] 
                        cycles += float(cycle)
                        print(f"Cycle: {cycle}")
                    print(f"Total Cycle: {cycles}")
                        
                if j < dnn_layer:
                    with open(art_file, 'r') as file:
                        data = yaml.safe_load(file)
                    
                        # Extract and print the name, area, number of entries, and ratio for non-zero areas
                    for table in data['ART']['tables']:
                        name = table.get('name')
                        area = table.get('area')
                        if area != 0:
                            # Simplify the name for the output
                            if 'system_top_level.' in name:
                                name = name.split('system_top_level.')[-1]
                            
                            # Extract the number of entries from the name
                            if '[' in name:
                                name_part, entries_part = name.split('[')
                                number_of_entries = entries_part.split('..')[1].replace(']', '')
                                name = name_part.strip()
                            else:
                                number_of_entries = 'Unknown'
                            
                            macro = read_and_compute_multiplication(model, j)
                            # Calculate total ratio
                            if number_of_entries != 'Unknown' and number_of_entries.isdigit():
                                total_ratio = (area / 4096) * macro * int(number_of_entries)
                            else:
                                total_ratio = 0
                            
                            total += total_ratio
                            
                            # Accumulate area for ADC or other components
                            if 'adc' in name.lower():
                                total_adc_area += total_ratio
                            else:
                                if name not in total_other_areas:
                                    total_other_areas[name] = 0
                                total_other_areas[name] += total_ratio
                
                            print(f"{name.replace('_', ' ')} area: {area}, number of {name}: {number_of_entries}, \ntotal {name.replace('_', ' ')} area: ({area}*{number_of_entries}/4096) * macro = {total_ratio}\n")
                    j += 1 
                    total_sum += total
                    total_macro += macro
                    print(f"Total Area for layer {j}: {total}\n")
                    print(f"Total Macro for layer {j}: {total_macro}\n")
                print(f"Total Area for all layers: {total_sum}")
                print(f"Total Area for ADC across all layers: {total_adc_area}")
        
        # Print total area for other components
        for component, area in total_other_areas.items():
            print(f"Total Area for {component.replace('_', ' ')} across all layers: {area}")
            # print(component.replace('_', ' '))
            if component.replace('_', ' ') ==  "column drivers":
                total_col_area = area
            elif component.replace('_', ' ') ==  "row drivers":
                total_row_area = area
            else:
                total_cim_unit_area = area
                                    
        energy *= 1e-6 # conver to J
        total_area = total_sum * 1e-6 # mm2
        throughput = 1 / (cycles * 1e-7) # s
       
        total_adc_area = total_adc_area * 1e-6 # mm2
        total_col_area = total_col_area * 1e-6 # mm2
        total_row_area = total_row_area * 1e-6 # mm2
        total_cim_unit_area = total_cim_unit_area * 1e-6 # mm2
        print("\n")
        print(f"Total Area for ADC across all layers: {total_adc_area}")
        print(f"Total Area for column driver across all layers: {total_col_area}")
        print(f"Total Area for row driver across all layers: {total_row_area}")
        print(f"Total Area for cim unit across all layers: {total_cim_unit_area}")
        print(f"Total Macro across all layers: {total_macro}")
        print ("{} \t {:.2e} \t {:.2f} \t {:.2e}".format(model, energy, total_area, throughput))
        
        return total_area, total_adc_area, total_col_area, total_row_area, total_cim_unit_area, total_macro, energy, throughput

    
##----------------------------------------- Running DNN -------------------------------------------

    for path in path_list:
        arch = f"{path.split('/')[-1].split('_')[0].upper()}_{DNN}_{array_sizes}"
        print(f"\nRunning {DNN} with {array_sizes} x {array_sizes} {path.split('/')[-1].split('_')[0].upper()} with {tech_node} nm in {time} scenario")

        num_layers = 1

        def run_dnn(dnn: str, layer: str, array_sizes: int, variables):
            print(f"{layer} ", end="", flush=True)
            spec = get_spec(
                "basic_analog",
                # Weight-stationary, dummy buffer on top to hold inputs & outputs, many
                # macros to ensure we can fit all weights.
                system="ws_dummy_buffer_many_macro",
                # Set the DNN and layer
                dnn=dnn,
                layer=layer,
            )
        
            # Do NOT generate a maximum-utilization workload; we're running a DNN
            # workload.
            spec.variables["MAX_UTILIZATION"] = False
        
            # Use a larger array to ensure we can fit all weights
            spec.architecture.find("column").spatial.meshX = array_sizes
            spec.architecture.find("row").spatial.meshY = array_sizes
        
            spec.variables.update(variables)
            output_stats = run_map(spec, arch)
            
            # Print computes for the layer
            macro_output_stats = MacroOutputStats.from_output_stats(output_stats)
            print(f"Computes for layer {int(layer) + 1}: {macro_output_stats.computes}")
            global macro
            macro[layer] = macro_output_stats.computes
            return output_stats
        
        layers = [f for f in os.listdir(f"../models/workloads/{DNN}") if f != "index.yaml" and f.endswith(".yaml")]
        layers = sorted(layers)
        print(f"Running: ", end="")
        
        # Parallel/Delayed is used to multiprocess. Equivalent to running the following
        # code in serial:
        results = joblib.Parallel(n_jobs=None)(
            joblib.delayed(run_dnn)(DNN, layer.split(".")[0], array_sizes, 
                                    {
                                        "CELL_CONFIG": path,
                                        "BITS_PER_CELL": 1 if path == SRAM_PATH else 4,
                                        "CIM_UNIT_WIDTH_CELLS": 4 if path == SRAM_PATH else 1,
                                        "IS_SRAM": path == SRAM_PATH,
                                        "TECHNOLOGY": tech_node,
                                        "ADC_RESOLUTION": 4 if path == SRAM_PATH else 6,
                                        "GLOBAL_CYCLE_SECONDS": 1e-7 if time == "fast" else 1e-4,
                                    }
                                    ) for layer in layers
        )
        print("")
        for r in results:
            r.clear_zero_energies()
        
        #Initialize overall_energy
        energy_layer = [0] * 16
        result = 0
        
        total_adc_energy = 0.0
        total_col_energy = 0.0
        total_row_energy = 0.0
        total_cim_unit_energy = 0.0
        # Calculate overall energy
        for r in results:
        
            per_component_energy = r.per_compute("per_component_energy")
            total_energy_per_layer = sum(per_component_energy.values()) * 1e15  # Convert to fJ
            total_adc_energy += per_component_energy.get('adc', 0.0)
            total_col_energy += per_component_energy.get('column_drivers', 0.0)
            total_row_energy += per_component_energy.get('row_drivers', 0.0)
            total_cim_unit_energy += per_component_energy.get('cim_unit', 0.0)
        
            total_adc_energy = total_adc_energy * 1e15
            total_col_energy = total_col_energy * 1e15
            total_row_energy = total_row_energy * 1e15
            total_cim_unit_energy = total_cim_unit_energy * 1e15
            total_energy = total_adc_energy + total_col_energy + total_row_energy + total_cim_unit_energy
        
            total_adc_energy = total_adc_energy/total_energy
            total_col_energy = total_col_energy/total_energy
            total_row_energy = total_row_energy/total_energy
            total_cim_unit_energy = total_cim_unit_energy/total_energy

            total_per_energy[(DNN, path)] = [total_adc_energy, total_col_energy, total_row_energy, total_cim_unit_energy]
            
        # Display overall energy
        print(f"Overall energy for DNN {DNN}: {total_energy} fJ")

        for i in range(4):
            print(f"total_per_energy[{DNN}][{path.split('/')[-1].split('_')[0].upper()}][{i}]: {total_per_energy[(DNN,path)][i]}")
        print() 
        
        # Display an energy breakdown for each layer as a bar chart. Display normalized per-MAC and per-layer energy.
        fig, ax = plt.subplots(figsize=(20, 5))
        
        bar_stacked(
            {i: r.per_compute("per_component_energy") * 1e15 for i, r in enumerate(results)},
            title= f"Using {path.split('/')[-1].split('_')[0].upper()} on {array_sizes} x {array_sizes} array sizes, {tech_node} nm running {DNN}",
            xlabel="Layer",
            ylabel="Energy (fJ/MAC)",
            ax=ax,
        )
# Out:
# Running dpt_large with 128 x 128 SRAM with 32 nm in fast scenario
# Computes for layer 1: 884736.0
# Computes for layer 2: 1181696.0
# Computes for layer 3: 1181696.0
# Computes for layer 4: 1181696.0
# Computes for layer 5: 1154.0
# Computes for layer 6: 10404.03125
# Computes for layer 7: 1181696.0
# Computes for layer 8: 4726784.0
# Computes for layer 9: 4726784.0
# Computes for layer 10: 1181696.0
# Computes for layer 11: 1181696.0
# Computes for layer 12: 1181696.0
# Computes for layer 13: 1154.0
# Computes for layer 14: 10404.03125
# Computes for layer 15: 1181696.0
# Computes for layer 16: 4726784.0
# Computes for layer 17: 4726784.0
# Computes for layer 18: 1181696.0
# Computes for layer 19: 1181696.0
# Computes for layer 20: 1181696.0
# Computes for layer 21: 1154.0
# Computes for layer 22: 10404.03125
# Computes for layer 23: 1181696.0
# Computes for layer 24: 4726784.0
# Computes for layer 25: 4726784.0
# Computes for layer 26: 1181696.0
# Computes for layer 27: 1181696.0
# Computes for layer 28: 1181696.0
# Computes for layer 29: 1154.0
# Computes for layer 30: 10404.03125
# Computes for layer 31: 1181696.0
# Computes for layer 32: 4726784.0
# Computes for layer 33: 4726784.0
# Computes for layer 34: 1181696.0
# Computes for layer 35: 1181696.0
# Computes for layer 36: 1181696.0
# Computes for layer 37: 1154.0
# Computes for layer 38: 10404.03125
# Computes for layer 39: 1181696.0
# Computes for layer 40: 4726784.0
# Computes for layer 41: 4726784.0
# Computes for layer 42: 1181696.0
# Computes for layer 43: 1181696.0
# Computes for layer 44: 1181696.0
# Computes for layer 45: 1154.0
# Computes for layer 46: 10404.03125
# Computes for layer 47: 1181696.0
# Computes for layer 48: 4726784.0
# Computes for layer 49: 4726784.0
# Computes for layer 50: 1181696.0
# Computes for layer 51: 1181696.0
# Computes for layer 52: 1181696.0
# Computes for layer 53: 1154.0
# Computes for layer 54: 10404.03125
# Computes for layer 55: 1181696.0
# Computes for layer 56: 4726784.0
# Computes for layer 57: 4726784.0
# Computes for layer 58: 1181696.0
# Computes for layer 59: 1181696.0
# Computes for layer 60: 1181696.0
# Computes for layer 61: 1154.0
# Computes for layer 62: 10404.03125
# Computes for layer 63: 1181696.0
# Computes for layer 64: 4726784.0
# Computes for layer 65: 4726784.0
# Computes for layer 66: 1181696.0
# Computes for layer 67: 1181696.0
# Computes for layer 68: 1181696.0
# Computes for layer 69: 1154.0
# Computes for layer 70: 10404.03125
# Computes for layer 71: 1181696.0
# Computes for layer 72: 4726784.0
# Computes for layer 73: 4726784.0
# Computes for layer 74: 1181696.0
# Computes for layer 75: 1181696.0
# Computes for layer 76: 1181696.0
# Computes for layer 77: 1154.0
# Computes for layer 78: 10404.03125
# Computes for layer 79: 1181696.0
# Computes for layer 80: 4726784.0
# Computes for layer 81: 4726784.0
# Computes for layer 82: 1181696.0
# Computes for layer 83: 1181696.0
# Computes for layer 84: 1181696.0
# Computes for layer 85: 1154.0
# Computes for layer 86: 10404.03125
# Computes for layer 87: 1181696.0
# Computes for layer 88: 4726784.0
# Computes for layer 89: 4726784.0
# Computes for layer 90: 1181696.0
# Computes for layer 91: 1181696.0
# Computes for layer 92: 1181696.0
# Computes for layer 93: 1154.0
# Computes for layer 94: 10404.03125
# Computes for layer 95: 1181696.0
# Computes for layer 96: 4726784.0
# Computes for layer 97: 4726784.0
# Computes for layer 98: 1181696.0
# Computes for layer 99: 1181696.0
# Computes for layer 100: 1181696.0
# Computes for layer 101: 1154.0
# Computes for layer 102: 10404.03125
# Computes for layer 103: 1181696.0
# Computes for layer 104: 4726784.0
# Computes for layer 105: 4726784.0
# Computes for layer 106: 1181696.0
# Computes for layer 107: 1181696.0
# Computes for layer 108: 1181696.0
# Computes for layer 109: 1154.0
# Computes for layer 110: 10404.03125
# Computes for layer 111: 1181696.0
# Computes for layer 112: 4726784.0
# Computes for layer 113: 4726784.0
# Computes for layer 114: 1181696.0
# Computes for layer 115: 1181696.0
# Computes for layer 116: 1181696.0
# Computes for layer 117: 1154.0
# Computes for layer 118: 10404.03125
# Computes for layer 119: 1181696.0
# Computes for layer 120: 4726784.0
# Computes for layer 121: 4726784.0
# Computes for layer 122: 1181696.0
# Computes for layer 123: 1181696.0
# Computes for layer 124: 1181696.0
# Computes for layer 125: 1154.0
# Computes for layer 126: 10404.03125
# Computes for layer 127: 1181696.0
# Computes for layer 128: 4726784.0
# Computes for layer 129: 4726784.0
# Computes for layer 130: 1181696.0
# Computes for layer 131: 1181696.0
# Computes for layer 132: 1181696.0
# Computes for layer 133: 1154.0
# Computes for layer 134: 10404.03125
# Computes for layer 135: 1181696.0
# Computes for layer 136: 4726784.0
# Computes for layer 137: 4726784.0
# Computes for layer 138: 1181696.0
# Computes for layer 139: 1181696.0
# Computes for layer 140: 1181696.0
# Computes for layer 141: 1154.0
# Computes for layer 142: 10404.03125
# Computes for layer 143: 1181696.0
# Computes for layer 144: 4726784.0
# Computes for layer 145: 4726784.0
# Computes for layer 146: 1181696.0
# Computes for layer 147: 1181696.0
# Computes for layer 148: 1181696.0
# Computes for layer 149: 1154.0
# Computes for layer 150: 10404.03125
# Computes for layer 151: 1181696.0
# Computes for layer 152: 4726784.0
# Computes for layer 153: 4726784.0
# Computes for layer 154: 1181696.0
# Computes for layer 155: 1181696.0
# Computes for layer 156: 1181696.0
# Computes for layer 157: 1154.0
# Computes for layer 158: 10404.03125
# Computes for layer 159: 1181696.0
# Computes for layer 160: 4726784.0
# Computes for layer 161: 4726784.0
# Computes for layer 162: 1181696.0
# Computes for layer 163: 1181696.0
# Computes for layer 164: 1181696.0
# Computes for layer 165: 1154.0
# Computes for layer 166: 10404.03125
# Computes for layer 167: 1181696.0
# Computes for layer 168: 4726784.0
# Computes for layer 169: 4726784.0
# Computes for layer 170: 1181696.0
# Computes for layer 171: 1181696.0
# Computes for layer 172: 1181696.0
# Computes for layer 173: 1154.0
# Computes for layer 174: 10404.03125
# Computes for layer 175: 1181696.0
# Computes for layer 176: 4726784.0
# Computes for layer 177: 4726784.0
# Computes for layer 178: 1181696.0
# Computes for layer 179: 1181696.0
# Computes for layer 180: 1181696.0
# Computes for layer 181: 1154.0
# Computes for layer 182: 10404.03125
# Computes for layer 183: 1181696.0
# Computes for layer 184: 4726784.0
# Computes for layer 185: 4726784.0
# Computes for layer 186: 1181696.0
# Computes for layer 187: 1181696.0
# Computes for layer 188: 1181696.0
# Computes for layer 189: 1154.0
# Computes for layer 190: 10404.03125
# Computes for layer 191: 1181696.0
# Computes for layer 192: 4726784.0
# Computes for layer 193: 4726784.0
# Computes for layer 194: 2359296.0
# Computes for layer 195: 294912.0
# Computes for layer 196: 2359296.0
# Computes for layer 197: 589824.0
# Computes for layer 198: 2359296.0
# Computes for layer 199: 1179648.0
# Computes for layer 200: 2359296.0
# Computes for layer 201: 1179648.0
# Computes for layer 202: 2654208.0
# Computes for layer 203: 10616832.0
# Computes for layer 204: 5308416.0
# Computes for layer 205: 2654208.0
# Computes for layer 206: 663552.0
# Computes for layer 207: 165888.0
# Computes for layer 208: 165888.0
# Computes for layer 209: 73728.0
# Computes for layer 210: 663552.0
# Computes for layer 211: 663552.0
# Computes for layer 212: 663552.0
# Computes for layer 213: 663552.0
# Computes for layer 214: 294912.0
# Computes for layer 215: 2654208.0
# Computes for layer 216: 2654208.0
# Computes for layer 217: 2654208.0
# Computes for layer 218: 2654208.0
# Computes for layer 219: 1179648.0
# Computes for layer 220: 10616832.0
# Computes for layer 221: 10616832.0
# Computes for layer 222: 10616832.0
# Computes for layer 223: 10616832.0
# Computes for layer 224: 4718592.0
# Computes for layer 225: 21233664.0
# Computes for layer 226: 10616832.0
# Computes for layer 227: 9216.0
#
# Overall energy for DNN dpt_large: 1000000000001102.6 fJ
# total_per_energy[dpt_large][SRAM][0]: 0.4847776383417458
# total_per_energy[dpt_large][SRAM][1]: 0.00293960908356164
# total_per_energy[dpt_large][SRAM][2]: 0.5105636829351832
# total_per_energy[dpt_large][SRAM][3]: 0.0017190696395093037
#
#
# Running dpt_large with 128 x 128 RRAM with 32 nm in fast scenario
# Computes for layer 1: 884736.0
# Computes for layer 2: 1181696.0
# Computes for layer 3: 1181696.0
# Computes for layer 4: 1181696.0
# Computes for layer 5: 1154.0
# Computes for layer 6: 10404.03125
# Computes for layer 7: 1181696.0
# Computes for layer 8: 4726784.0
# Computes for layer 9: 4726784.0
# Computes for layer 10: 1181696.0
# Computes for layer 11: 1181696.0
# Computes for layer 12: 1181696.0
# Computes for layer 13: 1154.0
# Computes for layer 14: 10404.03125
# Computes for layer 15: 1181696.0
# Computes for layer 16: 4726784.0
# Computes for layer 17: 4726784.0
# Computes for layer 18: 1181696.0
# Computes for layer 19: 1181696.0
# Computes for layer 20: 1181696.0
# Computes for layer 21: 1154.0
# Computes for layer 22: 10404.03125
# Computes for layer 23: 1181696.0
# Computes for layer 24: 4726784.0
# Computes for layer 25: 4726784.0
# Computes for layer 26: 1181696.0
# Computes for layer 27: 1181696.0
# Computes for layer 28: 1181696.0
# Computes for layer 29: 1154.0
# Computes for layer 30: 10404.03125
# Computes for layer 31: 1181696.0
# Computes for layer 32: 4726784.0
# Computes for layer 33: 4726784.0
# Computes for layer 34: 1181696.0
# Computes for layer 35: 1181696.0
# Computes for layer 36: 1181696.0
# Computes for layer 37: 1154.0
# Computes for layer 38: 10404.03125
# Computes for layer 39: 1181696.0
# Computes for layer 40: 4726784.0
# Computes for layer 41: 4726784.0
# Computes for layer 42: 1181696.0
# Computes for layer 43: 1181696.0
# Computes for layer 44: 1181696.0
# Computes for layer 45: 1154.0
# Computes for layer 46: 10404.03125
# Computes for layer 47: 1181696.0
# Computes for layer 48: 4726784.0
# Computes for layer 49: 4726784.0
# Computes for layer 50: 1181696.0
# Computes for layer 51: 1181696.0
# Computes for layer 52: 1181696.0
# Computes for layer 53: 1154.0
# Computes for layer 54: 10404.03125
# Computes for layer 55: 1181696.0
# Computes for layer 56: 4726784.0
# Computes for layer 57: 4726784.0
# Computes for layer 58: 1181696.0
# Computes for layer 59: 1181696.0
# Computes for layer 60: 1181696.0
# Computes for layer 61: 1154.0
# Computes for layer 62: 10404.03125
# Computes for layer 63: 1181696.0
# Computes for layer 64: 4726784.0
# Computes for layer 65: 4726784.0
# Computes for layer 66: 1181696.0
# Computes for layer 67: 1181696.0
# Computes for layer 68: 1181696.0
# Computes for layer 69: 1154.0
# Computes for layer 70: 10404.03125
# Computes for layer 71: 1181696.0
# Computes for layer 72: 4726784.0
# Computes for layer 73: 4726784.0
# Computes for layer 74: 1181696.0
# Computes for layer 75: 1181696.0
# Computes for layer 76: 1181696.0
# Computes for layer 77: 1154.0
# Computes for layer 78: 10404.03125
# Computes for layer 79: 1181696.0
# Computes for layer 80: 4726784.0
# Computes for layer 81: 4726784.0
# Computes for layer 82: 1181696.0
# Computes for layer 83: 1181696.0
# Computes for layer 84: 1181696.0
# Computes for layer 85: 1154.0
# Computes for layer 86: 10404.03125
# Computes for layer 87: 1181696.0
# Computes for layer 88: 4726784.0
# Computes for layer 89: 4726784.0
# Computes for layer 90: 1181696.0
# Computes for layer 91: 1181696.0
# Computes for layer 92: 1181696.0
# Computes for layer 93: 1154.0
# Computes for layer 94: 10404.03125
# Computes for layer 95: 1181696.0
# Computes for layer 96: 4726784.0
# Computes for layer 97: 4726784.0
# Computes for layer 98: 1181696.0
# Computes for layer 99: 1181696.0
# Computes for layer 100: 1181696.0
# Computes for layer 101: 1154.0
# Computes for layer 102: 10404.03125
# Computes for layer 103: 1181696.0
# Computes for layer 104: 4726784.0
# Computes for layer 105: 4726784.0
# Computes for layer 106: 1181696.0
# Computes for layer 107: 1181696.0
# Computes for layer 108: 1181696.0
# Computes for layer 109: 1154.0
# Computes for layer 110: 10404.03125
# Computes for layer 111: 1181696.0
# Computes for layer 112: 4726784.0
# Computes for layer 113: 4726784.0
# Computes for layer 114: 1181696.0
# Computes for layer 115: 1181696.0
# Computes for layer 116: 1181696.0
# Computes for layer 117: 1154.0
# Computes for layer 118: 10404.03125
# Computes for layer 119: 1181696.0
# Computes for layer 120: 4726784.0
# Computes for layer 121: 4726784.0
# Computes for layer 122: 1181696.0
# Computes for layer 123: 1181696.0
# Computes for layer 124: 1181696.0
# Computes for layer 125: 1154.0
# Computes for layer 126: 10404.03125
# Computes for layer 127: 1181696.0
# Computes for layer 128: 4726784.0
# Computes for layer 129: 4726784.0
# Computes for layer 130: 1181696.0
# Computes for layer 131: 1181696.0
# Computes for layer 132: 1181696.0
# Computes for layer 133: 1154.0
# Computes for layer 134: 10404.03125
# Computes for layer 135: 1181696.0
# Computes for layer 136: 4726784.0
# Computes for layer 137: 4726784.0
# Computes for layer 138: 1181696.0
# Computes for layer 139: 1181696.0
# Computes for layer 140: 1181696.0
# Computes for layer 141: 1154.0
# Computes for layer 142: 10404.03125
# Computes for layer 143: 1181696.0
# Computes for layer 144: 4726784.0
# Computes for layer 145: 4726784.0
# Computes for layer 146: 1181696.0
# Computes for layer 147: 1181696.0
# Computes for layer 148: 1181696.0
# Computes for layer 149: 1154.0
# Computes for layer 150: 10404.03125
# Computes for layer 151: 1181696.0
# Computes for layer 152: 4726784.0
# Computes for layer 153: 4726784.0
# Computes for layer 154: 1181696.0
# Computes for layer 155: 1181696.0
# Computes for layer 156: 1181696.0
# Computes for layer 157: 1154.0
# Computes for layer 158: 10404.03125
# Computes for layer 159: 1181696.0
# Computes for layer 160: 4726784.0
# Computes for layer 161: 4726784.0
# Computes for layer 162: 1181696.0
# Computes for layer 163: 1181696.0
# Computes for layer 164: 1181696.0
# Computes for layer 165: 1154.0
# Computes for layer 166: 10404.03125
# Computes for layer 167: 1181696.0
# Computes for layer 168: 4726784.0
# Computes for layer 169: 4726784.0
# Computes for layer 170: 1181696.0
# Computes for layer 171: 1181696.0
# Computes for layer 172: 1181696.0
# Computes for layer 173: 1154.0
# Computes for layer 174: 10404.03125
# Computes for layer 175: 1181696.0
# Computes for layer 176: 4726784.0
# Computes for layer 177: 4726784.0
# Computes for layer 178: 1181696.0
# Computes for layer 179: 1181696.0
# Computes for layer 180: 1181696.0
# Computes for layer 181: 1154.0
# Computes for layer 182: 10404.03125
# Computes for layer 183: 1181696.0
# Computes for layer 184: 4726784.0
# Computes for layer 185: 4726784.0
# Computes for layer 186: 1181696.0
# Computes for layer 187: 1181696.0
# Computes for layer 188: 1181696.0
# Computes for layer 189: 1154.0
# Computes for layer 190: 10404.03125
# Computes for layer 191: 1181696.0
# Computes for layer 192: 4726784.0
# Computes for layer 193: 4726784.0
# Computes for layer 194: 2359296.0
# Computes for layer 195: 294912.0
# Computes for layer 196: 2359296.0
# Computes for layer 197: 589824.0
# Computes for layer 198: 2359296.0
# Computes for layer 199: 1179648.0
# Computes for layer 200: 2359296.0
# Computes for layer 201: 1179648.0
# Computes for layer 202: 2654208.0
# Computes for layer 203: 10616832.0
# Computes for layer 204: 5308416.0
# Computes for layer 205: 2654208.0
# Computes for layer 206: 663552.0
# Computes for layer 207: 165888.0
# Computes for layer 208: 165888.0
# Computes for layer 209: 73728.0
# Computes for layer 210: 663552.0
# Computes for layer 211: 663552.0
# Computes for layer 212: 663552.0
# Computes for layer 213: 663552.0
# Computes for layer 214: 294912.0
# Computes for layer 215: 2654208.0
# Computes for layer 216: 2654208.0
# Computes for layer 217: 2654208.0
# Computes for layer 218: 2654208.0
# Computes for layer 219: 1179648.0
# Computes for layer 220: 10616832.0
# Computes for layer 221: 10616832.0
# Computes for layer 222: 10616832.0
# Computes for layer 223: 10616832.0
# Computes for layer 224: 4718592.0
# Computes for layer 225: 21233664.0
# Computes for layer 226: 10616832.0
# Computes for layer 227: 9216.0
#
# Overall energy for DNN dpt_large: 1000000000000979.4 fJ
# total_per_energy[dpt_large][RRAM][0]: 0.45968882602467864
# total_per_energy[dpt_large][RRAM][1]: 1.1555869872788764e-12
# total_per_energy[dpt_large][RRAM][2]: 0.3635077793494324
# total_per_energy[dpt_large][RRAM][3]: 0.17680339462473338
#
#
# Running gpt2_medium with 128 x 128 SRAM with 32 nm in fast scenario
# Computes for layer 1: 1572864.0
# Computes for layer 2: 524288.0
# Computes for layer 3: 512.0
# Computes for layer 4: 2048.0
# Computes for layer 5: 2097152.0
# Computes for layer 6: 2097152.0
# Computes for layer 7: 1572864.0
# Computes for layer 8: 524288.0
# Computes for layer 9: 512.0
# Computes for layer 10: 2048.0
# Computes for layer 11: 2097152.0
# Computes for layer 12: 2097152.0
# Computes for layer 13: 1572864.0
# Computes for layer 14: 524288.0
# Computes for layer 15: 512.0
# Computes for layer 16: 2048.0
# Computes for layer 17: 2097152.0
# Computes for layer 18: 2097152.0
# Computes for layer 19: 1572864.0
# Computes for layer 20: 524288.0
# Computes for layer 21: 512.0
# Computes for layer 22: 2048.0
# Computes for layer 23: 2097152.0
# Computes for layer 24: 2097152.0
# Computes for layer 25: 1572864.0
# Computes for layer 26: 524288.0
# Computes for layer 27: 512.0
# Computes for layer 28: 2048.0
# Computes for layer 29: 2097152.0
# Computes for layer 30: 2097152.0
# Computes for layer 31: 1572864.0
# Computes for layer 32: 524288.0
# Computes for layer 33: 512.0
# Computes for layer 34: 2048.0
# Computes for layer 35: 2097152.0
# Computes for layer 36: 2097152.0
# Computes for layer 37: 1572864.0
# Computes for layer 38: 524288.0
# Computes for layer 39: 512.0
# Computes for layer 40: 2048.0
# Computes for layer 41: 2097152.0
# Computes for layer 42: 2097152.0
# Computes for layer 43: 1572864.0
# Computes for layer 44: 524288.0
# Computes for layer 45: 512.0
# Computes for layer 46: 2048.0
# Computes for layer 47: 2097152.0
# Computes for layer 48: 2097152.0
# Computes for layer 49: 1572864.0
# Computes for layer 50: 524288.0
# Computes for layer 51: 512.0
# Computes for layer 52: 2048.0
# Computes for layer 53: 2097152.0
# Computes for layer 54: 2097152.0
# Computes for layer 55: 1572864.0
# Computes for layer 56: 524288.0
# Computes for layer 57: 512.0
# Computes for layer 58: 2048.0
# Computes for layer 59: 2097152.0
# Computes for layer 60: 2097152.0
# Computes for layer 61: 1572864.0
# Computes for layer 62: 524288.0
# Computes for layer 63: 512.0
# Computes for layer 64: 2048.0
# Computes for layer 65: 2097152.0
# Computes for layer 66: 2097152.0
# Computes for layer 67: 1572864.0
# Computes for layer 68: 524288.0
# Computes for layer 69: 512.0
# Computes for layer 70: 2048.0
# Computes for layer 71: 2097152.0
# Computes for layer 72: 2097152.0
# Computes for layer 73: 1572864.0
# Computes for layer 74: 524288.0
# Computes for layer 75: 512.0
# Computes for layer 76: 2048.0
# Computes for layer 77: 2097152.0
# Computes for layer 78: 2097152.0
# Computes for layer 79: 1572864.0
# Computes for layer 80: 524288.0
# Computes for layer 81: 512.0
# Computes for layer 82: 2048.0
# Computes for layer 83: 2097152.0
# Computes for layer 84: 2097152.0
# Computes for layer 85: 1572864.0
# Computes for layer 86: 524288.0
# Computes for layer 87: 512.0
# Computes for layer 88: 2048.0
# Computes for layer 89: 2097152.0
# Computes for layer 90: 2097152.0
# Computes for layer 91: 1572864.0
# Computes for layer 92: 524288.0
# Computes for layer 93: 512.0
# Computes for layer 94: 2048.0
# Computes for layer 95: 2097152.0
# Computes for layer 96: 2097152.0
# Computes for layer 97: 1572864.0
# Computes for layer 98: 524288.0
# Computes for layer 99: 512.0
# Computes for layer 100: 2048.0
# Computes for layer 101: 2097152.0
# Computes for layer 102: 2097152.0
# Computes for layer 103: 1572864.0
# Computes for layer 104: 524288.0
# Computes for layer 105: 512.0
# Computes for layer 106: 2048.0
# Computes for layer 107: 2097152.0
# Computes for layer 108: 2097152.0
# Computes for layer 109: 1572864.0
# Computes for layer 110: 524288.0
# Computes for layer 111: 512.0
# Computes for layer 112: 2048.0
# Computes for layer 113: 2097152.0
# Computes for layer 114: 2097152.0
# Computes for layer 115: 1572864.0
# Computes for layer 116: 524288.0
# Computes for layer 117: 512.0
# Computes for layer 118: 2048.0
# Computes for layer 119: 2097152.0
# Computes for layer 120: 2097152.0
# Computes for layer 121: 1572864.0
# Computes for layer 122: 524288.0
# Computes for layer 123: 512.0
# Computes for layer 124: 2048.0
# Computes for layer 125: 2097152.0
# Computes for layer 126: 2097152.0
# Computes for layer 127: 1572864.0
# Computes for layer 128: 524288.0
# Computes for layer 129: 512.0
# Computes for layer 130: 2048.0
# Computes for layer 131: 2097152.0
# Computes for layer 132: 2097152.0
# Computes for layer 133: 1572864.0
# Computes for layer 134: 524288.0
# Computes for layer 135: 512.0
# Computes for layer 136: 2048.0
# Computes for layer 137: 2097152.0
# Computes for layer 138: 2097152.0
# Computes for layer 139: 1572864.0
# Computes for layer 140: 524288.0
# Computes for layer 141: 512.0
# Computes for layer 142: 2048.0
# Computes for layer 143: 2097152.0
# Computes for layer 144: 2097152.0
# Computes for layer 145: 25731584.0
#
# Overall energy for DNN gpt2_medium: 1000000000000029.1 fJ
# total_per_energy[gpt2_medium][SRAM][0]: 0.49498867845044764
# total_per_energy[gpt2_medium][SRAM][1]: 0.003001527092731456
# total_per_energy[gpt2_medium][SRAM][2]: 0.5002545154552236
# total_per_energy[gpt2_medium][SRAM][3]: 0.0017552790015973338
#
#
# Running gpt2_medium with 128 x 128 RRAM with 32 nm in fast scenario
# Computes for layer 1: 1572864.0
# Computes for layer 2: 524288.0
# Computes for layer 3: 512.0
# Computes for layer 4: 2048.0
# Computes for layer 5: 2097152.0
# Computes for layer 6: 2097152.0
# Computes for layer 7: 1572864.0
# Computes for layer 8: 524288.0
# Computes for layer 9: 512.0
# Computes for layer 10: 2048.0
# Computes for layer 11: 2097152.0
# Computes for layer 12: 2097152.0
# Computes for layer 13: 1572864.0
# Computes for layer 14: 524288.0
# Computes for layer 15: 512.0
# Computes for layer 16: 2048.0
# Computes for layer 17: 2097152.0
# Computes for layer 18: 2097152.0
# Computes for layer 19: 1572864.0
# Computes for layer 20: 524288.0
# Computes for layer 21: 512.0
# Computes for layer 22: 2048.0
# Computes for layer 23: 2097152.0
# Computes for layer 24: 2097152.0
# Computes for layer 25: 1572864.0
# Computes for layer 26: 524288.0
# Computes for layer 27: 512.0
# Computes for layer 28: 2048.0
# Computes for layer 29: 2097152.0
# Computes for layer 30: 2097152.0
# Computes for layer 31: 1572864.0
# Computes for layer 32: 524288.0
# Computes for layer 33: 512.0
# Computes for layer 34: 2048.0
# Computes for layer 35: 2097152.0
# Computes for layer 36: 2097152.0
# Computes for layer 37: 1572864.0
# Computes for layer 38: 524288.0
# Computes for layer 39: 512.0
# Computes for layer 40: 2048.0
# Computes for layer 41: 2097152.0
# Computes for layer 42: 2097152.0
# Computes for layer 43: 1572864.0
# Computes for layer 44: 524288.0
# Computes for layer 45: 512.0
# Computes for layer 46: 2048.0
# Computes for layer 47: 2097152.0
# Computes for layer 48: 2097152.0
# Computes for layer 49: 1572864.0
# Computes for layer 50: 524288.0
# Computes for layer 51: 512.0
# Computes for layer 52: 2048.0
# Computes for layer 53: 2097152.0
# Computes for layer 54: 2097152.0
# Computes for layer 55: 1572864.0
# Computes for layer 56: 524288.0
# Computes for layer 57: 512.0
# Computes for layer 58: 2048.0
# Computes for layer 59: 2097152.0
# Computes for layer 60: 2097152.0
# Computes for layer 61: 1572864.0
# Computes for layer 62: 524288.0
# Computes for layer 63: 512.0
# Computes for layer 64: 2048.0
# Computes for layer 65: 2097152.0
# Computes for layer 66: 2097152.0
# Computes for layer 67: 1572864.0
# Computes for layer 68: 524288.0
# Computes for layer 69: 512.0
# Computes for layer 70: 2048.0
# Computes for layer 71: 2097152.0
# Computes for layer 72: 2097152.0
# Computes for layer 73: 1572864.0
# Computes for layer 74: 524288.0
# Computes for layer 75: 512.0
# Computes for layer 76: 2048.0
# Computes for layer 77: 2097152.0
# Computes for layer 78: 2097152.0
# Computes for layer 79: 1572864.0
# Computes for layer 80: 524288.0
# Computes for layer 81: 512.0
# Computes for layer 82: 2048.0
# Computes for layer 83: 2097152.0
# Computes for layer 84: 2097152.0
# Computes for layer 85: 1572864.0
# Computes for layer 86: 524288.0
# Computes for layer 87: 512.0
# Computes for layer 88: 2048.0
# Computes for layer 89: 2097152.0
# Computes for layer 90: 2097152.0
# Computes for layer 91: 1572864.0
# Computes for layer 92: 524288.0
# Computes for layer 93: 512.0
# Computes for layer 94: 2048.0
# Computes for layer 95: 2097152.0
# Computes for layer 96: 2097152.0
# Computes for layer 97: 1572864.0
# Computes for layer 98: 524288.0
# Computes for layer 99: 512.0
# Computes for layer 100: 2048.0
# Computes for layer 101: 2097152.0
# Computes for layer 102: 2097152.0
# Computes for layer 103: 1572864.0
# Computes for layer 104: 524288.0
# Computes for layer 105: 512.0
# Computes for layer 106: 2048.0
# Computes for layer 107: 2097152.0
# Computes for layer 108: 2097152.0
# Computes for layer 109: 1572864.0
# Computes for layer 110: 524288.0
# Computes for layer 111: 512.0
# Computes for layer 112: 2048.0
# Computes for layer 113: 2097152.0
# Computes for layer 114: 2097152.0
# Computes for layer 115: 1572864.0
# Computes for layer 116: 524288.0
# Computes for layer 117: 512.0
# Computes for layer 118: 2048.0
# Computes for layer 119: 2097152.0
# Computes for layer 120: 2097152.0
# Computes for layer 121: 1572864.0
# Computes for layer 122: 524288.0
# Computes for layer 123: 512.0
# Computes for layer 124: 2048.0
# Computes for layer 125: 2097152.0
# Computes for layer 126: 2097152.0
# Computes for layer 127: 1572864.0
# Computes for layer 128: 524288.0
# Computes for layer 129: 512.0
# Computes for layer 130: 2048.0
# Computes for layer 131: 2097152.0
# Computes for layer 132: 2097152.0
# Computes for layer 133: 1572864.0
# Computes for layer 134: 524288.0
# Computes for layer 135: 512.0
# Computes for layer 136: 2048.0
# Computes for layer 137: 2097152.0
# Computes for layer 138: 2097152.0
# Computes for layer 139: 1572864.0
# Computes for layer 140: 524288.0
# Computes for layer 141: 512.0
# Computes for layer 142: 2048.0
# Computes for layer 143: 2097152.0
# Computes for layer 144: 2097152.0
# Computes for layer 145: 25731584.0
#
# Overall energy for DNN gpt2_medium: 1000000000000035.4 fJ
# total_per_energy[gpt2_medium][RRAM][0]: 0.4703328509401236
# total_per_energy[gpt2_medium][RRAM][1]: 1.1823444283633175e-12
# total_per_energy[gpt2_medium][RRAM][2]: 0.35745296671447435
# total_per_energy[gpt2_medium][RRAM][3]: 0.17221418234421965

# %%
display_markdown(
    """
### Calculating Area in fast scenario

"""
)

# Initialize lists for each DNN
num_dnns = len(dnn_list)
total_area = [0] * (2 * num_dnns)
total_adc_area = [0] * (2 * num_dnns)
total_col_area = [0] * (2 * num_dnns)
total_row_area = [0] * (2 * num_dnns)
total_cim_unit_area = [0] * (2 * num_dnns)
total_macro = [0] * (2 * num_dnns)
energy = [0] * (2 * num_dnns)
throughput = [0] * (2 * num_dnns)

# Loop through both DNNs and extract their outputs for SRAM and RRAM
for i, dnn in enumerate(dnn_list):
    total_area[2 * i], total_adc_area[2 * i], total_col_area[2 * i], total_row_area[2 * i], total_cim_unit_area[2 * i], total_macro[2 * i], energy[2 * i], throughput[2 * i] = extract_outputs(f"SRAM_{dnn}_{array_sizes}")
    
    total_area[2 * i + 1], total_adc_area[2 * i + 1], total_col_area[2 * i + 1], total_row_area[2 * i + 1], total_cim_unit_area[2 * i + 1], total_macro[2 * i + 1], energy[2 * i + 1], throughput[2 * i + 1] = extract_outputs(f"RRAM_{dnn}_{array_sizes}")
# Out:
# ### Calculating Area in fast scenario
# ../outputs/SRAM_dpt_large_128/
# Model 	 Energy/inference (J) 	 Area (mm2) 	 Throughput (inf/s)
# Processing layer: SRAM_dpt_large_128_layer_1
# Cycle: 576
#
# Total Cycle: 576.0
# Size: 2
# Size: 16
# Size: 3
# All macro: 96
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 2737449.5999999996
#
# Size: 2
# Size: 16
# Size: 3
# All macro: 96
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 101246.40000000001
#
# Size: 2
# Size: 16
# Size: 3
# All macro: 96
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 89135.616
#
# Size: 2
# Size: 16
# Size: 3
# All macro: 96
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 515396.0755200001
#
# Total Area for layer 1: 3443227.6915199994
#
# Total Macro for layer 1: 96
#
# Total Area for all layers: 3443227.6915199994
# Total Area for ADC across all layers: 2737449.5999999996
# Processing layer: SRAM_dpt_large_128_layer_2
# Cycle: 577
#
# Total Cycle: 1153.0
# Size: 16
# Size: 8
# All macro: 128
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 3649932.8
#
# Size: 16
# Size: 8
# All macro: 128
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 134995.2
#
# Size: 16
# Size: 8
# All macro: 128
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 118847.488
#
# Size: 16
# Size: 8
# All macro: 128
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 687194.76736
#
# Total Area for layer 2: 4590970.25536
#
# Total Macro for layer 2: 224
#
# Total Area for all layers: 8034197.94688
# Total Area for ADC across all layers: 6387382.399999999
# Processing layer: SRAM_dpt_large_128_layer_3
# Cycle: 577
#
# Total Cycle: 1730.0
# Size: 16
# Size: 8
# All macro: 128
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 3649932.8
#
# Size: 16
# Size: 8
# All macro: 128
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 134995.2
#
# Size: 16
# Size: 8
# All macro: 128
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 118847.488
#
# Size: 16
# Size: 8
# All macro: 128
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 687194.76736
#
# Total Area for layer 3: 4590970.25536
#
# Total Macro for layer 3: 352
#
# Total Area for all layers: 12625168.20224
# Total Area for ADC across all layers: 10037315.2
# Processing layer: SRAM_dpt_large_128_layer_4
# Cycle: 577
#
# Total Cycle: 2307.0
# Size: 16
# Size: 8
# All macro: 128
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 3649932.8
#
# Size: 16
# Size: 8
# All macro: 128
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 134995.2
#
# Size: 16
# Size: 8
# All macro: 128
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 118847.488
#
# Size: 16
# Size: 8
# All macro: 128
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 687194.76736
#
# Total Area for layer 4: 4590970.25536
#
# Total Macro for layer 4: 480
#
# Total Area for all layers: 17216138.457599998
# Total Area for ADC across all layers: 13687248.0
# Processing layer: SRAM_dpt_large_128_layer_5
# Cycle: 16
#
# Total Cycle: 2323.0
# Size: 5
# All macro: 5
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 142575.5
#
# Size: 5
# All macro: 5
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 5273.25
#
# Size: 5
# All macro: 5
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 4642.48
#
# Size: 5
# All macro: 5
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 26843.5456
#
# Total Area for layer 5: 179334.77560000002
#
# Total Macro for layer 5: 485
#
# Total Area for all layers: 17395473.2332
# Total Area for ADC across all layers: 13829823.5
# Processing layer: SRAM_dpt_large_128_layer_6
# Cycle: 16
#
# Total Cycle: 2339.0
# Size: 10
# Size: 5
# All macro: 50
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 1425755.0
#
# Size: 10
# Size: 5
# All macro: 50
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 52732.50000000001
#
# Size: 10
# Size: 5
# All macro: 50
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 46424.799999999996
#
# Size: 10
# Size: 5
# All macro: 50
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 268435.456
#
# Total Area for layer 6: 1793347.756
#
# Total Macro for layer 6: 535
#
# Total Area for all layers: 19188820.9892
# Total Area for ADC across all layers: 15255578.5
# Processing layer: SRAM_dpt_large_128_layer_7
# Cycle: 577
#
# Total Cycle: 2916.0
# Size: 16
# Size: 8
# All macro: 128
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 3649932.8
#
# Size: 16
# Size: 8
# All macro: 128
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 134995.2
#
# Size: 16
# Size: 8
# All macro: 128
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 118847.488
#
# Size: 16
# Size: 8
# All macro: 128
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 687194.76736
#
# Total Area for layer 7: 4590970.25536
#
# Total Macro for layer 7: 663
#
# Total Area for all layers: 23779791.24456
# Total Area for ADC across all layers: 18905511.3
# Processing layer: SRAM_dpt_large_128_layer_8
# Cycle: 577
#
# Total Cycle: 3493.0
# Size: 64
# Size: 8
# All macro: 512
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 14599731.2
#
# Size: 64
# Size: 8
# All macro: 512
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 539980.8
#
# Size: 64
# Size: 8
# All macro: 512
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 475389.952
#
# Size: 64
# Size: 8
# All macro: 512
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 2748779.06944
#
# Total Area for layer 8: 18363881.02144
#
# Total Macro for layer 8: 1175
#
# Total Area for all layers: 42143672.266
# Total Area for ADC across all layers: 33505242.5
# Processing layer: SRAM_dpt_large_128_layer_9
# Cycle: 577
#
# Total Cycle: 4070.0
# Size: 16
# Size: 32
# All macro: 512
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 14599731.2
#
# Size: 16
# Size: 32
# All macro: 512
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 539980.8
#
# Size: 16
# Size: 32
# All macro: 512
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 475389.952
#
# Size: 16
# Size: 32
# All macro: 512
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 2748779.06944
#
# Total Area for layer 9: 18363881.02144
#
# Total Macro for layer 9: 1687
#
# Total Area for all layers: 60507553.28744
# Total Area for ADC across all layers: 48104973.7
# Processing layer: SRAM_dpt_large_128_layer_10
# Cycle: 577
#
# Total Cycle: 4647.0
# Size: 16
# Size: 8
# All macro: 128
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 3649932.8
#
# Size: 16
# Size: 8
# All macro: 128
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 134995.2
#
# Size: 16
# Size: 8
# All macro: 128
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 118847.488
#
# Size: 16
# Size: 8
# All macro: 128
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 687194.76736
#
# Total Area for layer 10: 4590970.25536
#
# Total Macro for layer 10: 1815
#
# Total Area for all layers: 65098523.5428
# Total Area for ADC across all layers: 51754906.5
# Processing layer: SRAM_dpt_large_128_layer_11
# Cycle: 577
#
# Total Cycle: 5224.0
# Size: 16
# Size: 8
# All macro: 128
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 3649932.8
#
# Size: 16
# Size: 8
# All macro: 128
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 134995.2
#
# Size: 16
# Size: 8
# All macro: 128
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 118847.488
#
# Size: 16
# Size: 8
# All macro: 128
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 687194.76736
#
# Total Area for layer 11: 4590970.25536
#
# Total Macro for layer 11: 1943
#
# Total Area for all layers: 69689493.79816
# Total Area for ADC across all layers: 55404839.3
# Processing layer: SRAM_dpt_large_128_layer_12
# Cycle: 577
#
# Total Cycle: 5801.0
# Size: 16
# Size: 8
# All macro: 128
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 3649932.8
#
# Size: 16
# Size: 8
# All macro: 128
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 134995.2
#
# Size: 16
# Size: 8
# All macro: 128
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 118847.488
#
# Size: 16
# Size: 8
# All macro: 128
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 687194.76736
#
# Total Area for layer 12: 4590970.25536
#
# Total Macro for layer 12: 2071
#
# Total Area for all layers: 74280464.05352
# Total Area for ADC across all layers: 59054772.099999994
# Processing layer: SRAM_dpt_large_128_layer_13
# Cycle: 16
#
# Total Cycle: 5817.0
# Size: 5
# All macro: 5
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 142575.5
#
# Size: 5
# All macro: 5
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 5273.25
#
# Size: 5
# All macro: 5
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 4642.48
#
# Size: 5
# All macro: 5
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 26843.5456
#
# Total Area for layer 13: 179334.77560000002
#
# Total Macro for layer 13: 2076
#
# Total Area for all layers: 74459798.82912
# Total Area for ADC across all layers: 59197347.599999994
# Processing layer: SRAM_dpt_large_128_layer_14
# Cycle: 16
#
# Total Cycle: 5833.0
# Size: 10
# Size: 5
# All macro: 50
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 1425755.0
#
# Size: 10
# Size: 5
# All macro: 50
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 52732.50000000001
#
# Size: 10
# Size: 5
# All macro: 50
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 46424.799999999996
#
# Size: 10
# Size: 5
# All macro: 50
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 268435.456
#
# Total Area for layer 14: 1793347.756
#
# Total Macro for layer 14: 2126
#
# Total Area for all layers: 76253146.58511999
# Total Area for ADC across all layers: 60623102.599999994
# Processing layer: SRAM_dpt_large_128_layer_15
# Cycle: 577
#
# Total Cycle: 6410.0
# Size: 16
# Size: 8
# All macro: 128
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 3649932.8
#
# Size: 16
# Size: 8
# All macro: 128
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 134995.2
#
# Size: 16
# Size: 8
# All macro: 128
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 118847.488
#
# Size: 16
# Size: 8
# All macro: 128
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 687194.76736
#
# Total Area for layer 15: 4590970.25536
#
# Total Macro for layer 15: 2254
#
# Total Area for all layers: 80844116.84048
# Total Area for ADC across all layers: 64273035.39999999
# Processing layer: SRAM_dpt_large_128_layer_16
# Cycle: 577
#
# Total Cycle: 6987.0
# Size: 64
# Size: 8
# All macro: 512
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 14599731.2
#
# Size: 64
# Size: 8
# All macro: 512
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 539980.8
#
# Size: 64
# Size: 8
# All macro: 512
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 475389.952
#
# Size: 64
# Size: 8
# All macro: 512
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 2748779.06944
#
# Total Area for layer 16: 18363881.02144
#
# Total Macro for layer 16: 2766
#
# Total Area for all layers: 99207997.86192
# Total Area for ADC across all layers: 78872766.6
# Processing layer: SRAM_dpt_large_128_layer_17
# Cycle: 577
#
# Total Cycle: 7564.0
# Size: 16
# Size: 32
# All macro: 512
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 14599731.2
#
# Size: 16
# Size: 32
# All macro: 512
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 539980.8
#
# Size: 16
# Size: 32
# All macro: 512
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 475389.952
#
# Size: 16
# Size: 32
# All macro: 512
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 2748779.06944
#
# Total Area for layer 17: 18363881.02144
#
# Total Macro for layer 17: 3278
#
# Total Area for all layers: 117571878.88336
# Total Area for ADC across all layers: 93472497.8
# Processing layer: SRAM_dpt_large_128_layer_18
# Cycle: 577
#
# Total Cycle: 8141.0
# Size: 16
# Size: 8
# All macro: 128
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 3649932.8
#
# Size: 16
# Size: 8
# All macro: 128
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 134995.2
#
# Size: 16
# Size: 8
# All macro: 128
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 118847.488
#
# Size: 16
# Size: 8
# All macro: 128
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 687194.76736
#
# Total Area for layer 18: 4590970.25536
#
# Total Macro for layer 18: 3406
#
# Total Area for all layers: 122162849.13872
# Total Area for ADC across all layers: 97122430.6
# Processing layer: SRAM_dpt_large_128_layer_19
# Cycle: 577
#
# Total Cycle: 8718.0
# Size: 16
# Size: 8
# All macro: 128
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 3649932.8
#
# Size: 16
# Size: 8
# All macro: 128
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 134995.2
#
# Size: 16
# Size: 8
# All macro: 128
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 118847.488
#
# Size: 16
# Size: 8
# All macro: 128
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 687194.76736
#
# Total Area for layer 19: 4590970.25536
#
# Total Macro for layer 19: 3534
#
# Total Area for all layers: 126753819.39408001
# Total Area for ADC across all layers: 100772363.39999999
# Processing layer: SRAM_dpt_large_128_layer_20
# Cycle: 577
#
# Total Cycle: 9295.0
# Size: 16
# Size: 8
# All macro: 128
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 3649932.8
#
# Size: 16
# Size: 8
# All macro: 128
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 134995.2
#
# Size: 16
# Size: 8
# All macro: 128
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 118847.488
#
# Size: 16
# Size: 8
# All macro: 128
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 687194.76736
#
# Total Area for layer 20: 4590970.25536
#
# Total Macro for layer 20: 3662
#
# Total Area for all layers: 131344789.64944002
# Total Area for ADC across all layers: 104422296.19999999
# Processing layer: SRAM_dpt_large_128_layer_21
# Cycle: 16
#
# Total Cycle: 9311.0
# Size: 5
# All macro: 5
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 142575.5
#
# Size: 5
# All macro: 5
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 5273.25
#
# Size: 5
# All macro: 5
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 4642.48
#
# Size: 5
# All macro: 5
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 26843.5456
#
# Total Area for layer 21: 179334.77560000002
#
# Total Macro for layer 21: 3667
#
# Total Area for all layers: 131524124.42504002
# Total Area for ADC across all layers: 104564871.69999999
# Processing layer: SRAM_dpt_large_128_layer_22
# Cycle: 16
#
# Total Cycle: 9327.0
# Size: 10
# Size: 5
# All macro: 50
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 1425755.0
#
# Size: 10
# Size: 5
# All macro: 50
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 52732.50000000001
#
# Size: 10
# Size: 5
# All macro: 50
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 46424.799999999996
#
# Size: 10
# Size: 5
# All macro: 50
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 268435.456
#
# Total Area for layer 22: 1793347.756
#
# Total Macro for layer 22: 3717
#
# Total Area for all layers: 133317472.18104002
# Total Area for ADC across all layers: 105990626.69999999
# Processing layer: SRAM_dpt_large_128_layer_23
# Cycle: 577
#
# Total Cycle: 9904.0
# Size: 16
# Size: 8
# All macro: 128
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 3649932.8
#
# Size: 16
# Size: 8
# All macro: 128
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 134995.2
#
# Size: 16
# Size: 8
# All macro: 128
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 118847.488
#
# Size: 16
# Size: 8
# All macro: 128
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 687194.76736
#
# Total Area for layer 23: 4590970.25536
#
# Total Macro for layer 23: 3845
#
# Total Area for all layers: 137908442.43640003
# Total Area for ADC across all layers: 109640559.49999999
# Processing layer: SRAM_dpt_large_128_layer_24
# Cycle: 577
#
# Total Cycle: 10481.0
# Size: 64
# Size: 8
# All macro: 512
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 14599731.2
#
# Size: 64
# Size: 8
# All macro: 512
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 539980.8
#
# Size: 64
# Size: 8
# All macro: 512
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 475389.952
#
# Size: 64
# Size: 8
# All macro: 512
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 2748779.06944
#
# Total Area for layer 24: 18363881.02144
#
# Total Macro for layer 24: 4357
#
# Total Area for all layers: 156272323.45784003
# Total Area for ADC across all layers: 124240290.69999999
# Processing layer: SRAM_dpt_large_128_layer_25
# Cycle: 577
#
# Total Cycle: 11058.0
# Size: 16
# Size: 32
# All macro: 512
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 14599731.2
#
# Size: 16
# Size: 32
# All macro: 512
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 539980.8
#
# Size: 16
# Size: 32
# All macro: 512
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 475389.952
#
# Size: 16
# Size: 32
# All macro: 512
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 2748779.06944
#
# Total Area for layer 25: 18363881.02144
#
# Total Macro for layer 25: 4869
#
# Total Area for all layers: 174636204.47928002
# Total Area for ADC across all layers: 138840021.89999998
# Processing layer: SRAM_dpt_large_128_layer_26
# Cycle: 577
#
# Total Cycle: 11635.0
# Size: 16
# Size: 8
# All macro: 128
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 3649932.8
#
# Size: 16
# Size: 8
# All macro: 128
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 134995.2
#
# Size: 16
# Size: 8
# All macro: 128
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 118847.488
#
# Size: 16
# Size: 8
# All macro: 128
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 687194.76736
#
# Total Area for layer 26: 4590970.25536
#
# Total Macro for layer 26: 4997
#
# Total Area for all layers: 179227174.73464003
# Total Area for ADC across all layers: 142489954.7
# Processing layer: SRAM_dpt_large_128_layer_27
# Cycle: 577
#
# Total Cycle: 12212.0
# Size: 16
# Size: 8
# All macro: 128
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 3649932.8
#
# Size: 16
# Size: 8
# All macro: 128
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 134995.2
#
# Size: 16
# Size: 8
# All macro: 128
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 118847.488
#
# Size: 16
# Size: 8
# All macro: 128
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 687194.76736
#
# Total Area for layer 27: 4590970.25536
#
# Total Macro for layer 27: 5125
#
# Total Area for all layers: 183818144.99000004
# Total Area for ADC across all layers: 146139887.5
# Processing layer: SRAM_dpt_large_128_layer_28
# Cycle: 577
#
# Total Cycle: 12789.0
# Size: 16
# Size: 8
# All macro: 128
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 3649932.8
#
# Size: 16
# Size: 8
# All macro: 128
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 134995.2
#
# Size: 16
# Size: 8
# All macro: 128
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 118847.488
#
# Size: 16
# Size: 8
# All macro: 128
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 687194.76736
#
# Total Area for layer 28: 4590970.25536
#
# Total Macro for layer 28: 5253
#
# Total Area for all layers: 188409115.24536005
# Total Area for ADC across all layers: 149789820.3
# Processing layer: SRAM_dpt_large_128_layer_29
# Cycle: 16
#
# Total Cycle: 12805.0
# Size: 5
# All macro: 5
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 142575.5
#
# Size: 5
# All macro: 5
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 5273.25
#
# Size: 5
# All macro: 5
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 4642.48
#
# Size: 5
# All macro: 5
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 26843.5456
#
# Total Area for layer 29: 179334.77560000002
#
# Total Macro for layer 29: 5258
#
# Total Area for all layers: 188588450.02096003
# Total Area for ADC across all layers: 149932395.8
# Processing layer: SRAM_dpt_large_128_layer_30
# Cycle: 16
#
# Total Cycle: 12821.0
# Size: 10
# Size: 5
# All macro: 50
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 1425755.0
#
# Size: 10
# Size: 5
# All macro: 50
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 52732.50000000001
#
# Size: 10
# Size: 5
# All macro: 50
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 46424.799999999996
#
# Size: 10
# Size: 5
# All macro: 50
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 268435.456
#
# Total Area for layer 30: 1793347.756
#
# Total Macro for layer 30: 5308
#
# Total Area for all layers: 190381797.77696005
# Total Area for ADC across all layers: 151358150.8
# Processing layer: SRAM_dpt_large_128_layer_31
# Cycle: 577
#
# Total Cycle: 13398.0
# Size: 16
# Size: 8
# All macro: 128
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 3649932.8
#
# Size: 16
# Size: 8
# All macro: 128
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 134995.2
#
# Size: 16
# Size: 8
# All macro: 128
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 118847.488
#
# Size: 16
# Size: 8
# All macro: 128
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 687194.76736
#
# Total Area for layer 31: 4590970.25536
#
# Total Macro for layer 31: 5436
#
# Total Area for all layers: 194972768.03232005
# Total Area for ADC across all layers: 155008083.60000002
# Processing layer: SRAM_dpt_large_128_layer_32
# Cycle: 577
#
# Total Cycle: 13975.0
# Size: 64
# Size: 8
# All macro: 512
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 14599731.2
#
# Size: 64
# Size: 8
# All macro: 512
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 539980.8
#
# Size: 64
# Size: 8
# All macro: 512
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 475389.952
#
# Size: 64
# Size: 8
# All macro: 512
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 2748779.06944
#
# Total Area for layer 32: 18363881.02144
#
# Total Macro for layer 32: 5948
#
# Total Area for all layers: 213336649.05376005
# Total Area for ADC across all layers: 169607814.8
# Processing layer: SRAM_dpt_large_128_layer_33
# Cycle: 577
#
# Total Cycle: 14552.0
# Size: 16
# Size: 32
# All macro: 512
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 14599731.2
#
# Size: 16
# Size: 32
# All macro: 512
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 539980.8
#
# Size: 16
# Size: 32
# All macro: 512
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 475389.952
#
# Size: 16
# Size: 32
# All macro: 512
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 2748779.06944
#
# Total Area for layer 33: 18363881.02144
#
# Total Macro for layer 33: 6460
#
# Total Area for all layers: 231700530.07520005
# Total Area for ADC across all layers: 184207546.0
# Processing layer: SRAM_dpt_large_128_layer_34
# Cycle: 577
#
# Total Cycle: 15129.0
# Size: 16
# Size: 8
# All macro: 128
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 3649932.8
#
# Size: 16
# Size: 8
# All macro: 128
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 134995.2
#
# Size: 16
# Size: 8
# All macro: 128
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 118847.488
#
# Size: 16
# Size: 8
# All macro: 128
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 687194.76736
#
# Total Area for layer 34: 4590970.25536
#
# Total Macro for layer 34: 6588
#
# Total Area for all layers: 236291500.33056006
# Total Area for ADC across all layers: 187857478.8
# Processing layer: SRAM_dpt_large_128_layer_35
# Cycle: 577
#
# Total Cycle: 15706.0
# Size: 16
# Size: 8
# All macro: 128
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 3649932.8
#
# Size: 16
# Size: 8
# All macro: 128
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 134995.2
#
# Size: 16
# Size: 8
# All macro: 128
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 118847.488
#
# Size: 16
# Size: 8
# All macro: 128
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 687194.76736
#
# Total Area for layer 35: 4590970.25536
#
# Total Macro for layer 35: 6716
#
# Total Area for all layers: 240882470.58592007
# Total Area for ADC across all layers: 191507411.60000002
# Processing layer: SRAM_dpt_large_128_layer_36
# Cycle: 577
#
# Total Cycle: 16283.0
# Size: 16
# Size: 8
# All macro: 128
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 3649932.8
#
# Size: 16
# Size: 8
# All macro: 128
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 134995.2
#
# Size: 16
# Size: 8
# All macro: 128
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 118847.488
#
# Size: 16
# Size: 8
# All macro: 128
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 687194.76736
#
# Total Area for layer 36: 4590970.25536
#
# Total Macro for layer 36: 6844
#
# Total Area for all layers: 245473440.84128007
# Total Area for ADC across all layers: 195157344.40000004
# Processing layer: SRAM_dpt_large_128_layer_37
# Cycle: 16
#
# Total Cycle: 16299.0
# Size: 5
# All macro: 5
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 142575.5
#
# Size: 5
# All macro: 5
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 5273.25
#
# Size: 5
# All macro: 5
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 4642.48
#
# Size: 5
# All macro: 5
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 26843.5456
#
# Total Area for layer 37: 179334.77560000002
#
# Total Macro for layer 37: 6849
#
# Total Area for all layers: 245652775.61688006
# Total Area for ADC across all layers: 195299919.90000004
# Processing layer: SRAM_dpt_large_128_layer_38
# Cycle: 16
#
# Total Cycle: 16315.0
# Size: 10
# Size: 5
# All macro: 50
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 1425755.0
#
# Size: 10
# Size: 5
# All macro: 50
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 52732.50000000001
#
# Size: 10
# Size: 5
# All macro: 50
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 46424.799999999996
#
# Size: 10
# Size: 5
# All macro: 50
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 268435.456
#
# Total Area for layer 38: 1793347.756
#
# Total Macro for layer 38: 6899
#
# Total Area for all layers: 247446123.37288007
# Total Area for ADC across all layers: 196725674.90000004
# Processing layer: SRAM_dpt_large_128_layer_39
# Cycle: 577
#
# Total Cycle: 16892.0
# Size: 16
# Size: 8
# All macro: 128
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 3649932.8
#
# Size: 16
# Size: 8
# All macro: 128
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 134995.2
#
# Size: 16
# Size: 8
# All macro: 128
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 118847.488
#
# Size: 16
# Size: 8
# All macro: 128
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 687194.76736
#
# Total Area for layer 39: 4590970.25536
#
# Total Macro for layer 39: 7027
#
# Total Area for all layers: 252037093.62824008
# Total Area for ADC across all layers: 200375607.70000005
# Processing layer: SRAM_dpt_large_128_layer_40
# Cycle: 577
#
# Total Cycle: 17469.0
# Size: 64
# Size: 8
# All macro: 512
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 14599731.2
#
# Size: 64
# Size: 8
# All macro: 512
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 539980.8
#
# Size: 64
# Size: 8
# All macro: 512
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 475389.952
#
# Size: 64
# Size: 8
# All macro: 512
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 2748779.06944
#
# Total Area for layer 40: 18363881.02144
#
# Total Macro for layer 40: 7539
#
# Total Area for all layers: 270400974.6496801
# Total Area for ADC across all layers: 214975338.90000004
# Processing layer: SRAM_dpt_large_128_layer_41
# Cycle: 577
#
# Total Cycle: 18046.0
# Size: 16
# Size: 32
# All macro: 512
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 14599731.2
#
# Size: 16
# Size: 32
# All macro: 512
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 539980.8
#
# Size: 16
# Size: 32
# All macro: 512
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 475389.952
#
# Size: 16
# Size: 32
# All macro: 512
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 2748779.06944
#
# Total Area for layer 41: 18363881.02144
#
# Total Macro for layer 41: 8051
#
# Total Area for all layers: 288764855.67112005
# Total Area for ADC across all layers: 229575070.10000002
# Processing layer: SRAM_dpt_large_128_layer_42
# Cycle: 577
#
# Total Cycle: 18623.0
# Size: 16
# Size: 8
# All macro: 128
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 3649932.8
#
# Size: 16
# Size: 8
# All macro: 128
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 134995.2
#
# Size: 16
# Size: 8
# All macro: 128
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 118847.488
#
# Size: 16
# Size: 8
# All macro: 128
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 687194.76736
#
# Total Area for layer 42: 4590970.25536
#
# Total Macro for layer 42: 8179
#
# Total Area for all layers: 293355825.92648005
# Total Area for ADC across all layers: 233225002.90000004
# Processing layer: SRAM_dpt_large_128_layer_43
# Cycle: 577
#
# Total Cycle: 19200.0
# Size: 16
# Size: 8
# All macro: 128
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 3649932.8
#
# Size: 16
# Size: 8
# All macro: 128
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 134995.2
#
# Size: 16
# Size: 8
# All macro: 128
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 118847.488
#
# Size: 16
# Size: 8
# All macro: 128
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 687194.76736
#
# Total Area for layer 43: 4590970.25536
#
# Total Macro for layer 43: 8307
#
# Total Area for all layers: 297946796.18184006
# Total Area for ADC across all layers: 236874935.70000005
# Processing layer: SRAM_dpt_large_128_layer_44
# Cycle: 577
#
# Total Cycle: 19777.0
# Size: 16
# Size: 8
# All macro: 128
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 3649932.8
#
# Size: 16
# Size: 8
# All macro: 128
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 134995.2
#
# Size: 16
# Size: 8
# All macro: 128
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 118847.488
#
# Size: 16
# Size: 8
# All macro: 128
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 687194.76736
#
# Total Area for layer 44: 4590970.25536
#
# Total Macro for layer 44: 8435
#
# Total Area for all layers: 302537766.43720007
# Total Area for ADC across all layers: 240524868.50000006
# Processing layer: SRAM_dpt_large_128_layer_45
# Cycle: 16
#
# Total Cycle: 19793.0
# Size: 5
# All macro: 5
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 142575.5
#
# Size: 5
# All macro: 5
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 5273.25
#
# Size: 5
# All macro: 5
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 4642.48
#
# Size: 5
# All macro: 5
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 26843.5456
#
# Total Area for layer 45: 179334.77560000002
#
# Total Macro for layer 45: 8440
#
# Total Area for all layers: 302717101.2128001
# Total Area for ADC across all layers: 240667444.00000006
# Processing layer: SRAM_dpt_large_128_layer_46
# Cycle: 16
#
# Total Cycle: 19809.0
# Size: 10
# Size: 5
# All macro: 50
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 1425755.0
#
# Size: 10
# Size: 5
# All macro: 50
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 52732.50000000001
#
# Size: 10
# Size: 5
# All macro: 50
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 46424.799999999996
#
# Size: 10
# Size: 5
# All macro: 50
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 268435.456
#
# Total Area for layer 46: 1793347.756
#
# Total Macro for layer 46: 8490
#
# Total Area for all layers: 304510448.96880007
# Total Area for ADC across all layers: 242093199.00000006
# Processing layer: SRAM_dpt_large_128_layer_47
# Cycle: 577
#
# Total Cycle: 20386.0
# Size: 16
# Size: 8
# All macro: 128
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 3649932.8
#
# Size: 16
# Size: 8
# All macro: 128
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 134995.2
#
# Size: 16
# Size: 8
# All macro: 128
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 118847.488
#
# Size: 16
# Size: 8
# All macro: 128
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 687194.76736
#
# Total Area for layer 47: 4590970.25536
#
# Total Macro for layer 47: 8618
#
# Total Area for all layers: 309101419.2241601
# Total Area for ADC across all layers: 245743131.80000007
# Processing layer: SRAM_dpt_large_128_layer_48
# Cycle: 577
#
# Total Cycle: 20963.0
# Size: 64
# Size: 8
# All macro: 512
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 14599731.2
#
# Size: 64
# Size: 8
# All macro: 512
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 539980.8
#
# Size: 64
# Size: 8
# All macro: 512
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 475389.952
#
# Size: 64
# Size: 8
# All macro: 512
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 2748779.06944
#
# Total Area for layer 48: 18363881.02144
#
# Total Macro for layer 48: 9130
#
# Total Area for all layers: 327465300.2456001
# Total Area for ADC across all layers: 260342863.00000006
# Processing layer: SRAM_dpt_large_128_layer_49
# Cycle: 577
#
# Total Cycle: 21540.0
# Size: 16
# Size: 32
# All macro: 512
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 14599731.2
#
# Size: 16
# Size: 32
# All macro: 512
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 539980.8
#
# Size: 16
# Size: 32
# All macro: 512
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 475389.952
#
# Size: 16
# Size: 32
# All macro: 512
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 2748779.06944
#
# Total Area for layer 49: 18363881.02144
#
# Total Macro for layer 49: 9642
#
# Total Area for all layers: 345829181.26704013
# Total Area for ADC across all layers: 274942594.20000005
# Processing layer: SRAM_dpt_large_128_layer_50
# Cycle: 577
#
# Total Cycle: 22117.0
# Size: 16
# Size: 8
# All macro: 128
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 3649932.8
#
# Size: 16
# Size: 8
# All macro: 128
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 134995.2
#
# Size: 16
# Size: 8
# All macro: 128
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 118847.488
#
# Size: 16
# Size: 8
# All macro: 128
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 687194.76736
#
# Total Area for layer 50: 4590970.25536
#
# Total Macro for layer 50: 9770
#
# Total Area for all layers: 350420151.52240014
# Total Area for ADC across all layers: 278592527.00000006
# Processing layer: SRAM_dpt_large_128_layer_51
# Cycle: 577
#
# Total Cycle: 22694.0
# Size: 16
# Size: 8
# All macro: 128
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 3649932.8
#
# Size: 16
# Size: 8
# All macro: 128
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 134995.2
#
# Size: 16
# Size: 8
# All macro: 128
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 118847.488
#
# Size: 16
# Size: 8
# All macro: 128
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 687194.76736
#
# Total Area for layer 51: 4590970.25536
#
# Total Macro for layer 51: 9898
#
# Total Area for all layers: 355011121.77776015
# Total Area for ADC across all layers: 282242459.8000001
# Processing layer: SRAM_dpt_large_128_layer_52
# Cycle: 577
#
# Total Cycle: 23271.0
# Size: 16
# Size: 8
# All macro: 128
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 3649932.8
#
# Size: 16
# Size: 8
# All macro: 128
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 134995.2
#
# Size: 16
# Size: 8
# All macro: 128
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 118847.488
#
# Size: 16
# Size: 8
# All macro: 128
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 687194.76736
#
# Total Area for layer 52: 4590970.25536
#
# Total Macro for layer 52: 10026
#
# Total Area for all layers: 359602092.03312016
# Total Area for ADC across all layers: 285892392.6000001
# Processing layer: SRAM_dpt_large_128_layer_53
# Cycle: 16
#
# Total Cycle: 23287.0
# Size: 5
# All macro: 5
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 142575.5
#
# Size: 5
# All macro: 5
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 5273.25
#
# Size: 5
# All macro: 5
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 4642.48
#
# Size: 5
# All macro: 5
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 26843.5456
#
# Total Area for layer 53: 179334.77560000002
#
# Total Macro for layer 53: 10031
#
# Total Area for all layers: 359781426.8087202
# Total Area for ADC across all layers: 286034968.1000001
# Processing layer: SRAM_dpt_large_128_layer_54
# Cycle: 16
#
# Total Cycle: 23303.0
# Size: 10
# Size: 5
# All macro: 50
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 1425755.0
#
# Size: 10
# Size: 5
# All macro: 50
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 52732.50000000001
#
# Size: 10
# Size: 5
# All macro: 50
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 46424.799999999996
#
# Size: 10
# Size: 5
# All macro: 50
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 268435.456
#
# Total Area for layer 54: 1793347.756
#
# Total Macro for layer 54: 10081
#
# Total Area for all layers: 361574774.56472015
# Total Area for ADC across all layers: 287460723.1000001
# Processing layer: SRAM_dpt_large_128_layer_55
# Cycle: 577
#
# Total Cycle: 23880.0
# Size: 16
# Size: 8
# All macro: 128
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 3649932.8
#
# Size: 16
# Size: 8
# All macro: 128
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 134995.2
#
# Size: 16
# Size: 8
# All macro: 128
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 118847.488
#
# Size: 16
# Size: 8
# All macro: 128
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 687194.76736
#
# Total Area for layer 55: 4590970.25536
#
# Total Macro for layer 55: 10209
#
# Total Area for all layers: 366165744.82008016
# Total Area for ADC across all layers: 291110655.9000001
# Processing layer: SRAM_dpt_large_128_layer_56
# Cycle: 577
#
# Total Cycle: 24457.0
# Size: 64
# Size: 8
# All macro: 512
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 14599731.2
#
# Size: 64
# Size: 8
# All macro: 512
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 539980.8
#
# Size: 64
# Size: 8
# All macro: 512
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 475389.952
#
# Size: 64
# Size: 8
# All macro: 512
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 2748779.06944
#
# Total Area for layer 56: 18363881.02144
#
# Total Macro for layer 56: 10721
#
# Total Area for all layers: 384529625.8415202
# Total Area for ADC across all layers: 305710387.1000001
# Processing layer: SRAM_dpt_large_128_layer_57
# Cycle: 577
#
# Total Cycle: 25034.0
# Size: 16
# Size: 32
# All macro: 512
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 14599731.2
#
# Size: 16
# Size: 32
# All macro: 512
# column drivers area: 1054.65, number of column_drivers: 4096,
# ...
#
# Total Area for all layers: 1030567461.6239997
# Total Area for ADC across all layers: 977478030.0000007
# Processing layer: RRAM_gpt2_medium_128_layer_128
# Cycle: 256
#
# Total Cycle: 22688.0
# Size: 16
# Size: 8
# All macro: 128
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 3808742.4
#
# Size: 16
# Size: 8
# All macro: 128
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 56449.664
#
# Size: 16
# Size: 8
# All macro: 128
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 64513.92
#
# Size: 16
# Size: 8
# All macro: 128
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 85899.34592
#
# Total Area for layer 128: 4015605.32992
#
# Total Macro for layer 128: 32978
#
# Total Area for all layers: 1034583066.9539198
# Total Area for ADC across all layers: 981286772.4000007
# Processing layer: RRAM_gpt2_medium_128_layer_129
# Cycle: 16
#
# Total Cycle: 22704.0
# Size: 2
# All macro: 2
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 59511.6
#
# Size: 2
# All macro: 2
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 882.026
#
# Size: 2
# All macro: 2
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 1008.03
#
# Size: 2
# All macro: 2
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 1342.17728
#
# Total Area for layer 129: 62743.83328
#
# Total Macro for layer 129: 32980
#
# Total Area for all layers: 1034645810.7871997
# Total Area for ADC across all layers: 981346284.0000007
# Processing layer: RRAM_gpt2_medium_128_layer_130
# Cycle: 16
#
# Total Cycle: 22720.0
# Size: 4
# Size: 2
# All macro: 8
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 238046.4
#
# Size: 4
# Size: 2
# All macro: 8
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 3528.104
#
# Size: 4
# Size: 2
# All macro: 8
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 4032.12
#
# Size: 4
# Size: 2
# All macro: 8
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 5368.70912
#
# Total Area for layer 130: 250975.33312
#
# Total Macro for layer 130: 32988
#
# Total Area for all layers: 1034896786.1203197
# Total Area for ADC across all layers: 981584330.4000007
# Processing layer: RRAM_gpt2_medium_128_layer_131
# Cycle: 256
#
# Total Cycle: 22976.0
# Size: 64
# Size: 8
# All macro: 512
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 15234969.6
#
# Size: 64
# Size: 8
# All macro: 512
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 225798.656
#
# Size: 64
# Size: 8
# All macro: 512
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 258055.68
#
# Size: 64
# Size: 8
# All macro: 512
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 343597.38368
#
# Total Area for layer 131: 16062421.31968
#
# Total Macro for layer 131: 33500
#
# Total Area for all layers: 1050959207.4399997
# Total Area for ADC across all layers: 996819300.0000007
# Processing layer: RRAM_gpt2_medium_128_layer_132
# Cycle: 256
#
# Total Cycle: 23232.0
# Size: 16
# Size: 32
# All macro: 512
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 15234969.6
#
# Size: 16
# Size: 32
# All macro: 512
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 225798.656
#
# Size: 16
# Size: 32
# All macro: 512
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 258055.68
#
# Size: 16
# Size: 32
# All macro: 512
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 343597.38368
#
# Total Area for layer 132: 16062421.31968
#
# Total Macro for layer 132: 34012
#
# Total Area for all layers: 1067021628.7596797
# Total Area for ADC across all layers: 1012054269.6000007
# Processing layer: RRAM_gpt2_medium_128_layer_133
# Cycle: 256
#
# Total Cycle: 23488.0
# Size: 48
# Size: 8
# All macro: 384
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 11426227.2
#
# Size: 48
# Size: 8
# All macro: 384
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 169348.992
#
# Size: 48
# Size: 8
# All macro: 384
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 193541.76
#
# Size: 48
# Size: 8
# All macro: 384
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 257698.03776000004
#
# Total Area for layer 133: 12046815.98976
#
# Total Macro for layer 133: 34396
#
# Total Area for all layers: 1079068444.7494397
# Total Area for ADC across all layers: 1023480496.8000008
# Processing layer: RRAM_gpt2_medium_128_layer_134
# Cycle: 256
#
# Total Cycle: 23744.0
# Size: 16
# Size: 8
# All macro: 128
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 3808742.4
#
# Size: 16
# Size: 8
# All macro: 128
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 56449.664
#
# Size: 16
# Size: 8
# All macro: 128
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 64513.92
#
# Size: 16
# Size: 8
# All macro: 128
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 85899.34592
#
# Total Area for layer 134: 4015605.32992
#
# Total Macro for layer 134: 34524
#
# Total Area for all layers: 1083084050.0793598
# Total Area for ADC across all layers: 1027289239.2000008
# Processing layer: RRAM_gpt2_medium_128_layer_135
# Cycle: 16
#
# Total Cycle: 23760.0
# Size: 2
# All macro: 2
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 59511.6
#
# Size: 2
# All macro: 2
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 882.026
#
# Size: 2
# All macro: 2
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 1008.03
#
# Size: 2
# All macro: 2
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 1342.17728
#
# Total Area for layer 135: 62743.83328
#
# Total Macro for layer 135: 34526
#
# Total Area for all layers: 1083146793.9126399
# Total Area for ADC across all layers: 1027348750.8000008
# Processing layer: RRAM_gpt2_medium_128_layer_136
# Cycle: 16
#
# Total Cycle: 23776.0
# Size: 4
# Size: 2
# All macro: 8
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 238046.4
#
# Size: 4
# Size: 2
# All macro: 8
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 3528.104
#
# Size: 4
# Size: 2
# All macro: 8
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 4032.12
#
# Size: 4
# Size: 2
# All macro: 8
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 5368.70912
#
# Total Area for layer 136: 250975.33312
#
# Total Macro for layer 136: 34534
#
# Total Area for all layers: 1083397769.24576
# Total Area for ADC across all layers: 1027586797.2000008
# Processing layer: RRAM_gpt2_medium_128_layer_137
# Cycle: 256
#
# Total Cycle: 24032.0
# Size: 64
# Size: 8
# All macro: 512
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 15234969.6
#
# Size: 64
# Size: 8
# All macro: 512
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 225798.656
#
# Size: 64
# Size: 8
# All macro: 512
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 258055.68
#
# Size: 64
# Size: 8
# All macro: 512
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 343597.38368
#
# Total Area for layer 137: 16062421.31968
#
# Total Macro for layer 137: 35046
#
# Total Area for all layers: 1099460190.56544
# Total Area for ADC across all layers: 1042821766.8000008
# Processing layer: RRAM_gpt2_medium_128_layer_138
# Cycle: 256
#
# Total Cycle: 24288.0
# Size: 16
# Size: 32
# All macro: 512
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 15234969.6
#
# Size: 16
# Size: 32
# All macro: 512
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 225798.656
#
# Size: 16
# Size: 32
# All macro: 512
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 258055.68
#
# Size: 16
# Size: 32
# All macro: 512
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 343597.38368
#
# Total Area for layer 138: 16062421.31968
#
# Total Macro for layer 138: 35558
#
# Total Area for all layers: 1115522611.88512
# Total Area for ADC across all layers: 1058056736.4000008
# Processing layer: RRAM_gpt2_medium_128_layer_139
# Cycle: 256
#
# Total Cycle: 24544.0
# Size: 48
# Size: 8
# All macro: 384
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 11426227.2
#
# Size: 48
# Size: 8
# All macro: 384
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 169348.992
#
# Size: 48
# Size: 8
# All macro: 384
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 193541.76
#
# Size: 48
# Size: 8
# All macro: 384
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 257698.03776000004
#
# Total Area for layer 139: 12046815.98976
#
# Total Macro for layer 139: 35942
#
# Total Area for all layers: 1127569427.8748798
# Total Area for ADC across all layers: 1069482963.6000009
# Processing layer: RRAM_gpt2_medium_128_layer_140
# Cycle: 256
#
# Total Cycle: 24800.0
# Size: 16
# Size: 8
# All macro: 128
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 3808742.4
#
# Size: 16
# Size: 8
# All macro: 128
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 56449.664
#
# Size: 16
# Size: 8
# All macro: 128
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 64513.92
#
# Size: 16
# Size: 8
# All macro: 128
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 85899.34592
#
# Total Area for layer 140: 4015605.32992
#
# Total Macro for layer 140: 36070
#
# Total Area for all layers: 1131585033.2048
# Total Area for ADC across all layers: 1073291706.0000008
# Processing layer: RRAM_gpt2_medium_128_layer_141
# Cycle: 16
#
# Total Cycle: 24816.0
# Size: 2
# All macro: 2
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 59511.6
#
# Size: 2
# All macro: 2
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 882.026
#
# Size: 2
# All macro: 2
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 1008.03
#
# Size: 2
# All macro: 2
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 1342.17728
#
# Total Area for layer 141: 62743.83328
#
# Total Macro for layer 141: 36072
#
# Total Area for all layers: 1131647777.03808
# Total Area for ADC across all layers: 1073351217.6000009
# Processing layer: RRAM_gpt2_medium_128_layer_142
# Cycle: 16
#
# Total Cycle: 24832.0
# Size: 4
# Size: 2
# All macro: 8
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 238046.4
#
# Size: 4
# Size: 2
# All macro: 8
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 3528.104
#
# Size: 4
# Size: 2
# All macro: 8
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 4032.12
#
# Size: 4
# Size: 2
# All macro: 8
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 5368.70912
#
# Total Area for layer 142: 250975.33312
#
# Total Macro for layer 142: 36080
#
# Total Area for all layers: 1131898752.3712
# Total Area for ADC across all layers: 1073589264.0000008
# Processing layer: RRAM_gpt2_medium_128_layer_143
# Cycle: 256
#
# Total Cycle: 25088.0
# Size: 64
# Size: 8
# All macro: 512
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 15234969.6
#
# Size: 64
# Size: 8
# All macro: 512
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 225798.656
#
# Size: 64
# Size: 8
# All macro: 512
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 258055.68
#
# Size: 64
# Size: 8
# All macro: 512
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 343597.38368
#
# Total Area for layer 143: 16062421.31968
#
# Total Macro for layer 143: 36592
#
# Total Area for all layers: 1147961173.69088
# Total Area for ADC across all layers: 1088824233.6000009
# Processing layer: RRAM_gpt2_medium_128_layer_144
# Cycle: 256
#
# Total Cycle: 25344.0
# Size: 16
# Size: 32
# All macro: 512
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 15234969.6
#
# Size: 16
# Size: 32
# All macro: 512
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 225798.656
#
# Size: 16
# Size: 32
# All macro: 512
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 258055.68
#
# Size: 16
# Size: 32
# All macro: 512
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 343597.38368
#
# Total Area for layer 144: 16062421.31968
#
# Total Macro for layer 144: 37104
#
# Total Area for all layers: 1164023595.01056
# Total Area for ADC across all layers: 1104059203.2000008
# Processing layer: RRAM_gpt2_medium_128_layer_145
# Cycle: 512
#
# Total Cycle: 25856.0
# Size: 786
# Size: 4
# All macro: 3144
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 93552235.2
#
# Size: 786
# Size: 4
# All macro: 3144
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 1386544.872
#
# Size: 786
# Size: 4
# All macro: 3144
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 1584623.16
#
# Size: 786
# Size: 4
# All macro: 3144
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 2109902.68416
#
# Total Area for layer 145: 98633305.91615999
#
# Total Macro for layer 145: 40248
#
# Total Area for all layers: 1262656900.9267201
# Total Area for ADC across all layers: 1197611438.4000008
# Total Area for column drivers across all layers: 17749891.224000014
# Total Area for row drivers across all layers: 20285595.719999984
# Total Area for cim unit across all layers: 27009975.582720064
#
#
# Total Area for ADC across all layers: 1197.6114384000007
# Total Area for column driver across all layers: 17.749891224000013
# Total Area for row driver across all layers: 20.285595719999982
# Total Area for cim unit across all layers: 27.009975582720063
# Total Macro across all layers: 40248
# RRAM_gpt2_medium_128 	 3.16e-03 	 1262.66 	 3.87e+02

# %%
print("\n### Area and Performance Results ###\n")

for i, dnn in enumerate(dnn_list):
    print(f"Results for {dnn} (SRAM):")
    print(f"  Total Area: {total_area[2 * i]}")
    print(f"  ADC Area: {total_adc_area[2 * i]}")
    print(f"  Column Driver Area: {total_col_area[2 * i]}")
    print(f"  Row Driver Area: {total_row_area[2 * i]}")
    print(f"  CIM Unit Area: {total_cim_unit_area[2 * i]}")
    print(f"  Total Macro: {total_macro[2 * i]}")
    print(f"  Energy: {energy[2 * i]}")
    print(f"  Throughput: {throughput[2 * i]}\n")

    print(f"Results for {dnn} (RRAM):")
    print(f"  Total Area: {total_area[2 * i + 1]}")
    print(f"  ADC Area: {total_adc_area[2 * i + 1]}")
    print(f"  Column Driver Area: {total_col_area[2 * i + 1]}")
    print(f"  Row Driver Area: {total_row_area[2 * i + 1]}")
    print(f"  CIM Unit Area: {total_cim_unit_area[2 * i + 1]}")
    print(f"  Total Macro: {total_macro[2 * i + 1]}")
    print(f"  Energy: {energy[2 * i + 1]}")
    print(f"  Throughput: {throughput[2 * i + 1]}\n")
# Out:
# ### Area and Performance Results ###
#
# Results for dpt_large (SRAM):
#   Total Area: 1030.6010884180812
#   ADC Area: 819.3528833999995
#   Column Driver Area: 30.30431309999998
#   Row Driver Area: 26.67940406400004
#   CIM Unit Area: 154.26448785408022
#   Total Macro: 28734
#   Energy: 0.006946794100000004
#   Throughput: 18.838351870271573
#
# Results for dpt_large (RRAM):
#   Total Area: 901.4406527337605
#   ADC Area: 855.0031571999996
#   Column Driver Area: 12.672067542000015
#   Row Driver Area: 14.482367009999985
#   CIM Unit Area: 19.283060981760027
#   Total Macro: 28734
#   Energy: 0.008378306799999994
#   Throughput: 18.838351870271573
#
# Results for gpt2_medium (SRAM):
#   Total Area: 1443.5732096697602
#   ADC Area: 1147.6757448
#   Column Driver Area: 42.447553200000016
#   Row Driver Area: 37.37010700799999
#   CIM Unit Area: 216.0798046617605
#   Total Macro: 40248
#   Energy: 0.0026079909
#   Throughput: 386.75742574257424
#
# Results for gpt2_medium (RRAM):
#   Total Area: 1262.65690092672
#   ADC Area: 1197.6114384000007
#   Column Driver Area: 17.749891224000013
#   Row Driver Area: 20.285595719999982
#   CIM Unit Area: 27.009975582720063
#   Total Macro: 40248
#   Energy: 0.0031604893099999995
#   Throughput: 386.75742574257424

# %%
import matplotlib.pyplot as plt
import numpy as np

sram_label = "SRAM"
rram_label = "RRAM"

x = np.arange(len(dnn_list))  # Number of DNNs
width = 0.35  # Bar width

# Create figure and axes for three different plots (energy, area, throughput)
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(18, 6))

# Energy Plot
ax1.bar(x - width/2, energy[::2], width, label=sram_label, color='tab:blue')  # SRAM for DNN1, DNN2
ax1.bar(x + width/2, energy[1::2], width, label=rram_label, color='tab:red')  # RRAM for DNN1, DNN2
ax1.set_title("Energy Consumption")
ax1.set_xticks(x)
ax1.set_xticklabels(dnn_list)
ax1.set_xlabel("DNN models")
ax1.set_ylabel("Energy")
ax1.legend()

# Area Plot
ax2.bar(x - width/2, total_area[::2], width, label=sram_label, color='tab:blue')  # SRAM for DNN1, DNN2
ax2.bar(x + width/2, total_area[1::2], width, label=rram_label, color='tab:red')  # RRAM for DNN1, DNN2
ax2.set_title("Area")
ax2.set_xticks(x)
ax2.set_xticklabels(dnn_list)
ax2.set_xlabel("DNN models")
ax2.set_ylabel("Area")
ax2.legend()

# Throughput Plot
ax3.bar(x - width/2, throughput[::2], width, label=sram_label, color='tab:blue')  # SRAM for DNN1, DNN2
ax3.bar(x + width/2, throughput[1::2], width, label=rram_label, color='tab:red')  # RRAM for DNN1, DNN2
ax3.set_title("Throughput")
ax3.set_xticks(x)
ax3.set_xticklabels(dnn_list)
ax3.set_xlabel("DNN models")
ax3.set_ylabel("Throughput")
ax3.legend()

# Adjust layout for better spacing
plt.tight_layout()
plt.show()

# %%
display_markdown(
    """
### Calculating the energy

"""
)

path_list = [SRAM_PATH, RRAM_PATH]  # List of paths
num_dnns = len(dnn_list)  # Get the number of DNN models
num_paths = len(path_list)  # Get the number of paths
num_cases = num_dnns * num_paths  # Total number of cases

# Initialize energy lists dynamically based on the number of cases
total_adc_energy = [0] * (2 * num_dnns)
total_col_energy = [0] * (2 * num_dnns)
total_row_energy = [0] * (2 * num_dnns)
total_cim_unit_energy = [0] * (2 * num_dnns)

# Iterate through all cases dynamically based on `j`
for j in range(2 * num_dnns):  # Now `j` will be 2 * number of DNN models
    # For each DNN model, calculate energy based on the path
    dnn_idx = j // 2  # Determine which DNN model (0 or 1, 2, etc.)
    path_idx = j % 2  # Determine which path (0 for SRAM, 1 for RRAM)

    # Now iterate through each energy category (ADC, Column, Row, CIM Unit)
    for i in range(4):  # Since there are 4 categories (ADC, Column, Row, CIM Unit)
        energy_value = total_per_energy[(dnn_list[dnn_idx], path_list[path_idx])][i] * energy[j]

        if i == 0:
            total_adc_energy[j] = energy_value
        elif i == 1:
            total_col_energy[j] = energy_value
        elif i == 2:
            total_row_energy[j] = energy_value
        else:
            total_cim_unit_energy[j] = energy_value

# Print the results for total energies
print("Total ADC Energy:", total_adc_energy)
print("Total Column Energy:", total_col_energy)
print("Total Row Energy:", total_row_energy)
print("Total CIM Unit Energy:", total_cim_unit_energy)
# Out:
# ### Calculating the energy
# Total ADC Energy: [0.0033676504378443756, 0.0038514140169665792, 0.0012909259690017936, 0.0014864819475380838]
# Total Column Energy: [2.042085903799242e-05, 9.681862313510116e-15, 7.827955343947094e-06, 3.736786926580325e-15]
# Total Row Energy: [0.003546780780288403, 0.003045579699576247, 0.0013046592239911324, 0.0011297262801288818]
# Total CIM Unit Energy: [1.1942022829232366e-05, 0.001481313083447486, 4.577751663126932e-06, 0.0005442810823292969]

# %%
import matplotlib.pyplot as plt
import numpy as np
fig, ax = plt.subplots(figsize=(10, 6)) 
path = ['SRAM', 'RRAM']
num_bars = len(dnn_list) * len(path)

x = np.arange(num_bars)

# Stack bars
ax.bar(x, total_cim_unit_energy, label='cim_unit')
ax.bar(x, total_row_energy, bottom=total_cim_unit_energy, label='row_drivers')
ax.bar(x, total_col_energy, bottom=np.array(total_cim_unit_energy) + np.array(total_row_energy), label='column_drivers')
ax.bar(x, total_adc_energy, bottom=np.array(total_cim_unit_energy) + np.array(total_row_energy) + np.array(total_col_energy), label='adc')

# Labels and title
ax.set_title(f"Energy vs Memory Type for {DNN} in fast scenario")
ax.set_xlabel("Memory type")
ax.set_ylabel("Energy (J)")
# Set x-ticks
xtick_labels = [f"{mem}-{dnn}" for dnn in dnn_list for mem in path]
ax.set_xticks(x)
ax.set_xticklabels(xtick_labels)

ax.legend()

# Show plot
plt.show()
