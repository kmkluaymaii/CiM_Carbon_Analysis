# %%
from _import_scripts import scripts
from scripts.notebook_utils import *
from scripts.tl_output_parsing import MacroOutputStats
from scripts.utils import *
import yaml

MACRO_PATH = "../models/arch/1_macro/basic_analog/" 
macro = {}
total_per_energy = {}
SRAM_PATH = f'"{os.path.abspath("../models/memory_cells/sram_example.cell.yaml")}"'
RRAM_PATH = f'"{os.path.abspath("../models/memory_cells/rram_example.cell.yaml")}"'

dnn_layers = {
    "alexnet": 9,
    "vgg16": 17,
    "dpt_large": 228,
    "gpt2_medium": 146,
    "mobilebert": 410,
    "vision_transformer": 99,
    "resnet-50": 54,
    "bert-large": 193,
    "efficientnetb-7": 274
}

# Define the architecture
array_sizes = 128
path_list = [SRAM_PATH, RRAM_PATH]
tech_node = 32
time = "fast"

dnn_list = ["vgg16", "gpt2_medium"]
for DNN in dnn_list:
    dnn_layer = dnn_layers.get(DNN, None)
    def create_layer_directory(base_output_dir: str, architecture: str, layer: int) -> str:
        layer_dir = os.path.join(base_output_dir, f"{architecture}_layer_{layer}")
        if not os.path.exists(layer_dir):
            os.makedirs(layer_dir)
        return layer_dir

    num_layers = 1

    def run_map(
        spec: tl.Specification,
        arch: str,
        accelergy_verbose: bool = False,
    ) -> dict:
        output_dir = get_run_dir()
        # Just use the directory name if it causes error
        base_output_dir = os.path.dirname(output_dir)
        base_output_dir = os.path.join(base_output_dir, arch)
        global num_layers

        mapper_result = None

        if num_layers < dnn_layer:
            # Create a directory for the current layer
            layer_dir = create_layer_directory(base_output_dir, arch, num_layers)
            # print(f"Layer directory: {layer_dir}")
            num_layers += 1

            run_prefix = f"{layer_dir}/timeloop-mapper"
            mapper_result = tl.call_mapper(
                specification=spec,
                output_dir=layer_dir,
                log_to=os.path.join(output_dir, f"{run_prefix}.log"),
            )
            if accelergy_verbose:
                tl.call_accelergy_verbose(
                    specification=spec,
                    output_dir=layer_dir,
                    log_to=os.path.join(output_dir, "accelergy.log"),
                )

        if mapper_result is None:
            # Handle case when mapper_result is not assigned (num_layers >= 17)
            # Raise an error, return a default value
            print("Warning: mapper_result is not assigned. num_layers >= 17")
            return {}

        return MacroOutputStats.from_output_stats(mapper_result)

    import re

    def extract_range(line):
        match = re.search(r'\[(\d+):(\d+)(,\d+)?\)', line)
        if match:
            start = int(match.group(1))
            end = int(match.group(2))
            return end - start
        return None

    def read_and_compute_multiplication(filename, i):
        filename = f"../outputs/{filename}/{filename}_layer_{i+1}/timeloop-mapper.map.txt"
        with open(filename, 'r') as file:
            lines = file.readlines()

        start_searching = False
        ranges = []

        for line in lines:
            # Start searching when 'inter_macro_in_system_spatial' is found
            if "inter_macro_in_system_spatial" in line:
                start_searching = True
            
            # Stop searching if we leave the 'inter_macro_in_system_spatial' section
            elif start_searching and "inter_" in line and "inter_macro_in_system_spatial" not in line:
                break

            # If we are in the 'inter_macro_in_system_spatial' section, look for the ranges
            if start_searching:
                if "for" in line:
                    range_size = extract_range(line)
                    if range_size is not None:
                        ranges.append(range_size)
                elif line.strip() == "":  # Exit the section on an empty line
                    break

        # Compute the multiplication of all ranges, or return 1 if no ranges were found
        if not ranges:
            print(f"All macro: 1")
            return 1

        result = 1
        for size in ranges:
            result *= size
            print(f"Size: {size}")
        print(f"All macro: {result}")
        return result


    def extract_layer_number(folder_name):
        match = re.search(r'layer_(\d+)', folder_name)
        return int(match.group(1)) if match else float('inf')

    def extract_outputs(model):
        
        output_dir = "../outputs/" + model + "/" 
        print(output_dir)

        print ("Model \t Energy/inference (J) \t Area (mm2) \t Throughput (inf/s)")
        #for model in models:    
        throughput = 0   
        energy = 0
        area = 0
        cycles = 0
        folders = sorted([folder for folder in os.listdir(output_dir) if model in folder], key=extract_layer_number)
        area_per_many_macro = 0
        area_layer = 0
        j = 0
        total_sum = 0
        total_adc_area = 0  # Total area for ADC across all layers
        total_other_areas = {}  # Dictionary to store total areas for other components
        total_col_area = 0
        total_row_area = 0
        total_cim_unit_area = 0
        total_area = 0
        total_macro = 0
        
        for folder in folders:
            total = 0
            if model in folder:
                print(f"Processing layer: {folder}")
                # print(folder)
                if os.path.isdir(output_dir + folder):
                    stat_file = output_dir + folder + "/timeloop-mapper.stats.txt"
                    art_file = output_dir + folder + "/timeloop-mapper.ART.yaml"
            
                    with open(stat_file, 'r') as f:
                        energy_stat = [line for line in f if line.startswith("Energy:")][0]
                        energy_uj = energy_stat.split(' ')[1] # uJ
                        energy += float(energy_uj)
                        # print(f"Energy for this layer: {float(energy_uj)} uj")
                    
                    with open(stat_file, 'r') as f:
                        cycle_stat = [line for line in f if line.startswith("Cycles:")][0]                  
                        cycle = cycle_stat.split(' ')[1] 
                        cycles += float(cycle)
                        
                if j < 16:
                    with open(art_file, 'r') as file:
                        data = yaml.safe_load(file)
                    
                        # Extract and print the name, area, number of entries, and ratio for non-zero areas
                    for table in data['ART']['tables']:
                        name = table.get('name')
                        area = table.get('area')
                        if area != 0:
                            # Simplify the name for the output
                            if 'system_top_level.' in name:
                                name = name.split('system_top_level.')[-1]
                            
                            # Extract the number of entries from the name
                            if '[' in name:
                                name_part, entries_part = name.split('[')
                                number_of_entries = entries_part.split('..')[1].replace(']', '')
                                name = name_part.strip()
                            else:
                                number_of_entries = 'Unknown'
                            
                            macro = read_and_compute_multiplication(model, j)
                            # Calculate total ratio
                            if number_of_entries != 'Unknown' and number_of_entries.isdigit():
                                total_ratio = (area / 4096) * macro * int(number_of_entries)
                            else:
                                total_ratio = 0
                            
                            total += total_ratio
                            
                            # Accumulate area for ADC or other components
                            if 'adc' in name.lower():
                                total_adc_area += total_ratio
                            else:
                                if name not in total_other_areas:
                                    total_other_areas[name] = 0
                                total_other_areas[name] += total_ratio
                
                            print(f"{name.replace('_', ' ')} area: {area}, number of {name}: {number_of_entries}, \ntotal {name.replace('_', ' ')} area: ({area}*{number_of_entries}/4096) * macro = {total_ratio}\n")
                    j += 1 
                    total_sum += total
                    total_macro += macro
                    print(f"Total Area for layer {j}: {total}\n")
                    print(f"Total Macro for layer {j}: {total_macro}\n")
                print(f"Total Area for all layers: {total_sum}")
                print(f"Total Area for ADC across all layers: {total_adc_area}")
        
        # Print total area for other components
        for component, area in total_other_areas.items():
            print(f"Total Area for {component.replace('_', ' ')} across all layers: {area}")
            # print(component.replace('_', ' '))
            if component.replace('_', ' ') ==  "column drivers":
                total_col_area = area
            elif component.replace('_', ' ') ==  "row drivers":
                total_row_area = area
            else:
                total_cim_unit_area = area
                                    
        energy *= 1e-6 # conver to J
        total_area = total_sum * 1e-6 # mm2
        throughput = 1 / (cycles * 1e-7) # s

        total_adc_area = total_adc_area * 1e-6 # mm2
        total_col_area = total_col_area * 1e-6 # mm2
        total_row_area = total_row_area * 1e-6 # mm2
        total_cim_unit_area = total_cim_unit_area * 1e-6 # mm2
        print("\n")
        print(f"Total Area for ADC across all layers: {total_adc_area}")
        print(f"Total Area for column driver across all layers: {total_col_area}")
        print(f"Total Area for row driver across all layers: {total_row_area}")
        print(f"Total Area for cim unit across all layers: {total_cim_unit_area}")
        print(f"Total Macro across all layers: {total_macro}")
        print ("{} \t {:.2e} \t {:.2f} \t {:.2e}".format(model, energy, total_area, throughput))
        
        return total_area, total_adc_area, total_col_area, total_row_area, total_cim_unit_area, total_macro, energy, throughput

    
##----------------------------------------- Running DNN -------------------------------------------

    for path in path_list:
        arch = f"{path.split('/')[-1].split('_')[0].upper()}_{DNN}_{array_sizes}"
        print(f"\nRunning {DNN} with {array_sizes} x {array_sizes} {path.split('/')[-1].split('_')[0].upper()} with {tech_node} nm in {time} scenario")

        num_layers = 1

        def run_dnn(dnn: str, layer: str, array_sizes: int, variables):
            print(f"{layer} ", end="", flush=True)
            spec = get_spec(
                "basic_analog",
                # Weight-stationary, dummy buffer on top to hold inputs & outputs, many
                # macros to ensure we can fit all weights.
                system="ws_dummy_buffer_many_macro",
                # Set the DNN and layer
                dnn=dnn,
                layer=layer,
            )
        
            # Do NOT generate a maximum-utilization workload; we're running a DNN
            # workload.
            spec.variables["MAX_UTILIZATION"] = False
        
            # Use a larger array to ensure we can fit all weights
            spec.architecture.find("column").spatial.meshX = array_sizes
            spec.architecture.find("row").spatial.meshY = array_sizes
        
            spec.variables.update(variables)
            output_stats = run_map(spec, arch)
            
            # Print computes for the layer
            macro_output_stats = MacroOutputStats.from_output_stats(output_stats)
            print(f"Computes for layer {int(layer) + 1}: {macro_output_stats.computes}")
            global macro
            macro[layer] = macro_output_stats.computes
            return output_stats
        
        layers = [f for f in os.listdir(f"../models/workloads/{DNN}") if f != "index.yaml" and f.endswith(".yaml")]
        layers = sorted(layers)
        print(f"Running: ", end="")
        
        # Parallel/Delayed is used to multiprocess. Equivalent to running the following
        # code in serial:
        results = joblib.Parallel(n_jobs=None)(
            joblib.delayed(run_dnn)(DNN, layer.split(".")[0], array_sizes, 
                                    {
                                        "CELL_CONFIG": path,
                                        "BITS_PER_CELL": 1 if path == SRAM_PATH else 4,
                                        "CIM_UNIT_WIDTH_CELLS": 4 if path == SRAM_PATH else 1,
                                        "IS_SRAM": path == SRAM_PATH,
                                        "TECHNOLOGY": tech_node,
                                        "ADC_RESOLUTION": 4 if path == SRAM_PATH else 6,
                                        "GLOBAL_CYCLE_SECONDS": 1e-7 if time == "fast" else 1e-4,
                                    }
                                    ) for layer in layers
        )
        print("")
        for r in results:
            r.clear_zero_energies()
        
        #Initialize overall_energy
        energy_layer = [0] * 16
        result = 0
        
        total_adc_energy = 0.0
        total_col_energy = 0.0
        total_row_energy = 0.0
        total_cim_unit_energy = 0.0
        # Calculate overall energy
        for r in results:
        
            per_component_energy = r.per_compute("per_component_energy")
            total_energy_per_layer = sum(per_component_energy.values()) * 1e15  # Convert to fJ
            total_adc_energy += per_component_energy.get('adc', 0.0)
            total_col_energy += per_component_energy.get('column_drivers', 0.0)
            total_row_energy += per_component_energy.get('row_drivers', 0.0)
            total_cim_unit_energy += per_component_energy.get('cim_unit', 0.0)
        
            total_adc_energy = total_adc_energy * 1e15
            total_col_energy = total_col_energy * 1e15
            total_row_energy = total_row_energy * 1e15
            total_cim_unit_energy = total_cim_unit_energy * 1e15
            total_energy = total_adc_energy + total_col_energy + total_row_energy + total_cim_unit_energy
        
            total_adc_energy = total_adc_energy/total_energy
            total_col_energy = total_col_energy/total_energy
            total_row_energy = total_row_energy/total_energy
            total_cim_unit_energy = total_cim_unit_energy/total_energy

            total_per_energy[(DNN, path)] = [total_adc_energy, total_col_energy, total_row_energy, total_cim_unit_energy]
            
        # Display overall energy
        print(f"Overall energy for DNN {DNN}: {total_energy} fJ")

        for i in range(4):
            print(f"total_per_energy[{DNN}][{path.split('/')[-1].split('_')[0].upper()}][{i}]: {total_per_energy[(DNN,path)][i]}")
        print() 
        
        # Display an energy breakdown for each layer as a bar chart. Display normalized per-MAC and per-layer energy.
        fig, ax = plt.subplots(figsize=(20, 5))
        
        bar_stacked(
            {i: r.per_compute("per_component_energy") * 1e15 for i, r in enumerate(results)},
            title= f"Using {path.split('/')[-1].split('_')[0].upper()} on {array_sizes} x {array_sizes} array sizes, {tech_node} nm running {DNN}",
            xlabel="Layer",
            ylabel="Energy (fJ/MAC)",
            ax=ax,
        )
# Out:
# Running vgg16 with 128 x 128 SRAM with 32 nm in fast scenario
# Computes for layer 1: 169344.0
# Computes for layer 2: 3612672.0
# Computes for layer 3: 1806336.0
# Computes for layer 4: 3612672.0
# Computes for layer 5: 1806336.0
# Computes for layer 6: 3612672.0
# Computes for layer 7: 3612672.0
# Computes for layer 8: 1806336.0
# Computes for layer 9: 3612672.0
# Computes for layer 10: 3612672.0
# Computes for layer 11: 903168.0
# Computes for layer 12: 903168.0
# Computes for layer 13: 903168.0
# Computes for layer 14: 200704.0
# Computes for layer 15: 32768.0
# Computes for layer 16: 8000.0
#
# Overall energy for DNN vgg16: 1000000000000030.8 fJ
# total_per_energy[vgg16][SRAM][0]: 0.7985268966502067
# total_per_energy[vgg16][SRAM][1]: 0.004820957159627002
# total_per_energy[vgg16][SRAM][2]: 0.19605623059565058
# total_per_energy[vgg16][SRAM][3]: 0.0005959155945156829
#
#
# Running vgg16 with 128 x 128 RRAM with 32 nm in fast scenario
# Computes for layer 1: 169344.0
# Computes for layer 2: 3612672.0
# Computes for layer 3: 1806336.0
# Computes for layer 4: 3612672.0
# Computes for layer 5: 1806336.0
# Computes for layer 6: 3612672.0
# Computes for layer 7: 3612672.0
# Computes for layer 8: 1806336.0
# Computes for layer 9: 3612672.0
# Computes for layer 10: 3612672.0
# Computes for layer 11: 903168.0
# Computes for layer 12: 903168.0
# Computes for layer 13: 903168.0
# Computes for layer 14: 200704.0
# Computes for layer 15: 32768.0
# Computes for layer 16: 8000.0
#
# Overall energy for DNN vgg16: 1000000000000037.1 fJ
# total_per_energy[vgg16][RRAM][0]: 0.7845134997435522
# total_per_energy[vgg16][RRAM][1]: 1.9714722363685405e-12
# total_per_energy[vgg16][RRAM][2]: 0.14518593988776937
# total_per_energy[vgg16][RRAM][3]: 0.07030056036670691
#
#
# Running gpt2_medium with 128 x 128 SRAM with 32 nm in fast scenario
# Computes for layer 1: 1572864.0
# Computes for layer 2: 524288.0
# Computes for layer 3: 512.0
# Computes for layer 4: 2048.0
# Computes for layer 5: 2097152.0
# Computes for layer 6: 2097152.0
# Computes for layer 7: 1572864.0
# Computes for layer 8: 524288.0
# Computes for layer 9: 512.0
# Computes for layer 10: 2048.0
# Computes for layer 11: 2097152.0
# Computes for layer 12: 2097152.0
# Computes for layer 13: 1572864.0
# Computes for layer 14: 524288.0
# Computes for layer 15: 512.0
# Computes for layer 16: 2048.0
# Computes for layer 17: 2097152.0
# Computes for layer 18: 2097152.0
# Computes for layer 19: 1572864.0
# Computes for layer 20: 524288.0
# Computes for layer 21: 512.0
# Computes for layer 22: 2048.0
# Computes for layer 23: 2097152.0
# Computes for layer 24: 2097152.0
# Computes for layer 25: 1572864.0
# Computes for layer 26: 524288.0
# Computes for layer 27: 512.0
# Computes for layer 28: 2048.0
# Computes for layer 29: 2097152.0
# Computes for layer 30: 2097152.0
# Computes for layer 31: 1572864.0
# Computes for layer 32: 524288.0
# Computes for layer 33: 512.0
# Computes for layer 34: 2048.0
# Computes for layer 35: 2097152.0
# Computes for layer 36: 2097152.0
# Computes for layer 37: 1572864.0
# Computes for layer 38: 524288.0
# Computes for layer 39: 512.0
# Computes for layer 40: 2048.0
# Computes for layer 41: 2097152.0
# Computes for layer 42: 2097152.0
# Computes for layer 43: 1572864.0
# Computes for layer 44: 524288.0
# Computes for layer 45: 512.0
# Computes for layer 46: 2048.0
# Computes for layer 47: 2097152.0
# Computes for layer 48: 2097152.0
# Computes for layer 49: 1572864.0
# Computes for layer 50: 524288.0
# Computes for layer 51: 512.0
# Computes for layer 52: 2048.0
# Computes for layer 53: 2097152.0
# Computes for layer 54: 2097152.0
# Computes for layer 55: 1572864.0
# Computes for layer 56: 524288.0
# Computes for layer 57: 512.0
# Computes for layer 58: 2048.0
# Computes for layer 59: 2097152.0
# Computes for layer 60: 2097152.0
# Computes for layer 61: 1572864.0
# Computes for layer 62: 524288.0
# Computes for layer 63: 512.0
# Computes for layer 64: 2048.0
# Computes for layer 65: 2097152.0
# Computes for layer 66: 2097152.0
# Computes for layer 67: 1572864.0
# Computes for layer 68: 524288.0
# Computes for layer 69: 512.0
# Computes for layer 70: 2048.0
# Computes for layer 71: 2097152.0
# Computes for layer 72: 2097152.0
# Computes for layer 73: 1572864.0
# Computes for layer 74: 524288.0
# Computes for layer 75: 512.0
# Computes for layer 76: 2048.0
# Computes for layer 77: 2097152.0
# Computes for layer 78: 2097152.0
# Computes for layer 79: 1572864.0
# Computes for layer 80: 524288.0
# Computes for layer 81: 512.0
# Computes for layer 82: 2048.0
# Computes for layer 83: 2097152.0
# Computes for layer 84: 2097152.0
# Computes for layer 85: 1572864.0
# Computes for layer 86: 524288.0
# Computes for layer 87: 512.0
# Computes for layer 88: 2048.0
# Computes for layer 89: 2097152.0
# Computes for layer 90: 2097152.0
# Computes for layer 91: 1572864.0
# Computes for layer 92: 524288.0
# Computes for layer 93: 512.0
# Computes for layer 94: 2048.0
# Computes for layer 95: 2097152.0
# Computes for layer 96: 2097152.0
# Computes for layer 97: 1572864.0
# Computes for layer 98: 524288.0
# Computes for layer 99: 512.0
# Computes for layer 100: 2048.0
# Computes for layer 101: 2097152.0
# Computes for layer 102: 2097152.0
# Computes for layer 103: 1572864.0
# Computes for layer 104: 524288.0
# Computes for layer 105: 512.0
# Computes for layer 106: 2048.0
# Computes for layer 107: 2097152.0
# Computes for layer 108: 2097152.0
# Computes for layer 109: 1572864.0
# Computes for layer 110: 524288.0
# Computes for layer 111: 512.0
# Computes for layer 112: 2048.0
# Computes for layer 113: 2097152.0
# Computes for layer 114: 2097152.0
# Computes for layer 115: 1572864.0
# Computes for layer 116: 524288.0
# Computes for layer 117: 512.0
# Computes for layer 118: 2048.0
# Computes for layer 119: 2097152.0
# Computes for layer 120: 2097152.0
# Computes for layer 121: 1572864.0
# Computes for layer 122: 524288.0
# Computes for layer 123: 512.0
# Computes for layer 124: 2048.0
# Computes for layer 125: 2097152.0
# Computes for layer 126: 2097152.0
# Computes for layer 127: 1572864.0
# Computes for layer 128: 524288.0
# Computes for layer 129: 512.0
# Computes for layer 130: 2048.0
# Computes for layer 131: 2097152.0
# Computes for layer 132: 2097152.0
# Computes for layer 133: 1572864.0
# Computes for layer 134: 524288.0
# Computes for layer 135: 512.0
# Computes for layer 136: 2048.0
# Computes for layer 137: 2097152.0
# Computes for layer 138: 2097152.0
# Computes for layer 139: 1572864.0
# Computes for layer 140: 524288.0
# Computes for layer 141: 512.0
# Computes for layer 142: 2048.0
# Computes for layer 143: 2097152.0
# Computes for layer 144: 2097152.0
# Computes for layer 145: 25731584.0
#
# Overall energy for DNN gpt2_medium: 1000000000000029.1 fJ
# total_per_energy[gpt2_medium][SRAM][0]: 0.49498867845044764
# total_per_energy[gpt2_medium][SRAM][1]: 0.003001527092731456
# total_per_energy[gpt2_medium][SRAM][2]: 0.5002545154552236
# total_per_energy[gpt2_medium][SRAM][3]: 0.0017552790015973338
#
#
# Running gpt2_medium with 128 x 128 RRAM with 32 nm in fast scenario
# Computes for layer 1: 1572864.0
# Computes for layer 2: 524288.0
# Computes for layer 3: 512.0
# Computes for layer 4: 2048.0
# Computes for layer 5: 2097152.0
# Computes for layer 6: 2097152.0
# Computes for layer 7: 1572864.0
# Computes for layer 8: 524288.0
# Computes for layer 9: 512.0
# Computes for layer 10: 2048.0
# Computes for layer 11: 2097152.0
# Computes for layer 12: 2097152.0
# Computes for layer 13: 1572864.0
# Computes for layer 14: 524288.0
# Computes for layer 15: 512.0
# Computes for layer 16: 2048.0
# Computes for layer 17: 2097152.0
# Computes for layer 18: 2097152.0
# Computes for layer 19: 1572864.0
# Computes for layer 20: 524288.0
# Computes for layer 21: 512.0
# Computes for layer 22: 2048.0
# Computes for layer 23: 2097152.0
# Computes for layer 24: 2097152.0
# Computes for layer 25: 1572864.0
# Computes for layer 26: 524288.0
# Computes for layer 27: 512.0
# Computes for layer 28: 2048.0
# Computes for layer 29: 2097152.0
# Computes for layer 30: 2097152.0
# Computes for layer 31: 1572864.0
# Computes for layer 32: 524288.0
# Computes for layer 33: 512.0
# Computes for layer 34: 2048.0
# Computes for layer 35: 2097152.0
# Computes for layer 36: 2097152.0
# Computes for layer 37: 1572864.0
# Computes for layer 38: 524288.0
# Computes for layer 39: 512.0
# Computes for layer 40: 2048.0
# Computes for layer 41: 2097152.0
# Computes for layer 42: 2097152.0
# Computes for layer 43: 1572864.0
# Computes for layer 44: 524288.0
# Computes for layer 45: 512.0
# Computes for layer 46: 2048.0
# Computes for layer 47: 2097152.0
# Computes for layer 48: 2097152.0
# Computes for layer 49: 1572864.0
# Computes for layer 50: 524288.0
# Computes for layer 51: 512.0
# Computes for layer 52: 2048.0
# Computes for layer 53: 2097152.0
# Computes for layer 54: 2097152.0
# Computes for layer 55: 1572864.0
# Computes for layer 56: 524288.0
# Computes for layer 57: 512.0
# Computes for layer 58: 2048.0
# Computes for layer 59: 2097152.0
# Computes for layer 60: 2097152.0
# Computes for layer 61: 1572864.0
# Computes for layer 62: 524288.0
# Computes for layer 63: 512.0
# Computes for layer 64: 2048.0
# Computes for layer 65: 2097152.0
# Computes for layer 66: 2097152.0
# Computes for layer 67: 1572864.0
# Computes for layer 68: 524288.0
# Computes for layer 69: 512.0
# Computes for layer 70: 2048.0
# Computes for layer 71: 2097152.0
# Computes for layer 72: 2097152.0
# Computes for layer 73: 1572864.0
# Computes for layer 74: 524288.0
# Computes for layer 75: 512.0
# Computes for layer 76: 2048.0
# Computes for layer 77: 2097152.0
# Computes for layer 78: 2097152.0
# Computes for layer 79: 1572864.0
# Computes for layer 80: 524288.0
# Computes for layer 81: 512.0
# Computes for layer 82: 2048.0
# Computes for layer 83: 2097152.0
# Computes for layer 84: 2097152.0
# Computes for layer 85: 1572864.0
# Computes for layer 86: 524288.0
# Computes for layer 87: 512.0
# Computes for layer 88: 2048.0
# Computes for layer 89: 2097152.0
# Computes for layer 90: 2097152.0
# Computes for layer 91: 1572864.0
# Computes for layer 92: 524288.0
# Computes for layer 93: 512.0
# Computes for layer 94: 2048.0
# Computes for layer 95: 2097152.0
# Computes for layer 96: 2097152.0
# Computes for layer 97: 1572864.0
# Computes for layer 98: 524288.0
# Computes for layer 99: 512.0
# Computes for layer 100: 2048.0
# Computes for layer 101: 2097152.0
# Computes for layer 102: 2097152.0
# Computes for layer 103: 1572864.0
# Computes for layer 104: 524288.0
# Computes for layer 105: 512.0
# Computes for layer 106: 2048.0
# Computes for layer 107: 2097152.0
# Computes for layer 108: 2097152.0
# Computes for layer 109: 1572864.0
# Computes for layer 110: 524288.0
# Computes for layer 111: 512.0
# Computes for layer 112: 2048.0
# Computes for layer 113: 2097152.0
# Computes for layer 114: 2097152.0
# Computes for layer 115: 1572864.0
# Computes for layer 116: 524288.0
# Computes for layer 117: 512.0
# Computes for layer 118: 2048.0
# Computes for layer 119: 2097152.0
# Computes for layer 120: 2097152.0
# Computes for layer 121: 1572864.0
# Computes for layer 122: 524288.0
# Computes for layer 123: 512.0
# Computes for layer 124: 2048.0
# Computes for layer 125: 2097152.0
# Computes for layer 126: 2097152.0
# Computes for layer 127: 1572864.0
# Computes for layer 128: 524288.0
# Computes for layer 129: 512.0
# Computes for layer 130: 2048.0
# Computes for layer 131: 2097152.0
# Computes for layer 132: 2097152.0
# Computes for layer 133: 1572864.0
# Computes for layer 134: 524288.0
# Computes for layer 135: 512.0
# Computes for layer 136: 2048.0
# Computes for layer 137: 2097152.0
# Computes for layer 138: 2097152.0
# Computes for layer 139: 1572864.0
# Computes for layer 140: 524288.0
# Computes for layer 141: 512.0
# Computes for layer 142: 2048.0
# Computes for layer 143: 2097152.0
# Computes for layer 144: 2097152.0
# Computes for layer 145: 25731584.0
#
# Overall energy for DNN gpt2_medium: 1000000000000035.4 fJ
# total_per_energy[gpt2_medium][RRAM][0]: 0.4703328509401236
# total_per_energy[gpt2_medium][RRAM][1]: 1.1823444283633175e-12
# total_per_energy[gpt2_medium][RRAM][2]: 0.35745296671447435
# total_per_energy[gpt2_medium][RRAM][3]: 0.17221418234421965

# %%
display_markdown(
    """
### Calculating Area in fast scenario

"""
)

# Initialize lists for each DNN
num_dnns = len(dnn_list)
total_area = [0] * (2 * num_dnns)
total_adc_area = [0] * (2 * num_dnns)
total_col_area = [0] * (2 * num_dnns)
total_row_area = [0] * (2 * num_dnns)
total_cim_unit_area = [0] * (2 * num_dnns)
total_macro = [0] * (2 * num_dnns)
energy = [0] * (2 * num_dnns)
throughput = [0] * (2 * num_dnns)

# Loop through both DNNs and extract their outputs for SRAM and RRAM
for i, dnn in enumerate(dnn_list):
    total_area[2 * i], total_adc_area[2 * i], total_col_area[2 * i], total_row_area[2 * i], total_cim_unit_area[2 * i], total_macro[2 * i], energy[2 * i], throughput[2 * i] = extract_outputs(f"SRAM_{dnn}_128_fast")
    
    total_area[2 * i + 1], total_adc_area[2 * i + 1], total_col_area[2 * i + 1], total_row_area[2 * i + 1], total_cim_unit_area[2 * i + 1], total_macro[2 * i + 1], energy[2 * i + 1], throughput[2 * i + 1] = extract_outputs(f"RRAM_{dnn}_128_fast")
# Out:
# ### Calculating Area in fast scenario
# ../outputs/SRAM_vgg16_128_fast/
# Model 	 Energy/inference (J) 	 Area (mm2) 	 Throughput (inf/s)
# Processing layer: SRAM_vgg16_128_fast_layer_1
# All macro: 1
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 28515.1
#
# All macro: 1
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 1054.65
#
# All macro: 1
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 928.496
#
# All macro: 1
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 5368.70912
#
# Total Area for layer 1: 35866.95512
#
# Total Macro for layer 1: 1
#
# Total Area for all layers: 35866.95512
# Total Area for ADC across all layers: 28515.1
# Processing layer: SRAM_vgg16_128_fast_layer_2
# Size: 5
# All macro: 5
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 142575.5
#
# Size: 5
# All macro: 5
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 5273.25
#
# Size: 5
# All macro: 5
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 4642.48
#
# Size: 5
# All macro: 5
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 26843.5456
#
# Total Area for layer 2: 179334.77560000002
#
# Total Macro for layer 2: 6
#
# Total Area for all layers: 215201.73072000002
# Total Area for ADC across all layers: 171090.6
# Processing layer: SRAM_vgg16_128_fast_layer_3
# Size: 2
# Size: 5
# All macro: 10
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 285151.0
#
# Size: 2
# Size: 5
# All macro: 10
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 10546.5
#
# Size: 2
# Size: 5
# All macro: 10
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 9284.96
#
# Size: 2
# Size: 5
# All macro: 10
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 53687.0912
#
# Total Area for layer 3: 358669.55120000005
#
# Total Macro for layer 3: 16
#
# Total Area for all layers: 573871.2819200001
# Total Area for ADC across all layers: 456241.6
# Processing layer: SRAM_vgg16_128_fast_layer_4
# Size: 3
# Size: 3
# Size: 2
# All macro: 18
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 513271.8
#
# Size: 3
# Size: 3
# Size: 2
# All macro: 18
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 18983.7
#
# Size: 3
# Size: 3
# Size: 2
# All macro: 18
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 16712.928
#
# Size: 3
# Size: 3
# Size: 2
# All macro: 18
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 96636.76416
#
# Total Area for layer 4: 645605.19216
#
# Total Macro for layer 4: 34
#
# Total Area for all layers: 1219476.47408
# Total Area for ADC across all layers: 969513.3999999999
# Processing layer: SRAM_vgg16_128_fast_layer_5
# Size: 3
# Size: 3
# Size: 4
# All macro: 36
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 1026543.6
#
# Size: 3
# Size: 3
# Size: 4
# All macro: 36
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 37967.4
#
# Size: 3
# Size: 3
# Size: 4
# All macro: 36
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 33425.856
#
# Size: 3
# Size: 3
# Size: 4
# All macro: 36
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 193273.52832
#
# Total Area for layer 5: 1291210.38432
#
# Total Macro for layer 5: 70
#
# Total Area for all layers: 2510686.8584000003
# Total Area for ADC across all layers: 1996057.0
# Processing layer: SRAM_vgg16_128_fast_layer_6
# Size: 3
# Size: 3
# Size: 4
# Size: 2
# All macro: 72
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 2053087.2
#
# Size: 3
# Size: 3
# Size: 4
# Size: 2
# All macro: 72
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 75934.8
#
# Size: 3
# Size: 3
# Size: 4
# Size: 2
# All macro: 72
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 66851.712
#
# Size: 3
# Size: 3
# Size: 4
# Size: 2
# All macro: 72
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 386547.05664
#
# Total Area for layer 6: 2582420.76864
#
# Total Macro for layer 6: 142
#
# Total Area for all layers: 5093107.627040001
# Total Area for ADC across all layers: 4049144.2
# Processing layer: SRAM_vgg16_128_fast_layer_7
# Size: 3
# Size: 3
# Size: 4
# Size: 2
# All macro: 72
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 2053087.2
#
# Size: 3
# Size: 3
# Size: 4
# Size: 2
# All macro: 72
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 75934.8
#
# Size: 3
# Size: 3
# Size: 4
# Size: 2
# All macro: 72
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 66851.712
#
# Size: 3
# Size: 3
# Size: 4
# Size: 2
# All macro: 72
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 386547.05664
#
# Total Area for layer 7: 2582420.76864
#
# Total Macro for layer 7: 214
#
# Total Area for all layers: 7675528.395680001
# Total Area for ADC across all layers: 6102231.4
# Processing layer: SRAM_vgg16_128_fast_layer_8
# Size: 3
# Size: 3
# Size: 8
# Size: 2
# All macro: 144
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 4106174.4
#
# Size: 3
# Size: 3
# Size: 8
# Size: 2
# All macro: 144
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 151869.6
#
# Size: 3
# Size: 3
# Size: 8
# Size: 2
# All macro: 144
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 133703.424
#
# Size: 3
# Size: 3
# Size: 8
# Size: 2
# All macro: 144
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 773094.11328
#
# Total Area for layer 8: 5164841.53728
#
# Total Macro for layer 8: 358
#
# Total Area for all layers: 12840369.93296
# Total Area for ADC across all layers: 10208405.8
# Processing layer: SRAM_vgg16_128_fast_layer_9
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 8212348.8
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 303739.2
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 267406.848
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 1546188.22656
#
# Total Area for layer 9: 10329683.07456
#
# Total Macro for layer 9: 646
#
# Total Area for all layers: 23170053.007519998
# Total Area for ADC across all layers: 18420754.6
# Processing layer: SRAM_vgg16_128_fast_layer_10
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 8212348.8
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 303739.2
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 267406.848
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 1546188.22656
#
# Total Area for layer 10: 10329683.07456
#
# Total Macro for layer 10: 934
#
# Total Area for all layers: 33499736.08208
# Total Area for ADC across all layers: 26633103.400000002
# Processing layer: SRAM_vgg16_128_fast_layer_11
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 8212348.8
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 303739.2
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 267406.848
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 1546188.22656
#
# Total Area for layer 11: 10329683.07456
#
# Total Macro for layer 11: 1222
#
# Total Area for all layers: 43829419.15664
# Total Area for ADC across all layers: 34845452.2
# Processing layer: SRAM_vgg16_128_fast_layer_12
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 8212348.8
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 303739.2
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 267406.848
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 1546188.22656
#
# Total Area for layer 12: 10329683.07456
#
# Total Macro for layer 12: 1510
#
# Total Area for all layers: 54159102.2312
# Total Area for ADC across all layers: 43057801.0
# Processing layer: SRAM_vgg16_128_fast_layer_13
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 8212348.8
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 303739.2
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 267406.848
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 1546188.22656
#
# Total Area for layer 13: 10329683.07456
#
# Total Macro for layer 13: 1798
#
# Total Area for all layers: 64488785.30576
# Total Area for ADC across all layers: 51270149.8
# Processing layer: SRAM_vgg16_128_fast_layer_14
# Size: 64
# Size: 49
# All macro: 3136
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 89423353.6
#
# Size: 64
# Size: 49
# All macro: 3136
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 3307382.4000000004
#
# Size: 64
# Size: 49
# All macro: 3136
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 2911763.456
#
# Size: 64
# Size: 49
# All macro: 3136
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 16836271.800320003
#
# Total Area for layer 14: 112478771.25632
#
# Total Macro for layer 14: 4934
#
# Total Area for all layers: 176967556.56208
# Total Area for ADC across all layers: 140693503.39999998
# Processing layer: SRAM_vgg16_128_fast_layer_15
# Size: 64
# Size: 32
# All macro: 2048
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 58398924.8
#
# Size: 64
# Size: 32
# All macro: 2048
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 2159923.2
#
# Size: 64
# Size: 32
# All macro: 2048
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 1901559.808
#
# Size: 64
# Size: 32
# All macro: 2048
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 10995116.27776
#
# Total Area for layer 15: 73455524.08576
#
# Total Macro for layer 15: 6982
#
# Total Area for all layers: 250423080.64784
# Total Area for ADC across all layers: 199092428.2
# Processing layer: SRAM_vgg16_128_fast_layer_16
# Size: 16
# Size: 32
# All macro: 512
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 14599731.2
#
# Size: 16
# Size: 32
# All macro: 512
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 539980.8
#
# Size: 16
# Size: 32
# All macro: 512
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 475389.952
#
# Size: 16
# Size: 32
# All macro: 512
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 2748779.06944
#
# Total Area for layer 16: 18363881.02144
#
# Total Macro for layer 16: 7494
#
# Total Area for all layers: 268786961.66928
# Total Area for ADC across all layers: 213692159.39999998
# Total Area for column drivers across all layers: 7903547.1
# Total Area for row drivers across all layers: 6958149.023999999
# Total Area for cim unit across all layers: 40233106.14528
#
#
# Total Area for ADC across all layers: 213.69215939999998
# Total Area for column driver across all layers: 7.903547099999999
# Total Area for row driver across all layers: 6.958149023999999
# Total Area for cim unit across all layers: 40.233106145280004
# Total Macro across all layers: 7494
# SRAM_vgg16_128_fast 	 4.88e-04 	 268.79 	 7.26e+01
# ../outputs/RRAM_vgg16_128_fast/
# Model 	 Energy/inference (J) 	 Area (mm2) 	 Throughput (inf/s)
# Processing layer: RRAM_vgg16_128_fast_layer_1
# All macro: 1
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 29755.8
#
# All macro: 1
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 441.013
#
# All macro: 1
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 504.015
#
# All macro: 1
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 671.08864
#
# Total Area for layer 1: 31371.91664
#
# Total Macro for layer 1: 1
#
# Total Area for all layers: 31371.91664
# Total Area for ADC across all layers: 29755.8
# Processing layer: RRAM_vgg16_128_fast_layer_2
# Size: 5
# All macro: 5
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 148779.0
#
# Size: 5
# All macro: 5
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 2205.065
#
# Size: 5
# All macro: 5
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 2520.075
#
# Size: 5
# All macro: 5
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 3355.4432
#
# Total Area for layer 2: 156859.58320000002
#
# Total Macro for layer 2: 6
#
# Total Area for all layers: 188231.49984000003
# Total Area for ADC across all layers: 178534.8
# Processing layer: RRAM_vgg16_128_fast_layer_3
# Size: 2
# Size: 5
# All macro: 10
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 297558.0
#
# Size: 2
# Size: 5
# All macro: 10
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 4410.13
#
# Size: 2
# Size: 5
# All macro: 10
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 5040.15
#
# Size: 2
# Size: 5
# All macro: 10
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 6710.8864
#
# Total Area for layer 3: 313719.16640000005
#
# Total Macro for layer 3: 16
#
# Total Area for all layers: 501950.66624000005
# Total Area for ADC across all layers: 476092.8
# Processing layer: RRAM_vgg16_128_fast_layer_4
# Size: 3
# Size: 3
# Size: 2
# All macro: 18
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 535604.4
#
# Size: 3
# Size: 3
# Size: 2
# All macro: 18
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 7938.2339999999995
#
# Size: 3
# Size: 3
# Size: 2
# All macro: 18
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 9072.27
#
# Size: 3
# Size: 3
# Size: 2
# All macro: 18
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 12079.59552
#
# Total Area for layer 4: 564694.4995200001
#
# Total Macro for layer 4: 34
#
# Total Area for all layers: 1066645.1657600002
# Total Area for ADC across all layers: 1011697.2
# Processing layer: RRAM_vgg16_128_fast_layer_5
# Size: 3
# Size: 3
# Size: 4
# All macro: 36
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 1071208.8
#
# Size: 3
# Size: 3
# Size: 4
# All macro: 36
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 15876.467999999999
#
# Size: 3
# Size: 3
# Size: 4
# All macro: 36
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 18144.54
#
# Size: 3
# Size: 3
# Size: 4
# All macro: 36
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 24159.19104
#
# Total Area for layer 5: 1129388.9990400001
#
# Total Macro for layer 5: 70
#
# Total Area for all layers: 2196034.1648000004
# Total Area for ADC across all layers: 2082906.0
# Processing layer: RRAM_vgg16_128_fast_layer_6
# Size: 3
# Size: 3
# Size: 4
# Size: 2
# All macro: 72
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 2142417.6
#
# Size: 3
# Size: 3
# Size: 4
# Size: 2
# All macro: 72
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 31752.935999999998
#
# Size: 3
# Size: 3
# Size: 4
# Size: 2
# All macro: 72
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 36289.08
#
# Size: 3
# Size: 3
# Size: 4
# Size: 2
# All macro: 72
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 48318.38208
#
# Total Area for layer 6: 2258777.9980800003
#
# Total Macro for layer 6: 142
#
# Total Area for all layers: 4454812.162880001
# Total Area for ADC across all layers: 4225323.6
# Processing layer: RRAM_vgg16_128_fast_layer_7
# Size: 3
# Size: 3
# Size: 4
# Size: 2
# All macro: 72
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 2142417.6
#
# Size: 3
# Size: 3
# Size: 4
# Size: 2
# All macro: 72
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 31752.935999999998
#
# Size: 3
# Size: 3
# Size: 4
# Size: 2
# All macro: 72
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 36289.08
#
# Size: 3
# Size: 3
# Size: 4
# Size: 2
# All macro: 72
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 48318.38208
#
# Total Area for layer 7: 2258777.9980800003
#
# Total Macro for layer 7: 214
#
# Total Area for all layers: 6713590.160960001
# Total Area for ADC across all layers: 6367741.199999999
# Processing layer: RRAM_vgg16_128_fast_layer_8
# Size: 3
# Size: 3
# Size: 8
# Size: 2
# All macro: 144
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 4284835.2
#
# Size: 3
# Size: 3
# Size: 8
# Size: 2
# All macro: 144
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 63505.871999999996
#
# Size: 3
# Size: 3
# Size: 8
# Size: 2
# All macro: 144
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 72578.16
#
# Size: 3
# Size: 3
# Size: 8
# Size: 2
# All macro: 144
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 96636.76416
#
# Total Area for layer 8: 4517555.996160001
#
# Total Macro for layer 8: 358
#
# Total Area for all layers: 11231146.15712
# Total Area for ADC across all layers: 10652576.399999999
# Processing layer: RRAM_vgg16_128_fast_layer_9
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 8569670.4
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 127011.74399999999
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 145156.32
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 193273.52832
#
# Total Area for layer 9: 9035111.992320001
#
# Total Macro for layer 9: 646
#
# Total Area for all layers: 20266258.14944
# Total Area for ADC across all layers: 19222246.799999997
# Processing layer: RRAM_vgg16_128_fast_layer_10
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 8569670.4
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 127011.74399999999
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 145156.32
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 193273.52832
#
# Total Area for layer 10: 9035111.992320001
#
# Total Macro for layer 10: 934
#
# Total Area for all layers: 29301370.141760003
# Total Area for ADC across all layers: 27791917.199999996
# Processing layer: RRAM_vgg16_128_fast_layer_11
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 8569670.4
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 127011.74399999999
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 145156.32
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 193273.52832
#
# Total Area for layer 11: 9035111.992320001
#
# Total Macro for layer 11: 1222
#
# Total Area for all layers: 38336482.13408001
# Total Area for ADC across all layers: 36361587.599999994
# Processing layer: RRAM_vgg16_128_fast_layer_12
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 8569670.4
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 127011.74399999999
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 145156.32
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 193273.52832
#
# Total Area for layer 12: 9035111.992320001
#
# Total Macro for layer 12: 1510
#
# Total Area for all layers: 47371594.12640001
# Total Area for ADC across all layers: 44931257.99999999
# Processing layer: RRAM_vgg16_128_fast_layer_13
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 8569670.4
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 127011.74399999999
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 145156.32
#
# Size: 3
# Size: 3
# Size: 8
# Size: 4
# All macro: 288
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 193273.52832
#
# Total Area for layer 13: 9035111.992320001
#
# Total Macro for layer 13: 1798
#
# Total Area for all layers: 56406706.11872001
# Total Area for ADC across all layers: 53500928.39999999
# Processing layer: RRAM_vgg16_128_fast_layer_14
# Size: 64
# Size: 49
# All macro: 3136
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 93314188.8
#
# Size: 64
# Size: 49
# All macro: 3136
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 1383016.768
#
# Size: 64
# Size: 49
# All macro: 3136
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 1580591.04
#
# Size: 64
# Size: 49
# All macro: 3136
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 2104533.9750400004
#
# Total Area for layer 14: 98382330.58304001
#
# Total Macro for layer 14: 4934
#
# Total Area for all layers: 154789036.70176002
# Total Area for ADC across all layers: 146815117.2
# Processing layer: RRAM_vgg16_128_fast_layer_15
# Size: 64
# Size: 32
# All macro: 2048
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 60939878.4
#
# Size: 64
# Size: 32
# All macro: 2048
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 903194.624
#
# Size: 64
# Size: 32
# All macro: 2048
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 1032222.72
#
# Size: 64
# Size: 32
# All macro: 2048
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 1374389.53472
#
# Total Area for layer 15: 64249685.27872
#
# Total Macro for layer 15: 6982
#
# Total Area for all layers: 219038721.98048002
# Total Area for ADC across all layers: 207754995.6
# Processing layer: RRAM_vgg16_128_fast_layer_16
# Size: 16
# Size: 32
# All macro: 512
# adc area: 29755.8, number of adc: 4096,
# total adc area: (29755.8*4096/4096) * macro = 15234969.6
#
# Size: 16
# Size: 32
# All macro: 512
# column drivers area: 441.013, number of column_drivers: 4096,
# total column drivers area: (441.013*4096/4096) * macro = 225798.656
#
# Size: 16
# Size: 32
# All macro: 512
# row drivers area: 504.015, number of row_drivers: 4096,
# total row drivers area: (504.015*4096/4096) * macro = 258055.68
#
# Size: 16
# Size: 32
# All macro: 512
# cim unit area: 0.04096, number of cim_unit: 67108864,
# total cim unit area: (0.04096*67108864/4096) * macro = 343597.38368
#
# Total Area for layer 16: 16062421.31968
#
# Total Macro for layer 16: 7494
#
# Total Area for all layers: 235101143.30016002
# Total Area for ADC across all layers: 222989965.2
# Total Area for column drivers across all layers: 3304951.422
# Total Area for row drivers across all layers: 3777088.4100000006
# Total Area for cim unit across all layers: 5029138.26816
#
#
# Total Area for ADC across all layers: 222.98996519999997
# Total Area for column driver across all layers: 3.304951422
# Total Area for row driver across all layers: 3.7770884100000006
# Total Area for cim unit across all layers: 5.0291382681600005
# Total Macro across all layers: 7494
# RRAM_vgg16_128_fast 	 5.91e-04 	 235.10 	 7.26e+01
# ../outputs/SRAM_gpt2_medium_128_fast/
# Model 	 Energy/inference (J) 	 Area (mm2) 	 Throughput (inf/s)
# Processing layer: SRAM_gpt2_medium_128_fast_layer_1
# Size: 48
# Size: 8
# All macro: 384
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 10949798.399999999
#
# Size: 48
# Size: 8
# All macro: 384
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 404985.60000000003
#
# Size: 48
# Size: 8
# All macro: 384
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 356542.464
#
# Size: 48
# Size: 8
# All macro: 384
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 2061584.3020800003
#
# Total Area for layer 1: 13772910.766079998
#
# Total Macro for layer 1: 384
#
# Total Area for all layers: 13772910.766079998
# Total Area for ADC across all layers: 10949798.399999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_2
# Size: 16
# Size: 8
# All macro: 128
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 3649932.8
#
# Size: 16
# Size: 8
# All macro: 128
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 134995.2
#
# Size: 16
# Size: 8
# All macro: 128
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 118847.488
#
# Size: 16
# Size: 8
# All macro: 128
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 687194.76736
#
# Total Area for layer 2: 4590970.25536
#
# Total Macro for layer 2: 512
#
# Total Area for all layers: 18363881.02144
# Total Area for ADC across all layers: 14599731.2
# Processing layer: SRAM_gpt2_medium_128_fast_layer_3
# Size: 2
# All macro: 2
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 57030.2
#
# Size: 2
# All macro: 2
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 2109.3
#
# Size: 2
# All macro: 2
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 1856.992
#
# Size: 2
# All macro: 2
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 10737.41824
#
# Total Area for layer 3: 71733.91024
#
# Total Macro for layer 3: 514
#
# Total Area for all layers: 18435614.931679998
# Total Area for ADC across all layers: 14656761.399999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_4
# Size: 4
# Size: 2
# All macro: 8
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 228120.8
#
# Size: 4
# Size: 2
# All macro: 8
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 8437.2
#
# Size: 4
# Size: 2
# All macro: 8
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 7427.968
#
# Size: 4
# Size: 2
# All macro: 8
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 42949.67296
#
# Total Area for layer 4: 286935.64096
#
# Total Macro for layer 4: 522
#
# Total Area for all layers: 18722550.572639998
# Total Area for ADC across all layers: 14884882.2
# Processing layer: SRAM_gpt2_medium_128_fast_layer_5
# Size: 64
# Size: 8
# All macro: 512
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 14599731.2
#
# Size: 64
# Size: 8
# All macro: 512
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 539980.8
#
# Size: 64
# Size: 8
# All macro: 512
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 475389.952
#
# Size: 64
# Size: 8
# All macro: 512
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 2748779.06944
#
# Total Area for layer 5: 18363881.02144
#
# Total Macro for layer 5: 1034
#
# Total Area for all layers: 37086431.59408
# Total Area for ADC across all layers: 29484613.4
# Processing layer: SRAM_gpt2_medium_128_fast_layer_6
# Size: 16
# Size: 32
# All macro: 512
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 14599731.2
#
# Size: 16
# Size: 32
# All macro: 512
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 539980.8
#
# Size: 16
# Size: 32
# All macro: 512
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 475389.952
#
# Size: 16
# Size: 32
# All macro: 512
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 2748779.06944
#
# Total Area for layer 6: 18363881.02144
#
# Total Macro for layer 6: 1546
#
# Total Area for all layers: 55450312.61552
# Total Area for ADC across all layers: 44084344.599999994
# Processing layer: SRAM_gpt2_medium_128_fast_layer_7
# Size: 48
# Size: 8
# All macro: 384
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 10949798.399999999
#
# Size: 48
# Size: 8
# All macro: 384
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 404985.60000000003
#
# Size: 48
# Size: 8
# All macro: 384
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 356542.464
#
# Size: 48
# Size: 8
# All macro: 384
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 2061584.3020800003
#
# Total Area for layer 7: 13772910.766079998
#
# Total Macro for layer 7: 1930
#
# Total Area for all layers: 69223223.38159999
# Total Area for ADC across all layers: 55034142.99999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_8
# Size: 16
# Size: 8
# All macro: 128
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 3649932.8
#
# Size: 16
# Size: 8
# All macro: 128
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 134995.2
#
# Size: 16
# Size: 8
# All macro: 128
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 118847.488
#
# Size: 16
# Size: 8
# All macro: 128
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 687194.76736
#
# Total Area for layer 8: 4590970.25536
#
# Total Macro for layer 8: 2058
#
# Total Area for all layers: 73814193.63696
# Total Area for ADC across all layers: 58684075.79999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_9
# Size: 2
# All macro: 2
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 57030.2
#
# Size: 2
# All macro: 2
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 2109.3
#
# Size: 2
# All macro: 2
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 1856.992
#
# Size: 2
# All macro: 2
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 10737.41824
#
# Total Area for layer 9: 71733.91024
#
# Total Macro for layer 9: 2060
#
# Total Area for all layers: 73885927.5472
# Total Area for ADC across all layers: 58741105.99999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_10
# Size: 4
# Size: 2
# All macro: 8
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 228120.8
#
# Size: 4
# Size: 2
# All macro: 8
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 8437.2
#
# Size: 4
# Size: 2
# All macro: 8
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 7427.968
#
# Size: 4
# Size: 2
# All macro: 8
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 42949.67296
#
# Total Area for layer 10: 286935.64096
#
# Total Macro for layer 10: 2068
#
# Total Area for all layers: 74172863.18815999
# Total Area for ADC across all layers: 58969226.79999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_11
# Size: 64
# Size: 8
# All macro: 512
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 14599731.2
#
# Size: 64
# Size: 8
# All macro: 512
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 539980.8
#
# Size: 64
# Size: 8
# All macro: 512
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 475389.952
#
# Size: 64
# Size: 8
# All macro: 512
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 2748779.06944
#
# Total Area for layer 11: 18363881.02144
#
# Total Macro for layer 11: 2580
#
# Total Area for all layers: 92536744.20959999
# Total Area for ADC across all layers: 73568957.99999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_12
# Size: 16
# Size: 32
# All macro: 512
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 14599731.2
#
# Size: 16
# Size: 32
# All macro: 512
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 539980.8
#
# Size: 16
# Size: 32
# All macro: 512
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 475389.952
#
# Size: 16
# Size: 32
# All macro: 512
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 2748779.06944
#
# Total Area for layer 12: 18363881.02144
#
# Total Macro for layer 12: 3092
#
# Total Area for all layers: 110900625.23103999
# Total Area for ADC across all layers: 88168689.19999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_13
# Size: 48
# Size: 8
# All macro: 384
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 10949798.399999999
#
# Size: 48
# Size: 8
# All macro: 384
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 404985.60000000003
#
# Size: 48
# Size: 8
# All macro: 384
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 356542.464
#
# Size: 48
# Size: 8
# All macro: 384
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 2061584.3020800003
#
# Total Area for layer 13: 13772910.766079998
#
# Total Macro for layer 13: 3476
#
# Total Area for all layers: 124673535.99711998
# Total Area for ADC across all layers: 99118487.6
# Processing layer: SRAM_gpt2_medium_128_fast_layer_14
# Size: 16
# Size: 8
# All macro: 128
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 3649932.8
#
# Size: 16
# Size: 8
# All macro: 128
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 134995.2
#
# Size: 16
# Size: 8
# All macro: 128
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 118847.488
#
# Size: 16
# Size: 8
# All macro: 128
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 687194.76736
#
# Total Area for layer 14: 4590970.25536
#
# Total Macro for layer 14: 3604
#
# Total Area for all layers: 129264506.25247997
# Total Area for ADC across all layers: 102768420.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_15
# Size: 2
# All macro: 2
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 57030.2
#
# Size: 2
# All macro: 2
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 2109.3
#
# Size: 2
# All macro: 2
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 1856.992
#
# Size: 2
# All macro: 2
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 10737.41824
#
# Total Area for layer 15: 71733.91024
#
# Total Macro for layer 15: 3606
#
# Total Area for all layers: 129336240.16271996
# Total Area for ADC across all layers: 102825450.6
# Processing layer: SRAM_gpt2_medium_128_fast_layer_16
# Size: 4
# Size: 2
# All macro: 8
# adc area: 28515.1, number of adc: 4096,
# total adc area: (28515.1*4096/4096) * macro = 228120.8
#
# Size: 4
# Size: 2
# All macro: 8
# column drivers area: 1054.65, number of column_drivers: 4096,
# total column drivers area: (1054.65*4096/4096) * macro = 8437.2
#
# Size: 4
# Size: 2
# All macro: 8
# row drivers area: 928.496, number of row_drivers: 4096,
# total row drivers area: (928.496*4096/4096) * macro = 7427.968
#
# Size: 4
# Size: 2
# All macro: 8
# cim unit area: 0.32768, number of cim_unit: 67108864,
# total cim unit area: (0.32768*67108864/4096) * macro = 42949.67296
#
# Total Area for layer 16: 286935.64096
#
# Total Macro for layer 16: 3614
#
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_17
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_18
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_19
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_20
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_21
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_22
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_23
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_24
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_25
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_26
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_27
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_28
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_29
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_30
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_31
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_32
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_33
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_34
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_35
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_36
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_37
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_38
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_39
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_40
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_41
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_42
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_43
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_44
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_45
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_46
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_47
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_48
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_49
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_50
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_51
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_52
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_53
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_54
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_55
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_56
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_57
# Total Area for all layers: 129623175.80367996
# Total Area for ADC across all layers: 103053571.39999999
# Processing layer: SRAM_gpt2_medium_128_fast_layer_58
# Total Area for all layers: 129623175.80367996
# ...
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_41
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_42
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_43
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_44
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_45
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_46
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_47
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_48
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_49
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_50
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_51
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_52
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_53
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_54
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_55
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_56
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_57
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_58
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_59
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_60
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_61
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_62
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_63
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_64
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_65
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_66
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_67
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_68
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_69
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_70
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_71
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_72
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_73
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_74
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_75
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_76
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_77
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_78
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_79
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_80
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_81
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_82
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_83
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_84
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_85
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_86
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_87
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_88
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_89
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_90
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_91
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_92
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_93
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_94
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_95
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_96
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_97
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_98
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_99
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_100
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_101
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_102
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_103
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_104
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_105
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_106
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_107
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_108
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_109
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_110
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_111
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_112
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_113
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_114
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_115
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_116
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_117
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_118
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_119
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_120
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_121
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_122
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_123
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_124
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_125
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_126
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_127
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_128
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_129
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_130
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_131
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_132
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_133
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_134
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_135
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_136
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_137
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_138
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_139
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_140
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_141
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_142
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_143
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_144
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Processing layer: RRAM_gpt2_medium_128_fast_layer_145
# Total Area for all layers: 113378106.73696
# Total Area for ADC across all layers: 107537461.2
# Total Area for column drivers across all layers: 1593820.9820000003
# Total Area for row drivers across all layers: 1821510.21
# Total Area for cim unit across all layers: 2425314.34496
#
#
# Total Area for ADC across all layers: 107.5374612
# Total Area for column driver across all layers: 1.5938209820000002
# Total Area for row driver across all layers: 1.8215102099999998
# Total Area for cim unit across all layers: 2.42531434496
# Total Macro across all layers: 3614
# RRAM_gpt2_medium_128_fast 	 3.16e-03 	 113.38 	 3.87e+02

# %%
print("\n### Area and Performance Results ###\n")

for i, dnn in enumerate(dnn_list):
    print(f"Results for {dnn} (SRAM):")
    print(f"  Total Area: {total_area[2 * i]}")
    print(f"  ADC Area: {total_adc_area[2 * i]}")
    print(f"  Column Driver Area: {total_col_area[2 * i]}")
    print(f"  Row Driver Area: {total_row_area[2 * i]}")
    print(f"  CIM Unit Area: {total_cim_unit_area[2 * i]}")
    print(f"  Total Macro: {total_macro[2 * i]}")
    print(f"  Energy: {energy[2 * i]}")
    print(f"  Throughput: {throughput[2 * i]}\n")

    print(f"Results for {dnn} (RRAM):")
    print(f"  Total Area: {total_area[2 * i + 1]}")
    print(f"  ADC Area: {total_adc_area[2 * i + 1]}")
    print(f"  Column Driver Area: {total_col_area[2 * i + 1]}")
    print(f"  Row Driver Area: {total_row_area[2 * i + 1]}")
    print(f"  CIM Unit Area: {total_cim_unit_area[2 * i + 1]}")
    print(f"  Total Macro: {total_macro[2 * i + 1]}")
    print(f"  Energy: {energy[2 * i + 1]}")
    print(f"  Throughput: {throughput[2 * i + 1]}\n")
# Out:
# ### Area and Performance Results ###
#
# Results for vgg16 (SRAM):
#   Total Area: 268.78696166928
#   ADC Area: 213.69215939999998
#   Column Driver Area: 7.903547099999999
#   Row Driver Area: 6.958149023999999
#   CIM Unit Area: 40.233106145280004
#   Total Macro: 7494
#   Energy: 0.0004879689999999999
#   Throughput: 72.57210038172926
#
# Results for vgg16 (RRAM):
#   Total Area: 235.10114330016
#   ADC Area: 222.98996519999997
#   Column Driver Area: 3.304951422
#   Row Driver Area: 3.7770884100000006
#   CIM Unit Area: 5.0291382681600005
#   Total Macro: 7494
#   Energy: 0.000590666
#   Throughput: 72.57210038172926
#
# Results for gpt2_medium (SRAM):
#   Total Area: 129.62317580367994
#   ADC Area: 103.05357139999998
#   Column Driver Area: 3.8115050999999998
#   Row Driver Area: 3.355584544
#   CIM Unit Area: 19.40251475968
#   Total Macro: 3614
#   Energy: 0.0026079909
#   Throughput: 386.75742574257424
#
# Results for gpt2_medium (RRAM):
#   Total Area: 113.37810673695999
#   ADC Area: 107.5374612
#   Column Driver Area: 1.5938209820000002
#   Row Driver Area: 1.8215102099999998
#   CIM Unit Area: 2.42531434496
#   Total Macro: 3614
#   Energy: 0.0031604893099999995
#   Throughput: 386.75742574257424

# %%
import matplotlib.pyplot as plt
import numpy as np

sram_label = "SRAM"
rram_label = "RRAM"

x = np.arange(len(dnn_list))  # Number of DNNs
width = 0.35  # Bar width

# Create figure and axes for three different plots (energy, area, throughput)
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(18, 6))

# Energy Plot
ax1.bar(x - width/2, energy[::2], width, label=sram_label, color='tab:blue')  # SRAM for DNN1, DNN2
ax1.bar(x + width/2, energy[1::2], width, label=rram_label, color='tab:red')  # RRAM for DNN1, DNN2
ax1.set_title("Energy Consumption")
ax1.set_xticks(x)
ax1.set_xticklabels(dnn_list)
ax1.set_xlabel("DNN models")
ax1.set_ylabel("Energy")
ax1.legend()

# Area Plot
ax2.bar(x - width/2, total_area[::2], width, label=sram_label, color='tab:blue')  # SRAM for DNN1, DNN2
ax2.bar(x + width/2, total_area[1::2], width, label=rram_label, color='tab:red')  # RRAM for DNN1, DNN2
ax2.set_title("Area")
ax2.set_xticks(x)
ax2.set_xticklabels(dnn_list)
ax2.set_xlabel("DNN models")
ax2.set_ylabel("Area")
ax2.legend()

# Throughput Plot
ax3.bar(x - width/2, throughput[::2], width, label=sram_label, color='tab:blue')  # SRAM for DNN1, DNN2
ax3.bar(x + width/2, throughput[1::2], width, label=rram_label, color='tab:red')  # RRAM for DNN1, DNN2
ax3.set_title("Throughput")
ax3.set_xticks(x)
ax3.set_xticklabels(dnn_list)
ax3.set_xlabel("DNN models")
ax3.set_ylabel("Throughput")
ax3.legend()

# Adjust layout for better spacing
plt.tight_layout()
plt.show()

# %%
display_markdown(
    """
### Calculating the energy

"""
)

path_list = [SRAM_PATH, RRAM_PATH]
total_adc_energy = [0] * 4
total_col_energy = [0] * 4
total_row_energy = [0] * 4
total_cim_unit_energy = [0] * 4
for j in range(len(energy)):
    if j == 0:
        for i in range(4):
            if i == 0:
                total_adc_energy[j] = total_per_energy[(dnn_list[0], path_list[0])][i] * energy[j]
            elif i == 1:
                total_col_energy[j] = total_per_energy[(dnn_list[0], path_list[0])][i] * energy[j]
            elif i == 2:
                total_row_energy[j] = total_per_energy[(dnn_list[0], path_list[0])][i] * energy[j]
            else:
                total_cim_unit_energy[j] = total_per_energy[(dnn_list[0], path_list[0])][i] * energy[j]
    elif j == 1:
        for i in range(4):
            if i == 0:
                total_adc_energy[j] = total_per_energy[(dnn_list[0], path_list[1])][i] * energy[j]
            elif i == 1:
                total_col_energy[j] = total_per_energy[(dnn_list[0], path_list[1])][i] * energy[j]
            elif i == 2:
                total_row_energy[j] = total_per_energy[(dnn_list[0], path_list[1])][i] * energy[j]
            else:
                total_cim_unit_energy[j] = total_per_energy[(dnn_list[0], path_list[1])][i] * energy[j]
    elif j == 2:
        for i in range(4):
            if i == 0:
                total_adc_energy[j] = total_per_energy[(dnn_list[1], path_list[0])][i] * energy[j]
            elif i == 1:
                total_col_energy[j] = total_per_energy[(dnn_list[1], path_list[0])][i] * energy[j]
            elif i == 2:
                total_row_energy[j] = total_per_energy[(dnn_list[1], path_list[0])][i] * energy[j]
            else:
                total_cim_unit_energy[j] = total_per_energy[(dnn_list[1], path_list[0])][i] * energy[j]
    else:
        for i in range(4):
            if i == 0:
                total_adc_energy[j] = total_per_energy[(dnn_list[1], path_list[1])][i] * energy[j]
            elif i == 1:
                total_col_energy[j] = total_per_energy[(dnn_list[1], path_list[1])][i] * energy[j]
            elif i == 2:
                total_row_energy[j] = total_per_energy[(dnn_list[1], path_list[1])][i] * energy[j]
            else:
                total_cim_unit_energy[j] = total_per_energy[(dnn_list[1], path_list[1])][i] * energy[j]

    
print("Total ADC Energy:", total_adc_energy)
print("Total Column Energy:", total_col_energy)
print("Total Row Energy:", total_row_energy)
print("Total CIM Unit Energy:", total_cim_unit_energy)
# Out:
# ### Calculating the energy
# Total ADC Energy: [0.00038965637123150463, 0.000463385450839525, 0.0012909259690017936, 0.0014864819475380838]
# Total Column Energy: [2.352477644226028e-06, 1.1644816199668604e-15, 7.827955343947094e-06, 3.736786926580325e-15]
# Total Row Energy: [9.566936278752899e-05, 8.575639836974919e-05, 0.0013046592239911324, 0.0011297262801288818]
# Total CIM Unit Energy: [2.9078833674022323e-07, 4.15241507895613e-05, 4.577751663126932e-06, 0.0005442810823292969]

# %%
import matplotlib.pyplot as plt
import numpy as np
fig, ax = plt.subplots(figsize=(10, 6)) 
path = ['SRAM', 'RRAM']
num_bars = len(dnn_list) * len(path)

x = np.arange(num_bars)

# Stack bars
ax.bar(x, total_cim_unit_energy, label='cim_unit')
ax.bar(x, total_row_energy, bottom=total_cim_unit_energy, label='row_drivers')
ax.bar(x, total_col_energy, bottom=np.array(total_cim_unit_energy) + np.array(total_row_energy), label='column_drivers')
ax.bar(x, total_adc_energy, bottom=np.array(total_cim_unit_energy) + np.array(total_row_energy) + np.array(total_col_energy), label='adc')

# Labels and title
ax.set_title(f"Energy vs Memory Type for {DNN} in fast scenario")
ax.set_xlabel("Memory type")
ax.set_ylabel("Energy (J)")
# Set x-ticks
xtick_labels = [f"{mem}-{dnn}" for dnn in dnn_list for mem in path]
ax.set_xticks(x)
ax.set_xticklabels(xtick_labels)

ax.legend()

# Show plot
plt.show()
